# %%
import pandas as pd
import numpy as np
import os
from typing import Callable # this is to define test_func functions dtype as function itself
import re # for regural expression
import warnings
warnings.filterwarnings('ignore')

# %%
print(os.getcwd())
os.chdir(r'd:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem')
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem

# %%
mi = pd.read_csv(filepath_or_buffer=r'data\raw_data\mi_mobile_new_data.csv',   index_col=False)
samsung = pd.read_csv(filepath_or_buffer=r'data\raw_data\samsung_mobile_new_data.csv',   index_col=False)
apple = pd.read_csv(filepath_or_buffer=r'data\raw_data\apple_mobile_new_data.csv',   index_col=False)
onePlus = pd.read_csv(filepath_or_buffer=r'data\raw_data\one_plus_mobile_new_data.csv',   index_col=False)
realme = pd.read_csv(filepath_or_buffer=r'data\raw_data\realme_mobile_data.csv',   index_col=False)
vivo = pd.read_csv(filepath_or_buffer=r'data\raw_data\vivo_mobile_data.csv',   index_col=False)
oppo = pd.read_csv(filepath_or_buffer=r'data\raw_data\oppo_mobile_data.csv',   index_col=False)
motorola = pd.read_csv(filepath_or_buffer=r'data\raw_data\motorola_mobile_data.csv',   index_col=False)
techno = pd.read_csv(filepath_or_buffer=r'data\raw_data\techno_mobile_data.csv',   index_col=False)
infinix = pd.read_csv(filepath_or_buffer=r'data\raw_data\infinix_mobile_data.csv',   index_col=False)

# %%
infinix.rename({'camera':'os_processor','oS_Processor':'camera'},axis=1,inplace=True)
# techno.rename({'camera':'os_processor','oS_Processor':'camera'},axis=1,inplace=True)
motorola.rename({'camera':'os_processor','oS_Processor':'camera'},axis=1,inplace=True)
vivo.rename({'camera':'os_processor','oS_Processor':'camera'},axis=1,inplace=True)
realme.rename({'camera':'os_processor','oS_Processor':'camera'},axis=1,inplace=True)

dataframes_list = [mi, samsung, apple, onePlus, realme, vivo, oppo, motorola, techno, infinix]

# %%
for i in dataframes_list:
    i.drop_duplicates(inplace=True)

# %%
dataframes_dict = {
    'mi': mi,
    'samsung': samsung,
    'apple': apple,
    'onePlus': onePlus,
    'realme': realme,
    'vivo': vivo,
    'oppo': oppo,
    'motorola': motorola,
    'techno': techno,
    'infinix': infinix
}

# %% [markdown]
# ## Shape

# %%
for i,j in dataframes_dict.items():
    print(f'{i} data shape :{j.shape}')
# Out:
# mi data shape :(517, 10)
# samsung data shape :(566, 10)
# apple data shape :(424, 10)
# onePlus data shape :(188, 10)
# realme data shape :(249, 10)
# vivo data shape :(308, 10)
# oppo data shape :(251, 10)
# motorola data shape :(119, 10)
# techno data shape :(151, 10)
# infinix data shape :(165, 10)

# %% [markdown]
# ## Handle Null values

# %%
for key,value in dataframes_dict.items():
    print(f'dataframe is {key} \n {sum(value.isnull().sum())}')
    print()
# Out:
# dataframe is mi
#  28
#
# dataframe is samsung
#  81
#
# dataframe is apple
#  322
#
# dataframe is onePlus
#  0
#
# dataframe is realme
#  35
#
# dataframe is vivo
#  7
#
# dataframe is oppo
#  0
#
# dataframe is motorola
#  0
#
# dataframe is techno
#  0
#
# dataframe is infinix
#  2

# %%
mi.dropna(inplace=True)
realme.dropna(inplace=True)
vivo.dropna(inplace=True)
infinix.dropna(inplace=True)
samsung.dropna(inplace=True)

# %%
oppo[oppo['ratings'].isnull() ==True]
# Out:
# Empty DataFrame
# Columns: [name, ratings, price, imgURL, storage_ram, os_processor, camera, display, network, battery]
# Index: []

# %%
# oppo['ratings'][46] = 4.3
# oppo['ratings'][47] = 4.3
# oppo['ratings'][167] = 4.5
# oppo['ratings'][191] = 4.1
# oppo['ratings'][214] = 4.3
# oppo['ratings'][215] = 4.3
# oppo['ratings'][239] = 4.4
# oppo['ratings'][263] = 4.4
# oppo['os_processor'][191] = 'Operating SystemAndroid Pie Android v9.0 (Pie)Processor CoreOcta CorePrimary Clock Speed0.1 MHz'

# %%
for key,value in dataframes_dict.items():
    print(f'dataframe is {key} \n {sum(value.isnull().sum())}')
    print()
# Out:
# dataframe is mi
#  0
#
# dataframe is samsung
#  0
#
# dataframe is apple
#  322
#
# dataframe is onePlus
#  0
#
# dataframe is realme
#  0
#
# dataframe is vivo
#  0
#
# dataframe is oppo
#  0
#
# dataframe is motorola
#  0
#
# dataframe is techno
#  0
#
# dataframe is infinix
#  0

# %%
def random_values(col_name:str,df:pd.DataFrame,total=6):
    for i in range(0,total):
        index = np.random.randint(df.shape[0])
        print(index,':',df[col_name].iloc[index])

# %% [markdown]
# # Price

# %%
def clean_price_col(dataframe:pd.DataFrame):
    dataframe.reset_index(inplace=True)
    for Index,i in enumerate(dataframe['price']):
        i = str(i).replace('₹','')
        i = str(i).replace(',','')
        dataframe['price'][Index] = i

    dataframe['price'] = dataframe['price'].astype('Int16')
    dataframe['price'] = dataframe['price'].abs()  

    show = f'datatype -{dataframe["price"].dtype}'   
    return show

# %% [markdown]
# ## storage_ram

# %%
def remove_internal(txt):
    return txt.replace('Internal','')

# %%
## Going to remove 'Storage32 GBRAM2 GBExpandable Storage128' words after this.....
def cut_remove_words(txt):
    split = txt.split()
    if 'GBExpandable' in split:
        string = split[:5]
        extract_GB_TB = string[-1]
        pattern = r'[TB]+|[GB]+'
        found = re.findall(pattern,extract_GB_TB)

        final_string = ' '.join(string[:4]) + ''.join(found)

        return final_string
    else:
        return ' '.join(split[:2])

# %%
def func_apply(func:Callable,col_name,df:pd.DataFrame,df_name=None):
    df[col_name] = df[col_name].apply(func)
    print(f'Successfully applied function in {df_name}')
    
    print(f'{random_values(col_name=col_name,df=df,total=6)}')

# %% [markdown]
# ## remove Operating

# %%
def remove_operating(txt):
    return txt.replace('Operating','')

for i in dataframes_list:
    print(func_apply(func=remove_operating,col_name='os_processor',df=i,df_name=None))
# Out:
# Successfully applied function in None
# 106 :  SystemAndroid Pie 9Processor TypeQualcomm Snapdragon 660 AIEProcessor CoreOcta CorePrimary Clock Speed2.2 GHzSecondary Clock Speed1.8 GHz FrequencyGSM: B2, B3, B5, B8, WCDMA: B1, B2, B5, B8, 4G LTE-TDD: B40, B41, 4G LTE-FDD: B1, B3, B5, B8, CA: 1C (Only DLCA), 3C, 40C, 41C
# 61 :  SystemAndroid 11Processor CoreOcta CorePrimary Clock Speed2.4 GHz
# 354 :  SystemAndroid 12Processor TypeMediatek MT6769Z Helio G85Processor CoreOcta CorePrimary Clock Speed2 GHzSecondary Clock Speed1.8 GHz
# 380 :  SystemAndroid Oreo 8.1Processor CoreQuad CorePrimary Clock Speed2 GHz
# 332 :  SystemAndroid Android 13Processor CoreOcta CorePrimary Clock Speed2.2 GHz
# 221 :  SystemAndroid 12Processor TypeMediatek Dimensity 1080Processor CoreOcta CorePrimary Clock Speed2.6 GHzSecondary Clock Speed2 GHz Frequency2G GSM: B3/B5/B8, 3G WCDMA: B1/B5/B6/B8/B19, 4G LTE TDD: B34/B38/B39/B40/B41, 4G LTE FDD: B1/B3/B5/B8/B19, 5G SA: N1/N3/N5/N8/N28A/N38/N40/N41/N77/N78, 5G NSA: N38/N40/N41/N77/N78
# None
# None
# Successfully applied function in None
# 520 :  SystemAndroid 10Processor TypeExynos 2100Processor CoreOcta CorePrimary Clock Speed2.9 GHz
# 352 :  System0v FrequencyGSM - 900, 1800
# 262 :  SystemAndroid Q 10Processor TypeMediaTek | MT6739WW quad coreProcessor CoreOcta CorePrimary Clock Speed1.5 GHzSecondary Clock Speed2 GHz
# 466 :  SystemAndroid Android v12.0Processor CoreOcta CorePrimary Clock Speed2 GHz
# 72 :  SystemAndroid 13Processor TypeQualcomm Snapdragon 8 Gen 2Processor CoreOcta CorePrimary Clock Speed3.36 GHzSecondary Clock Speed3.36 GHz Frequency2G GSM: 850/900/1800/1900 MHz
# 110 :  SystemAndroid 13Processor TypeQualcomm Snapdragon 8 Gen 2Processor CoreOcta CorePrimary Clock Speed3.36 GHzSecondary Clock Speed3.36 GHz Frequency2G GSM: 850/900/1800/1900 MHz
# None
# None
# Successfully applied function in None
# 170 :  SystemiOS 15Processor TypeA15 Bionic ChipProcessor CoreHexa Core Frequency2G GSM/EDGE: 850, 900, 1800, 1900 MHz, 3G UMTS/HSPA+/DC-HSDPA: 850, 900, 1700/2100, 1900, 2100 MHz, 4G TD-LTE: Bands 34, 38, 39, 40, 41, 42, 46, 48, 4G FDD-LTE: Bands 1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 30, 32, 66, 5G NR: Bands n1, n2, n3, n5, n7, n8, n12, n20, n25, n28, n30, n38, n40, n41, n48, n66, n77, n78, n79
# 266 :  SystemiOS 9Processor TypeA9 Chip with 64-bit Architecture and M9 Motion Co-processorProcessor CoreDual CorePrimary Clock Speed1.84 GHz FrequencyGSM - 850, 900, 1800, 1900; UMTS - 850, 900, 1700, 1900, 2100; 4G LTE (TD) - Band 38/39/40/41
# 245 :  SystemiOS 9Processor TypeApple A9 64-bit processor and Embedded M9 Motion Co-processorProcessor CoreDual CorePrimary Clock Speed1.84 GHz FrequencyGSM - 850, 900, 1800, 1900; UMTS - 850, 900, 1700, 1900, 2100; 4G LTE (TD) - Band 38/39/40/41
# 127 :  SystemiOS 9Processor TypeA8 Chip with 64-bit Architecture and M8 Motion Co-processor FrequencyGSM - 850, 900, 1800, 1900; UMTS - 1700, 2100; LTE - 700, 2300, 2500, 2600
# 83 :  SystemiOS 16Processor TypeA15 Bionic Chip, 6 Core ProcessorProcessor CoreHexa Core Frequency5G NR (Bands n1, n2, n3, n5, n7, n8, n12, n20, n25, n26, n28, n30, n38, n40, n41, n48, n53, n66, n70, n77, n78, n79), 4G FDD-LTE (B1, B2, B3, B4, B5, B7, B8, B12, B13, B17, B18, B19, B20, B25, B26, B28, B30, B32, B66), 4G TD-LTE (B34, B38, B39, B40, B41, B42, B46, B48, B53), 3G UMTS/HSPA+/DC-HSDPA (850, 900, 1700/2100, 1900, 2100 MHz), 2G GSM/EDGE (850, 900, 1800, 1900 MHz)
# 350 :  SystemiOS 14Processor TypeA14 Bionic Chip with Next Generation Neural Engine
# None
# None
# Successfully applied function in None
# 15 :  SystemAndroid 13Processor CoreOcta CorePrimary Clock Speed2.4 GHz
# 105 :  SystemAndroid 12Processor CoreOcta CorePrimary Clock Speed2.2 GHz
# 3 :  SystemAndroid OxygenOS based on Android 13Processor CoreOcta CorePrimary Clock Speed3.2 MHz
# 126 :  SystemAndroid Oxygen 11.3Processor CoreOcta CorePrimary Clock Speed3 GHz
# 7 :  SystemAndroid 13Processor CoreOcta CorePrimary Clock Speed2.4 GHz
# 118 :  SystemAndroid Pie 10Processor TypeQualcomm Snapdragon 865Processor CoreOcta CorePrimary Clock Speed2.84 GHz
# None
# None
# Successfully applied function in None
# 150 :  SystemAndroid Android 13Processor CoreOcta CorePrimary Clock Speed2.2 GHz
# 96 :  SystemAndroid 11Processor CoreOcta CorePrimary Clock Speed1.8 GHz
# 18 :  SystemAndroid 13Processor TypeQualcomm Snapdragon 695 5GProcessor CoreOcta CorePrimary Clock Speed2.2 GHzSecondary Clock Speed1.8 GHz Frequency2G GSM: 850/900/1800/1900 MHz, 3G WCDMA: B1/B2/B4/B5/B6/B8/B19, 4G TD-LTE: B34/B38/B39/B40/B41 (2515 - 2675 MHz), 4G LTE FDD: B1/B2/B3/B4/B5/B7/B8/B19/B20/B28A, 5G NR_SA?n1/n5/n8/n28A/n41/n78, 5G NR_NSA: n41/n77/n78
# 93 :  SystemAndroid Q 12Processor TypeQualcomm Snapdragon 680Processor CoreOcta CorePrimary Clock Speed2.4 GHzSecondary Clock Speed1.9 GHz Frequency2G GSM: 850/900/1800/1900 MHz, 3G UMTS (WCDMA): B1/B5/B8, 4G FDD LTE: B1/B3/B5/B8, 4G TD LTE: B38/B40/B41 (2535 - 2655 MHz)
# 78 :  SystemAndroid 11Processor TypeMediatek Dimensity 810Processor CoreOcta CorePrimary Clock Speed2.4 GHzSecondary Clock Speed2 GHz FrequencySIM 1: 2G GSM: 850/900/1800/1900 MHz, 3G WCDMA: B1/B2/B5/B6/B8/B19, 4G LTE TDD: B34/B38/B39/B40/B41 (2515-2675 MHz), 4G LTE FDD: B1/B2/B3/B5/B7/B8/B28A, 5G NR_NSA: n41(2515 - 2675 MHz)/n77/n78, 5G NR_SA: n1/n28A/n41(2515-2675 MHz)/n78, SIM 2: 2G GSM: 850/900/1800/1900 MHz, 3G WCDMA: B1/B2/B5/B6/B8/B19, 4G LTE TDD: B34/B38/B39/B40/B41 (2515-2675 MHz), 4G LTE FDD: B1/B2/B3/B5/B7/B8/B28A, 5G NR_NSA: n41(2515-2675 MHz)/n77/n78, 5G NR_SA: n1/n28A/n41 (2515-2675MHz)/n78
# 176 :  SystemAndroid 10Processor TypeMediaTek Helio G90TProcessor CoreOcta CorePrimary Clock Speed2.05 GHzSecondary Clock Speed2 GHz FrequencyGSM Bands: 850/900/1800/1900, WCDMA Bands: 1/5/8 , 4G LTE Bands: FDD LTE - 1/3/5/8, TDD LTE - 38/40/41 (2535-2655 MHz)
# None
# None
# Successfully applied function in None
# 258 :  SystemAndroid 10Processor TypeMediaTek Helio P35Processor CoreOcta CorePrimary Clock Speed2.3 GHz Frequency2G GSM: B2/B3/B5/B8, 3G WCDMA: B1/B5/B8, 4G LTE FDD: B1/B3/B5/B8, 4G LTE TDD: B38/B40/B41
# 147 :  SystemAndroid 13Processor TypeMediatek Dimensity 900Processor CoreOcta CorePrimary Clock Speed2.4 GHz Frequency2G GSM: 850/900/1800/1900 MHz, 3G WCDMA: B1/B5/B8, 4G FDD-LTE: B1/B3/B5/B8, 4G TDD-LTE: B38/B40/B41 (120M), 5G NR NSA: n77/n78, 5G NR SA: n1/n3/n8/n28A/n77/n78
# 237 :  SystemAndroid 11Processor TypeMediaTek Helio P35Processor CoreOcta CorePrimary Clock Speed2.3 GHz Frequency2G GSM: B3/B5/B8, 3G WCDMA: B1/B5/B8, 4G LTE FDD: B1/B3/B5/B8, 4G LTE TDD: B38/B40/B41
# 213 :  SystemAndroid 12Processor TypeQualcomm Snapdragon 695Processor CoreOcta CorePrimary Clock Speed2.2 GHz Frequency2G GSM: 850/900/1800, 3G WCDMA: B1/B5/B8, 4G FDD-LTE: B1/B3/B5/B8, 4G TDD- LTE: B38/B40/B41 (120 M), 5G NR_NSA: n77/n78
# 144 :  SystemAndroid 11Processor TypeMediatek Helio P35Processor CoreOcta CorePrimary Clock Speed2.3 GHz Frequency3G WCDMA: B1/B5/B8, 4G FDD LTE: B1/B3/B5/B8, 4G TDD LTE: B38/B40/B41
# 184 :  SystemAndroid Pie 9Processor TypeQualcomm Snapdragon 675AIEProcessor CoreOcta CorePrimary Clock Speed2 GHz Frequency2G GSM (B2/B3/B5/B8), 3G WCDMA (B1/B5/B8), 4G FDD-LTE (B1/B3/B5/B8), 4G TDD-LTE (B38/B40/B41)
# None
# None
# Successfully applied function in None
# 3 :  SystemAndroidProcessor CoreOcta CorePrimary Clock Speed2 GHz
# 57 :  SystemAndroid 10Processor TypeMediaTek Helio P95Processor CoreOcta CorePrimary Clock Speed2.2 GHzSecondary Clock Speed2 GHz Frequency2G GSM: 850/900/1800/1900, 3G WCDMA: B1/B5/B8, 4G LTE FDD: B1/B3/B5/B8, 4G LTE TDD: B38/B40/B41
# 32 :  SystemAndroid 10Processor TypeMediaTek Helio P35 (MT6765)Processor CoreOcta CorePrimary Clock Speed2.3 GHz Frequency2G GSM: 850/900/1800/1900 MHz, 3G WCDMA: B1/B5/B8, 4G LTE FDD: B1/B3/B5/B7/B8, 4G LTE TD: B38/B40/B41 (2535 - 2656 MHz)
# 80 :  SystemAndroid Nougat 7.1Processor TypeMediatek MT6750 Octa Core 1.5 GHzProcessor CoreOcta CorePrimary Clock Speed1.5 GHz FrequencyGSM: Band 2/3/5/8, WCDMA: Band 1/5/8, 4G FDD-LTE: Version 1 (Bands 1/3/5/8/38/40/41)
# 207 :  SystemAndroid 10Processor TypeQualcomm Snapdragon 460Processor CoreOcta CorePrimary Clock Speed1.8 GHzSecondary Clock Speed1.6 GHz FrequencyGSM: 850/900/1800/1900, WCDMA: B1/B5/B8, 4G FDD LTE: B1/B3/B5/B8, 4G TDD LTE: B38/B40/B41 (2535 - 2655 MHz)
# 101 :  SystemAndroid Oreo 8.1Processor TypeMediaTek Helio P35Processor CoreOcta CorePrimary Clock Speed2.3 GHz
# None
# None
# Successfully applied function in None
# 35 :  SystemAndroid 12Processor TypeMediatek Helio G99Processor CoreOcta CorePrimary Clock Speed2.2 GHz Frequency4G LTE: B1/B2/B3/B5/B7/B8/B18/B19/B20/B26/B28/B38/B40/B41, 3G UMTS: B1/B2/B5/B6/B8/B19, 2G GSM: B2/B3/B5/B8
# 23 :  SystemAndroid 13 (Go Edition)Processor TypeUnisoc T606Processor CoreOcta CorePrimary Clock Speed1.6 GHzSecondary Clock Speed1.6 GHz Frequency4G LTE: B1/B3/B5/B7/B8/B20/B28/B38/B40/B41, 3G UMTS: B1/B5/B8, 2G GSM: B3/B5/B8
# 19 :  SystemAndroid 13 (Go Edition)Processor TypeUnisoc T606Processor CoreOcta CorePrimary Clock Speed1.6 GHzSecondary Clock Speed1.6 GHz Frequency4G LTE: B1/B3/B5/B7/B8/B20/B28/B38/B40/B41, 3G UMTS: B1/B5/B8, 2G GSM: B3/B5/B8
# 59 :  SystemAndroid 10Processor TypeQualcomm Snapdragon 750GProcessor CoreOcta CorePrimary Clock Speed2.2 GHz FrequencyGSM: B2/B3/B5/B8, WCDMA: B1/B2/B5/B8/B19, 4G LTE: B1/B2/B3/B4/B5/B7/B8/B12/B18/B19/B20/B26/B28/B38/B39/B40/B41/B42/B43/B66, 5G: : N1/N3/N5/N7/N8/N28/N38/N41/N66/N77/N78
# 9 :  SystemAndroid 12Processor TypeMediatek Helio G37Processor CoreOcta CorePrimary Clock Speed2.3 GHzSecondary Clock Speed1.8 GHz Frequency4G LTE: B1/B3/B5/B7/B8/B20/B38/B40/B41, 3G UMTS: B1/B5/B8, 2G GSM: B3/B5/B8
# 64 :  SystemAndroid 11Processor TypeQualcomm Snapdragon 732GProcessor CoreOcta CorePrimary Clock Speed2.3 GHzSecondary Clock Speed1.8 GHz Frequency2G GSM: B2/B3/B5/B8, 3G WCDMA: B1/B2/B4/B5/B8/B19, 4G LTE: B1/B2/B3/B4/B5/B7/B8/B18/B19/B20/B26/B28/B38/B40/B41
# None
# None
# Successfully applied function in None
# 70 :  SystemAndroid Q ?Android 13.0Processor Type7nm Dimensity 6020Processor CoreOcta CorePrimary Clock Speed2.2 GHzSecondary Clock Speed2.2 GHzTertiary Clock Speed1.8 GHz
# 15 :  SystemAndroid 12Processor TypeMediaTek Helio A22Processor CoreQuad CorePrimary Clock Speed2 GHz
# 128 :  SystemAndroid Android 11Processor TypeHelio A25Processor CoreOcta CorePrimary Clock Speed1.8 GHzSecondary Clock Speed1.5 GHz
# 74 :  SystemAndroid 13Processor TypeMediatek Dimensity 6020Processor CoreOcta CorePrimary Clock Speed2.2 GHzSecondary Clock Speed2 GHz
# 65 :  SystemAndroid 13Processor TypeMediatek Dimensity 6020Processor CoreOcta CorePrimary Clock Speed2.2 GHzSecondary Clock Speed2 GHz
# 94 : 64MP + 50MP + 2MP
# None
# None
# Successfully applied function in None
# 50 :  SystemAndroid 11Processor TypeMediatek Helio A22Processor CoreQuad CorePrimary Clock Speed2 GHz Frequency2G GSM: B2/B3/B5/B8, 3G WCDMA: B1/B5/B8, 4G LTE: B1/B3/B5/B8/B38/B40/B41
# 153 :  SystemAndroid Pie 9.0Processor TypeMediaTek A22 Quad Core 2.0 GHzProcessor CoreQuad CorePrimary Clock Speed2 GHz FrequencyGSM: B2/B3/B5/B8, WCDMA: B1/B5/B8, 4G LTE: B1/B3/B5/B8/B38/B40/B41
# 140 :  SystemAndroid 11Processor TypeMediaTek Helio G85Processor CoreOcta CorePrimary Clock Speed2 GHz Frequency2G GSM: B2/B3/B5/B8, 3G WCDMA: B1/B5/B8, 4G LTE: B1/B3/B5/B8/B38/B40/B41
# 21 :  SystemAndroid 12Processor TypeDimensity 810Processor CoreOcta CorePrimary Clock Speed2.4 GHz Frequency2G GSM: B2/B3/B5/B8, 3G WCDMA: B1/B5/B8, 4G LTE: B1/B3/B5/B7/B8/B20/B28/B38/B40/B41, 5G: n1/n3/n5/n7/n8/n20/n28/38/n40/n41/n77/n78
# 124 :  SystemAndroid 11Processor TypeMediaTek Helio G88Processor CoreOcta CorePrimary Clock Speed2 GHz Frequency2G GSM: B2/B3/B5/B8, 3G WCDMA: B1/B5/B8, 4G LTE: B1/B3/B5/B8/B38/B40/B41
# 120 :  SystemAndroid Pie 9Processor TypeHelio P22 (MTK6762)Processor CoreOcta CorePrimary Clock Speed2 GHz FrequencyGSM - B2/3/5/8, WCDMA - B1/5/8, 4G LTE - B1/3/5/8/B38/B40/B41
# None
# None

# %% [markdown]
# ## ***os_processor***

# %%
def extract_processor(text):
    string = text.split()
    find = re.findall(r'Speed\d.*+',' '.join(string))
    find = ' '.join(find).split()
    pattern = r'.*Processor'
    match = re.findall(pattern, text)
    
    if match:
        return match[0]  + ' '+ ''.join(find[0])
    else:
        return text

# %%
for df_name ,df in dataframes_dict.items():
    if df_name == 'apple':
        continue
    else:
        print(func_apply(func=extract_processor,col_name='os_processor',df=df,df_name=df_name))
# Out:
# Successfully applied function in mi
# 22 :  SystemAndroid 11Processor TypeQualcomm Snapdragon 778GProcessor Speed2.4
# 355 :  SystemQ 10Processor TypeQualcomm Snapdragon 662Processor Speed2
# 29 :  SystemAndroid 10Processor TypeQualcomm Snapdragon 865Processor Speed2.84
# 248 :  SystemAndroid Q 11Processor Speed2.3
# 215 :  SystemAndroid 12Processor TypeMediatek Dimensity 1080Processor Speed2.6
# 410 :  SystemAndroid Marshmallow 6.0.1Processor TypeQualcomm Snapdragon 650 64-bitProcessor Speed1.8
# None
# None
# Successfully applied function in samsung
# 526 :  SystemAndroid Pie 9.0Processor TypeExynos 7904Processor Speed1.8
# 331 :  SystemAndroid 10Processor TypeQualcomm Snapdragon (SDM450-F01) Octa CoreProcessor Speed1.8
# 373 :  SystemAndroid Lollipop 5.1Processor TypeQualcomm Snapdragon 410 Quad Core 1.2GHzProcessor Speed1.2
# 243 :  SystemAndroid 12Processor Speed2.99
# 315 :  SystemAndroid 11Processor TypeExynos 850Processor Speed2
# 254 :  SystemAndroid 12Processor TypeQualcomm Snapdragon 8+ Gen 1Processor Speed3.18
# None
# None
# Successfully applied function in onePlus
# 172 :  SystemAndroid 11Processor Speed2.4
# 89 :  SystemAndroid Q 11Processor Speed2.4
# 25 :  SystemAndroid Android 12Processor Speed2.2
# 120 :  SystemAndroid Q 11Processor Speed2.4
# 71 :  SystemAndroid 12Processor Speed2.2
# 131 :  SystemAndroid Q 13Processor Speed2.4
# None
# None
# Successfully applied function in realme
# 79 :  SystemAndroid 10Processor TypeMediaTek Helio G35Processor Speed2.3
# 26 :  SystemAndroid 13Processor Speed2
# 27 :  SystemAndroid 13Processor Speed2
# 97 :  SystemAndroid 10Processor TypeSnapdragon 720GProcessor Speed2.3
# 159 :  SystemAndroid Pie 9.0Processor TypeMediaTek P22 Octa Core 2.0 GHzProcessor Speed2
# 73 :  SystemAndroid 11Processor TypeMediaTek Helio G85Processor Speed2
# None
# None
# Successfully applied function in vivo
# 60 :  SystemAndroid 12Processor TypeMediatek Dimensity 1300Processor Speed3
# 121 :  SystemAndroid 12Processor TypeQualcomm Snapdragon 680Processor Speed2.4
# 233 :  SystemAndroid 11Processor TypeMediatek Helio P35Processor Speed2.3
# 33 :  SystemAndroid 12Processor TypeQualcomm Snapdragon 680Processor Speed2.4
# 3 :  SystemAndroid 13Processor TypeDimensity 6020Processor Speed2.2
# 84 :  SystemAndroid 12Processor TypeMediatek Dimensity 810Processor Speed2.4
# None
# None
# Successfully applied function in oppo
# 166 :  SystemAndroid Pie 9.0Processor TypeMediaTek Helio P22Processor Speed2
# 217 :  SystemAndroid Pie 9Processor TypeQualcomm Snapdragon 665Processor Speed1.8
# 195 :  SystemAndroid Oreo 8.1Processor TypeQualcomm Snapdragon 450Processor Speed1.8
# 151 :  SystemAndroid 11Processor TypeQualcomm Snapdragon 680Processor Speed2.4
# 39 :  SystemAndroid Q ColorOS 12.1. 1Processor TypeMTK Helio G35Processor Speed2.3
# 182 :  SystemAndroid Pie 9Processor TypeMediaTek Helio P35Processor Speed1.8
# None
# None
# Successfully applied function in motorola
# 45 :  SystemAndroid 12Processor TypeQualcomm Snapdragon 680Processor Speed2.4
# 91 :  SystemAndroid 11Processor TypeMediaTek Dimensity 800UProcessor Speed2.4
# 69 :  SystemAndroid Pie 9Processor TypeQualcomm Snapdragon 665Processor Speed2
# 87 :  Frequency2G GSM: 900/1800 MHz
# 104 :  SystemAndroid 12Processor TypeQualcomm Snapdragon 695 5GProcessor Speed2.2
# 0 :  SystemAndroid 12Processor TypeQualcomm Snapdragon 680Processor Speed2.4
# None
# None
# Successfully applied function in techno
# 19 :  SystemAndroid ?HiOS 12.0 based on Android 12Processor Speed3.05
# 75 :  SystemAndroid 12.0Primary Clock Speed1.6 MHz
# 9 :  SystemAndroid 12Processor TypeMediaTek Helio G85Processor Speed2
# 0 :  SystemAndroid 12Processor TypeMediaTek Helio G88Processor Speed2
# 78 :  SystemAndroid 13Processor TypeMediatek Dimensity 8050Processor Speed3
# 15 :  SystemAndroid 12Processor TypeMediaTek Helio A22Processor Speed2
# None
# None
# Successfully applied function in infinix
# 122 :  SystemAndroid 13Processor TypeDimensity 6080Processor Speed2.4
# 31 :  SystemAndroid 12Processor TypeMediatek Helio G85Processor Speed2
# 49 :  SystemAndroid 11Processor TypeMediatek Helio A22Processor Speed2
# 37 :  SystemAndroid 11Processor TypeMeditek Helio G37Processor Speed2.3
# 89 :  SystemAndroid Nougat 7Processor TypeMediatek MT6753 Octa Core 1.3 GhzProcessor Speed1.3
# 0 :  SystemAndroid 12Processor TypeUnisoc Spreadtrum SC9863A1Processor Speed1.6
# None
# None

# %% [markdown]
# ## camera

# %%
def camera_extract(row):
    row_splitted = row.split()
    pattern = r'\d+MP'
    words = ' '.join(row_splitted)
    find_cam = re.findall(pattern,words)
    return ' '.join(find_cam)

# %%
for df_name ,df in dataframes_dict.items():
    print(func_apply(func=camera_extract,col_name='camera',df=df,df_name=df_name))
# Out:
# Successfully applied function in mi
# 18 : 8MP
# 238 : 50MP 50MP 5MP 5MP
# 142 : 13MP 5MP
# 122 : 13MP 5MP
# 36 : 108MP 108MP 8MP 2MP 16MP
# 116 : 12MP 5MP
# None
# None
# Successfully applied function in samsung
# 469 : 48MP 5MP 2MP 2MP 48MP 5MP 2MP 2MP 8MP
# 473 : 64MP 8MP 5MP 64MP 5MP 8MP 32MP 32MP
# 414 : 48MP 12MP 5MP 5MP 48MP 12MP 5MP 5MP 32MP 32MP
# 456 : 13MP 2MP 13MP 8MP 5MP
# 11 : 13MP 2MP 13MP 2MP 13MP 5MP 5MP
# 484 : 48MP 8MP 2MP 2MP 48MP 8MP 2MP 2MP 13MP 13MP
# None
# None
# Successfully applied function in apple
# 190 : 12MP 63MP 7MP
# 87 : 12MP 12MP 12MP 12MP 63MP 12MP 12MP
# 402 : 64MP 32MP 8MP 64MP 32MP 8MP 32MP 32MP
# 304 : 12MP 12MP 12MP 63MP 7MP
# 139 : 12MP 12MP 12MP 63MP 7MP
# 150 : 12MP 12MP 63MP 8MP 7MP 7MP
# None
# None
# Successfully applied function in onePlus
# 12 : 50MP
# 52 : 50MP
# 98 : 64MP
# 27 : 50MP
# 36 : 48MP
# 141 : 64MP
# None
# None
# Successfully applied function in realme
# 102 : 64MP 12MP 8MP 2MP 8MP 64MP 12MP 2MP 32MP 8MP 32MP 8MP
# 211 : 13MP 2MP 2MP 13MP 2MP 2MP 5MP 5MP
# 10 : 64MP 2MP 64MP 2MP 64MP 8MP 8MP
# 207 : 48MP 2MP 2MP 48MP 2MP 2MP 16MP 16MP
# 193 : 8MP 8MP 5MP 5MP
# 112 : 50MP 8MP 2MP 50MP 8MP 2MP 16MP 16MP
# None
# None
# Successfully applied function in vivo
# 3 : 50MP 2MP 50MP 2MP 8MP 8MP
# 296 : 13MP 2MP 2MP 13MP 2MP 2MP 13MP 2MP 2MP 8MP 8MP
# 132 : 64MP 8MP 2MP 64MP 8MP 2MP 32MP 32MP
# 203 : 8MP 8MP 5MP 5MP
# 75 : 50MP 8MP 2MP 50MP 8MP 2MP 50MP 50MP
# 169 : 16MP 24MP
# None
# None
# Successfully applied function in oppo
# 114 : 48MP 8MP 2MP 2MP 48MP 48MP 16MP
# 74 : 64MP
# 229 : 13MP 8MP
# 209 : 13MP 8MP
# 147 : 13MP 16MP
# 39 : 8MP 5MP
# None
# None
# Successfully applied function in motorola
# 72 : 200MP 50MP 12MP 200MP 50MP 12MP 60MP 60MP
# 39 : 50MP 50MP 2MP 50MP 50MP 2MP 32MP 32MP
# 85 : 50MP 8MP 2MP 16MP
# 45 : 50MP 8MP 2MP 50MP 8MP 2MP 16MP 16MP
# 41 : 50MP 8MP 2MP 13MP
# 26 : 108MP 8MP 2MP 108MP 8MP 2MP 108MP 16MP 16MP
# None
# None
# Successfully applied function in techno
# 109 : 13MP 8MP
# 72 : 64MP 2MP 32MP
# 118 : 16MP 8MP
# 149 : 50MP 32MP
# 19 : 64MP
# 84 : 50MP
# None
# None
# Successfully applied function in infinix
# 98 : 50MP 2MP 50MP 2MP 8MP 8MP
# 114 : 13MP 13MP 13MP 8MP 8MP
# 42 : 108MP 13MP 2MP 108MP 13MP 2MP 60MP
# 116 : 48MP 2MP 2MP 48MP 2MP 2MP 16MP 16MP
# 32 : 50MP 50MP 8MP 8MP
# 143 : 16MP 5MP 2MP 16MP 5MP 2MP 32MP 32MP
# None
# None

# %% [markdown]
# ## network

# %%
def network(txt):
    pattern = r'\bNetwork Type(4G|5G|3G|2G)\b'
    search = re.search(pattern,txt)
    if search:
        find = re.findall(pattern,txt)
        return ''.join(find)
    else:
        pattern = r'\bNetwork Type(4G|5G|3G|2G)Supported'
        find = re.findall(pattern,txt)
        return ''.join(find)

# %%
for df_name ,df in dataframes_dict.items():
    print(func_apply(func=network,col_name='network',df=df,df_name=df_name))
# Out:
# Successfully applied function in mi
# 174 : 2G
# 181 : 5G
# 16 : 5G
# 445 : 3G
# 319 : 4G
# 404 : 3G
# None
# None
# Successfully applied function in samsung
# 128 : 4G
# 134 : 5G
# 298 : 5G
# 180 : 5G
# 278 : 3G
# 527 : 3G
# None
# None
# Successfully applied function in apple
# 261 : 5G
# 8 : 4G
# 271 : 5G
# 93 : 4G
# 50 : 5G
# 322 : 5G
# None
# None
# Successfully applied function in onePlus
# 32 : 4G
# 143 : 5G
# 28 : 5G
# 100 : 5G
# 122 : 5G
# 22 : 5G
# None
# None
# Successfully applied function in realme
# 31 : 5G
# 201 : 4G
# 135 : 4G
# 129 : 5G
# 186 : 3G
# 56 : 5G
# None
# None
# Successfully applied function in vivo
# 158 : 4G
# 73 : 5G
# 215 : 5G
# 15 : 4G
# 16 : 5G
# 68 : 4G
# None
# None
# Successfully applied function in oppo
# 172 : 4G
# 158 : 3G
# 160 : 5G
# 46 : 4G
# 105 : 3G
# 37 : 2G
# None
# None
# Successfully applied function in motorola
# 7 : 4G
# 31 : 5G
# 64 : 4G
# 55 : 4G
# 111 : 5G
# 67 : 4G
# None
# None
# Successfully applied function in techno
# 49 : 4G
# 5 : 4G
# 107 : 4G
# 130 : 5G
# 143 : 4G
# 28 : 4G
# None
# None
# Successfully applied function in infinix
# 95 : 4G
# 35 : 4G
# 24 : 5G
# 17 : 5G
# 154 : 3G
# 12 : 4G
# None
# None

# %% [markdown]
# ## Battery

# %%
apple.fillna('notMentioned',inplace=True)

# %%
def extract_battery(txt):
    if txt == 'notMentioned':
        return 'notMentioned'
    else:
        capBattery = txt.split()[1]
        return capBattery 

for df_name, df in dataframes_dict.items():
    print(func_apply(func=extract_battery, col_name='battery', df=df, df_name=df_name))
# Out:
# Successfully applied function in mi
# 117 : Capacity4000
# 116 : Capacity4000
# 99 : Capacity4000
# 236 : Capacity5000
# 399 : Capacity5000
# 50 : Capacity6000
# None
# None
# Successfully applied function in samsung
# 46 : Capacity4500
# 522 : Capacity4000
# 28 : Capacity6000
# 343 : Capacity2600
# 116 : Capacity3900
# 40 : Capacity4500
# None
# None
# Successfully applied function in apple
# 326 : notMentioned
# 318 : notMentioned
# 293 : notMentioned
# 297 : notMentioned
# 266 : Capacity2750
# 350 : notMentioned
# None
# None
# Successfully applied function in onePlus
# 52 : Capacity4500
# 148 : Capacity4500
# 27 : Capacity5000
# 44 : Capacity5000
# 136 : Capacity4500
# 102 : Capacity4115
# None
# None
# Successfully applied function in realme
# 69 : Capacity5000
# 16 : Capacity5000
# 194 : Capacity5000
# 26 : Capacity5000
# 210 : Capacity5000
# 65 : Capacity5000
# None
# None
# Successfully applied function in vivo
# 184 : Capacity4500
# 163 : Capacity4000
# 207 : Capacity4030
# 183 : Capacity4500
# 264 : Capacity5000
# 295 : Capacity5000
# None
# None
# Successfully applied function in oppo
# 233 : Capacity5000
# 189 : Capacity4350
# 93 : Capacity5000
# 17 : Capacity4230
# 50 : Capacity5000
# 132 : Capacity4310
# None
# None
# Successfully applied function in motorola
# 78 : Capacity5000
# 12 : Capacity5000
# 16 : Capacity800
# 109 : Capacity5000
# 104 : Capacity5000
# 17 : Capacity800
# None
# None
# Successfully applied function in techno
# 82 : Capacity5000
# 83 : Capacity5000
# 33 : Capacity5000
# 78 : Capacity5000
# 22 : Capacity5000
# 14 : Capacity5000
# None
# None
# Successfully applied function in infinix
# 123 : Capacity6000
# 120 : Capacity5000
# 61 : Capacity5000
# 119 : Capacity5000
# 154 : Capacity4000
# 125 : Capacity5000
# None
# None

# %% [markdown]
# # Mi

# %%
mi
# Out:
#                                           name  ratings    price
# 0          Redmi 9A Sport (Coral Green, 32 GB)      4.2   ₹8,990  \
# 1       Xiaomi 11Lite NE (Vinyl Black, 128 GB)      4.2  ₹21,430
# 2    Xiaomi 11Lite NE (Diamond Dazzle, 128 GB)      4.2  ₹20,999
# 3     Xiaomi 11Lite NE (Tuscany Coral, 128 GB)      4.2  ₹20,999
# 4               Mi 11 Lite (Jazz Blue, 128 GB)      4.2  ₹17,499
# ..                                         ...      ...      ...
# 546             13 pro (Ceramic Black, 256 GB)      4.3  ₹79,999
# 547               Mi A3 (Not just Blue, 64 GB)      4.2  ₹14,999
# 548          Mi 10T Pro (Lunar Silver, 128 GB)      4.3  ₹26,899
# 549                     Redmi Y1 (Gold, 32 GB)      4.5   ₹8,999
# 550    Redmi Note 7 Pro (Neptune Blue, 128 GB)      4.3  ₹17,999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/k...
# ..                                                 ...
# 546  https://rukminim2.flixcart.com/image/312/312/x...
# 547  https://rukminim2.flixcart.com/image/312/312/k...
# 548  https://rukminim2.flixcart.com/image/312/312/k...
# 549  https://rukminim2.flixcart.com/image/312/312/j...
# 550  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                            storage_ram
# 0    Internal Storage32 GBRAM3 GBMemory Card Slot T...  \
# 1    Internal Storage128 GBRAM6 GBExpandable Storag...
# 2    Internal Storage128 GBRAM6 GBExpandable Storag...
# 3    Internal Storage128 GBRAM6 GBExpandable Storag...
# 4    Internal Storage128 GBRAM8 GBExpandable Storag...
# ..                                                 ...
# 546  Internal Storage256 GBRAM12 GBMemory Card Slot...
# 547  Internal Storage64 GBRAM4 GBExpandable Storage...
# 548    Internal Storage128 GBRAM8 GBCall Log MemoryYes
# 549  Internal Storage32 GBRAM3 GBExpandable Storage...
# 550  Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                           os_processor
# 0                   SystemAndroid Q 10Processor Speed2  \
# 1     SystemAndroid 11Processor TypeQualcomm Snapdr...
# 2     SystemAndroid 11Processor TypeQualcomm Snapdr...
# 3     SystemAndroid 11Processor TypeQualcomm Snapdr...
# 4     SystemAndroid 11Processor TypeQualcomm Snapdr...
# ..                                                 ...
# 546   SystemAndroid MIUI 14, Android 13.0Processor ...
# 547   SystemAndroid Pie 9Processor TypeQualcomm Sna...
# 548   SystemAndroid 10Processor TypeQualcomm Snapdr...
# 549   SystemAndroid Nougat 7.1.2Processor TypeQualc...
# 550   SystemAndroid Pie 9.0Processor TypeQualcomm S...
#
#                                                 camera
# 0                                                 13MP  \
# 1                                    64MP 8MP 5MP 20MP
# 2                                    64MP 8MP 5MP 20MP
# 3                                    64MP 8MP 5MP 20MP
# 4                  64MP 8MP 5MP 64MP 8MP 5MP 16MP 16MP
# ..                                                 ...
# 546                                               50MP
# 547                48MP 8MP 2MP 48MP 8MP 2MP 32MP 32MP
# 548  108MP 13MP 5MP 108MP 13MP 5MP 108MP 13MP 5MP 20MP
# 549                                          13MP 16MP
# 550                             48MP 5MP 48MP 5MP 13MP
#
#                                                display network       battery
# 0    Display Size16.59 cm (6.53 inch)Resolution1600...      4G  Capacity5000
# 1    Display Size16.64 cm (6.55 inch)Resolution1080...      5G  Capacity4250
# 2    Display Size16.64 cm (6.55 inch)Resolution1080...      5G  Capacity4250
# 3    Display Size16.64 cm (6.55 inch)Resolution1080...      5G  Capacity4250
# 4    Display Size16.64 cm (6.55 inch)Resolution2400...      4G  Capacity4250
# ..                                                 ...     ...           ...
# 546  Display Size17.09 cm (6.73 inch)Resolution3200...      5G  Capacity4820
# 547  Display Size15.46 cm (6.088 inch)Resolution156...      4G  Capacity4030
# 548  Display Size16.94 cm (6.67 inch)Resolution2400...      5G  Capacity5000
# 549  Display Size13.97 cm (5.5 inch)Resolution1280 ...      3G  Capacity3080
# 550  Display Size16.0 cm (6.3 inch)Resolution2340 x...      3G  Capacity4000
#
# [489 rows x 10 columns]

# %% [markdown]
# ### ***price***

# %%
clean_price_col(mi)
# Out:
# 'datatype -Int16'

# %% [markdown]
# ### *****storage_ram*****

# %%
func_apply(func=remove_internal,col_name='storage_ram',df=mi)
# Out:
# Successfully applied function in None
# 211 :  Storage128 GBRAM6 GBExpandable Storage1 TBSupported Memory Card TypeMicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 327 :  Storage64 GBRAM4 GBMemory Card Slot TypeDedicated Slot
# 52 :  Storage64 GBRAM6 GBExpandable Storage128 GBSupported Memory Card TypemicroSDMemory Card Slot TypeHybrid Slot
# 420 :  Storage64 GBRAM3 GBExpandable Storage512 GBMemory Card Slot TypeDedicated Slot
# 43 :  Storage128 GBRAM6 GBExpandable Storage512 GBSupported Memory Card TypeMicroSDMemory Card Slot TypeDedicated Slot
# 471 :  Storage16 GBRAM2 GBPhone Book MemoryYesCall Log MemoryYesSMS MemoryYes
# None

# %%
func_apply(func=cut_remove_words,col_name='storage_ram',df=mi)
# Out:
# Successfully applied function in None
# 354 : Storage128 GBRAM4 GBExpandable Storage1TB
# 367 : Storage6 GBRAM128
# 358 : Storage64 GBRAM4
# 387 : Storage128 GBRAM6 GBExpandable Storage512GB
# 470 : Storage128 GBRAM6 GBExpandable Storage1TB
# 377 : Storage64 GBRAM6 GBExpandable Storage512GB
# None

# %% [markdown]
# # Samsung

# %%
samsung.dropna(inplace=True)

# %%
samsung
# Out:
#                                                   name  ratings      price
# 0           SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)      4.3     ₹9,499  \
# 1          SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)      4.3    ₹10,499
# 2          SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)      4.3    ₹10,499
# 3          SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)      4.3    ₹10,499
# 4            SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)      4.3    ₹15,499
# ..                                                 ...      ...        ...
# 569         SAMSUNG Galaxy M40 (Seawater Blue, 128 GB)      4.5    ₹21,490
# 570  SAMSUNG Galaxy Note 20 Ultra 5G (Mystic Bronze...      4.3  ₹1,04,999
# 571    SAMSUNG Galaxy A30s (Prism Crush Violet, 64 GB)      4.3    ₹16,199
# 572              SAMSUNG Galaxy J4 Plus (Black, 32 GB)      4.4     ₹9,000
# 573     SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)      4.2    ₹34,999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 569  https://rukminim2.flixcart.com/image/312/312/k...
# 570  https://rukminim2.flixcart.com/image/312/312/k...
# 571  https://rukminim2.flixcart.com/image/312/312/k...
# 572  https://rukminim2.flixcart.com/image/312/312/j...
# 573  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 0    Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 1    Internal Storage128 GBRAM4 GBExpandable Storag...
# 2    Internal Storage128 GBRAM4 GBExpandable Storag...
# 3    Internal Storage128 GBRAM4 GBExpandable Storag...
# 4    Internal Storage128 GBRAM6 GBTotal Memory128 G...
# ..                                                 ...
# 569  Internal Storage128 GBRAM6 GBMemory Card Slot ...
# 570  Internal Storage256 GBRAM12 GBExpandable Stora...
# 571  Internal Storage64 GBRAM4 GBSupported Memory C...
# 572  Internal Storage32 GBRAM2 GBExpandable Storage...
# 573  Internal Storage128 GBRAM8 GBExpandable Storag...
#
#                                           os_processor
# 0     SystemAndroid 12Processor TypeExynos 850Proce...  \
# 1     SystemAndroid 12Processor TypeExynos 850Proce...
# 2     SystemAndroid 12Processor TypeExynos 850Proce...
# 3     SystemAndroid 12Processor TypeExynos 850Proce...
# 4     SystemAndroid 12Processor TypeQualcomm Snapdr...
# ..                                                 ...
# 569              SystemAndroid Pie 9.0Processor Speed2
# 570   SystemAndroid 10Processor TypeExynos Octa Cor...
# 571   SystemAndroid Pie 9.0Processor TypeExynos 790...
# 572   SystemAndroid Oreo 8.1Processor TypeQualcomm ...
# 573   SystemAndroid 10Processor TypeQualcomm SM7150...
#
#                                         camera
# 0            50MP 5MP 2MP 50MP 5MP 2MP 8MP 8MP  \
# 1            50MP 5MP 2MP 50MP 5MP 2MP 8MP 8MP
# 2            50MP 5MP 2MP 50MP 5MP 2MP 8MP 8MP
# 3            50MP 5MP 2MP 50MP 5MP 2MP 8MP 8MP
# 4            50MP 8MP 2MP 50MP 8MP 2MP 8MP 8MP
# ..                                         ...
# 569                                       32MP
# 570  108MP 12MP 12MP 108MP 12MP 12MP 10MP 10MP
# 571             25MP 5MP 8MP 25MP 5MP 8MP 16MP
# 572                                   13MP 5MP
# 573   64MP 12MP 5MP 5MP 64MP 12MP 5MP 5MP 32MP
#
#                                                display network       battery
# 0    Display Size16.76 cm (6.6 inch)Resolution2408 ...      4G  Capacity6000
# 1    Display Size16.76 cm (6.6 inch)Resolution2408 ...      4G  Capacity6000
# 2    Display Size16.76 cm (6.6 inch)Resolution2408 ...      4G  Capacity6000
# 3    Display Size16.76 cm (6.6 inch)Resolution2408 ...      4G  Capacity6000
# 4    Display Size16.76 cm (6.6 inch)Resolution2408 ...      5G  Capacity5000
# ..                                                 ...     ...           ...
# 569  Display Size16.0 cm (6.3 inch)Resolution2340 x...      4G  Capacity3500
# 570  Display Size17.53 cm (6.9 inch)Resolution3088 ...      5G  Capacity4500
# 571  Display Size16.26 cm (6.4 inch)Resolution1920 ...      3G  Capacity4000
# 572  Display Size15.24 cm (6 inch)Resolution720 x 1...      3G  Capacity3300
# 573  Display Size17.02 cm (6.7 inch)Resolution2340 ...      4G  Capacity4500
#
# [529 rows x 10 columns]

# %% [markdown]
# ### ***price***

# %%
clean_price_col(samsung)
# Out:
# 'datatype -Int16'

# %% [markdown]
# ### *****storage_ram*****

# %%
func_apply(func=remove_internal,col_name='storage_ram',df=samsung)
# Out:
# Successfully applied function in None
# 433 :  Storage128 GBRAM8 GBExpandable Storage512 GBMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 19 :  Storage128 GBRAM6 GBExpandable Storage1 TBSupported Memory Card TypeMicroSDMemory Card Slot TypeDedicated Slot
# 162 :  Storage128 GBRAM8 GBExpandable Storage1 TBSupported Memory Card TypeMicroSDMemory Card Slot TypeHybrid Slot
# 219 :  Storage128 GBRAM4 GBTotal Memory128 GBExpandable Storage1 TBSupported Memory Card TypeMicroSDMemory Card Slot TypeDedicated Slot
# 63 :  Storage128 GBRAM8 GBTotal Memory128 GBExpandable Storage1 TBSupported Memory Card TypeMicroSDMemory Card Slot TypeDedicated Slot
# 280 :  Storage32 GBRAM3 GBExpandable Storage512 GBSupported Memory Card TypemicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# None

# %%
func_apply(func=cut_remove_words,col_name='storage_ram',df=samsung)
# Out:
# Successfully applied function in None
# 325 : Storage128 GBRAM8 GBTotal Memory128GB
# 288 : Storage512 GBRAM12
# 253 : Storage128 GBRAM6 GBExpandable Storage1TB
# 508 : Storage64 GBRAM4 GBExpandable Storage512GB
# 117 : Storage128 GBRAM8 GBTotal Memory128GB
# 6 : Storage64 GBRAM4 GBTotal Memory64GB
# None

# %% [markdown]
# # apple

# %%
apple
# Out:
#                                              name  ratings      price
# 0                  APPLE iPhone 13 (Blue, 128 GB)      4.7    ₹61,999  \
# 1              APPLE iPhone 13 (Midnight, 128 GB)      4.7    ₹61,999
# 2             APPLE iPhone 13 (Starlight, 128 GB)      4.7    ₹61,999
# 3                  APPLE iPhone 13 (Pink, 128 GB)      4.7    ₹61,999
# 4              APPLE iPhone 14 (Midnight, 128 GB)      4.6    ₹69,999
# ..                                            ...      ...        ...
# 419              APPLE iPhone XR (Yellow, 128 GB)      4.6    ₹41,699
# 420  APPLE iPhone 11 Pro (Midnight Green, 256 GB)      4.6  ₹1,21,300
# 421                APPLE iPhone X (Silver, 64 GB)      4.6    ₹91,900
# 422           APPLE iPhone X (Space Gray, 256 GB)      4.6  ₹1,06,900
# 423            APPLE iPhone X (Space Gray, 64 GB)      4.6    ₹91,900
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/k...  \
# 1    https://rukminim2.flixcart.com/image/312/312/k...
# 2    https://rukminim2.flixcart.com/image/312/312/k...
# 3    https://rukminim2.flixcart.com/image/312/312/k...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 419  https://rukminim2.flixcart.com/image/312/312/k...
# 420  https://rukminim2.flixcart.com/image/312/312/k...
# 421  https://rukminim2.flixcart.com/image/312/312/j...
# 422  https://rukminim2.flixcart.com/image/312/312/j...
# 423  https://rukminim2.flixcart.com/image/312/312/j...
#
#                 storage_ram
# 0    Internal Storage128 GB  \
# 1    Internal Storage128 GB
# 2    Internal Storage128 GB
# 3    Internal Storage128 GB
# 4    Internal Storage128 GB
# ..                      ...
# 419  Internal Storage128 GB
# 420  Internal Storage256 GB
# 421   Internal Storage64 GB
# 422  Internal Storage256 GB
# 423   Internal Storage64 GB
#
#                                           os_processor
# 0     SystemiOS 15Processor TypeA15 Bionic ChipProc...  \
# 1     SystemiOS 15Processor TypeA15 Bionic ChipProc...
# 2     SystemiOS 15Processor TypeA15 Bionic ChipProc...
# 3     SystemiOS 15Processor TypeA15 Bionic ChipProc...
# 4     SystemiOS 16Processor TypeA15 Bionic Chip, 6 ...
# ..                                                 ...
# 419        SystemiOS 14.2Processor TypeA12 Bionic Chip
# 420          SystemiOS 13Processor TypeA13 Bionic Chip
# 421   SystemiOS 11Processor TypeA11 Bionic Chip wit...
# 422   SystemiOS 11Processor TypeA11 Bionic Chip wit...
# 423   SystemiOS 11Processor TypeA11 Bionic Chip wit...
#
#                                  camera
# 0         12MP 12MP 12MP 63MP 12MP 12MP  \
# 1         12MP 12MP 12MP 63MP 12MP 12MP
# 2         12MP 12MP 12MP 63MP 12MP 12MP
# 3         12MP 12MP 12MP 63MP 12MP 12MP
# 4    12MP 12MP 12MP 12MP 63MP 12MP 12MP
# ..                                  ...
# 419                       12MP 63MP 7MP
# 420  12MP 12MP 12MP 12MP 64MP 12MP 12MP
# 421                  12MP 12MP 63MP 7MP
# 422                  12MP 12MP 63MP 7MP
# 423                  12MP 12MP 63MP 7MP
#
#                                                display network       battery
# 0    Display Size15.49 cm (6.1 inch)Resolution2532 ...      5G  notMentioned
# 1    Display Size15.49 cm (6.1 inch)Resolution2532 ...      5G  notMentioned
# 2    Display Size15.49 cm (6.1 inch)Resolution2532 ...      5G  notMentioned
# 3    Display Size15.49 cm (6.1 inch)Resolution2532 ...      5G  notMentioned
# 4    Display Size15.49 cm (6.1 inch)Resolution2532 ...      5G  notMentioned
# ..                                                 ...     ...           ...
# 419  Display Size15.49 cm (6.1 inch)Resolution1792 ...      3G  notMentioned
# 420  Display Size14.73 cm (5.8 inch)Resolution2436 ...      4G  notMentioned
# 421  Display Size14.73 cm (5.8 inch)Resolution2436 ...      3G  notMentioned
# 422  Display Size14.73 cm (5.8 inch)Resolution2436 ...      3G  notMentioned
# 423  Display Size14.73 cm (5.8 inch)Resolution2436 ...      3G  notMentioned
#
# [424 rows x 10 columns]

# %% [markdown]
# ### ***price***

# %%
clean_price_col(apple)
# Out:
# 'datatype -Int16'

# %% [markdown]
# ### *****storage_ram*****

# %%
func_apply(func=remove_internal,col_name='storage_ram',df=apple)
# Out:
# Successfully applied function in None
# 245 :  Storage32 GBPhone Book MemoryYesCall Log MemoryYesSMS MemoryYes
# 152 :  Storage128 GB
# 324 :  Storage8 GBPhone Book MemoryYesCall Log MemoryYesSMS MemoryYes
# 91 :  Storage512 GB
# 63 :  Storage512 GB
# 375 :  Storage128 GB
# None

# %%
def remove_extra(txt):
    split = txt.split()
    word = split[0]
    if 'Storage1' in split: 
        replace = word.replace('Storage1','Storage1024')
        return replace
    else:
        return word
    
func_apply(func=remove_extra,col_name='storage_ram',df=apple)
# Out:
# Successfully applied function in None
# 241 : Storage64
# 158 : Storage256
# 110 : Storage512
# 90 : Storage256
# 105 : Storage128
# 181 : Storage256
# None

# %% [markdown]
# ### ***os_processor***

# %%
def extract_processor(text):
    pattern = r'.*Chip'
    match = re.findall(pattern, text)
    if match:
        return match[0]
    else:
        split = text.split()
        return ' '.join(split[:5])

func_apply(extract_processor,'os_processor',df=apple)
# Out:
# Successfully applied function in None
# 328 :  SystemiOS 12Processor TypeA11 Bionic Chip
# 231 : SystemiOS 8Processor TypeApple A8 64-bit
# 40 :  SystemiOS 14Processor TypeA14 Bionic Chip
# 231 : SystemiOS 8Processor TypeApple A8 64-bit
# 247 :  SystemiOS 13Processor TypeA13 Bionic Chip
# 368 :  SystemiOS 12Processor TypeA12 Bionic Chip
# None

# %% [markdown]
# # onePlus

# %%
onePlus
# Out:
#                                                   name  ratings    price
# 0        OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)      4.4  ₹17,676  \
# 1       OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)      4.4  ₹17,691
# 2             OnePlus 11R 5G (Galactic Silver, 256 GB)      4.5  ₹44,690
# 3             OnePlus 11R 5G (Galactic Silver, 128 GB)      4.5  ₹39,734
# 4                 OnePlus 11R 5G (Sonic Black, 256 GB)      4.5  ₹44,284
# ..                                                 ...      ...      ...
# 183                 OnePlus N20 SE (BLUE OASIS, 64 GB)      4.2  ₹15,674
# 184            OnePlus 9 Pro 5G (Morning Mist, 128 GB)      3.8  ₹47,999
# 185                   OnePlus 6 (Mirror Black, 128 GB)      4.2  ₹17,990
# 186  OnePlus 6T McLaren Edition (Speed Orange, 256 GB)      4.0  ₹26,990
# 187         OnePlus Nord CE 2 5G (Gray Mirror, 128 GB)      4.2  ₹24,990
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 183  https://rukminim2.flixcart.com/image/312/312/x...
# 184  https://rukminim2.flixcart.com/image/312/312/x...
# 185  https://rukminim2.flixcart.com/image/312/312/x...
# 186  https://rukminim2.flixcart.com/image/312/312/x...
# 187  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 0    Internal Storage128 GBRAM6 GBMemory Card Slot ...  \
# 1    Internal Storage128 GBRAM6 GBMemory Card Slot ...
# 2                       Internal Storage256 GBRAM16 GB
# 3                        Internal Storage128 GBRAM8 GB
# 4                       Internal Storage256 GBRAM16 GB
# ..                                                 ...
# 183  Internal Storage64 GBRAM4 GBMemory Card Slot T...
# 184                      Internal Storage128 GBRAM8 GB
# 185  Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 186  Internal Storage256 GBRAM10 GBMemory Card Slot...
# 187  Internal Storage128 GBRAM8 GBMemory Card Slot ...
#
#                                           os_processor               camera
# 0                   SystemAndroid 10Processor Speed2.2                 64MP  \
# 1                   SystemAndroid 13Processor Speed2.2                 64MP
# 2     SystemAndroid OxygenOS based on Android 13Pro...                 50MP
# 3     SystemAndroid OxygenOS based on Android 13Pro...                 50MP
# 4     SystemAndroid Oxygen OxygenOS based on Androi...                 50MP
# ..                                                 ...                  ...
# 183       SystemAndroid Oxygen 12.1Processor Speed1600                 50MP
# 184                 SystemAndroid 11Processor Speed2.4                 48MP
# 185           SystemAndroid Oreo 8.1Processor Speed2.7  20MP 20MP 16MP 16MP
# 186           SystemAndroid Oxygen 9Processor Speed2.8  20MP 16MP 20MP 16MP
# 187                 SystemAndroid 11Processor Speed2.4                 50MP
#
#                                                display network       battery
# 0    Display Size16.74 cm (6.59 inch)Resolution2412...      5G  Capacity5000
# 1    Display Size16.74 cm (6.59 inch)Resolution2412...      5G  Capacity5000
# 2    Display Size17.02 cm (6.7 inch)Resolution2772x...      5G  Capacity5000
# 3    Display Size17.02 cm (6.7 inch)Resolution2772x...      5G  Capacity5000
# 4    Display Size17.02 cm (6.7 inch)Resolution2772x...      5G  Capacity5000
# ..                                                 ...     ...           ...
# 183  Display Size16.66 cm (6.56 inch)Resolution1612...      4G  Capacity5000
# 184  Display Size17.02 cm (6.7 inch)Resolution3216 ...      5G  Capacity4500
# 185  Display Size15.95 cm (6.28 inch)Resolution1080...      4G  Capacity3300
# 186  Display Size16.28 cm (6.41 inch)Resolution2280...      4G  Capacity3300
# 187  Display Size16.33 cm (6.43 inch)Resolution2400...      5G  Capacity4500
#
# [188 rows x 10 columns]

# %% [markdown]
# ### ***price***

# %%
clean_price_col(onePlus)
# Out:
# 'datatype -Int16'

# %% [markdown]
# ### *****storage_ram*****

# %%
func_apply(func=remove_internal,col_name='storage_ram',df=onePlus)
# Out:
# Successfully applied function in None
# 12 :  Storage128 GBRAM8 GB
# 144 :  Storage256 GBRAM12 GB
# 166 :  Storage256 GBRAM12 GB
# 170 :  Storage256 GBRAM12 GB
# 107 :  Storage128 GBRAM8 GBMemory Card Slot TypeHybrid Slot
# 84 :  Storage128 GBRAM8 GB
# None

# %%
func_apply(func=cut_remove_words,col_name='storage_ram',df=onePlus)
# Out:
# Successfully applied function in None
# 102 : Storage64 GBRAM6
# 88 : Storage256 GBRAM12
# 94 : Storage128 GBRAM8
# 170 : Storage256 GBRAM12
# 5 : Storage256 GBRAM12
# 53 : Storage128 GBRAM8
# None

# %% [markdown]
# # realme

# %%
realme
# Out:
#                                      name  ratings    price
# 0    realme C33 2023 (Sandy Gold, 128 GB)      4.4  ₹10,499  \
# 1     realme C33 2023 (Aqua Blue, 128 GB)      4.4  ₹10,499
# 2     realme C33 2023 (Night Sea, 128 GB)      4.4  ₹10,499
# 3         realme C30 (Denim Black, 32 GB)      4.2   ₹5,999
# 4        realme C30 (Bamboo Green, 32 GB)      4.1   ₹6,499
# ..                                    ...      ...      ...
# 257     realme GT 2 (Paper Green, 256 GB)      4.3  ₹38,999
# 258     realme GT 2 (Paper Green, 128 GB)      4.6  ₹34,999
# 259      realme C21Y (Cross Black, 32 GB)      4.4   ₹7,499
# 260        realme C33 (Sandy Gold, 64 GB)      4.4   ₹9,999
# 261        realme C33 (Sandy Gold, 32 GB)      4.4   ₹8,999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/l...
# 4    https://rukminim2.flixcart.com/image/312/312/l...
# ..                                                 ...
# 257  https://rukminim2.flixcart.com/image/312/312/l...
# 258  https://rukminim2.flixcart.com/image/312/312/l...
# 259  https://rukminim2.flixcart.com/image/312/312/k...
# 260  https://rukminim2.flixcart.com/image/312/312/x...
# 261  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 0    Internal Storage128 GBRAM4 GBExpandable Storag...  \
# 1    Internal Storage128 GBRAM4 GBExpandable Storag...
# 2    Internal Storage128 GBRAM4 GBExpandable Storag...
# 3    Internal Storage32 GBRAM2 GBExpandable Storage...
# 4    Internal Storage32 GBRAM3 GBExpandable Storage...
# ..                                                 ...
# 257   Internal Storage256 GBRAM12 GBCall Log MemoryYes
# 258    Internal Storage128 GBRAM8 GBCall Log MemoryYes
# 259  Internal Storage32 GBRAM3 GBExpandable Storage...
# 260  Internal Storage64 GBRAM4 GBExpandable Storage...
# 261  Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                           os_processor
# 0     SystemAndroid 12Processor TypeUnisoc T612Proc...  \
# 1     SystemAndroid 12Processor TypeUnisoc T612Proc...
# 2     SystemAndroid 12Processor TypeUnisoc T612Proc...
# 3     SystemAndroid 11Processor TypeUnisoc T612Proc...
# 4     SystemAndroid 11Processor TypeUnisoc T612Proc...
# ..                                                 ...
# 257   SystemAndroid 12Processor TypeQualcomm Snapdr...
# 258   SystemAndroid 12Processor TypeQualcomm Snapdr...
# 259   SystemAndroid 11Processor TypeUnisoc T610Proc...
# 260   SystemAndroid 12Processor TypeUnisoc T612Proc...
# 261   SystemAndroid 12Processor TypeUnisoc T612Proc...
#
#                                        camera
# 0          50MP 3MP 50MP 5MP 3MP 50MP 5MP 5MP  \
# 1          50MP 3MP 50MP 5MP 3MP 50MP 5MP 5MP
# 2          50MP 3MP 50MP 5MP 3MP 50MP 5MP 5MP
# 3                             8MP 8MP 5MP 5MP
# 4                             8MP 8MP 5MP 5MP
# ..                                        ...
# 257  50MP 8MP 2MP 50MP 8MP 2MP 50MP 16MP 16MP
# 258  50MP 8MP 2MP 50MP 8MP 2MP 50MP 16MP 16MP
# 259         13MP 2MP 2MP 13MP 2MP 2MP 5MP 5MP
# 260        50MP 3MP 50MP 5MP 3MP 50MP 5MP 5MP
# 261        50MP 3MP 50MP 5MP 3MP 50MP 5MP 5MP
#
#                                                display network       battery
# 0    Display Size16.51 cm (6.5 inch)Resolution1600 ...      4G  Capacity5000
# 1    Display Size16.51 cm (6.5 inch)Resolution1600 ...      4G  Capacity5000
# 2    Display Size16.51 cm (6.5 inch)Resolution1600 ...      4G  Capacity5000
# 3    Display Size16.51 cm (6.5 inch)Resolution1600 ...      4G  Capacity5000
# 4    Display Size16.51 cm (6.5 inch)Resolution1600 ...      4G  Capacity5000
# ..                                                 ...     ...           ...
# 257  Display Size16.81 cm (6.62 inch)Resolution2400...      5G  Capacity5000
# 258  Display Size16.81 cm (6.62 inch)Resolution2400...      5G  Capacity5000
# 259  Display Size16.51 cm (6.5 inch)Resolution1600 ...      4G  Capacity5000
# 260  Display Size16.51 cm (6.5 inch)Resolution1600 ...      4G  Capacity5000
# 261  Display Size16.51 cm (6.5 inch)Resolution1600 ...      4G  Capacity5000
#
# [214 rows x 10 columns]

# %% [markdown]
# ### ***price***

# %%
clean_price_col(realme)
# Out:
# 'datatype -Int16'

# %% [markdown]
# ### *****storage_ram*****

# %%
func_apply(func=remove_internal,col_name='storage_ram',df=realme)
# Out:
# Successfully applied function in None
# 17 :  Storage64 GBRAM4 GBExpandable Storage1 TBSupported Memory Card TypeMicroSDMemory Card Slot TypeDedicated Slot
# 25 :  Storage128 GBRAM6 GBExpandable Storage1 TBSupported Memory Card TypeMicroSDMemory Card Slot TypeHybrid Slot
# 118 :  Storage32 GBRAM3 GBExpandable Storage256 GBSupported Memory Card TypemicroSDMemory Card Slot TypeDedicated Slot
# 190 :  Storage128 GBRAM8 GB
# 190 :  Storage128 GBRAM8 GB
# 15 :  Storage64 GBRAM6 GBExpandable Storage1 TBSupported Memory Card TypeMicroSDMemory Card Slot TypeDedicated Slot
# None

# %%
func_apply(func=cut_remove_words,col_name='storage_ram',df=realme)
# Out:
# Successfully applied function in None
# 99 : Storage128 GBRAM8 GBExpandable Storage256GB
# 182 : Storage128 GBRAM8
# 166 : Storage128 GBRAM6
# 98 : Storage256 GBRAM8
# 68 : Storage64 GBRAM4 GBExpandable Storage256GB
# 194 : Storage64 GBRAM4 GBExpandable Storage1TB
# None

# %% [markdown]
# # vivo

# %%
vivo
# Out:
#                                      name  ratings    price
# 0       vivo T2x 5G (Marine Blue, 128 GB)      4.4  ₹13,999  \
# 1     vivo T2x 5G (Glimmer Black, 128 GB)      4.4  ₹13,999
# 2       vivo T2x 5G (Aurora Gold, 128 GB)      4.4  ₹13,999
# 3       vivo T2x 5G (Aurora Gold, 128 GB)      4.3  ₹15,999
# 4     vivo T2x 5G (Glimmer Black, 128 GB)      4.3  ₹15,999
# ..                                    ...      ...      ...
# 307      vivo Y20 (Obsidian Black, 64 GB)      4.3  ₹16,990
# 308         vivo Y20 (Purist Blue, 64 GB)      4.3  ₹16,990
# 309    vivo S1 Pro (Dreamy White, 128 GB)      4.4  ₹20,990
# 310  vivo Y51A (Crystal Symphony, 128 GB)      4.3  ₹16,990
# 311    vivo S1 Pro (Mystic Black, 128 GB)      4.4  ₹18,950
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 307  https://rukminim2.flixcart.com/image/312/312/k...
# 308  https://rukminim2.flixcart.com/image/312/312/k...
# 309  https://rukminim2.flixcart.com/image/312/312/k...
# 310  https://rukminim2.flixcart.com/image/312/312/k...
# 311  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 0    Internal Storage128 GBRAM6 GBMemory Card Slot ...  \
# 1    Internal Storage128 GBRAM6 GBMemory Card Slot ...
# 2    Internal Storage128 GBRAM6 GBMemory Card Slot ...
# 3    Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 4    Internal Storage128 GBRAM8 GBMemory Card Slot ...
# ..                                                 ...
# 307  Internal Storage64 GBRAM4 GBExpandable Storage...
# 308  Internal Storage64 GBRAM4 GBExpandable Storage...
# 309  Internal Storage128 GBRAM8 GBExpandable Storag...
# 310  Internal Storage128 GBRAM6 GBExpandable Storag...
# 311  Internal Storage128 GBRAM8 GBExpandable Storag...
#
#                                           os_processor
# 0     SystemAndroid 13Processor TypeDimensity 6020P...  \
# 1     SystemAndroid 13Processor TypeDimensity 6020P...
# 2     SystemAndroid 13Processor TypeDimensity 6020P...
# 3     SystemAndroid 13Processor TypeDimensity 6020P...
# 4     SystemAndroid 13Processor TypeDimensity 6020P...
# ..                                                 ...
# 307   SystemAndroid 10Processor TypeQualcomm Snapdr...
# 308   SystemAndroid 10Processor TypeQualcomm Snapdr...
# 309   SystemAndroid Pie 9Processor TypeQualcomm Sna...
# 310   SystemAndroid 11Processor TypeQualcomm Snapdr...
# 311   SystemAndroid Pie 9Processor TypeQualcomm Sna...
#
#                                                camera
# 0                           50MP 2MP 50MP 2MP 8MP 8MP  \
# 1                           50MP 2MP 50MP 2MP 8MP 8MP
# 2                           50MP 2MP 50MP 2MP 8MP 8MP
# 3                           50MP 2MP 50MP 2MP 8MP 8MP
# 4                           50MP 2MP 50MP 2MP 8MP 8MP
# ..                                                ...
# 307    13MP 2MP 2MP 13MP 2MP 2MP 13MP 2MP 2MP 8MP 8MP
# 308    13MP 2MP 2MP 13MP 2MP 2MP 13MP 2MP 2MP 8MP 8MP
# 309  48MP 8MP 2MP 2MP 48MP 48MP 8MP 2MP 2MP 32MP 32MP
# 310               48MP 8MP 2MP 48MP 8MP 2MP 16MP 16MP
# 311  48MP 8MP 2MP 2MP 48MP 48MP 8MP 2MP 2MP 32MP 32MP
#
#                                                display network       battery
# 0    Display Size16.71 cm (6.58 inch)Resolution2408...      5G  Capacity5000
# 1    Display Size16.71 cm (6.58 inch)Resolution2408...      5G  Capacity5000
# 2    Display Size16.71 cm (6.58 inch)Resolution2408...      5G  Capacity5000
# 3    Display Size16.71 cm (6.58 inch)Resolution2408...      5G  Capacity5000
# 4    Display Size16.71 cm (6.58 inch)Resolution2408...      5G  Capacity5000
# ..                                                 ...     ...           ...
# 307  Display Size16.54 cm (6.51 inch)Resolution1600...      4G  Capacity5000
# 308  Display Size16.54 cm (6.51 inch)Resolution1600...      4G  Capacity5000
# 309  Display Size16.21 cm (6.38 inch)Resolution1080...      4G  Capacity4500
# 310  Display Size16.71 cm (6.58 inch)Resolution2408...      4G  Capacity5000
# 311  Display Size16.21 cm (6.38 inch)Resolution1080...      4G  Capacity4500
#
# [301 rows x 10 columns]

# %% [markdown]
# ### ***price***

# %%
clean_price_col(vivo)
# Out:
# 'datatype -Int16'

# %% [markdown]
# ### ***storage_ram***

# %%
func_apply(func=remove_internal,col_name='storage_ram',df=vivo)
# Out:
# Successfully applied function in None
# 254 :  Storage128 GBRAM8 GBCall Log MemoryYes
# 237 :  Storage64 GBRAM4 GBExpandable Storage256 GBSupported Memory Card TypemicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 250 :  Storage256 GBRAM12 GBPhone Book MemoryYesCall Log MemoryYes
# 188 :  Storage128 GBRAM8 GBCall Log MemoryYes
# 103 :  Storage128 GBRAM8 GBCall Log MemoryYes
# 300 :  Storage128 GBRAM8 GBExpandable Storage256 GBSupported Memory Card TypemicroSDMemory Card Slot TypeHybrid Slot
# None

# %%
func_apply(func=cut_remove_words,col_name='storage_ram',df=vivo)
# Out:
# Successfully applied function in None
# 215 : Storage256 GBRAM12
# 169 : Storage64 GBRAM4 GBExpandable Storage256GB
# 118 : Storage256 GBRAM12
# 268 : Storage128 GBRAM6 GBExpandable Storage256GB
# 197 : Storage64 GBRAM4 GBExpandable Storage256GB
# 121 : Storage128 GBRAM4
# None

# %% [markdown]
# # oppo

# %%
oppo
# Out:
#                                             name  ratings    price
# 0                        OPPO A17k (Blue, 64 GB)      4.5   ₹9,499  \
# 1                    OPPO A17 (Lake Blue, 64 GB)      4.4  ₹12,200
# 2               OPPO A17 (Midnight Black, 64 GB)      4.4  ₹12,499
# 3            OPPO A78 5G (Glowing Black, 128 GB)      4.3  ₹18,142
# 4                    OPPO A17 (Lake Blue, 64 GB)      4.4  ₹12,499
# ..                                           ...      ...      ...
# 248                       OPPO A5s (Gold, 64 GB)      4.3  ₹15,990
# 249  OPPO Reno7 Pro 5G (Startrails Blue, 256 GB)      4.4  ₹34,999
# 250                        OPPO A5s (Red, 32 GB)      4.3  ₹13,990
# 251               OPPO A15S (Fancy White, 64 GB)      4.4  ₹11,309
# 252                OPPO A7 (Glaring Gold, 64 GB)      4.4  ₹16,990
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 248  https://rukminim2.flixcart.com/image/312/312/k...
# 249  https://rukminim2.flixcart.com/image/312/312/k...
# 250  https://rukminim2.flixcart.com/image/312/312/k...
# 251  https://rukminim2.flixcart.com/image/312/312/k...
# 252  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                            storage_ram
# 0    Internal Storage64 GBRAM3 GBExpandable Storage...  \
# 1    Internal Storage64 GBRAM4 GBMemory Card Slot T...
# 2    Internal Storage64 GBRAM4 GBExpandable Storage...
# 3    Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 4    Internal Storage64 GBRAM4 GBExpandable Storage...
# ..                                                 ...
# 248  Internal Storage64 GBRAM4 GBExpandable Storage...
# 249  Internal Storage256 GBRAM12 GBExpandable Stora...
# 250  Internal Storage32 GBRAM3 GBExpandable Storage...
# 251  Internal Storage64 GBRAM4 GBMemory Card Slot T...
# 252  Internal Storage64 GBRAM3 GBExpandable Storage...
#
#                                           os_processor
# 0     SystemAndroid 12Processor TypeMediatek Helio ...  \
# 1     SystemAndroid Q 12Processor TypeMediatek Heli...
# 2     SystemAndroid 12Processor TypeMediatek Helio ...
# 3                        SystemAndroidProcessor Speed2
# 4     SystemAndroid 12Processor TypeMediatek Helio ...
# ..                                                 ...
# 248   SystemAndroid Oreo 8.1Processor TypeMediaTek ...
# 249   SystemAndroid 11Processor TypeMediaTek Dimens...
# 250   SystemAndroid Oreo 8.1Processor TypeMTK MT676...
# 251             SystemAndroid Q 10.0Processor Speed2.3
# 252   SystemAndroid Oreo 8.1Processor TypeQualcomm ...
#
#                                   camera
# 0                        8MP 8MP 5MP 5MP  \
# 1          50MP 3MP 50MP 3MP 3MP 5MP 5MP
# 2      50MP 3MP 3MP 50MP 3MP 3MP 5MP 5MP
# 3                                   13MP
# 4      50MP 3MP 3MP 50MP 3MP 3MP 5MP 5MP
# ..                                   ...
# 248                         13MP 2MP 8MP
# 249  50MP 8MP 2MP 50MP 8MP 2MP 32MP 32MP
# 250                         13MP 2MP 8MP
# 251                                 13MP
# 252                        13MP 2MP 16MP
#
#                                                display network       battery
# 0    Display Size16.66 cm (6.56 inch)Resolution1612...      4G  Capacity5000
# 1    Display Size16.66 cm (6.56 inch)Resolution1612...      4G  Capacity5000
# 2    Display Size16.66 cm (6.56 inch)Resolution1612...      4G  Capacity5000
# 3    Display Size16.66 cm (6.56 inch)Resolution720 ...      5G  Capacity5000
# 4    Display Size16.66 cm (6.56 inch)Resolution1612...      4G  Capacity5000
# ..                                                 ...     ...           ...
# 248  Display Size15.75 cm (6.2 inch)Resolution1520 ...      3G  Capacity4230
# 249  Display Size16.51 cm (6.5 inch)Resolution2400 ...      5G  Capacity4500
# 250  Display Size15.75 cm (6.2 inch)Resolution1520 ...      3G  Capacity4230
# 251  Display Size16.56 cm (6.52 inch)Resolution720 ...      4G  Capacity4230
# 252  Display Size15.75 cm (6.2 inch)Resolution1520 ...      3G  Capacity4230
#
# [251 rows x 10 columns]

# %%
func_apply(func=remove_internal,col_name='storage_ram',df=oppo)
# Out:
# Successfully applied function in None
# 235 :  Storage64 GBRAM6 GBExpandable Storage256 GBSupported Memory Card TypemicroSDMemory Card Slot TypeDedicated Slot
# 248 :  Storage32 GBRAM3 GBExpandable Storage256 GBSupported Memory Card TypemicroSDMemory Card Slot TypeDedicated Slot
# 89 :  Storage128 GBRAM8 GBExpandable Storage256 GBMemory Card Slot TypeDedicated Slot
# 7 :  Storage128 GBRAM8 GBExpandable Storage1 TBMemory Card Slot TypeHybrid Slot
# 137 :  Storage32 GBRAM2 GBExpandable Storage256 GBSupported Memory Card TypemicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 29 :  Storage32 GBRAM3 GBExpandable Storage1 TBSupported Memory Card TypeMicroSDMemory Card Slot TypeDedicated Slot
# None

# %%
func_apply(func=cut_remove_words,col_name='storage_ram',df=oppo)
# Out:
# Successfully applied function in None
# 201 : Storage128 GBRAM8
# 40 : Storage128 GBRAM8
# 129 : Storage128 GBRAM6 GBExpandable Storage1TB
# 60 : Storage256 GBRAM8
# 106 : Storage64 GBRAM4 GBExpandable Storage256GB
# 14 : Storage128 GBRAM8 GBExpandable Storage1TB
# None

# %% [markdown]
# # motorola

# %%
motorola
# Out:
#                                                 name  ratings    price
# 0               MOTOROLA g42 (Atlantic Green, 64 GB)      4.2   ₹9,999  \
# 1                 MOTOROLA e13 (Cosmic Black, 64 GB)      4.0   ₹7,299
# 2                MOTOROLA G32 (Mineral Gray, 128 GB)      4.1  ₹11,999
# 3                  MOTOROLA e32 (Arctic Blue, 64 GB)      3.9   ₹7,999
# 4               MOTOROLA g13 (Lavender Blue, 128 GB)      3.9   ₹9,999
# ..                                               ...      ...      ...
# 115              Moto E6s (Polished Graphite, 64 GB)      4.1   ₹7,499
# 116                 MOTOROLA G30 (Pastel Sky, 64 GB)      4.1  ₹10,999
# 117          MOTOROLA G10 Power (Breeze Blue, 64 GB)      4.2   ₹9,999
# 118  MOTOROLA Edge 20 Fusion 5G (Cyber Teal, 128 GB)      4.0  ₹18,999
# 119    MOTOROLA Edge 30 Pro (Stardust White, 128 GB)      4.0  ₹34,999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/l...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 115  https://rukminim2.flixcart.com/image/312/312/k...
# 116  https://rukminim2.flixcart.com/image/312/312/k...
# 117  https://rukminim2.flixcart.com/image/312/312/k...
# 118  https://rukminim2.flixcart.com/image/312/312/k...
# 119  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 0    Internal Storage64 GBRAM4 GBSupported Memory C...  \
# 1    Internal Storage64 GBRAM4 GBExpandable Storage...
# 2    Internal Storage128 GBRAM8 GBSupported Memory ...
# 3    Internal Storage64 GBRAM4 GBExpandable Storage...
# 4    Internal Storage128 GBRAM4 GBExpandable Storag...
# ..                                                 ...
# 115  Internal Storage64 GBRAM4 GBExpandable Storage...
# 116  Internal Storage64 GBRAM4 GBSupported Memory C...
# 117  Internal Storage64 GBRAM4 GBSupported Memory C...
# 118  Internal Storage128 GBRAM6 GBMemory Card Slot ...
# 119                      Internal Storage128 GBRAM8 GB
#
#                                           os_processor
# 0     SystemAndroid 12Processor TypeQualcomm Snapdr...  \
# 1     SystemAndroid 13 (Go Edition)Processor TypeUn...
# 2     SystemAndroid 12Processor TypeQualcomm Snapdr...
# 3     SystemAndroid 12Processor TypeMediatek Helio ...
# 4     SystemAndroid 13Processor TypeHelio G85Proces...
# ..                                                 ...
# 115   SystemAndroid 11Processor TypeSnapdragon 662P...
# 116   SystemAndroid 11Processor TypeSnapdragon 460P...
# 117   SystemAndroid 11Processor TypeMediaTek Dimens...
# 118   SystemAndroid 12Processor TypeQualcomm Snapdr...
# 119  Primary Camera AvailableYesPrimary Camera 50MP...
#
#                                                 camera
# 0                  50MP 8MP 2MP 50MP 8MP 2MP 16MP 16MP  \
# 1                                    13MP 13MP 5MP 5MP
# 2                  50MP 8MP 2MP 50MP 8MP 2MP 16MP 16MP
# 3                            50MP 2MP 50MP 2MP 8MP 8MP
# 4                    50MP 2MP 2MP 50MP 2MP 2MP 8MP 8MP
# ..                                                 ...
# 115                          13MP 2MP 13MP 2MP 8MP 8MP
# 116  64MP 8MP 2MP 2MP 64MP 8MP 2MP 2MP 64MP 8MP 13M...
# 117              48MP 8MP 2MP 2MP 48MP 8MP 2MP 2MP 8MP
# 118              108MP 8MP 2MP 108MP 8MP 2MP 32MP 32MP
# 119              50MP 50MP 2MP 50MP 50MP 2MP 60MP 60MP
#
#                                                display network       battery
# 0    Display Size16.43 cm (6.47 inch)Resolution2400...      4G  Capacity5000
# 1    Display Size16.51 cm (6.5 inch)Resolution1600 ...      4G  Capacity5000
# 2    Display Size16.51 cm (6.5 inch)Resolution2400 ...      4G  Capacity5000
# 3    Display Size16.51 cm (6.5 inch)Resolution1600 ...      4G  Capacity5000
# 4    Display Size16.51 cm (6.5 inch)Resolution1600 ...      2G  Capacity5000
# ..                                                 ...     ...           ...
# 115  Display Size15.49 cm (6.1 inch)Resolution1560 ...      4G  Capacity3000
# 116  Display Size16.54 cm (6.51 inch)Resolution1600...      4G  Capacity5000
# 117  Display Size16.54 cm (6.51 inch)Resolution1600...      4G  Capacity6000
# 118  Display Size16.94 cm (6.67 inch)Resolution2400...      5G  Capacity5000
# 119  Display Size16.3 cm (6.417 inch)Resolution2400...      5G  Capacity4800
#
# [119 rows x 10 columns]

# %% [markdown]
# ### ***price***

# %%
clean_price_col(motorola)
# Out:
# 'datatype -Int16'

# %% [markdown]
# ### ***storage_ram***

# %%
func_apply(func=remove_internal,col_name='storage_ram',df=motorola)
# Out:
# Successfully applied function in None
# 66 :  Storage16 GBRAM2 GBExpandable Storage32 GBSupported Memory Card TypemicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 53 :  Storage128 GBRAM6 GBSupported Memory Card TypemicroSDMemory Card Slot TypeHybrid Slot
# 92 :  Storage128 GBRAM8 GB
# 100 :  Storage128 GBRAM6 GBSupported Memory Card TypemicroSDMemory Card Slot TypeHybrid Slot
# 74 :  Storage128 GBRAM8 GBSupported Memory Card TypeMicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 32 :  Storage256 GBRAM12 GB
# None

# %%
func_apply(func=cut_remove_words,col_name='storage_ram',df=motorola)
# Out:
# Successfully applied function in None
# 16 : Storage32 MBRAM4
# 86 : Storage64 GBRAM4 GBExpandable Storage1TB
# 55 : Storage64 GBRAM4 GBExpandable Storage1TB
# 42 : Storage64 GBRAM4 GBExpandable Storage1TB
# 98 : Storage64 GBRAM4
# 80 : Storage64 GBRAM4 GBExpandable Storage512GB
# None

# %%
def random_values(col_name:str,df:pd.DataFrame,total=6):
    for i in range(0,total):
        index = np.random.randint(df.shape[0])
        print(index,':',df[col_name].iloc[index])        

random_values(col_name='storage_ram',df=motorola)
# Out:
# 107 : Storage128 GBRAM6
# 91 : Storage128 GBRAM6
# 70 : Storage64 GBRAM4 GBExpandable Storage256GB
# 33 : Storage64 GBRAM4 GBExpandable Storage1TB
# 74 : Storage128 GBRAM8
# 15 : Storage128 GBRAM8

# %% [markdown]
# # techno

# %%
techno
# Out:
#                                           name  ratings    price
# 0             Tecno Pova 3 (Eco Black, 128 GB)      4.1  ₹13,998  \
# 1      Tecno Pop 5 Pro (Deepsea Luster, 32 GB)      4.2   ₹6,960
# 2              Tecno Pova 3 (Eco Black, 64 GB)      4.2  ₹10,849
# 3            Tecno Pova 3 (Tech Silver, 64 GB)      4.2  ₹10,978
# 4    Tecno Spark Go 2023 (UYUNI BLUE, 32+3 GB)      4.1   ₹6,750
# ..                                         ...      ...      ...
# 146         Tecno Camon 15 (SHOAL GOLD, 64 GB)      4.2  ₹12,499
# 147           Tecno Camon 19 Neo (Green, 6 GB)      4.1  ₹18,490
# 148  Tecno Spark 10 Pro (Starry Black, 256 GB)      4.1  ₹14,999
# 149   Tecno Spark 10 Pro (Pearl White, 256 GB)      4.1  ₹14,999
# 150       Tecno Spark 10 pro (Meta Blue, 8 GB)      4.1  ₹13,999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/l...  \
# 1    https://rukminim2.flixcart.com/image/312/312/k...
# 2    https://rukminim2.flixcart.com/image/312/312/l...
# 3    https://rukminim2.flixcart.com/image/312/312/l...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 146  https://rukminim2.flixcart.com/image/312/312/k...
# 147  https://rukminim2.flixcart.com/image/312/312/x...
# 148  https://rukminim2.flixcart.com/image/312/312/x...
# 149  https://rukminim2.flixcart.com/image/312/312/x...
# 150  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 0    Internal Storage128 GBRAM6 GBExpandable Storag...  \
# 1    Internal Storage32 GBRAM3 GBExpandable Storage...
# 2    Internal Storage64 GBRAM4 GBExpandable Storage...
# 3    Internal Storage64 GBRAM4 GBExpandable Storage...
# 4    Internal Storage32+3 GBRAM3 GBMemory Card Slot...
# ..                                                 ...
# 146  Internal Storage64 GBRAM4 GBExpandable Storage...
# 147  Internal Storage6 GBRAM128 GBMemory Card Slot ...
# 148  Internal Storage256 GBRAM8 GBExpandable Storag...
# 149  Internal Storage256 GBRAM8 GBExpandable Storag...
# 150  Internal Storage8 GBRAM8 GBMemory Card Slot Ty...
#
#                                           os_processor
# 0     SystemAndroid 12Processor TypeMediaTek Helio ...  \
# 1     SystemAndroid 11 (Go Edition)Processor TypeHe...
# 2     SystemAndroid 12Processor TypeMediaTek Helio ...
# 3     SystemAndroid 12Processor TypeMediaTek Helio ...
# 4             SystemAndroid 12Primary Clock Speed2 GHz
# ..                                                 ...
# 146   SystemAndroid 10Processor TypeHelio P22 MT676...
# 147   SystemAndroid Android 12Primary Clock Speed2 GHz
# 148   SystemAndroid 13Processor TypeMediatek MT6769...
# 149   SystemAndroid 13Processor TypeMediatek MT6769...
# 150           SystemAndroid 13Primary Clock Speed2 GHz
#
#                                   camera
# 0                       50MP 2MP 2MP 8MP  \
# 1                                8MP 5MP
# 2                       50MP 2MP 2MP 8MP
# 3                       50MP 2MP 2MP 8MP
# 4                                   13MP
# ..                                   ...
# 146  48MP 2MP 2MP 48MP 2MP 2MP 16MP 16MP
# 147                                 48MP
# 148                            50MP 32MP
# 149                            50MP 32MP
# 150                                 50MP
#
#                                                display network       battery
# 0    Display Size17.53 cm (6.9 inch)Resolution1080 ...      4G  Capacity7000
# 1    Display Size16.56 cm (6.52 inch)Resolution720 ...      4G  Capacity6000
# 2    Display Size17.53 cm (6.9 inch)Resolution1080 ...      4G  Capacity7000
# 3    Display Size17.53 cm (6.9 inch)Resolution1080 ...      4G  Capacity7000
# 4    Display Size16.66 cm (6.56 inch)Resolution720x...      4G  Capacity5000
# ..                                                 ...     ...           ...
# 146  Display Size16.64 cm (6.55 inch)Resolution720 ...      4G  Capacity5000
# 147  Display Size17.27 cm (6.8 inch)Resolution2460x...      2G  Capacity5000
# 148  Display Size17.22 cm (6.78 inch)Resolution2460...      4G  Capacity5000
# 149  Display Size17.22 cm (6.78 inch)Resolution2460...      4G  Capacity5000
# 150  Display Size17.27 cm (6.8 inch)Resolution1080 ...      4G  Capacity5000
#
# [151 rows x 10 columns]

# %% [markdown]
# ### ***price***

# %%
techno['price'][95] = '15999'

# %%
clean_price_col(techno)
# Out:
# 'datatype -Int16'

# %%
techno[techno['price'] == 'nan']
# Out:
# Empty DataFrame
# Columns: [index, name, ratings, price, imgURL, storage_ram, os_processor, camera, display, network, battery]
# Index: []

# %%
random_values(col_name='storage_ram',df=techno)
# Out:
# 13 : Internal Storage64 GBRAM4 GBExpandable Storage512 GBSupported Memory Card TypeMicro SDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 48 : Internal Storage128 GBRAM8 GBExpandable Storage1 TBSupported Memory Card TypeMicro SDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 137 : Internal Storage64 GBRAM3 GBMemory Card Slot TypeDedicated Slot
# 150 : Internal Storage8 GBRAM8 GBMemory Card Slot TypeDedicated Slot
# 125 : Internal Storage32 GBRAM2 GBExpandable Storage256 GBSupported Memory Card TypemicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 7 : Internal Storage64 GBRAM2 GBMemory Card Slot TypeDedicated Slot

# %% [markdown]
# ### ***storage_ram***

# %%
func_apply(func=remove_internal,col_name='storage_ram',df=techno)
# Out:
# Successfully applied function in None
# 118 :  Storage64 GBRAM4 GBExpandable Storage256 GBSupported Memory Card TypemicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 26 :  Storage64 GBRAM2 GBExpandable Storage256 GBSupported Memory Card TypemicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 85 :  Storage128 GBRAM8 GBExpandable Storage1 TBSupported Memory Card TypeMicro SDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 115 :  Storage32 GBRAM2 GBTotal Memory32 GBMemory Card Slot TypeDedicated Slot
# 113 :  Storage128 GBRAM8 GBExpandable Storage2 TBSupported Memory Card TypemicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 6 :  Storage32+3 GBRAM3 GBMemory Card Slot TypeDedicated Slot
# None

# %%
func_apply(func=cut_remove_words,col_name='storage_ram',df=techno)
# Out:
# Successfully applied function in None
# 100 : Storage128 GBRAM4 GBExpandable Storage512GB
# 111 : Storage128 GBRAM6 GBExpandable Storage512GB
# 118 : Storage64 GBRAM4 GBExpandable Storage256GB
# 8 : Storage64 GBRAM2
# 105 : Storage128 GBRAM6 GBExpandable Storage256GB
# 83 : Storage256 GBRAM8 GBExpandable Storage1TB
# None

# %% [markdown]
# # infinix

# %%
infinix
# Out:
#                                              name  ratings    price
# 0             Infinix SMART 7 (Azure Blue, 64 GB)      4.3   ₹7,299  \
# 1              Infinix HOT 30i (Marigold, 128 GB)      4.3   ₹8,999
# 2               Infinix HOT 30i (Marigold, 64 GB)      4.3   ₹7,999
# 3         Infinix HOT 30i (Diamond White, 128 GB)      4.3   ₹8,999
# 4          Infinix HOT 30i (Diamond White, 64 GB)      4.3   ₹7,999
# ..                                            ...      ...      ...
# 187          Infinix Hot S3X (Milan Black, 32 GB)      4.2  ₹10,999
# 188   Infinix Note 10 Pro (Nordic Secret, 256 GB)      4.2  ₹16,999
# 189   Infinix Note 5 Stylus (Bordeaux Red, 64 GB)      3.9  ₹16,999
# 190  Infinix Note 5 Stylus (Charcoal Blue, 64 GB)      3.9  ₹16,999
# 191       Infinix S5 Lite (Midnight Black, 64 GB)      4.3   ₹9,999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 187  https://rukminim2.flixcart.com/image/312/312/j...
# 188  https://rukminim2.flixcart.com/image/312/312/k...
# 189  https://rukminim2.flixcart.com/image/312/312/j...
# 190  https://rukminim2.flixcart.com/image/312/312/j...
# 191  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 0    Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 1    Internal Storage128 GBRAM8 GBExpandable Storag...
# 2    Internal Storage64 GBRAM4 GBExpandable Storage...
# 3    Internal Storage128 GBRAM8 GBExpandable Storag...
# 4    Internal Storage64 GBRAM4 GBExpandable Storage...
# ..                                                 ...
# 187  Internal Storage32 GBRAM3 GBExpandable Storage...
# 188  Internal Storage256 GBRAM8 GBExpandable Storag...
# 189  Internal Storage64 GBRAM4 GBExpandable Storage...
# 190  Internal Storage64 GBRAM4 GBExpandable Storage...
# 191  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                           os_processor
# 0     SystemAndroid 12Processor TypeUnisoc Spreadtr...  \
# 1     SystemAndroid 12Processor TypeG37Processor Sp...
# 2     SystemAndroid 12Processor TypeG37Processor Sp...
# 3     SystemAndroid 12Processor TypeG37Processor Sp...
# 4     SystemAndroid 12Processor TypeG37Processor Sp...
# ..                                                 ...
# 187   SystemAndroid Oreo 8.1Processor TypeQualcomm ...
# 188   SystemAndroid 11Processor TypeMediaTek Helio ...
# 189   SystemAndroid Oreo 8.1Processor TypeMediatek ...
# 190   SystemAndroid Oreo 8.1Processor TypeMediatek ...
# 191   SystemAndroid Pie 9Processor TypeHelio P22 (M...
#
#                                           camera
# 0                              13MP 13MP 5MP 5MP  \
# 1                              50MP 50MP 5MP 5MP
# 2                              50MP 50MP 5MP 5MP
# 3                              50MP 50MP 5MP 5MP
# 4                              50MP 50MP 5MP 5MP
# ..                                           ...
# 187                                13MP 2MP 16MP
# 188  64MP 8MP 2MP 2MP 64MP 8MP 2MP 2MP 16MP 16MP
# 189                          16MP 16MP 16MP 16MP
# 190                          16MP 16MP 16MP 16MP
# 191                  16MP 2MP 16MP 2MP 16MP 16MP
#
#                                                display network       battery
# 0    Display Size16.76 cm (6.6 inch)Resolution1612 ...      4G  Capacity6000
# 1    Display Size16.76 cm (6.6 inch)Resolution1612 ...      2G  Capacity5000
# 2    Display Size16.76 cm (6.6 inch)Resolution1612 ...      2G  Capacity5000
# 3    Display Size16.76 cm (6.6 inch)Resolution1612 ...      2G  Capacity5000
# 4    Display Size16.76 cm (6.6 inch)Resolution1612 ...      2G  Capacity5000
# ..                                                 ...     ...           ...
# 187  Display Size15.75 cm (6.2 inch)Resolution1500 ...      3G  Capacity4000
# 188  Display Size17.65 cm (6.95 inch)Resolution2460...      4G  Capacity5000
# 189  Display Size15.06 cm (5.93 inch)Resolution1080...      3G  Capacity4000
# 190  Display Size15.06 cm (5.93 inch)Resolution1080...      3G  Capacity4000
# 191  Display Size16.76 cm (6.6 inch)Resolution720 x...      4G  Capacity4000
#
# [163 rows x 10 columns]

# %% [markdown]
# ## ***price***

# %%
clean_price_col(infinix)
# Out:
# 'datatype -Int16'

# %% [markdown]
# ### ***storage_ram***

# %%
func_apply(func=remove_internal,col_name='storage_ram',df=infinix)
# Out:
# Successfully applied function in None
# 44 :  Storage64 GBRAM4 GBExpandable Storage256 GBSupported Memory Card TypeMicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 162 :  Storage64 GBRAM4 GBExpandable Storage256 GBSupported Memory Card TypemicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 145 :  Storage128 GBRAM8 GBExpandable Storage256 GBMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 48 :  Storage64 GBRAM4 GBExpandable Storage256 GBSupported Memory Card TypeMicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 68 :  Storage64 GBRAM6 GBExpandable Storage256 GBSupported Memory Card TypeMicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 21 :  Storage64 GBRAM4 GBExpandable Storage1 TBSupported Memory Card TypeMicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# None

# %%
func_apply(func=cut_remove_words,col_name='storage_ram',df=infinix)
# Out:
# Successfully applied function in None
# 107 : Storage64 GBRAM4 GBExpandable Storage256GB
# 27 : Storage32 GBRAM2 GBExpandable Storage512GB
# 57 : Storage64 GBRAM4 GBExpandable Storage256GB
# 86 : Storage64 GBRAM4 GBExpandable Storage256GB
# 67 : Storage128 GBRAM8 GBExpandable Storage256GB
# 2 : Storage64 GBRAM4 GBExpandable Storage1TB
# None

# %%
random_values(col_name='storage_ram',df=infinix)
# Out:
# 112 : Storage32 GBRAM2 GBExpandable Storage256GB
# 110 : Storage64 GBRAM4 GBExpandable Storage256GB
# 10 : Storage64 GBRAM2 GBExpandable Storage1TB
# 157 : Storage128 GBRAM8 GBExpandable Storage512GB
# 88 : Storage128 GBRAM8 GBExpandable Storage1TB
# 86 : Storage64 GBRAM4 GBExpandable Storage256GB

# %%
mi
# Out:
#      index                                       name  ratings  price
# 0        0        Redmi 9A Sport (Coral Green, 32 GB)      4.2   8990  \
# 1        1     Xiaomi 11Lite NE (Vinyl Black, 128 GB)      4.2  21430
# 2        2  Xiaomi 11Lite NE (Diamond Dazzle, 128 GB)      4.2  20999
# 3        3   Xiaomi 11Lite NE (Tuscany Coral, 128 GB)      4.2  20999
# 4        4             Mi 11 Lite (Jazz Blue, 128 GB)      4.2  17499
# ..     ...                                        ...      ...    ...
# 484    546             13 pro (Ceramic Black, 256 GB)      4.3  14463
# 485    547               Mi A3 (Not just Blue, 64 GB)      4.2  14999
# 486    548          Mi 10T Pro (Lunar Silver, 128 GB)      4.3  26899
# 487    549                     Redmi Y1 (Gold, 32 GB)      4.5   8999
# 488    550    Redmi Note 7 Pro (Neptune Blue, 128 GB)      4.3  17999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/k...
# ..                                                 ...
# 484  https://rukminim2.flixcart.com/image/312/312/x...
# 485  https://rukminim2.flixcart.com/image/312/312/k...
# 486  https://rukminim2.flixcart.com/image/312/312/k...
# 487  https://rukminim2.flixcart.com/image/312/312/j...
# 488  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                      storage_ram
# 0                               Storage32 GBRAM3  \
# 1      Storage128 GBRAM6 GBExpandable Storage1TB
# 2      Storage128 GBRAM6 GBExpandable Storage1TB
# 3      Storage128 GBRAM6 GBExpandable Storage1TB
# 4    Storage128 GBRAM8 GBExpandable Storage512GB
# ..                                           ...
# 484                           Storage256 GBRAM12
# 485   Storage64 GBRAM4 GBExpandable Storage256GB
# 486                            Storage128 GBRAM8
# 487   Storage32 GBRAM3 GBExpandable Storage128GB
# 488  Storage128 GBRAM6 GBExpandable Storage256GB
#
#                                           os_processor
# 0                   SystemAndroid Q 10Processor Speed2  \
# 1     SystemAndroid 11Processor TypeQualcomm Snapdr...
# 2     SystemAndroid 11Processor TypeQualcomm Snapdr...
# 3     SystemAndroid 11Processor TypeQualcomm Snapdr...
# 4     SystemAndroid 11Processor TypeQualcomm Snapdr...
# ..                                                 ...
# 484   SystemAndroid MIUI 14, Android 13.0Processor ...
# 485   SystemAndroid Pie 9Processor TypeQualcomm Sna...
# 486   SystemAndroid 10Processor TypeQualcomm Snapdr...
# 487   SystemAndroid Nougat 7.1.2Processor TypeQualc...
# 488   SystemAndroid Pie 9.0Processor TypeQualcomm S...
#
#                                                 camera
# 0                                                 13MP  \
# 1                                    64MP 8MP 5MP 20MP
# 2                                    64MP 8MP 5MP 20MP
# 3                                    64MP 8MP 5MP 20MP
# 4                  64MP 8MP 5MP 64MP 8MP 5MP 16MP 16MP
# ..                                                 ...
# 484                                               50MP
# 485                48MP 8MP 2MP 48MP 8MP 2MP 32MP 32MP
# 486  108MP 13MP 5MP 108MP 13MP 5MP 108MP 13MP 5MP 20MP
# 487                                          13MP 16MP
# 488                             48MP 5MP 48MP 5MP 13MP
#
#                                                display network       battery
# 0    Display Size16.59 cm (6.53 inch)Resolution1600...      4G  Capacity5000
# 1    Display Size16.64 cm (6.55 inch)Resolution1080...      5G  Capacity4250
# 2    Display Size16.64 cm (6.55 inch)Resolution1080...      5G  Capacity4250
# 3    Display Size16.64 cm (6.55 inch)Resolution1080...      5G  Capacity4250
# 4    Display Size16.64 cm (6.55 inch)Resolution2400...      4G  Capacity4250
# ..                                                 ...     ...           ...
# 484  Display Size17.09 cm (6.73 inch)Resolution3200...      5G  Capacity4820
# 485  Display Size15.46 cm (6.088 inch)Resolution156...      4G  Capacity4030
# 486  Display Size16.94 cm (6.67 inch)Resolution2400...      5G  Capacity5000
# 487  Display Size13.97 cm (5.5 inch)Resolution1280 ...      3G  Capacity3080
# 488  Display Size16.0 cm (6.3 inch)Resolution2340 x...      3G  Capacity4000
#
# [489 rows x 11 columns]

# %%
for df_name ,df in dataframes_dict.items():
    try:
        df = df.drop(columns=['index'])
    except:
        print('notfound')
    # print(func_apply(func=camera_extract,col_name='camera',df=df,df_name=df_name))
# Out:
# notfound

# %%
mi.to_csv(path_or_buf=r'data\data_for_word2Vec\mi_mobile_new_data.csv',   index=False)
samsung.to_csv(path_or_buf=r'data\data_for_word2Vec\samsung_mobile_new_data.csv',   index=False)
apple.to_csv(path_or_buf=r'data\data_for_word2Vec\apple_mobile_new_data.csv',   index=False)
onePlus.to_csv(path_or_buf=r'data\data_for_word2Vec\one_plus_mobile_new_data.csv',   index=False)
realme.to_csv(path_or_buf=r'data\data_for_word2Vec\realme_mobile_data.csv',   index=False)
vivo.to_csv(path_or_buf=r'data\data_for_word2Vec\vivo_mobile_data.csv',   index=False)
oppo.to_csv(path_or_buf=r'data\data_for_word2Vec\oppo_mobile_data.csv',   index=False)
motorola.to_csv(path_or_buf=r'data\data_for_word2Vec\motorola_mobile_data.csv',   index=False)
techno.to_csv(path_or_buf=r'data\data_for_word2Vec\techno_mobile_data.csv',   index=False)
infinix.to_csv(path_or_buf=r'data\data_for_word2Vec\infinix_mobile_data.csv',   index=False)

# %% [markdown]
# > #                                                                   **END**
