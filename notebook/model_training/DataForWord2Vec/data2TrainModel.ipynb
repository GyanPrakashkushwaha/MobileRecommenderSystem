# %%
import pandas as pd
import numpy as np
import os
from typing import Callable # this is to define test_func functions dtype as function itself
import re # for regural expression
import warnings
warnings.filterwarnings('ignore')

# %%
print(os.getcwd())
os.chdir(r'd:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem')
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem

# %%
mi = pd.read_csv(filepath_or_buffer=r'data\raw_data\mi_mobile_new_data.csv',   index_col=False)
samsung = pd.read_csv(filepath_or_buffer=r'data\raw_data\samsung_mobile_new_data.csv',   index_col=False)
apple = pd.read_csv(filepath_or_buffer=r'data\raw_data\apple_mobile_new_data.csv',   index_col=False)
onePlus = pd.read_csv(filepath_or_buffer=r'data\raw_data\one_plus_mobile_new_data.csv',   index_col=False)
realme = pd.read_csv(filepath_or_buffer=r'data\raw_data\realme_mobile_data.csv',   index_col=False)
vivo = pd.read_csv(filepath_or_buffer=r'data\raw_data\vivo_mobile_data.csv',   index_col=False)
oppo = pd.read_csv(filepath_or_buffer=r'data\raw_data\oppo_mobile_data.csv',   index_col=False)
motorola = pd.read_csv(filepath_or_buffer=r'data\raw_data\motorola_mobile_data.csv',   index_col=False)
techno = pd.read_csv(filepath_or_buffer=r'data\raw_data\techno_mobile_data.csv',   index_col=False)
infinix = pd.read_csv(filepath_or_buffer=r'data\raw_data\infinix_mobile_data.csv',   index_col=False)

# %%
infinix.rename({'camera':'os_processor','oS_Processor':'camera'},axis=1,inplace=True)
techno.rename({'camera':'os_processor','oS_Processor':'camera'},axis=1,inplace=True)
motorola.rename({'camera':'os_processor','oS_Processor':'camera'},axis=1,inplace=True)
oppo.rename({'camera':'os_processor','oS_Processor':'camera'},axis=1,inplace=True)
vivo.rename({'camera':'os_processor','oS_Processor':'camera'},axis=1,inplace=True)
realme.rename({'camera':'os_processor','oS_Processor':'camera'},axis=1,inplace=True)

dataframes_list = [mi, samsung, apple, onePlus, realme, vivo, oppo, motorola, techno, infinix]

# %%
for i in dataframes_list:
    i.drop_duplicates(inplace=True)

# %%
dataframes_dict = {
    'mi': mi,
    'samsung': samsung,
    'apple': apple,
    'onePlus': onePlus,
    'realme': realme,
    'vivo': vivo,
    'oppo': oppo,
    'motorola': motorola,
    'techno': techno,
    'infinix': infinix
}

# %% [markdown]
# ## Shape

# %%
for i,j in dataframes_dict.items():
    print(f'{i} data shape :{j.shape}')
# Out:
# mi data shape :(517, 10)
# samsung data shape :(566, 10)
# apple data shape :(424, 10)
# onePlus data shape :(188, 10)
# realme data shape :(249, 10)
# vivo data shape :(308, 10)
# oppo data shape :(251, 10)
# motorola data shape :(119, 10)
# techno data shape :(151, 10)
# infinix data shape :(165, 10)

# %% [markdown]
# ## Handle Null values

# %%
for key,value in dataframes_dict.items():
    print(f'dataframe is {key} \n {sum(value.isnull().sum())}')
    print()
# Out:
# dataframe is mi
#  28
#
# dataframe is samsung
#  81
#
# dataframe is apple
#  322
#
# dataframe is onePlus
#  0
#
# dataframe is realme
#  35
#
# dataframe is vivo
#  7
#
# dataframe is oppo
#  0
#
# dataframe is motorola
#  0
#
# dataframe is techno
#  0
#
# dataframe is infinix
#  2

# %%
mi.dropna(inplace=True)
realme.dropna(inplace=True)
vivo.dropna(inplace=True)
infinix.dropna(inplace=True)
samsung.dropna(inplace=True)

# %%
oppo[oppo['ratings'].isnull() ==True]
# Out:
# Empty DataFrame
# Columns: [name, ratings, price, imgURL, storage_ram, os_processor, os_processor, display, network, battery]
# Index: []

# %%
# oppo['ratings'][46] = 4.3
# oppo['ratings'][47] = 4.3
# oppo['ratings'][167] = 4.5
# oppo['ratings'][191] = 4.1
# oppo['ratings'][214] = 4.3
# oppo['ratings'][215] = 4.3
# oppo['ratings'][239] = 4.4
# oppo['ratings'][263] = 4.4
# oppo['os_processor'][191] = 'Operating SystemAndroid Pie Android v9.0 (Pie)Processor CoreOcta CorePrimary Clock Speed0.1 MHz'

# %%
for key,value in dataframes_dict.items():
    print(f'dataframe is {key} \n {sum(value.isnull().sum())}')
    print()
# Out:
# dataframe is mi
#  0
#
# dataframe is samsung
#  0
#
# dataframe is apple
#  322
#
# dataframe is onePlus
#  0
#
# dataframe is realme
#  0
#
# dataframe is vivo
#  0
#
# dataframe is oppo
#  0
#
# dataframe is motorola
#  0
#
# dataframe is techno
#  0
#
# dataframe is infinix
#  0

# %%
def random_values(col_name:str,df:pd.DataFrame,total=6):
    for i in range(0,total):
        index = np.random.randint(df.shape[0])
        print(index,':',df[col_name].iloc[index])

# %% [markdown]
# # Price

# %%
def clean_price_col(dataframe:pd.DataFrame):
    dataframe.reset_index(inplace=True)
    for Index,i in enumerate(dataframe['price']):
        i = str(i).replace('₹','')
        i = str(i).replace(',','')
        dataframe['price'][Index] = i

    dataframe['price'] = dataframe['price'].astype('Int16')
    dataframe['price'] = dataframe['price'].abs()  

    show = f'datatype -{dataframe["price"].dtype}'   
    return show

# %% [markdown]
# ## storage_ram

# %%
def remove_internal(txt):
    return txt.replace('Internal','')

# %%
## Going to remove 'Storage32 GBRAM2 GBExpandable Storage128' words after this.....
def cut_remove_words(txt):
    split = txt.split()
    if 'GBExpandable' in split:
        string = split[:5]
        extract_GB_TB = string[-1]
        pattern = r'[TB]+|[GB]+'
        found = re.findall(pattern,extract_GB_TB)

        final_string = ' '.join(string[:4]) + ''.join(found)

        return final_string
    else:
        return ' '.join(split[:2])

# %%
def func_apply(func:Callable,col_name,df:pd.DataFrame):
    df[col_name] = df[col_name].apply(func)
    print('Successfully applied function')
    
    print(f'{random_values(col_name=col_name,df=df,total=6)}')

# %% [markdown]
# ## remove Operating

# %%
def remove_operating(txt):
    return txt.replace('Operating','')

for i in dataframes_list:
    print(func_apply(func=remove_operating,col_name='os_processor',df=i))
# Out:
# Successfully applied function
# 34 :  SystemAndroid Q 11Processor CoreOcta CorePrimary Clock Speed3.2 GHz
# 342 :  SystemAndroid Android 13Processor CoreOcta CorePrimary Clock Speed2.2 GHz
# 216 :  SystemAndroid 11Processor TypeMediatek Helio G35Processor CoreOcta CorePrimary Clock Speed2.3 GHzSecondary Clock Speed2.3 GHzTertiary Clock Speed2.3 GHz Frequency2G GSM: B2/B3/B5/B8, 3G WCDMA: B1/B5/B8, 4G LTE TDD: B40/B41, 4G LTE FDD: B1/B3/B5/B8
# sample data:
#  None
# None
# Successfully applied function
# 339 :  SystemAndroid Q 10Processor TypeMediaTek | MT6739WW quad coreProcessor CoreOcta CorePrimary Clock Speed1.5 GHzSecondary Clock Speed2 GHz
# 325 :  SystemAndroid Pie 10Processor TypeExynos 9611-Octa Core processorProcessor CoreOcta CorePrimary Clock Speed2.3 GHzSecondary Clock Speed1.7 GHz
# 195 :  SystemAndroid 11Processor TypeMediaTek Helio G80 (MT6769V)Processor CoreOcta CorePrimary Clock Speed2 GHzSecondary Clock Speed1.8 GHz
# sample data:
#  None
# None
# Successfully applied function
# 368 :  SystemiOS 12Processor TypeA12 Bionic Chip
# 361 :  SystemiOS 12Processor TypeA10 Fusion Chip with 64-bit Architecture and Embedded M10 Motion Co-processor
# 362 :  SystemiOS 12Processor TypeApple A10 Fusion 64-bit processor and Embedded M10 Motion Co-processor
# sample data:
#  None
# None
# Successfully applied function
# 26 :  SystemAndroid 11Processor CoreOcta CorePrimary Clock Speed2.2 GHz
# 177 :  SystemAndroid 13Processor CoreOcta CorePrimary Clock Speed2.4 GHz
# 141 :  SystemAndroid Oxygen OXYGEN OS BASED ON ANDROID 12Primary Clock Speed120 GHz
# sample data:
#  None
# None
# Successfully applied function
# 12 :  SystemAndroid 13Processor TypeHelio G88Processor CoreOcta CorePrimary Clock Speed2 GHzSecondary Clock Speed1.8 GHz Frequency2G GSM: 850/900/1800/1900 MHz, 3G WCDMA: B1/B5/B8, 4G FDD LTE: B1/B3/B5/B8, 4G TD LTE: B38/B40/B41 (2535 MHz - 2655 MHz)
# 131 :  SystemAndroid 11Processor TypeUnisoc T610 Octa CoreProcessor CoreOcta CorePrimary Clock Speed1.8 GHzSecondary Clock Speed1.8 GHz Frequency2G GSM: 850/900/1800/1900MHz, 3G WCDMA: Bands 1/5/8, 4G FDD-LTE: Bands 1/3/5/8, 4G TD-LTE: Bands 38/40/41
# 4 :  SystemAndroid 11Processor TypeUnisoc T612Processor CoreOcta CorePrimary Clock Speed1.82 GHzSecondary Clock Speed1.82 GHz Frequency2G GSM: 850/900/1800/1900, 3G WCDMA: B1/B5/B8, 4G FDD-LTE: B1/B3/B5/B8, 4G TD-LTE: B38/B40/B41 (2535 - 2655 MHz)
# sample data:
#  None
# None
# Successfully applied function
# 216 :  SystemAndroid 11Processor TypeQualcomm Snapdragon 662Processor CoreOcta CorePrimary Clock Speed2 GHz
# 266 :  SystemAndroid Oreo 8.1Processor TypeMediaTek Helio P22Processor CoreOcta CorePrimary Clock Speed2 GHz Frequency2G GSM: B2/B3/B5/B8, 3G WCDMA: B1/B5/B8, 4G FDD LTE: B1/B3/B5/B8, 4G TDD LTE: B38/B40/B41
# 40 :  SystemAndroid 12Processor TypeMediatek Helio P35Processor CoreOcta CorePrimary Clock Speed2.3 GHzSecondary Clock Speed1.8 GHz Frequency2G GSM: B3/B5/B8, 3G WCDMA: B1/B5/B8, 4G FDD LTE: B1/B3/B5/B8, 4G TDD LTE: B38/B40/B41 (120M)
# sample data:
#  None
# None
# Successfully applied function
# 132 : os_processor    Operating SystemAndroid 11Processor TypeMediaT...
# os_processor    Primary Camera AvailableYesPrimary Camera48MP ...
# Name: 134, dtype: object
# 163 : os_processor    Operating SystemAndroid Q 11Processor CoreOcta...
# os_processor    Primary Camera AvailableYesPrimary Camera64MP ...
# Name: 165, dtype: object
# 111 : os_processor    Operating SystemAndroid Pie 9.0Processor TypeM...
# os_processor    Primary Camera AvailableYesPrimary Camera48MP ...
# Name: 113, dtype: object
# sample data:
#  None
# None
# Successfully applied function
# 21 :  Frequency2G GSM: 900/1800 MHz
# 43 :  SystemAndroid 12Processor TypeMediatek Helio G37Processor CoreOcta CorePrimary Clock Speed2.3 GHzSecondary Clock Speed1.8 GHz Frequency4G LTE: B1/B3/B5/B7/B8/B20/B38/B40/B41, 3G UMTS: B1/B2/B5/B8, 2G GSM: B2/B3/B5/B8
# 22 :  SystemAndroid 13Processor TypeDimensity 8020Processor CoreOcta CorePrimary Clock Speed2.6 GHz Frequency5G: n1/n2/n3/n5/n7/n8/n20/n28/n38/n40/n41/n66/n77/n78, 4G: B1/B2/B3/B4/B5/B7/B8/B12/B13/B17/B20/B26/B28/B32/B38/B39/B40/B41/B42/B43/B66, 3G: B1/B2/B4/B5/B8, 2G: B2/B3/B5/B8
# sample data:
#  None
# None
# Successfully applied function
# 133 : os_processor    Operating SystemAndroid 11 (Go edition)Process...
# os_processor    Primary Camera AvailableYesPrimary Camera13MP ...
# Name: 133, dtype: object
# 8 : os_processor    Operating SystemAndroid Android 12.0Processor ...
# os_processor    Primary Camera12MP Rear CameraDual Camera Lens...
# Name: 8, dtype: object
# 15 : os_processor    Operating SystemAndroid 12Processor TypeMediaT...
# os_processor    Primary Camera AvailableYesPrimary Camera13MP ...
# Name: 15, dtype: object
# sample data:
#  None
# None
# Successfully applied function
# 53 :  SystemAndroid 12Processor TypeMediatek Dimensity 810 5GProcessor CoreOcta CorePrimary Clock Speed2.4 GHz Frequency2G GSM: B2/B3/B5/B8, 3G WCDMA: B1/B5/B8, 4G LTE: B1/B3/B5/B7/B8/B20/B28/B38/B40/B41, 5G: n38/n40/n41/n77/n78/n1/n3/n5/n7/n8/n20/n28
# 80 :  SystemAndroid 11Processor TypeMediatek Helio G88Processor CoreOcta CorePrimary Clock Speed2 GHz Frequency2G GSM: B2/B3/B5/B8, 3G WCDMA: B1/B5/B8, 4G LTE: B1/B3/B5/B8/B38/B40/B41
# 26 :  SystemAndroid 12Processor TypeMediatek Helio G85Processor CoreOcta CorePrimary Clock Speed2 GHz Frequency2G GSM: B2/B3/B5/B8, 3G WCDMA: B1/B5/B8, 4G LTE FDD: B1/B3/B5/B8, 4G LTE TDD: B38/B40/B41
# sample data:
#  None
# None

# %% [markdown]
# # Mi

# %%
mi
# Out:
#                                           name  ratings    price
# 0          Redmi 9A Sport (Coral Green, 32 GB)      4.2   ₹8,990  \
# 1       Xiaomi 11Lite NE (Vinyl Black, 128 GB)      4.2  ₹21,430
# 2    Xiaomi 11Lite NE (Diamond Dazzle, 128 GB)      4.2  ₹20,999
# 3     Xiaomi 11Lite NE (Tuscany Coral, 128 GB)      4.2  ₹20,999
# 4               Mi 11 Lite (Jazz Blue, 128 GB)      4.2  ₹17,499
# ..                                         ...      ...      ...
# 546             13 pro (Ceramic Black, 256 GB)      4.3  ₹79,999
# 547               Mi A3 (Not just Blue, 64 GB)      4.2  ₹14,999
# 548          Mi 10T Pro (Lunar Silver, 128 GB)      4.3  ₹26,899
# 549                     Redmi Y1 (Gold, 32 GB)      4.5   ₹8,999
# 550    Redmi Note 7 Pro (Neptune Blue, 128 GB)      4.3  ₹17,999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/k...
# ..                                                 ...
# 546  https://rukminim2.flixcart.com/image/312/312/x...
# 547  https://rukminim2.flixcart.com/image/312/312/k...
# 548  https://rukminim2.flixcart.com/image/312/312/k...
# 549  https://rukminim2.flixcart.com/image/312/312/j...
# 550  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                            storage_ram
# 0    Internal Storage32 GBRAM3 GBMemory Card Slot T...  \
# 1    Internal Storage128 GBRAM6 GBExpandable Storag...
# 2    Internal Storage128 GBRAM6 GBExpandable Storag...
# 3    Internal Storage128 GBRAM6 GBExpandable Storag...
# 4    Internal Storage128 GBRAM8 GBExpandable Storag...
# ..                                                 ...
# 546  Internal Storage256 GBRAM12 GBMemory Card Slot...
# 547  Internal Storage64 GBRAM4 GBExpandable Storage...
# 548    Internal Storage128 GBRAM8 GBCall Log MemoryYes
# 549  Internal Storage32 GBRAM3 GBExpandable Storage...
# 550  Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                           os_processor
# 0     SystemAndroid Q 10Processor CoreOcta CorePrim...  \
# 1     SystemAndroid 11Processor TypeQualcomm Snapdr...
# 2     SystemAndroid 11Processor TypeQualcomm Snapdr...
# 3     SystemAndroid 11Processor TypeQualcomm Snapdr...
# 4     SystemAndroid 11Processor TypeQualcomm Snapdr...
# ..                                                 ...
# 546   SystemAndroid MIUI 14, Android 13.0Processor ...
# 547   SystemAndroid Pie 9Processor TypeQualcomm Sna...
# 548   SystemAndroid 10Processor TypeQualcomm Snapdr...
# 549   SystemAndroid Nougat 7.1.2Processor TypeQualc...
# 550   SystemAndroid Pie 9.0Processor TypeQualcomm S...
#
#                                                 camera
# 0                       Primary Camera13MP Rear Camera  \
# 1    Primary Camera AvailableYesPrimary Camera64MP ...
# 2    Primary Camera AvailableYesPrimary Camera64MP ...
# 3    Primary Camera AvailableYesPrimary Camera64MP ...
# 4    Primary Camera AvailableYesPrimary Camera64MP ...
# ..                                                 ...
# 546  Primary Camera50MP Rear CameraDual Camera Lens...
# 547  Primary Camera AvailableYesPrimary Camera48MP ...
# 548  Primary Camera AvailableYesPrimary Camera108MP...
# 549  Primary Camera AvailableYesPrimary Camera13MP ...
# 550  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                                display
# 0    Display Size16.59 cm (6.53 inch)Resolution1600...  \
# 1    Display Size16.64 cm (6.55 inch)Resolution1080...
# 2    Display Size16.64 cm (6.55 inch)Resolution1080...
# 3    Display Size16.64 cm (6.55 inch)Resolution1080...
# 4    Display Size16.64 cm (6.55 inch)Resolution2400...
# ..                                                 ...
# 546  Display Size17.09 cm (6.73 inch)Resolution3200...
# 547  Display Size15.46 cm (6.088 inch)Resolution156...
# 548  Display Size16.94 cm (6.67 inch)Resolution2400...
# 549  Display Size13.97 cm (5.5 inch)Resolution1280 ...
# 550  Display Size16.0 cm (6.3 inch)Resolution2340 x...
#
#                                                network
# 0    Network Type4G VOLTE, 4GSupported Networks4G V...  \
# 1    Network Type5G, 4G VOLTESupported Networks5G, ...
# 2    Network Type5G, 4G VOLTESupported Networks5G, ...
# 3    Network Type5G, 4G VOLTESupported Networks5G, ...
# 4    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# ..                                                 ...
# 546                 Network Type5GSupported Networks5G
# 547  Network Type4G VOLTE, 4G, 2G, 3GSupported Netw...
# 548  Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...
# 549  Network Type3G, 4G, 2GSupported NetworksGSM, W...
# 550  Network Type3G, 4G VOLTE, 2GSupported Networks...
#
#                                              battery
# 0                           Battery Capacity5000 mAh
# 1          Battery Capacity4250 mAhBattery TypeLi-Po
# 2          Battery Capacity4250 mAhBattery TypeLi-Po
# 3          Battery Capacity4250 mAhBattery TypeLi-Po
# 4            Battery Capacity4250 mAhTalk Time30 hrs
# ..                                               ...
# 546                         Battery Capacity4820 mAh
# 547  Battery Capacity4030 mAhBattery TypeLithium-ion
# 548          Battery Capacity5000 mAhTalk Time26 hrs
# 549                         Battery Capacity3080 mAh
# 550                         Battery Capacity4000 mAh
#
# [489 rows x 10 columns]

# %% [markdown]
# ### ***price***

# %%
clean_price_col(mi)
# Out:
# 'datatype -Int16'

# %% [markdown]
# ### *****storage_ram*****

# %%
func_apply(func=remove_internal,col_name='storage_ram',df=mi)
# Out:
# Successfully applied function
# 370 : Storage64 GBRAM4
# 19 : Storage128 GBRAM4
# 56 : Storage32 GBRAM3 GBExpandable Storage128GBGB
# None

# %%
func_apply(func=cut_remove_words,col_name='storage_ram',df=mi)
# Out:
# Successfully applied function
# 208 : Storage256 GBRAM12
# 211 : Storage128 GBRAM6 GBExpandable Storage1TBTB
# 334 : Storage64 GBRAM4
# sample data: None

# %% [markdown]
# # Samsung

# %%
samsung.dropna(inplace=True)

# %%
samsung
# Out:
#                                                   name  ratings      price
# 0           SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)      4.3     ₹9,499  \
# 1          SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)      4.3    ₹10,499
# 2          SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)      4.3    ₹10,499
# 3          SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)      4.3    ₹10,499
# 4            SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)      4.3    ₹15,499
# ..                                                 ...      ...        ...
# 569         SAMSUNG Galaxy M40 (Seawater Blue, 128 GB)      4.5    ₹21,490
# 570  SAMSUNG Galaxy Note 20 Ultra 5G (Mystic Bronze...      4.3  ₹1,04,999
# 571    SAMSUNG Galaxy A30s (Prism Crush Violet, 64 GB)      4.3    ₹16,199
# 572              SAMSUNG Galaxy J4 Plus (Black, 32 GB)      4.4     ₹9,000
# 573     SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)      4.2    ₹34,999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 569  https://rukminim2.flixcart.com/image/312/312/k...
# 570  https://rukminim2.flixcart.com/image/312/312/k...
# 571  https://rukminim2.flixcart.com/image/312/312/k...
# 572  https://rukminim2.flixcart.com/image/312/312/j...
# 573  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 0    Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 1    Internal Storage128 GBRAM4 GBExpandable Storag...
# 2    Internal Storage128 GBRAM4 GBExpandable Storag...
# 3    Internal Storage128 GBRAM4 GBExpandable Storag...
# 4    Internal Storage128 GBRAM6 GBTotal Memory128 G...
# ..                                                 ...
# 569  Internal Storage128 GBRAM6 GBMemory Card Slot ...
# 570  Internal Storage256 GBRAM12 GBExpandable Stora...
# 571  Internal Storage64 GBRAM4 GBSupported Memory C...
# 572  Internal Storage32 GBRAM2 GBExpandable Storage...
# 573  Internal Storage128 GBRAM8 GBExpandable Storag...
#
#                                           os_processor
# 0     SystemAndroid 12Processor TypeExynos 850Proce...  \
# 1     SystemAndroid 12Processor TypeExynos 850Proce...
# 2     SystemAndroid 12Processor TypeExynos 850Proce...
# 3     SystemAndroid 12Processor TypeExynos 850Proce...
# 4     SystemAndroid 12Processor TypeQualcomm Snapdr...
# ..                                                 ...
# 569   SystemAndroid Pie 9.0Processor CoreOcta CoreP...
# 570   SystemAndroid 10Processor TypeExynos Octa Cor...
# 571   SystemAndroid Pie 9.0Processor TypeExynos 790...
# 572   SystemAndroid Oreo 8.1Processor TypeQualcomm ...
# 573   SystemAndroid 10Processor TypeQualcomm SM7150...
#
#                                                 camera
# 0    Primary Camera AvailableYesPrimary Camera50MP ...  \
# 1    Primary Camera AvailableYesPrimary Camera50MP ...
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
# 3    Primary Camera AvailableYesPrimary Camera50MP ...
# 4    Primary Camera AvailableYesPrimary Camera50MP ...
# ..                                                 ...
# 569  Primary Camera32MP Rear CameraDual Camera Lens...
# 570  Primary Camera AvailableYesPrimary Camera108MP...
# 571  Primary Camera AvailableYesPrimary Camera25MP ...
# 572  Primary Camera AvailableYesPrimary Camera13MP ...
# 573  Primary Camera AvailableYesPrimary Camera64MP ...
#
#                                                display
# 0    Display Size16.76 cm (6.6 inch)Resolution2408 ...  \
# 1    Display Size16.76 cm (6.6 inch)Resolution2408 ...
# 2    Display Size16.76 cm (6.6 inch)Resolution2408 ...
# 3    Display Size16.76 cm (6.6 inch)Resolution2408 ...
# 4    Display Size16.76 cm (6.6 inch)Resolution2408 ...
# ..                                                 ...
# 569  Display Size16.0 cm (6.3 inch)Resolution2340 x...
# 570  Display Size17.53 cm (6.9 inch)Resolution3088 ...
# 571  Display Size16.26 cm (6.4 inch)Resolution1920 ...
# 572  Display Size15.24 cm (6 inch)Resolution720 x 1...
# 573  Display Size17.02 cm (6.7 inch)Resolution2340 ...
#
#                                                network
# 0    Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 1    Network Type4G, 3G, 2GSupported Networks4G LTE...
# 2    Network Type4G, 3G, 2GSupported Networks4G LTE...
# 3    Network Type4G, 3G, 2GSupported Networks4G LTE...
# 4    Network Type5G, 4G, 3G, 2GSupported Networks5G...
# ..                                                 ...
# 569  Network Type4G, 3G, 2GSupported Networks4G LTE...
# 570  Network Type5G, 4G, 3G, 2GSupported Networks5G...
# 571  Network Type3G, 4G, 2GSupported NetworksGSM, W...
# 572  Network Type3G, 4G, 2GSupported NetworksGSM, W...
# 573  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                                     battery
# 0    Battery Capacity6000 mAhDual BatteryNo
# 1    Battery Capacity6000 mAhDual BatteryNo
# 2    Battery Capacity6000 mAhDual BatteryNo
# 3    Battery Capacity6000 mAhDual BatteryNo
# 4                  Battery Capacity5000 mAh
# ..                                      ...
# 569                Battery Capacity3500 mAh
# 570                Battery Capacity4500 mAh
# 571                Battery Capacity4000 mAh
# 572  Battery Capacity3300 mAhDual BatteryNo
# 573                Battery Capacity4500 mAh
#
# [529 rows x 10 columns]

# %% [markdown]
# ### ***price***

# %%
clean_price_col(samsung)
# Out:
# 'datatype -Int16'

# %% [markdown]
# ### *****storage_ram*****

# %%
func_apply(func=remove_internal,col_name='storage_ram',df=samsung)
# Out:
# Successfully applied function
# 287 :  StorageNAPhone Book Memory1000Call Log MemoryYesSMS MemoryYes
# 354 :  Storage128 GBRAM8 GBMemory Card Slot TypeHybrid Slot
# 378 :  Storage128 GBRAM8 GBExpandable Storage1 TBSupported Memory Card TypemicroSDMemory Card Slot TypeDedicated Slot
# sample data:
#  None

# %%
func_apply(func=cut_remove_words,col_name='storage_ram',df=samsung)
# Out:
# Successfully applied function
# 183 : Storage128 GBRAM6 GBTotal Memory128GB
# 144 : Storage64 GBRAM4 GBExpandable Storage512GB
# 306 : Storage128 GBRAM4
# sample data:
#  None

# %% [markdown]
# # apple

# %%
apple
# Out:
#                                              name  ratings      price
# 0                  APPLE iPhone 13 (Blue, 128 GB)      4.7    ₹61,999  \
# 1              APPLE iPhone 13 (Midnight, 128 GB)      4.7    ₹61,999
# 2             APPLE iPhone 13 (Starlight, 128 GB)      4.7    ₹61,999
# 3                  APPLE iPhone 13 (Pink, 128 GB)      4.7    ₹61,999
# 4              APPLE iPhone 14 (Midnight, 128 GB)      4.6    ₹69,999
# ..                                            ...      ...        ...
# 419              APPLE iPhone XR (Yellow, 128 GB)      4.6    ₹41,699
# 420  APPLE iPhone 11 Pro (Midnight Green, 256 GB)      4.6  ₹1,21,300
# 421                APPLE iPhone X (Silver, 64 GB)      4.6    ₹91,900
# 422           APPLE iPhone X (Space Gray, 256 GB)      4.6  ₹1,06,900
# 423            APPLE iPhone X (Space Gray, 64 GB)      4.6    ₹91,900
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/k...  \
# 1    https://rukminim2.flixcart.com/image/312/312/k...
# 2    https://rukminim2.flixcart.com/image/312/312/k...
# 3    https://rukminim2.flixcart.com/image/312/312/k...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 419  https://rukminim2.flixcart.com/image/312/312/k...
# 420  https://rukminim2.flixcart.com/image/312/312/k...
# 421  https://rukminim2.flixcart.com/image/312/312/j...
# 422  https://rukminim2.flixcart.com/image/312/312/j...
# 423  https://rukminim2.flixcart.com/image/312/312/j...
#
#                 storage_ram
# 0    Internal Storage128 GB  \
# 1    Internal Storage128 GB
# 2    Internal Storage128 GB
# 3    Internal Storage128 GB
# 4    Internal Storage128 GB
# ..                      ...
# 419  Internal Storage128 GB
# 420  Internal Storage256 GB
# 421   Internal Storage64 GB
# 422  Internal Storage256 GB
# 423   Internal Storage64 GB
#
#                                           os_processor
# 0     SystemiOS 15Processor TypeA15 Bionic ChipProc...  \
# 1     SystemiOS 15Processor TypeA15 Bionic ChipProc...
# 2     SystemiOS 15Processor TypeA15 Bionic ChipProc...
# 3     SystemiOS 15Processor TypeA15 Bionic ChipProc...
# 4     SystemiOS 16Processor TypeA15 Bionic Chip, 6 ...
# ..                                                 ...
# 419        SystemiOS 14.2Processor TypeA12 Bionic Chip
# 420          SystemiOS 13Processor TypeA13 Bionic Chip
# 421   SystemiOS 11Processor TypeA11 Bionic Chip wit...
# 422   SystemiOS 11Processor TypeA11 Bionic Chip wit...
# 423   SystemiOS 11Processor TypeA11 Bionic Chip wit...
#
#                                                 camera
# 0    Primary Camera AvailableYesPrimary Camera12MP ...  \
# 1    Primary Camera AvailableYesPrimary Camera12MP ...
# 2    Primary Camera AvailableYesPrimary Camera12MP ...
# 3    Primary Camera AvailableYesPrimary Camera12MP ...
# 4    Primary Camera AvailableYesPrimary Camera12MP ...
# ..                                                 ...
# 419  Primary Camera AvailableYesPrimary Camera12MP ...
# 420  Primary Camera AvailableYesPrimary Camera12MP ...
# 421  Primary Camera AvailableYesPrimary Camera12MP ...
# 422  Primary Camera AvailableYesPrimary Camera12MP ...
# 423  Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                                display
# 0    Display Size15.49 cm (6.1 inch)Resolution2532 ...  \
# 1    Display Size15.49 cm (6.1 inch)Resolution2532 ...
# 2    Display Size15.49 cm (6.1 inch)Resolution2532 ...
# 3    Display Size15.49 cm (6.1 inch)Resolution2532 ...
# 4    Display Size15.49 cm (6.1 inch)Resolution2532 ...
# ..                                                 ...
# 419  Display Size15.49 cm (6.1 inch)Resolution1792 ...
# 420  Display Size14.73 cm (5.8 inch)Resolution2436 ...
# 421  Display Size14.73 cm (5.8 inch)Resolution2436 ...
# 422  Display Size14.73 cm (5.8 inch)Resolution2436 ...
# 423  Display Size14.73 cm (5.8 inch)Resolution2436 ...
#
#                                                network battery
# 0    Network Type5G, 4G, 3G, 2GSupported Networks5G...     NaN
# 1    Network Type5G, 4G, 3G, 2GSupported Networks5G...     NaN
# 2    Network Type5G, 4G, 3G, 2GSupported Networks5G...     NaN
# 3    Network Type5G, 4G, 3G, 2GSupported Networks5G...     NaN
# 4    Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...     NaN
# ..                                                 ...     ...
# 419  Network Type3G, 4G, 2GSupported NetworksGSM, W...     NaN
# 420  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...     NaN
# 421  Network Type3G, 4G, 2GSupported NetworksGSM, W...     NaN
# 422  Network Type3G, 4G, 2GSupported NetworksGSM, W...     NaN
# 423  Network Type3G, 4G, 2GSupported NetworksGSM, W...     NaN
#
# [424 rows x 10 columns]

# %% [markdown]
# ### ***price***

# %%
clean_price_col(apple)
# Out:
# 'datatype -Int16'

# %% [markdown]
# ### *****storage_ram*****

# %%
func_apply(func=remove_internal,col_name='storage_ram',df=apple)
# Out:
# Successfully applied function
# 275 :  Storage256 GB
# 185 :  Storage256 GB
# 32 :  Storage256 GB
# sample data:
#  None

# %%
def remove_extra(txt):
    split = txt.split()
    word = split[0]
    if 'Storage1' in split: 
        replace = word.replace('Storage1','Storage1024')
        return replace
    else:
        return word
    
func_apply(func=remove_extra,col_name='storage_ram',df=apple)
# Out:
# Successfully applied function
# 157 : Storage256
# 282 : Storage32
# 140 : Storage64
# sample data:
#  None

# %%
# apple

# %% [markdown]
# # onePlus

# %%
onePlus
# Out:
#                                                   name  ratings    price
# 0        OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)      4.4  ₹17,676  \
# 1       OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)      4.4  ₹17,691
# 2             OnePlus 11R 5G (Galactic Silver, 256 GB)      4.5  ₹44,690
# 3             OnePlus 11R 5G (Galactic Silver, 128 GB)      4.5  ₹39,734
# 4                 OnePlus 11R 5G (Sonic Black, 256 GB)      4.5  ₹44,284
# ..                                                 ...      ...      ...
# 183                 OnePlus N20 SE (BLUE OASIS, 64 GB)      4.2  ₹15,674
# 184            OnePlus 9 Pro 5G (Morning Mist, 128 GB)      3.8  ₹47,999
# 185                   OnePlus 6 (Mirror Black, 128 GB)      4.2  ₹17,990
# 186  OnePlus 6T McLaren Edition (Speed Orange, 256 GB)      4.0  ₹26,990
# 187         OnePlus Nord CE 2 5G (Gray Mirror, 128 GB)      4.2  ₹24,990
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 183  https://rukminim2.flixcart.com/image/312/312/x...
# 184  https://rukminim2.flixcart.com/image/312/312/x...
# 185  https://rukminim2.flixcart.com/image/312/312/x...
# 186  https://rukminim2.flixcart.com/image/312/312/x...
# 187  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 0    Internal Storage128 GBRAM6 GBMemory Card Slot ...  \
# 1    Internal Storage128 GBRAM6 GBMemory Card Slot ...
# 2                       Internal Storage256 GBRAM16 GB
# 3                        Internal Storage128 GBRAM8 GB
# 4                       Internal Storage256 GBRAM16 GB
# ..                                                 ...
# 183  Internal Storage64 GBRAM4 GBMemory Card Slot T...
# 184                      Internal Storage128 GBRAM8 GB
# 185  Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 186  Internal Storage256 GBRAM10 GBMemory Card Slot...
# 187  Internal Storage128 GBRAM8 GBMemory Card Slot ...
#
#                                           os_processor
# 0     SystemAndroid 10Processor CoreOcta CorePrimar...  \
# 1     SystemAndroid 13Processor CoreOcta CorePrimar...
# 2     SystemAndroid OxygenOS based on Android 13Pro...
# 3     SystemAndroid OxygenOS based on Android 13Pro...
# 4     SystemAndroid Oxygen OxygenOS based on Androi...
# ..                                                 ...
# 183   SystemAndroid Oxygen 12.1Processor CoreOcta C...
# 184   SystemAndroid 11Processor CoreDual CorePrimar...
# 185   SystemAndroid Oreo 8.1Processor CoreOcta Core...
# 186   SystemAndroid Oxygen 9Processor CoreOcta Core...
# 187   SystemAndroid 11Processor CoreOcta CorePrimar...
#
#                                                 camera
# 0                       Primary Camera64MP Rear Camera  \
# 1                       Primary Camera64MP Rear Camera
# 2    Primary Camera50MP Rear CameraDual Camera Lens...
# 3    Primary Camera50MP Rear CameraDual Camera Lens...
# 4    Primary Camera50MP Rear CameraDual Camera Lens...
# ..                                                 ...
# 183  Primary Camera50MP Rear CameraDual Camera Lens...
# 184  Primary Camera48MP Rear CameraDual Camera Lens...
# 185  Primary Camera AvailableYesPrimary Camera20MP ...
# 186  Primary Camera AvailableYesPrimary Camera20MP ...
# 187  Primary Camera50MP Rear CameraDual Camera Lens...
#
#                                                display
# 0    Display Size16.74 cm (6.59 inch)Resolution2412...  \
# 1    Display Size16.74 cm (6.59 inch)Resolution2412...
# 2    Display Size17.02 cm (6.7 inch)Resolution2772x...
# 3    Display Size17.02 cm (6.7 inch)Resolution2772x...
# 4    Display Size17.02 cm (6.7 inch)Resolution2772x...
# ..                                                 ...
# 183  Display Size16.66 cm (6.56 inch)Resolution1612...
# 184  Display Size17.02 cm (6.7 inch)Resolution3216 ...
# 185  Display Size15.95 cm (6.28 inch)Resolution1080...
# 186  Display Size16.28 cm (6.41 inch)Resolution2280...
# 187  Display Size16.33 cm (6.43 inch)Resolution2400...
#
#                                                network
# 0                   Network Type5GSupported Networks5G  \
# 1                   Network Type5GSupported Networks5G
# 2                   Network Type5GSupported Networks5G
# 3                   Network Type5GSupported Networks5G
# 4                   Network Type5GSupported Networks5G
# ..                                                 ...
# 183     Network Type4G VOLTESupported Networks4G VoLTE
# 184  Network Type5GSupported Networks4G LTE, GSM, C...
# 185  Network Type4GSupported Networks4G VoLTEWi-FiY...
# 186  Network Type4G VOLTE, 4GSupported Networks4G V...
# 187                 Network Type5GSupported Networks5G
#
#                       battery
# 0    Battery Capacity5000 mAh
# 1    Battery Capacity5000 mAh
# 2    Battery Capacity5000 mAh
# 3    Battery Capacity5000 mAh
# 4    Battery Capacity5000 mAh
# ..                        ...
# 183  Battery Capacity5000 mAh
# 184  Battery Capacity4500 mAh
# 185  Battery Capacity3300 mAh
# 186  Battery Capacity3300 mAh
# 187  Battery Capacity4500 mAh
#
# [188 rows x 10 columns]

# %% [markdown]
# ### ***price***

# %%
clean_price_col(onePlus)
# Out:
# 'datatype -Int16'

# %% [markdown]
# ### *****storage_ram*****

# %%
func_apply(func=remove_internal,col_name='storage_ram',df=onePlus)
# Out:
# Successfully applied function
# 127 :  Storage256 GBRAM12 GBMemory Card Slot TypeDedicated Slot
# 108 :  Storage256 GBRAM12 GBSupported Memory Card TypeMicroSDMemory Card Slot TypeDedicated Slot
# 150 :  Storage256 GBRAM12 GB
# sample data:
#  None

# %%
func_apply(func=cut_remove_words,col_name='storage_ram',df=onePlus)
# Out:
# Successfully applied function
# 117 : Storage256 GBRAM12
# 7 : Storage128 GBRAM8
# 23 : Storage128 GBRAM8
# sample data:
#  None

# %% [markdown]
# # realme

# %%
realme
# Out:
#                                      name  ratings    price
# 0    realme C33 2023 (Sandy Gold, 128 GB)      4.4  ₹10,499  \
# 1     realme C33 2023 (Aqua Blue, 128 GB)      4.4  ₹10,499
# 2     realme C33 2023 (Night Sea, 128 GB)      4.4  ₹10,499
# 3         realme C30 (Denim Black, 32 GB)      4.2   ₹5,999
# 4        realme C30 (Bamboo Green, 32 GB)      4.1   ₹6,499
# ..                                    ...      ...      ...
# 257     realme GT 2 (Paper Green, 256 GB)      4.3  ₹38,999
# 258     realme GT 2 (Paper Green, 128 GB)      4.6  ₹34,999
# 259      realme C21Y (Cross Black, 32 GB)      4.4   ₹7,499
# 260        realme C33 (Sandy Gold, 64 GB)      4.4   ₹9,999
# 261        realme C33 (Sandy Gold, 32 GB)      4.4   ₹8,999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/l...
# 4    https://rukminim2.flixcart.com/image/312/312/l...
# ..                                                 ...
# 257  https://rukminim2.flixcart.com/image/312/312/l...
# 258  https://rukminim2.flixcart.com/image/312/312/l...
# 259  https://rukminim2.flixcart.com/image/312/312/k...
# 260  https://rukminim2.flixcart.com/image/312/312/x...
# 261  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 0    Internal Storage128 GBRAM4 GBExpandable Storag...  \
# 1    Internal Storage128 GBRAM4 GBExpandable Storag...
# 2    Internal Storage128 GBRAM4 GBExpandable Storag...
# 3    Internal Storage32 GBRAM2 GBExpandable Storage...
# 4    Internal Storage32 GBRAM3 GBExpandable Storage...
# ..                                                 ...
# 257   Internal Storage256 GBRAM12 GBCall Log MemoryYes
# 258    Internal Storage128 GBRAM8 GBCall Log MemoryYes
# 259  Internal Storage32 GBRAM3 GBExpandable Storage...
# 260  Internal Storage64 GBRAM4 GBExpandable Storage...
# 261  Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                           os_processor
# 0     SystemAndroid 12Processor TypeUnisoc T612Proc...  \
# 1     SystemAndroid 12Processor TypeUnisoc T612Proc...
# 2     SystemAndroid 12Processor TypeUnisoc T612Proc...
# 3     SystemAndroid 11Processor TypeUnisoc T612Proc...
# 4     SystemAndroid 11Processor TypeUnisoc T612Proc...
# ..                                                 ...
# 257   SystemAndroid 12Processor TypeQualcomm Snapdr...
# 258   SystemAndroid 12Processor TypeQualcomm Snapdr...
# 259   SystemAndroid 11Processor TypeUnisoc T610Proc...
# 260   SystemAndroid 12Processor TypeUnisoc T612Proc...
# 261   SystemAndroid 12Processor TypeUnisoc T612Proc...
#
#                                                 camera
# 0    Primary Camera AvailableYesPrimary Camera50MP ...  \
# 1    Primary Camera AvailableYesPrimary Camera50MP ...
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
# 3    Primary Camera AvailableYesPrimary Camera8MP R...
# 4    Primary Camera AvailableYesPrimary Camera8MP R...
# ..                                                 ...
# 257  Primary Camera AvailableYesPrimary Camera50MP ...
# 258  Primary Camera AvailableYesPrimary Camera50MP ...
# 259  Primary Camera AvailableYesPrimary Camera13MP ...
# 260  Primary Camera AvailableYesPrimary Camera50MP ...
# 261  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                                display
# 0    Display Size16.51 cm (6.5 inch)Resolution1600 ...  \
# 1    Display Size16.51 cm (6.5 inch)Resolution1600 ...
# 2    Display Size16.51 cm (6.5 inch)Resolution1600 ...
# 3    Display Size16.51 cm (6.5 inch)Resolution1600 ...
# 4    Display Size16.51 cm (6.5 inch)Resolution1600 ...
# ..                                                 ...
# 257  Display Size16.81 cm (6.62 inch)Resolution2400...
# 258  Display Size16.81 cm (6.62 inch)Resolution2400...
# 259  Display Size16.51 cm (6.5 inch)Resolution1600 ...
# 260  Display Size16.51 cm (6.5 inch)Resolution1600 ...
# 261  Display Size16.51 cm (6.5 inch)Resolution1600 ...
#
#                                                network
# 0    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 1    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 2    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 3    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 4    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# ..                                                 ...
# 257  Network Type5G, 4G, 3G, 2GSupported Networks5G...
# 258  Network Type5G, 4G, 3G, 2GSupported Networks5G...
# 259  Network Type4G, 3G, 2GSupported Networks4G LTE...
# 260  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 261  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                       battery
# 0    Battery Capacity5000 mAh
# 1    Battery Capacity5000 mAh
# 2    Battery Capacity5000 mAh
# 3    Battery Capacity5000 mAh
# 4    Battery Capacity5000 mAh
# ..                        ...
# 257  Battery Capacity5000 mAh
# 258  Battery Capacity5000 mAh
# 259  Battery Capacity5000 mAh
# 260  Battery Capacity5000 mAh
# 261  Battery Capacity5000 mAh
#
# [214 rows x 10 columns]

# %% [markdown]
# ### ***price***

# %%
clean_price_col(realme)
# Out:
# 'datatype -Int16'

# %% [markdown]
# ### *****storage_ram*****

# %%
func_apply(func=remove_internal,col_name='storage_ram',df=realme)
# Out:
# Successfully applied function
# 133 :  Storage64 GBRAM4 GBExpandable Storage256 GBSupported Memory Card TypemicroSDMemory Card Slot TypeDedicated Slot
# 19 :  Storage128 GBRAM6 GBExpandable Storage1 TBSupported Memory Card TypeMicroSDMemory Card Slot TypeHybrid Slot
# 82 :  Storage256 GBRAM12 GB
# sample data:
#  None

# %%
func_apply(func=cut_remove_words,col_name='storage_ram',df=realme)
# Out:
# Successfully applied function
# 195 : Storage64 GBRAM4 GBExpandable Storage1TB
# 114 : Storage64 GBRAM4 GBExpandable Storage256GB
# 212 : Storage64 GBRAM4 GBExpandable Storage1TB
# sample data:
#  None

# %% [markdown]
# # vivo

# %%
vivo
# Out:
#                                      name  ratings    price
# 0       vivo T2x 5G (Marine Blue, 128 GB)      4.4  ₹13,999  \
# 1     vivo T2x 5G (Glimmer Black, 128 GB)      4.4  ₹13,999
# 2       vivo T2x 5G (Aurora Gold, 128 GB)      4.4  ₹13,999
# 3       vivo T2x 5G (Aurora Gold, 128 GB)      4.3  ₹15,999
# 4     vivo T2x 5G (Glimmer Black, 128 GB)      4.3  ₹15,999
# ..                                    ...      ...      ...
# 307      vivo Y20 (Obsidian Black, 64 GB)      4.3  ₹16,990
# 308         vivo Y20 (Purist Blue, 64 GB)      4.3  ₹16,990
# 309    vivo S1 Pro (Dreamy White, 128 GB)      4.4  ₹20,990
# 310  vivo Y51A (Crystal Symphony, 128 GB)      4.3  ₹16,990
# 311    vivo S1 Pro (Mystic Black, 128 GB)      4.4  ₹18,950
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 307  https://rukminim2.flixcart.com/image/312/312/k...
# 308  https://rukminim2.flixcart.com/image/312/312/k...
# 309  https://rukminim2.flixcart.com/image/312/312/k...
# 310  https://rukminim2.flixcart.com/image/312/312/k...
# 311  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 0    Internal Storage128 GBRAM6 GBMemory Card Slot ...  \
# 1    Internal Storage128 GBRAM6 GBMemory Card Slot ...
# 2    Internal Storage128 GBRAM6 GBMemory Card Slot ...
# 3    Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 4    Internal Storage128 GBRAM8 GBMemory Card Slot ...
# ..                                                 ...
# 307  Internal Storage64 GBRAM4 GBExpandable Storage...
# 308  Internal Storage64 GBRAM4 GBExpandable Storage...
# 309  Internal Storage128 GBRAM8 GBExpandable Storag...
# 310  Internal Storage128 GBRAM6 GBExpandable Storag...
# 311  Internal Storage128 GBRAM8 GBExpandable Storag...
#
#                                           os_processor
# 0     SystemAndroid 13Processor TypeDimensity 6020P...  \
# 1     SystemAndroid 13Processor TypeDimensity 6020P...
# 2     SystemAndroid 13Processor TypeDimensity 6020P...
# 3     SystemAndroid 13Processor TypeDimensity 6020P...
# 4     SystemAndroid 13Processor TypeDimensity 6020P...
# ..                                                 ...
# 307   SystemAndroid 10Processor TypeQualcomm Snapdr...
# 308   SystemAndroid 10Processor TypeQualcomm Snapdr...
# 309   SystemAndroid Pie 9Processor TypeQualcomm Sna...
# 310   SystemAndroid 11Processor TypeQualcomm Snapdr...
# 311   SystemAndroid Pie 9Processor TypeQualcomm Sna...
#
#                                                 camera
# 0    Primary Camera AvailableYesPrimary Camera50MP ...  \
# 1    Primary Camera AvailableYesPrimary Camera50MP ...
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
# 3    Primary Camera AvailableYesPrimary Camera50MP ...
# 4    Primary Camera AvailableYesPrimary Camera50MP ...
# ..                                                 ...
# 307  Primary Camera AvailableYesPrimary Camera13MP ...
# 308  Primary Camera AvailableYesPrimary Camera13MP ...
# 309  Primary Camera AvailableYesPrimary Camera48MP ...
# 310  Primary Camera AvailableYesPrimary Camera48MP ...
# 311  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                                display
# 0    Display Size16.71 cm (6.58 inch)Resolution2408...  \
# 1    Display Size16.71 cm (6.58 inch)Resolution2408...
# 2    Display Size16.71 cm (6.58 inch)Resolution2408...
# 3    Display Size16.71 cm (6.58 inch)Resolution2408...
# 4    Display Size16.71 cm (6.58 inch)Resolution2408...
# ..                                                 ...
# 307  Display Size16.54 cm (6.51 inch)Resolution1600...
# 308  Display Size16.54 cm (6.51 inch)Resolution1600...
# 309  Display Size16.21 cm (6.38 inch)Resolution1080...
# 310  Display Size16.71 cm (6.58 inch)Resolution2408...
# 311  Display Size16.21 cm (6.38 inch)Resolution1080...
#
#                                                network
# 0    Network Type5G, 4G, 3GSupported Networks5G, 4G...  \
# 1    Network Type5G, 4G, 3GSupported Networks5G, 4G...
# 2    Network Type5G, 4G, 3GSupported Networks5G, 4G...
# 3    Network Type5G, 4G, 3GSupported Networks5G, 4G...
# 4    Network Type5G, 4G, 3GSupported Networks5G, 4G...
# ..                                                 ...
# 307  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 308  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 309  Network Type4G VOLTE, 4G, 2G, 3GSupported Netw...
# 310  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 311  Network Type4G VOLTE, 4G, 2G, 3GSupported Netw...
#
#                                          battery
# 0    Battery Capacity5000 mAhBattery TypeLithium
# 1    Battery Capacity5000 mAhBattery TypeLithium
# 2    Battery Capacity5000 mAhBattery TypeLithium
# 3    Battery Capacity5000 mAhBattery TypeLithium
# 4    Battery Capacity5000 mAhBattery TypeLithium
# ..                                           ...
# 307                     Battery Capacity5000 mAh
# 308                     Battery Capacity5000 mAh
# 309                     Battery Capacity4500 mAh
# 310                     Battery Capacity5000 mAh
# 311                     Battery Capacity4500 mAh
#
# [301 rows x 10 columns]

# %% [markdown]
# ### ***price***

# %%
clean_price_col(vivo)
# Out:
# 'datatype -Int16'

# %% [markdown]
# ### ***storage_ram***

# %%
func_apply(func=remove_internal,col_name='storage_ram',df=vivo)
# Out:
# Successfully applied function
# 4 :  Storage128 GBRAM8 GBMemory Card Slot TypeHybrid SlotCall Log MemoryYes
# 27 :  Storage256 GBRAM12 GBCall Log MemoryYes
# 6 :  Storage128 GBRAM4 GBMemory Card Slot TypeHybrid SlotCall Log MemoryYes
# sample data:
#  None

# %%
func_apply(func=cut_remove_words,col_name='storage_ram',df=vivo)
# Out:
# Successfully applied function
# 255 : Storage256 GBRAM12
# 188 : Storage128 GBRAM8
# 57 : Storage128 GBRAM4 GBExpandable Storage1TB
# sample data:
#  None

# %% [markdown]
# # oppo

# %%
oppo
# Out:
#                                             name  ratings    price
# 0                        OPPO A17k (Blue, 64 GB)      4.5   ₹9,499  \
# 1                    OPPO A17 (Lake Blue, 64 GB)      4.4  ₹12,200
# 2               OPPO A17 (Midnight Black, 64 GB)      4.4  ₹12,499
# 3            OPPO A78 5G (Glowing Black, 128 GB)      4.3  ₹18,142
# 4                    OPPO A17 (Lake Blue, 64 GB)      4.4  ₹12,499
# ..                                           ...      ...      ...
# 248                       OPPO A5s (Gold, 64 GB)      4.3  ₹15,990
# 249  OPPO Reno7 Pro 5G (Startrails Blue, 256 GB)      4.4  ₹34,999
# 250                        OPPO A5s (Red, 32 GB)      4.3  ₹13,990
# 251               OPPO A15S (Fancy White, 64 GB)      4.4  ₹11,309
# 252                OPPO A7 (Glaring Gold, 64 GB)      4.4  ₹16,990
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 248  https://rukminim2.flixcart.com/image/312/312/k...
# 249  https://rukminim2.flixcart.com/image/312/312/k...
# 250  https://rukminim2.flixcart.com/image/312/312/k...
# 251  https://rukminim2.flixcart.com/image/312/312/k...
# 252  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                            storage_ram
# 0    Internal Storage64 GBRAM3 GBExpandable Storage...  \
# 1    Internal Storage64 GBRAM4 GBMemory Card Slot T...
# 2    Internal Storage64 GBRAM4 GBExpandable Storage...
# 3    Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 4    Internal Storage64 GBRAM4 GBExpandable Storage...
# ..                                                 ...
# 248  Internal Storage64 GBRAM4 GBExpandable Storage...
# 249  Internal Storage256 GBRAM12 GBExpandable Stora...
# 250  Internal Storage32 GBRAM3 GBExpandable Storage...
# 251  Internal Storage64 GBRAM4 GBMemory Card Slot T...
# 252  Internal Storage64 GBRAM3 GBExpandable Storage...
#
#                                           os_processor
# 0    Operating SystemAndroid 12Processor TypeMediat...  \
# 1    Operating SystemAndroid Q 12Processor TypeMedi...
# 2    Operating SystemAndroid 12Processor TypeMediat...
# 3    Operating SystemAndroidProcessor CoreOcta Core...
# 4    Operating SystemAndroid 12Processor TypeMediat...
# ..                                                 ...
# 248  Operating SystemAndroid Oreo 8.1Processor Type...
# 249  Operating SystemAndroid 11Processor TypeMediaT...
# 250  Operating SystemAndroid Oreo 8.1Processor Type...
# 251  Operating SystemAndroid Q 10.0Processor CoreOc...
# 252  Operating SystemAndroid Oreo 8.1Processor Type...
#
#                                           os_processor
# 0    Primary Camera AvailableYesPrimary Camera8MP R...  \
# 1    Primary Camera AvailableYesPrimary Camera50MP ...
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
# 3    Primary Camera13MP Rear CameraDual Camera Lens...
# 4    Primary Camera AvailableYesPrimary Camera50MP ...
# ..                                                 ...
# 248  Primary Camera AvailableYesPrimary Camera13MP ...
# 249  Primary Camera AvailableYesPrimary Camera50MP ...
# 250  Primary Camera AvailableYesPrimary Camera13MP ...
# 251  Primary Camera13MP Rear CameraDual Camera Lens...
# 252  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                                display
# 0    Display Size16.66 cm (6.56 inch)Resolution1612...  \
# 1    Display Size16.66 cm (6.56 inch)Resolution1612...
# 2    Display Size16.66 cm (6.56 inch)Resolution1612...
# 3    Display Size16.66 cm (6.56 inch)Resolution720 ...
# 4    Display Size16.66 cm (6.56 inch)Resolution1612...
# ..                                                 ...
# 248  Display Size15.75 cm (6.2 inch)Resolution1520 ...
# 249  Display Size16.51 cm (6.5 inch)Resolution2400 ...
# 250  Display Size15.75 cm (6.2 inch)Resolution1520 ...
# 251  Display Size16.56 cm (6.52 inch)Resolution720 ...
# 252  Display Size15.75 cm (6.2 inch)Resolution1520 ...
#
#                                                network
# 0    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 1    Network Type4G VOLTE, 4G, 3GSupported Networks...
# 2    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 3                   Network Type5GSupported Networks5G
# 4    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# ..                                                 ...
# 248  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
# 249  Network Type5G, 4G VOLTESupported Networks5G, ...
# 250  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
# 251  Network Type4G VOLTE, 3GSupported Networks4G V...
# 252  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
#
#                                      battery
# 0                   Battery Capacity5000 mAh
# 1                   Battery Capacity5000 mAh
# 2                   Battery Capacity5000 mAh
# 3                   Battery Capacity5000 mAh
# 4                   Battery Capacity5000 mAh
# ..                                       ...
# 248  Battery Capacity4230 mAhTalk Time50 hrs
# 249                 Battery Capacity4500 mAh
# 250  Battery Capacity4230 mAhTalk Time50 hrs
# 251                 Battery Capacity4230 mAh
# 252  Battery Capacity4230 mAhTalk Time32 hrs
#
# [251 rows x 10 columns]

# %%
func_apply(func=remove_internal,col_name='storage_ram',df=oppo)
# Out:
# Successfully applied function
# 94 :  Storage128 GBRAM6 GBExpandable Storage256 GBSupported Memory Card TypemicroSDMemory Card Slot TypeHybrid Slot
# 98 :  Storage64 GBRAM4 GBExpandable Storage256 GBSupported Memory Card TypemicroSDMemory Card Slot TypeDedicated Slot
# 10 :  Storage64 GBRAM3 GBExpandable Storage2 TBSupported Memory Card TypeMicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# sample data:
#  None

# %%
func_apply(func=cut_remove_words,col_name='storage_ram',df=oppo)
# Out:
# Successfully applied function
# 161 : Storage32 MBRAM32
# 73 : Storage256 GBRAM12
# 104 : Storage128 GBRAM4 GBExpandable Storage256GB
# sample data:
#  None

# %% [markdown]
# # motorola

# %%
motorola
# Out:
#                                                 name  ratings    price
# 0               MOTOROLA g42 (Atlantic Green, 64 GB)      4.2   ₹9,999  \
# 1                 MOTOROLA e13 (Cosmic Black, 64 GB)      4.0   ₹7,299
# 2                MOTOROLA G32 (Mineral Gray, 128 GB)      4.1  ₹11,999
# 3                  MOTOROLA e32 (Arctic Blue, 64 GB)      3.9   ₹7,999
# 4               MOTOROLA g13 (Lavender Blue, 128 GB)      3.9   ₹9,999
# ..                                               ...      ...      ...
# 115              Moto E6s (Polished Graphite, 64 GB)      4.1   ₹7,499
# 116                 MOTOROLA G30 (Pastel Sky, 64 GB)      4.1  ₹10,999
# 117          MOTOROLA G10 Power (Breeze Blue, 64 GB)      4.2   ₹9,999
# 118  MOTOROLA Edge 20 Fusion 5G (Cyber Teal, 128 GB)      4.0  ₹18,999
# 119    MOTOROLA Edge 30 Pro (Stardust White, 128 GB)      4.0  ₹34,999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/l...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 115  https://rukminim2.flixcart.com/image/312/312/k...
# 116  https://rukminim2.flixcart.com/image/312/312/k...
# 117  https://rukminim2.flixcart.com/image/312/312/k...
# 118  https://rukminim2.flixcart.com/image/312/312/k...
# 119  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 0    Internal Storage64 GBRAM4 GBSupported Memory C...  \
# 1    Internal Storage64 GBRAM4 GBExpandable Storage...
# 2    Internal Storage128 GBRAM8 GBSupported Memory ...
# 3    Internal Storage64 GBRAM4 GBExpandable Storage...
# 4    Internal Storage128 GBRAM4 GBExpandable Storag...
# ..                                                 ...
# 115  Internal Storage64 GBRAM4 GBExpandable Storage...
# 116  Internal Storage64 GBRAM4 GBSupported Memory C...
# 117  Internal Storage64 GBRAM4 GBSupported Memory C...
# 118  Internal Storage128 GBRAM6 GBMemory Card Slot ...
# 119                      Internal Storage128 GBRAM8 GB
#
#                                           os_processor
# 0     SystemAndroid 12Processor TypeQualcomm Snapdr...  \
# 1     SystemAndroid 13 (Go Edition)Processor TypeUn...
# 2     SystemAndroid 12Processor TypeQualcomm Snapdr...
# 3     SystemAndroid 12Processor TypeMediatek Helio ...
# 4     SystemAndroid 13Processor TypeHelio G85Proces...
# ..                                                 ...
# 115   SystemAndroid 11Processor TypeSnapdragon 662P...
# 116   SystemAndroid 11Processor TypeSnapdragon 460P...
# 117   SystemAndroid 11Processor TypeMediaTek Dimens...
# 118   SystemAndroid 12Processor TypeQualcomm Snapdr...
# 119  Primary Camera AvailableYesPrimary Camera 50MP...
#
#                                                 camera
# 0    Primary Camera AvailableYesPrimary Camera50MP ...  \
# 1    Primary Camera AvailableYesPrimary Camera13MP ...
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
# 3    Primary Camera AvailableYesPrimary Camera50MP ...
# 4    Primary Camera AvailableYesPrimary Camera50MP ...
# ..                                                 ...
# 115  Primary Camera AvailableYesPrimary Camera13MP ...
# 116  Primary Camera AvailableYesPrimary Camera64MP ...
# 117  Primary Camera AvailableYesPrimary Camera48MP ...
# 118  Primary Camera AvailableYesPrimary Camera108MP...
# 119  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                                display
# 0    Display Size16.43 cm (6.47 inch)Resolution2400...  \
# 1    Display Size16.51 cm (6.5 inch)Resolution1600 ...
# 2    Display Size16.51 cm (6.5 inch)Resolution2400 ...
# 3    Display Size16.51 cm (6.5 inch)Resolution1600 ...
# 4    Display Size16.51 cm (6.5 inch)Resolution1600 ...
# ..                                                 ...
# 115  Display Size15.49 cm (6.1 inch)Resolution1560 ...
# 116  Display Size16.54 cm (6.51 inch)Resolution1600...
# 117  Display Size16.54 cm (6.51 inch)Resolution1600...
# 118  Display Size16.94 cm (6.67 inch)Resolution2400...
# 119  Display Size16.3 cm (6.417 inch)Resolution2400...
#
#                                                network
# 0    Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 1    Network Type4G, 3G, 2GSupported Networks4G LTE...
# 2    Network Type4G, 3G, 2GSupported Networks4G LTE...
# 3    Network Type4G, 3G, 2GSupported Networks4G LTE...
# 4    Network Type2G, 3G, 4GSupported Networks4G LTE...
# ..                                                 ...
# 115  Network Type4G, 3G, 2GSupported Networks4G LTE...
# 116  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 117  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 118  Network Type5G, 4G, 3G, 2GSupported Networks5G...
# 119  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                       battery
# 0    Battery Capacity5000 mAh
# 1    Battery Capacity5000 mAh
# 2    Battery Capacity5000 mAh
# 3    Battery Capacity5000 mAh
# 4    Battery Capacity5000 mAh
# ..                        ...
# 115  Battery Capacity3000 mAh
# 116  Battery Capacity5000 mAh
# 117  Battery Capacity6000 mAh
# 118  Battery Capacity5000 mAh
# 119  Battery Capacity4800 mAh
#
# [119 rows x 10 columns]

# %% [markdown]
# ### ***price***

# %%
clean_price_col(motorola)
# Out:
# 'datatype -Int16'

# %% [markdown]
# ### ***storage_ram***

# %%
func_apply(func=remove_internal,col_name='storage_ram',df=motorola)
# Out:
# Successfully applied function
# 107 :  Storage128 GBRAM6 GBSupported Memory Card TypemicroSDMemory Card Slot TypeHybrid Slot
# 48 :  Storage64 GBRAM4 GBSupported Memory Card TypeMicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 69 :  Storage64 GBRAM4 GBExpandable Storage512 GBSupported Memory Card TypemicroSDMemory Card Slot TypeHybrid Slot
# sample data:
#  None

# %%
func_apply(func=cut_remove_words,col_name='storage_ram',df=motorola)
# Out:
# Successfully applied function
# 57 : Storage64 GBRAM4 GBExpandable Storage1TB
# 83 : Storage64 GBRAM4
# 11 : Storage128 GBRAM4 GBExpandable Storage1TB
# sample data:
#  None

# %%
def random_values(col_name:str,df:pd.DataFrame,total=6):
    for i in range(0,total):
        index = np.random.randint(df.shape[0])
        print(index,':',df[col_name].iloc[index])        

random_values(col_name='storage_ram',df=motorola)
# Out:
# 104 : Storage128 GBRAM6 GBExpandable Storage1TB
# 81 : Storage128 GBRAM6
# 54 : Storage64 GBRAM4 GBExpandable Storage1TB
# 28 : Storage0 MBExpandable
# 72 : Storage128 GBRAM8
# 89 : Storage0 MBExpandable

# %% [markdown]
# # techno

# %%
techno
# Out:
#                                           name  ratings    price
# 0             Tecno Pova 3 (Eco Black, 128 GB)      4.1  ₹13,998  \
# 1      Tecno Pop 5 Pro (Deepsea Luster, 32 GB)      4.2   ₹6,960
# 2              Tecno Pova 3 (Eco Black, 64 GB)      4.2  ₹10,849
# 3            Tecno Pova 3 (Tech Silver, 64 GB)      4.2  ₹10,978
# 4    Tecno Spark Go 2023 (UYUNI BLUE, 32+3 GB)      4.1   ₹6,750
# ..                                         ...      ...      ...
# 146         Tecno Camon 15 (SHOAL GOLD, 64 GB)      4.2  ₹12,499
# 147           Tecno Camon 19 Neo (Green, 6 GB)      4.1  ₹18,490
# 148  Tecno Spark 10 Pro (Starry Black, 256 GB)      4.1  ₹14,999
# 149   Tecno Spark 10 Pro (Pearl White, 256 GB)      4.1  ₹14,999
# 150       Tecno Spark 10 pro (Meta Blue, 8 GB)      4.1  ₹13,999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/l...  \
# 1    https://rukminim2.flixcart.com/image/312/312/k...
# 2    https://rukminim2.flixcart.com/image/312/312/l...
# 3    https://rukminim2.flixcart.com/image/312/312/l...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 146  https://rukminim2.flixcart.com/image/312/312/k...
# 147  https://rukminim2.flixcart.com/image/312/312/x...
# 148  https://rukminim2.flixcart.com/image/312/312/x...
# 149  https://rukminim2.flixcart.com/image/312/312/x...
# 150  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 0    Internal Storage128 GBRAM6 GBExpandable Storag...  \
# 1    Internal Storage32 GBRAM3 GBExpandable Storage...
# 2    Internal Storage64 GBRAM4 GBExpandable Storage...
# 3    Internal Storage64 GBRAM4 GBExpandable Storage...
# 4    Internal Storage32+3 GBRAM3 GBMemory Card Slot...
# ..                                                 ...
# 146  Internal Storage64 GBRAM4 GBExpandable Storage...
# 147  Internal Storage6 GBRAM128 GBMemory Card Slot ...
# 148  Internal Storage256 GBRAM8 GBExpandable Storag...
# 149  Internal Storage256 GBRAM8 GBExpandable Storag...
# 150  Internal Storage8 GBRAM8 GBMemory Card Slot Ty...
#
#                                           os_processor
# 0    Operating SystemAndroid 12Processor TypeMediaT...  \
# 1    Operating SystemAndroid 11 (Go Edition)Process...
# 2    Operating SystemAndroid 12Processor TypeMediaT...
# 3    Operating SystemAndroid 12Processor TypeMediaT...
# 4    Operating SystemAndroid 12Primary Clock Speed2...
# ..                                                 ...
# 146  Operating SystemAndroid 10Processor TypeHelio ...
# 147  Operating SystemAndroid Android 12Primary Cloc...
# 148  Operating SystemAndroid 13Processor TypeMediat...
# 149  Operating SystemAndroid 13Processor TypeMediat...
# 150  Operating SystemAndroid 13Primary Clock Speed2...
#
#                                           os_processor
# 0    Primary Camera AvailableYesPrimary Camera50MP ...  \
# 1    Primary Camera AvailableYesPrimary Camera8MP R...
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
# 3    Primary Camera AvailableYesPrimary Camera50MP ...
# 4    Primary Camera13MP Rear CameraDual Camera Lens...
# ..                                                 ...
# 146  Primary Camera AvailableYesPrimary Camera48MP ...
# 147  Primary Camera48MP Rear CameraDual Camera Lens...
# 148  Primary Camera AvailableYesPrimary Camera50MP ...
# 149  Primary Camera AvailableYesPrimary Camera50MP ...
# 150  Primary Camera50MP Rear CameraDual Camera Lens...
#
#                                                display
# 0    Display Size17.53 cm (6.9 inch)Resolution1080 ...  \
# 1    Display Size16.56 cm (6.52 inch)Resolution720 ...
# 2    Display Size17.53 cm (6.9 inch)Resolution1080 ...
# 3    Display Size17.53 cm (6.9 inch)Resolution1080 ...
# 4    Display Size16.66 cm (6.56 inch)Resolution720x...
# ..                                                 ...
# 146  Display Size16.64 cm (6.55 inch)Resolution720 ...
# 147  Display Size17.27 cm (6.8 inch)Resolution2460x...
# 148  Display Size17.22 cm (6.78 inch)Resolution2460...
# 149  Display Size17.22 cm (6.78 inch)Resolution2460...
# 150  Display Size17.27 cm (6.8 inch)Resolution1080 ...
#
#                                                network
# 0    Network Type4G VOLTE, 4GSupported Networks4G V...  \
# 1    Network Type4G VOLTE, 4GSupported Networks4G V...
# 2    Network Type4G VOLTE, 4GSupported Networks4G V...
# 3    Network Type4G VOLTE, 4GSupported Networks4G V...
# 4       Network Type4G VOLTESupported Networks4G VoLTE
# ..                                                 ...
# 146  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 147     Network Type2G, 3G, 4GSupported Networks4G LTE
# 148  Network Type4G VOLTE, 4GSupported Networks4G V...
# 149  Network Type4G VOLTE, 4GSupported Networks4G V...
# 150  Network Type4GSupported Networks4G LTE, GSM, W...
#
#                                                battery
# 0       Battery Capacity7000 mAhBattery TypeLi-Polymer
# 1            Battery Capacity6000 mAhBattery TypeLi-Po
# 2            Battery Capacity7000 mAhBattery TypeLi-Po
# 3            Battery Capacity7000 mAhBattery TypeLi-Po
# 4                             Battery Capacity5000 mAh
# ..                                                 ...
# 146                           Battery Capacity5000 mAh
# 147                           Battery Capacity5000 mAh
# 148          Battery Capacity5000 mAhBattery TypeLi-Po
# 149          Battery Capacity5000 mAhBattery TypeLi-Po
# 150  Battery Capacity5000 mAhBattery TypeNon-Remova...
#
# [151 rows x 10 columns]

# %% [markdown]
# ### ***price***

# %%
techno['price'][95] = '15999'

# %%
clean_price_col(techno)
# Out:
# 'datatype -Int16'

# %%
techno[techno['price'] == 'nan']
# Out:
# Empty DataFrame
# Columns: [index, name, ratings, price, imgURL, storage_ram, os_processor, os_processor, display, network, battery]
# Index: []

# %%
random_values(col_name='storage_ram',df=techno)
# Out:
# 117 : Internal Storage64 GBRAM3 GBMemory Card Slot TypeDedicated Slot
# 113 : Internal Storage128 GBRAM8 GBExpandable Storage2 TBSupported Memory Card TypemicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 21 : Internal Storage64 GBRAM4 GBExpandable Storage512 GBSupported Memory Card TypeMicro SDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 34 : Internal Storage64 GBRAM3 GBExpandable Storage256 GBSupported Memory Card TypemicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 16 : Internal Storage64 GBRAM3 GBMemory Card Slot TypeDedicated Slot
# 23 : Internal Storage64 GBRAM3 GBExpandable Storage512 GBSupported Memory Card TypeMicro SDMemory Card Slot TypeDedicated SlotCall Log MemoryYes

# %% [markdown]
# ### ***storage_ram***

# %%
func_apply(func=remove_internal,col_name='storage_ram',df=techno)
# Out:
# Successfully applied function
# 8 :  Storage64 GBRAM2 GBMemory Card Slot TypeDedicated Slot
# 106 :  Storage128 GBRAM8 GBExpandable Storage2 TBSupported Memory Card TypemicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 5 :  Storage64 GBRAM4 GBExpandable Storage512 GBSupported Memory Card TypeMicro SDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# sample data:
#  None

# %%
func_apply(func=cut_remove_words,col_name='storage_ram',df=techno)
# Out:
# Successfully applied function
# 136 : Storage64 GBRAM3
# 79 : Storage8 GBRAM128
# 73 : Storage64 GBRAM4 GBExpandable Storage1TB
# sample data:
#  None

# %% [markdown]
# # infinix

# %%
infinix
# Out:
#                                              name  ratings    price
# 0             Infinix SMART 7 (Azure Blue, 64 GB)      4.3   ₹7,299  \
# 1              Infinix HOT 30i (Marigold, 128 GB)      4.3   ₹8,999
# 2               Infinix HOT 30i (Marigold, 64 GB)      4.3   ₹7,999
# 3         Infinix HOT 30i (Diamond White, 128 GB)      4.3   ₹8,999
# 4          Infinix HOT 30i (Diamond White, 64 GB)      4.3   ₹7,999
# ..                                            ...      ...      ...
# 187          Infinix Hot S3X (Milan Black, 32 GB)      4.2  ₹10,999
# 188   Infinix Note 10 Pro (Nordic Secret, 256 GB)      4.2  ₹16,999
# 189   Infinix Note 5 Stylus (Bordeaux Red, 64 GB)      3.9  ₹16,999
# 190  Infinix Note 5 Stylus (Charcoal Blue, 64 GB)      3.9  ₹16,999
# 191       Infinix S5 Lite (Midnight Black, 64 GB)      4.3   ₹9,999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 187  https://rukminim2.flixcart.com/image/312/312/j...
# 188  https://rukminim2.flixcart.com/image/312/312/k...
# 189  https://rukminim2.flixcart.com/image/312/312/j...
# 190  https://rukminim2.flixcart.com/image/312/312/j...
# 191  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 0    Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 1    Internal Storage128 GBRAM8 GBExpandable Storag...
# 2    Internal Storage64 GBRAM4 GBExpandable Storage...
# 3    Internal Storage128 GBRAM8 GBExpandable Storag...
# 4    Internal Storage64 GBRAM4 GBExpandable Storage...
# ..                                                 ...
# 187  Internal Storage32 GBRAM3 GBExpandable Storage...
# 188  Internal Storage256 GBRAM8 GBExpandable Storag...
# 189  Internal Storage64 GBRAM4 GBExpandable Storage...
# 190  Internal Storage64 GBRAM4 GBExpandable Storage...
# 191  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                           os_processor
# 0     SystemAndroid 12Processor TypeUnisoc Spreadtr...  \
# 1     SystemAndroid 12Processor TypeG37Processor Co...
# 2     SystemAndroid 12Processor TypeG37Processor Co...
# 3     SystemAndroid 12Processor TypeG37Processor Co...
# 4     SystemAndroid 12Processor TypeG37Processor Co...
# ..                                                 ...
# 187   SystemAndroid Oreo 8.1Processor TypeQualcomm ...
# 188   SystemAndroid 11Processor TypeMediaTek Helio ...
# 189   SystemAndroid Oreo 8.1Processor TypeMediatek ...
# 190   SystemAndroid Oreo 8.1Processor TypeMediatek ...
# 191   SystemAndroid Pie 9Processor TypeHelio P22 (M...
#
#                                                 camera
# 0    Primary Camera AvailableYesPrimary Camera13MP ...  \
# 1    Primary Camera AvailableYesPrimary Camera50MP ...
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
# 3    Primary Camera AvailableYesPrimary Camera50MP ...
# 4    Primary Camera AvailableYesPrimary Camera50MP ...
# ..                                                 ...
# 187  Primary Camera AvailableYesPrimary Camera13MP ...
# 188  Primary Camera AvailableYesPrimary Camera64MP ...
# 189  Primary Camera AvailableYesPrimary Camera16MP ...
# 190  Primary Camera AvailableYesPrimary Camera16MP ...
# 191  Primary Camera AvailableYesPrimary Camera16MP ...
#
#                                                display
# 0    Display Size16.76 cm (6.6 inch)Resolution1612 ...  \
# 1    Display Size16.76 cm (6.6 inch)Resolution1612 ...
# 2    Display Size16.76 cm (6.6 inch)Resolution1612 ...
# 3    Display Size16.76 cm (6.6 inch)Resolution1612 ...
# 4    Display Size16.76 cm (6.6 inch)Resolution1612 ...
# ..                                                 ...
# 187  Display Size15.75 cm (6.2 inch)Resolution1500 ...
# 188  Display Size17.65 cm (6.95 inch)Resolution2460...
# 189  Display Size15.06 cm (5.93 inch)Resolution1080...
# 190  Display Size15.06 cm (5.93 inch)Resolution1080...
# 191  Display Size16.76 cm (6.6 inch)Resolution720 x...
#
#                                                network
# 0    Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 1    Network Type2G, 3G, 4GSupported Networks4G LTE...
# 2    Network Type2G, 3G, 4GSupported Networks4G LTE...
# 3    Network Type2G, 3G, 4GSupported Networks4G LTE...
# 4    Network Type2G, 3G, 4GSupported Networks4G LTE...
# ..                                                 ...
# 187  Network Type3G, 4G, 2GSupported NetworksGSM, W...
# 188  Network Type4G, 3G, 2GSupported Networks4G LTE...
# 189  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
# 190  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
# 191  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                                                battery
# 0    Battery Capacity6000 mAhBattery TypeLithium-io...
# 1    Battery Capacity5000 mAhBattery TypeLithium-io...
# 2    Battery Capacity5000 mAhBattery TypeLithium-io...
# 3    Battery Capacity5000 mAhBattery TypeLithium-io...
# 4    Battery Capacity5000 mAhBattery TypeLithium-io...
# ..                                                 ...
# 187                           Battery Capacity4000 mAh
# 188                           Battery Capacity5000 mAh
# 189  Battery Capacity4000 mAhBattery TypeLi-ion Pol...
# 190  Battery Capacity4000 mAhBattery TypeLi-ion Pol...
# 191                           Battery Capacity4000 mAh
#
# [163 rows x 10 columns]

# %% [markdown]
# ## ***price***

# %%
clean_price_col(infinix)
# Out:
# 'datatype -Int16'

# %% [markdown]
# ### ***storage_ram***

# %%
func_apply(func=remove_internal,col_name='storage_ram',df=infinix)
# Out:
# Successfully applied function
# 100 :  Storage64 GBRAM4 GBExpandable Storage256 GBSupported Memory Card TypeMicro SDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 32 :  Storage128 GBRAM6 GBExpandable Storage1 TBSupported Memory Card TypeMicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# 87 :  Storage64 GBRAM4 GBExpandable Storage256 GBSupported Memory Card TypemicroSDMemory Card Slot TypeDedicated SlotCall Log MemoryYes
# sample data:
#  None

# %%
func_apply(func=cut_remove_words,col_name='storage_ram',df=infinix)
# Out:
# Successfully applied function
# 105 : Storage64 GBRAM6 GBExpandable Storage256GB
# 125 : Storage128 GBRAM6 GBExpandable Storage512GB
# 86 : Storage64 GBRAM4 GBExpandable Storage256GB
# sample data:
#  None

# %%
random_values(col_name='storage_ram',df=infinix)
# Out:
# 96 : Storage128 GBRAM8 GBExpandable Storage512GB
# 80 : Storage128 GBRAM4 GBExpandable Storage256GB
# 94 : Storage64 GBRAM4 GBExpandable Storage256GB
# 149 : Storage32 GBRAM3 GBExpandable Storage128GB
# 6 : Storage64 GBRAM4 GBExpandable Storage1TB
# 79 : Storage64 GBRAM4 GBExpandable Storage512GB

# %% [markdown]
# > #                                                                   **END**
