# %%
import pandas as pd
import os
import numpy as np
from ensure import ensure_annotations
import re
import warnings
warnings.filterwarnings('ignore')

# %%
print(os.getcwd())
print(os.chdir(r'd:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem'))
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem
# None
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem

# %%
df = pd.read_csv(r'data\raw_data\apple_mobile_new_data.csv',index_col=None)

# %%
df.drop_duplicates(inplace=True,ignore_index=True)

# %%
df
# Out:
#                                              name  ratings      price
# 0                  APPLE iPhone 13 (Blue, 128 GB)      4.7    ₹61,999  \
# 1              APPLE iPhone 13 (Midnight, 128 GB)      4.7    ₹61,999
# 2             APPLE iPhone 13 (Starlight, 128 GB)      4.7    ₹61,999
# 3                  APPLE iPhone 13 (Pink, 128 GB)      4.7    ₹61,999
# 4              APPLE iPhone 14 (Midnight, 128 GB)      4.6    ₹69,999
# ..                                            ...      ...        ...
# 419              APPLE iPhone XR (Yellow, 128 GB)      4.6    ₹41,699
# 420  APPLE iPhone 11 Pro (Midnight Green, 256 GB)      4.6  ₹1,21,300
# 421                APPLE iPhone X (Silver, 64 GB)      4.6    ₹91,900
# 422           APPLE iPhone X (Space Gray, 256 GB)      4.6  ₹1,06,900
# 423            APPLE iPhone X (Space Gray, 64 GB)      4.6    ₹91,900
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/k...  \
# 1    https://rukminim2.flixcart.com/image/312/312/k...
# 2    https://rukminim2.flixcart.com/image/312/312/k...
# 3    https://rukminim2.flixcart.com/image/312/312/k...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 419  https://rukminim2.flixcart.com/image/312/312/k...
# 420  https://rukminim2.flixcart.com/image/312/312/k...
# 421  https://rukminim2.flixcart.com/image/312/312/j...
# 422  https://rukminim2.flixcart.com/image/312/312/j...
# 423  https://rukminim2.flixcart.com/image/312/312/j...
#
#                 storage_ram
# 0    Internal Storage128 GB  \
# 1    Internal Storage128 GB
# 2    Internal Storage128 GB
# 3    Internal Storage128 GB
# 4    Internal Storage128 GB
# ..                      ...
# 419  Internal Storage128 GB
# 420  Internal Storage256 GB
# 421   Internal Storage64 GB
# 422  Internal Storage256 GB
# 423   Internal Storage64 GB
#
#                                           os_processor
# 0    Operating SystemiOS 15Processor TypeA15 Bionic...  \
# 1    Operating SystemiOS 15Processor TypeA15 Bionic...
# 2    Operating SystemiOS 15Processor TypeA15 Bionic...
# 3    Operating SystemiOS 15Processor TypeA15 Bionic...
# 4    Operating SystemiOS 16Processor TypeA15 Bionic...
# ..                                                 ...
# 419  Operating SystemiOS 14.2Processor TypeA12 Bion...
# 420  Operating SystemiOS 13Processor TypeA13 Bionic...
# 421  Operating SystemiOS 11Processor TypeA11 Bionic...
# 422  Operating SystemiOS 11Processor TypeA11 Bionic...
# 423  Operating SystemiOS 11Processor TypeA11 Bionic...
#
#                                                 camera
# 0    Primary Camera AvailableYesPrimary Camera12MP ...  \
# 1    Primary Camera AvailableYesPrimary Camera12MP ...
# 2    Primary Camera AvailableYesPrimary Camera12MP ...
# 3    Primary Camera AvailableYesPrimary Camera12MP ...
# 4    Primary Camera AvailableYesPrimary Camera12MP ...
# ..                                                 ...
# 419  Primary Camera AvailableYesPrimary Camera12MP ...
# 420  Primary Camera AvailableYesPrimary Camera12MP ...
# 421  Primary Camera AvailableYesPrimary Camera12MP ...
# 422  Primary Camera AvailableYesPrimary Camera12MP ...
# 423  Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                                display
# 0    Display Size15.49 cm (6.1 inch)Resolution2532 ...  \
# 1    Display Size15.49 cm (6.1 inch)Resolution2532 ...
# 2    Display Size15.49 cm (6.1 inch)Resolution2532 ...
# 3    Display Size15.49 cm (6.1 inch)Resolution2532 ...
# 4    Display Size15.49 cm (6.1 inch)Resolution2532 ...
# ..                                                 ...
# 419  Display Size15.49 cm (6.1 inch)Resolution1792 ...
# 420  Display Size14.73 cm (5.8 inch)Resolution2436 ...
# 421  Display Size14.73 cm (5.8 inch)Resolution2436 ...
# 422  Display Size14.73 cm (5.8 inch)Resolution2436 ...
# 423  Display Size14.73 cm (5.8 inch)Resolution2436 ...
#
#                                                network battery
# 0    Network Type5G, 4G, 3G, 2GSupported Networks5G...     NaN
# 1    Network Type5G, 4G, 3G, 2GSupported Networks5G...     NaN
# 2    Network Type5G, 4G, 3G, 2GSupported Networks5G...     NaN
# 3    Network Type5G, 4G, 3G, 2GSupported Networks5G...     NaN
# 4    Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...     NaN
# ..                                                 ...     ...
# 419  Network Type3G, 4G, 2GSupported NetworksGSM, W...     NaN
# 420  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...     NaN
# 421  Network Type3G, 4G, 2GSupported NetworksGSM, W...     NaN
# 422  Network Type3G, 4G, 2GSupported NetworksGSM, W...     NaN
# 423  Network Type3G, 4G, 2GSupported NetworksGSM, W...     NaN
#
# [424 rows x 10 columns]

# %%
@ensure_annotations
def random_values(feature_name:str,total=6):
    for i in range(0,total):
        index = np.random.randint(df.shape[0])
        print(index,':',df[feature_name].iloc[index])

# %%
random_values('battery')
# Out:
# 153 : nan
# 18 : nan
# 176 : nan
# 324 : nan
# 85 : nan
# 416 : nan

# %%
df.isnull().sum()
# Out:
# name              0
# ratings           0
# price             0
# imgURL            0
# storage_ram       0
# os_processor      0
# camera            0
# display           0
# network           0
# battery         322
# dtype: int64

# %%
df.shape
# Out:
# (424, 10)

# %%
df[df['ratings'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [name, ratings, price, imgURL, storage_ram, os_processor, camera, display, network, battery]
# Index: []

# %%
# df['ratings'][164] = 4.7
# df['ratings'][187] = 4.3
# df['ratings'][210] = 4.5
# df['ratings'][234] = 4.5
# df['ratings'][258] = 4.5
# df['ratings'][282] = 4.4
# df['ratings'][305] = 4.7
# df['ratings'][328] = 4.6
# df['ratings'][351] = 4.5
# df['ratings'][375] = 4.6
# df['ratings'][399] = 3.9
# df['ratings'][423] = 4.6

# %%
df[df['ratings'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [name, ratings, price, imgURL, storage_ram, os_processor, camera, display, network, battery]
# Index: []

# %%
df.isnull().sum()
# Out:
# name              0
# ratings           0
# price             0
# imgURL            0
# storage_ram       0
# os_processor      0
# camera            0
# display           0
# network           0
# battery         322
# dtype: int64

# %% [markdown]
# ## NOW I CAN START

# %% [markdown]
# ## Battery

# %%
df = df.drop(labels=['battery'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 424 entries, 0 to 423
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          424 non-null    object
#  1   ratings       424 non-null    float64
#  2   price         424 non-null    object
#  3   imgURL        424 non-null    object
#  4   storage_ram   424 non-null    object
#  5   os_processor  424 non-null    object
#  6   camera        424 non-null    object
#  7   display       424 non-null    object
#  8   network       424 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 29.9+ KB

# %% [markdown]
# ## Storage

# %%
random_values('storage_ram')
# Out:
# 76 : Internal Storage1 TB
# 306 : Internal Storage128 GB
# 223 : Internal Storage256 GB
# 41 : Internal Storage64 GB
# 99 : Internal Storage128 GB
# 318 : Internal Storage64 GBPhone Book MemoryYesCall Log MemoryYesSMS MemoryYes

# %%
def extract_storage(row):
    storage = row.split()[1]
    return storage
df['storage'] = df['storage_ram'].apply(func=extract_storage)

# %%
import warnings
warnings.filterwarnings('ignore')
count = 0
for i in range(0,len(df['storage'])):
    df['storage'][i]= df['storage'].iloc[i].replace('Storage','')
    count+=1
print(f'looped till {count} index')
# Out:
# looped till 424 index

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 424 entries, 0 to 423
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          424 non-null    object
#  1   ratings       424 non-null    float64
#  2   price         424 non-null    object
#  3   imgURL        424 non-null    object
#  4   storage_ram   424 non-null    object
#  5   os_processor  424 non-null    object
#  6   camera        424 non-null    object
#  7   display       424 non-null    object
#  8   network       424 non-null    object
#  9   storage       424 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 33.3+ KB

# %%
random_values('storage')
# Out:
# 382 : 128
# 196 : 256
# 150 : 64
# 0 : 128
# 356 : 64
# 235 : 256

# %%
df['storage'] = df['storage'].replace('1','1024')

# %%
df['storage'] = df['storage'].astype('Int16')

# %% [markdown]
# ## Processors

# %%
def extract_processor(text):
    pattern = r'.*Processor'
    match = re.findall(pattern, text)
    if match:
        return match[0]
    else:
        return text

# %%
df['os_processor'].apply(func=extract_processor)
# Out:
# 0      Operating SystemiOS 15Processor TypeA15 Bionic...
# 1      Operating SystemiOS 15Processor TypeA15 Bionic...
# 2      Operating SystemiOS 15Processor TypeA15 Bionic...
# 3      Operating SystemiOS 15Processor TypeA15 Bionic...
# 4      Operating SystemiOS 16Processor TypeA15 Bionic...
#                              ...
# 419                    Operating SystemiOS 14.2Processor
# 420                      Operating SystemiOS 13Processor
# 421                      Operating SystemiOS 11Processor
# 422                      Operating SystemiOS 11Processor
# 423                      Operating SystemiOS 11Processor
# Name: os_processor, Length: 424, dtype: object

# %%
df['processors'] = df['os_processor'].apply(func=extract_processor)

# %% [markdown]
# ## IOS Version

# %%
random_values('processors')
# Out:
# 87 : Operating SystemiOS 15Processor TypeA15 Bionic ChipProcessor
# 320 : Operating SystemiOS 12Processor
# 205 : Operating SystemiOS 14.2Processor
# 165 : Operating SystemiOS 15Processor TypeA15 Bionic Chip, 6 Core ProcessorProcessor
# 309 : Operating SystemiOS 14Processor
# 23 : Operating SystemiOS 14Processor

# %%
random_values('os_processor')
# Out:
# 89 : Operating SystemiOS 15Processor TypeA15 Bionic ChipProcessor CoreHexa CoreOperating Frequency2G GSM/EDGE: 850, 900, 1800, 1900 MHz, 3G UMTS/HSPA+/DC-HSDPA: 850, 900, 1700/2100, 1900, 2100 MHz, 4G TD-LTE: Bands 34, 38, 39, 40, 41, 42, 46, 48, 4G FDD-LTE: Bands 1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 30, 32, 66, 5G NR: Bands n1, n2, n3, n5, n7, n8, n12, n20, n25, n28, n30, n38, n40, n41, n48, n66, n77, n78, n79
# 190 : Operating SystemiOS 12Processor TypeA12 Bionic Chip
# 271 : Operating SystemiOS 15Processor TypeA15 Bionic ChipProcessor CoreHexa CoreOperating Frequency2G GSM/EDGE: 850, 900, 1800, 1900 MHz, 3G UMTS/HSPA+/DC-HSDPA: 850, 900, 1700/2100, 1900, 2100 MHz, 4G TD-LTE: Bands 34, 38, 39, 40, 41, 42, 46, 48, 4G FDD-LTE: Bands 1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 30, 32, 66, 5G NR: Bands n1, n2, n3, n5, n7, n8, n12, n20, n25, n28, n30, n38, n40, n41, n48, n66, n77, n78, n79
# 1 : Operating SystemiOS 15Processor TypeA15 Bionic ChipProcessor CoreHexa CoreOperating Frequency2G GSM/EDGE: 850, 900, 1800, 1900 MHz, 3G UMTS/HSPA+/DC-HSDPA: 850, 900, 1700/2100, 1900, 2100 MHz, 4G TD-LTE: Bands 34, 38, 39, 40, 41, 42, 46, 48, 4G FDD-LTE: Bands 1, 2, 3, 4, 5, 7, 8, 12, 13, 17, 18, 19, 20, 25, 26, 28, 30, 32, 66, 5G NR: Bands n1, n2, n3, n5, n7, n8, n12, n20, n25, n28, n30, n38, n40, n41, n48, n66, n77, n78, n79
# 23 : Operating SystemiOS 14Processor TypeA14 Bionic Chip with Next Generation Neural Engine
# 346 : Operating SystemiOS 14Processor TypeA14 Bionic Chip with Next Generation Neural Engine

# %%
def ios_version(text_):
    pattern=r'^\d+[Processor]|\d+[.Processor]'
    found = re.findall(pattern,text_)
    if found:
        return found[0]
    else:
        return text_

# %%
df['processors'].apply(ios_version)
# Out:
# 0      15P
# 1      15P
# 2      15P
# 3      15P
# 4      16P
#       ...
# 419    14.
# 420    13P
# 421    11P
# 422    11P
# 423    11P
# Name: processors, Length: 424, dtype: object

# %%
df['ios_version'] = df['processors'].apply(ios_version)

# %%
random_values('ios_version')
# Out:
# 303 : 14P
# 5 : 16P
# 368 : 12P
# 58 : 14.
# 242 : 13P
# 255 : 9P

# %%
df.reset_index(inplace=True)
for Index,i in enumerate(df['ios_version']):
    # print(i)
    i = str(i).replace('P','')
    i = str(i).replace('.','')
    df['ios_version'][Index] = i

# %%
random_values('ios_version')
# Out:
# 341 : 9
# 350 : 14
# 392 : 15
# 384 : 7
# 277 : 14
# 399 : 7

# %%
non_numeric = [i for i in df['ios_version'] if len(i)> 2]
non_numeric
# Out:
# ['Operating SystemiOS 7Operating FrequencyGSM - 850, 900, 1800, 1900; UMTS - 2100',
#  'Operating SystemiOS 7Operating FrequencyGSM - 850, 900, 1800, 1900; UMTS - 2100']

# %%
df[df['ios_version'] == 'Operating SystemiOS 7Operating FrequencyGSM - 850, 900, 1800, 1900; UMTS - 2100'] # Just Droping
# Out:
#      index                          name  ratings    price
# 317    317  APPLE IPhone 4 (Black, 8 GB)      4.5  ₹22,900  \
# 324    324  APPLE IPhone 4 (White, 8 GB)      4.6  ₹13,999
#
#                                                 imgURL
# 317  https://rukminim2.flixcart.com/image/312/312/m...  \
# 324  https://rukminim2.flixcart.com/image/312/312/m...
#
#                                            storage_ram
# 317  Internal Storage8 GBPhone Book MemoryYesCall L...  \
# 324  Internal Storage8 GBPhone Book MemoryYesCall L...
#
#                                           os_processor
# 317  Operating SystemiOS 7Operating FrequencyGSM - ...  \
# 324  Operating SystemiOS 7Operating FrequencyGSM - ...
#
#                                                 camera
# 317  Primary Camera AvailableYesPrimary Camera5MP R...  \
# 324  Primary Camera AvailableYesPrimary Camera5MP R...
#
#                                                display
# 317  Display Size8.89 cm (3.5 inch)Resolution640 x ...  \
# 324  Display Size8.89 cm (3.5 inch)Resolution640 x ...
#
#                                                network  storage
# 317  Network Type3GSupported NetworksGSMInternet Co...        8  \
# 324  Network Type3GSupported NetworksGSMInternet Co...        8
#
#                                             processors
# 317  Operating SystemiOS 7Operating FrequencyGSM - ...  \
# 324  Operating SystemiOS 7Operating FrequencyGSM - ...
#
#                                            ios_version
# 317  Operating SystemiOS 7Operating FrequencyGSM - ...
# 324  Operating SystemiOS 7Operating FrequencyGSM - ...

# %%
df = df.drop(df[df['ios_version'] == 'Operating SystemiOS 7Operating FrequencyGSM - 850, 900, 1800, 1900; UMTS - 2100'].index)

# %%
df['ios_version'] = df['ios_version'].astype('Int16')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 422 entries, 0 to 423
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         422 non-null    int64
#  1   name          422 non-null    object
#  2   ratings       422 non-null    float64
#  3   price         422 non-null    object
#  4   imgURL        422 non-null    object
#  5   storage_ram   422 non-null    object
#  6   os_processor  422 non-null    object
#  7   camera        422 non-null    object
#  8   display       422 non-null    object
#  9   network       422 non-null    object
#  10  storage       422 non-null    Int16
#  11  processors    422 non-null    object
#  12  ios_version   422 non-null    Int16
# dtypes: Int16(2), float64(1), int64(1), object(9)
# memory usage: 42.0+ KB

# %% [markdown]
# ## Processors

# %%
def processor(text):
    pattern=r'(?<=Type).*'
    search = re.search(pattern,text)
    if search != None:
        return ' '.join(re.findall(pattern,text))
    else:
        return 'not montioned'

# %%
for i in range(0,9):
    rand = np.random.randint(df.shape[0])
    txt = processor(df['processors'].iloc[rand])
    print(df['processors'].iloc[rand],f'::index -{rand}')
    print(txt)
    print()
# Out:
# Operating SystemiOS 16Processor TypeA16 Bionic Chip, 6 Core ProcessorProcessor ::index -67
# A16 Bionic Chip, 6 Core ProcessorProcessor
#
# Operating SystemiOS 15Processor TypeA15 Bionic ChipProcessor ::index -142
# A15 Bionic ChipProcessor
#
# Operating SystemiOS 13Processor ::index -179
# not montioned
#
# Operating SystemiOS 16Processor TypeA16 Bionic Chip, 6 Core ProcessorProcessor ::index -67
# A16 Bionic Chip, 6 Core ProcessorProcessor
#
# Operating SystemiOS 12Processor ::index -233
# not montioned
#
# Operating SystemiOS 15Processor TypeA15 Bionic Chip, 6 Core ProcessorProcessor ::index -198
# A15 Bionic Chip, 6 Core ProcessorProcessor
#
# Operating SystemiOS 12Processor ::index -249
# not montioned
#
# Operating SystemiOS 14.2Processor ::index -276
# not montioned
#
# Operating SystemiOS 7Processor ::index -387
# not montioned

# %%
df['processor'] = df['processors'].apply(processor)
df = df.drop('processors',axis=1)
df = df.drop('index',axis=1)

# %%
random_values('processor')
# Out:
# 283 : not montioned
# 47 : A15 Bionic Chip, 6 Core ProcessorProcessor
# 141 : not montioned
# 266 : A9 Chip with 64-bit Architecture and M9 Motion Co-processorProcessor
# 227 : not montioned
# 250 : not montioned

# %%
df
# Out:
#                                              name  ratings      price
# 0                  APPLE iPhone 13 (Blue, 128 GB)      4.7    ₹61,999  \
# 1              APPLE iPhone 13 (Midnight, 128 GB)      4.7    ₹61,999
# 2             APPLE iPhone 13 (Starlight, 128 GB)      4.7    ₹61,999
# 3                  APPLE iPhone 13 (Pink, 128 GB)      4.7    ₹61,999
# 4              APPLE iPhone 14 (Midnight, 128 GB)      4.6    ₹69,999
# ..                                            ...      ...        ...
# 419              APPLE iPhone XR (Yellow, 128 GB)      4.6    ₹41,699
# 420  APPLE iPhone 11 Pro (Midnight Green, 256 GB)      4.6  ₹1,21,300
# 421                APPLE iPhone X (Silver, 64 GB)      4.6    ₹91,900
# 422           APPLE iPhone X (Space Gray, 256 GB)      4.6  ₹1,06,900
# 423            APPLE iPhone X (Space Gray, 64 GB)      4.6    ₹91,900
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/k...  \
# 1    https://rukminim2.flixcart.com/image/312/312/k...
# 2    https://rukminim2.flixcart.com/image/312/312/k...
# 3    https://rukminim2.flixcart.com/image/312/312/k...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 419  https://rukminim2.flixcart.com/image/312/312/k...
# 420  https://rukminim2.flixcart.com/image/312/312/k...
# 421  https://rukminim2.flixcart.com/image/312/312/j...
# 422  https://rukminim2.flixcart.com/image/312/312/j...
# 423  https://rukminim2.flixcart.com/image/312/312/j...
#
#                 storage_ram
# 0    Internal Storage128 GB  \
# 1    Internal Storage128 GB
# 2    Internal Storage128 GB
# 3    Internal Storage128 GB
# 4    Internal Storage128 GB
# ..                      ...
# 419  Internal Storage128 GB
# 420  Internal Storage256 GB
# 421   Internal Storage64 GB
# 422  Internal Storage256 GB
# 423   Internal Storage64 GB
#
#                                           os_processor
# 0    Operating SystemiOS 15Processor TypeA15 Bionic...  \
# 1    Operating SystemiOS 15Processor TypeA15 Bionic...
# 2    Operating SystemiOS 15Processor TypeA15 Bionic...
# 3    Operating SystemiOS 15Processor TypeA15 Bionic...
# 4    Operating SystemiOS 16Processor TypeA15 Bionic...
# ..                                                 ...
# 419  Operating SystemiOS 14.2Processor TypeA12 Bion...
# 420  Operating SystemiOS 13Processor TypeA13 Bionic...
# 421  Operating SystemiOS 11Processor TypeA11 Bionic...
# 422  Operating SystemiOS 11Processor TypeA11 Bionic...
# 423  Operating SystemiOS 11Processor TypeA11 Bionic...
#
#                                                 camera
# 0    Primary Camera AvailableYesPrimary Camera12MP ...  \
# 1    Primary Camera AvailableYesPrimary Camera12MP ...
# 2    Primary Camera AvailableYesPrimary Camera12MP ...
# 3    Primary Camera AvailableYesPrimary Camera12MP ...
# 4    Primary Camera AvailableYesPrimary Camera12MP ...
# ..                                                 ...
# 419  Primary Camera AvailableYesPrimary Camera12MP ...
# 420  Primary Camera AvailableYesPrimary Camera12MP ...
# 421  Primary Camera AvailableYesPrimary Camera12MP ...
# 422  Primary Camera AvailableYesPrimary Camera12MP ...
# 423  Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                                display
# 0    Display Size15.49 cm (6.1 inch)Resolution2532 ...  \
# 1    Display Size15.49 cm (6.1 inch)Resolution2532 ...
# 2    Display Size15.49 cm (6.1 inch)Resolution2532 ...
# 3    Display Size15.49 cm (6.1 inch)Resolution2532 ...
# 4    Display Size15.49 cm (6.1 inch)Resolution2532 ...
# ..                                                 ...
# 419  Display Size15.49 cm (6.1 inch)Resolution1792 ...
# 420  Display Size14.73 cm (5.8 inch)Resolution2436 ...
# 421  Display Size14.73 cm (5.8 inch)Resolution2436 ...
# 422  Display Size14.73 cm (5.8 inch)Resolution2436 ...
# 423  Display Size14.73 cm (5.8 inch)Resolution2436 ...
#
#                                                network  storage  ios_version
# 0    Network Type5G, 4G, 3G, 2GSupported Networks5G...      128           15  \
# 1    Network Type5G, 4G, 3G, 2GSupported Networks5G...      128           15
# 2    Network Type5G, 4G, 3G, 2GSupported Networks5G...      128           15
# 3    Network Type5G, 4G, 3G, 2GSupported Networks5G...      128           15
# 4    Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...      128           16
# ..                                                 ...      ...          ...
# 419  Network Type3G, 4G, 2GSupported NetworksGSM, W...      128           14
# 420  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...      256           13
# 421  Network Type3G, 4G, 2GSupported NetworksGSM, W...       64           11
# 422  Network Type3G, 4G, 2GSupported NetworksGSM, W...      256           11
# 423  Network Type3G, 4G, 2GSupported NetworksGSM, W...       64           11
#
#                                       processor
# 0                      A15 Bionic ChipProcessor
# 1                      A15 Bionic ChipProcessor
# 2                      A15 Bionic ChipProcessor
# 3                      A15 Bionic ChipProcessor
# 4    A15 Bionic Chip, 6 Core ProcessorProcessor
# ..                                          ...
# 419                               not montioned
# 420                               not montioned
# 421                               not montioned
# 422                               not montioned
# 423                               not montioned
#
# [422 rows x 12 columns]

# %% [markdown]
# ## Remove columns
# 1) storage_ram
# 2) os_processor

# %%
df = df.drop(columns=['os_processor','storage_ram'])

# %% [markdown]
# ## Price

# %%
df.reset_index(inplace=True)
for Index,i in enumerate(df['price']):
    i = str(i).replace('₹','')
    i = str(i).replace(',','')
    df['price'][Index] = i

# %%
df['price'] = df['price'].astype('Int16')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 422 entries, 0 to 421
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        422 non-null    int64
#  1   name         422 non-null    object
#  2   ratings      422 non-null    float64
#  3   price        422 non-null    Int16
#  4   imgURL       422 non-null    object
#  5   camera       422 non-null    object
#  6   display      422 non-null    object
#  7   network      422 non-null    object
#  8   storage      422 non-null    Int16
#  9   ios_version  422 non-null    Int16
#  10  processor    422 non-null    object
# dtypes: Int16(3), float64(1), int64(1), object(6)
# memory usage: 30.2+ KB

# %%
df['price'] = df['price'].abs() # this is to remove the negative values from price feature

# %%
df = df.drop(['index'],axis=1)

# %%
df
# Out:
#                                              name  ratings  price
# 0                  APPLE iPhone 13 (Blue, 128 GB)      4.7   3537  \
# 1              APPLE iPhone 13 (Midnight, 128 GB)      4.7   3537
# 2             APPLE iPhone 13 (Starlight, 128 GB)      4.7   3537
# 3                  APPLE iPhone 13 (Pink, 128 GB)      4.7   3537
# 4              APPLE iPhone 14 (Midnight, 128 GB)      4.6   4463
# ..                                            ...      ...    ...
# 417              APPLE iPhone XR (Yellow, 128 GB)      4.6  23837
# 418  APPLE iPhone 11 Pro (Midnight Green, 256 GB)      4.6   9772
# 419                APPLE iPhone X (Silver, 64 GB)      4.6  26364
# 420           APPLE iPhone X (Space Gray, 256 GB)      4.6  24172
# 421            APPLE iPhone X (Space Gray, 64 GB)      4.6  26364
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/k...  \
# 1    https://rukminim2.flixcart.com/image/312/312/k...
# 2    https://rukminim2.flixcart.com/image/312/312/k...
# 3    https://rukminim2.flixcart.com/image/312/312/k...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 417  https://rukminim2.flixcart.com/image/312/312/k...
# 418  https://rukminim2.flixcart.com/image/312/312/k...
# 419  https://rukminim2.flixcart.com/image/312/312/j...
# 420  https://rukminim2.flixcart.com/image/312/312/j...
# 421  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                                 camera
# 0    Primary Camera AvailableYesPrimary Camera12MP ...  \
# 1    Primary Camera AvailableYesPrimary Camera12MP ...
# 2    Primary Camera AvailableYesPrimary Camera12MP ...
# 3    Primary Camera AvailableYesPrimary Camera12MP ...
# 4    Primary Camera AvailableYesPrimary Camera12MP ...
# ..                                                 ...
# 417  Primary Camera AvailableYesPrimary Camera12MP ...
# 418  Primary Camera AvailableYesPrimary Camera12MP ...
# 419  Primary Camera AvailableYesPrimary Camera12MP ...
# 420  Primary Camera AvailableYesPrimary Camera12MP ...
# 421  Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                                display
# 0    Display Size15.49 cm (6.1 inch)Resolution2532 ...  \
# 1    Display Size15.49 cm (6.1 inch)Resolution2532 ...
# 2    Display Size15.49 cm (6.1 inch)Resolution2532 ...
# 3    Display Size15.49 cm (6.1 inch)Resolution2532 ...
# 4    Display Size15.49 cm (6.1 inch)Resolution2532 ...
# ..                                                 ...
# 417  Display Size15.49 cm (6.1 inch)Resolution1792 ...
# 418  Display Size14.73 cm (5.8 inch)Resolution2436 ...
# 419  Display Size14.73 cm (5.8 inch)Resolution2436 ...
# 420  Display Size14.73 cm (5.8 inch)Resolution2436 ...
# 421  Display Size14.73 cm (5.8 inch)Resolution2436 ...
#
#                                                network  storage  ios_version
# 0    Network Type5G, 4G, 3G, 2GSupported Networks5G...      128           15  \
# 1    Network Type5G, 4G, 3G, 2GSupported Networks5G...      128           15
# 2    Network Type5G, 4G, 3G, 2GSupported Networks5G...      128           15
# 3    Network Type5G, 4G, 3G, 2GSupported Networks5G...      128           15
# 4    Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...      128           16
# ..                                                 ...      ...          ...
# 417  Network Type3G, 4G, 2GSupported NetworksGSM, W...      128           14
# 418  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...      256           13
# 419  Network Type3G, 4G, 2GSupported NetworksGSM, W...       64           11
# 420  Network Type3G, 4G, 2GSupported NetworksGSM, W...      256           11
# 421  Network Type3G, 4G, 2GSupported NetworksGSM, W...       64           11
#
#                                       processor
# 0                      A15 Bionic ChipProcessor
# 1                      A15 Bionic ChipProcessor
# 2                      A15 Bionic ChipProcessor
# 3                      A15 Bionic ChipProcessor
# 4    A15 Bionic Chip, 6 Core ProcessorProcessor
# ..                                          ...
# 417                               not montioned
# 418                               not montioned
# 419                               not montioned
# 420                               not montioned
# 421                               not montioned
#
# [422 rows x 10 columns]

# %% [markdown]
# ## Processor

# %%
df['processor']
# Out:
# 0                        A15 Bionic ChipProcessor
# 1                        A15 Bionic ChipProcessor
# 2                        A15 Bionic ChipProcessor
# 3                        A15 Bionic ChipProcessor
# 4      A15 Bionic Chip, 6 Core ProcessorProcessor
#                           ...
# 417                                 not montioned
# 418                                 not montioned
# 419                                 not montioned
# 420                                 not montioned
# 421                                 not montioned
# Name: processor, Length: 422, dtype: object

# %%
random_values('processor',10)
# Out:
# 292 : not montioned
# 161 : not montioned
# 108 : A15 Bionic ChipProcessor
# 68 : A16 Bionic Chip, 6 Core ProcessorProcessor
# 349 : not montioned
# 377 : not montioned
# 40 : not montioned
# 267 : not montioned
# 233 : not montioned
# 160 : A15 Bionic ChipProcessor

# %%
def processor_extract_dimensity(text):
    splitted_sentence = text.split()

    if 'Mediatek' and 'Dimensity' in splitted_sentence:
        pattern = r'(\d+)+[Processor]'
        string = ' '.join(splitted_sentence)
        match = re.search(pattern,string)
        if match == None:
            if 'Dimensity' == str(splitted_sentence[1]):
                return 'Dimensity'+str(splitted_sentence[2])
            else:
                return 'Dimensity'+str(splitted_sentence[1])
        else:
            find = re.findall(pattern,string)
            return 'Dimensity'+ ''.join(find)
    else:
        return text

# %%
df['processor'] = df['processor'].apply(processor_extract_dimensity)

# %%
for i in range(0,9):
    rand = np.random.randint(df.shape[0])
    txt = processor_extract_dimensity(df['processor'].iloc[rand])
    print(df['processor'].iloc[rand],f'::index -{rand}')
    print(txt)
    print()
# Out:
# not montioned ::index -300
# not montioned
#
# not montioned ::index -244
# not montioned
#
# A15 Bionic Chip, 6 Core ProcessorProcessor ::index -65
# A15 Bionic Chip, 6 Core ProcessorProcessor
#
# A15 Bionic ChipProcessor ::index -1
# A15 Bionic ChipProcessor
#
# not montioned ::index -139
# not montioned
#
# A16 Bionic Chip, 6 Core ProcessorProcessor ::index -61
# A16 Bionic Chip, 6 Core ProcessorProcessor
#
# not montioned ::index -19
# not montioned
#
# A15 Bionic ChipProcessor ::index -2
# A15 Bionic ChipProcessor
#
# not montioned ::index -417
# not montioned

# %%
def processor_extract_ios(text):
    splitted_sentence = text.split()
    pattern = r'^A\d*'
    search = re.search(pattern,' '.join(splitted_sentence))
    if search != None:
        match =re.findall(pattern,' '.join(splitted_sentence))
        return ' '.join(match)
    else:
        return 'otherProcessor'

# %%
for i in range(0,9):
    rand = np.random.randint(df.shape[0])
    txt = processor_extract_ios(df['processor'].iloc[rand])
    print(df['processor'].iloc[rand],f'::index -{rand}')
    print(txt)
    print()
# Out:
# A15 Bionic Chip, 6 Core ProcessorProcessor ::index -39
# A15
#
# not montioned ::index -360
# otherProcessor
#
# not montioned ::index -136
# otherProcessor
#
# not montioned ::index -41
# otherProcessor
#
# not montioned ::index -300
# otherProcessor
#
# not montioned ::index -405
# otherProcessor
#
# not montioned ::index -123
# otherProcessor
#
# not montioned ::index -343
# otherProcessor
#
# A9 Chip with 64-bit Architecture and M9 Motion Co-processorProcessor ::index -237
# A9

# %%
df['processor'] = df['processor'].apply(processor_extract_ios)

# %%
random_values('processor')
# Out:
# 413 : otherProcessor
# 241 : otherProcessor
# 214 : otherProcessor
# 359 : otherProcessor
# 176 : A16
# 129 : otherProcessor

# %%
df
# Out:
#                                              name  ratings  price
# 0                  APPLE iPhone 13 (Blue, 128 GB)      4.7   3537  \
# 1              APPLE iPhone 13 (Midnight, 128 GB)      4.7   3537
# 2             APPLE iPhone 13 (Starlight, 128 GB)      4.7   3537
# 3                  APPLE iPhone 13 (Pink, 128 GB)      4.7   3537
# 4              APPLE iPhone 14 (Midnight, 128 GB)      4.6   4463
# ..                                            ...      ...    ...
# 417              APPLE iPhone XR (Yellow, 128 GB)      4.6  23837
# 418  APPLE iPhone 11 Pro (Midnight Green, 256 GB)      4.6   9772
# 419                APPLE iPhone X (Silver, 64 GB)      4.6  26364
# 420           APPLE iPhone X (Space Gray, 256 GB)      4.6  24172
# 421            APPLE iPhone X (Space Gray, 64 GB)      4.6  26364
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/k...  \
# 1    https://rukminim2.flixcart.com/image/312/312/k...
# 2    https://rukminim2.flixcart.com/image/312/312/k...
# 3    https://rukminim2.flixcart.com/image/312/312/k...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 417  https://rukminim2.flixcart.com/image/312/312/k...
# 418  https://rukminim2.flixcart.com/image/312/312/k...
# 419  https://rukminim2.flixcart.com/image/312/312/j...
# 420  https://rukminim2.flixcart.com/image/312/312/j...
# 421  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                                 camera
# 0    Primary Camera AvailableYesPrimary Camera12MP ...  \
# 1    Primary Camera AvailableYesPrimary Camera12MP ...
# 2    Primary Camera AvailableYesPrimary Camera12MP ...
# 3    Primary Camera AvailableYesPrimary Camera12MP ...
# 4    Primary Camera AvailableYesPrimary Camera12MP ...
# ..                                                 ...
# 417  Primary Camera AvailableYesPrimary Camera12MP ...
# 418  Primary Camera AvailableYesPrimary Camera12MP ...
# 419  Primary Camera AvailableYesPrimary Camera12MP ...
# 420  Primary Camera AvailableYesPrimary Camera12MP ...
# 421  Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                                display
# 0    Display Size15.49 cm (6.1 inch)Resolution2532 ...  \
# 1    Display Size15.49 cm (6.1 inch)Resolution2532 ...
# 2    Display Size15.49 cm (6.1 inch)Resolution2532 ...
# 3    Display Size15.49 cm (6.1 inch)Resolution2532 ...
# 4    Display Size15.49 cm (6.1 inch)Resolution2532 ...
# ..                                                 ...
# 417  Display Size15.49 cm (6.1 inch)Resolution1792 ...
# 418  Display Size14.73 cm (5.8 inch)Resolution2436 ...
# 419  Display Size14.73 cm (5.8 inch)Resolution2436 ...
# 420  Display Size14.73 cm (5.8 inch)Resolution2436 ...
# 421  Display Size14.73 cm (5.8 inch)Resolution2436 ...
#
#                                                network  storage  ios_version
# 0    Network Type5G, 4G, 3G, 2GSupported Networks5G...      128           15  \
# 1    Network Type5G, 4G, 3G, 2GSupported Networks5G...      128           15
# 2    Network Type5G, 4G, 3G, 2GSupported Networks5G...      128           15
# 3    Network Type5G, 4G, 3G, 2GSupported Networks5G...      128           15
# 4    Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...      128           16
# ..                                                 ...      ...          ...
# 417  Network Type3G, 4G, 2GSupported NetworksGSM, W...      128           14
# 418  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...      256           13
# 419  Network Type3G, 4G, 2GSupported NetworksGSM, W...       64           11
# 420  Network Type3G, 4G, 2GSupported NetworksGSM, W...      256           11
# 421  Network Type3G, 4G, 2GSupported NetworksGSM, W...       64           11
#
#           processor
# 0               A15
# 1               A15
# 2               A15
# 3               A15
# 4               A15
# ..              ...
# 417  otherProcessor
# 418  otherProcessor
# 419  otherProcessor
# 420  otherProcessor
# 421  otherProcessor
#
# [422 rows x 10 columns]

# %% [markdown]
# ## Network
# I don't need in my project I will just drop.

# %%
df = df.drop(labels=['network'],axis=1)

# %% [markdown]
# ## Camera

# %%
def camera_extract(row):
    if isinstance(row, str):  # Check if row is a string
        row_splitted = row.split()
        pattern = r'\d+MP'
        words = ' '.join(row_splitted)
        find_cam = re.findall(pattern, words)
        return ' '.join(find_cam)
    else:
        return np.nan

# %%
df['camera'] = df['camera'].apply(camera_extract)
# df = df.drop('index',axis=1)

# %%
df
# Out:
#                                              name  ratings  price
# 0                  APPLE iPhone 13 (Blue, 128 GB)      4.7   3537  \
# 1              APPLE iPhone 13 (Midnight, 128 GB)      4.7   3537
# 2             APPLE iPhone 13 (Starlight, 128 GB)      4.7   3537
# 3                  APPLE iPhone 13 (Pink, 128 GB)      4.7   3537
# 4              APPLE iPhone 14 (Midnight, 128 GB)      4.6   4463
# ..                                            ...      ...    ...
# 417              APPLE iPhone XR (Yellow, 128 GB)      4.6  23837
# 418  APPLE iPhone 11 Pro (Midnight Green, 256 GB)      4.6   9772
# 419                APPLE iPhone X (Silver, 64 GB)      4.6  26364
# 420           APPLE iPhone X (Space Gray, 256 GB)      4.6  24172
# 421            APPLE iPhone X (Space Gray, 64 GB)      4.6  26364
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/k...  \
# 1    https://rukminim2.flixcart.com/image/312/312/k...
# 2    https://rukminim2.flixcart.com/image/312/312/k...
# 3    https://rukminim2.flixcart.com/image/312/312/k...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 417  https://rukminim2.flixcart.com/image/312/312/k...
# 418  https://rukminim2.flixcart.com/image/312/312/k...
# 419  https://rukminim2.flixcart.com/image/312/312/j...
# 420  https://rukminim2.flixcart.com/image/312/312/j...
# 421  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                  camera
# 0         12MP 12MP 12MP 63MP 12MP 12MP  \
# 1         12MP 12MP 12MP 63MP 12MP 12MP
# 2         12MP 12MP 12MP 63MP 12MP 12MP
# 3         12MP 12MP 12MP 63MP 12MP 12MP
# 4    12MP 12MP 12MP 12MP 63MP 12MP 12MP
# ..                                  ...
# 417                       12MP 63MP 7MP
# 418  12MP 12MP 12MP 12MP 64MP 12MP 12MP
# 419                  12MP 12MP 63MP 7MP
# 420                  12MP 12MP 63MP 7MP
# 421                  12MP 12MP 63MP 7MP
#
#                                                display  storage  ios_version
# 0    Display Size15.49 cm (6.1 inch)Resolution2532 ...      128           15  \
# 1    Display Size15.49 cm (6.1 inch)Resolution2532 ...      128           15
# 2    Display Size15.49 cm (6.1 inch)Resolution2532 ...      128           15
# 3    Display Size15.49 cm (6.1 inch)Resolution2532 ...      128           15
# 4    Display Size15.49 cm (6.1 inch)Resolution2532 ...      128           16
# ..                                                 ...      ...          ...
# 417  Display Size15.49 cm (6.1 inch)Resolution1792 ...      128           14
# 418  Display Size14.73 cm (5.8 inch)Resolution2436 ...      256           13
# 419  Display Size14.73 cm (5.8 inch)Resolution2436 ...       64           11
# 420  Display Size14.73 cm (5.8 inch)Resolution2436 ...      256           11
# 421  Display Size14.73 cm (5.8 inch)Resolution2436 ...       64           11
#
#           processor
# 0               A15
# 1               A15
# 2               A15
# 3               A15
# 4               A15
# ..              ...
# 417  otherProcessor
# 418  otherProcessor
# 419  otherProcessor
# 420  otherProcessor
# 421  otherProcessor
#
# [422 rows x 9 columns]

# %%
def camera(txt):
    lst = []
    splitted = txt.split()
    for i in splitted:
        make_int = i.replace('MP','')
        lst.append(int(make_int))
    return max(lst)

# %%
for i in range(0,9):
    rand = np.random.randint(df.shape[0])
    txt = camera(df['camera'].iloc[rand])
    print(df['camera'].iloc[rand],f'::index -{rand}')
    print(txt)
    print()
# Out:
# 12MP 12MP 12MP 12MP 64MP 12MP 12MP ::index -410
# 64
#
# 12MP 12MP 63MP 7MP ::index -136
# 63
#
# 64MP 32MP 8MP 64MP 32MP 8MP 32MP 32MP ::index -211
# 64
#
# 12MP 63MP 7MP ::index -333
# 63
#
# 8MP 2MP ::index -403
# 8
#
# 12MP 12MP 12MP 12MP 63MP 12MP 12MP ::index -15
# 63
#
# 12MP 63MP 7MP ::index -225
# 63
#
# 12MP 12MP 12MP 12MP 12MP ::index -318
# 12
#
# 12MP 63MP 7MP ::index -388
# 63

# %%
df['camera'] = df['camera'].apply(camera)

# %%
df
# Out:
#                                              name  ratings  price
# 0                  APPLE iPhone 13 (Blue, 128 GB)      4.7   3537  \
# 1              APPLE iPhone 13 (Midnight, 128 GB)      4.7   3537
# 2             APPLE iPhone 13 (Starlight, 128 GB)      4.7   3537
# 3                  APPLE iPhone 13 (Pink, 128 GB)      4.7   3537
# 4              APPLE iPhone 14 (Midnight, 128 GB)      4.6   4463
# ..                                            ...      ...    ...
# 417              APPLE iPhone XR (Yellow, 128 GB)      4.6  23837
# 418  APPLE iPhone 11 Pro (Midnight Green, 256 GB)      4.6   9772
# 419                APPLE iPhone X (Silver, 64 GB)      4.6  26364
# 420           APPLE iPhone X (Space Gray, 256 GB)      4.6  24172
# 421            APPLE iPhone X (Space Gray, 64 GB)      4.6  26364
#
#                                                 imgURL  camera      display
# 0    https://rukminim2.flixcart.com/image/312/312/k...      63         OLED  \
# 1    https://rukminim2.flixcart.com/image/312/312/k...      63         OLED
# 2    https://rukminim2.flixcart.com/image/312/312/k...      63         OLED
# 3    https://rukminim2.flixcart.com/image/312/312/k...      63         OLED
# 4    https://rukminim2.flixcart.com/image/312/312/x...      63  other_types
# ..                                                 ...     ...          ...
# 417  https://rukminim2.flixcart.com/image/312/312/k...      63      IPS LCD
# 418  https://rukminim2.flixcart.com/image/312/312/k...      64  other_types
# 419  https://rukminim2.flixcart.com/image/312/312/j...      63         OLED
# 420  https://rukminim2.flixcart.com/image/312/312/j...      63         OLED
# 421  https://rukminim2.flixcart.com/image/312/312/j...      63         OLED
#
#      storage  ios_version       processor
# 0        128           15             A15
# 1        128           15             A15
# 2        128           15             A15
# 3        128           15             A15
# 4        128           16             A15
# ..       ...          ...             ...
# 417      128           14  otherProcessor
# 418      256           13  otherProcessor
# 419       64           11  otherProcessor
# 420      256           11  otherProcessor
# 421       64           11  otherProcessor
#
# [422 rows x 9 columns]

# %%
random_values('camera')
# Out:
# 1 : 63
# 270 : 12
# 223 : 12
# 383 : 8
# 63 : 63
# 181 : 12

# %% [markdown]
# ## display

# %%
random_values('display')
# Out:
# 411 : Display Size15.49 cm (6.1 inch)Resolution1792 x 828 pixelsGPUApple-designed GPU - 4-core, Graphics Performance - Upto 50% Faster than A11 Bionic, Metal 2 Optimised, 3D, Graphics-intensive Gameplay, Faster and More FluidDisplay TypeAll-screen LCD Multi-touch Display with IPS TechnologyHD Game SupportYesOther Display Features1400:1 Contrast Ratio (Typical), True Tone Display (Six-channel Light Sensor), Wide Colour Display (P3), 625 nits Maximum Brightness (Typical), Fingerprint-resistant Oleophobic Coating, Support for Display of Multiple Languages and Characters Simultaneously, Liquid Retina HD Display, Tap to Wake, Wide Colour Gamut,
# 361 : Display Size11.94 cm (4.7 inch)Resolution1334 x 750 PixelsResolution TypeRetina HD DisplayDisplay TypeLED-backlit IPSOther Display FeaturesMulti-touch Display, 1400:1 Contrast Ratio, Wide Color Display (P3), 625 cd/m2 Maximum Brightness, Dual Domain Pixels for Wide Viewing Angles, Fingerprint Resistant Oleophobic Coating, Display of Multiple Languages and Characters Simultaneously, Display Zoom, Reachability
# 168 : Display Size13.72 cm (5.4 inch)Resolution2340 x 1080 PixelsResolution TypeSuper Retina XDR DisplayDisplay TypeSuper Retina XDR DisplayOther Display FeaturesSuper Retina XDR Display, 5.4‑inch (Diagonal) All‑screen OLED Display, HDR Display, True Tone, Wide Colour (P3), Haptic Touch, 20,00,000:1 Contrast Ratio (Typical), 800 nits max Brightness (Typical), 1,200 nits max Brightness (HDR), Fingerprint-resistant Oleophobic Coating, Support for Display of Multiple Languages and Characters Simultaneously
# 224 : Display Size13.72 cm (5.4 inch)Resolution2340 x 1080 PixelsResolution TypeSuper Retina XDR DisplayDisplay TypeSuper Retina XDR DisplayOther Display FeaturesSuper Retina XDR Display, 5.4 inch (Diagonal) All Screen OLED Display, HDR Display, True Tone, Wide Colour (P3), Haptic Touch, 2000000:1 Contrast Ratio (Typical), 625 nits Max Brightness (Typical), 1200 nits Max Brightness (HDR), Fingerprint-resistant Oleophobic Coating, Support for Display of Multiple Languages and Characters Simultaneously
# 148 : Display Size11.94 cm (4.7 inch)Resolution1334 x 750 PixelsResolution TypeRetina HD DisplayGPU4 CoreDisplay TypeRetina HD LCD DisplayOther Display FeaturesWidescreen LCD Multi Touch Display with IPS Technology, Contrast Ratio: 1400:1, True Tone Display, Wide Color Display (P3), Max Brightness: 625 nits, Display Zoom
# 186 : Display Size13.72 cm (5.4 inch)Resolution2340 x 1080 PixelsResolution TypeSuper Retina XDR DisplayDisplay TypeSuper Retina XDR DisplayOther Display FeaturesSuper Retina XDR Display, 5.4 inch (Diagonal) All Screen OLED Display, HDR Display, True Tone, Wide Colour (P3), Haptic Touch, 2000000:1 Contrast Ratio (Typical), 625 nits Max Brightness (Typical), 1200 nits Max Brightness (HDR), Fingerprint-resistant Oleophobic Coating, Support for Display of Multiple Languages and Characters Simultaneously

# %%
def display_extract(row):
    split_row = row.split()
    if 'LCD' in split_row:
        if 'IPS' in split_row and 'LCD' in split_row:
            return 'IPS LCD'
        return 'LCD'
    
    if 'OLED' in split_row:
        return 'OLED'
    
    if 'TFT' in split_row:
        return 'TFT'
    
    if 'LED' in split_row:
        return 'LED'

    # if 'Adreno' in split_row:
    #     return 'Adreno'
    if 'AMOLED' in split_row:
        if 'HD+' in split_row and 'AMOLED' in split_row:
            return 'HD+ AMOLED'
        return 'AMOLED'
    
    return 'other_types'

# %%
random_values('display')
# Out:
# 58 : Display Size15.49 cm (6.1 inch)Resolution1792 x 828 PixelsResolution TypeLiquid Retina HD DisplayDisplay TypeLiquid Retina HDHD Game SupportYesOther Display Features1400:1 Contrast Ratio (Typical), True Tone Display, Wide Colour Display (P3), Haptic Touch, 625 nits Max Brightness (Typical), Fingerprint Resistant Oleophobic Coating, Support for Display of Multiple Languages and Characters Simultaneously
# 314 : Display Size11.94 cm (4.7 inch)Resolution1334 x 750 PixelsResolution TypeRetina HD DisplayDisplay TypeLED-backlit IPSOther Display FeaturesMulti-touch Display, 1400:1 Contrast Ratio, Wide Color Display (P3), 625 cd/m2 Maximum Brightness, Dual Domain Pixels for Wide Viewing Angles, Fingerprint Resistant Oleophobic Coating, Display of Multiple Languages and Characters Simultaneously, Display Zoom, Reachability
# 104 : Display Size15.49 cm (6.1 inch)Resolution2532 x 1170 PixelsResolution TypeSuper Retina XDR DisplayDisplay TypeSuper Retina XDR DisplayOther Display FeaturesSuper Retina XDR Display, 6.1‑inch (Diagonal) All‑screen OLED Display, ProMotion Technology with Adaptive Refresh Rates up to 120Hz, HDR Display, True Tone, Wide Colour (P3), Haptic Touch, 20,00,000:1 Contrast Ratio (Typical), 1000 nits max Brightness (Typical), 1,200 nits max Brightness (HDR), Fingerprint-resistant Oleophobic Coating, Support for Display of Multiple Languages and Characters Simultaneously
# 350 : Display Size17.02 cm (6.7 inch)Resolution2412 x 1080 PixelsResolution TypeFull HD+GPUARM Mali G68 MC4Display TypeFull HD+ AMOLED DisplayDisplay Colors1.07 BillionOther Display Features120 Hz 3D Curved Display, Aspect Ratio: 20:9, HDR10+, Ultra Narrow Bazel, 240Hz Touch Sampling Rate, Brightness: 500nits
# 384 : Display Size17.02 cm (6.7 inch)Resolution2778 x 1284 PixelsResolution TypeSuper Retina XDR DisplayDisplay TypeSuper Retina XDR DisplayOther Display FeaturesSuper Retina XDR Display, 6.7 inch (Diagonal) All Screen OLED Display, HDR Display, True Tone, Wide Colour, Haptic Touch, 2000000:1 Contrast Ratio (Typical), 800 nits Max Brightness (Typical); 1200 nits Max Brightness (HDR), Fingerprint-resistant Oleophobic Coating, Support for Display of Multiple Languages and Characters Simultaneously
# 413 : Display Size11.94 cm (4.7 inch)Resolution1334 x 750 PixelsResolution TypeRetina HD DisplayDisplay TypeLED-backlit IPSOther Display FeaturesMulti-touch Display, 1400:1 Contrast Ratio, Wide Color Display (P3), 625 cd/m2 Maximum Brightness, Dual Domain Pixels for Wide Viewing Angles, Fingerprint Resistant Oleophobic Coating, Display of Multiple Languages and Characters Simultaneously, Display Zoom, Reachability

# %%
df['display'] = df['display'].apply(display_extract)

# %%
df
# Out:
#                                              name  ratings  price
# 0                  APPLE iPhone 13 (Blue, 128 GB)      4.7   3537  \
# 1              APPLE iPhone 13 (Midnight, 128 GB)      4.7   3537
# 2             APPLE iPhone 13 (Starlight, 128 GB)      4.7   3537
# 3                  APPLE iPhone 13 (Pink, 128 GB)      4.7   3537
# 4              APPLE iPhone 14 (Midnight, 128 GB)      4.6   4463
# ..                                            ...      ...    ...
# 417              APPLE iPhone XR (Yellow, 128 GB)      4.6  23837
# 418  APPLE iPhone 11 Pro (Midnight Green, 256 GB)      4.6   9772
# 419                APPLE iPhone X (Silver, 64 GB)      4.6  26364
# 420           APPLE iPhone X (Space Gray, 256 GB)      4.6  24172
# 421            APPLE iPhone X (Space Gray, 64 GB)      4.6  26364
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/k...  \
# 1    https://rukminim2.flixcart.com/image/312/312/k...
# 2    https://rukminim2.flixcart.com/image/312/312/k...
# 3    https://rukminim2.flixcart.com/image/312/312/k...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 417  https://rukminim2.flixcart.com/image/312/312/k...
# 418  https://rukminim2.flixcart.com/image/312/312/k...
# 419  https://rukminim2.flixcart.com/image/312/312/j...
# 420  https://rukminim2.flixcart.com/image/312/312/j...
# 421  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                  camera      display  storage  ios_version
# 0         12MP 12MP 12MP 63MP 12MP 12MP         OLED      128           15  \
# 1         12MP 12MP 12MP 63MP 12MP 12MP         OLED      128           15
# 2         12MP 12MP 12MP 63MP 12MP 12MP         OLED      128           15
# 3         12MP 12MP 12MP 63MP 12MP 12MP         OLED      128           15
# 4    12MP 12MP 12MP 12MP 63MP 12MP 12MP  other_types      128           16
# ..                                  ...          ...      ...          ...
# 417                       12MP 63MP 7MP      IPS LCD      128           14
# 418  12MP 12MP 12MP 12MP 64MP 12MP 12MP  other_types      256           13
# 419                  12MP 12MP 63MP 7MP         OLED       64           11
# 420                  12MP 12MP 63MP 7MP         OLED      256           11
# 421                  12MP 12MP 63MP 7MP         OLED       64           11
#
#           processor
# 0               A15
# 1               A15
# 2               A15
# 3               A15
# 4               A15
# ..              ...
# 417  otherProcessor
# 418  otherProcessor
# 419  otherProcessor
# 420  otherProcessor
# 421  otherProcessor
#
# [422 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 422 entries, 0 to 421
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         422 non-null    object
#  1   ratings      422 non-null    float64
#  2   price        422 non-null    Int16
#  3   imgURL       422 non-null    object
#  4   camera       422 non-null    int64
#  5   display      422 non-null    object
#  6   storage      422 non-null    Int16
#  7   ios_version  422 non-null    Int16
#  8   processor    422 non-null    object
# dtypes: Int16(3), float64(1), int64(1), object(4)
# memory usage: 23.6+ KB

# %%
for i in df.columns:
    if df[i].dtype == 'int64':
        df[i] = df[i].astype('int16')
    elif df[i].dtype == 'float64':
        df[i] = df[i].astype('float16')

    else:
        pass

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 422 entries, 0 to 421
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         422 non-null    object
#  1   ratings      422 non-null    float16
#  2   price        422 non-null    Int16
#  3   imgURL       422 non-null    object
#  4   camera       422 non-null    int16
#  5   display      422 non-null    object
#  6   storage      422 non-null    Int16
#  7   ios_version  422 non-null    Int16
#  8   processor    422 non-null    object
# dtypes: Int16(3), float16(1), int16(1), object(4)
# memory usage: 18.7+ KB

# %%
df.isnull().sum()
# Out:
# name           0
# ratings        0
# price          0
# imgURL         0
# camera         0
# display        0
# storage        0
# ios_version    0
# processor      0
# dtype: int64
