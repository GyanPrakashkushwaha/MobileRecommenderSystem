# %%
import pandas as pd
import os
import numpy as np
from ensure import ensure_annotations
import re
import warnings
warnings.filterwarnings('ignore')

# %%
print(os.getcwd())
os.chdir(r'd:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem')
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem\notebook\experiments
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem

# %%
df = pd.read_csv(r'data\raw_data\oppo_mobile_data.csv',index_col=None)

# %%
df.drop_duplicates(inplace=True,ignore_index=True)

# %%
df
# Out:
#                                             name  ratings    price
# 0                        OPPO A17k (Blue, 64 GB)      4.5   ₹9,499  \
# 1                    OPPO A17 (Lake Blue, 64 GB)      4.4  ₹12,200
# 2               OPPO A17 (Midnight Black, 64 GB)      4.4  ₹12,499
# 3            OPPO A78 5G (Glowing Black, 128 GB)      4.3  ₹18,142
# 4                    OPPO A17 (Lake Blue, 64 GB)      4.4  ₹12,499
# ..                                           ...      ...      ...
# 248                       OPPO A5s (Gold, 64 GB)      4.3  ₹15,990
# 249  OPPO Reno7 Pro 5G (Startrails Blue, 256 GB)      4.4  ₹34,999
# 250                        OPPO A5s (Red, 32 GB)      4.3  ₹13,990
# 251               OPPO A15S (Fancy White, 64 GB)      4.4  ₹11,309
# 252                OPPO A7 (Glaring Gold, 64 GB)      NaN  ₹16,990
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 248  https://rukminim2.flixcart.com/image/312/312/k...
# 249  https://rukminim2.flixcart.com/image/312/312/k...
# 250  https://rukminim2.flixcart.com/image/312/312/k...
# 251  https://rukminim2.flixcart.com/image/312/312/k...
# 252  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                            storage_ram
# 0    Internal Storage64 GBRAM3 GBExpandable Storage...  \
# 1    Internal Storage64 GBRAM4 GBMemory Card Slot T...
# 2    Internal Storage64 GBRAM4 GBExpandable Storage...
# 3    Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 4    Internal Storage64 GBRAM4 GBExpandable Storage...
# ..                                                 ...
# 248  Internal Storage64 GBRAM4 GBExpandable Storage...
# 249  Internal Storage256 GBRAM12 GBExpandable Stora...
# 250  Internal Storage32 GBRAM3 GBExpandable Storage...
# 251  Internal Storage64 GBRAM4 GBMemory Card Slot T...
# 252  Internal Storage64 GBRAM3 GBExpandable Storage...
#
#                                                 camera
# 0    Operating SystemAndroid 12Processor TypeMediat...  \
# 1    Operating SystemAndroid Q 12Processor TypeMedi...
# 2    Operating SystemAndroid 12Processor TypeMediat...
# 3    Operating SystemAndroidProcessor CoreOcta Core...
# 4    Operating SystemAndroid 12Processor TypeMediat...
# ..                                                 ...
# 248  Operating SystemAndroid Oreo 8.1Processor Type...
# 249  Operating SystemAndroid 11Processor TypeMediaT...
# 250  Operating SystemAndroid Oreo 8.1Processor Type...
# 251  Operating SystemAndroid Q 10.0Processor CoreOc...
# 252  Operating SystemAndroid Oreo 8.1Processor Type...
#
#                                           oS_Processor
# 0    Primary Camera AvailableYesPrimary Camera8MP R...  \
# 1    Primary Camera AvailableYesPrimary Camera50MP ...
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
# 3    Primary Camera13MP Rear CameraDual Camera Lens...
# 4    Primary Camera AvailableYesPrimary Camera50MP ...
# ..                                                 ...
# 248  Primary Camera AvailableYesPrimary Camera13MP ...
# 249  Primary Camera AvailableYesPrimary Camera50MP ...
# 250  Primary Camera AvailableYesPrimary Camera13MP ...
# 251  Primary Camera13MP Rear CameraDual Camera Lens...
# 252  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                                display
# 0    Display Size16.66 cm (6.56 inch)Resolution1612...  \
# 1    Display Size16.66 cm (6.56 inch)Resolution1612...
# 2    Display Size16.66 cm (6.56 inch)Resolution1612...
# 3    Display Size16.66 cm (6.56 inch)Resolution720 ...
# 4    Display Size16.66 cm (6.56 inch)Resolution1612...
# ..                                                 ...
# 248  Display Size15.75 cm (6.2 inch)Resolution1520 ...
# 249  Display Size16.51 cm (6.5 inch)Resolution2400 ...
# 250  Display Size15.75 cm (6.2 inch)Resolution1520 ...
# 251  Display Size16.56 cm (6.52 inch)Resolution720 ...
# 252  Display Size15.75 cm (6.2 inch)Resolution1520 ...
#
#                                                network
# 0    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 1    Network Type4G VOLTE, 4G, 3GSupported Networks...
# 2    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 3                   Network Type5GSupported Networks5G
# 4    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# ..                                                 ...
# 248  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
# 249  Network Type5G, 4G VOLTESupported Networks5G, ...
# 250  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
# 251  Network Type4G VOLTE, 3GSupported Networks4G V...
# 252  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
#
#                                      battery
# 0                   Battery Capacity5000 mAh
# 1                   Battery Capacity5000 mAh
# 2                   Battery Capacity5000 mAh
# 3                   Battery Capacity5000 mAh
# 4                   Battery Capacity5000 mAh
# ..                                       ...
# 248  Battery Capacity4230 mAhTalk Time50 hrs
# 249                 Battery Capacity4500 mAh
# 250  Battery Capacity4230 mAhTalk Time50 hrs
# 251                 Battery Capacity4230 mAh
# 252  Battery Capacity4230 mAhTalk Time32 hrs
#
# [253 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# name            0
# ratings         8
# price           0
# imgURL          0
# storage_ram     0
# camera          1
# oS_Processor    0
# display         0
# network         0
# battery         0
# dtype: int64

# %%
df[df['ratings'].isnull() == True]
# Out:
#                                   name  ratings    price
# 46        OPPO A16 (Pearl Blue, 64 GB)      NaN  ₹13,390  \
# 47     OPPO A16 (Crystal Black, 64 GB)      NaN  ₹13,480
# 159              OPPO F7 (Red, 128 GB)      NaN  ₹27,990
# 183      OPPO Reno (JET BLACK, 128 GB)      NaN  ₹39,990
# 204  OPPO F17 (Dynamic Orange, 128 GB)      NaN  ₹20,990
# 205             OPPO F3 (Black, 64 GB)      NaN  ₹20,990
# 228    OPPO F11 (Marble Green, 128 GB)      NaN  ₹23,990
# 252      OPPO A7 (Glaring Gold, 64 GB)      NaN  ₹16,990
#
#                                                 imgURL
# 46   https://rukminim2.flixcart.com/image/312/312/k...  \
# 47   https://rukminim2.flixcart.com/image/312/312/k...
# 159  https://rukminim2.flixcart.com/image/312/312/j...
# 183  https://rukminim2.flixcart.com/image/312/312/k...
# 204  https://rukminim2.flixcart.com/image/312/312/k...
# 205  https://rukminim2.flixcart.com/image/312/312/j...
# 228  https://rukminim2.flixcart.com/image/312/312/k...
# 252  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                            storage_ram
# 46   Internal Storage64 GBRAM4 GBSupported Memory C...  \
# 47   Internal Storage64 GBRAM4 GBSupported Memory C...
# 159  Internal Storage128 GBRAM6 GBExpandable Storag...
# 183  Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 204  Internal Storage128 GBRAM6 GBMemory Card Slot ...
# 205  Internal Storage64 GBRAM4 GBExpandable Storage...
# 228  Internal Storage128 GBRAM6 GBExpandable Storag...
# 252  Internal Storage64 GBRAM3 GBExpandable Storage...
#
#                                                 camera
# 46   Operating SystemAndroid 11Processor TypeMediaT...  \
# 47   Operating SystemAndroid 11Processor TypeMediaT...
# 159  Operating SystemAndroid Oreo 8.1.0Processor Ty...
# 183                                                NaN
# 204  Operating SystemAndroid 10Processor TypeQualco...
# 205  Operating SystemAndroid Marshmallow 6Processor...
# 228  Operating SystemAndroid Pie 9Processor TypeMTK...
# 252  Operating SystemAndroid Oreo 8.1Processor Type...
#
#                                           oS_Processor
# 46   Primary Camera AvailableYesPrimary Camera13MP ...  \
# 47   Primary Camera AvailableYesPrimary Camera13MP ...
# 159  Primary Camera AvailableYesPrimary Camera16MP ...
# 183  Primary Camera48MP Rear CameraDual Camera Lens...
# 204  Primary Camera AvailableYesPrimary Camera16MP ...
# 205  Primary Camera AvailableYesPrimary Camera13MP ...
# 228  Primary Camera AvailableYesPrimary Camera48MP ...
# 252  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                                display
# 46   Display Size16.56 cm (6.52 inch)Resolution720 ...  \
# 47   Display Size16.56 cm (6.52 inch)Resolution720 ...
# 159  Display Size15.82 cm (6.23 inch)Resolution2280...
# 183  Display Size16.26 cm (6.4 inch)Resolution1440 ...
# 204  Display Size16.36 cm (6.44 inch)Resolution2400...
# 205  Display Size13.97 cm (5.5 inch)Resolution1920 ...
# 228  Display Size16.59 cm (6.53 inch)Resolution1080...
# 252  Display Size15.75 cm (6.2 inch)Resolution1520 ...
#
#                                                network
# 46   Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 47   Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 159  Network Type3G, 4G, 2GSupported NetworksGSM, W...
# 183    Network Type3G, 4GSupported NetworksGSM, 4G LTE
# 204  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 205  Network Type3G, 4G, 2GSupported NetworksWCDMA,...
# 228  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
# 252  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
#
#                                             battery
# 46                         Battery Capacity5000 mAh
# 47                         Battery Capacity5000 mAh
# 159                        Battery Capacity3400 mAh
# 183                        Battery Capacity3765 mAh
# 204                        Battery Capacity4015 mAh
# 205                        Battery Capacity3200 mAh
# 228  Battery Capacity4020 mAhBattery TypeLi-polymer
# 252         Battery Capacity4230 mAhTalk Time32 hrs

# %%
df['ratings'][46] = 4.3
df['ratings'][47] = 4.3
df['ratings'][159] = 4.5
df['ratings'][183] = 4.1
df['ratings'][204] = 4.3
df['ratings'][205] = 4.3
df['ratings'][228] = 4.4
df['ratings'][252] = 4.4
# df['os_processor'][181] = 'Operating SystemAndroid Pie Android v9.0 (Pie)Processor CoreOcta CorePrimary Clock Speed0.1 MHz'

# %%
df
# Out:
#                                             name  ratings    price
# 0                        OPPO A17k (Blue, 64 GB)      4.5   ₹9,499  \
# 1                    OPPO A17 (Lake Blue, 64 GB)      4.4  ₹12,200
# 2               OPPO A17 (Midnight Black, 64 GB)      4.4  ₹12,499
# 3            OPPO A78 5G (Glowing Black, 128 GB)      4.3  ₹18,142
# 4                    OPPO A17 (Lake Blue, 64 GB)      4.4  ₹12,499
# ..                                           ...      ...      ...
# 248                       OPPO A5s (Gold, 64 GB)      4.3  ₹15,990
# 249  OPPO Reno7 Pro 5G (Startrails Blue, 256 GB)      4.4  ₹34,999
# 250                        OPPO A5s (Red, 32 GB)      4.3  ₹13,990
# 251               OPPO A15S (Fancy White, 64 GB)      4.4  ₹11,309
# 252                OPPO A7 (Glaring Gold, 64 GB)      4.4  ₹16,990
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 248  https://rukminim2.flixcart.com/image/312/312/k...
# 249  https://rukminim2.flixcart.com/image/312/312/k...
# 250  https://rukminim2.flixcart.com/image/312/312/k...
# 251  https://rukminim2.flixcart.com/image/312/312/k...
# 252  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                            storage_ram
# 0    Internal Storage64 GBRAM3 GBExpandable Storage...  \
# 1    Internal Storage64 GBRAM4 GBMemory Card Slot T...
# 2    Internal Storage64 GBRAM4 GBExpandable Storage...
# 3    Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 4    Internal Storage64 GBRAM4 GBExpandable Storage...
# ..                                                 ...
# 248  Internal Storage64 GBRAM4 GBExpandable Storage...
# 249  Internal Storage256 GBRAM12 GBExpandable Stora...
# 250  Internal Storage32 GBRAM3 GBExpandable Storage...
# 251  Internal Storage64 GBRAM4 GBMemory Card Slot T...
# 252  Internal Storage64 GBRAM3 GBExpandable Storage...
#
#                                                 camera
# 0    Operating SystemAndroid 12Processor TypeMediat...  \
# 1    Operating SystemAndroid Q 12Processor TypeMedi...
# 2    Operating SystemAndroid 12Processor TypeMediat...
# 3    Operating SystemAndroidProcessor CoreOcta Core...
# 4    Operating SystemAndroid 12Processor TypeMediat...
# ..                                                 ...
# 248  Operating SystemAndroid Oreo 8.1Processor Type...
# 249  Operating SystemAndroid 11Processor TypeMediaT...
# 250  Operating SystemAndroid Oreo 8.1Processor Type...
# 251  Operating SystemAndroid Q 10.0Processor CoreOc...
# 252  Operating SystemAndroid Oreo 8.1Processor Type...
#
#                                           oS_Processor
# 0    Primary Camera AvailableYesPrimary Camera8MP R...  \
# 1    Primary Camera AvailableYesPrimary Camera50MP ...
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
# 3    Primary Camera13MP Rear CameraDual Camera Lens...
# 4    Primary Camera AvailableYesPrimary Camera50MP ...
# ..                                                 ...
# 248  Primary Camera AvailableYesPrimary Camera13MP ...
# 249  Primary Camera AvailableYesPrimary Camera50MP ...
# 250  Primary Camera AvailableYesPrimary Camera13MP ...
# 251  Primary Camera13MP Rear CameraDual Camera Lens...
# 252  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                                display
# 0    Display Size16.66 cm (6.56 inch)Resolution1612...  \
# 1    Display Size16.66 cm (6.56 inch)Resolution1612...
# 2    Display Size16.66 cm (6.56 inch)Resolution1612...
# 3    Display Size16.66 cm (6.56 inch)Resolution720 ...
# 4    Display Size16.66 cm (6.56 inch)Resolution1612...
# ..                                                 ...
# 248  Display Size15.75 cm (6.2 inch)Resolution1520 ...
# 249  Display Size16.51 cm (6.5 inch)Resolution2400 ...
# 250  Display Size15.75 cm (6.2 inch)Resolution1520 ...
# 251  Display Size16.56 cm (6.52 inch)Resolution720 ...
# 252  Display Size15.75 cm (6.2 inch)Resolution1520 ...
#
#                                                network
# 0    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 1    Network Type4G VOLTE, 4G, 3GSupported Networks...
# 2    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 3                   Network Type5GSupported Networks5G
# 4    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# ..                                                 ...
# 248  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
# 249  Network Type5G, 4G VOLTESupported Networks5G, ...
# 250  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
# 251  Network Type4G VOLTE, 3GSupported Networks4G V...
# 252  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
#
#                                      battery
# 0                   Battery Capacity5000 mAh
# 1                   Battery Capacity5000 mAh
# 2                   Battery Capacity5000 mAh
# 3                   Battery Capacity5000 mAh
# 4                   Battery Capacity5000 mAh
# ..                                       ...
# 248  Battery Capacity4230 mAhTalk Time50 hrs
# 249                 Battery Capacity4500 mAh
# 250  Battery Capacity4230 mAhTalk Time50 hrs
# 251                 Battery Capacity4230 mAh
# 252  Battery Capacity4230 mAhTalk Time32 hrs
#
# [253 rows x 10 columns]

# %%
df[df['ratings'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [name, ratings, price, imgURL, storage_ram, camera, oS_Processor, display, network, battery]
# Index: []

# %%
@ensure_annotations
def random_values(feature_name=['price','name','display'],total=6):
    for i in range(0,total):
        index = np.random.randint(df.shape[0])
        print(index,':',df[feature_name].iloc[index])

# %%
df # I am camera in oS_Processor and oS_Processor in camera so going to swap two
# Out:
#                                             name  ratings    price
# 0                        OPPO A17k (Blue, 64 GB)      4.5   ₹9,499  \
# 1                    OPPO A17 (Lake Blue, 64 GB)      4.4  ₹12,200
# 2               OPPO A17 (Midnight Black, 64 GB)      4.4  ₹12,499
# 3            OPPO A78 5G (Glowing Black, 128 GB)      4.3  ₹18,142
# 4                    OPPO A17 (Lake Blue, 64 GB)      4.4  ₹12,499
# ..                                           ...      ...      ...
# 248                       OPPO A5s (Gold, 64 GB)      4.3  ₹15,990
# 249  OPPO Reno7 Pro 5G (Startrails Blue, 256 GB)      4.4  ₹34,999
# 250                        OPPO A5s (Red, 32 GB)      4.3  ₹13,990
# 251               OPPO A15S (Fancy White, 64 GB)      4.4  ₹11,309
# 252                OPPO A7 (Glaring Gold, 64 GB)      4.4  ₹16,990
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 248  https://rukminim2.flixcart.com/image/312/312/k...
# 249  https://rukminim2.flixcart.com/image/312/312/k...
# 250  https://rukminim2.flixcart.com/image/312/312/k...
# 251  https://rukminim2.flixcart.com/image/312/312/k...
# 252  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                            storage_ram
# 0    Internal Storage64 GBRAM3 GBExpandable Storage...  \
# 1    Internal Storage64 GBRAM4 GBMemory Card Slot T...
# 2    Internal Storage64 GBRAM4 GBExpandable Storage...
# 3    Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 4    Internal Storage64 GBRAM4 GBExpandable Storage...
# ..                                                 ...
# 248  Internal Storage64 GBRAM4 GBExpandable Storage...
# 249  Internal Storage256 GBRAM12 GBExpandable Stora...
# 250  Internal Storage32 GBRAM3 GBExpandable Storage...
# 251  Internal Storage64 GBRAM4 GBMemory Card Slot T...
# 252  Internal Storage64 GBRAM3 GBExpandable Storage...
#
#                                                 camera
# 0    Operating SystemAndroid 12Processor TypeMediat...  \
# 1    Operating SystemAndroid Q 12Processor TypeMedi...
# 2    Operating SystemAndroid 12Processor TypeMediat...
# 3    Operating SystemAndroidProcessor CoreOcta Core...
# 4    Operating SystemAndroid 12Processor TypeMediat...
# ..                                                 ...
# 248  Operating SystemAndroid Oreo 8.1Processor Type...
# 249  Operating SystemAndroid 11Processor TypeMediaT...
# 250  Operating SystemAndroid Oreo 8.1Processor Type...
# 251  Operating SystemAndroid Q 10.0Processor CoreOc...
# 252  Operating SystemAndroid Oreo 8.1Processor Type...
#
#                                           oS_Processor
# 0    Primary Camera AvailableYesPrimary Camera8MP R...  \
# 1    Primary Camera AvailableYesPrimary Camera50MP ...
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
# 3    Primary Camera13MP Rear CameraDual Camera Lens...
# 4    Primary Camera AvailableYesPrimary Camera50MP ...
# ..                                                 ...
# 248  Primary Camera AvailableYesPrimary Camera13MP ...
# 249  Primary Camera AvailableYesPrimary Camera50MP ...
# 250  Primary Camera AvailableYesPrimary Camera13MP ...
# 251  Primary Camera13MP Rear CameraDual Camera Lens...
# 252  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                                display
# 0    Display Size16.66 cm (6.56 inch)Resolution1612...  \
# 1    Display Size16.66 cm (6.56 inch)Resolution1612...
# 2    Display Size16.66 cm (6.56 inch)Resolution1612...
# 3    Display Size16.66 cm (6.56 inch)Resolution720 ...
# 4    Display Size16.66 cm (6.56 inch)Resolution1612...
# ..                                                 ...
# 248  Display Size15.75 cm (6.2 inch)Resolution1520 ...
# 249  Display Size16.51 cm (6.5 inch)Resolution2400 ...
# 250  Display Size15.75 cm (6.2 inch)Resolution1520 ...
# 251  Display Size16.56 cm (6.52 inch)Resolution720 ...
# 252  Display Size15.75 cm (6.2 inch)Resolution1520 ...
#
#                                                network
# 0    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 1    Network Type4G VOLTE, 4G, 3GSupported Networks...
# 2    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 3                   Network Type5GSupported Networks5G
# 4    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# ..                                                 ...
# 248  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
# 249  Network Type5G, 4G VOLTESupported Networks5G, ...
# 250  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
# 251  Network Type4G VOLTE, 3GSupported Networks4G V...
# 252  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
#
#                                      battery
# 0                   Battery Capacity5000 mAh
# 1                   Battery Capacity5000 mAh
# 2                   Battery Capacity5000 mAh
# 3                   Battery Capacity5000 mAh
# 4                   Battery Capacity5000 mAh
# ..                                       ...
# 248  Battery Capacity4230 mAhTalk Time50 hrs
# 249                 Battery Capacity4500 mAh
# 250  Battery Capacity4230 mAhTalk Time50 hrs
# 251                 Battery Capacity4230 mAh
# 252  Battery Capacity4230 mAhTalk Time32 hrs
#
# [253 rows x 10 columns]

# %%
df.rename({'camera':'os_processor','oS_Processor':'camera'},axis=1,inplace=True)

# %%
df
# Out:
#                                             name  ratings    price
# 0                        OPPO A17k (Blue, 64 GB)      4.5   ₹9,499  \
# 1                    OPPO A17 (Lake Blue, 64 GB)      4.4  ₹12,200
# 2               OPPO A17 (Midnight Black, 64 GB)      4.4  ₹12,499
# 3            OPPO A78 5G (Glowing Black, 128 GB)      4.3  ₹18,142
# 4                    OPPO A17 (Lake Blue, 64 GB)      4.4  ₹12,499
# ..                                           ...      ...      ...
# 248                       OPPO A5s (Gold, 64 GB)      4.3  ₹15,990
# 249  OPPO Reno7 Pro 5G (Startrails Blue, 256 GB)      4.4  ₹34,999
# 250                        OPPO A5s (Red, 32 GB)      4.3  ₹13,990
# 251               OPPO A15S (Fancy White, 64 GB)      4.4  ₹11,309
# 252                OPPO A7 (Glaring Gold, 64 GB)      4.4  ₹16,990
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 248  https://rukminim2.flixcart.com/image/312/312/k...
# 249  https://rukminim2.flixcart.com/image/312/312/k...
# 250  https://rukminim2.flixcart.com/image/312/312/k...
# 251  https://rukminim2.flixcart.com/image/312/312/k...
# 252  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                            storage_ram
# 0    Internal Storage64 GBRAM3 GBExpandable Storage...  \
# 1    Internal Storage64 GBRAM4 GBMemory Card Slot T...
# 2    Internal Storage64 GBRAM4 GBExpandable Storage...
# 3    Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 4    Internal Storage64 GBRAM4 GBExpandable Storage...
# ..                                                 ...
# 248  Internal Storage64 GBRAM4 GBExpandable Storage...
# 249  Internal Storage256 GBRAM12 GBExpandable Stora...
# 250  Internal Storage32 GBRAM3 GBExpandable Storage...
# 251  Internal Storage64 GBRAM4 GBMemory Card Slot T...
# 252  Internal Storage64 GBRAM3 GBExpandable Storage...
#
#                                           os_processor
# 0    Operating SystemAndroid 12Processor TypeMediat...  \
# 1    Operating SystemAndroid Q 12Processor TypeMedi...
# 2    Operating SystemAndroid 12Processor TypeMediat...
# 3    Operating SystemAndroidProcessor CoreOcta Core...
# 4    Operating SystemAndroid 12Processor TypeMediat...
# ..                                                 ...
# 248  Operating SystemAndroid Oreo 8.1Processor Type...
# 249  Operating SystemAndroid 11Processor TypeMediaT...
# 250  Operating SystemAndroid Oreo 8.1Processor Type...
# 251  Operating SystemAndroid Q 10.0Processor CoreOc...
# 252  Operating SystemAndroid Oreo 8.1Processor Type...
#
#                                                 camera
# 0    Primary Camera AvailableYesPrimary Camera8MP R...  \
# 1    Primary Camera AvailableYesPrimary Camera50MP ...
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
# 3    Primary Camera13MP Rear CameraDual Camera Lens...
# 4    Primary Camera AvailableYesPrimary Camera50MP ...
# ..                                                 ...
# 248  Primary Camera AvailableYesPrimary Camera13MP ...
# 249  Primary Camera AvailableYesPrimary Camera50MP ...
# 250  Primary Camera AvailableYesPrimary Camera13MP ...
# 251  Primary Camera13MP Rear CameraDual Camera Lens...
# 252  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                                display
# 0    Display Size16.66 cm (6.56 inch)Resolution1612...  \
# 1    Display Size16.66 cm (6.56 inch)Resolution1612...
# 2    Display Size16.66 cm (6.56 inch)Resolution1612...
# 3    Display Size16.66 cm (6.56 inch)Resolution720 ...
# 4    Display Size16.66 cm (6.56 inch)Resolution1612...
# ..                                                 ...
# 248  Display Size15.75 cm (6.2 inch)Resolution1520 ...
# 249  Display Size16.51 cm (6.5 inch)Resolution2400 ...
# 250  Display Size15.75 cm (6.2 inch)Resolution1520 ...
# 251  Display Size16.56 cm (6.52 inch)Resolution720 ...
# 252  Display Size15.75 cm (6.2 inch)Resolution1520 ...
#
#                                                network
# 0    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 1    Network Type4G VOLTE, 4G, 3GSupported Networks...
# 2    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 3                   Network Type5GSupported Networks5G
# 4    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# ..                                                 ...
# 248  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
# 249  Network Type5G, 4G VOLTESupported Networks5G, ...
# 250  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
# 251  Network Type4G VOLTE, 3GSupported Networks4G V...
# 252  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
#
#                                      battery
# 0                   Battery Capacity5000 mAh
# 1                   Battery Capacity5000 mAh
# 2                   Battery Capacity5000 mAh
# 3                   Battery Capacity5000 mAh
# 4                   Battery Capacity5000 mAh
# ..                                       ...
# 248  Battery Capacity4230 mAhTalk Time50 hrs
# 249                 Battery Capacity4500 mAh
# 250  Battery Capacity4230 mAhTalk Time50 hrs
# 251                 Battery Capacity4230 mAh
# 252  Battery Capacity4230 mAhTalk Time32 hrs
#
# [253 rows x 10 columns]

# %%
df.to_csv(r'data\cleaned_dataset\vivo_cleaned_data.csv',index=True)

# %% [markdown]
# ## Price

# %%
df.reset_index(inplace=True)
for Index,i in enumerate(df['price']):
    i = str(i).replace('₹','')
    i = str(i).replace(',','')
    df['price'][Index] = i

# %%
df['price'] = df['price'].astype('Int16')

# %%
df['price'] = df['price'].abs() # this is to remove the negative values from price feature

# %%
random_values('price')
# Out:
# 88 : 21990
# 195 : 15498
# 157 : 12990
# 169 : 8590
# 169 : 8590
# 81 : 29990

# %% [markdown]
# ## Ratings

# %%
df['ratings'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Ram

# %%
df[df['price'] <= 6000]
# Out:
#      index                                name  ratings  price
# 163    163                   GREENBERRI RAFALE      4.4    899  \
# 170    170           OPPO Neo 5 (White, 16 GB)      4.4   4999
# 226    226  OPPO Find X (Glacier Blue, 256 GB)      4.4   4546
#
#                                                 imgURL
# 163  https://rukminim2.flixcart.com/image/312/312/x...  \
# 170  https://rukminim2.flixcart.com/image/312/312/m...
# 226  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                            storage_ram
# 163  Internal Storage32 MBRAM32 MBMemory Card Slot ...  \
# 170                       Internal Storage16 GBRAM1 GB
# 226  Internal Storage256 GBRAM8 GBMemory Card Slot ...
#
#                                           os_processor
# 163  Operating SystemAndroid 12Processor TypeMediat...  \
# 170  Operating SystemAndroid 10Processor TypeQualco...
# 226  Operating SystemAndroid Oreo 8.1.0Processor Ty...
#
#                                                 camera
# 163                      Primary Camera2MP Rear Camera  \
# 170                      Primary Camera8MP Rear Camera
# 226  Primary Camera AvailableYesPrimary Camera16MP ...
#
#                                                display
# 163  Display Size4.57 cm (1.8 inch)Resolution320 X ...  \
# 170  Display Size11.43 cm (4.5 inch)Resolution480 x...
# 226  Display Size16.26 cm (6.4 inch)Resolution2340 ...
#
#                                                network
# 163                Network Type2GSupported NetworksGSM  \
# 170               Network Type3GSupported NetworksUMTS
# 226  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
#
#                                             battery
# 163          Battery Capacity1000 mAhDual BatteryNo
# 170                        Battery Capacity2000 mAh
# 226  Battery Capacity3730 mAhBattery TypeLi-polymer

# %%
## removing these mobilphones

# %%
df = df.drop(index=df[df['price'] <= 6000].index)

# %%
def extract_ram(row):
    ram = row.split()[2]
    return ram

df['ram'] = df['storage_ram'].apply(func=extract_ram)

# %%
import warnings
warnings.filterwarnings('ignore')
df.reset_index(inplace=True)
count = 0
for i in range(0,len(df['ram'])):
    # df['ram'][i]= df['ram'].iloc[i].replace('MBRAM','')
    df['ram'][i]= df['ram'].iloc[i].replace('GBRAM','')
    count+=1
print(f'looped till {count} index')
# Out:
# looped till 250 index

# %%
random_values('ram',9)
# Out:
# 212 : 3
# 143 : 6
# 200 : 8
# 160 : 4
# 144 : 6
# 25 : 6
# 218 : 8
# 127 : 8
# 218 : 8

# %%
df['ram'] = df['ram'].astype('Int16')

# %% [markdown]
# ## storage

# %%
def extract_storage(row):
    storage = row.split()[1]
    return storage


df['storage'] = df['storage_ram'].apply(func=extract_storage)

# %%
df = df.drop(columns=['level_0','index'])

# %%
import warnings
warnings.filterwarnings('ignore')
df.reset_index(inplace=True)
count = 0
for i in range(0,len(df['storage'])):
    df['storage'][i]= df['storage'].iloc[i].replace('Storage','')
    count+=1
print(f'looped till {count} index')
# Out:
# looped till 250 index

# %%
df['storage'] = df['storage'].astype('Int16')
## Removing storage_ram
df = df.drop(columns=['storage_ram','index'])

# %%
random_values('storage')
# Out:
# 189 : 128
# 4 : 64
# 239 : 16
# 244 : 64
# 67 : 256
# 174 : 64

# %% [markdown]
# ## Android Version

# %%
def extract_processor(text):
    pattern = r'.*Processor'
    match = re.findall(pattern, text)
    if match:
        return match[0]
    else:
        return text

# %%
df
# Out:
#                                             name  ratings  price
# 0                        OPPO A17k (Blue, 64 GB)      4.5   9499  \
# 1                    OPPO A17 (Lake Blue, 64 GB)      4.4  12200
# 2               OPPO A17 (Midnight Black, 64 GB)      4.4  12499
# 3            OPPO A78 5G (Glowing Black, 128 GB)      4.3  18142
# 4                    OPPO A17 (Lake Blue, 64 GB)      4.4  12499
# ..                                           ...      ...    ...
# 245                       OPPO A5s (Gold, 64 GB)      4.3  15990
# 246  OPPO Reno7 Pro 5G (Startrails Blue, 256 GB)      4.4  30537
# 247                        OPPO A5s (Red, 32 GB)      4.3  13990
# 248               OPPO A15S (Fancy White, 64 GB)      4.4  11309
# 249                OPPO A7 (Glaring Gold, 64 GB)      4.4  16990
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 245  https://rukminim2.flixcart.com/image/312/312/k...
# 246  https://rukminim2.flixcart.com/image/312/312/k...
# 247  https://rukminim2.flixcart.com/image/312/312/k...
# 248  https://rukminim2.flixcart.com/image/312/312/k...
# 249  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                           os_processor
# 0    Operating SystemAndroid 12Processor TypeMediat...  \
# 1    Operating SystemAndroid Q 12Processor TypeMedi...
# 2    Operating SystemAndroid 12Processor TypeMediat...
# 3    Operating SystemAndroidProcessor CoreOcta Core...
# 4    Operating SystemAndroid 12Processor TypeMediat...
# ..                                                 ...
# 245  Operating SystemAndroid Oreo 8.1Processor Type...
# 246  Operating SystemAndroid 11Processor TypeMediaT...
# 247  Operating SystemAndroid Oreo 8.1Processor Type...
# 248  Operating SystemAndroid Q 10.0Processor CoreOc...
# 249  Operating SystemAndroid Oreo 8.1Processor Type...
#
#                                                 camera
# 0    Primary Camera AvailableYesPrimary Camera8MP R...  \
# 1    Primary Camera AvailableYesPrimary Camera50MP ...
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
# 3    Primary Camera13MP Rear CameraDual Camera Lens...
# 4    Primary Camera AvailableYesPrimary Camera50MP ...
# ..                                                 ...
# 245  Primary Camera AvailableYesPrimary Camera13MP ...
# 246  Primary Camera AvailableYesPrimary Camera50MP ...
# 247  Primary Camera AvailableYesPrimary Camera13MP ...
# 248  Primary Camera13MP Rear CameraDual Camera Lens...
# 249  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                                display
# 0    Display Size16.66 cm (6.56 inch)Resolution1612...  \
# 1    Display Size16.66 cm (6.56 inch)Resolution1612...
# 2    Display Size16.66 cm (6.56 inch)Resolution1612...
# 3    Display Size16.66 cm (6.56 inch)Resolution720 ...
# 4    Display Size16.66 cm (6.56 inch)Resolution1612...
# ..                                                 ...
# 245  Display Size15.75 cm (6.2 inch)Resolution1520 ...
# 246  Display Size16.51 cm (6.5 inch)Resolution2400 ...
# 247  Display Size15.75 cm (6.2 inch)Resolution1520 ...
# 248  Display Size16.56 cm (6.52 inch)Resolution720 ...
# 249  Display Size15.75 cm (6.2 inch)Resolution1520 ...
#
#                                                network
# 0    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 1    Network Type4G VOLTE, 4G, 3GSupported Networks...
# 2    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 3                   Network Type5GSupported Networks5G
# 4    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# ..                                                 ...
# 245  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
# 246  Network Type5G, 4G VOLTESupported Networks5G, ...
# 247  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
# 248  Network Type4G VOLTE, 3GSupported Networks4G V...
# 249  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
#
#                                      battery  ram  storage
# 0                   Battery Capacity5000 mAh    3       64
# 1                   Battery Capacity5000 mAh    4       64
# 2                   Battery Capacity5000 mAh    4       64
# 3                   Battery Capacity5000 mAh    8      128
# 4                   Battery Capacity5000 mAh    4       64
# ..                                       ...  ...      ...
# 245  Battery Capacity4230 mAhTalk Time50 hrs    4       64
# 246                 Battery Capacity4500 mAh   12      256
# 247  Battery Capacity4230 mAhTalk Time50 hrs    3       32
# 248                 Battery Capacity4230 mAh    4       64
# 249  Battery Capacity4230 mAhTalk Time32 hrs    3       64
#
# [250 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          250 non-null    object
#  1   ratings       250 non-null    float64
#  2   price         250 non-null    Int16
#  3   imgURL        250 non-null    object
#  4   os_processor  249 non-null    object
#  5   camera        250 non-null    object
#  6   display       250 non-null    object
#  7   network       250 non-null    object
#  8   battery       250 non-null    object
#  9   ram           250 non-null    Int16
#  10  storage       250 non-null    Int16
# dtypes: Int16(3), float64(1), object(7)
# memory usage: 18.0+ KB

# %%
df[df['os_processor'].isnull() == True]
# Out:
#                               name  ratings  price
# 181  OPPO Reno (JET BLACK, 128 GB)      4.1  25546  \
#
#                                                 imgURL os_processor
# 181  https://rukminim2.flixcart.com/image/312/312/k...          NaN  \
#
#                                                 camera
# 181  Primary Camera48MP Rear CameraDual Camera Lens...  \
#
#                                                display
# 181  Display Size16.26 cm (6.4 inch)Resolution1440 ...  \
#
#                                              network
# 181  Network Type3G, 4GSupported NetworksGSM, 4G LTE  \
#
#                       battery  ram  storage
# 181  Battery Capacity3765 mAh    8      128

# %%
df['os_processor'][181] = 'Operating SystemAndroid Pie Android v9.0 (Pie)Processor CoreOcta CorePrimary Clock Speed0.1 MHz'

# %%
random_values('os_processor')
# Out:
# 140 : Operating SystemAndroid 10Processor TypeQualcomm Snapdragon 460Processor CoreOcta CorePrimary Clock Speed1.8 GHzSecondary Clock Speed1.6 GHzOperating FrequencyGSM: 850/900/1800/1900, WCDMA: B1/B5/B8, 4G FDD LTE: B1/B3/B5/B8, 4G TDD LTE: B38/B40/B41 (2535 - 2655 MHz)
# 249 : Operating SystemAndroid Oreo 8.1Processor TypeQualcomm Snapdragon 450Processor CoreOcta CorePrimary Clock Speed1.8 GHzOperating FrequencyGSM: 850/900/1800/1900 MHz, WCDMA: Bands 1/5/8, FDD-LTE: Bands 1/3/5/8, TD-LTE: Bands 38/40/41, Note B41: 2535 - 2655 MHz
# 193 : Operating SystemAndroid Q Android 12Processor TypeMediatek Helio G35Processor CoreOcta CorePrimary Clock Speed2.3 MHzSecondary Clock Speed2.3 GHzTertiary Clock Speed1.8 GHzOperating Frequency2G GSM: 850/900/1800/1900, 3G UMTS (WCDMA): B1/B5/B8, 4G TD LTE: B38/B40/B41, 4G LTE FDD: B1/B3/B5/B8
# 235 : Operating SystemAndroid 11Processor TypeMediaTek Dimensity 1200Processor CoreOcta CorePrimary Clock Speed3 GHzOperating Frequency2G GSM: 850/900/1800/1900 MHz, 3G UMTS (WCDMA): Bands 1/2/4/5/6/8/19, 4G TD-LTE: Bands 38/39/40/41 (194 MHz), 4G LTE FDD: Bands 1/2/3/4/5/7/8/12/17/18/19/20/26/28, 5G: n1/n3/n5/n7/n8/n28/n38/n40/n41/n77/n78
# 90 : Operating SystemAndroid 13 (Tiramisu)Primary Clock Speed1.2 GHz
# 13 : Operating SystemAndroid 12Processor TypeMediatek Helio G35Processor CoreOcta CorePrimary Clock Speed2.4 GHzSecondary Clock Speed2 GHz

# %%
df['os_processor'] = df['os_processor'].apply(extract_processor)

# %%
random_values('os_processor')
# Out:
# 27 : Operating SystemAndroid 10Processor TypeMediaTek Helio P35 (MT6765)Processor
# 190 : Operating SystemAndroid Pie android version 10Processor
# 149 : Operating SystemAndroid Lollipop 5.1.1Processor TypeMediatek MT6755 or MTK7650Processor
# 13 : Operating SystemAndroid 12Processor TypeMediatek Helio G35Processor
# 89 : Operating SystemAndroid 10Processor TypeQualcomm Snapdragon 662Processor
# 239 : Operating SystemAndroid Lollipop Color OS 3.0 based on Android 5.1Processor TypeQualcomm Snapdragon 410 Quad Core 1.2GHzProcessor

# %%
# df.to_csv(r'data\cleaned_dataset\vivo_cleaned_data.csv',index=True)

# %%
random_values('os_processor',10)
# Out:
# 45 : Operating SystemAndroid 13Processor TypeMediatek Dimensity 9000+Processor
# 183 : Operating SystemAndroid 10Processor TypeQualcomm Snapdragon 460Processor
# 186 : Operating SystemAndroid Nougat 7.1Processor TypeMediatek MT6763T Octa Core 2.5 GHzProcessor
# 34 : Operating SystemAndroid Q AndroidProcessor TypeMediaTek Dimensity 700Processor
# 50 : Operating SystemAndroid 11Processor TypeMediaTek Helio G35Processor
# 183 : Operating SystemAndroid 10Processor TypeQualcomm Snapdragon 460Processor
# 99 : Operating SystemAndroid Oreo 8.1Processor TypeMediaTek Helio P35Processor
# 16 : Operating SystemAndroid 11Processor TypeMediaTek Helio G35Processor
# 221 : Operating SystemAndroid Pie 9Processor TypeMediaTek Helio P70 Octa Core 2.1 GHzProcessor
# 11 : Operating SystemAndroid 12Processor TypeMediatek Helio P35Processor

# %%
df
# Out:
#                                             name  ratings  price
# 0                        OPPO A17k (Blue, 64 GB)      4.5   9499  \
# 1                    OPPO A17 (Lake Blue, 64 GB)      4.4  12200
# 2               OPPO A17 (Midnight Black, 64 GB)      4.4  12499
# 3            OPPO A78 5G (Glowing Black, 128 GB)      4.3  18142
# 4                    OPPO A17 (Lake Blue, 64 GB)      4.4  12499
# ..                                           ...      ...    ...
# 245                       OPPO A5s (Gold, 64 GB)      4.3  15990
# 246  OPPO Reno7 Pro 5G (Startrails Blue, 256 GB)      4.4  30537
# 247                        OPPO A5s (Red, 32 GB)      4.3  13990
# 248               OPPO A15S (Fancy White, 64 GB)      4.4  11309
# 249                OPPO A7 (Glaring Gold, 64 GB)      4.4  16990
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 245  https://rukminim2.flixcart.com/image/312/312/k...
# 246  https://rukminim2.flixcart.com/image/312/312/k...
# 247  https://rukminim2.flixcart.com/image/312/312/k...
# 248  https://rukminim2.flixcart.com/image/312/312/k...
# 249  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                           os_processor
# 0    Operating SystemAndroid 12Processor TypeMediat...  \
# 1    Operating SystemAndroid Q 12Processor TypeMedi...
# 2    Operating SystemAndroid 12Processor TypeMediat...
# 3                     Operating SystemAndroidProcessor
# 4    Operating SystemAndroid 12Processor TypeMediat...
# ..                                                 ...
# 245  Operating SystemAndroid Oreo 8.1Processor Type...
# 246  Operating SystemAndroid 11Processor TypeMediaT...
# 247  Operating SystemAndroid Oreo 8.1Processor Type...
# 248            Operating SystemAndroid Q 10.0Processor
# 249  Operating SystemAndroid Oreo 8.1Processor Type...
#
#                                                 camera
# 0    Primary Camera AvailableYesPrimary Camera8MP R...  \
# 1    Primary Camera AvailableYesPrimary Camera50MP ...
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
# 3    Primary Camera13MP Rear CameraDual Camera Lens...
# 4    Primary Camera AvailableYesPrimary Camera50MP ...
# ..                                                 ...
# 245  Primary Camera AvailableYesPrimary Camera13MP ...
# 246  Primary Camera AvailableYesPrimary Camera50MP ...
# 247  Primary Camera AvailableYesPrimary Camera13MP ...
# 248  Primary Camera13MP Rear CameraDual Camera Lens...
# 249  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                                display
# 0    Display Size16.66 cm (6.56 inch)Resolution1612...  \
# 1    Display Size16.66 cm (6.56 inch)Resolution1612...
# 2    Display Size16.66 cm (6.56 inch)Resolution1612...
# 3    Display Size16.66 cm (6.56 inch)Resolution720 ...
# 4    Display Size16.66 cm (6.56 inch)Resolution1612...
# ..                                                 ...
# 245  Display Size15.75 cm (6.2 inch)Resolution1520 ...
# 246  Display Size16.51 cm (6.5 inch)Resolution2400 ...
# 247  Display Size15.75 cm (6.2 inch)Resolution1520 ...
# 248  Display Size16.56 cm (6.52 inch)Resolution720 ...
# 249  Display Size15.75 cm (6.2 inch)Resolution1520 ...
#
#                                                network
# 0    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 1    Network Type4G VOLTE, 4G, 3GSupported Networks...
# 2    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 3                   Network Type5GSupported Networks5G
# 4    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# ..                                                 ...
# 245  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
# 246  Network Type5G, 4G VOLTESupported Networks5G, ...
# 247  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
# 248  Network Type4G VOLTE, 3GSupported Networks4G V...
# 249  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
#
#                                      battery  ram  storage
# 0                   Battery Capacity5000 mAh    3       64
# 1                   Battery Capacity5000 mAh    4       64
# 2                   Battery Capacity5000 mAh    4       64
# 3                   Battery Capacity5000 mAh    8      128
# 4                   Battery Capacity5000 mAh    4       64
# ..                                       ...  ...      ...
# 245  Battery Capacity4230 mAhTalk Time50 hrs    4       64
# 246                 Battery Capacity4500 mAh   12      256
# 247  Battery Capacity4230 mAhTalk Time50 hrs    3       32
# 248                 Battery Capacity4230 mAh    4       64
# 249  Battery Capacity4230 mAhTalk Time32 hrs    3       64
#
# [250 rows x 11 columns]

# %%
def android_version(text_):
    split = text_.split()
    if 'OxygenProcessor' in split:
        return 'OxygenProcessor'
    elif 'ANdroid' in split:
        return split[3]
    elif 'OxygenOSProcessor' in split:
        return 'OxygenOSProcessor'
    else:
        pattern=r'^\d+[Processor]|\d+[GProcessor]|\d++[.Processor]'
        found = re.findall(pattern,text_)
        if found:
            return found[0]
        else:
            return 'other androidVerion'

# %%
for i in range(0,9):
    rand = np.random.randint(df.shape[0])
    # print(rand)
    txt = android_version(df['os_processor'].iloc[rand])
    print(df['os_processor'].iloc[rand],f'::index -{rand}')
    print(txt)
    print()
# Out:
# Operating SystemAndroid Pie 9Processor TypeQualcomm Snapdragon 665Processor ::index -105
# 9P
#
# Operating SystemAndroid Pie 9Processor TypeMTK MT6771V (P70)Processor ::index -225
# 9P
#
# Operating SystemAndroid Pie 9.0Processor TypeMediaTek Helio P70Processor ::index -118
# 9.
#
# Operating SystemAndroid ColorOS 13.1 on top of Android 13Processor TypeQualcomm Snapdragon™ 695 (SDM 695)Processor ::index -62
# 13.
#
# Operating SystemAndroid 11Processor TypeMediatek Helio P22Processor ::index -29
# 11P
#
# Operating SystemAndroid 13Processor TypeSnapdragon 778G 5GProcessor ::index -64
# 13P
#
# Operating SystemAndroid Marshmallow 6Processor TypeMediatek MT6750T Octa Core 1.5 GHzProcessor ::index -161
# 6P
#
# Operating SystemAndroid 10Processor TypeQualcomm Snapdragon 460Processor ::index -120
# 10P
#
# Operating SystemAndroid Jelly Bean 4.2Processor ::index -191
# 4.

# %%
df['android_version'] = df['os_processor'].apply(android_version)

# %%
df.reset_index(inplace=True)
for Index,i in enumerate(df['android_version']):
    # print(i)
    i = str(i).replace('P','')
    i = str(i).replace('.','')
    df['android_version'][Index] = i

# %%
random_values('android_version')
# Out:
# 146 : 11
# 112 : 9
# 4 : 12
# 245 : 8
# 45 : 13
# 212 : 5

# %% [markdown]
# ## Processor

# %%
def processor(text):
    pattern=r'(?<=Type).*'
    search = re.search(pattern,text)
    if search != None:
        return ' '.join(re.findall(pattern,text))
    else:
        return 'not montioned'

# %%
random_values('os_processor')
# Out:
# 66 : Operating SystemAndroid 13Processor TypeSnapdragon 8+ Gen 1Processor
# 161 : Operating SystemAndroid Marshmallow 6Processor TypeMediatek MT6750T Octa Core 1.5 GHzProcessor
# 174 : Operating SystemAndroid 10Processor TypeQualcomm Snapdragon 460Processor
# 98 : Operating SystemAndroid Pie 9Processor TypeQualcomm Snapdragon 665Processor
# 45 : Operating SystemAndroid 13Processor TypeMediatek Dimensity 9000+Processor
# 13 : Operating SystemAndroid 12Processor TypeMediatek Helio G35Processor

# %%
df['processor'] = df['os_processor'].apply(processor)
df = df.drop('os_processor',axis=1)
df = df.drop('index',axis=1)

# %%
def processor_extract(text):
    splitted_sentence = text.split()
    if 'Mediatek' and 'Helio' in splitted_sentence:
        pattern = r'\d+[Processor]|\d+'
        string = ' '.join(splitted_sentence)
        match = re.search(pattern,string)
        if match == None:
            return 'Heilo'+str(splitted_sentence[2])
        else:
            find = re.findall(pattern,string)
            return 'Heilo'+''.join(find)


    elif 'Mediatek' and 'Dimensity' in splitted_sentence:
        pattern = r'(\d+)+[Processor]'
        string = ' '.join(splitted_sentence)
        match = re.search(pattern,string)
        if match == None:
            if 'Dimensity' == str(splitted_sentence[1]):
                return 'Dimensity'+str(splitted_sentence[2])
            else:
                return 'Dimensity'+str(splitted_sentence[1])
        
        else:
            find = re.findall(pattern,string)
            return 'Dimensity'+ ''.join(find)

    elif 'Snapdragon' and 'Gen' and '4' in splitted_sentence:
        return 'Gen4'   

    elif 'Snapdragon' and 'Gen' and '8' in splitted_sentence:         
        return 'Gen8'
    
    elif 'Unisoc' in splitted_sentence:
        
        if 'Unisoc' and 'Tiger' in splitted_sentence:
            pattern = r'[T]\d[Processor]'
            string = ' '.join(splitted_sentence)
            match = re.findall(pattern,string)
            return 'UnisocTiger' + ''.join(splitted_sentence[2])
        
        elif 'Unisoc' == splitted_sentence[0]:
            pattern = r'[T]\d.'
            string = ' '.join(splitted_sentence)
            match = re.findall(pattern,string)
            return 'Unisoc' + ''.join(splitted_sentence[1])

        
        pattern = r'T(\d+)Processor|\d+'
        string = ' '.join(splitted_sentence)
        match = re.findall(pattern,string)
        return 'Unisoc'+' '.join(match)
    

    elif 'Snapdragon' in splitted_sentence:
        pattern = r'\d+[Processor]'
        if 'Gen' and '4' and '8' not in splitted_sentence:
            string = ' '.join(splitted_sentence)
            match = re.search(pattern,string)
            if match == None:
                if 'Snapdragon' == str(splitted_sentence[1]):
                    return 'Snapdragon'+str(splitted_sentence[2])
                else:
                    return 'Snapdragon'+str(splitted_sentence[1])
            else:
                find = re.findall(pattern,string)
                return 'Snapdragon'+''.join(find)
    
    elif 'MediaTek' == splitted_sentence[0]:
        pattern = r'[P]\d.'
        string = ' '.join(splitted_sentence)
        match = re.findall(pattern,string)
        return 'MediaTek' + ' '.join(match)

    else:
        return 'not mentioned'

# %%
print(extract_processor(df['processor'][206]))
print(df['processor'][206])
# Out:
# MediaTek MT6582Processor
# MediaTek MT6582Processor

# %%
for i in range(0,9):
    rand = np.random.randint(df.shape[0])
    # print(rand)
    txt = processor_extract(df['processor'].iloc[rand])
    print(df['processor'].iloc[rand],f'::index -{rand}')
    print(txt)
    print()
# Out:
# MTK MT6771V (P70)Processor ::index -224
# not mentioned
#
# Qualcomm Snapdragon 662Processor ::index -150
# Snapdragon662P
#
# Mediatek Dimensity 900Processor ::index -35
# Dimensity900
#
# Mediatek Dimensity 900Processor ::index -35
# Dimensity900
#
# MediaTek Dimensity 1000+ (MT6889)Processor ::index -189
# Dimensity1000+
#
# Mediatek MT6750T Octa Core 1.5GHzProcessor ::index -203
# not mentioned
#
# Snapdragon 450 (MSM450) Octa Core 1.8 GHzProcessor ::index -187
# Snapdragon450
#
# MediaTek Dimensity 700Processor ::index -146
# Dimensity700
#
# Qualcomm Snapdragon 660 Octa Core 1.95 GHzProcessor ::index -234
# Snapdragon660

# %%
df['processor']=df['processor'].apply(processor_extract)

# %% [markdown]
# ## camera

# %%
def camera_extract(row):
    row_splitted = row.split()
    pattern = r'\d+MP'
    words = ' '.join(row_splitted)
    find_cam = re.findall(pattern,words)
    return ' '.join(find_cam)

# %%
df['camera'] = df['camera'].apply(camera_extract)

# %%
def camera(txt):
    lst = []
    splitted = txt.split()
    for i in splitted:
        make_int = i.replace('MP','')
        lst.append(int(make_int))
    return max(lst)

# %%
df['camera'] = df['camera'].apply(func=camera)
df['camera'] = df['camera'].astype('Int16')

# %%
random_values('camera')
# Out:
# 100 : 13
# 168 : 8
# 170 : 16
# 45 : 50
# 109 : 48
# 115 : 48

# %% [markdown]
# ## display

# %%
def display_extract(row):
    split_row = row.split()
    if 'LCD' in split_row:
        if 'IPS' in split_row and 'LCD' in split_row:
            return 'IPS LCD'
        return 'LCD'
    
    if 'OLED' in split_row:
        return 'OLED'
    
    if 'TFT' in split_row:
        return 'TFT'
    
    if 'LED' in split_row:
        return 'LED'

    # if 'Adreno' in split_row:
    #     return 'Adreno'
    if 'AMOLED' in split_row:
        if 'HD+' in split_row and 'AMOLED' in split_row:
            return 'HD+ AMOLED'
        return 'AMOLED'
    
    return 'other'

# %%
df['display'] = df['display'].apply(display_extract)

# %% [markdown]
# ## network

# %%
df = df.drop(columns=['network'])

# %% [markdown]
# ## battery

# %%
def extract_battery(row):
    return row.split()[1]

df['battery'] = df['battery'].apply(extract_battery)

# %%
df.reset_index(inplace=True)
count = 0
for i in range(0,len(df['battery'])):
    # print(i)
    df['battery'][i]= df['battery'].iloc[i].replace('Capacity','')
    # print(df['battery'][i])
    count+=1
print(f'looped till {count} index')
# Out:
# looped till 250 index

# %%
df['battery'] = df['battery'].astype('Int16')

# %%
df = df.drop(labels='index',axis=1)

# %%
df
# Out:
#                                             name  ratings  price
# 0                        OPPO A17k (Blue, 64 GB)      4.5   9499  \
# 1                    OPPO A17 (Lake Blue, 64 GB)      4.4  12200
# 2               OPPO A17 (Midnight Black, 64 GB)      4.4  12499
# 3            OPPO A78 5G (Glowing Black, 128 GB)      4.3  18142
# 4                    OPPO A17 (Lake Blue, 64 GB)      4.4  12499
# ..                                           ...      ...    ...
# 245                       OPPO A5s (Gold, 64 GB)      4.3  15990
# 246  OPPO Reno7 Pro 5G (Startrails Blue, 256 GB)      4.4  30537
# 247                        OPPO A5s (Red, 32 GB)      4.3  13990
# 248               OPPO A15S (Fancy White, 64 GB)      4.4  11309
# 249                OPPO A7 (Glaring Gold, 64 GB)      4.4  16990
#
#                                                 imgURL  camera     display
# 0    https://rukminim2.flixcart.com/image/312/312/x...       8       other  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...      50         LCD
# 2    https://rukminim2.flixcart.com/image/312/312/x...      50         LCD
# 3    https://rukminim2.flixcart.com/image/312/312/x...      13       other
# 4    https://rukminim2.flixcart.com/image/312/312/x...      50         LCD
# ..                                                 ...     ...         ...
# 245  https://rukminim2.flixcart.com/image/312/312/k...      13       other
# 246  https://rukminim2.flixcart.com/image/312/312/k...      50  HD+ AMOLED
# 247  https://rukminim2.flixcart.com/image/312/312/k...      13       other
# 248  https://rukminim2.flixcart.com/image/312/312/k...      13       other
# 249  https://rukminim2.flixcart.com/image/312/312/j...      16       other
#
#      battery  ram  storage      android_version                   processor
# 0       5000    3       64                   12                    Heilo35P
# 1       5000    4       64                   12                    Heilo35P
# 2       5000    4       64                   12                    Heilo35P
# 3       5000    8      128  other androidVerion               not mentioned
# 4       5000    4       64                   12                    Heilo35P
# ..       ...  ...      ...                  ...                         ...
# 245     4230    4       64                    8                    Heilo35P
# 246     4500   12      256                   11  Dimensity1200-MaxProcessor
# 247     4230    3       32                    8               not mentioned
# 248     4230    4       64                   10               not mentioned
# 249     4230    3       64                    8              Snapdragon450P
#
# [250 rows x 11 columns]

# %%
df.to_csv(r'data\cleaned_dataset\oppo_cleaned_data.csv',index=False)
