# %%
import pandas as pd
import os
import numpy as np
from ensure import ensure_annotations
import re
import warnings
warnings.filterwarnings('ignore')

# %%
print(os.getcwd())
print(os.chdir(r'd:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem'))
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem
# None
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem

# %%
df = pd.read_csv(r'data\raw_data\techno_mobile_data.csv',index_col=None)

# %%
df.isnull().sum()
# Out:
# name            0
# ratings         0
# price           1
# imgURL          0
# storage_ram     0
# camera          0
# oS_Processor    0
# display         0
# network         0
# battery         0
# dtype: int64

# %%
df
# Out:
#                                           name  ratings    price
# 0             Tecno Pova 3 (Eco Black, 128 GB)      4.1  ₹13,998  \
# 1      Tecno Pop 5 Pro (Deepsea Luster, 32 GB)      4.2   ₹6,960
# 2              Tecno Pova 3 (Eco Black, 64 GB)      4.2  ₹10,849
# 3            Tecno Pova 3 (Tech Silver, 64 GB)      4.2  ₹10,978
# 4    Tecno Spark Go 2023 (UYUNI BLUE, 32+3 GB)      4.1   ₹6,750
# ..                                         ...      ...      ...
# 147         Tecno Camon 15 (SHOAL GOLD, 64 GB)      4.2  ₹12,499
# 148           Tecno Camon 19 Neo (Green, 6 GB)      4.1  ₹18,490
# 149  Tecno Spark 10 Pro (Starry Black, 256 GB)      4.1  ₹14,999
# 150   Tecno Spark 10 Pro (Pearl White, 256 GB)      4.1  ₹14,999
# 151       Tecno Spark 10 pro (Meta Blue, 8 GB)      4.1  ₹13,999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/l...  \
# 1    https://rukminim2.flixcart.com/image/312/312/k...
# 2    https://rukminim2.flixcart.com/image/312/312/l...
# 3    https://rukminim2.flixcart.com/image/312/312/l...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 147  https://rukminim2.flixcart.com/image/312/312/k...
# 148  https://rukminim2.flixcart.com/image/312/312/x...
# 149  https://rukminim2.flixcart.com/image/312/312/x...
# 150  https://rukminim2.flixcart.com/image/312/312/x...
# 151  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 0    Internal Storage128 GBRAM6 GBExpandable Storag...  \
# 1    Internal Storage32 GBRAM3 GBExpandable Storage...
# 2    Internal Storage64 GBRAM4 GBExpandable Storage...
# 3    Internal Storage64 GBRAM4 GBExpandable Storage...
# 4    Internal Storage32+3 GBRAM3 GBMemory Card Slot...
# ..                                                 ...
# 147  Internal Storage64 GBRAM4 GBExpandable Storage...
# 148  Internal Storage6 GBRAM128 GBMemory Card Slot ...
# 149  Internal Storage256 GBRAM8 GBExpandable Storag...
# 150  Internal Storage256 GBRAM8 GBExpandable Storag...
# 151  Internal Storage8 GBRAM8 GBMemory Card Slot Ty...
#
#                                                 camera
# 0    Operating SystemAndroid 12Processor TypeMediaT...  \
# 1    Operating SystemAndroid 11 (Go Edition)Process...
# 2    Operating SystemAndroid 12Processor TypeMediaT...
# 3    Operating SystemAndroid 12Processor TypeMediaT...
# 4    Operating SystemAndroid 12Primary Clock Speed2...
# ..                                                 ...
# 147  Operating SystemAndroid 10Processor TypeHelio ...
# 148  Operating SystemAndroid Android 12Primary Cloc...
# 149  Operating SystemAndroid 13Processor TypeMediat...
# 150  Operating SystemAndroid 13Processor TypeMediat...
# 151  Operating SystemAndroid 13Primary Clock Speed2...
#
#                                           oS_Processor
# 0    Primary Camera AvailableYesPrimary Camera50MP ...  \
# 1    Primary Camera AvailableYesPrimary Camera8MP R...
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
# 3    Primary Camera AvailableYesPrimary Camera50MP ...
# 4    Primary Camera13MP Rear CameraDual Camera Lens...
# ..                                                 ...
# 147  Primary Camera AvailableYesPrimary Camera48MP ...
# 148  Primary Camera48MP Rear CameraDual Camera Lens...
# 149  Primary Camera AvailableYesPrimary Camera50MP ...
# 150  Primary Camera AvailableYesPrimary Camera50MP ...
# 151  Primary Camera50MP Rear CameraDual Camera Lens...
#
#                                                display
# 0    Display Size17.53 cm (6.9 inch)Resolution1080 ...  \
# 1    Display Size16.56 cm (6.52 inch)Resolution720 ...
# 2    Display Size17.53 cm (6.9 inch)Resolution1080 ...
# 3    Display Size17.53 cm (6.9 inch)Resolution1080 ...
# 4    Display Size16.66 cm (6.56 inch)Resolution720x...
# ..                                                 ...
# 147  Display Size16.64 cm (6.55 inch)Resolution720 ...
# 148  Display Size17.27 cm (6.8 inch)Resolution2460x...
# 149  Display Size17.22 cm (6.78 inch)Resolution2460...
# 150  Display Size17.22 cm (6.78 inch)Resolution2460...
# 151  Display Size17.27 cm (6.8 inch)Resolution1080 ...
#
#                                                network
# 0    Network Type4G VOLTE, 4GSupported Networks4G V...  \
# 1    Network Type4G VOLTE, 4GSupported Networks4G V...
# 2    Network Type4G VOLTE, 4GSupported Networks4G V...
# 3    Network Type4G VOLTE, 4GSupported Networks4G V...
# 4       Network Type4G VOLTESupported Networks4G VoLTE
# ..                                                 ...
# 147  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 148     Network Type2G, 3G, 4GSupported Networks4G LTE
# 149  Network Type4G VOLTE, 4GSupported Networks4G V...
# 150  Network Type4G VOLTE, 4GSupported Networks4G V...
# 151  Network Type4GSupported Networks4G LTE, GSM, W...
#
#                                                battery
# 0       Battery Capacity7000 mAhBattery TypeLi-Polymer
# 1            Battery Capacity6000 mAhBattery TypeLi-Po
# 2            Battery Capacity7000 mAhBattery TypeLi-Po
# 3            Battery Capacity7000 mAhBattery TypeLi-Po
# 4                             Battery Capacity5000 mAh
# ..                                                 ...
# 147                           Battery Capacity5000 mAh
# 148                           Battery Capacity5000 mAh
# 149          Battery Capacity5000 mAhBattery TypeLi-Po
# 150          Battery Capacity5000 mAhBattery TypeLi-Po
# 151  Battery Capacity5000 mAhBattery TypeNon-Remova...
#
# [152 rows x 10 columns]

# %%
df[df['ratings'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [name, ratings, price, imgURL, storage_ram, camera, oS_Processor, display, network, battery]
# Index: []

# %% [markdown]
# ## Filling NaN values manually

# %%
df['ratings'][92] = 4
df['ratings'][93] = 4.2
df['ratings'][94] = 4.5
df['ratings'][95] = 4
df['ratings'][151] = 4.1

## camera
df['camera'][95] = '64MP + 50MP + 2MP'

# %%
df[df['ratings'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [name, ratings, price, imgURL, storage_ram, camera, oS_Processor, display, network, battery]
# Index: []

# %%
df.to_csv(r'data\raw_data\techno_mobile_data.csv',index=False)

# %%
@ensure_annotations
def random_values(feature_name=['price','name','display'],total=6):
    for i in range(0,total):
        index = np.random.randint(df.shape[0])
        print(index,':',df[feature_name].iloc[index])

# %%
df.shape
# Out:
# (152, 10)

# %% [markdown]
# ## Price

# %%
df.reset_index(inplace=True)
for Index,i in enumerate(df['price']):
    i = str(i).replace('₹','')
    i = str(i).replace(',','')
    df['price'][Index] = i

# %%
(df['price']).isna() == True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 147    False
# 148    False
# 149    False
# 150    False
# 151    False
# Name: price, Length: 152, dtype: bool

# %%
df[df['price'] == np.nan]
# Out:
# Empty DataFrame
# Columns: [index, name, ratings, price, imgURL, storage_ram, camera, oS_Processor, display, network, battery]
# Index: []

# %%
df[df['price'] == 'nan']
# Out:
#     index                                   name  ratings price
# 95     95  Tecno Camon 19 Pro (Mondrian, 128 GB)      4.0   nan  \
#
#                                                imgURL
# 95  https://rukminim2.flixcart.com/image/312/312/x...  \
#
#                                           storage_ram             camera
# 95  Internal Storage128 GBRAM8 GBExpandable Storag...  64MP + 50MP + 2MP  \
#
#                                          oS_Processor
# 95  Primary Camera AvailableYesPrimary Camera64MP ...  \
#
#                                               display
# 95  Display Size17.27 cm (6.8 inch)Resolution1080 ...  \
#
#                                               network
# 95  Network Type4G VOLTE, 4GSupported Networks4G V...  \
#
#                                            battery
# 95  Battery Capacity5000 mAhBattery TypeLi-Polymer

# %%
## Filling manually the nan vlaue
df['price'][95] = '15999'

# %%
df[(df['price']).isna() == True]
# Out:
# Empty DataFrame
# Columns: [index, name, ratings, price, imgURL, storage_ram, camera, oS_Processor, display, network, battery]
# Index: []

# %%
random_values('price')
# Out:
# 11 : 14699
# 67 : 20349
# 144 : 8999
# 139 : 8290
# 2 : 10849
# 147 : 12499

# %%
df['price'] = df['price'].astype('Int16')

# %%
df['price'] = df['price'].abs() # this is to remove the negative values from price feature

# %%
df = df.drop(index=df[df['price'] <=6000].index) # droping the mobiles less than 6000

# %%
random_values('price')
# Out:
# 63 : 13810
# 16 : 7590
# 69 : 15999
# 93 : 10699
# 140 : 7999
# 140 : 7999

# %%
df.shape
# Out:
# (152, 11)

# %% [markdown]
# ## Ratings

# %%
df['ratings'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Ram

# %%
def extract_ram(row):
    ram = row.split()[2]
    return ram

df['ram'] = df['storage_ram'].apply(func=extract_ram)

# %%
import warnings
warnings.filterwarnings('ignore')
# df.reset_index(inplace=True)
count = 0
for i in range(0,len(df['ram'])):
    df['ram'][i]= df['ram'].iloc[i].replace('MBRAM','')
    df['ram'][i]= df['ram'].iloc[i].replace('GBRAM','')
    count+=1
print(f'looped till {count} index')
# Out:
# looped till 152 index

# %%
random_values('ram')
# Out:
# 148 : 128
# 130 : 3
# 72 : 8
# 103 : 4
# 43 : 8
# 23 : 3

# %%
df[df['ram'] ==  'MBRAM2']
# Out:
# Empty DataFrame
# Columns: [index, name, ratings, price, imgURL, storage_ram, camera, oS_Processor, display, network, battery, ram]
# Index: []

# %%
df['ram'] = df['ram'].astype('Int16')

# %%
df
# Out:
#      index                                       name  ratings  price
# 0        0           Tecno Pova 3 (Eco Black, 128 GB)      4.1  13998  \
# 1        1    Tecno Pop 5 Pro (Deepsea Luster, 32 GB)      4.2   6960
# 2        2            Tecno Pova 3 (Eco Black, 64 GB)      4.2  10849
# 3        3          Tecno Pova 3 (Tech Silver, 64 GB)      4.2  10978
# 4        4  Tecno Spark Go 2023 (UYUNI BLUE, 32+3 GB)      4.1   6750
# ..     ...                                        ...      ...    ...
# 147    147         Tecno Camon 15 (SHOAL GOLD, 64 GB)      4.2  12499
# 148    148           Tecno Camon 19 Neo (Green, 6 GB)      4.1  18490
# 149    149  Tecno Spark 10 Pro (Starry Black, 256 GB)      4.1  14999
# 150    150   Tecno Spark 10 Pro (Pearl White, 256 GB)      4.1  14999
# 151    151       Tecno Spark 10 pro (Meta Blue, 8 GB)      4.1  13999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/l...  \
# 1    https://rukminim2.flixcart.com/image/312/312/k...
# 2    https://rukminim2.flixcart.com/image/312/312/l...
# 3    https://rukminim2.flixcart.com/image/312/312/l...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 147  https://rukminim2.flixcart.com/image/312/312/k...
# 148  https://rukminim2.flixcart.com/image/312/312/x...
# 149  https://rukminim2.flixcart.com/image/312/312/x...
# 150  https://rukminim2.flixcart.com/image/312/312/x...
# 151  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 0    Internal Storage128 GBRAM6 GBExpandable Storag...  \
# 1    Internal Storage32 GBRAM3 GBExpandable Storage...
# 2    Internal Storage64 GBRAM4 GBExpandable Storage...
# 3    Internal Storage64 GBRAM4 GBExpandable Storage...
# 4    Internal Storage32+3 GBRAM3 GBMemory Card Slot...
# ..                                                 ...
# 147  Internal Storage64 GBRAM4 GBExpandable Storage...
# 148  Internal Storage6 GBRAM128 GBMemory Card Slot ...
# 149  Internal Storage256 GBRAM8 GBExpandable Storag...
# 150  Internal Storage256 GBRAM8 GBExpandable Storag...
# 151  Internal Storage8 GBRAM8 GBMemory Card Slot Ty...
#
#                                                 camera
# 0    Operating SystemAndroid 12Processor TypeMediaT...  \
# 1    Operating SystemAndroid 11 (Go Edition)Process...
# 2    Operating SystemAndroid 12Processor TypeMediaT...
# 3    Operating SystemAndroid 12Processor TypeMediaT...
# 4    Operating SystemAndroid 12Primary Clock Speed2...
# ..                                                 ...
# 147  Operating SystemAndroid 10Processor TypeHelio ...
# 148  Operating SystemAndroid Android 12Primary Cloc...
# 149  Operating SystemAndroid 13Processor TypeMediat...
# 150  Operating SystemAndroid 13Processor TypeMediat...
# 151  Operating SystemAndroid 13Primary Clock Speed2...
#
#                                           oS_Processor
# 0    Primary Camera AvailableYesPrimary Camera50MP ...  \
# 1    Primary Camera AvailableYesPrimary Camera8MP R...
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
# 3    Primary Camera AvailableYesPrimary Camera50MP ...
# 4    Primary Camera13MP Rear CameraDual Camera Lens...
# ..                                                 ...
# 147  Primary Camera AvailableYesPrimary Camera48MP ...
# 148  Primary Camera48MP Rear CameraDual Camera Lens...
# 149  Primary Camera AvailableYesPrimary Camera50MP ...
# 150  Primary Camera AvailableYesPrimary Camera50MP ...
# 151  Primary Camera50MP Rear CameraDual Camera Lens...
#
#                                                display
# 0    Display Size17.53 cm (6.9 inch)Resolution1080 ...  \
# 1    Display Size16.56 cm (6.52 inch)Resolution720 ...
# 2    Display Size17.53 cm (6.9 inch)Resolution1080 ...
# 3    Display Size17.53 cm (6.9 inch)Resolution1080 ...
# 4    Display Size16.66 cm (6.56 inch)Resolution720x...
# ..                                                 ...
# 147  Display Size16.64 cm (6.55 inch)Resolution720 ...
# 148  Display Size17.27 cm (6.8 inch)Resolution2460x...
# 149  Display Size17.22 cm (6.78 inch)Resolution2460...
# 150  Display Size17.22 cm (6.78 inch)Resolution2460...
# 151  Display Size17.27 cm (6.8 inch)Resolution1080 ...
#
#                                                network
# 0    Network Type4G VOLTE, 4GSupported Networks4G V...  \
# 1    Network Type4G VOLTE, 4GSupported Networks4G V...
# 2    Network Type4G VOLTE, 4GSupported Networks4G V...
# 3    Network Type4G VOLTE, 4GSupported Networks4G V...
# 4       Network Type4G VOLTESupported Networks4G VoLTE
# ..                                                 ...
# 147  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 148     Network Type2G, 3G, 4GSupported Networks4G LTE
# 149  Network Type4G VOLTE, 4GSupported Networks4G V...
# 150  Network Type4G VOLTE, 4GSupported Networks4G V...
# 151  Network Type4GSupported Networks4G LTE, GSM, W...
#
#                                                battery  ram
# 0       Battery Capacity7000 mAhBattery TypeLi-Polymer    6
# 1            Battery Capacity6000 mAhBattery TypeLi-Po    3
# 2            Battery Capacity7000 mAhBattery TypeLi-Po    4
# 3            Battery Capacity7000 mAhBattery TypeLi-Po    4
# 4                             Battery Capacity5000 mAh    3
# ..                                                 ...  ...
# 147                           Battery Capacity5000 mAh    4
# 148                           Battery Capacity5000 mAh  128
# 149          Battery Capacity5000 mAhBattery TypeLi-Po    8
# 150          Battery Capacity5000 mAhBattery TypeLi-Po    8
# 151  Battery Capacity5000 mAhBattery TypeNon-Remova...    8
#
# [152 rows x 12 columns]

# %%
# df = df.drop(columns=['level_0','index'])

# %% [markdown]
# ## storage

# %%
def extract_storage(row):
    storage = row.split()[1]
    return storage


df['storage'] = df['storage_ram'].apply(func=extract_storage)

# %%
df.columns
# Out:
# Index(['index', 'name', 'ratings', 'price', 'imgURL', 'storage_ram', 'camera',
#        'oS_Processor', 'display', 'network', 'battery', 'ram', 'storage'],
#       dtype='object')

# %%
import warnings
warnings.filterwarnings('ignore')
df.reset_index(inplace=True)
count = 0
for i in range(0,len(df['storage'])):
    df['storage'][i]= df['storage'].iloc[i].replace('Storage','')
    count+=1
print(f'looped till {count} index')
# Out:
# looped till 152 index

# %%
random_values('storage')
# Out:
# 141 : 32
# 124 : 32
# 9 : 128
# 57 : 64
# 99 : 64
# 125 : 32

# %%
df[df['storage'] == '32+3']
# Out:
#    level_0  index                                          name  ratings
# 4        4      4     Tecno Spark Go 2023 (UYUNI BLUE, 32+3 GB)      4.1  \
# 6        6      6  Tecno Spark Go 2023 (Endless Black, 32+3 GB)      4.1
#
#    price                                             imgURL
# 4   6750  https://rukminim2.flixcart.com/image/312/312/x...  \
# 6   6708  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                          storage_ram
# 4  Internal Storage32+3 GBRAM3 GBMemory Card Slot...  \
# 6  Internal Storage32+3 GBRAM3 GBMemory Card Slot...
#
#                                               camera
# 4  Operating SystemAndroid 12Primary Clock Speed2...  \
# 6  Operating SystemAndroid 12Processor Type2?GHz,...
#
#                                         oS_Processor
# 4  Primary Camera13MP Rear CameraDual Camera Lens...  \
# 6  Primary Camera13MP Rear CameraDual Camera Lens...
#
#                                              display
# 4  Display Size16.66 cm (6.56 inch)Resolution720x...  \
# 6  Display Size16.66 cm (6.56 inch)Resolution720*...
#
#                                           network
# 4  Network Type4G VOLTESupported Networks4G VoLTE  \
# 6  Network Type4G VOLTESupported Networks4G VoLTE
#
#                                              battery  ram storage
# 4                           Battery Capacity5000 mAh    3    32+3
# 6  Battery Capacity5000 mAhBattery TypeNon-Remova...    3    32+3

# %%
df['storage'][4] = 32
df['storage'][6] = 32

# %%
df.isnull().sum()
# Out:
# level_0         0
# index           0
# name            0
# ratings         0
# price           0
# imgURL          0
# storage_ram     0
# camera          0
# oS_Processor    0
# display         0
# network         0
# battery         0
# ram             0
# storage         0
# dtype: int64

# %%
##

# %% [markdown]
# # Stopped Here

# %%
# df['storage'] = df['storage'].astype('Int16')
# ## Removing storage_ram
# df = df.drop(columns=['storage_ram','index'])

# %% [markdown]
# ## Android Version

# %%
df.rename({'camera':'os_processor','oS_Processor':'camera'},axis=1,inplace=True)

# %%
def android_version(text_):
    split = text_.split()
    if 'OxygenProcessor' in split:
        return 'OxygenProcessor'
    elif 'ANdroid' in split:
        return split[3]
    elif 'OxygenOSProcessor' in split:
        return 'OxygenOSProcessor'
    else:
        pattern=r'^\d+[Processor]|\d+[GProcessor]|\d++[.Processor]'
        found = re.findall(pattern,text_)
        if found:
            return found[0]
        else:
            return 'other androidVerion'

# %%
df['android_version'] = df['os_processor'].apply(android_version)

# %%
# df.reset_index(inplace=True)
for Index,i in enumerate(df['android_version']):
    # print(i)
    i = str(i).replace('P','')
    i = str(i).replace('.','')
    df['android_version'][Index] = i

# %%
random_values('android_version')
# Out:
# 89 : 9
# 41 : 12
# 81 : 12
# 93 : 11
# 19 : 12
# 43 : 13

# %% [markdown]
# ## Processor

# %%
def processor(text):
    pattern=r'(?<=Type).*'
    search = re.search(pattern,text)
    if search != None:
        return ' '.join(re.findall(pattern,text))
    else:
        return 'not montioned'

# %%
# df['processor'] = df['os_processor'].apply(processor)
# df = df.drop('os_processor',axis=1)
# df = df.drop('index',axis=1)

# %%
# for i in range(0,9):
#     rand = np.random.randint(df.shape[0])
#     # print(rand)
#     txt = processor(df['processor'].iloc[rand])
#     print(df['processor'].iloc[rand],f'::index -{rand}')
#     print(txt)
#     print()

# %%
df
# Out:
#      level_0  index                                       name  ratings
# 0          0      0           Tecno Pova 3 (Eco Black, 128 GB)      4.1  \
# 1          1      1    Tecno Pop 5 Pro (Deepsea Luster, 32 GB)      4.2
# 2          2      2            Tecno Pova 3 (Eco Black, 64 GB)      4.2
# 3          3      3          Tecno Pova 3 (Tech Silver, 64 GB)      4.2
# 4          4      4  Tecno Spark Go 2023 (UYUNI BLUE, 32+3 GB)      4.1
# ..       ...    ...                                        ...      ...
# 147      147    147         Tecno Camon 15 (SHOAL GOLD, 64 GB)      4.2
# 148      148    148           Tecno Camon 19 Neo (Green, 6 GB)      4.1
# 149      149    149  Tecno Spark 10 Pro (Starry Black, 256 GB)      4.1
# 150      150    150   Tecno Spark 10 Pro (Pearl White, 256 GB)      4.1
# 151      151    151       Tecno Spark 10 pro (Meta Blue, 8 GB)      4.1
#
#      price                                             imgURL
# 0    13998  https://rukminim2.flixcart.com/image/312/312/l...  \
# 1     6960  https://rukminim2.flixcart.com/image/312/312/k...
# 2    10849  https://rukminim2.flixcart.com/image/312/312/l...
# 3    10978  https://rukminim2.flixcart.com/image/312/312/l...
# 4     6750  https://rukminim2.flixcart.com/image/312/312/x...
# ..     ...                                                ...
# 147  12499  https://rukminim2.flixcart.com/image/312/312/k...
# 148  18490  https://rukminim2.flixcart.com/image/312/312/x...
# 149  14999  https://rukminim2.flixcart.com/image/312/312/x...
# 150  14999  https://rukminim2.flixcart.com/image/312/312/x...
# 151  13999  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 0    Internal Storage128 GBRAM6 GBExpandable Storag...  \
# 1    Internal Storage32 GBRAM3 GBExpandable Storage...
# 2    Internal Storage64 GBRAM4 GBExpandable Storage...
# 3    Internal Storage64 GBRAM4 GBExpandable Storage...
# 4    Internal Storage32+3 GBRAM3 GBMemory Card Slot...
# ..                                                 ...
# 147  Internal Storage64 GBRAM4 GBExpandable Storage...
# 148  Internal Storage6 GBRAM128 GBMemory Card Slot ...
# 149  Internal Storage256 GBRAM8 GBExpandable Storag...
# 150  Internal Storage256 GBRAM8 GBExpandable Storag...
# 151  Internal Storage8 GBRAM8 GBMemory Card Slot Ty...
#
#                                           os_processor
# 0    Operating SystemAndroid 12Processor TypeMediaT...  \
# 1    Operating SystemAndroid 11 (Go Edition)Process...
# 2    Operating SystemAndroid 12Processor TypeMediaT...
# 3    Operating SystemAndroid 12Processor TypeMediaT...
# 4    Operating SystemAndroid 12Primary Clock Speed2...
# ..                                                 ...
# 147  Operating SystemAndroid 10Processor TypeHelio ...
# 148  Operating SystemAndroid Android 12Primary Cloc...
# 149  Operating SystemAndroid 13Processor TypeMediat...
# 150  Operating SystemAndroid 13Processor TypeMediat...
# 151  Operating SystemAndroid 13Primary Clock Speed2...
#
#                                                 camera
# 0    Primary Camera AvailableYesPrimary Camera50MP ...  \
# 1    Primary Camera AvailableYesPrimary Camera8MP R...
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
# 3    Primary Camera AvailableYesPrimary Camera50MP ...
# 4    Primary Camera13MP Rear CameraDual Camera Lens...
# ..                                                 ...
# 147  Primary Camera AvailableYesPrimary Camera48MP ...
# 148  Primary Camera48MP Rear CameraDual Camera Lens...
# 149  Primary Camera AvailableYesPrimary Camera50MP ...
# 150  Primary Camera AvailableYesPrimary Camera50MP ...
# 151  Primary Camera50MP Rear CameraDual Camera Lens...
#
#                                                display
# 0    Display Size17.53 cm (6.9 inch)Resolution1080 ...  \
# 1    Display Size16.56 cm (6.52 inch)Resolution720 ...
# 2    Display Size17.53 cm (6.9 inch)Resolution1080 ...
# 3    Display Size17.53 cm (6.9 inch)Resolution1080 ...
# 4    Display Size16.66 cm (6.56 inch)Resolution720x...
# ..                                                 ...
# 147  Display Size16.64 cm (6.55 inch)Resolution720 ...
# 148  Display Size17.27 cm (6.8 inch)Resolution2460x...
# 149  Display Size17.22 cm (6.78 inch)Resolution2460...
# 150  Display Size17.22 cm (6.78 inch)Resolution2460...
# 151  Display Size17.27 cm (6.8 inch)Resolution1080 ...
#
#                                                network
# 0    Network Type4G VOLTE, 4GSupported Networks4G V...  \
# 1    Network Type4G VOLTE, 4GSupported Networks4G V...
# 2    Network Type4G VOLTE, 4GSupported Networks4G V...
# 3    Network Type4G VOLTE, 4GSupported Networks4G V...
# 4       Network Type4G VOLTESupported Networks4G VoLTE
# ..                                                 ...
# 147  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 148     Network Type2G, 3G, 4GSupported Networks4G LTE
# 149  Network Type4G VOLTE, 4GSupported Networks4G V...
# 150  Network Type4G VOLTE, 4GSupported Networks4G V...
# 151  Network Type4GSupported Networks4G LTE, GSM, W...
#
#                                                battery  ram storage
# 0       Battery Capacity7000 mAhBattery TypeLi-Polymer    6     128  \
# 1            Battery Capacity6000 mAhBattery TypeLi-Po    3      32
# 2            Battery Capacity7000 mAhBattery TypeLi-Po    4      64
# 3            Battery Capacity7000 mAhBattery TypeLi-Po    4      64
# 4                             Battery Capacity5000 mAh    3      32
# ..                                                 ...  ...     ...
# 147                           Battery Capacity5000 mAh    4      64
# 148                           Battery Capacity5000 mAh  128       6
# 149          Battery Capacity5000 mAhBattery TypeLi-Po    8     256
# 150          Battery Capacity5000 mAhBattery TypeLi-Po    8     256
# 151  Battery Capacity5000 mAhBattery TypeNon-Remova...    8       8
#
#     android_version
# 0                12
# 1                22
# 2                12
# 3                12
# 4                12
# ..              ...
# 147              10
# 148              12
# 149              13
# 150              13
# 151              13
#
# [152 rows x 15 columns]

# %%
def processor_extract(text):
    splitted_sentence = text.split()
    if 'Mediatek' and 'Helio' in splitted_sentence:
        pattern = r'\d+[Processor]|\d+'
        string = ' '.join(splitted_sentence)
        match = re.search(pattern,string)
        if match == None:
            return 'Heilo'+str(splitted_sentence[2])
        else:
            find = re.findall(pattern,string)
            return 'Heilo'+''.join(find)


    elif 'Mediatek' and 'Dimensity' in splitted_sentence:
        pattern = r'(\d+)+[Processor]'
        string = ' '.join(splitted_sentence)
        match = re.search(pattern,string)
        if match == None:
            if 'Dimensity' == str(splitted_sentence[1]):
                return 'Dimensity'+str(splitted_sentence[2])
            else:
                return 'Dimensity'+str(splitted_sentence[1])
        
        else:
            find = re.findall(pattern,string)
            return 'Dimensity'+ ''.join(find)

    elif 'Snapdragon' and 'Gen' and '4' in splitted_sentence:
        return 'Gen4'   

    elif 'Snapdragon' and 'Gen' and '8' in splitted_sentence:         
        return 'Gen8'
    
    elif 'Unisoc' in splitted_sentence:
        
        if 'Unisoc' and 'Tiger' in splitted_sentence:
            pattern = r'[T]\d[Processor]'
            string = ' '.join(splitted_sentence)
            match = re.findall(pattern,string)
            return 'UnisocTiger' + ''.join(splitted_sentence[2])
        
        elif 'Unisoc' == splitted_sentence[0]:
            pattern = r'[T]\d.'
            string = ' '.join(splitted_sentence)
            match = re.findall(pattern,string)
            return 'Unisoc' + ''.join(splitted_sentence[1])

        
        pattern = r'T(\d+)Processor|\d+'
        string = ' '.join(splitted_sentence)
        match = re.findall(pattern,string)
        return 'Unisoc'+' '.join(match)
    

    elif 'Snapdragon' in splitted_sentence:
        pattern = r'\d+[Processor]'
        if 'Gen' and '4' and '8' not in splitted_sentence:
            string = ' '.join(splitted_sentence)
            match = re.search(pattern,string)
            if match == None:
                if 'Snapdragon' == str(splitted_sentence[1]):
                    return 'Snapdragon'+str(splitted_sentence[2])
                else:
                    return 'Snapdragon'+str(splitted_sentence[1])
            else:
                find = re.findall(pattern,string)
                return 'Snapdragon'+''.join(find)
    
    elif 'MediaTek' == splitted_sentence[0]:
        pattern = r'[P]\d.'
        string = ' '.join(splitted_sentence)
        match = re.findall(pattern,string)
        return 'MediaTek' + ' '.join(match)

    else:
        return 'not mentioned'

# %%
for i in range(0,9):
    rand = np.random.randint(df.shape[0])
    # print(rand)
    txt = processor_extract(df['os_processor'].iloc[rand])
    print(df['os_processor'].iloc[rand],f'::index -{rand}')
    print(txt)
    print()
# Out:
# Operating SystemAndroid 12Processor TypeMediaTek Dimensity 810 MT6833Processor CoreOcta CorePrimary Clock Speed2.4 GHzSecondary Clock Speed2 GHz ::index -37
# Dimensity126833
#
# Operating SystemAndroid Android 12.0Processor CoreOcta CorePrimary Clock Speed2 GHz ::index -10
# not mentioned
#
# Operating SystemAndroid Pie 9Processor TypeHelio P35 (MTK 6765)Processor CoreOcta CorePrimary Clock Speed2.3 GHzOperating FrequencyGSM: 850/900/1800/1900, WCDMA:B1/B2/B4/B5/B8, FDD-LTE:B1/B2/B3/B4/B5/B7/B8/B20/B28A/B28B, TDD-LTE:B38/B40/B41 ::index -143
# not mentioned
#
# Operating SystemAndroid HiOS 8.6 based on Android 12-Go EditionProcessor TypeUnisoc SC9863AProcessor CoreOcta CorePrimary Clock Speed120 MHzSecondary Clock Speed1.2 GHz ::index -124
# not mentioned
#
# Operating SystemAndroid HIOS 8.6Primary Clock Speed2 MHz ::index -62
# not mentioned
#
# Operating SystemAndroid 12Processor TypeMediaTek Helio G37Processor CoreOcta CorePrimary Clock Speed2.3 GHzSecondary Clock Speed1.8 GHz ::index -5
# Heilo12P37P2318
#
# Operating SystemAndroid 12Processor TypeMediaTek Helio A22Processor CoreQuad CorePrimary Clock Speed2 GHz ::index -28
# Heilo12P22P2
#
# Operating SystemAndroid 13Processor TypeUnisoc Tiger T606Processor CoreOcta CorePrimary Clock Speed1.6 GHzSecondary Clock Speed1.4 GHz ::index -82
# not mentioned
#
# Operating SystemAndroid 12Primary Clock Speed2.1 GHz ::index -60
# not mentioned

# %%
df['processor']=df['processor'].apply(processor_extract)

# %%
random_values('processor')
# Out:
# 119 : Heilo25P215
# 72 : Dimensity6020
# 147 : Heilo226762P223581581358384041
# 109 : not mentioned
# 17 : Heilo35P2318
# 61 : Heilo20P18

# %% [markdown]
# ## camera

# %%
def camera_extract(row):
    row_splitted = row.split()
    pattern = r'\d+MP'
    words = ' '.join(row_splitted)
    find_cam = re.findall(pattern,words)
    return ' '.join(find_cam)

# %%
df['camera'] = df['camera'].apply(camera_extract)

# %%
def camera(txt):
    if not txt:
        return 13

    lst = []
    splitted = txt.split()
    for i in splitted:
        make_int = i.replace('MP', '')
        lst.append(int(make_int))

    return max(lst)

# %%
random_values('camera')
# Out:
# 142 : 50MP
# 109 : 50MP
# 111 : 48MP 2MP 2MP 2MP 8MP
# 21 : 50MP 2MP 8MP
# 14 : 13MP 5MP
# 82 : 16MP 8MP

# %%
df['camera'] = df['camera'].apply(func=camera)
df['camera'] = df['camera'].astype('Int16')

# %% [markdown]
# ## display

# %%
def display_extract(row):
    split_row = row.split()
    if 'LCD' in split_row:
        if 'IPS' in split_row and 'LCD' in split_row:
            return 'IPS LCD'
        return 'LCD'
    
    if 'OLED' in split_row:
        return 'OLED'
    
    if 'TFT' in split_row:
        return 'TFT'
    
    if 'LED' in split_row:
        return 'LED'

    # if 'Adreno' in split_row:
    #     return 'Adreno'
    if 'AMOLED' in split_row:
        if 'HD+' in split_row and 'AMOLED' in split_row:
            return 'HD+ AMOLED'
        return 'AMOLED'
    
    return 'other'

# %%
df['display'] = df['display'].apply(display_extract)

# %% [markdown]
# ## network

# %%
df = df.drop(columns=['network'])

# %% [markdown]
# ## battery

# %%
def extract_battery(row):
    return row.split()[1]

df['battery'] = df['battery'].apply(extract_battery)

# %%
df.reset_index(inplace=True)
count = 0
for i in range(0,len(df['battery'])):
    # print(i)
    df['battery'][i]= df['battery'].iloc[i].replace('Capacity','')
    # print(df['battery'][i])
    count+=1
print(f'looped till {count} index')
# Out:
# looped till 152 index

# %%
df['battery'] = df['battery'].astype('Int16')

# %%
df = df.drop(labels='index',axis=1)

# %%
df
# Out:
#      level_0                                       name  ratings  price
# 0          0           Tecno Pova 3 (Eco Black, 128 GB)      4.1  13998  \
# 1          1    Tecno Pop 5 Pro (Deepsea Luster, 32 GB)      4.2   6960
# 2          2            Tecno Pova 3 (Eco Black, 64 GB)      4.2  10849
# 3          3          Tecno Pova 3 (Tech Silver, 64 GB)      4.2  10978
# 4          4  Tecno Spark Go 2023 (UYUNI BLUE, 32+3 GB)      4.1   6750
# ..       ...                                        ...      ...    ...
# 147      147         Tecno Camon 15 (SHOAL GOLD, 64 GB)      4.2  12499
# 148      148           Tecno Camon 19 Neo (Green, 6 GB)      4.1  18490
# 149      149  Tecno Spark 10 Pro (Starry Black, 256 GB)      4.1  14999
# 150      150   Tecno Spark 10 Pro (Pearl White, 256 GB)      4.1  14999
# 151      151       Tecno Spark 10 pro (Meta Blue, 8 GB)      4.1  13999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/l...  \
# 1    https://rukminim2.flixcart.com/image/312/312/k...
# 2    https://rukminim2.flixcart.com/image/312/312/l...
# 3    https://rukminim2.flixcart.com/image/312/312/l...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 147  https://rukminim2.flixcart.com/image/312/312/k...
# 148  https://rukminim2.flixcart.com/image/312/312/x...
# 149  https://rukminim2.flixcart.com/image/312/312/x...
# 150  https://rukminim2.flixcart.com/image/312/312/x...
# 151  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram  camera display
# 0    Internal Storage128 GBRAM6 GBExpandable Storag...      50   other  \
# 1    Internal Storage32 GBRAM3 GBExpandable Storage...       8     LCD
# 2    Internal Storage64 GBRAM4 GBExpandable Storage...      50   other
# 3    Internal Storage64 GBRAM4 GBExpandable Storage...      50   other
# 4    Internal Storage32+3 GBRAM3 GBMemory Card Slot...      13   other
# ..                                                 ...     ...     ...
# 147  Internal Storage64 GBRAM4 GBExpandable Storage...      48   other
# 148  Internal Storage6 GBRAM128 GBMemory Card Slot ...      48   other
# 149  Internal Storage256 GBRAM8 GBExpandable Storag...      50   other
# 150  Internal Storage256 GBRAM8 GBExpandable Storag...      50   other
# 151  Internal Storage8 GBRAM8 GBMemory Card Slot Ty...      50   other
#
#      battery  ram storage android_version                       processor
# 0       7000    6     128              12                     Heilo88P218
# 1       6000    3      32              22                       Heilo22P2
# 2       7000    4      64              12                     Heilo88P218
# 3       7000    4      64              12                     Heilo88P218
# 4       5000    3      32              12                   not mentioned
# ..       ...  ...     ...             ...                             ...
# 147     5000    4      64              10  Heilo226762P223581581358384041
# 148     5000  128       6              12                   not mentioned
# 149     5000    8     256              13                 Heilo676988P218
# 150     5000    8     256              13                 Heilo676988P218
# 151     5000    8       8              13                   not mentioned
#
# [152 rows x 13 columns]

# %%
df = df.drop(labels='storage_ram',axis=1)

# %%
df
# Out:
#      level_0                                       name  ratings  price
# 0          0           Tecno Pova 3 (Eco Black, 128 GB)      4.1  13998  \
# 1          1    Tecno Pop 5 Pro (Deepsea Luster, 32 GB)      4.2   6960
# 2          2            Tecno Pova 3 (Eco Black, 64 GB)      4.2  10849
# 3          3          Tecno Pova 3 (Tech Silver, 64 GB)      4.2  10978
# 4          4  Tecno Spark Go 2023 (UYUNI BLUE, 32+3 GB)      4.1   6750
# ..       ...                                        ...      ...    ...
# 147      147         Tecno Camon 15 (SHOAL GOLD, 64 GB)      4.2  12499
# 148      148           Tecno Camon 19 Neo (Green, 6 GB)      4.1  18490
# 149      149  Tecno Spark 10 Pro (Starry Black, 256 GB)      4.1  14999
# 150      150   Tecno Spark 10 Pro (Pearl White, 256 GB)      4.1  14999
# 151      151       Tecno Spark 10 pro (Meta Blue, 8 GB)      4.1  13999
#
#                                                 imgURL  camera display
# 0    https://rukminim2.flixcart.com/image/312/312/l...      50   other  \
# 1    https://rukminim2.flixcart.com/image/312/312/k...       8     LCD
# 2    https://rukminim2.flixcart.com/image/312/312/l...      50   other
# 3    https://rukminim2.flixcart.com/image/312/312/l...      50   other
# 4    https://rukminim2.flixcart.com/image/312/312/x...      13   other
# ..                                                 ...     ...     ...
# 147  https://rukminim2.flixcart.com/image/312/312/k...      48   other
# 148  https://rukminim2.flixcart.com/image/312/312/x...      48   other
# 149  https://rukminim2.flixcart.com/image/312/312/x...      50   other
# 150  https://rukminim2.flixcart.com/image/312/312/x...      50   other
# 151  https://rukminim2.flixcart.com/image/312/312/x...      50   other
#
#      battery  ram storage android_version                       processor
# 0       7000    6     128              12                     Heilo88P218
# 1       6000    3      32              22                       Heilo22P2
# 2       7000    4      64              12                     Heilo88P218
# 3       7000    4      64              12                     Heilo88P218
# 4       5000    3      32              12                   not mentioned
# ..       ...  ...     ...             ...                             ...
# 147     5000    4      64              10  Heilo226762P223581581358384041
# 148     5000  128       6              12                   not mentioned
# 149     5000    8     256              13                 Heilo676988P218
# 150     5000    8     256              13                 Heilo676988P218
# 151     5000    8       8              13                   not mentioned
#
# [152 rows x 12 columns]

# %%
df.to_csv(r'data\cleaned_dataset\techno_plus_cleaned_data.csv')
