# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import os
import numpy as np
from itertools import zip_longest

# %%
def bs4_soup(pages):
    URL = f'https://www.flipkart.com/search?q=oneplus+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={pages}'
    request = requests.get(URL)
    soup = bs(request.text,'html.parser')
    soup = soup.find('div',class_ = '_1YokD2 _3Mn1Gg')

    return soup , URL

# %%
def mob_specs(soup):
    names = soup.find_all('div', class_='_4rR01T')
    mob_names = [i.text if i else None for i in names]

    ratings = soup.find_all('div', class_='_3LWZlK')
    mob_ratings = [i.text if i else None for i in ratings]

    price = soup.find_all('div', class_='_30jeq3 _1_WHN1')
    mob_price = [i.text if i else None for i in price]

    img = soup.find_all('div', class_='CXW8mj')
    mob_img_URL = [i.find('img')['src'] if i.find('img') else None for i in img]

    return mob_names, mob_ratings, mob_price, mob_img_URL

# %%
def features_from_mob_links(soup):
    mobile_links = ['https://www.flipkart.com' + i['href'] for i in soup.find_all('a', class_='_1fQZEK')]
    mobile_req = [requests.get(url=i) for i in mobile_links]
    mobile_soup = [bs(i.text, 'html.parser').find('div', class_='_1YokD2 _2GoDe3') for i in mobile_req]
    mobile_specs_soup = [i.find_all('div', class_='_3k-BhJ') for i in mobile_soup]

    storage_ram = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Memory' in str(specs_.text) and 'Storage' in str(specs_.text)]
    storage_ram_cross_checked = [i for i in storage_ram if 'Internal' in i.split()]

    os_processor = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Os' in str(specs_.text) and 'Processor' in str(specs_.text)]
    os_processor_cross_checked = [i for i in os_processor if 'Operating' in i.split()]

    camera = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Camera' in str(specs_.text) and 'FeaturesPrimary' in str(specs_.text)]
    camera_cross_checked = [i for i in camera if 'Primary' and 'Camera' in i.split()]

    display = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Display' in str(specs_.text) and 'FeaturesDisplay' in str(specs_.text)]
    display_cross_checked = [i for i in display if 'Display' and 'cm' in i.split()]

    network = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Connectivity' in str(specs_.text) and 'FeaturesNetwork' in str(specs_.text)]
    network_cross_checked = [i for i in network if 'Network' in i.split()]

    battery = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Battery' in str(specs_.text) and 'FeaturesBattery' in str(specs_.text)]
    battery_cross_checked = [i for i in battery if 'Battery' in i.split()]

    return mobile_specs_soup, storage_ram_cross_checked, os_processor_cross_checked, camera_cross_checked, display_cross_checked, network_cross_checked, battery_cross_checked

# %%
def fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery):
    tuple_data = zip_longest(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery,fillvalue=np.nan)
    
    data = [i for i in tuple_data]
    return data

# %%
def print_len(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery):
    print(f"Length of mob_names: {len(mob_names)}")
    print(f"Length of mob_ratings: {len(mob_ratings)}")
    print(f"Length of mob_price: {len(mob_price)}")
    print(f"Length of mob_img_URL: {len(mob_img_URL)}")
    print(f"Length of storage_ram: {len(storage_ram)}")
    print(f"Length of os_processor: {len(os_processor)}")
    print(f"Length of camera: {len(camera)}")
    print(f"Length of display: {len(display)}")
    print(f"Length of network: {len(network)}")
    print(f"Length of battery: {len(battery)}")

# %%
df = pd.DataFrame()

page_start = 1
page_ends = 9

for pages in range(page_start, page_ends):

    soup, URL = bs4_soup(pages=pages)
    
    mob_names, mob_ratings, mob_price, mob_img_URL = mob_specs(soup)
    mobile_specs_soup, storage_ram, os_processor, camera, display, network, battery = features_from_mob_links(soup=soup)
    
    data = fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)

    if mobile_specs_soup is not None and soup is not None:
        
        print_len(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)

        page_df = pd.DataFrame(data=data,columns=['name', 'ratings', 'price', 'imgURL', 'storage_ram','os_processor',
                                                   'camera', 'display', 'network', 'battery'])

        if not page_df.empty:
            df = pd.concat(objs=[df, page_df], ignore_index=True)
            print(f'scraping data from page:{pages}')
            print(f'working in {URL} Page')
            print(f'page df : page_shape : {page_df.shape} \n {page_df.sample(2)}')
            print(f'df : df shape : {df.shape} \n {df.sample(2)}')
            print()

    else:
        print(f"Skipping page {pages} due to empty mobile_specs_soup or soup.")
# Out:
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:1
# working in https://www.flipkart.com/search?q=oneplus+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1 Page
# page df : page_shape : (24, 10)
#                                         name ratings    price
# 3  OnePlus 11R 5G (Galactic Silver, 128 GB)     4.5  ₹39,734  \
# 5        OnePlus 10R (Forest Green, 256 GB)       4  ₹34,990
#
#                                               imgURL
# 3  https://rukminim2.flixcart.com/image/312/312/x...  \
# 5  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                          storage_ram
# 3                      Internal Storage128 GBRAM8 GB  \
# 5  Internal Storage256 GBRAM12 GBMemory Card Slot...
#
#                                         os_processor
# 3  Operating SystemAndroid OxygenOS based on Andr...  \
# 5  Operating SystemAndroid 12Processor CoreOcta C...
#
#                                               camera
# 3  Primary Camera50MP Rear CameraDual Camera Lens...  \
# 5                     Primary Camera50MP Rear Camera
#
#                                              display
# 3  Display Size17.02 cm (6.7 inch)Resolution2772x...  \
# 5  Display Size17.02 cm (6.7 inch)Resolution2400 ...
#
#                               network                   battery
# 3  Network Type5GSupported Networks5G  Battery Capacity5000 mAh
# 5  Network Type5GSupported Networks5G  Battery Capacity5000 mAh
# df : df shape : (24, 10)
#                                               name ratings    price
# 13          OnePlus 11 5G (Eternal Green, 256 GB)     4.5  ₹61,999  \
# 0   OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)     4.4  ₹17,676
#
#                                                imgURL
# 13  https://rukminim2.flixcart.com/image/312/312/x...  \
# 0   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 13  Internal Storage256 GBRAM16 GBMemory Card Slot...  \
# 0   Internal Storage128 GBRAM6 GBMemory Card Slot ...
#
#                                          os_processor
# 13  Operating SystemAndroid OxygenOS based on Andr...  \
# 0   Operating SystemAndroid 10Processor CoreOcta C...
#
#                                                camera
# 13  Primary Camera50MP Rear CameraDual Camera Lens...  \
# 0                      Primary Camera64MP Rear Camera
#
#                                               display
# 13  Display Size17.02 cm (6.7 inch)Resolution3216x...  \
# 0   Display Size16.74 cm (6.59 inch)Resolution2412...
#
#                                network                   battery
# 13  Network Type5GSupported Networks5G  Battery Capacity5000 mAh
# 0   Network Type5GSupported Networks5G  Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 21
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 23
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:2
# working in https://www.flipkart.com/search?q=oneplus+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2 Page
# page df : page_shape : (24, 10)
#                                         name ratings    price
# 21  OnePlus Nord 3 5G (Misty Green, 128 GB)     NaN  ₹33,934  \
# 13     OnePlus 8T 5G (Lunar Silver, 128 GB)     4.4  ₹29,990
#
#                                                imgURL
# 21  https://rukminim2.flixcart.com/image/312/312/x...  \
# 13  https://rukminim2.flixcart.com/image/312/312/k...
#
#                       storage_ram
# 21  Internal Storage128 GBRAM8 GB  \
# 13  Internal Storage128 GBRAM8 GB
#
#                                          os_processor
# 21  Operating SystemAndroid ANdroid 13 OxygenOSPro...  \
# 13  Operating SystemAndroid Q 11Processor CoreDual...
#
#                                                camera
# 21                     Primary Camera50MP Rear Camera  \
# 13  Primary Camera48MP Rear CameraDual Camera Lens...
#
#                                               display
# 21  Display Size17.12 cm (6.74 inch)Resolution1240...  \
# 13  Display Size16.64 cm (6.55 inch)Resolution2400...
#
#                                               network
# 21                 Network Type5GSupported Networks5G  \
# 13  Network Type5GSupported Networks5G, GSM, CDMA,...
#
#                      battery
# 21  Battery Capacity5000 mAh
# 13  Battery Capacity4500 mAh
# df : df shape : (48, 10)
#                                 name ratings    price
# 24  OnePlus Nord (Gray Onyx, 64 GB)     4.3  ₹24,490  \
# 40          OnePlus 7 (Red, 256 GB)     4.6  ₹32,990
#
#                                                imgURL
# 24  https://rukminim2.flixcart.com/image/312/312/k...  \
# 40  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 24  Internal Storage64 GBRAM6 GBMemory Card Slot T...  \
# 40                      Internal Storage256 GBRAM8 GB
#
#                                          os_processor
# 24  Operating SystemAndroid Q 10Processor TypeQual...  \
# 40  Operating SystemAndroid Pie OxygenProcessor Co...
#
#                                                camera
# 24  Primary Camera AvailableYesPrimary Camera48MP ...  \
# 40                     Primary Camera50MP Rear Camera
#
#                                               display
# 24  Display Size16.36 cm (6.44 inch)Resolution2400...  \
# 40  Display Size16.28 cm (6.41 inch)Resolution2340...
#
#                                               network
# 24  Network Type5G, 4G VOLTESupported Networks5G, ...  \
# 40  Network Type4G VOLTESupported Networks4G LTEBl...
#
#                                             battery
# 24  Battery Capacity4115 mAhBattery Typelithium-ion
# 40  Battery Capacity3700 mAhBattery Typelithium-ion
#
# Length of mob_names: 24
# Length of mob_ratings: 22
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:3
# working in https://www.flipkart.com/search?q=oneplus+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3 Page
# page df : page_shape : (24, 10)
#                                          name ratings    price
# 13  OnePlus Nord 2T 5G (Gray Shadow, 128 GB)     4.4  ₹28,864  \
# 18      OnePlus 9RT 5G (Nano Silver, 256 GB)     3.9  ₹46,999
#
#                                                imgURL
# 13  https://rukminim2.flixcart.com/image/312/312/x...  \
# 18  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 13  Internal Storage128 GBRAM8 GBMemory Card Slot ...  \
# 18                     Internal Storage256 GBRAM12 GB
#
#                                          os_processor
# 13  Operating SystemAndroid 13Processor CoreOcta C...  \
# 18  Operating SystemAndroid Q 11Processor CoreDual...
#
#                                                camera
# 13                     Primary Camera50MP Rear Camera  \
# 18  Primary Camera50MP Rear CameraDual Camera Lens...
#
#                                               display
# 13  Display Size17.02 cm (6.7 inch)Resolution2400 ...  \
# 18  Display Size16.81 cm (6.62 inch)Resolution1080...
#
#                                               network
# 13                 Network Type5GSupported Networks5G  \
# 18  Network Type5GSupported Networks5G, GSM, CDMA,...
#
#                      battery
# 13  Battery Capacity4500 mAh
# 18  Battery Capacity4500 mAh
# df : df shape : (72, 10)
#                                         name ratings    price
# 10    OnePlus Nord 2T 5G (Jade Fog, 128 GB)     4.4  ₹28,885  \
# 44  OnePlus Nord 3 5G (Misty Green, 256 GB)       4  ₹37,999
#
#                                                imgURL
# 10  https://rukminim2.flixcart.com/image/312/312/x...  \
# 44  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 10  Internal Storage128 GBRAM8 GBMemory Card Slot ...  \
# 44                     Internal Storage256 GBRAM16 GB
#
#                                          os_processor
# 10  Operating SystemAndroid 13Processor CoreDeca C...  \
# 44  Operating SystemAndroid Android 13 OxygenOSPro...
#
#                                                camera
# 10                     Primary Camera50MP Rear Camera  \
# 44  Primary Camera50MP Rear CameraDual Camera Lens...
#
#                                               display
# 10  Display Size17.02 cm (6.7 inch)Resolution2400 ...  \
# 44  Display Size17.12 cm (6.74 inch)Resolution1240...
#
#                                network                   battery
# 10  Network Type5GSupported Networks5G  Battery Capacity4500 mAh
# 44  Network Type5GSupported Networks5G  Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 23
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 23
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:4
# working in https://www.flipkart.com/search?q=oneplus+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4 Page
# page df : page_shape : (24, 10)
#                                      name ratings    price
# 22  OnePlus 9RT 5G (Nano Silver, 256 GB)     4.3  ₹50,999  \
# 1     OnePlus 10R (Forest Green, 128 GB)     4.3  ₹31,990
#
#                                                imgURL
# 22  https://rukminim2.flixcart.com/image/312/312/x...  \
# 1   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 22                      Internal Storage256 GBRAM8 GB  \
# 1   Internal Storage128 GBRAM8 GBMemory Card Slot ...
#
#                                          os_processor
# 22  Operating SystemAndroid Q 11Processor CoreDual...  \
# 1   Operating SystemAndroid 12Processor CoreOcta C...
#
#                                                camera
# 22  Primary Camera50MP Rear CameraDual Camera Lens...  \
# 1   Primary Camera50MP Rear CameraDual Camera Lens...
#
#                                               display
# 22  Display Size16.81 cm (6.62 inch)Resolution1080...  \
# 1   Display Size17.02 cm (6.7 inch)Resolution2400 ...
#
#                                               network
# 22  Network Type5GSupported Networks4G LTE, 5G, GS...  \
# 1                  Network Type5GSupported Networks5G
#
#                      battery
# 22  Battery Capacity4500 mAh
# 1   Battery Capacity5000 mAh
# df : df shape : (96, 10)
#                                       name ratings    price
# 89  OnePlus 10R 5G (Sierra Black, 256 GB)     4.3  ₹34,878  \
# 88  OnePlus 11 5G (Eternal Green, 128 GB)     4.2  ₹55,999
#
#                                                imgURL
# 89  https://rukminim2.flixcart.com/image/312/312/x...  \
# 88  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 89  Internal Storage256 GBRAM12 GBMemory Card Slot...  \
# 88  Internal Storage128 GBRAM8 GBMemory Card Slot ...
#
#                                          os_processor
# 89  Operating SystemAndroid 11Processor CoreOcta C...  \
# 88  Operating SystemAndroid OxygenOS based on Andr...
#
#                                                camera
# 89  Primary Camera50MP Rear CameraDual Camera Lens...  \
# 88  Primary Camera50MP Rear CameraDual Camera Lens...
#
#                                               display
# 89  Display Size17.02 cm (6.7 inch)Resolution2400 ...  \
# 88  Display Size17.02 cm (6.7 inch)Resolution3216x...
#
#                                network                   battery
# 89  Network Type5GSupported Networks5G  Battery Capacity4500 mAh
# 88  Network Type5GSupported Networks5G  Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 23
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:5
# working in https://www.flipkart.com/search?q=oneplus+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5 Page
# page df : page_shape : (24, 10)
#                                                name ratings    price
# 18           OnePlus Nord 2T 5G (Jade Fog, 128 GB)     4.4  ₹28,185  \
# 12  OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)     4.3  ₹17,990
#
#                                                imgURL
# 18  https://rukminim2.flixcart.com/image/312/312/x...  \
# 12  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 18  Internal Storage128 GBRAM8 GBMemory Card Slot ...  \
# 12  Internal Storage128 GBRAM8 GBMemory Card Slot ...
#
#                                          os_processor
# 18  Operating SystemAndroid 13Processor CoreDeca C...  \
# 12  Operating SystemAndroid 12Processor CoreOcta C...
#
#                                                camera
# 18  Primary Camera64MP Rear CameraDual Camera Lens...  \
# 12  Primary Camera50MP Rear CameraDual Camera Lens...
#
#                                               display
# 18  Display Size17.02 cm (6.7 inch)Resolution2400 ...  \
# 12  Display Size16.74 cm (6.59 inch)Resolution2412...
#
#                                network                   battery
# 18  Network Type5GSupported Networks5G  Battery Capacity4500 mAh
# 12  Network Type5GSupported Networks5G  Battery Capacity5000 mAh
# df : df shape : (120, 10)
#                                          name ratings    price
# 32         OnePlus 8 (Glacial Green, 128 GB)     4.5  ₹33,980  \
# 46  OnePlus 10T 5G (Moonstone Black, 128 GB)     NaN  ₹49,999
#
#                                                imgURL
# 32  https://rukminim2.flixcart.com/image/312/312/k...  \
# 46  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 32  Internal Storage128 GBRAM8 GBSupported Memory ...  \
# 46  Internal Storage128 GBRAM8 GBMemory Card Slot ...
#
#                                          os_processor
# 32  Operating SystemAndroid Pie 10Processor TypeQu...  \
# 46  Operating SystemAndroid 12Processor CoreOcta C...
#
#                                                camera
# 32                     Primary Camera50MP Rear Camera  \
# 46  Primary Camera48MP Rear CameraDual Camera Lens...
#
#                                               display
# 32  Display Size16.64 cm (6.55 inch)Resolution2400...  \
# 46  Display Size17.02 cm (6.7 inch)Resolution2412x...
#
#                                               network
# 32  Network Type4G VOLTE, 5GSupported Networks4G V...  \
# 46                 Network Type5GSupported Networks5G
#
#                                             battery
# 32  Battery Capacity4300 mAhBattery Typelithium-ion
# 46                         Battery Capacity4800 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 23
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:6
# working in https://www.flipkart.com/search?q=oneplus+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=6 Page
# page df : page_shape : (24, 10)
#                                       name ratings    price
# 22  OnePlus Nord 2T 5G (Jade Fog, 256 GB)     4.3  ₹29,208  \
# 1          OnePlus 8 (Onyx Black, 256 GB)     4.4  ₹34,999
#
#                                                imgURL
# 22  https://rukminim2.flixcart.com/image/312/312/x...  \
# 1   https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 22  Internal Storage256 GBRAM12 GBMemory Card Slot...  \
# 1   Internal Storage256 GBRAM12 GBSupported Memory...
#
#                                          os_processor
# 22  Operating SystemAndroid 12Processor CoreOcta C...  \
# 1   Operating SystemAndroid Pie 10Processor TypeQu...
#
#                                                camera
# 22                     Primary Camera50MP Rear Camera  \
# 1   Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                               display
# 22  Display Size17.02 cm (6.7 inch)Resolution2400x...  \
# 1   Display Size16.64 cm (6.55 inch)Resolution2400...
#
#                                               network
# 22                 Network Type5GSupported Networks5G  \
# 1   Network Type4G VOLTE, 5GSupported Networks4G V...
#
#                                             battery
# 22                         Battery Capacity4500 mAh
# 1   Battery Capacity4300 mAhBattery Typelithium-ion
# df : df shape : (144, 10)
#                                           name ratings    price
# 15   OnePlus Nord 2T 5G (Gray Shadow, 128 GB)     4.4  ₹27,819  \
# 110   OnePlus Nord 2 5G (Gray Sierra, 128 GB)     4.4  ₹25,989
#
#                                                 imgURL
# 15   https://rukminim2.flixcart.com/image/312/312/x...  \
# 110  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 15   Internal Storage128 GBRAM8 GBMemory Card Slot ...  \
# 110  Internal Storage128 GBRAM8 GBMemory Card Slot ...
#
#                                           os_processor
# 15   Operating SystemAndroid 13Processor CoreOcta C...  \
# 110  Operating SystemAndroid 11Processor CoreOcta C...
#
#                                                 camera
# 15                      Primary Camera50MP Rear Camera  \
# 110  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                                display
# 15   Display Size17.02 cm (6.7 inch)Resolution2400 ...  \
# 110  Display Size16.33 cm (6.43 inch)Resolution2400...
#
#                                              network                   battery
# 15                Network Type5GSupported Networks5G  Battery Capacity4500 mAh
# 110  Network Type5GSupported Networks5G, 4G LTE, GSM  Battery Capacity4500 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 22
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:7
# working in https://www.flipkart.com/search?q=oneplus+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=7 Page
# page df : page_shape : (24, 10)
#                                           name ratings    price
# 4  OnePlus 10 Pro 5G (Emerald Forest, 256 GB)     4.5  ₹53,999  \
# 6         OnePlus 7 Pro (Mirror Grey, 128 GB)     4.3  ₹41,799
#
#                                               imgURL
# 4  https://rukminim2.flixcart.com/image/312/312/x...  \
# 6  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                          storage_ram
# 4                     Internal Storage256 GBRAM12 GB  \
# 6  Internal Storage128 GBRAM6 GBMemory Card Slot ...
#
#                                         os_processor
# 4  Operating SystemAndroid 12Processor CoreDual C...  \
# 6  Operating SystemAndroid Pie 9 Pie OxygenOSProc...
#
#                                               camera
# 4                     Primary Camera48MP Rear Camera  \
# 6  Primary Camera AvailableYesPrimary Camera48 MP...
#
#                                              display
# 4  Display Size17.02 cm (6.7 inch)Resolution3216 ...  \
# 6  Display Size16.94 cm (6.67 inch)Resolution3120...
#
#                                              network
# 4  Network Type5GSupported Networks5G, GSM, CDMA, 5G  \
# 6  Network Type4G VOLTESupported Networks4G LTE3G...
#
#                                            battery
# 4                         Battery Capacity5000 mAh
# 6  Battery Capacity4000 mAhBattery Typelithium-ion
# df : df shape : (168, 10)
#                                           name ratings    price
# 159   OnePlus 9 Pro 5G (Morning Mist, 256 GB)     3.8  ₹47,999  \
# 39   OnePlus 8T 5G (Aquamarine Green, 256 GB)     3.3  ₹32,999
#
#                                                 imgURL
# 159  https://rukminim2.flixcart.com/image/312/312/x...  \
# 39   https://rukminim2.flixcart.com/image/312/312/l...
#
#                         storage_ram
# 159  Internal Storage256 GBRAM12 GB  \
# 39   Internal Storage256 GBRAM12 GB
#
#                                           os_processor
# 159  Operating SystemAndroid Q 11Processor CoreDual...  \
# 39   Operating SystemAndroid Q 11Processor CoreDual...
#
#                                                 camera
# 159  Primary Camera48MP Rear CameraDual Camera Lens...  \
# 39   Primary Camera AvailableYesPrimary Camera48 MP...
#
#                                                display
# 159  Display Size17.02 cm (6.7 inch)Resolution3216 ...  \
# 39   Display Size16.64 cm (6.55 inch)Resolution2400...
#
#                                                network
# 159  Network Type5GSupported Networks5G, 4G LTE, GS...  \
# 39   Network Type5GSupported Networks4G LTE, 5G, CD...
#
#                       battery
# 159  Battery Capacity4500 mAh
# 39   Battery Capacity4500 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 22
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:8
# working in https://www.flipkart.com/search?q=oneplus+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=8 Page
# page df : page_shape : (24, 10)
#                                    name ratings    price
# 11  OnePlus 9 5G (Winter Mist, 128 GB)     3.9  ₹37,190  \
# 18   OnePlus 9R 5G (Lake Blue, 128 GB)     3.7  ₹29,999
#
#                                                imgURL
# 11  https://rukminim2.flixcart.com/image/312/312/x...  \
# 18  https://rukminim2.flixcart.com/image/312/312/x...
#
#                       storage_ram
# 11  Internal Storage128 GBRAM8 GB  \
# 18  Internal Storage128 GBRAM8 GB
#
#                                          os_processor
# 11  Operating SystemAndroid 11Processor CoreDual C...  \
# 18  Operating SystemAndroid Q 11Processor CoreDual...
#
#                                                camera
# 11                     Primary Camera48MP Rear Camera  \
# 18  Primary Camera48MP Rear CameraDual Camera Lens...
#
#                                               display
# 11  Display Size16.64 cm (6.55 inch)Resolution2400...  \
# 18  Display Size16.64 cm (6.55 inch)Resolution2400...
#
#                                               network
# 11  Network Type5GSupported Networks4G LTE, CDMA, ...  \
# 18  Network Type5GSupported NetworksGSM, CDMA, 4G ...
#
#                      battery
# 11  Battery Capacity4500 mAh
# 18  Battery Capacity4500 mAh
# df : df shape : (192, 10)
#                                                    name ratings    price
# 134         OnePlus Nord CE 2 5G (Gray Mirror, 128 GB)     4.3  ₹24,989  \
# 99   OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256...     4.3  ₹21,249
#
#                                                 imgURL
# 134  https://rukminim2.flixcart.com/image/312/312/x...  \
# 99   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 134  Internal Storage128 GBRAM8 GBMemory Card Slot ...  \
# 99   Internal Storage256 GBRAM8 GBMemory Card Slot ...
#
#                                           os_processor
# 134  Operating SystemAndroid Q 13Processor CoreOcta...  \
# 99   Operating SystemAndroid Android 13Processor Co...
#
#                                                 camera
# 134  Primary Camera50MP Rear CameraDual Camera Lens...  \
# 99   Primary Camera108MP Rear CameraDual Camera Len...
#
#                                                display
# 134  Display Size16.33 cm (6.43 inch)Resolution2400...  \
# 99   Display Size17.07 cm (6.72 inch)Resolution2400...
#
#                                 network                   battery
# 134  Network Type5GSupported Networks5G  Battery Capacity4500 mAh
# 99   Network Type5GSupported Networks5G  Battery Capacity5000 mAh

# %%
df
# Out:
#                                                   name ratings    price
# 0        OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)     4.4  ₹17,676  \
# 1       OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)     4.4  ₹17,691
# 2             OnePlus 11R 5G (Galactic Silver, 256 GB)     4.5  ₹44,690
# 3             OnePlus 11R 5G (Galactic Silver, 128 GB)     4.5  ₹39,734
# 4                 OnePlus 11R 5G (Sonic Black, 256 GB)     4.5  ₹44,284
# ..                                                 ...     ...      ...
# 187                 OnePlus N20 SE (BLUE OASIS, 64 GB)     4.2  ₹15,674
# 188            OnePlus 9 Pro 5G (Morning Mist, 128 GB)     3.8  ₹47,999
# 189                   OnePlus 6 (Mirror Black, 128 GB)     4.2  ₹17,990
# 190  OnePlus 6T McLaren Edition (Speed Orange, 256 GB)     NaN  ₹26,990
# 191         OnePlus Nord CE 2 5G (Gray Mirror, 128 GB)     NaN  ₹24,990
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 187  https://rukminim2.flixcart.com/image/312/312/x...
# 188  https://rukminim2.flixcart.com/image/312/312/x...
# 189  https://rukminim2.flixcart.com/image/312/312/x...
# 190  https://rukminim2.flixcart.com/image/312/312/x...
# 191  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 0    Internal Storage128 GBRAM6 GBMemory Card Slot ...  \
# 1    Internal Storage128 GBRAM6 GBMemory Card Slot ...
# 2                       Internal Storage256 GBRAM16 GB
# 3                        Internal Storage128 GBRAM8 GB
# 4                       Internal Storage256 GBRAM16 GB
# ..                                                 ...
# 187  Internal Storage64 GBRAM4 GBMemory Card Slot T...
# 188                      Internal Storage128 GBRAM8 GB
# 189  Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 190  Internal Storage256 GBRAM10 GBMemory Card Slot...
# 191  Internal Storage128 GBRAM8 GBMemory Card Slot ...
#
#                                           os_processor
# 0    Operating SystemAndroid 10Processor CoreOcta C...  \
# 1    Operating SystemAndroid 13Processor CoreOcta C...
# 2    Operating SystemAndroid OxygenOS based on Andr...
# 3    Operating SystemAndroid OxygenOS based on Andr...
# 4    Operating SystemAndroid Oxygen OxygenOS based ...
# ..                                                 ...
# 187  Operating SystemAndroid Oxygen 12.1Processor C...
# 188  Operating SystemAndroid 11Processor CoreDual C...
# 189  Operating SystemAndroid Oreo 8.1Processor Core...
# 190  Operating SystemAndroid Oxygen 9Processor Core...
# 191  Operating SystemAndroid 11Processor CoreOcta C...
#
#                                                 camera
# 0                       Primary Camera64MP Rear Camera  \
# 1                       Primary Camera64MP Rear Camera
# 2    Primary Camera50MP Rear CameraDual Camera Lens...
# 3    Primary Camera50MP Rear CameraDual Camera Lens...
# 4    Primary Camera50MP Rear CameraDual Camera Lens...
# ..                                                 ...
# 187  Primary Camera50MP Rear CameraDual Camera Lens...
# 188  Primary Camera48MP Rear CameraDual Camera Lens...
# 189  Primary Camera AvailableYesPrimary Camera20MP ...
# 190  Primary Camera AvailableYesPrimary Camera20MP ...
# 191  Primary Camera50MP Rear CameraDual Camera Lens...
#
#                                                display
# 0    Display Size16.74 cm (6.59 inch)Resolution2412...  \
# 1    Display Size16.74 cm (6.59 inch)Resolution2412...
# 2    Display Size17.02 cm (6.7 inch)Resolution2772x...
# 3    Display Size17.02 cm (6.7 inch)Resolution2772x...
# 4    Display Size17.02 cm (6.7 inch)Resolution2772x...
# ..                                                 ...
# 187  Display Size16.66 cm (6.56 inch)Resolution1612...
# 188  Display Size17.02 cm (6.7 inch)Resolution3216 ...
# 189  Display Size15.95 cm (6.28 inch)Resolution1080...
# 190  Display Size16.28 cm (6.41 inch)Resolution2280...
# 191  Display Size16.33 cm (6.43 inch)Resolution2400...
#
#                                                network
# 0                   Network Type5GSupported Networks5G  \
# 1                   Network Type5GSupported Networks5G
# 2                   Network Type5GSupported Networks5G
# 3                   Network Type5GSupported Networks5G
# 4                   Network Type5GSupported Networks5G
# ..                                                 ...
# 187     Network Type4G VOLTESupported Networks4G VoLTE
# 188  Network Type5GSupported Networks4G LTE, GSM, C...
# 189  Network Type4GSupported Networks4G VoLTEWi-FiY...
# 190  Network Type4G VOLTE, 4GSupported Networks4G V...
# 191                 Network Type5GSupported Networks5G
#
#                       battery
# 0    Battery Capacity5000 mAh
# 1    Battery Capacity5000 mAh
# 2    Battery Capacity5000 mAh
# 3    Battery Capacity5000 mAh
# 4    Battery Capacity5000 mAh
# ..                        ...
# 187  Battery Capacity5000 mAh
# 188  Battery Capacity4500 mAh
# 189  Battery Capacity3300 mAh
# 190  Battery Capacity3300 mAh
# 191  Battery Capacity4500 mAh
#
# [192 rows x 10 columns]

# %%
print(os.getcwd())
os.chdir(r'd:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem')
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem\notebook\data_Ingestion\scraping
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem

# %%
df.to_csv(r'data\raw_data\one_pluse_mobile_new_data.csv',index=False)
