# %% [markdown]
# ## Extracting the pages

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
mi_mobiles_URL = 'https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1'
mi_mobiles_URL
# Out:
# 'https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1'

# %%
url_client = urlopen(mi_mobiles_URL) # I am going to see the all HTML content now in my PC because of this
url_client

# %%
url_client.code # if this is 200 this is its okk
# Out:
# 200

# %%
url_client.length
# Out:
# 144443

# %%
page = url_client.read()

# %%
html = bs(markup=page,features='html.parser')

# %%
html
# Out:
# <!DOCTYPE html>
# ...

# %%
thirty_mobiles = html.findAll(name='div',attrs={'class':'_1AtVbE col-12-12'})

# %%
thirty_mobiles[5]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBGHDXFKYSE5TPK" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/redmi-9a-sport-coral-green-32-gb/p/itm53bc6ebfe147b?pid=MOBGHDXFKYSE5TPK&amp;lid=LSTMOBGHDXFKYSE5TPKB0PNZI&amp;marketplace=FLIPKART&amp;q=mi+mobiles&amp;store=tyy%2F4io&amp;srno=s_1_4&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=6a24c93d-5e77-45a8-a601-038c6aab1d0e.MOBGHDXFKYSE5TPK.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=jz7a3mdf0w0000001689748278840&amp;qH=fe263b216b5e362a" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Redmi 9A Sport (Coral Green, 32 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/x/i/8/-original-imag7chxqqu7h5hs.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30
# ...

# %%
thirty_mobiles[5].div.div.div.find_all('div',)
# Out:
# [<a class="_1fQZEK" href="/redmi-9a-sport-coral-green-32-gb/p/itm53bc6ebfe147b?pid=MOBGHDXFKYSE5TPK&amp;lid=LSTMOBGHDXFKYSE5TPKB0PNZI&amp;marketplace=FLIPKART&amp;q=mi+mobiles&amp;store=tyy%2F4io&amp;srno=s_1_4&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=6a24c93d-5e77-45a8-a601-038c6aab1d0e.MOBGHDXFKYSE5TPK.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=jz7a3mdf0w0000001689748278840&amp;qH=fe263b216b5e362a" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Redmi 9A Sport (Coral Green, 32 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/x/i/8/-original-imag7chxqqu7h5hs.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</s
# ...

# %% [markdown]
# ## Again

# %%
mi_mobiles_URL = 'https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1'
mi_mobiles_URL
# Out:
# 'https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1'

# %%
next_page = soup.find('a',class_ = '_1LKTO3').get('href')

# %%
'https://www.flipkart.com' +next_page
# Out:
# 'https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2'

# %%
mi_mobiles_URL = 'https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1'

# %%
request = requests.get(mi_mobiles_URL)
request

soup = bs(request.text,'html.parser')
soup

# %%
mobile_names = soup.find_all('div',class_ = '_4rR01T')
mobile_names
# Out:
# [<div class="_4rR01T">REDMI 10 Power (Sporty Orange, 128 GB)</div>,
#  <div class="_4rR01T">Redmi 9A Sport (Carbon Black, 32 GB)</div>,
#  <div class="_4rR01T">Redmi 9A Sport (Metallic Blue, 32 GB)</div>,
#  <div class="_4rR01T">Redmi 9A Sport (Coral Green, 32 GB)</div>,
#  <div class="_4rR01T">Xiaomi 11Lite NE (Vinyl Black, 128 GB)</div>,
#  <div class="_4rR01T">Mi 11 Lite (Jazz Blue, 128 GB)</div>,
#  <div class="_4rR01T">Mi 11 Lite (Vinyl Black, 128 GB)</div>,
#  <div class="_4rR01T">Redmi 8A Dual (Sea Blue, 32 GB)</div>,
#  <div class="_4rR01T">Redmi 10 Prime (Phantom Black, 64 GB)</div>,
#  <div class="_4rR01T">Xiaomi 12 Pro 5G (Noir Black, 256 GB)</div>,
#  <div class="_4rR01T">Redmi 6 (Gold, 32 GB)</div>,
#  <div class="_4rR01T">Redmi 9A Sport (Coral Green, 32 GB)</div>,
#  <div class="_4rR01T">Redmi 9 (Carbon Black, 64 GB)</div>,
#  <div class="_4rR01T">Redmi 7A (Matte Blue, 32 GB)</div>,
#  <div class="_4rR01T">Mi 10T (Cosmic Black, 128 GB)</div>,
# ...

# %%
mobile_prices = soup.find_all('div',class_ = '_30jeq3 _1_WHN1')
for i ,j in zip(mobile_prices , mobile_names):
    print(i.text,'- ',j.text)
# mobile_prices
# Out:
# ₹12,990 -  REDMI 10 Power (Sporty Orange, 128 GB)
# ₹7,105 -  Redmi 9A Sport (Carbon Black, 32 GB)
# ₹7,530 -  Redmi 9A Sport (Metallic Blue, 32 GB)
# ₹8,490 -  Redmi 9A Sport (Coral Green, 32 GB)
# ₹21,650 -  Xiaomi 11Lite NE (Vinyl Black, 128 GB)
# ₹18,999 -  Mi 11 Lite (Jazz Blue, 128 GB)
# ₹18,999 -  Mi 11 Lite (Vinyl Black, 128 GB)
# ₹8,290 -  Redmi 8A Dual (Sea Blue, 32 GB)
# ₹11,990 -  Redmi 10 Prime (Phantom Black, 64 GB)
# ₹41,999 -  Xiaomi 12 Pro 5G (Noir Black, 256 GB)
# ₹8,999 -  Redmi 6 (Gold, 32 GB)
# ₹7,290 -  Redmi 9A Sport (Coral Green, 32 GB)
# ₹10,480 -  Redmi 9 (Carbon Black, 64 GB)
# ₹6,999 -  Redmi 7A (Matte Blue, 32 GB)
# ₹23,790 -  Mi 10T (Cosmic Black, 128 GB)
# ₹21,999 -  Mi 11 Lite (Vinyl Black, 128 GB)
# ₹8,999 -  Redmi 6 (Black, 32 GB)
# ₹44,999 -  Xiaomi 12 Pro 5G (Noir Black, 256 GB)
# ₹8,488 -  Redmi 9A Sport (Carbon Black, 32 GB)
# ₹11,990 -  Redmi 10 Prime (Astral White, 64 GB)
# ₹12,800 -  REDMI 10 Power (Power Black, 128 GB)
# ...

# %%
mobile_ratings = soup.find_all('div',class_ = '_3LWZlK')
mobile_ratings[0].text
# Out:
# '4.2'

# %%
complete_specs = soup.find_all()

# %%
box = soup.find('div',class_ = '_1YokD2 _3Mn1Gg')

# %%
box
# Out:
# <div class="_1YokD2 _3Mn1Gg" style="flex-grow:1;overflow:auto"><div class="_1YokD2 _2GoDe3 col-12-12" style="background-color:#ffffff;align-items:flex-end"><div class="_1AtVbE" style="flex-grow:1;overflow:auto"><div class="W_R1IA"><div class="_1MR4o5"><div class="_3GIHBu"><a class="_2whKao" href="/">Home</a><svg class="_39X-Og" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><div class="_3GIHBu"><a class="_2whKao" href="/mobiles-accessories/pr?sid=tyy&amp;marketplace=FLIPKART">Mobiles &amp; Accessories</a><svg class="_39X-Og" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><div class="_3GIHBu"><a class="_2whKao" href="/mobiles/pr?sid=tyy,4io&amp;marketplace=FLIPKART">Mobiles</a><svg clas
# ...
