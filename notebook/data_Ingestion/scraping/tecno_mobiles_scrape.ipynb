# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import os
import numpy as np
from itertools import zip_longest

# %%
def bs4_soup(pages):
    URL = f'https://www.flipkart.com/search?q=techno+mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={pages}'
    request = requests.get(URL)
    soup = bs(request.text,'html.parser')
    soup = soup.find('div',class_ = '_1YokD2 _3Mn1Gg')

    return soup , URL

# %%
def mob_specs(soup):
    names = soup.find_all('div', class_='_4rR01T')
    mob_names = [i.text if i else None for i in names]

    ratings = soup.find_all('div', class_='_3LWZlK')
    mob_ratings = [i.text if i else None for i in ratings]

    price = soup.find_all('div', class_='_30jeq3 _1_WHN1')
    mob_price = [i.text if i else None for i in price]

    img = soup.find_all('div', class_='CXW8mj')
    mob_img_URL = [i.find('img')['src'] if i.find('img') else None for i in img]

    return mob_names, mob_ratings, mob_price, mob_img_URL

# %%
def features_from_mob_links(soup):
    mobile_links = ['https://www.flipkart.com' + i['href'] for i in soup.find_all('a', class_='_1fQZEK')]
    mobile_req = [requests.get(url=i) for i in mobile_links]
    mobile_soup = [bs(i.text, 'html.parser').find('div', class_='_1YokD2 _2GoDe3') for i in mobile_req]
    mobile_specs_soup = [i.find_all('div', class_='_3k-BhJ') for i in mobile_soup]

    storage_ram = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Memory' in str(specs_.text) and 'Storage' in str(specs_.text)]
    storage_ram_cross_checked = [i for i in storage_ram if 'Internal' in i.split()]

    os_processor = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Os' in str(specs_.text) and 'Processor' in str(specs_.text)]
    os_processor_cross_checked = [i for i in os_processor if 'Operating' in i.split()]

    camera = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Camera' in str(specs_.text) and 'FeaturesPrimary' in str(specs_.text)]
    camera_cross_checked = [i for i in camera if 'Primary' and 'Camera' in i.split()]

    display = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Display' in str(specs_.text) and 'FeaturesDisplay' in str(specs_.text)]
    display_cross_checked = [i for i in display if 'Display' and 'cm' in i.split()]

    network = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Connectivity' in str(specs_.text) and 'FeaturesNetwork' in str(specs_.text)]
    network_cross_checked = [i for i in network if 'Network' in i.split()]

    battery = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Battery' in str(specs_.text) and 'FeaturesBattery' in str(specs_.text)]
    battery_cross_checked = [i for i in battery if 'Battery' in i.split()]

    return mobile_specs_soup, storage_ram_cross_checked, os_processor_cross_checked, camera_cross_checked, display_cross_checked, network_cross_checked, battery_cross_checked

# %%
def fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery):
    tuple_data = zip_longest(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery,fillvalue=np.nan)
    
    data = [i for i in tuple_data]
    return data

# %%
def print_len(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery):
    print(f"Length of mob_names: {len(mob_names)}")
    print(f"Length of mob_ratings: {len(mob_ratings)}")
    print(f"Length of mob_price: {len(mob_price)}")
    print(f"Length of mob_img_URL: {len(mob_img_URL)}")
    print(f"Length of storage_ram: {len(storage_ram)}")
    print(f"Length of os_processor: {len(os_processor)}")
    print(f"Length of camera: {len(camera)}")
    print(f"Length of display: {len(display)}")
    print(f"Length of network: {len(network)}")
    print(f"Length of battery: {len(battery)}")

# %%
df = pd.DataFrame()

page_start = 1
page_ends = 9

for pages in range(page_start, page_ends):

    soup, URL = bs4_soup(pages=pages)
    
    mob_names, mob_ratings, mob_price, mob_img_URL = mob_specs(soup)
    mobile_specs_soup, storage_ram, os_processor, camera, display, network, battery = features_from_mob_links(soup=soup)
    
    data = fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)

    if mobile_specs_soup is not None and soup is not None:
        
        print_len(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)

        page_df = pd.DataFrame(data=data,columns=['name', 'ratings', 'price', 'imgURL', 'storage_ram', 'camera',
       'oS_Processor', 'display', 'network', 'battery'])

        if not page_df.empty:
            df = pd.concat(objs=[df, page_df], ignore_index=True)
            print(f'scraping data from page:{pages}')
            print(f'working in {URL} Page')
            print(f'page df : page_shape : {page_df.shape} \n {page_df.sample(2)}')
            print(f'df : df shape : {df.shape} \n {df.sample(2)}')
            print()

    else:
        print(f"Skipping page {pages} due to empty mobile_specs_soup or soup.")
# Out:
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:1
# working in https://www.flipkart.com/search?q=techno+mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1 Page
# page df : page_shape : (24, 10)
#                                          name ratings    price
# 20   Tecno Phantom X (Summer Sunset, 256 GB)     4.3  ₹21,999  \
# 22  Tecno Spark Go 2022 (Iris Purple, 32 GB)     4.2   ₹6,999
#
#                                                imgURL
# 20  https://rukminim2.flixcart.com/image/312/312/x...  \
# 22  https://rukminim2.flixcart.com/image/312/312/l...
#
#                                           storage_ram
# 20  Internal Storage256 GBRAM8 GBMemory Card Slot ...  \
# 22  Internal Storage32 GBRAM2 GBMemory Card Slot T...
#
#                                                camera
# 20  Operating SystemAndroid 11Processor CoreDual C...  \
# 22  Operating System?HiOS 7.6 based on Android 11-...
#
#                                          oS_Processor
# 20  Primary Camera13MP Rear CameraDual Camera Lens...  \
# 22  Primary Camera13MP Rear CameraDual Camera Lens...
#
#                                               display
# 20  Display Size17.02 cm (6.7 inch)Resolution1080 ...  \
# 22  Display Size16.56 cm (6.52 inch)Resolution720 ...
#
#                                               network
# 20  Network Type4G VOLTESupported Networks4G LTE, ...  \
# 22  Network Type4GSupported Networks4G LTE, GSM, 4...
#
#                                               battery
# 20  Battery Capacity4700 mAhBattery TypeLi-Po 4700...
# 22                           Battery Capacity5000 mAh
# df : df shape : (24, 10)
#                                         name ratings    price
# 11  Tecno Camon 19 (Sea Salt White, 128 GB)     4.2  ₹14,699  \
# 1   Tecno Pop 5 Pro (Deepsea Luster, 32 GB)     4.2   ₹6,960
#
#                                                imgURL
# 11  https://rukminim2.flixcart.com/image/312/312/x...  \
# 1   https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 11  Internal Storage128 GBRAM6 GBExpandable Storag...  \
# 1   Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                                camera
# 11  Operating SystemAndroid 12Processor TypeMediaT...  \
# 1   Operating SystemAndroid 11 (Go Edition)Process...
#
#                                          oS_Processor
# 11  Primary Camera AvailableYesPrimary Camera64MP ...  \
# 1   Primary Camera AvailableYesPrimary Camera8MP R...
#
#                                               display
# 11  Display Size17.27 cm (6.8 inch)Resolution1080 ...  \
# 1   Display Size16.56 cm (6.52 inch)Resolution720 ...
#
#                                               network
# 11  Network Type4G VOLTE, 4GSupported Networks4G V...  \
# 1   Network Type4G VOLTE, 4GSupported Networks4G V...
#
#                                       battery
# 11  Battery Capacity5000 mAhBattery TypeLi-Po
# 1   Battery Capacity6000 mAhBattery TypeLi-Po
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:2
# working in https://www.flipkart.com/search?q=techno+mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2 Page
# page df : page_shape : (24, 10)
#                                            name ratings    price
# 12  Tecno Pova Neo 5G (Sapphire Black, 128 GB)     3.9  ₹15,499  \
# 18       Tecno Spark 10 5G (Meta Blue, 128 GB)     4.5  ₹14,198
#
#                                                imgURL
# 12  https://rukminim2.flixcart.com/image/312/312/x...  \
# 18  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 12  Internal Storage128 GBRAM4 GBExpandable Storag...  \
# 18  Internal Storage128 GBRAM8 GBMemory Card Slot ...
#
#                                                camera
# 12  Operating SystemAndroid 12Processor TypeMediaT...  \
# 18  Operating SystemAndroid 13Primary Clock Speed2...
#
#                                          oS_Processor
# 12  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 18  Primary Camera50MP Rear CameraDual Camera Lens...
#
#                                               display
# 12  Display Size17.27 cm (6.8 inch)Resolution1080 ...  \
# 18  Display Size16.76 cm (6.6 inch)Resolution1612 ...
#
#                                               network
# 12  Network Type4G, 4G VOLTE, 5GSupported Networks...  \
# 18         Network Type5GSupported Networks5G, 4G LTE
#
#                                       battery
# 12  Battery Capacity6000 mAhBattery TypeLi-Po
# 18                   Battery Capacity5000 mAh
# df : df shape : (48, 10)
#                                         name ratings   price
# 1   Tecno Pop 5 Pro (Deepsea Luster, 32 GB)     4.2  ₹6,960  \
# 46    Tecno Spark 9 (Infinity Black, 64 GB)       4  ₹9,999
#
#                                                imgURL
# 1   https://rukminim2.flixcart.com/image/312/312/k...  \
# 46  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 1   Internal Storage32 GBRAM3 GBExpandable Storage...  \
# 46  Internal Storage64 GBRAM3 GBExpandable Storage...
#
#                                                camera
# 1   Operating SystemAndroid 11 (Go Edition)Process...  \
# 46  Operating SystemAndroid 12Processor TypeMediaT...
#
#                                          oS_Processor
# 1   Primary Camera AvailableYesPrimary Camera8MP R...  \
# 46  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 1   Display Size16.56 cm (6.52 inch)Resolution720 ...  \
# 46  Display Size16.76 cm (6.6 inch)Resolution720 x...
#
#                                               network
# 1   Network Type4G VOLTE, 4GSupported Networks4G V...  \
# 46  Network Type4G VOLTE, 4GSupported Networks4G V...
#
#                                       battery
# 1   Battery Capacity6000 mAhBattery TypeLi-Po
# 46  Battery Capacity5000 mAhBattery TypeLi-Po
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:3
# working in https://www.flipkart.com/search?q=techno+mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3 Page
# page df : page_shape : (24, 10)
#                                          name ratings    price
# 19  Tecno Camon 20 Pro (Dark Welkin, 128 GB)     4.2  ₹20,349  \
# 22   Tecno Spark Power 2 (Misty Grey, 64 GB)     4.3  ₹11,999
#
#                                                imgURL
# 19  https://rukminim2.flixcart.com/image/312/312/x...  \
# 22  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 19  Internal Storage128 GBRAM8 GBExpandable Storag...  \
# 22  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                                camera
# 19  Operating SystemAndroid 13Processor TypeMediat...  \
# 22  Operating SystemAndroid 10Processor TypeMediaT...
#
#                                          oS_Processor
# 19  Primary Camera AvailableYesPrimary Camera64MP ...  \
# 22  Primary Camera AvailableYesPrimary Camera16 MP...
#
#                                               display
# 19  Display Size16.94 cm (6.67 inch)Resolution1080...  \
# 22  Display Size17.78 cm (7 inch)Resolution1640 x ...
#
#                                               network
# 19  Network Type5G, 4G VOLTE, 4GSupported Networks...  \
# 22  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                                       battery
# 19  Battery Capacity5000 mAhBattery TypeLi-Po
# 22                   Battery Capacity6000 mAh
# df : df shape : (72, 10)
#                                      name ratings   price
# 35  Tecno Spark 8 (Atlantic Blue, 64 GB)     4.1  ₹8,899  \
# 57   Tecno Pop 7 Pro (uyuni blue, 64 GB)     4.3  ₹7,299
#
#                                                imgURL
# 35  https://rukminim2.flixcart.com/image/312/312/k...  \
# 57  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 35  Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 57  Internal Storage64 GBRAM3 GBMemory Card Slot T...
#
#                                                camera
# 35  Operating SystemAndroid 11Processor TypeMediaT...  \
# 57  Operating SystemAndroid 12.0Primary Clock Spee...
#
#                                          oS_Processor
# 35  Primary Camera AvailableYesPrimary Camera16MP ...  \
# 57  Primary Camera50MP Rear CameraDual Camera Lens...
#
#                                               display
# 35  Display Size16.66 cm (6.56 inch)Resolution720 ...  \
# 57  Display Size16.66 cm (6.56 inch)Resolution1612...
#
#                                               network
# 35  Network Type4G VOLTE, 4GSupported Networks4G V...  \
# 57     Network Type4G VOLTESupported Networks4G VoLTE
#
#                                       battery
# 35  Battery Capacity5000 mAhBattery TypeLi-Po
# 57                   Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 20
# Length of mob_price: 23
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:4
# working in https://www.flipkart.com/search?q=techno+mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4 Page
# page df : page_shape : (24, 10)
#                                               name ratings    price
# 19  Tecno Spark 8 Pro (Interstellar Black, 64 GB)       4   ₹9,498  \
# 0             Tecno Spark 10 5G (Meta Blue, 4 GB)     4.5  ₹14,990
#
#                                                imgURL
# 19  https://rukminim2.flixcart.com/image/312/312/k...  \
# 0   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 19  Internal Storage64 GBRAM4 GBMemory Card Slot T...  \
# 0   Internal Storage4 GBRAM8 GBExpandable Storage1...
#
#                                                camera
# 19  Operating SystemAndroid Q 11Primary Clock Spee...  \
# 0   Operating SystemAndroid Q Android 13.0Processo...
#
#                                          oS_Processor
# 19  Primary Camera48MP Rear CameraDual Camera Lens...  \
# 0   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 19  Display Size17.27 cm (6.8 inch)Resolution1080 ...  \
# 0   Display Size14.12 cm (5.56 inch)Resolution720 ...
#
#                                               network
# 19  Network Type4G VOLTE, 4GSupported Networks4G V...  \
# 0   Network Type5G, 4G VOLTE, 4G, 3GSupported Netw...
#
#                      battery
# 19  Battery Capacity5000 mAh
# 0   Battery Capacity5000 mAh
# df : df shape : (96, 10)
#                                        name ratings    price
# 3        Tecno Pova 3 (Tech Silver, 64 GB)     4.2  ₹10,978  \
# 7  Tecno Pop 7 pro (?Endless Black, 64 GB)       4   ₹6,998
#
#                                               imgURL
# 3  https://rukminim2.flixcart.com/image/312/312/l...  \
# 7  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                          storage_ram
# 3  Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 7  Internal Storage64 GBRAM2 GBMemory Card Slot T...
#
#                                               camera
# 3  Operating SystemAndroid 12Processor TypeMediaT...  \
# 7  Operating SystemAndroid Android 12.0Processor ...
#
#                                         oS_Processor
# 3  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 7  Primary Camera12MP Rear CameraDual Camera Lens...
#
#                                              display
# 3  Display Size17.53 cm (6.9 inch)Resolution1080 ...  \
# 7  Display Size16.66 cm (6.56 inch)Resolution1612...
#
#                                              network
# 3  Network Type4G VOLTE, 4GSupported Networks4G V...  \
# 7     Network Type4G VOLTESupported Networks4G VoLTE
#
#                                      battery
# 3  Battery Capacity7000 mAhBattery TypeLi-Po
# 7                   Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:5
# working in https://www.flipkart.com/search?q=techno+mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5 Page
# page df : page_shape : (24, 10)
#                                       name ratings   price
# 1       Tecno Pop 5 Pro (Ice Blue, 32 GB)     4.2  ₹6,950  \
# 23  Tecno Spark 8 (Turquoise Cyan, 64 GB)     4.1  ₹8,598
#
#                                                imgURL
# 1   https://rukminim2.flixcart.com/image/312/312/k...  \
# 23  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 1   Internal Storage32 GBRAM3 GBExpandable Storage...  \
# 23  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                                camera
# 1   Operating SystemAndroid 11 (Go Edition)Process...  \
# 23  Operating SystemAndroid 11Processor TypeMediaT...
#
#                                          oS_Processor
# 1   Primary Camera AvailableYesPrimary Camera8MP R...  \
# 23  Primary Camera AvailableYesPrimary Camera16MP ...
#
#                                               display
# 1   Display Size16.56 cm (6.52 inch)Resolution720 ...  \
# 23  Display Size16.66 cm (6.56 inch)Resolution720 ...
#
#                                               network
# 1   Network Type4G VOLTE, 4GSupported Networks4G V...  \
# 23  Network Type4G VOLTE, 4GSupported Networks4G V...
#
#                                       battery
# 1   Battery Capacity6000 mAhBattery TypeLi-Po
# 23  Battery Capacity5000 mAhBattery TypeLi-Po
# df : df shape : (120, 10)
#                                       name ratings   price
# 118  Tecno Pop 7 pro (?Uyuni Blue, 64 GB)     4.3  ₹8,999  \
# 23      Tecno Spark 9 (Sky Mirror, 64 GB)       4  ₹8,390
#
#                                                 imgURL
# 118  https://rukminim2.flixcart.com/image/312/312/x...  \
# 23   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 118  Internal Storage64 GBRAM3 GBMemory Card Slot T...  \
# 23   Internal Storage64 GBRAM3 GBExpandable Storage...
#
#                                                 camera
# 118  Operating SystemAndroid Android 12.0Processor ...  \
# 23   Operating SystemAndroid 12Processor TypeMediaT...
#
#                                           oS_Processor
# 118  Primary Camera12MP Rear CameraDual Camera Lens...  \
# 23   Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                                display
# 118  Display Size16.66 cm (6.56 inch)Resolution1612...  \
# 23   Display Size16.76 cm (6.6 inch)Resolution720 x...
#
#                                                network
# 118     Network Type4G VOLTESupported Networks4G VoLTE  \
# 23   Network Type4G VOLTE, 4GSupported Networks4G V...
#
#                                        battery
# 118                   Battery Capacity5000 mAh
# 23   Battery Capacity5000 mAhBattery TypeLi-Po
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:6
# working in https://www.flipkart.com/search?q=techno+mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=6 Page
# page df : page_shape : (24, 10)
#                                        name ratings   price
# 21  Tecno Spark Go 2020 (Aqua Blue, 32 GB)     4.4  ₹6,999  \
# 17     Tecno SPARK 7 (spruce green, 64 GB)       4  ₹9,049
#
#                                                imgURL
# 21  https://rukminim2.flixcart.com/image/312/312/k...  \
# 17  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 21  Internal Storage32 GBRAM2 GBExpandable Storage...  \
# 17  Internal Storage64 GBRAM3 GBMemory Card Slot T...
#
#                                                camera
# 21  Operating SystemAndroid 10 (Go Edition)Process...  \
# 17  Operating SystemAndroid Q ANDROID 10Processor ...
#
#                                          oS_Processor
# 21  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 17  Primary Camera16MP Rear CameraDual Camera Lens...
#
#                                               display
# 21  Display Size16.56 cm (6.52 inch)Resolution1600...  \
# 17  Display Size16.51 cm (6.5 inch)Resolution720 x...
#
#                                               network
# 21  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 17     Network Type4G VOLTESupported Networks4G VoLTE
#
#                      battery
# 21  Battery Capacity5000 mAh
# 17  Battery Capacity6000 mAh
# df : df shape : (144, 10)
#                                      name ratings    price
# 87  Tecno Camon 19 Neo (Eco Black, 6 GB)     4.3  ₹13,999  \
# 81         Tecno Spark 10C (Black, 8 GB)     3.9   ₹9,999
#
#                                                imgURL
# 87  https://rukminim2.flixcart.com/image/312/312/x...  \
# 81  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 87  Internal Storage6 GBRAM128 GBMemory Card Slot ...  \
# 81  Internal Storage8 GBRAM128 GBMemory Card Slot ...
#
#                                                camera
# 87  Operating SystemAndroid Android 12Primary Cloc...  \
# 81  Operating SystemAndroid 12Primary Clock Speed2...
#
#                                          oS_Processor
# 87  Primary Camera48MP Rear CameraDual Camera Lens...  \
# 81  Primary Camera16MP Rear CameraDual Camera Lens...
#
#                                               display
# 87  Display Size17.27 cm (6.8 inch)Resolution2460x...  \
# 81  Display Size16.76 cm (6.6 inch)Resolution720 X...
#
#                                            network                   battery
# 87  Network Type2G, 3G, 4GSupported Networks4G LTE  Battery Capacity5000 mAh
# 81          Network Type4GSupported Networks4G LTE  Battery Capacity5000 mAh
#
# Length of mob_names: 8
# Length of mob_ratings: 7
# Length of mob_price: 8
# Length of mob_img_URL: 8
# Length of storage_ram: 8
# Length of os_processor: 8
# Length of camera: 8
# Length of display: 8
# Length of network: 8
# Length of battery: 8
# scraping data from page:7
# working in https://www.flipkart.com/search?q=techno+mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=7 Page
# page df : page_shape : (8, 10)
#                                          name ratings    price
# 5  Tecno Spark 10 Pro (Starry Black, 256 GB)     4.1  ₹14,999  \
# 0         Tecno Spark 7T (Jewel Blue, 64 GB)     4.2   ₹8,999
#
#                                               imgURL
# 5  https://rukminim2.flixcart.com/image/312/312/x...  \
# 0  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                          storage_ram
# 5  Internal Storage256 GBRAM8 GBExpandable Storag...  \
# 0  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                               camera
# 5  Operating SystemAndroid 13Processor TypeMediat...  \
# 0  Operating SystemAndroid Andriod 11Processor Ty...
#
#                                         oS_Processor
# 5  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 0  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                              display
# 5  Display Size17.22 cm (6.78 inch)Resolution2460...  \
# 0  Display Size16.56 cm (6.52 inch)Resolution720 ...
#
#                                              network
# 5  Network Type4G VOLTE, 4GSupported Networks4G V...  \
# 0  Network Type4GSupported Networks4G LTE, 4G VoL...
#
#                                      battery
# 5  Battery Capacity5000 mAhBattery TypeLi-Po
# 0  Battery Capacity6000 mAhBattery TypeLi-Po
# df : df shape : (152, 10)
#                                       name ratings    price
# 118  Tecno Pop 7 pro (?Uyuni Blue, 64 GB)     4.3   ₹8,999  \
# 2         Tecno Pova 3 (Eco Black, 64 GB)     4.2  ₹10,849
#
#                                                 imgURL
# 118  https://rukminim2.flixcart.com/image/312/312/x...  \
# 2    https://rukminim2.flixcart.com/image/312/312/l...
#
#                                            storage_ram
# 118  Internal Storage64 GBRAM3 GBMemory Card Slot T...  \
# 2    Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                                 camera
# 118  Operating SystemAndroid Android 12.0Processor ...  \
# 2    Operating SystemAndroid 12Processor TypeMediaT...
#
#                                           oS_Processor
# 118  Primary Camera12MP Rear CameraDual Camera Lens...  \
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                                display
# 118  Display Size16.66 cm (6.56 inch)Resolution1612...  \
# 2    Display Size17.53 cm (6.9 inch)Resolution1080 ...
#
#                                                network
# 118     Network Type4G VOLTESupported Networks4G VoLTE  \
# 2    Network Type4G VOLTE, 4GSupported Networks4G V...
#
#                                        battery
# 118                   Battery Capacity5000 mAh
# 2    Battery Capacity7000 mAhBattery TypeLi-Po
#
# Length of mob_names: 0
# Length of mob_ratings: 0
# Length of mob_price: 0
# Length of mob_img_URL: 0
# Length of storage_ram: 0
# Length of os_processor: 0
# Length of camera: 0
# Length of display: 0
# Length of network: 0
# Length of battery: 0

# %%
df
# Out:
#                                           name ratings    price
# 0             Tecno Pova 3 (Eco Black, 128 GB)     4.1  ₹13,998  \
# 1      Tecno Pop 5 Pro (Deepsea Luster, 32 GB)     4.2   ₹6,960
# 2              Tecno Pova 3 (Eco Black, 64 GB)     4.2  ₹10,849
# 3            Tecno Pova 3 (Tech Silver, 64 GB)     4.2  ₹10,978
# 4    Tecno Spark Go 2023 (UYUNI BLUE, 32+3 GB)     4.1   ₹6,750
# ..                                         ...     ...      ...
# 147         Tecno Camon 15 (SHOAL GOLD, 64 GB)     4.2  ₹12,499
# 148           Tecno Camon 19 Neo (Green, 6 GB)     4.1  ₹18,490
# 149  Tecno Spark 10 Pro (Starry Black, 256 GB)     4.1  ₹14,999
# 150   Tecno Spark 10 Pro (Pearl White, 256 GB)     4.1  ₹14,999
# 151       Tecno Spark 10 pro (Meta Blue, 8 GB)     NaN  ₹13,999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/l...  \
# 1    https://rukminim2.flixcart.com/image/312/312/k...
# 2    https://rukminim2.flixcart.com/image/312/312/l...
# 3    https://rukminim2.flixcart.com/image/312/312/l...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 147  https://rukminim2.flixcart.com/image/312/312/k...
# 148  https://rukminim2.flixcart.com/image/312/312/x...
# 149  https://rukminim2.flixcart.com/image/312/312/x...
# 150  https://rukminim2.flixcart.com/image/312/312/x...
# 151  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 0    Internal Storage128 GBRAM6 GBExpandable Storag...  \
# 1    Internal Storage32 GBRAM3 GBExpandable Storage...
# 2    Internal Storage64 GBRAM4 GBExpandable Storage...
# 3    Internal Storage64 GBRAM4 GBExpandable Storage...
# 4    Internal Storage32+3 GBRAM3 GBMemory Card Slot...
# ..                                                 ...
# 147  Internal Storage64 GBRAM4 GBExpandable Storage...
# 148  Internal Storage6 GBRAM128 GBMemory Card Slot ...
# 149  Internal Storage256 GBRAM8 GBExpandable Storag...
# 150  Internal Storage256 GBRAM8 GBExpandable Storag...
# 151  Internal Storage8 GBRAM8 GBMemory Card Slot Ty...
#
#                                                 camera
# 0    Operating SystemAndroid 12Processor TypeMediaT...  \
# 1    Operating SystemAndroid 11 (Go Edition)Process...
# 2    Operating SystemAndroid 12Processor TypeMediaT...
# 3    Operating SystemAndroid 12Processor TypeMediaT...
# 4    Operating SystemAndroid 12Primary Clock Speed2...
# ..                                                 ...
# 147  Operating SystemAndroid 10Processor TypeHelio ...
# 148  Operating SystemAndroid Android 12Primary Cloc...
# 149  Operating SystemAndroid 13Processor TypeMediat...
# 150  Operating SystemAndroid 13Processor TypeMediat...
# 151  Operating SystemAndroid 13Primary Clock Speed2...
#
#                                           oS_Processor
# 0    Primary Camera AvailableYesPrimary Camera50MP ...  \
# 1    Primary Camera AvailableYesPrimary Camera8MP R...
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
# 3    Primary Camera AvailableYesPrimary Camera50MP ...
# 4    Primary Camera13MP Rear CameraDual Camera Lens...
# ..                                                 ...
# 147  Primary Camera AvailableYesPrimary Camera48MP ...
# 148  Primary Camera48MP Rear CameraDual Camera Lens...
# 149  Primary Camera AvailableYesPrimary Camera50MP ...
# 150  Primary Camera AvailableYesPrimary Camera50MP ...
# 151  Primary Camera50MP Rear CameraDual Camera Lens...
#
#                                                display
# 0    Display Size17.53 cm (6.9 inch)Resolution1080 ...  \
# 1    Display Size16.56 cm (6.52 inch)Resolution720 ...
# 2    Display Size17.53 cm (6.9 inch)Resolution1080 ...
# 3    Display Size17.53 cm (6.9 inch)Resolution1080 ...
# 4    Display Size16.66 cm (6.56 inch)Resolution720x...
# ..                                                 ...
# 147  Display Size16.64 cm (6.55 inch)Resolution720 ...
# 148  Display Size17.27 cm (6.8 inch)Resolution2460x...
# 149  Display Size17.22 cm (6.78 inch)Resolution2460...
# 150  Display Size17.22 cm (6.78 inch)Resolution2460...
# 151  Display Size17.27 cm (6.8 inch)Resolution1080 ...
#
#                                                network
# 0    Network Type4G VOLTE, 4GSupported Networks4G V...  \
# 1    Network Type4G VOLTE, 4GSupported Networks4G V...
# 2    Network Type4G VOLTE, 4GSupported Networks4G V...
# 3    Network Type4G VOLTE, 4GSupported Networks4G V...
# 4       Network Type4G VOLTESupported Networks4G VoLTE
# ..                                                 ...
# 147  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 148     Network Type2G, 3G, 4GSupported Networks4G LTE
# 149  Network Type4G VOLTE, 4GSupported Networks4G V...
# 150  Network Type4G VOLTE, 4GSupported Networks4G V...
# 151  Network Type4GSupported Networks4G LTE, GSM, W...
#
#                                                battery
# 0       Battery Capacity7000 mAhBattery TypeLi-Polymer
# 1            Battery Capacity6000 mAhBattery TypeLi-Po
# 2            Battery Capacity7000 mAhBattery TypeLi-Po
# 3            Battery Capacity7000 mAhBattery TypeLi-Po
# 4                             Battery Capacity5000 mAh
# ..                                                 ...
# 147                           Battery Capacity5000 mAh
# 148                           Battery Capacity5000 mAh
# 149          Battery Capacity5000 mAhBattery TypeLi-Po
# 150          Battery Capacity5000 mAhBattery TypeLi-Po
# 151  Battery Capacity5000 mAhBattery TypeNon-Remova...
#
# [152 rows x 10 columns]

# %%
print(os.getcwd())
os.chdir(r'd:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem')
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem

# %%
df['imgURL'][0]
# Out:
# 'https://rukminim2.flixcart.com/image/312/312/l55nekw0/mobile/g/i/s/pova-3-lf7-tecno-original-imagfw48vgyzg5hw.jpeg?q=70'

# %%
df.to_csv(r'data\raw_data\techno_mobile_data.csv',index=False)
