# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import os
import numpy as np
from itertools import zip_longest

# %%
def bs4_soup(pages):
    URL = f'https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={pages}'
    request = requests.get(URL)
    soup = bs(request.text,'html.parser')
    soup = soup.find('div',class_ = '_1YokD2 _3Mn1Gg')

    return soup , URL

# %%
def mob_specs(soup):
    names = soup.find_all('div', class_='_4rR01T')
    mob_names = [i.text if i else None for i in names]

    ratings = soup.find_all('div', class_='_3LWZlK')
    mob_ratings = [i.text if i else None for i in ratings]

    price = soup.find_all('div', class_='_30jeq3 _1_WHN1')
    mob_price = [i.text if i else None for i in price]

    img = soup.find_all('div', class_='CXW8mj')
    mob_img_URL = [i.find('img')['src'] if i.find('img') else None for i in img]

    return mob_names, mob_ratings, mob_price, mob_img_URL

# %%
def features_from_mob_links(soup):
    mobile_links = ['https://www.flipkart.com' + i['href'] for i in soup.find_all('a', class_='_1fQZEK')]
    mobile_req = [requests.get(url=i) for i in mobile_links]
    mobile_soup = [bs(i.text, 'html.parser').find('div', class_='_1YokD2 _2GoDe3') for i in mobile_req]
    mobile_specs_soup = [i.find_all('div', class_='_3k-BhJ') for i in mobile_soup]

    storage_ram = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Memory' in str(specs_.text) and 'Storage' in str(specs_.text)]
    storage_ram_cross_checked = [i for i in storage_ram if 'Internal' in i.split()]

    os_processor = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Os' in str(specs_.text) and 'Processor' in str(specs_.text)]
    os_processor_cross_checked = [i for i in os_processor if 'Operating' in i.split()]

    camera = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Camera' in str(specs_.text) and 'FeaturesPrimary' in str(specs_.text)]
    camera_cross_checked = [i for i in camera if 'Primary' and 'Camera' in i.split()]

    display = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Display' in str(specs_.text) and 'FeaturesDisplay' in str(specs_.text)]
    display_cross_checked = [i for i in display if 'Display' and 'cm' in i.split()]

    network = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Connectivity' in str(specs_.text) and 'FeaturesNetwork' in str(specs_.text)]
    network_cross_checked = [i for i in network if 'Network' in i.split()]

    battery = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Battery' in str(specs_.text) and 'FeaturesBattery' in str(specs_.text)]
    battery_cross_checked = [i for i in battery if 'Battery' in i.split()]

    return mobile_specs_soup, storage_ram_cross_checked, os_processor_cross_checked, camera_cross_checked, display_cross_checked, network_cross_checked, battery_cross_checked

# %%
def fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery):
    tuple_data = zip_longest(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery,fillvalue=np.nan)
    
    data = [i for i in tuple_data]
    return data

# %%
def print_len(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery):
    print(f"Length of mob_names: {len(mob_names)}")
    print(f"Length of mob_ratings: {len(mob_ratings)}")
    print(f"Length of mob_price: {len(mob_price)}")
    print(f"Length of mob_img_URL: {len(mob_img_URL)}")
    print(f"Length of storage_ram: {len(storage_ram)}")
    print(f"Length of os_processor: {len(os_processor)}")
    print(f"Length of camera: {len(camera)}")
    print(f"Length of display: {len(display)}")
    print(f"Length of network: {len(network)}")
    print(f"Length of battery: {len(battery)}")

# %%
df = pd.DataFrame()

page_start = 1

for pages in range(page_start, 14):

    soup, URL = bs4_soup(pages=pages)
    
    mob_names, mob_ratings, mob_price, mob_img_URL = mob_specs(soup)
    mobile_specs_soup, storage_ram, os_processor, camera, display, network, battery = features_from_mob_links(soup=soup)
    
    data = fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)

    if mobile_specs_soup is not None and soup is not None:
        
        print_len(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)

        page_df = pd.DataFrame(data=data,columns=['name', 'ratings', 'price', 'imgURL', 'storage_ram', 'camera',
       'oS_Processor', 'display', 'network', 'battery'])

        if not page_df.empty:
            df = pd.concat(objs=[df, page_df], ignore_index=True)
            print(f'scraping data from page:{pages}')
            print(f'working in {URL} Page')
            print(f'page df : page_shape : {page_df.shape} \n {page_df.sample(2)}')
            print(f'df : df shape : {df.shape} \n {df.sample(2)}')
            print()

    else:
        print(f"Skipping page {pages} due to empty mobile_specs_soup or soup.")
# Out:
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:1
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1 Page
# page df : page_shape : (24, 10)
#                                  name ratings    price
# 15     vivo Y02 (Cosmic Grey, 32 GB)     4.3   ₹8,499  \
# 11  vivo T2 5G (Nitro Blaze, 128 GB)     4.4  ₹18,999
#
#                                                imgURL
# 15  https://rukminim2.flixcart.com/image/312/312/x...  \
# 11  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 15  Internal Storage32 GBRAM3 GBSupported Memory C...  \
# 11  Internal Storage128 GBRAM6 GBMemory Card Slot ...
#
#                                                camera
# 15  Operating SystemAndroid 12Processor TypeMediaT...  \
# 11  Operating SystemAndroid 13Processor TypeSnapdr...
#
#                                          oS_Processor
# 15  Primary Camera AvailableYesPrimary Camera8MP R...  \
# 11  Primary Camera AvailableYesPrimary Camera64 MP...
#
#                                               display
# 15  Display Size16.54 cm (6.51 inch)Resolution1600...  \
# 11  Display Size16.21 cm (6.38 inch)Resolution2400...
#
#                                               network
# 15  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 11  Network Type5G, 4G, 3GSupported Networks5G, 4G...
#
#                                         battery
# 15                     Battery Capacity5000 mAh
# 11  Battery Capacity4500 mAhBattery TypeLithium
# df : df shape : (24, 10)
#                                   name ratings    price
# 13      vivo Y02 (Orchid Blue, 32 GB)     4.3   ₹8,499  \
# 5   vivo T2x 5G (Aurora Gold, 128 GB)     4.4  ₹12,999
#
#                                                imgURL
# 13  https://rukminim2.flixcart.com/image/312/312/x...  \
# 5   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 13  Internal Storage32 GBRAM3 GBSupported Memory C...  \
# 5   Internal Storage128 GBRAM4 GBMemory Card Slot ...
#
#                                                camera
# 13  Operating SystemAndroid 12Processor TypeMediaT...  \
# 5   Operating SystemAndroid 13Processor TypeDimens...
#
#                                          oS_Processor
# 13  Primary Camera AvailableYesPrimary Camera8MP R...  \
# 5   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 13  Display Size16.54 cm (6.51 inch)Resolution1600...  \
# 5   Display Size16.71 cm (6.58 inch)Resolution2408...
#
#                                               network
# 13  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 5   Network Type5G, 4G, 3GSupported Networks5G, 4G...
#
#                                         battery
# 13                     Battery Capacity5000 mAh
# 5   Battery Capacity5000 mAhBattery TypeLithium
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:2
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2 Page
# page df : page_shape : (24, 10)
#                                      name ratings    price
# 23       vivo Y16 (Steller Black, 64 GB)     4.3  ₹12,600  \
# 10  vivo Y56 5G (Orange Shimmer, 128 GB)     4.2  ₹19,999
#
#                                                imgURL
# 23  https://rukminim2.flixcart.com/image/312/312/x...  \
# 10  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 23  Internal Storage64 GBRAM4 GBMemory Card Slot T...  \
# 10  Internal Storage128 GBRAM8 GBSupported Memory ...
#
#                                                camera
# 23  Operating SystemAndroid Android 12Processor Co...  \
# 10  Operating SystemAndroid 13Processor TypeMediat...
#
#                                          oS_Processor
# 23  Primary Camera13MP Rear CameraDual Camera Lens...  \
# 10  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 23  Display Size16.54 cm (6.51 inch)Resolution1600...  \
# 10  Display Size16.71 cm (6.58 inch)Resolution2408...
#
#                                               network
# 23     Network Type4G, 3G, 2GSupported Networks4G LTE  \
# 10  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                      battery
# 23  Battery Capacity5000 mAh
# 10  Battery Capacity5000 mAh
# df : df shape : (48, 10)
#                                       name ratings    price
# 20       vivo Y33s (Mirror Black, 128 GB)     4.3  ₹15,774  \
# 33  vivo T1 44W (Midnight Galaxy, 128 GB)     4.4  ₹15,999
#
#                                                imgURL
# 20  https://rukminim2.flixcart.com/image/312/312/k...  \
# 33  https://rukminim2.flixcart.com/image/312/312/l...
#
#                                           storage_ram
# 20  Internal Storage128 GBRAM8 GBExpandable Storag...  \
# 33  Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                                camera
# 20  Operating SystemAndroid 11Processor TypeMediaT...  \
# 33  Operating SystemAndroid 12Processor TypeQualco...
#
#                                          oS_Processor
# 20  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 33  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 20  Display Size16.71 cm (6.58 inch)Resolution2408...  \
# 33  Display Size16.36 cm (6.44 inch)Resolution2400...
#
#                                               network
# 20  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 33  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 20  Battery Capacity5000 mAh
# 33  Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:3
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3 Page
# page df : page_shape : (24, 10)
#                                      name ratings    price
# 14       vivo Y21T (Pearl White, 128 GB)     4.4  ₹15,390  \
# 19  vivo V23 5G (Stardust Black, 256 GB)     4.3  ₹32,979
#
#                                                imgURL
# 14  https://rukminim2.flixcart.com/image/312/312/x...  \
# 19  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 14  Internal Storage128 GBRAM4 GBExpandable Storag...  \
# 19  Internal Storage256 GBRAM12 GBSupported Memory...
#
#                                                camera
# 14  Operating SystemAndroid 11Processor TypeQualco...  \
# 19  Operating SystemAndroid 12Processor TypeMediat...
#
#                                          oS_Processor
# 14  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 19  Primary Camera AvailableYesPrimary Camera64MP ...
#
#                                               display
# 14  Display Size16.71 cm (6.58 inch)Resolution2400...  \
# 19  Display Size16.36 cm (6.44 inch)Resolution2400...
#
#                                               network
# 14  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 19  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                      battery
# 14  Battery Capacity5000 mAh
# 19  Battery Capacity4200 mAh
# df : df shape : (72, 10)
#                                   name ratings    price
# 13      vivo Y02 (Orchid Blue, 32 GB)     4.3   ₹8,499  \
# 7   vivo T2x 5G (Aurora Gold, 128 GB)     4.4  ₹13,999
#
#                                                imgURL
# 13  https://rukminim2.flixcart.com/image/312/312/x...  \
# 7   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 13  Internal Storage32 GBRAM3 GBSupported Memory C...  \
# 7   Internal Storage128 GBRAM6 GBMemory Card Slot ...
#
#                                                camera
# 13  Operating SystemAndroid 12Processor TypeMediaT...  \
# 7   Operating SystemAndroid 13Processor TypeDimens...
#
#                                          oS_Processor
# 13  Primary Camera AvailableYesPrimary Camera8MP R...  \
# 7   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 13  Display Size16.54 cm (6.51 inch)Resolution1600...  \
# 7   Display Size16.71 cm (6.58 inch)Resolution2408...
#
#                                               network
# 13  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 7   Network Type5G, 4G, 3GSupported Networks5G, 4G...
#
#                                         battery
# 13                     Battery Capacity5000 mAh
# 7   Battery Capacity5000 mAhBattery TypeLithium
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:4
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4 Page
# page df : page_shape : (24, 10)
#                                      name ratings    price
# 16  vivo T1 5G (Rainbow Fantasy, 128 GB)     4.4  ₹18,990  \
# 21        vivo T1 44W (Ice Dawn, 128 GB)     4.4  ₹19,999
#
#                                                imgURL
# 16  https://rukminim2.flixcart.com/image/312/312/k...  \
# 21  https://rukminim2.flixcart.com/image/312/312/l...
#
#                                           storage_ram
# 16  Internal Storage128 GBRAM6 GBExpandable Storag...  \
# 21  Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                                camera
# 16  Operating SystemAndroid 12Processor TypeQualco...  \
# 21  Operating SystemAndroid 12Processor TypeQualco...
#
#                                          oS_Processor
# 16  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 21  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 16  Display Size16.71 cm (6.58 inch)Resolution2408...  \
# 21  Display Size16.36 cm (6.44 inch)Resolution2400...
#
#                                               network
# 16  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 21  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 16  Battery Capacity5000 mAh
# 21  Battery Capacity5000 mAh
# df : df shape : (96, 10)
#                                     name ratings    price
# 45  vivo T1 Pro 5G (Turbo Cyan, 128 GB)     4.4  ₹23,999  \
# 5     vivo T2x 5G (Aurora Gold, 128 GB)     4.4  ₹12,999
#
#                                                imgURL
# 45  https://rukminim2.flixcart.com/image/312/312/l...  \
# 5   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 45  Internal Storage128 GBRAM6 GBMemory Card Slot ...  \
# 5   Internal Storage128 GBRAM4 GBMemory Card Slot ...
#
#                                                camera
# 45  Operating SystemAndroid 12Processor TypeQualco...  \
# 5   Operating SystemAndroid 13Processor TypeDimens...
#
#                                          oS_Processor
# 45  Primary Camera AvailableYesPrimary Camera64MP ...  \
# 5   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 45  Display Size16.36 cm (6.44 inch)Resolution2404...  \
# 5   Display Size16.71 cm (6.58 inch)Resolution2408...
#
#                                               network
# 45  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 5   Network Type5G, 4G, 3GSupported Networks5G, 4G...
#
#                                         battery
# 45                     Battery Capacity4700 mAh
# 5   Battery Capacity5000 mAhBattery TypeLithium
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:5
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5 Page
# page df : page_shape : (24, 10)
#                               name ratings    price
# 2   vivo T1X (Space Blue, 128 GB)     4.5  ₹16,999  \
# 12  vivo Y1s (Olive Black, 32 GB)     4.3   ₹9,999
#
#                                                imgURL
# 2   https://rukminim2.flixcart.com/image/312/312/x...  \
# 12  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 2   Internal Storage128 GBRAM4 GBSupported Memory ...  \
# 12  Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                                camera
# 2   Operating SystemAndroid 12Processor TypeQualco...  \
# 12  Operating SystemAndroid 10Processor TypeMediaT...
#
#                                          oS_Processor
# 2   Primary Camera AvailableYesPrimary Camera50MP ...  \
# 12  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 2   Display Size16.71 cm (6.58 inch)Resolution2408...  \
# 12  Display Size15.8 cm (6.22 inch)Resolution1520 ...
#
#                                               network
# 2   Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 12  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 2   Battery Capacity5000 mAh
# 12  Battery Capacity4030 mAh
# df : df shape : (120, 10)
#                                       name ratings    price
# 46   vivo T1 Pro 5G (Turbo Black, 128 GB)     4.4  ₹24,999  \
# 108         vivo Y1s (Olive Black, 32 GB)     4.3   ₹9,999
#
#                                                 imgURL
# 46   https://rukminim2.flixcart.com/image/312/312/l...  \
# 108  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 46   Internal Storage128 GBRAM8 GBMemory Card Slot ...  \
# 108  Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                                 camera
# 46   Operating SystemAndroid 12Processor TypeQualco...  \
# 108  Operating SystemAndroid 10Processor TypeMediaT...
#
#                                           oS_Processor
# 46   Primary Camera AvailableYesPrimary Camera64MP ...  \
# 108  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                                display
# 46   Display Size16.36 cm (6.44 inch)Resolution2404...  \
# 108  Display Size15.8 cm (6.22 inch)Resolution1520 ...
#
#                                                network
# 46   Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 108  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                       battery
# 46   Battery Capacity4700 mAh
# 108  Battery Capacity4030 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 23
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:6
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=6 Page
# page df : page_shape : (24, 10)
#                                        name ratings    price
# 14         vivo V21 5G (Dusk Blue, 256 GB)     4.3  ₹27,490  \
# 2   vivo V25 Pro 5G (Sailing Blue, 128 GB)     4.3  ₹31,500
#
#                                                imgURL
# 14  https://rukminim2.flixcart.com/image/312/312/k...  \
# 2   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 14  Internal Storage256 GBRAM8 GBSupported Memory ...  \
# 2     Internal Storage128 GBRAM8 GBCall Log MemoryYes
#
#                                                camera
# 14  Operating SystemAndroid 11Processor TypeMediaT...  \
# 2   Operating SystemAndroid 12Processor TypeMediat...
#
#                                          oS_Processor
# 14  Primary Camera AvailableYesPrimary Camera64MP ...  \
# 2   Primary Camera AvailableYesPrimary Camera64MP ...
#
#                                               display
# 14  Display Size16.36 cm (6.44 inch)Resolution2404...  \
# 2   Display Size16.66 cm (6.56 inch)Resolution2376...
#
#                                               network
# 14  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 2   Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                      battery
# 14  Battery Capacity4000 mAh
# 2   Battery Capacity4830 mAh
# df : df shape : (144, 10)
#                                  name ratings    price
# 10  vivo T2 5G (Nitro Blaze, 128 GB)     4.4  ₹20,999  \
# 16  vivo V27 5G (Magic Blue, 128 GB)     4.4  ₹32,999
#
#                                                imgURL
# 10  https://rukminim2.flixcart.com/image/312/312/x...  \
# 16  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 10  Internal Storage128 GBRAM8 GBMemory Card Slot ...  \
# 16                      Internal Storage128 GBRAM8 GB
#
#                                                camera
# 10  Operating SystemAndroid 13Processor TypeSnapdr...  \
# 16  Operating SystemAndroid 13Processor TypeMediat...
#
#                                          oS_Processor
# 10  Primary Camera AvailableYesPrimary Camera64 MP...  \
# 16  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 10  Display Size16.21 cm (6.38 inch)Resolution2400...  \
# 16  Display Size17.22 cm (6.78 Inch)Resolution2400...
#
#                                               network
# 10  Network Type5G, 4G, 3GSupported Networks5G, 4G...  \
# 16  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                                         battery
# 10  Battery Capacity4500 mAhBattery TypeLithium
# 16                     Battery Capacity4600 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 20
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:7
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=7 Page
# page df : page_shape : (24, 10)
#                                   name ratings    price
# 15  vivo Y27 (Burgundy Black, 128 GB)     4.3  ₹14,999  \
# 21     vivo Y91 (Starry Black, 32 GB)     NaN  ₹10,990
#
#                                                imgURL
# 15  https://rukminim2.flixcart.com/image/312/312/x...  \
# 21  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 15  Internal Storage128 GBRAM6 GBSupported Memory ...  \
# 21  Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                                camera
# 15  Operating SystemAndroid 13Processor TypeHelio ...  \
# 21  Operating SystemAndroid Oreo 8.1Processor Type...
#
#                                          oS_Processor
# 15  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 21  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 15  Display Size16.87 cm (6.64 inch)Resolution2388...  \
# 21  Display Size15.8 cm (6.22 inch)Resolution1520 ...
#
#                                               network
# 15  Network Type2G, 3G, 4GSupported Networks4G LTE...  \
# 21  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
#
#                                        battery
# 15                    Battery Capacity5000 mAh
# 21  Battery Capacity4030 mAhBattery TypeLi-ion
# df : df shape : (168, 10)
#                                       name ratings    price
# 60   vivo V25 Pro 5G (Pure Black, 128 GB)     4.3  ₹35,999  \
# 104  vivo V23e 5G (Midnight Blue, 128 GB)     4.2  ₹24,999
#
#                                                 imgURL
# 60   https://rukminim2.flixcart.com/image/312/312/x...  \
# 104  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 60     Internal Storage128 GBRAM8 GBCall Log MemoryYes  \
# 104  Internal Storage128 GBRAM8 GBExpandable Storag...
#
#                                                 camera
# 60   Operating SystemAndroid 12Processor TypeMediat...  \
# 104  Operating SystemAndroid 12Processor TypeMediat...
#
#                                           oS_Processor
# 60   Primary Camera AvailableYesPrimary Camera64MP ...  \
# 104  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                                display
# 60   Display Size16.66 cm (6.56 inch)Resolution2376...  \
# 104  Display Size16.36 cm (6.44 inch)Resolution2400...
#
#                                                network
# 60   Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 104  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                       battery
# 60   Battery Capacity4830 mAh
# 104  Battery Capacity4050 mAh
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 9
#       5 for pages in range(page_start, 14):
#       7     soup, URL = bs4_soup(pages=pages)
# ----> 9     mob_names, mob_ratings, mob_price, mob_img_URL = mob_specs(soup)
#      10     mobile_specs_soup, storage_ram, os_processor, camera, display, network, battery = features_from_mob_links(soup=soup)
#      12     data = fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)
#
# Cell In[3], line 2, in mob_specs(soup)
#       1 def mob_specs(soup):
# ----> 2     names = soup.find_all('div', class_='_4rR01T')
#       3     mob_names = [i.text if i else None for i in names]
#       5     ratings = soup.find_all('div', class_='_3LWZlK')
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
print(os.getcwd())
os.chdir(r'd:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem')
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem\notebook\data_Ingestion\scraping
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem

# %%
df.isnull().sum()
# Out:
# name            0
# ratings         5
# price           1
# imgURL          0
# storage_ram     0
# camera          0
# oS_Processor    0
# display         0
# network         0
# battery         0
# dtype: int64

# %%
df.to_csv(r'data\raw_data\vivo_mobile_data.csv',index=False)
