# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import os
import numpy as np
from itertools import zip_longest

# %%
def bs4_soup(pages):
    URL = f'https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={pages}'
    request = requests.get(URL)
    soup = bs(request.text,'html.parser')
    soup = soup.find('div',class_ = '_1YokD2 _3Mn1Gg')

    return soup , URL

# %%
def mob_specs(soup):
    names = soup.find_all('div', class_='_4rR01T')
    mob_names = [i.text if i else None for i in names]

    ratings = soup.find_all('div', class_='_3LWZlK')
    mob_ratings = [i.text if i else None for i in ratings]

    price = soup.find_all('div', class_='_30jeq3 _1_WHN1')
    mob_price = [i.text if i else None for i in price]

    img = soup.find_all('div', class_='CXW8mj')
    mob_img_URL = [i.find('img')['src'] if i.find('img') else None for i in img]

    return mob_names, mob_ratings, mob_price, mob_img_URL

# %%
def features_from_mob_links(soup):
    mobile_links = ['https://www.flipkart.com' + i['href'] for i in soup.find_all('a', class_='_1fQZEK')]
    mobile_req = [requests.get(url=i) for i in mobile_links]
    mobile_soup = [bs(i.text, 'html.parser').find('div', class_='_1YokD2 _2GoDe3') for i in mobile_req]
    mobile_specs_soup = [i.find_all('div', class_='_3k-BhJ') for i in mobile_soup]

    storage_ram = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Memory' in str(specs_.text) and 'Storage' in str(specs_.text)]
    storage_ram_cross_checked = [i for i in storage_ram if 'Internal' in i.split()]

    os_processor = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Os' in str(specs_.text) and 'Processor' in str(specs_.text)]
    os_processor_cross_checked = [i for i in os_processor if 'Operating' in i.split()]

    camera = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Camera' in str(specs_.text) and 'FeaturesPrimary' in str(specs_.text)]
    camera_cross_checked = [i for i in camera if 'Primary' and 'Camera' in i.split()]

    display = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Display' in str(specs_.text) and 'FeaturesDisplay' in str(specs_.text)]
    display_cross_checked = [i for i in display if 'Display' and 'cm' in i.split()]

    network = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Connectivity' in str(specs_.text) and 'FeaturesNetwork' in str(specs_.text)]
    network_cross_checked = [i for i in network if 'Network' in i.split()]

    battery = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Battery' in str(specs_.text) and 'FeaturesBattery' in str(specs_.text)]
    battery_cross_checked = [i for i in battery if 'Battery' in i.split()]

    return mobile_specs_soup, storage_ram_cross_checked, os_processor_cross_checked, camera_cross_checked, display_cross_checked, network_cross_checked, battery_cross_checked

# %%
def fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery):
    tuple_data = zip_longest(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery,fillvalue=np.nan)
    
    data = [i for i in tuple_data]
    return data

# %%
def print_len(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery):
    print(f"Length of mob_names: {len(mob_names)}")
    print(f"Length of mob_ratings: {len(mob_ratings)}")
    print(f"Length of mob_price: {len(mob_price)}")
    print(f"Length of mob_img_URL: {len(mob_img_URL)}")
    print(f"Length of storage_ram: {len(storage_ram)}")
    print(f"Length of os_processor: {len(os_processor)}")
    print(f"Length of camera: {len(camera)}")
    print(f"Length of display: {len(display)}")
    print(f"Length of network: {len(network)}")
    print(f"Length of battery: {len(battery)}")

# %%
df = pd.DataFrame()

page_start = 1

for pages in range(page_start, 14):

    soup, URL = bs4_soup(pages=pages)
    
    mob_names, mob_ratings, mob_price, mob_img_URL = mob_specs(soup)
    mobile_specs_soup, storage_ram, os_processor, camera, display, network, battery = features_from_mob_links(soup=soup)
    
    data = fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)

    if mobile_specs_soup is not None and soup is not None:
        
        print_len(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)

        page_df = pd.DataFrame(data=data,columns=['name', 'ratings', 'price', 'imgURL', 'storage_ram', 'camera',
       'oS_Processor', 'display', 'network', 'battery'])

        if not page_df.empty:
            df = pd.concat(objs=[df, page_df], ignore_index=True)
            print(f'scraping data from page:{pages}')
            print(f'working in {URL} Page')
            print(f'page df : page_shape : {page_df.shape} \n {page_df.sample(2)}')
            print(f'df : df shape : {df.shape} \n {df.sample(2)}')
            print()

    else:
        print(f"Skipping page {pages} due to empty mobile_specs_soup or soup.")
# Out:
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:1
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1 Page
# page df : page_shape : (24, 10)
#                                     name ratings    price
# 1   vivo T2x 5G (Glimmer Black, 128 GB)     4.4  ₹13,999  \
# 17     vivo V27 5G (Magic Blue, 128 GB)     4.4  ₹32,999
#
#                                                imgURL
# 1   https://rukminim2.flixcart.com/image/312/312/x...  \
# 17  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 1   Internal Storage128 GBRAM6 GBMemory Card Slot ...  \
# 17                      Internal Storage128 GBRAM8 GB
#
#                                                camera
# 1   Operating SystemAndroid 13Processor TypeDimens...  \
# 17  Operating SystemAndroid 13Processor TypeMediat...
#
#                                          oS_Processor
# 1   Primary Camera AvailableYesPrimary Camera50MP ...  \
# 17  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 1   Display Size16.71 cm (6.58 inch)Resolution2408...  \
# 17  Display Size17.22 cm (6.78 Inch)Resolution2400...
#
#                                               network
# 1   Network Type5G, 4G, 3GSupported Networks5G, 4G...  \
# 17  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                                         battery
# 1   Battery Capacity5000 mAhBattery TypeLithium
# 17                     Battery Capacity4600 mAh
# df : df shape : (24, 10)
#                                    name ratings    price
# 5    vivo T2x 5G (Marine Blue, 128 GB)     4.3  ₹15,999  \
# 23  vivo Y56 5G (Black Engine, 128 GB)     4.2  ₹19,999
#
#                                                imgURL
# 5   https://rukminim2.flixcart.com/image/312/312/x...  \
# 23  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 5   Internal Storage128 GBRAM8 GBMemory Card Slot ...  \
# 23  Internal Storage128 GBRAM8 GBSupported Memory ...
#
#                                                camera
# 5   Operating SystemAndroid 13Processor TypeDimens...  \
# 23  Operating SystemAndroid 13Processor TypeMediat...
#
#                                          oS_Processor
# 5   Primary Camera AvailableYesPrimary Camera50MP ...  \
# 23  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 5   Display Size16.71 cm (6.58 inch)Resolution2408...  \
# 23  Display Size16.71 cm (6.58 inch)Resolution2408...
#
#                                               network
# 5   Network Type5G, 4G, 3GSupported Networks5G, 4G...  \
# 23  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                                         battery
# 5   Battery Capacity5000 mAhBattery TypeLithium
# 23                     Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:2
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2 Page
# page df : page_shape : (24, 10)
#                                       name ratings    price
# 17        vivo Y16 (Steller Black, 64 GB)     4.2  ₹10,999  \
# 7   vivo T1 44W (Midnight Galaxy, 128 GB)     4.3  ₹17,999
#
#                                                imgURL
# 17  https://rukminim2.flixcart.com/image/312/312/x...  \
# 7   https://rukminim2.flixcart.com/image/312/312/l...
#
#                                           storage_ram
# 17  Internal Storage64 GBRAM3 GBExpandable Storage...  \
# 7   Internal Storage128 GBRAM8 GBExpandable Storag...
#
#                                                camera
# 17  Operating SystemAndroid 12Processor TypeMediat...  \
# 7   Operating SystemAndroid 12Processor TypeQualco...
#
#                                          oS_Processor
# 17  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 7   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 17  Display Size16.54 cm (6.51 inch)Resolution1600...  \
# 7   Display Size16.36 cm (6.44 inch)Resolution2400...
#
#                                               network
# 17  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 7   Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 17  Battery Capacity5000 mAh
# 7   Battery Capacity5000 mAh
# df : df shape : (48, 10)
#                                   name ratings    price
# 42  vivo Y100A (Pacific Blue, 256 GB)     4.4  ₹25,999  \
# 37   vivo Y16 (Drizzling Gold, 64 GB)     4.2  ₹10,499
#
#                                                imgURL
# 42  https://rukminim2.flixcart.com/image/312/312/x...  \
# 37  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 42  Internal Storage256 GBRAM8 GBMemory Card Slot ...  \
# 37  Internal Storage64 GBRAM3 GBExpandable Storage...
#
#                                                camera
# 42  Operating SystemAndroid 13Processor TypeSnapdr...  \
# 37  Operating SystemAndroid 12Processor TypeMediat...
#
#                                          oS_Processor
# 42  Primary Camera AvailableYesPrimary Camera64MP ...  \
# 37  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 42  Display Size16.21 cm (6.38 inch)Resolution2400...  \
# 37  Display Size16.54 cm (6.51 inch)Resolution1600...
#
#                                               network
# 42  Network Type3G, 4G, 5GSupported Networks4G LTE...  \
# 37  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                                         battery
# 42  Battery Capacity4500 mAhBattery TypeLithium
# 37                     Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:3
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3 Page
# page df : page_shape : (24, 10)
#                                      name ratings    price
# 14     vivo Y565G (Black Engine, 128 GB)     4.3  ₹19,999  \
# 11  vivo Y100 5G (Twilight Gold, 128 GB)     4.3  ₹23,999
#
#                                                imgURL
# 14  https://rukminim2.flixcart.com/image/312/312/x...  \
# 11  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 14  Internal Storage128 GBRAM8 GBMemory Card Slot ...  \
# 11  Internal Storage128 GBRAM8 GBSupported Memory ...
#
#                                                camera
# 14  Operating SystemAndroid Q Funtouch OS 13 (Base...  \
# 11  Operating SystemAndroid 13Processor TypeMediat...
#
#                                          oS_Processor
# 14  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 11  Primary Camera AvailableYesPrimary Camera64MP ...
#
#                                               display
# 14  Display Size16.71 cm (6.58 inch)Resolution2408...  \
# 11  Display Size16.21 cm (6.38 inch)Resolution2400...
#
#                                               network
# 14  Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...  \
# 11  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                      battery
# 14  Battery Capacity5000 mAh
# 11  Battery Capacity4500 mAh
# df : df shape : (72, 10)
#                                    name ratings    price
# 11  vivo T2 5G (Velocity Wave, 128 GB)     4.4  ₹18,999  \
# 34    vivo T1 44W (Starry Sky, 128 GB)     4.4  ₹15,999
#
#                                                imgURL
# 11  https://rukminim2.flixcart.com/image/312/312/x...  \
# 34  https://rukminim2.flixcart.com/image/312/312/l...
#
#                                           storage_ram
# 11  Internal Storage128 GBRAM6 GBMemory Card Slot ...  \
# 34  Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                                camera
# 11  Operating SystemAndroid 13Processor TypeSnapdr...  \
# 34  Operating SystemAndroid 12Processor TypeQualco...
#
#                                          oS_Processor
# 11  Primary Camera AvailableYesPrimary Camera64 MP...  \
# 34  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 11  Display Size16.21 cm (6.38 inch)Resolution2400...  \
# 34  Display Size16.36 cm (6.44 inch)Resolution2400...
#
#                                               network
# 11  Network Type5G, 4G, 3GSupported Networks5G, 4G...  \
# 34  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                                         battery
# 11  Battery Capacity4500 mAhBattery TypeLithium
# 34                     Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:4
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4 Page
# page df : page_shape : (24, 10)
#                                    name ratings    price
# 15  vivo X70 Pro (Aurora Dawn, 256 GB)     4.4  ₹44,999  \
# 19     vivo V21 5G (Dusk Blue, 128 GB)     4.3  ₹27,990
#
#                                                imgURL
# 15  https://rukminim2.flixcart.com/image/312/312/k...  \
# 19  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 15   Internal Storage256 GBRAM12 GBCall Log MemoryYes  \
# 19  Internal Storage128 GBRAM8 GBSupported Memory ...
#
#                                                camera
# 15  Operating SystemAndroid 11Processor TypeMediaT...  \
# 19  Operating SystemAndroid 11Processor TypeMediaT...
#
#                                          oS_Processor
# 15  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 19  Primary Camera AvailableYesPrimary Camera64MP ...
#
#                                               display
# 15  Display Size16.66 cm (6.56 inch)Resolution2376...  \
# 19  Display Size16.36 cm (6.44 inch)Resolution2404...
#
#                                               network
# 15  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 19  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                      battery
# 15  Battery Capacity4450 mAh
# 19  Battery Capacity4000 mAh
# df : df shape : (96, 10)
#                                      name ratings    price
# 68  vivo V23 5G (Stardust Black, 256 GB)     4.3  ₹32,979  \
# 69      vivo T1X (Gravity Black, 128 GB)     4.4  ₹14,999
#
#                                                imgURL
# 68  https://rukminim2.flixcart.com/image/312/312/k...  \
# 69  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 68  Internal Storage256 GBRAM12 GBSupported Memory...  \
# 69  Internal Storage128 GBRAM6 GBSupported Memory ...
#
#                                                camera
# 68  Operating SystemAndroid 12Processor TypeMediat...  \
# 69  Operating SystemAndroid 12Processor TypeQualco...
#
#                                          oS_Processor
# 68  Primary Camera AvailableYesPrimary Camera64MP ...  \
# 69  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 68  Display Size16.36 cm (6.44 inch)Resolution2400...  \
# 69  Display Size16.71 cm (6.58 inch)Resolution2408...
#
#                                               network
# 68  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 69  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 68  Battery Capacity4200 mAh
# 69  Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 22
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:5
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5 Page
# page df : page_shape : (24, 10)
#                                         name ratings    price
# 5          vivo Y21E (Midnight Blue, 64 GB)     4.2  ₹12,490  \
# 6  vivo V23 Pro 5G (Stardust Black, 128 GB)     4.3  ₹38,990
#
#                                               imgURL
# 5  https://rukminim2.flixcart.com/image/312/312/k...  \
# 6  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                          storage_ram
# 5  Internal Storage64 GBRAM3 GBMemory Card Slot T...  \
# 6  Internal Storage128 GBRAM8 GBExpandable Storag...
#
#                                               camera
# 5  Operating SystemAndroid Q 11Processor CoreOcta...  \
# 6  Operating SystemAndroid 12Processor TypeMediat...
#
#                                         oS_Processor
# 5  Primary Camera13MP Rear CameraDual Camera Lens...  \
# 6  Primary Camera AvailableYesPrimary Camera108MP...
#
#                                              display
# 5  Display Size16.54 cm (6.51 inch)Resolution720 ...  \
# 6  Display Size16.66 cm (6.56 inch)Resolution2376...
#
#                                              network                   battery
# 5  Network Type4G VOLTE, 4G, 3GSupported Networks...  Battery Capacity5000 mAh
# 6  Network Type5G, 4G, 3G, 2GSupported Networks5G...  Battery Capacity4300 mAh
# df : df shape : (120, 10)
#                                       name ratings    price
# 77  vivo V27 Pro 5G (Noble Black, 256 GB)     4.4  ₹39,999  \
# 41        vivo Y16 (Steller Black, 64 GB)     4.2  ₹10,999
#
#                                                imgURL
# 77  https://rukminim2.flixcart.com/image/312/312/x...  \
# 41  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 77    Internal Storage256 GBRAM8 GBCall Log MemoryYes  \
# 41  Internal Storage64 GBRAM3 GBExpandable Storage...
#
#                                                camera
# 77  Operating SystemAndroid 13Processor TypeMediat...  \
# 41  Operating SystemAndroid 12Processor TypeMediat...
#
#                                          oS_Processor
# 77  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 41  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 77  Display Size17.22 cm (6.78 inch)Resolution2400...  \
# 41  Display Size16.54 cm (6.51 inch)Resolution1600...
#
#                                               network
# 77  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 41  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 77  Battery Capacity4600 mAh
# 41  Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 22
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:6
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=6 Page
# page df : page_shape : (24, 10)
#                                        name ratings    price
# 22       vivo X90 (Asteroid Black, 256 GB)     NaN  ₹59,999  \
# 10  vivo V25 Pro 5G (Sailing Blue, 128 GB)     3.9  ₹29,990
#
#                                                imgURL
# 22  https://rukminim2.flixcart.com/image/312/312/x...  \
# 10  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                         storage_ram
# 22  Internal Storage256 GBRAM8 GBCall Log MemoryYes  \
# 10  Internal Storage128 GBRAM8 GBCall Log MemoryYes
#
#                                                camera
# 22  Operating SystemAndroid 13Processor TypeDimens...  \
# 10  Operating SystemAndroid 12Processor TypeMediat...
#
#                                          oS_Processor
# 22  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 10  Primary Camera AvailableYesPrimary Camera64MP ...
#
#                                               display
# 22  Display Size17.22 cm (6.78 inch)Resolution2800...  \
# 10  Display Size16.66 cm (6.56 inch)Resolution2376...
#
#                                               network
# 22  Network Type2G, 3G, 4G, 5GSupported Networks4G...  \
# 10  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                                         battery
# 22  Battery Capacity4810 mAhBattery TypeLithium
# 10                     Battery Capacity4830 mAh
# df : df shape : (144, 10)
#                                       name ratings    price
# 31  vivo T1 44W (Midnight Galaxy, 128 GB)     4.3  ₹17,999  \
# 28    vivo V25 5G (Elegant Black, 256 GB)     4.2  ₹27,990
#
#                                                imgURL
# 31  https://rukminim2.flixcart.com/image/312/312/l...  \
# 28  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 31  Internal Storage128 GBRAM8 GBExpandable Storag...  \
# 28   Internal Storage256 GBRAM12 GBCall Log MemoryYes
#
#                                                camera
# 31  Operating SystemAndroid 12Processor TypeQualco...  \
# 28  Operating SystemAndroid 12Processor TypeMediat...
#
#                                          oS_Processor
# 31  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 28  Primary Camera AvailableYesPrimary Camera64MP ...
#
#                                               display
# 31  Display Size16.36 cm (6.44 inch)Resolution2400...  \
# 28  Display Size16.36 cm (6.44 inch)Resolution2408...
#
#                                               network
# 31  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 28  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                      battery
# 31  Battery Capacity5000 mAh
# 28  Battery Capacity4500 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 22
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:7
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=7 Page
# page df : page_shape : (24, 10)
#                                  name ratings    price
# 20  vivo Z1Pro (Mirror Black, 64 GB)     4.5  ₹15,990  \
# 0            vivo Y81 (Black, 32 GB)     4.4  ₹13,990
#
#                                                imgURL
# 20  https://rukminim2.flixcart.com/image/312/312/k...  \
# 0   https://rukminim2.flixcart.com/image/312/312/j...
#
#                                           storage_ram
# 20  Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 0   Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                                camera
# 20  Operating SystemAndroid Pie 9Processor TypeQua...  \
# 0   Operating SystemAndroid Oreo 8.1Processor Type...
#
#                                          oS_Processor
# 20  Primary Camera AvailableYesPrimary Camera16MP ...  \
# 0   Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 20  Display Size16.59 cm (6.53 inch)Resolution2340...  \
# 0   Display Size15.49 cm (6.1 inch)Resolution1520 ...
#
#                                               network
# 20  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...  \
# 0   Network Type3G, 4G VOLTE, 2GSupported Networks...
#
#                                        battery
# 20  Battery Capacity5000 mAhBattery TypeLi-ion
# 0                     Battery Capacity3260 mAh
# df : df shape : (168, 10)
#                                    name ratings    price
# 22  vivo Y56 5G (Black Engine, 128 GB)     4.2  ₹17,999  \
# 95       vivo Y1s (Olive Black, 32 GB)     4.3   ₹9,999
#
#                                                imgURL
# 22  https://rukminim2.flixcart.com/image/312/312/x...  \
# 95  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 22  Internal Storage128 GBRAM4 GBSupported Memory ...  \
# 95  Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                                camera
# 22  Operating SystemAndroid 13Processor TypeMediat...  \
# 95  Operating SystemAndroid 10Processor TypeMediaT...
#
#                                          oS_Processor
# 22  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 95  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 22  Display Size16.71 cm (6.58 inch)Resolution2408...  \
# 95  Display Size15.8 cm (6.22 inch)Resolution1520 ...
#
#                                               network
# 22  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 95  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 22  Battery Capacity5000 mAh
# 95  Battery Capacity4030 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 23
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:8
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=8 Page
# page df : page_shape : (24, 10)
#                                 name ratings    price
# 16   vivo Y20A (Nebula Blue, 64 GB)     4.4  ₹12,990  \
# 14  vivo Y36 (Meteor Black, 128 GB)     4.3  ₹16,999
#
#                                                imgURL
# 16  https://rukminim2.flixcart.com/image/312/312/k...  \
# 14  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 16  Internal Storage64 GBRAM3 GBExpandable Storage...  \
# 14  Internal Storage128 GBRAM8 GBSupported Memory ...
#
#                                                camera
# 16  Operating SystemAndroid 10Processor TypeQualco...  \
# 14  Operating SystemAndroid 13Processor TypeSnapdr...
#
#                                          oS_Processor
# 16  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 14  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 16  Display Size16.54 cm (6.51 inch)Resolution1600...  \
# 14  Display Size16.87 cm (6.64 inch)Resolution2388...
#
#                                               network
# 16  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 14  Network Type2G, 3G, 4GSupported Networks4G LTE...
#
#                      battery
# 16  Battery Capacity5000 mAh
# 14  Battery Capacity5000 mAh
# df : df shape : (192, 10)
#                                        name ratings    price
# 86     vivo V21 5G (Sunset Dazzle, 128 GB)     4.3  ₹27,990  \
# 155  vivo Y100 A 5G (Pacific Blue, 256 GB)     3.9  ₹27,250
#
#                                                 imgURL
# 86   https://rukminim2.flixcart.com/image/312/312/k...  \
# 155  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 86   Internal Storage128 GBRAM8 GBSupported Memory ...  \
# 155  Internal Storage256 GBRAM8 GBExpandable Storag...
#
#                                                 camera
# 86   Operating SystemAndroid 11Processor TypeMediaT...  \
# 155  Operating SystemAndroid 13Processor TypeMediat...
#
#                                           oS_Processor
# 86   Primary Camera AvailableYesPrimary Camera64MP ...  \
# 155  Primary Camera AvailableYesPrimary Camera64MP ...
#
#                                                display
# 86   Display Size16.36 cm (6.44 inch)Resolution2404...  \
# 155  Display Size16.21 cm (6.38 inch)Resolution2400...
#
#                                                network
# 86   Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 155  Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...
#
#                       battery
# 86   Battery Capacity4000 mAh
# 155  Battery Capacity4500 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:9
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=9 Page
# page df : page_shape : (24, 10)
#                                  name ratings    price
# 14     vivo S1 (Skyline Blue, 64 GB)     4.5  ₹20,990  \
# 20  vivo Y20 (Obsidian Black, 64 GB)     4.4  ₹16,999
#
#                                                imgURL
# 14  https://rukminim2.flixcart.com/image/312/312/k...  \
# 20  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 14  Internal Storage64 GBRAM6 GBExpandable Storage...  \
# 20  Internal Storage64 GBRAM6 GBExpandable Storage...
#
#                                                camera
# 14  Operating SystemAndroid Pie 9Processor TypeHel...  \
# 20  Operating SystemAndroid 10Processor TypeQualco...
#
#                                          oS_Processor
# 14  Primary Camera AvailableYesPrimary Camera16MP ...  \
# 20  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 14  Display Size16.21 cm (6.38 inch)Resolution1080...  \
# 20  Display Size16.54 cm (6.51 inch)Resolution1600...
#
#                                               network
# 14  Network Type3G, 4G, 2GSupported NetworksGSM, W...  \
# 20  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                      battery
# 14  Battery Capacity4500 mAh
# 20  Battery Capacity5000 mAh
# df : df shape : (216, 10)
#                                    name ratings    price
# 96   vivo X60 (Midnight Black, 128 GB)     4.4  ₹37,990  \
# 182    vivo Y36 (Meteor Black, 128 GB)     4.3  ₹16,999
#
#                                                 imgURL
# 96   https://rukminim2.flixcart.com/image/312/312/k...  \
# 182  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 96     Internal Storage128 GBRAM8 GBCall Log MemoryYes  \
# 182  Internal Storage128 GBRAM8 GBSupported Memory ...
#
#                                                 camera
# 96   Operating SystemAndroid 11Processor TypeQualco...  \
# 182  Operating SystemAndroid 13Processor TypeSnapdr...
#
#                                           oS_Processor
# 96   Primary Camera AvailableYesPrimary Camera48MP ...  \
# 182  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                                display
# 96   Display Size16.66 cm (6.56 inch)Resolution2376...  \
# 182  Display Size16.87 cm (6.64 inch)Resolution2388...
#
#                                                network
# 96   Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 182  Network Type2G, 3G, 4GSupported Networks4G LTE...
#
#                       battery
# 96   Battery Capacity4300 mAh
# 182  Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:10
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=10 Page
# page df : page_shape : (24, 10)
#                                name ratings    price
# 11  vivo Y20T (Purist Blue, 64 GB)     4.3  ₹14,990  \
# 15   vivo Y1S (Olive Black, 32 GB)     3.8   ₹8,399
#
#                                                imgURL
# 11  https://rukminim2.flixcart.com/image/312/312/k...  \
# 15  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 11  Internal Storage64 GBRAM6 GBExpandable Storage...  \
# 15  Internal Storage32 GBRAM2 GBMemory Card Slot T...
#
#                                                camera
# 11  Operating SystemAndroid 11Processor TypeQualco...  \
# 15  Operating SystemAndroid 10Processor CoreOcta C...
#
#                                          oS_Processor
# 11  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 15                     Primary Camera13MP Rear Camera
#
#                                               display
# 11  Display Size16.54 cm (6.51 inch)Resolution1600...  \
# 15  Display Size15.8 cm (6.22 inch)Resolution1520 ...
#
#                                               network
# 11  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 15  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                      battery
# 11  Battery Capacity5000 mAh
# 15  Battery Capacity4030 mAh
# df : df shape : (240, 10)
#                                      name ratings    price
# 107  vivo X80 pro (Cosmic Black, 256 GB)     4.3  ₹59,890  \
# 5      vivo T2x 5G (Marine Blue, 128 GB)     4.3  ₹15,999
#
#                                                 imgURL
# 107  https://rukminim2.flixcart.com/image/312/312/x...  \
# 5    https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 107  Internal Storage256 GBRAM12 GBMemory Card Slot...  \
# 5    Internal Storage128 GBRAM8 GBMemory Card Slot ...
#
#                                                 camera
# 107  Operating SystemAndroid Android 12Processor Co...  \
# 5    Operating SystemAndroid 13Processor TypeDimens...
#
#                                           oS_Processor
# 107  Primary Camera50MP Rear CameraDual Camera Lens...  \
# 5    Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                                display
# 107  Display Size17.22 cm (6.78 inch)Resolution3200...  \
# 5    Display Size16.71 cm (6.58 inch)Resolution2408...
#
#                                                network
# 107                 Network Type5GSupported Networks5G  \
# 5    Network Type5G, 4G, 3GSupported Networks5G, 4G...
#
#                                          battery
# 107                     Battery Capacity4700 mAh
# 5    Battery Capacity5000 mAhBattery TypeLithium
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:11
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=11 Page
# page df : page_shape : (24, 10)
#                                   name ratings    price
# 17  vivo V27 5G (Noble Black, 256 GB)     4.4  ₹40,999  \
# 5        vivo Y3s (Mint Green, 32 GB)     4.3   ₹9,490
#
#                                                imgURL
# 17  https://rukminim2.flixcart.com/image/312/312/x...  \
# 5   https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 17                     Internal Storage256 GBRAM12 GB  \
# 5   Internal Storage32 GBRAM2 GBExpandable Storage...
#
#                                                camera
# 17  Operating SystemAndroid 13Processor TypeMediat...  \
# 5   Operating SystemAndroid 11Processor TypeMediat...
#
#                                          oS_Processor
# 17  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 5   Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 17  Display Size17.22 cm (6.78 Inch)Resolution2400...  \
# 5   Display Size16.54 cm (6.51 inch)Resolution1600...
#
#                                               network
# 17  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 5   Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 17  Battery Capacity4600 mAh
# 5   Battery Capacity5000 mAh
# df : df shape : (264, 10)
#                                       name ratings    price
# 166  vivo V11 (Starry Night Black, 64 GB)     NaN  ₹24,990  \
# 63         vivo Y35 (Agate Black, 128 GB)     4.4  ₹16,999
#
#                                                 imgURL
# 166  https://rukminim2.flixcart.com/image/312/312/j...  \
# 63   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 166  Internal Storage64 GBRAM6 GBExpandable Storage...  \
# 63   Internal Storage128 GBRAM8 GBSupported Memory ...
#
#                                                 camera
# 166  Operating SystemAndroid Oreo 8.1Processor Type...  \
# 63   Operating SystemAndroid 12Processor TypeQualco...
#
#                                           oS_Processor
# 166  Primary Camera AvailableYesPrimary Camera16MP ...  \
# 63   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                                display
# 166  Display Size16.0 cm (6.3 inch)Resolution2280 x...  \
# 63   Display Size16.71 cm (6.58 inch)Resolution2408...
#
#                                                network
# 166  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...  \
# 63   Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                                         battery
# 166  Battery Capacity3315 mAhBattery TypeLi-ion
# 63                     Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:12
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=12 Page
# page df : page_shape : (24, 10)
#                                name ratings    price
# 21   vivo X50 (Frost Blue, 128 GB)     4.3  ₹26,999  \
# 10  vivo V9 (Sapphire Blue, 64 GB)     4.5  ₹23,990
#
#                                                imgURL
# 21  https://rukminim2.flixcart.com/image/312/312/k...  \
# 10  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                           storage_ram
# 21                      Internal Storage128 GBRAM8 GB  \
# 10  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                                camera
# 21  Operating SystemAndroid 10Processor TypeQualco...  \
# 10  Operating SystemAndroid Oreo 8.1Processor Type...
#
#                                          oS_Processor
# 21  Primary Camera AvailableYesPrimary Camera48MP ...  \
# 10  Primary Camera AvailableYesPrimary Camera16MP ...
#
#                                               display
# 21  Display Size16.66 cm (6.56 inch)Resolution2376...  \
# 10  Display Size16.0 cm (6.3 inch)Resolution2280 x...
#
#                                               network
# 21  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 10  Network Type3G, 4G VOLTE, 2GSupported Networks...
#
#                      battery
# 21  Battery Capacity4200 mAh
# 10  Battery Capacity3260 mAh
# df : df shape : (288, 10)
#                                  name ratings    price
# 184   vivo Y20A (Nebula Blue, 64 GB)     4.4  ₹12,990  \
# 139  vivo V21 5G (Dusk Blue, 256 GB)     4.2  ₹27,490
#
#                                                 imgURL
# 184  https://rukminim2.flixcart.com/image/312/312/k...  \
# 139  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 184  Internal Storage64 GBRAM3 GBExpandable Storage...  \
# 139  Internal Storage256 GBRAM8 GBSupported Memory ...
#
#                                                 camera
# 184  Operating SystemAndroid 10Processor TypeQualco...  \
# 139  Operating SystemAndroid 11Processor TypeMediaT...
#
#                                           oS_Processor
# 184  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 139  Primary Camera AvailableYesPrimary Camera64MP ...
#
#                                                display
# 184  Display Size16.54 cm (6.51 inch)Resolution1600...  \
# 139  Display Size16.36 cm (6.44 inch)Resolution2404...
#
#                                                network
# 184  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 139  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                       battery
# 184  Battery Capacity5000 mAh
# 139  Battery Capacity4000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:13
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=13 Page
# page df : page_shape : (24, 10)
#                                     name ratings    price
# 5   vivo Y83 Pro (Nebula Purple, 64 GB)     4.4  ₹16,990  \
# 10          vivo Y12 (Aqua Blue, 64 GB)     4.4  ₹13,990
#
#                                                imgURL
# 5   https://rukminim2.flixcart.com/image/312/312/j...  \
# 10  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 5   Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 10  Internal Storage64 GBRAM3 GBExpandable Storage...
#
#                                                camera
# 5   Operating SystemAndroid Oreo 8.1Processor Type...  \
# 10  Operating SystemAndroid Pie 9.0Processor TypeM...
#
#                                          oS_Processor
# 5   Primary Camera AvailableYesPrimary Camera13MP ...  \
# 10  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 5   Display Size15.8 cm (6.22 inch)Resolution1520 ...  \
# 10  Display Size16.13 cm (6.35 inch)Resolution720 ...
#
#                                               network
# 5   Network Type3G, 4G VOLTE, 2GSupported Networks...  \
# 10  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
#
#                                        battery
# 5                     Battery Capacity3260 mAh
# 10  Battery Capacity5000 mAhBattery TypeLi-ion
# df : df shape : (312, 10)
#                                    name ratings    price
# 262    vivo U10 (Electric Blue, 64 GB)     4.4  ₹13,990  \
# 16   vivo V27 5G (Noble Black, 128 GB)     4.4  ₹32,999
#
#                                                 imgURL
# 262  https://rukminim2.flixcart.com/image/312/312/k...  \
# 16   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 262  Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 16                       Internal Storage128 GBRAM8 GB
#
#                                                 camera
# 262  Operating SystemAndroid Pie 9Processor TypeQua...  \
# 16   Operating SystemAndroid 13Processor TypeMediat...
#
#                                           oS_Processor
# 262  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 16   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                                display
# 262  Display Size16.13 cm (6.35 inch)Resolution720 ...  \
# 16   Display Size17.22 cm (6.78 Inch)Resolution2400...
#
#                                                network
# 262  Network Type4G VOLTE, 4G, 2G, 3GSupported Netw...  \
# 16   Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                       battery
# 262  Battery Capacity5000 mAh
# 16   Battery Capacity4600 mAh

# %%
print(os.getcwd())
os.chdir(r'd:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem')
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem\notebook\data_Ingestion\scraping
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem

# %%
df.isnull().sum()
# Out:
# name            0
# ratings         7
# price           0
# imgURL          0
# storage_ram     0
# camera          0
# oS_Processor    0
# display         0
# network         0
# battery         0
# dtype: int64

# %%
df.to_csv(r'data\raw_data\vivo_mobile_data.csv',index=False)
