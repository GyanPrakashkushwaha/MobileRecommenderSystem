# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import os
import numpy as np
from itertools import zip_longest

# %%
def bs4_soup(pages):
    URL = f'https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={pages}'
    request = requests.get(URL)
    soup = bs(request.text,'html.parser')
    soup = soup.find('div',class_ = '_1YokD2 _3Mn1Gg')

    return soup , URL

# %%
def mob_specs(soup):
    names = soup.find_all('div', class_='_4rR01T')
    mob_names = [i.text if i else None for i in names]

    ratings = soup.find_all('div', class_='_3LWZlK')
    mob_ratings = [i.text if i else None for i in ratings]

    price = soup.find_all('div', class_='_30jeq3 _1_WHN1')
    mob_price = [i.text if i else None for i in price]

    img = soup.find_all('div', class_='CXW8mj')
    mob_img_URL = [i.find('img')['src'] if i.find('img') else None for i in img]

    return mob_names, mob_ratings, mob_price, mob_img_URL

# %%
def features_from_mob_links(soup):
    mobile_links = ['https://www.flipkart.com' + i['href'] for i in soup.find_all('a', class_='_1fQZEK')]
    mobile_req = [requests.get(url=i) for i in mobile_links]
    mobile_soup = [bs(i.text, 'html.parser').find('div', class_='_1YokD2 _2GoDe3') for i in mobile_req]
    mobile_specs_soup = [i.find_all('div', class_='_3k-BhJ') for i in mobile_soup]

    storage_ram = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Memory' in str(specs_.text) and 'Storage' in str(specs_.text)]
    storage_ram_cross_checked = [i for i in storage_ram if 'Internal' in i.split()]

    os_processor = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Os' in str(specs_.text) and 'Processor' in str(specs_.text)]
    os_processor_cross_checked = [i for i in os_processor if 'Operating' in i.split()]

    camera = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Camera' in str(specs_.text) and 'FeaturesPrimary' in str(specs_.text)]
    camera_cross_checked = [i for i in camera if 'Primary' and 'Camera' in i.split()]

    display = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Display' in str(specs_.text) and 'FeaturesDisplay' in str(specs_.text)]
    display_cross_checked = [i for i in display if 'Display' and 'cm' in i.split()]

    network = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Connectivity' in str(specs_.text) and 'FeaturesNetwork' in str(specs_.text)]
    network_cross_checked = [i for i in network if 'Network' in i.split()]

    battery = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Battery' in str(specs_.text) and 'FeaturesBattery' in str(specs_.text)]
    battery_cross_checked = [i for i in battery if 'Battery' in i.split()]

    return mobile_specs_soup, storage_ram_cross_checked, os_processor_cross_checked, camera_cross_checked, display_cross_checked, network_cross_checked, battery_cross_checked

# %%
def fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery):
    tuple_data = zip_longest(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery,fillvalue=np.nan)
    
    data = [i for i in tuple_data]
    return data

# %%
def print_len(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery):
    print(f"Length of mob_names: {len(mob_names)}")
    print(f"Length of mob_ratings: {len(mob_ratings)}")
    print(f"Length of mob_price: {len(mob_price)}")
    print(f"Length of mob_img_URL: {len(mob_img_URL)}")
    print(f"Length of storage_ram: {len(storage_ram)}")
    print(f"Length of os_processor: {len(os_processor)}")
    print(f"Length of camera: {len(camera)}")
    print(f"Length of display: {len(display)}")
    print(f"Length of network: {len(network)}")
    print(f"Length of battery: {len(battery)}")

# %%
df = pd.DataFrame()

page_start = 1

for pages in range(page_start, 14):

    soup, URL = bs4_soup(pages=pages)
    
    mob_names, mob_ratings, mob_price, mob_img_URL = mob_specs(soup)
    mobile_specs_soup, storage_ram, os_processor, camera, display, network, battery = features_from_mob_links(soup=soup)
    
    data = fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)

    if mobile_specs_soup is not None and soup is not None:
        
        print_len(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)

        page_df = pd.DataFrame(data=data,columns=['name', 'ratings', 'price', 'imgURL', 'storage_ram', 'camera',
       'oS_Processor', 'display', 'network', 'battery'])

        if not page_df.empty:
            df = pd.concat(objs=[df, page_df], ignore_index=True)
            print(f'scraping data from page:{pages}')
            print(f'working in {URL} Page')
            print(f'page df : page_shape : {page_df.shape} \n {page_df.sample(2)}')
            print(f'df : df shape : {df.shape} \n {df.sample(2)}')
            print()

    else:
        print(f"Skipping page {pages} due to empty mobile_specs_soup or soup.")
# Out:
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:1
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1 Page
# page df : page_shape : (24, 10)
#                                   name ratings    price
# 19   vivo T1 44W (Starry Sky, 128 GB)     4.3  ₹17,999  \
# 7   vivo T2x 5G (Aurora Gold, 128 GB)     4.4  ₹12,999
#
#                                                imgURL
# 19  https://rukminim2.flixcart.com/image/312/312/l...  \
# 7   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 19  Internal Storage128 GBRAM8 GBExpandable Storag...  \
# 7   Internal Storage128 GBRAM4 GBMemory Card Slot ...
#
#                                                camera
# 19  Operating SystemAndroid 12Processor TypeQualco...  \
# 7   Operating SystemAndroid 13Processor TypeDimens...
#
#                                          oS_Processor
# 19  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 7   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 19  Display Size16.36 cm (6.44 inch)Resolution2400...  \
# 7   Display Size16.71 cm (6.58 inch)Resolution2408...
#
#                                               network
# 19  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 7   Network Type5G, 4G, 3GSupported Networks5G, 4G...
#
#                                         battery
# 19                     Battery Capacity5000 mAh
# 7   Battery Capacity5000 mAhBattery TypeLithium
# df : df shape : (24, 10)
#                                    name ratings    price
# 8  vivo T2x 5G (Glimmer Black, 128 GB)     4.4  ₹12,999  \
# 3    vivo T2x 5G (Marine Blue, 128 GB)     4.4  ₹13,999
#
#                                               imgURL
# 8  https://rukminim2.flixcart.com/image/312/312/x...  \
# 3  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                          storage_ram
# 8  Internal Storage128 GBRAM4 GBMemory Card Slot ...  \
# 3  Internal Storage128 GBRAM6 GBMemory Card Slot ...
#
#                                               camera
# 8  Operating SystemAndroid 13Processor TypeDimens...  \
# 3  Operating SystemAndroid 13Processor TypeDimens...
#
#                                         oS_Processor
# 8  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 3  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                              display
# 8  Display Size16.71 cm (6.58 inch)Resolution2408...  \
# 3  Display Size16.71 cm (6.58 inch)Resolution2408...
#
#                                              network
# 8  Network Type5G, 4G, 3GSupported Networks5G, 4G...  \
# 3  Network Type5G, 4G, 3GSupported Networks5G, 4G...
#
#                                        battery
# 8  Battery Capacity5000 mAhBattery TypeLithium
# 3  Battery Capacity5000 mAhBattery TypeLithium
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:2
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2 Page
# page df : page_shape : (24, 10)
#                                  name ratings    price
# 9    vivo Y16 (Steller Black, 64 GB)     4.3  ₹11,999  \
# 14  vivo Y33s (Midday Dream, 128 GB)     4.3  ₹17,989
#
#                                                imgURL
# 9   https://rukminim2.flixcart.com/image/312/312/x...  \
# 14  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 9   Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 14  Internal Storage128 GBRAM8 GBExpandable Storag...
#
#                                                camera
# 9   Operating SystemAndroid 12Processor TypeMediat...  \
# 14  Operating SystemAndroid 11Processor TypeMediaT...
#
#                                          oS_Processor
# 9   Primary Camera AvailableYesPrimary Camera13MP ...  \
# 14  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 9   Display Size16.54 cm (6.51 inch)Resolution1600...  \
# 14  Display Size16.71 cm (6.58 inch)Resolution2408...
#
#                                               network
# 9   Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 14  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 9   Battery Capacity5000 mAh
# 14  Battery Capacity5000 mAh
# df : df shape : (48, 10)
#                                    name ratings    price
# 45      vivo Y22 (Starlit Blue, 64 GB)     4.3  ₹14,499  \
# 27  vivo Y22 (Metaverse Green, 128 GB)     4.3  ₹14,499
#
#                                                imgURL
# 45  https://rukminim2.flixcart.com/image/312/312/x...  \
# 27  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 45  Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 27  Internal Storage128 GBRAM4 GBExpandable Storag...
#
#                                                camera
# 45  Operating SystemAndroid 12Processor TypeMediat...  \
# 27  Operating SystemAndroid 12Processor TypeMediat...
#
#                                          oS_Processor
# 45  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 27  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 45  Display Size16.64 cm (6.55 inch)Resolution1600...  \
# 27  Display Size16.64 cm (6.55 inch)Resolution1600...
#
#                                               network
# 45  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 27  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 45  Battery Capacity5000 mAh
# 27  Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:3
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3 Page
# page df : page_shape : (24, 10)
#                                      name ratings    price
# 8       vivo Y16 (Drizzling Gold, 32 GB)     4.2  ₹11,699  \
# 23  vivo V27 Pro 5G (Magic Blue, 256 GB)     4.5  ₹42,999
#
#                                                imgURL
# 8   https://rukminim2.flixcart.com/image/312/312/x...  \
# 23  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 8   Internal Storage32 GBRAM3 GBExpandable Storage...  \
# 23   Internal Storage256 GBRAM12 GBCall Log MemoryYes
#
#                                                camera
# 8   Operating SystemAndroid 12Processor TypeMediat...  \
# 23  Operating SystemAndroid 13Processor TypeMediat...
#
#                                          oS_Processor
# 8   Primary Camera AvailableYesPrimary Camera13MP ...  \
# 23  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 8   Display Size16.54 cm (6.51 inch)Resolution1600...  \
# 23  Display Size17.22 cm (6.78 inch)Resolution2400...
#
#                                               network
# 8   Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 23  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                      battery
# 8   Battery Capacity5000 mAh
# 23  Battery Capacity4600 mAh
# df : df shape : (72, 10)
#                                     name ratings    price
# 1   vivo T2x 5G (Glimmer Black, 128 GB)     4.3  ₹15,999  \
# 28     vivo Y16 (Steller Black, 128 GB)     4.3  ₹16,999
#
#                                                imgURL
# 1   https://rukminim2.flixcart.com/image/312/312/x...  \
# 28  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 1   Internal Storage128 GBRAM8 GBMemory Card Slot ...  \
# 28  Internal Storage128 GBRAM4 GBExpandable Storag...
#
#                                                camera
# 1   Operating SystemAndroid 13Processor TypeDimens...  \
# 28  Operating SystemAndroid 12Processor TypeMediat...
#
#                                          oS_Processor
# 1   Primary Camera AvailableYesPrimary Camera50MP ...  \
# 28  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 1   Display Size16.71 cm (6.58 inch)Resolution2408...  \
# 28  Display Size16.54 cm (6.51 inch)Resolution1600...
#
#                                               network
# 1   Network Type5G, 4G, 3GSupported Networks5G, 4G...  \
# 28  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                                         battery
# 1   Battery Capacity5000 mAhBattery TypeLithium
# 28                     Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:4
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4 Page
# page df : page_shape : (24, 10)
#                                  name ratings    price
# 16  vivo Y21E (Midnight Blue, 64 GB)     4.3  ₹12,499  \
# 14            vivo Y16 (Gold, 64 GB)     4.3  ₹12,890
#
#                                                imgURL
# 16  https://rukminim2.flixcart.com/image/312/312/k...  \
# 14  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 16  Internal Storage64 GBRAM3 GBMemory Card Slot T...  \
# 14  Internal Storage64 GBRAM4 GBMemory Card Slot T...
#
#                                                camera
# 16  Operating SystemAndroid Q 11Processor CoreOcta...  \
# 14  Operating SystemAndroid Android 12Processor Co...
#
#                                          oS_Processor
# 16  Primary Camera13MP Rear CameraDual Camera Lens...  \
# 14  Primary Camera13MP Rear CameraDual Camera Lens...
#
#                                               display
# 16  Display Size16.54 cm (6.51 inch)Resolution720 ...  \
# 14  Display Size16.54 cm (6.51 inch)Resolution1600...
#
#                                               network
# 16  Network Type4G VOLTE, 4G, 3GSupported Networks...  \
# 14     Network Type4G, 3G, 2GSupported Networks4G LTE
#
#                      battery
# 16  Battery Capacity5000 mAh
# 14  Battery Capacity5000 mAh
# df : df shape : (96, 10)
#                                       name ratings    price
# 51     vivo Y100A (Twilight Gold, 256 GB)     4.4  ₹25,999  \
# 72  vivo V27 Pro 5G (Noble Black, 256 GB)     4.4  ₹39,999
#
#                                                imgURL
# 51  https://rukminim2.flixcart.com/image/312/312/x...  \
# 72  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 51  Internal Storage256 GBRAM8 GBMemory Card Slot ...  \
# 72    Internal Storage256 GBRAM8 GBCall Log MemoryYes
#
#                                                camera
# 51  Operating SystemAndroid 13Processor TypeSnapdr...  \
# 72  Operating SystemAndroid 13Processor TypeMediat...
#
#                                          oS_Processor
# 51  Primary Camera AvailableYesPrimary Camera64MP ...  \
# 72  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 51  Display Size16.21 cm (6.38 inch)Resolution2400...  \
# 72  Display Size17.22 cm (6.78 inch)Resolution2400...
#
#                                               network
# 51  Network Type3G, 4G, 5GSupported Networks4G LTE...  \
# 72  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                                         battery
# 51  Battery Capacity4500 mAhBattery TypeLithium
# 72                     Battery Capacity4600 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 22
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:5
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5 Page
# page df : page_shape : (24, 10)
#                                 name ratings    price
# 10    vivo Y91i (Ocean Blue, 32 GB)     4.3   ₹9,990  \
# 3   vivo Y16 (Steller Black, 32 GB)     4.2  ₹12,999
#
#                                                imgURL
# 10  https://rukminim2.flixcart.com/image/312/312/k...  \
# 3   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 10  Internal Storage32 GBRAM2 GBExpandable Storage...  \
# 3   Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                                camera
# 10  Operating SystemAndroid Oreo 8.1Processor Type...  \
# 3   Operating SystemAndroid 12Processor TypeMediat...
#
#                                          oS_Processor
# 10  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 3   Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 10  Display Size15.8 cm (6.22 inch)Resolution1520 ...  \
# 3   Display Size16.54 cm (6.51 inch)Resolution1600...
#
#                                               network
# 10  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...  \
# 3   Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 10  Battery Capacity4030 mAh
# 3   Battery Capacity5000 mAh
# df : df shape : (120, 10)
#                                    name ratings    price
# 101    vivo Y01 (Sapphire Blue, 32 GB)     4.4  ₹12,999  \
# 22   vivo Y16 (Drizzling Gold, 128 GB)     4.3  ₹12,900
#
#                                                 imgURL
# 101  https://rukminim2.flixcart.com/image/312/312/x...  \
# 22   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 101  Internal Storage32 GBRAM2 GBSupported Memory C...  \
# 22   Internal Storage128 GBRAM4 GBExpandable Storag...
#
#                                                 camera
# 101  Operating SystemAndroid 11Processor TypeMediat...  \
# 22   Operating SystemAndroid 12Processor TypeMediat...
#
#                                           oS_Processor
# 101  Primary Camera AvailableYesPrimary Camera8MP R...  \
# 22   Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                                display
# 101  Display Size16.54 cm (6.51 inch)Resolution1600...  \
# 22   Display Size16.54 cm (6.51 inch)Resolution1600...
#
#                                                network
# 101  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 22   Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                       battery
# 101  Battery Capacity5000 mAh
# 22   Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 22
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:6
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=6 Page
# page df : page_shape : (24, 10)
#                                name ratings    price
# 9     vivo V9 Youth (Black, 32 GB)     4.4  ₹19,990  \
# 7  vivo Y91 (Nebula Purple, 32 GB)     4.4  ₹10,990
#
#                                               imgURL
# 9  https://rukminim2.flixcart.com/image/312/312/j...  \
# 7  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                          storage_ram
# 9  Internal Storage32 GBRAM4 GBExpandable Storage...  \
# 7  Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                               camera
# 9  Operating SystemAndroid Oreo 8.1Processor Type...  \
# 7  Operating SystemAndroid Oreo 8.1Processor Type...
#
#                                         oS_Processor
# 9  Primary Camera AvailableYesPrimary Camera16MP ...  \
# 7  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                              display
# 9  Display Size16.0 cm (6.3 inch)Resolution2280 x...  \
# 7  Display Size15.8 cm (6.22 inch)Resolution1520 ...
#
#                                              network
# 9  Network Type3G, 4G VOLTE, 2GSupported Networks...  \
# 7  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
#
#                                       battery
# 9                    Battery Capacity3260 mAh
# 7  Battery Capacity4030 mAhBattery TypeLi-ion
# df : df shape : (144, 10)
#                                       name ratings    price
# 135  vivo V17 (Glacier ice white, 128 GB)     4.3  ₹27,990  \
# 86                 vivo Y16 (Gold, 64 GB)     4.3  ₹12,890
#
#                                                 imgURL
# 135  https://rukminim2.flixcart.com/image/312/312/k...  \
# 86   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 135  Internal Storage128 GBRAM8 GBExpandable Storag...  \
# 86   Internal Storage64 GBRAM4 GBMemory Card Slot T...
#
#                                                 camera
# 135  Operating SystemAndroid Pie 9Processor TypeQua...  \
# 86   Operating SystemAndroid Android 12Processor Co...
#
#                                           oS_Processor
# 135  Primary Camera AvailableYesPrimary Camera48MP ...  \
# 86   Primary Camera13MP Rear CameraDual Camera Lens...
#
#                                                display
# 135  Display Size16.36 cm (6.44 inch)Resolution2400...  \
# 86   Display Size16.54 cm (6.51 inch)Resolution1600...
#
#                                                network
# 135  Network Type4G, 3G, 2GSupported Networks4G VoL...  \
# 86      Network Type4G, 3G, 2GSupported Networks4G LTE
#
#                       battery
# 135  Battery Capacity4500 mAh
# 86   Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 23
# Length of mob_price: 23
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:7
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=7 Page
# page df : page_shape : (24, 10)
#                                 name ratings    price
# 1  vivo Z1x (Phantom Purple, 64 GB)     4.5  ₹19,990  \
# 6       vivo Y15 (Aqua Blue, 64 GB)     4.4  ₹15,990
#
#                                               imgURL
# 1  https://rukminim2.flixcart.com/image/312/312/k...  \
# 6  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                          storage_ram
# 1                       Internal Storage64 GBRAM6 GB  \
# 6  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                               camera
# 1  Operating SystemAndroid Pie 9Processor TypeQua...  \
# 6  Operating SystemAndroid Pie 9.0Processor TypeM...
#
#                                         oS_Processor
# 1  Primary Camera AvailableYesPrimary Camera48MP ...  \
# 6  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                              display
# 1  Display Size16.21 cm (6.38 inch)Resolution2340...  \
# 6  Display Size16.13 cm (6.35 inch)Resolution720 ...
#
#                                              network
# 1  Network Type3G, 4G, 2GSupported Networks4G VoL...  \
# 6  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
#
#                                       battery
# 1                    Battery Capacity4500 mAh
# 6  Battery Capacity5000 mAhBattery TypeLi-ion
# df : df shape : (168, 10)
#                                      name ratings    price
# 97     vivo Y27 (Burgundy Black, 128 GB)     4.2  ₹14,999  \
# 165  vivo V23 5G (Sunshine Gold, 256 GB)     4.2   ₹9,499
#
#                                                 imgURL
# 97   https://rukminim2.flixcart.com/image/312/312/x...  \
# 165  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 97   Internal Storage128 GBRAM6 GBSupported Memory ...  \
# 165   Internal Storage256 GBRAM12 GBCall Log MemoryYes
#
#                                                 camera
# 97   Operating SystemAndroid 13Processor TypeHelio ...  \
# 165  Operating SystemAndroid 12Processor TypeMediat...
#
#                                           oS_Processor
# 97   Primary Camera AvailableYesPrimary Camera50MP ...  \
# 165  Primary Camera AvailableYesPrimary Camera64MP ...
#
#                                                display
# 97   Display Size16.87 cm (6.64 inch)Resolution2388...  \
# 165  Display Size16.36 cm (6.44 inch)Resolution2400...
#
#                                                network
# 97   Network Type2G, 3G, 4GSupported Networks4G LTE...  \
# 165  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                       battery
# 97   Battery Capacity5000 mAh
# 165  Battery Capacity4200 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:8
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=8 Page
# page df : page_shape : (24, 10)
#                                  name ratings    price
# 12  vivo Y21A (Midnight Blue, 64 GB)     4.3  ₹12,625  \
# 15   vivo T1X (Diamond Glow, 128 GB)     4.4  ₹16,990
#
#                                                imgURL
# 12  https://rukminim2.flixcart.com/image/312/312/k...  \
# 15  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 12  Internal Storage64 GBRAM4 GBTotal Memory64 GBE...  \
# 15  Internal Storage128 GBRAM6 GBSupported Memory ...
#
#                                                camera
# 12  Operating SystemAndroid Q 11.1Processor TypeMe...  \
# 15  Operating SystemAndroid 12Processor TypeQualco...
#
#                                          oS_Processor
# 12  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 15  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 12  Display Size16.54 cm (6.51 inch)Resolution720 ...  \
# 15  Display Size16.71 cm (6.58 inch)Resolution2408...
#
#                                               network
# 12  Network Type4G VOLTESupported Networks4G LTE, ...  \
# 15  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                                               battery
# 12  Battery Capacity5000 mAhBattery Type5000Dual B...
# 15                           Battery Capacity5000 mAh
# df : df shape : (192, 10)
#                                   name ratings    price
# 104  vivo T1X (Gravity Black, 128 GB)     4.3  ₹16,999  \
# 188     vivo Y1S (Olive Black, 32 GB)     3.8  ₹10,990
#
#                                                 imgURL
# 104  https://rukminim2.flixcart.com/image/312/312/x...  \
# 188  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 104  Internal Storage128 GBRAM4 GBSupported Memory ...  \
# 188  Internal Storage32 GBRAM2 GBMemory Card Slot T...
#
#                                                 camera
# 104  Operating SystemAndroid 12Processor TypeQualco...  \
# 188  Operating SystemAndroid 10Processor CoreOcta C...
#
#                                           oS_Processor
# 104  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 188                     Primary Camera13MP Rear Camera
#
#                                                display
# 104  Display Size16.71 cm (6.58 inch)Resolution2408...  \
# 188  Display Size15.8 cm (6.22 inch)Resolution1520 ...
#
#                                                network
# 104  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 188  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                       battery
# 104  Battery Capacity5000 mAh
# 188  Battery Capacity4030 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:9
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=9 Page
# page df : page_shape : (24, 10)
#                                  name ratings    price
# 15      vivo Y50 (Iris Blue, 128 GB)     4.4  ₹19,990  \
# 23  vivo V19 (Mystic Silver, 256 GB)     4.4  ₹34,990
#
#                                                imgURL
# 15  https://rukminim2.flixcart.com/image/312/312/k...  \
# 23  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 15  Internal Storage128 GBRAM8 GBExpandable Storag...  \
# 23  Internal Storage256 GBRAM8 GBExpandable Storag...
#
#                                                camera
# 15  Operating SystemAndroid 10Processor TypeQualco...  \
# 23  Operating SystemAndroid 10Processor TypeQualco...
#
#                                          oS_Processor
# 15  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 23  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                               display
# 15  Display Size16.59 cm (6.53 inch)Resolution2340...  \
# 23  Display Size16.36 cm (6.44 inch)Resolution2400...
#
#                                               network
# 15  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 23  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                      battery
# 15  Battery Capacity5000 mAh
# 23  Battery Capacity4500 mAh
# df : df shape : (216, 10)
#                                       name ratings    price
# 150           vivo Y15 (Aqua Blue, 64 GB)     4.4  ₹15,990  \
# 196  vivo V23e 5G (Sunshine Gold, 128 GB)     4.2  ₹25,999
#
#                                                 imgURL
# 150  https://rukminim2.flixcart.com/image/312/312/k...  \
# 196  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 150  Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 196  Internal Storage128 GBRAM8 GBExpandable Storag...
#
#                                                 camera
# 150  Operating SystemAndroid Pie 9.0Processor TypeM...  \
# 196  Operating SystemAndroid 12Processor TypeMediat...
#
#                                           oS_Processor
# 150  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 196  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                                display
# 150  Display Size16.13 cm (6.35 inch)Resolution720 ...  \
# 196  Display Size16.36 cm (6.44 inch)Resolution2400...
#
#                                                network
# 150  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...  \
# 196  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                                         battery
# 150  Battery Capacity5000 mAhBattery TypeLi-ion
# 196                    Battery Capacity4050 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:10
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=10 Page
# page df : page_shape : (24, 10)
#                                      name ratings    price
# 18  vivo T1 5G (Rainbow Fantasy, 128 GB)     4.4  ₹16,990  \
# 5   vivo T1 5G (Rainbow Fantasy, 128 GB)     4.3  ₹19,990
#
#                                                imgURL
# 18  https://rukminim2.flixcart.com/image/312/312/k...  \
# 5   https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 18  Internal Storage128 GBRAM6 GBExpandable Storag...  \
# 5   Internal Storage128 GBRAM8 GBExpandable Storag...
#
#                                                camera
# 18  Operating SystemAndroid 12Processor TypeQualco...  \
# 5   Operating SystemAndroid 12Processor TypeQualco...
#
#                                          oS_Processor
# 18  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 5   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 18  Display Size16.71 cm (6.58 inch)Resolution2408...  \
# 5   Display Size16.71 cm (6.58 inch)Resolution2408...
#
#                                               network
# 18  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 5   Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                      battery
# 18  Battery Capacity5000 mAh
# 5   Battery Capacity5000 mAh
# df : df shape : (240, 10)
#                                     name ratings    price
# 12   vivo T2 5G (Velocity Wave, 128 GB)     4.4  ₹20,999  \
# 211     vivo U10 (Electric Blue, 64 GB)     4.4  ₹13,990
#
#                                                 imgURL
# 12   https://rukminim2.flixcart.com/image/312/312/x...  \
# 211  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 12   Internal Storage128 GBRAM8 GBMemory Card Slot ...  \
# 211  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                                 camera
# 12   Operating SystemAndroid 13Processor TypeSnapdr...  \
# 211  Operating SystemAndroid Pie 9Processor TypeQua...
#
#                                           oS_Processor
# 12   Primary Camera AvailableYesPrimary Camera64 MP...  \
# 211  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                                display
# 12   Display Size16.21 cm (6.38 inch)Resolution2400...  \
# 211  Display Size16.13 cm (6.35 inch)Resolution720 ...
#
#                                                network
# 12   Network Type5G, 4G, 3GSupported Networks5G, 4G...  \
# 211  Network Type4G VOLTE, 4G, 2G, 3GSupported Netw...
#
#                                          battery
# 12   Battery Capacity4500 mAhBattery TypeLithium
# 211                     Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:11
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=11 Page
# page df : page_shape : (24, 10)
#                                     name ratings    price
# 9          vivo Y50 (Iris Blue, 128 GB)     4.4  ₹19,990  \
# 12  vivo X70 Pro (Cosmic Black, 128 GB)     4.5  ₹41,990
#
#                                                imgURL
# 9   https://rukminim2.flixcart.com/image/312/312/k...  \
# 12  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 9   Internal Storage128 GBRAM8 GBExpandable Storag...  \
# 12    Internal Storage128 GBRAM8 GBCall Log MemoryYes
#
#                                                camera
# 9   Operating SystemAndroid 10Processor TypeQualco...  \
# 12  Operating SystemAndroid 11Processor TypeMediaT...
#
#                                          oS_Processor
# 9   Primary Camera AvailableYesPrimary Camera13MP ...  \
# 12  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 9   Display Size16.59 cm (6.53 inch)Resolution2340...  \
# 12  Display Size16.66 cm (6.56 inch)Resolution2376...
#
#                                               network
# 9   Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 12  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                      battery
# 9   Battery Capacity5000 mAh
# 12  Battery Capacity4450 mAh
# df : df shape : (264, 10)
#                                    name ratings    price
# 122    vivo Y93 (Nebula Purple, 64 GB)     4.4  ₹14,990  \
# 157  vivo Y33T (Mid day dream, 128 GB)     4.3  ₹14,499
#
#                                                 imgURL
# 122  https://rukminim2.flixcart.com/image/312/312/j...  \
# 157  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 122  Internal Storage64 GBRAM3 GBExpandable Storage...  \
# 157  Internal Storage128 GBRAM8 GBExpandable Storag...
#
#                                                 camera
# 122  Operating SystemAndroid Oreo 8.1Processor Type...  \
# 157  Operating SystemAndroid 11Processor TypeQualco...
#
#                                           oS_Processor
# 122  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 157  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                                display
# 122  Display Size15.8 cm (6.22 inch)Resolution1520 ...  \
# 157  Display Size16.71 cm (6.58 inch)Resolution2408...
#
#                                                network
# 122  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...  \
# 157  Network Type4G, 3G, 2GSupported Networks4G VoL...
#
#                       battery
# 122  Battery Capacity4030 mAh
# 157  Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:12
# working in https://www.flipkart.com/search?q=vivo+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=12 Page
# page df : page_shape : (24, 10)
#                                name ratings    price
# 19  vivo X50 (Glaze Black, 256 GB)     4.3  ₹44,990  \
# 1   vivo Y11 (Mineral Blue, 32 GB)     4.4   ₹9,990
#
#                                                imgURL
# 19  https://rukminim2.flixcart.com/image/312/312/k...  \
# 1   https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 19                      Internal Storage256 GBRAM8 GB  \
# 1   Internal Storage32 GBRAM3 GBMemory Card Slot T...
#
#                                                camera
# 19  Operating SystemAndroid 10Processor TypeQualco...  \
# 1   Operating SystemAndroid Pie 9Processor TypeSDM...
#
#                                          oS_Processor
# 19  Primary Camera AvailableYesPrimary Camera48MP ...  \
# 1   Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 19  Display Size16.66 cm (6.56 inch)Resolution2376...  \
# 1   Display Size16.13 cm (6.35 inch)Resolution720 ...
#
#                                               network
# 19  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 1   Network Type4G VOLTE, 4G, 2G, 3GSupported Netw...
#
#                      battery
# 19  Battery Capacity4200 mAh
# 1   Battery Capacity5000 mAh
# df : df shape : (288, 10)
#                                    name ratings    price
# 198     vivo Y15c (Mystic Blue, 32 GB)     4.2   ₹9,499  \
# 276  vivo Y72 5G (Prism Magic, 128 GB)     4.3  ₹17,999
#
#                                                 imgURL
# 198  https://rukminim2.flixcart.com/image/312/312/l...  \
# 276  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 198  Internal Storage32 GBRAM3 GBExpandable Storage...  \
# 276    Internal Storage128 GBRAM8 GBCall Log MemoryYes
#
#                                                 camera
# 198  Operating SystemAndroid 12Processor TypeMediat...  \
# 276  Operating SystemAndroid 11Processor TypeQualco...
#
#                                           oS_Processor
# 198  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 276  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                                display
# 198  Display Size16.54 cm (6.51 inch)Resolution1600...  \
# 276  Display Size16.71 cm (6.58 inch)Resolution2408...
#
#                                                network
# 198  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 276  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                       battery
# 198  Battery Capacity5000 mAh
# 276  Battery Capacity5000 mAh
#
# Length of mob_names: 0
# Length of mob_ratings: 0
# Length of mob_price: 0
# Length of mob_img_URL: 0
# Length of storage_ram: 0
# Length of os_processor: 0
# Length of camera: 0
# Length of display: 0
# Length of network: 0
# Length of battery: 0

# %%
print(os.getcwd())
os.chdir(r'd:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem')
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem\notebook\data_Ingestion\scraping
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem

# %%
df.isnull().sum()
# Out:
# name            0
# ratings         5
# price           1
# imgURL          0
# storage_ram     0
# camera          0
# oS_Processor    0
# display         0
# network         0
# battery         0
# dtype: int64

# %%
df.to_csv(r'data\raw_data\vivo_mobile_data.csv',index=False)
