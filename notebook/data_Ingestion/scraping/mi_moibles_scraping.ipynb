# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import os
import numpy as np
from itertools import zip_longest

# %%
def bs4_soup(pages):
    URL = f'https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={pages}'
    request = requests.get(URL)
    soup = bs(request.text,'html.parser')
    soup = soup.find('div',class_ = '_1YokD2 _3Mn1Gg')

    return soup , URL

# %%
def mob_specs(soup):
    names = soup.find_all('div', class_='_4rR01T')
    mob_names = [i.text if i else None for i in names]

    ratings = soup.find_all('div', class_='_3LWZlK')
    mob_ratings = [i.text if i else None for i in ratings]

    price = soup.find_all('div', class_='_30jeq3 _1_WHN1')
    mob_price = [i.text if i else None for i in price]

    img = soup.find_all('div', class_='CXW8mj')
    mob_img_URL = [i.find('img')['src'] if i.find('img') else None for i in img]

    return mob_names, mob_ratings, mob_price, mob_img_URL

# %%
def features_from_mob_links(soup):
    mobile_links = ['https://www.flipkart.com' + i['href'] for i in soup.find_all('a', class_='_1fQZEK')]
    mobile_req = [requests.get(url=i) for i in mobile_links]
    mobile_soup = [bs(i.text, 'html.parser').find('div', class_='_1YokD2 _2GoDe3') for i in mobile_req]
    mobile_specs_soup = [i.find_all('div', class_='_3k-BhJ') for i in mobile_soup]

    storage_ram = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Memory' in str(specs_.text) and 'Storage' in str(specs_.text)]
    storage_ram_cross_checked = [i for i in storage_ram if 'Internal' in i.split()]

    os_processor = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Os' in str(specs_.text) and 'Processor' in str(specs_.text)]
    os_processor_cross_checked = [i for i in os_processor if 'Operating' in i.split()]

    camera = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Camera' in str(specs_.text) and 'FeaturesPrimary' in str(specs_.text)]
    camera_cross_checked = [i for i in camera if 'Primary' and 'Camera' in i.split()]

    display = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Display' in str(specs_.text) and 'FeaturesDisplay' in str(specs_.text)]
    display_cross_checked = [i for i in display if 'Display' and 'cm' in i.split()]

    network = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Connectivity' in str(specs_.text) and 'FeaturesNetwork' in str(specs_.text)]
    network_cross_checked = [i for i in network if 'Network' in i.split()]

    battery = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Battery' in str(specs_.text) and 'FeaturesBattery' in str(specs_.text)]
    battery_cross_checked = [i for i in battery if 'Battery' in i.split()]

    return mobile_specs_soup, storage_ram_cross_checked, os_processor_cross_checked, camera_cross_checked, display_cross_checked, network_cross_checked, battery_cross_checked

# %%
def fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery):
    tuple_data = zip_longest(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery,fillvalue=np.nan)
    
    data = [i for i in tuple_data]
    return data

# %%
def print_len(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery):
    print(f"Length of mob_names: {len(mob_names)}")
    print(f"Length of mob_ratings: {len(mob_ratings)}")
    print(f"Length of mob_price: {len(mob_price)}")
    print(f"Length of mob_img_URL: {len(mob_img_URL)}")
    print(f"Length of storage_ram: {len(storage_ram)}")
    print(f"Length of os_processor: {len(os_processor)}")
    print(f"Length of camera: {len(camera)}")
    print(f"Length of display: {len(display)}")
    print(f"Length of network: {len(network)}")
    print(f"Length of battery: {len(battery)}")

# %%
df = pd.DataFrame()

page_start = 1
page_ends = 24

for pages in range(page_start, page_ends):

    soup, URL = bs4_soup(pages=pages)
    
    mob_names, mob_ratings, mob_price, mob_img_URL = mob_specs(soup)
    mobile_specs_soup, storage_ram, os_processor, camera, display, network, battery = features_from_mob_links(soup=soup)
    
    data = fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)

    if mobile_specs_soup is not None and soup is not None:
        
        print_len(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)

        page_df = pd.DataFrame(data=data,columns=['name', 'ratings', 'price', 'imgURL', 'storage_ram','os_processor',
                                                   'camera', 'display', 'network', 'battery'])

        if not page_df.empty:
            df = pd.concat(objs=[df, page_df], ignore_index=True)
            print(f'scraping data from page:{pages}')
            print(f'working in {URL} Page')
            print(f'page df : page_shape : {page_df.shape} \n {page_df.sample(2)}')
            print(f'df : df shape : {df.shape} \n {df.sample(2)}')
            print()

    else:
        print(f"Skipping page {pages} due to empty mobile_specs_soup or soup.")
# Out:
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:1
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1 Page
# page df : page_shape : (24, 10)
#                                        name ratings    price
# 16  Xiaomi 12 Pro 5G (Opera Mauve, 256 GB)     4.2  ₹44,999  \
# 11                 Redmi 6A (Black, 16 GB)     4.3   ₹6,500
#
#                                                imgURL
# 16  https://rukminim2.flixcart.com/image/312/312/x...  \
# 11  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                           storage_ram
# 16   Internal Storage256 GBRAM12 GBCall Log MemoryYes  \
# 11  Internal Storage16 GBRAM2 GBExpandable Storage...
#
#                                          os_processor
# 16  Operating SystemAndroid 12Processor TypeSnapdr...  \
# 11  Operating SystemAndroid Oreo 8.1Processor Core...
#
#                                                camera
# 16  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 11  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 16  Display Size17.09 cm (6.73 inch)Resolution2400...  \
# 11  Display Size13.84 cm (5.45 inch)Resolution720 ...
#
#                                               network
# 16  Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...  \
# 11  Network Type3G, 4G VOLTE, 2GSupported Networks...
#
#                                               battery
# 16  Battery Capacity4600 mAhBattery TypeLithium Po...
# 11                           Battery Capacity3000 mAh
# df : df shape : (24, 10)
#                                      name ratings    price
# 21  Xiaomi 11Lite NE (Jazz Blue, 128 GB)     4.2  ₹22,000  \
# 19         Redmi 9 (Carbon Black, 64 GB)     4.2  ₹10,480
#
#                                                imgURL
# 21  https://rukminim2.flixcart.com/image/312/312/x...  \
# 19  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 21  Internal Storage128 GBRAM8 GBMemory Card Slot ...  \
# 19  Internal Storage64 GBRAM4 GBMemory Card Slot T...
#
#                                          os_processor
# 21  Operating SystemAndroid 11Processor CoreOcta C...  \
# 19  Operating SystemAndroid Q 10Processor TypeMedi...
#
#                                                camera
# 21  Primary Camera64MP Rear CameraDual Camera Lens...  \
# 19  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 21  Display Size16.64 cm (6.55 inch)Resolution1080...  \
# 19  Display Size16.59 cm (6.53 inch)Resolution720 ...
#
#                                               network
# 21  Network Type5G, 4G VOLTESupported Networks5G, ...  \
# 19  Network Type4G VOLTE, 3GSupported Networks4G V...
#
#                                       battery
# 21                   Battery Capacity4250 mAh
# 19  Battery Capacity5000 mAhBattery TypeLi-Po
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:2
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2 Page
# page df : page_shape : (24, 10)
#                                     name ratings    price
# 0  Xiaomi 11Lite NE (Jazz Blue, 128 GB)     4.2  ₹22,970  \
# 7                 Redmi 6 (Gold, 32 GB)     4.4   ₹8,999
#
#                                               imgURL
# 0  https://rukminim2.flixcart.com/image/312/312/x...  \
# 7  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                          storage_ram
# 0  Internal Storage128 GBRAM8 GBExpandable Storag...  \
# 7  Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                         os_processor
# 0  Operating SystemAndroid 11Processor TypeQualco...  \
# 7  Operating SystemAndroid Oreo 8.1Processor Type...
#
#                                               camera
# 0  Primary Camera AvailableYesPrimary Camera64MP ...  \
# 7  Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                              display
# 0  Display Size16.64 cm (6.55 inch)Resolution1080...  \
# 7  Display Size13.84 cm (5.45 inch)Resolution1440...
#
#                                              network
# 0  Network Type5G, 4G VOLTESupported Networks5G, ...  \
# 7  Network Type3G, 4G VOLTE, 2GSupported Networks...
#
#                                              battery
# 0          Battery Capacity4250 mAhBattery TypeLi-Po
# 7  Battery Capacity3000 mAhBattery TypeLithium-po...
# df : df shape : (48, 10)
#                                     name ratings    price
# 31                Redmi 6 (Gold, 32 GB)     4.4   ₹8,999  \
# 47  Redmi Note 6 Pro (Rose Gold, 64 GB)     4.5  ₹17,999
#
#                                                imgURL
# 31  https://rukminim2.flixcart.com/image/312/312/j...  \
# 47  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                           storage_ram
# 31  Internal Storage32 GBRAM3 GBExpandable Storage...  \
# 47  Internal Storage64 GBRAM6 GBExpandable Storage...
#
#                                          os_processor
# 31  Operating SystemAndroid Oreo 8.1Processor Type...  \
# 47  Operating SystemAndroid Oreo 8.1Processor Type...
#
#                                                camera
# 31  Primary Camera AvailableYesPrimary Camera12MP ...  \
# 47  Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                               display
# 31  Display Size13.84 cm (5.45 inch)Resolution1440...  \
# 47  Display Size15.9 cm (6.26 inch)Resolution2280 ...
#
#                                               network
# 31  Network Type3G, 4G VOLTE, 2GSupported Networks...  \
# 47  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
#
#                                               battery
# 31  Battery Capacity3000 mAhBattery TypeLithium-po...
# 47                           Battery Capacity4000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 23
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:3
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3 Page
# page df : page_shape : (24, 10)
#                                name ratings    price
# 2    Mi 11X (Cosmic Black, 128 GB)     4.2  ₹23,990  \
# 13  Redmi Note 5 Pro (Gold, 64 GB)     4.5  ₹16,999
#
#                                                imgURL
# 2   https://rukminim2.flixcart.com/image/312/312/x...  \
# 13  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                           storage_ram
# 2   Internal Storage128 GBRAM8 GBMemory Card Slot ...  \
# 13  Internal Storage64 GBRAM6 GBExpandable Storage...
#
#                                          os_processor
# 2   Operating SystemAndroid Q 11Processor CoreOcta...  \
# 13  Operating SystemAndroid Nougat 7.1.2Processor ...
#
#                                                camera
# 2   Primary Camera48MP Rear CameraDual Camera Lens...  \
# 13  Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                               display
# 2   Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 13  Display Size15.21 cm (5.99 inch)Resolution2160...
#
#                                               network
# 2      Network Type5G, 4G, 3G, 2GSupported Networks5G  \
# 13  Network Type3G, 4G VOLTE, 4GSupported Networks...
#
#                      battery
# 2   Battery Capacity4520 mAh
# 13  Battery Capacity4000 mAh
# df : df shape : (72, 10)
#                                      name ratings    price
# 54  Redmi 10 Prime (Astral White, 64 GB)     4.2  ₹14,490  \
# 17  Redmi 10 Prime (Astral White, 64 GB)     4.2  ₹14,490
#
#                                                imgURL
# 54  https://rukminim2.flixcart.com/image/312/312/k...  \
# 17  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 54  Internal Storage64 GBRAM4 GBMemory Card Slot T...  \
# 17  Internal Storage64 GBRAM4 GBMemory Card Slot T...
#
#                                          os_processor
# 54  Operating SystemAndroid 11Processor CoreOcta C...  \
# 17  Operating SystemAndroid 11Processor CoreOcta C...
#
#                                                camera
# 54  Primary Camera8MP Rear CameraDual Camera LensP...  \
# 17  Primary Camera8MP Rear CameraDual Camera LensP...
#
#                                               display
# 54  Display Size16.51 cm (6.5 inch)Resolution2400 ...  \
# 17  Display Size16.51 cm (6.5 inch)Resolution2400 ...
#
#                                               network
# 54  Network Type4G VOLTE, 4GSupported Networks4G V...  \
# 17  Network Type4G VOLTE, 4GSupported Networks4G V...
#
#                      battery
# 54  Battery Capacity6000 mAh
# 17  Battery Capacity6000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:4
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4 Page
# page df : page_shape : (24, 10)
#                                           name ratings    price
# 19  REDMI Note 11 Pro (Phantom White, 128 GB)     4.2  ₹21,290  \
# 23              Redmi 7A (Matte Black, 32 GB)     4.3   ₹6,999
#
#                                                imgURL
# 19  https://rukminim2.flixcart.com/image/312/312/x...  \
# 23  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 19  Internal Storage128 GBRAM6 GBMemory Card Slot ...  \
# 23  Internal Storage32 GBRAM2 GBExpandable Storage...
#
#                                          os_processor
# 19  Operating SystemAndroid Q 11Processor CoreDual...  \
# 23  Operating SystemAndroid Pie 9.0Processor TypeQ...
#
#                                                camera
# 19  Primary Camera108MP Rear CameraDual Camera Len...  \
# 23  Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                               display
# 19  Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 23  Display Size13.84 cm (5.45 inch)Resolution1440...
#
#                                               network
# 19        Network Type4GSupported Networks4G LTE, GSM  \
# 23  Network Type4G VOLTE, 3G, 2GSupported Networks...
#
#                      battery
# 19  Battery Capacity5000 mAh
# 23  Battery Capacity4000 mAh
# df : df shape : (96, 10)
#                                          name ratings    price
# 39  Redmi Note 9 Pro (Glacier White, 128 GB)     4.3  ₹17,999  \
# 42       Redmi 9A Sport (Coral Green, 32 GB)     4.1   ₹7,090
#
#                                                imgURL
# 39  https://rukminim2.flixcart.com/image/312/312/k...  \
# 42  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 39  Internal Storage128 GBRAM4 GBExpandable Storag...  \
# 42  Internal Storage32 GBRAM2 GBMemory Card Slot T...
#
#                                          os_processor
# 39  Operating SystemAndroid Q 10Processor TypeQual...  \
# 42  Operating SystemAndroid Q 10Processor CoreOcta...
#
#                                                camera
# 39  Primary Camera AvailableYesPrimary Camera48MP ...  \
# 42                     Primary Camera13MP Rear Camera
#
#                                               display
# 39  Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 42  Display Size16.59 cm (6.53 inch)Resolution720 ...
#
#                                               network
# 39  Network Type4G VOLTE, 3GSupported Networks4G L...  \
# 42   Network Type4G VOLTE, 4GSupported Networks4G LTE
#
#                                               battery
# 39  Battery Capacity5020 mAhBattery Typelithium-io...
# 42                           Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:5
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5 Page
# page df : page_shape : (24, 10)
#                                      name ratings    price
# 6   MI 11X 5G (CELESTIAL SILVER, 128 GB)     4.2  ₹25,999  \
# 12      Redmi 8A (Midnight Black, 32 GB)     4.4   ₹7,999
#
#                                                imgURL
# 6   https://rukminim2.flixcart.com/image/312/312/k...  \
# 12  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 6                       Internal Storage128 GBRAM6 GB  \
# 12  Internal Storage32 GBRAM2 GBExpandable Storage...
#
#                                          os_processor
# 6   Operating SystemAndroid Nougat 11Processor Cor...  \
# 12  Operating SystemAndroid Pie 9.0Processor TypeQ...
#
#                                                camera
# 6                      Primary Camera48MP Rear Camera  \
# 12  Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                               display
# 6   Display Size16.94 cm (6.67 inch)Resolution1080...  \
# 12  Display Size15.8 cm (6.22 inch)Resolution1520 ...
#
#                                               network
# 6   Network Type4G VOLTE, 5GSupported Networks4G V...  \
# 12  Network Type4G VOLTE, 3G, 2GSupported Networks...
#
#                                            battery
# 6                         Battery Capacity4520 mAh
# 12  Battery Capacity5000 mAhBattery TypeLi-polymer
# df : df shape : (120, 10)
#                         name ratings   price
# 74  Redmi Go (Black, 16 GB)     4.3  ₹5,999  \
# 75   Redmi 6 (Black, 32 GB)     4.4  ₹8,999
#
#                                                imgURL
# 74  https://rukminim2.flixcart.com/image/312/312/j...  \
# 75  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                           storage_ram
# 74  Internal Storage16 GBRAM1 GBExpandable Storage...  \
# 75  Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                          os_processor
# 74  Operating SystemAndroid Oreo 8.1Processor Type...  \
# 75  Operating SystemAndroid Oreo 8.1Processor Type...
#
#                                                camera
# 74  Primary Camera AvailableYesPrimary Camera8MP R...  \
# 75  Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                               display
# 74  Display Size12.7 cm (5 inch)Resolution1280 x 7...  \
# 75  Display Size13.84 cm (5.45 inch)Resolution1440...
#
#                                               network
# 74  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...  \
# 75  Network Type3G, 4G VOLTE, 2GSupported Networks...
#
#                                               battery
# 74                           Battery Capacity3000 mAh
# 75  Battery Capacity3000 mAhBattery TypeLithium-po...
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:6
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=6 Page
# page df : page_shape : (24, 10)
#                                 name ratings    price
# 6   Redmi K20 (Carbon Black, 64 GB)     4.5  ₹22,999  \
# 11     Redmi 8A (Ocean Blue, 32 GB)     4.4   ₹8,999
#
#                                                imgURL
# 6   https://rukminim2.flixcart.com/image/312/312/j...  \
# 11  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 6                        Internal Storage64 GBRAM6 GB  \
# 11  Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                          os_processor
# 6   Operating SystemAndroid Pie 9.0Processor TypeQ...  \
# 11  Operating SystemAndroid Pie 9.0Processor TypeQ...
#
#                                                camera
# 6   Primary Camera AvailableYesPrimary Camera48MP ...  \
# 11  Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                               display
# 6   Display Size16.23 cm (6.39 inch)Resolution2340...  \
# 11  Display Size15.8 cm (6.22 inch)Resolution1520 ...
#
#                                               network
# 6   Network Type3G, 4G VOLTE, 2GSupported Networks...  \
# 11  Network Type3G, 4G VOLTE, 2GSupported Networks...
#
#                                            battery
# 6                         Battery Capacity4000 mAh
# 11  Battery Capacity5000 mAhBattery TypeLi-polymer
# df : df shape : (144, 10)
#                                                 name ratings    price
# 36                     Redmi 7A (Matte Blue, 32 GB)     4.3   ₹6,999  \
# 51  Xiaomi 11i Hypercharge 5G (Purple Mist, 128 GB)     4.2  ₹23,999
#
#                                                imgURL
# 36  https://rukminim2.flixcart.com/image/312/312/k...  \
# 51  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 36  Internal Storage32 GBRAM2 GBExpandable Storage...  \
# 51  Internal Storage128 GBRAM6 GBTotal Memory128 G...
#
#                                          os_processor
# 36  Operating SystemAndroid Pie 9.0Processor TypeQ...  \
# 51  Operating SystemAndroid 11Processor TypeMediat...
#
#                                                camera
# 36  Primary Camera AvailableYesPrimary Camera12MP ...  \
# 51  Primary Camera AvailableYesPrimary Camera108MP...
#
#                                               display
# 36  Display Size13.84 cm (5.45 inch)Resolution1440...  \
# 51  Display Size16.94 cm (6.67 inch)Resolution2400...
#
#                                               network
# 36  Network Type4G VOLTE, 3G, 2GSupported Networks...  \
# 51  Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...
#
#                                     battery
# 36                 Battery Capacity4000 mAh
# 51  Battery Capacity4500 mAhTalk Time28 hrs
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:7
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=7 Page
# page df : page_shape : (24, 10)
#                          name ratings    price
# 11     Redmi 6 (Gold, 64 GB)     4.4  ₹10,499  \
# 8   Mi Mix 2 (Black, 128 GB)     4.3  ₹37,999
#
#                                                imgURL
# 11  https://rukminim2.flixcart.com/image/312/312/j...  \
# 8   https://rukminim2.flixcart.com/image/312/312/j...
#
#                                           storage_ram
# 11  Internal Storage64 GBRAM3 GBExpandable Storage...  \
# 8                       Internal Storage128 GBRAM6 GB
#
#                                          os_processor
# 11  Operating SystemAndroid Oreo 8.1Processor Type...  \
# 8   Operating SystemAndroid Nougat 7.1.1Processor ...
#
#                                                camera
# 11  Primary Camera AvailableYesPrimary Camera12MP ...  \
# 8   Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                               display
# 11  Display Size13.84 cm (5.45 inch)Resolution1440...  \
# 8   Display Size15.21 cm (5.99 inch)Resolution2160...
#
#                                               network
# 11  Network Type3G, 4G VOLTE, 2GSupported Networks...  \
# 8   Network Type3G, 4G VOLTE, 2GSupported Networks...
#
#                                               battery
# 11  Battery Capacity3000 mAhBattery TypeLithium-po...
# 8                            Battery Capacity3400 mAh
# df : df shape : (168, 10)
#                                          name ratings    price
# 145    REDMI Note 11 Pro (Star Blue, 128 GB)     4.1  ₹23,999  \
# 66   Xiaomi 12 Pro 5G (Couture Blue, 256 GB)     4.2  ₹44,999
#
#                                                 imgURL
# 145  https://rukminim2.flixcart.com/image/312/312/x...  \
# 66   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 145  Internal Storage128 GBRAM8 GBMemory Card Slot ...  \
# 66    Internal Storage256 GBRAM12 GBCall Log MemoryYes
#
#                                           os_processor
# 145  Operating SystemAndroid Q 11Processor CoreDual...  \
# 66   Operating SystemAndroid 12Processor TypeSnapdr...
#
#                                                 camera
# 145  Primary Camera108MP Rear CameraDual Camera Len...  \
# 66   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                                display
# 145  Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 66   Display Size17.09 cm (6.73 inch)Resolution2400...
#
#                                                network
# 145        Network Type4GSupported Networks4G LTE, GSM  \
# 66   Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...
#
#                                                battery
# 145                           Battery Capacity5000 mAh
# 66   Battery Capacity4600 mAhBattery TypeLithium Po...
#
# Length of mob_names: 24
# Length of mob_ratings: 0
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:8
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=8 Page
# page df : page_shape : (24, 10)
#                                      name  ratings    price
# 16  Redmi Note 7 Pro (Nebula Red, 64 GB)      NaN  ₹16,999  \
# 1                 Redmi 5A (Grey, 16 GB)      NaN   ₹5,999
#
#                                                imgURL
# 16  https://rukminim2.flixcart.com/image/312/312/k...  \
# 1   https://rukminim2.flixcart.com/image/312/312/j...
#
#                                           storage_ram
# 16  Internal Storage64 GBRAM6 GBExpandable Storage...  \
# 1   Internal Storage16 GBRAM2 GBExpandable Storage...
#
#                                          os_processor
# 16  Operating SystemAndroid Pie 9Processor TypeQua...  \
# 1   Operating SystemAndroid Nougat 7.1.2Processor ...
#
#                                                camera
# 16  Primary Camera AvailableYesPrimary Camera48MP ...  \
# 1   Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 16  Display Size16.0 cm (6.3 inch)Resolution2340 x...  \
# 1   Display Size12.7 cm (5 inch)Resolution1280 x 7...
#
#                                               network
# 16  Network Type3G, 4G VOLTE, 2GSupported Networks...  \
# 1   Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
#
#                      battery
# 16  Battery Capacity4000 mAh
# 1   Battery Capacity3000 mAh
# df : df shape : (192, 10)
#                                        name ratings   price
# 114  Redmi 9A Sport (Metallic Blue, 32 GB)     4.2  ₹9,498  \
# 36            Redmi 7A (Matte Blue, 32 GB)     4.3  ₹6,999
#
#                                                 imgURL
# 114  https://rukminim2.flixcart.com/image/312/312/x...  \
# 36   https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 114  Internal Storage32 GBRAM3 GBMemory Card Slot T...  \
# 36   Internal Storage32 GBRAM2 GBExpandable Storage...
#
#                                           os_processor
# 114  Operating SystemAndroid Q 10Processor CoreOcta...  \
# 36   Operating SystemAndroid Pie 9.0Processor TypeQ...
#
#                                                 camera
# 114                     Primary Camera13MP Rear Camera  \
# 36   Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                                display
# 114  Display Size16.59 cm (6.53 inch)Resolution1600...  \
# 36   Display Size13.84 cm (5.45 inch)Resolution1440...
#
#                                                network
# 114  Network Type4G VOLTE, 4GSupported Networks4G V...  \
# 36   Network Type4G VOLTE, 3G, 2GSupported Networks...
#
#                       battery
# 114  Battery Capacity5000 mAh
# 36   Battery Capacity4000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:9
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=9 Page
# page df : page_shape : (24, 10)
#                                        name ratings    price
# 2      Redmi Note 5 Pro (Lake Blue, 64 GB)     4.5  ₹14,999  \
# 13  REDMI 11 Prime (Playful Green, 128 GB)     4.4  ₹10,999
#
#                                                imgURL
# 2   https://rukminim2.flixcart.com/image/312/312/j...  \
# 13  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 2   Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 13  Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                          os_processor
# 2   Operating SystemAndroid Nougat 7.1.2Processor ...  \
# 13  Operating SystemAndroid 12Processor TypeHelio ...
#
#                                                camera
# 2   Primary Camera AvailableYesPrimary Camera12MP ...  \
# 13  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 2   Display Size15.21 cm (5.99 inch)Resolution2160...  \
# 13  Display Size16.71 cm (6.58 inch)Resolution2408...
#
#                                               network
# 2   Network Type3G, 4G VOLTE, 4GSupported Networks...  \
# 13  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                                               battery
# 2                            Battery Capacity4000 mAh
# 13  Battery Capacity5000 mAhBattery TypeLithium Po...
# df : df shape : (216, 10)
#                                  name ratings    price
# 209  REDMI Note 12 (Ice Blue, 64 GB)     4.1  ₹13,999  \
# 56        Redmi 6 (Rose Gold, 32 GB)     4.4   ₹8,999
#
#                                                 imgURL
# 209  https://rukminim2.flixcart.com/image/312/312/x...  \
# 56   https://rukminim2.flixcart.com/image/312/312/j...
#
#                                            storage_ram
# 209  Internal Storage64 GBRAM6 GBExpandable Storage...  \
# 56   Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                           os_processor
# 209  Operating SystemAndroid 13Processor TypeSnapdr...  \
# 56   Operating SystemAndroid Oreo 8.1Processor Type...
#
#                                                 camera
# 209  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 56   Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                                display
# 209  Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 56   Display Size13.84 cm (5.45 inch)Resolution1440...
#
#                                                network
# 209  Network Type2G, 3G, 4G, 4G VOLTESupported Netw...  \
# 56   Network Type3G, 4G VOLTE, 2GSupported Networks...
#
#                                                battery
# 209  Battery Capacity5000 mAhBattery TypeLithium Po...
# 56   Battery Capacity3000 mAhBattery TypeLithium-po...
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:10
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=10 Page
# page df : page_shape : (24, 10)
#                                                name ratings    price
# 11  REDMI Note 12 Pro 5G (Stardust Purple, 128 GB)     4.2  ₹23,999  \
# 17        REDMI Note 12 5G (Frosted Green, 128 GB)       4  ₹16,999
#
#                                                imgURL
# 11  https://rukminim2.flixcart.com/image/312/312/x...  \
# 17  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 11  Internal Storage128 GBRAM6 GBTotal Memory128 G...  \
# 17  Internal Storage128 GBRAM4 GBExpandable Storag...
#
#                                          os_processor
# 11  Operating SystemAndroid 12Processor TypeMediat...  \
# 17  Operating SystemAndroid 12Processor TypeQualco...
#
#                                                camera
# 11  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 17  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                               display
# 11  Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 17  Display Size16.94 cm (6.67 inch)Resolution2400...
#
#                                               network
# 11  Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...  \
# 17  Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...
#
#                                               battery
# 11  Battery Capacity5000 mAhBattery TypeLithium Po...
# 17  Battery Capacity5000 mAhBattery TypeLithium Po...
# df : df shape : (240, 10)
#                                        name ratings    price
# 38  Redmi Note 9 Pro (Aurora Blue, 128 GB)     4.3  ₹14,999  \
# 44               Redmi 9A (SeaBlue, 32 GB)     4.3   ₹7,499
#
#                                                imgURL
# 38  https://rukminim2.flixcart.com/image/312/312/k...  \
# 44  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 38  Internal Storage128 GBRAM6 GBExpandable Storag...  \
# 44  Internal Storage32 GBRAM2 GBMemory Card Slot T...
#
#                                          os_processor
# 38  Operating SystemAndroid Pie 10Processor TypeQu...  \
# 44  Operating SystemAndroid Q 10Processor CoreOcta...
#
#                                                camera
# 38  Primary Camera AvailableYesPrimary Camera48MP ...  \
# 44                     Primary Camera13MP Rear Camera
#
#                                               display
# 38  Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 44  Display Size16.59 cm (6.53 inch)Resolution720 ...
#
#                                               network
# 38  Network Type4G VOLTE, 3GSupported Networks4G L...  \
# 44  Network Type4G VOLTE, 3GSupported Networks4G V...
#
#                                               battery
# 38  Battery Capacity5020 mAhBattery Typelithium-io...
# 44                           Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:11
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=11 Page
# page df : page_shape : (24, 10)
#                                 name ratings    price
# 19   REDMI 12C (Matte Black, 64 GB)     4.2   ₹8,815  \
# 3   REDMI 10 (Pacific Blue, 128 GB)     4.2  ₹10,999
#
#                                                imgURL
# 19  https://rukminim2.flixcart.com/image/312/312/x...  \
# 3   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 19  Internal Storage64 GBRAM4 GBMemory Card Slot T...  \
# 3   Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                          os_processor
# 19  Operating SystemAndroid MIUI 13, Android 12.0P...  \
# 3   Operating SystemAndroid 11Processor TypeQualco...
#
#                                                camera
# 19  Primary Camera50MP Rear CameraDual Camera Lens...  \
# 3   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 19  Display Size17.04 cm (6.71 inch)Resolution1650...  \
# 3   Display Size17.02 cm (6.7 inch)Resolution1650 ...
#
#                                               network
# 19     Network Type4G VOLTESupported Networks4G VoLTE  \
# 3   Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                                               battery
# 19                           Battery Capacity5000 mAh
# 3   Battery Capacity6000 mAhTalk Time32 HrsDual Ba...
# df : df shape : (264, 10)
#                                           name ratings    price
# 239            13 pro (Ceramic White, 256 GB)     3.6  ₹74,990  \
# 231  REDMI Note 12 5G (Mystique Blue, 128 GB)       4  ₹16,999
#
#                                                 imgURL
# 239  https://rukminim2.flixcart.com/image/312/312/x...  \
# 231  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 239  Internal Storage256 GBRAM12 GBMemory Card Slot...  \
# 231  Internal Storage128 GBRAM4 GBExpandable Storag...
#
#                                           os_processor
# 239  Operating SystemAndroid MIUI 14, Android 13.0P...  \
# 231  Operating SystemAndroid 12Processor TypeQualco...
#
#                                                 camera
# 239  Primary Camera50MP Rear CameraDual Camera Lens...  \
# 231  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                                display
# 239  Display Size17.09 cm (6.73 inch)Resolution3200...  \
# 231  Display Size16.94 cm (6.67 inch)Resolution2400...
#
#                                                network
# 239                 Network Type5GSupported Networks5G  \
# 231  Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...
#
#                                                battery
# 239                           Battery Capacity4820 mAh
# 231  Battery Capacity5000 mAhBattery TypeLithium Po...
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:12
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=12 Page
# page df : page_shape : (24, 10)
#                                      name ratings    price
# 1      REDMI 10 (Caribbean Green, 64 GB)     4.3   ₹9,999  \
# 17  REDMI Note 11S (Polar White, 128 GB)     4.1  ₹20,999
#
#                                                imgURL
# 1   https://rukminim2.flixcart.com/image/312/312/x...  \
# 17  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 1   Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 17  Internal Storage128 GBRAM6 GBMemory Card Slot ...
#
#                                          os_processor
# 1   Operating SystemAndroid 11Processor TypeQualco...  \
# 17  Operating SystemAndroid Q 11Processor CoreOcta...
#
#                                                camera
# 1   Primary Camera AvailableYesPrimary Camera50MP ...  \
# 17  Primary Camera108MP Rear CameraDual Camera Len...
#
#                                               display
# 1   Display Size17.02 cm (6.7 inch)Resolution1650 ...  \
# 17  Display Size16.33 cm (6.43 inch)Resolution2400...
#
#                                               network
# 1   Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 17                 Network Type5GSupported Networks5G
#
#                                               battery
# 1   Battery Capacity6000 mAhTalk Time32 HrsDual Ba...
# 17                           Battery Capacity5000 mAh
# df : df shape : (288, 10)
#                                        name ratings    price
# 44               Redmi 9A (SeaBlue, 32 GB)     4.3   ₹7,499  \
# 57  Xiaomi 11Lite NE (Vinyl Black, 128 GB)     4.2  ₹20,999
#
#                                                imgURL
# 44  https://rukminim2.flixcart.com/image/312/312/k...  \
# 57  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 44  Internal Storage32 GBRAM2 GBMemory Card Slot T...  \
# 57  Internal Storage128 GBRAM6 GBMemory Card Slot ...
#
#                                          os_processor
# 44  Operating SystemAndroid Q 10Processor CoreOcta...  \
# 57  Operating SystemAndroid 11Processor CoreOcta C...
#
#                                                camera
# 44                     Primary Camera13MP Rear Camera  \
# 57  Primary Camera64MP Rear CameraDual Camera Lens...
#
#                                               display
# 44  Display Size16.59 cm (6.53 inch)Resolution720 ...  \
# 57  Display Size16.64 cm (6.55 inch)Resolution2400...
#
#                                               network
# 44  Network Type4G VOLTE, 3GSupported Networks4G V...  \
# 57                 Network Type5GSupported Networks5G
#
#                      battery
# 44  Battery Capacity5000 mAh
# 57  Battery Capacity4250 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 23
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:13
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=13 Page
# page df : page_shape : (24, 10)
#                                      name ratings    price
# 23  REDMI Note 11S (Polar White, 128 GB)     4.1  ₹15,995  \
# 0      REDMI 9 Prime (Space Blue, 64 GB)     4.4  ₹11,490
#
#                                                imgURL
# 23  https://rukminim2.flixcart.com/image/312/312/x...  \
# 0   https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 23  Internal Storage128 GBRAM6 GBMemory Card Slot ...  \
# 0   Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                          os_processor
# 23  Operating SystemAndroid Q 11Processor CoreOcta...  \
# 0   Operating SystemAndroid 10Processor TypeMediaT...
#
#                                                camera
# 23                                                NaN  \
# 0   Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 23  Display Size16.33 cm (6.43 inch)Resolution2400...  \
# 0   Display Size16.59 cm (6.53 inch)Resolution2340...
#
#                                               network
# 23                 Network Type5GSupported Networks5G  \
# 0   Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                                     battery
# 23                 Battery Capacity5000 mAh
# 0   Battery Capacity5020 mAhTalk Time31 hrs
# df : df shape : (312, 10)
#                                            name ratings    price
# 287  REDMI 10 Prime 2022 (Bifrost Blue, 64 GB)     4.2  ₹11,990  \
# 70           Redmi Note 7S (Onyx Black, 32 GB)     4.3  ₹11,999
#
#                                                 imgURL
# 287  https://rukminim2.flixcart.com/image/312/312/l...  \
# 70   https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 287  Internal Storage64 GBRAM4 GBMemory Card Slot T...  \
# 70   Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                           os_processor
# 287  Operating SystemAndroid Q MIUI 11Processor Cor...  \
# 70   Operating SystemAndroid Pie 9.0Processor TypeQ...
#
#                                                 camera
# 287  Primary Camera8MP Rear CameraDual Camera LensP...  \
# 70   Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                                display
# 287  Display Size16.51 cm (6.5 inch)Resolution1080 ...  \
# 70   Display Size16.0 cm (6.3 inch)Resolution2340 x...
#
#                                                network
# 287             Network Type4GSupported Networks4G LTE  \
# 70   Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
#
#                                             battery
# 287                        Battery Capacity6000 mAh
# 70   Battery Capacity4000 mAhBattery TypeLi-polymer
#
# Length of mob_names: 24
# Length of mob_ratings: 0
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 23
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:14
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=14 Page
# page df : page_shape : (24, 10)
#                                      name  ratings    price
# 1                              Peace Mi4      NaN     ₹849  \
# 17  REDMI Note 11S (Polar White, 128 GB)      NaN  ₹16,390
#
#                                                imgURL
# 1   https://rukminim2.flixcart.com/image/312/312/x...  \
# 17  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 1   Internal Storage128 MBRAM64 MBMemory Card Slot...  \
# 17  Internal Storage128 GBRAM8 GBMemory Card Slot ...
#
#                                          os_processor
# 1     Operating System1.77Primary Clock Speed1.77 MHz  \
# 17  Operating SystemAndroid Q 11Processor CoreOcta...
#
#                                                camera
# 1   Primary Camera108MP Rear CameraDual Camera Len...  \
# 17  Primary Camera108MP Rear CameraDual Camera Len...
#
#                                               display
# 1   Display Size4.57 cm (1.8 inch)Resolution128x16...  \
# 17  Display Size16.33 cm (6.43 inch)Resolution720 ...
#
#                                               network
# 1                 Network Type2GSupported NetworksGSM  \
# 17  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 1   Battery Capacity2500 mAh
# 17  Battery Capacity5000 mAh
# df : df shape : (336, 10)
#                                 name ratings    price
# 169          Redmi 5A (Grey, 16 GB)     NaN   ₹5,999  \
# 32   Mi 11 Lite (Jazz Blue, 128 GB)     4.2  ₹17,499
#
#                                                 imgURL
# 169  https://rukminim2.flixcart.com/image/312/312/j...  \
# 32   https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 169  Internal Storage16 GBRAM2 GBExpandable Storage...  \
# 32   Internal Storage128 GBRAM8 GBExpandable Storag...
#
#                                           os_processor
# 169  Operating SystemAndroid Nougat 7.1.2Processor ...  \
# 32   Operating SystemAndroid 11Processor TypeQualco...
#
#                                                 camera
# 169  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 32   Primary Camera AvailableYesPrimary Camera64MP ...
#
#                                                display
# 169  Display Size12.7 cm (5 inch)Resolution1280 x 7...  \
# 32   Display Size16.64 cm (6.55 inch)Resolution2400...
#
#                                                network
# 169  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...  \
# 32   Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                                      battery
# 169                 Battery Capacity3000 mAh
# 32   Battery Capacity4250 mAhTalk Time30 hrs
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:15
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=15 Page
# page df : page_shape : (24, 10)
#                                       name ratings    price
# 15    REDMI Note 9 (Shadow Black, 128 GB)     4.3  ₹14,999  \
# 5   REDMI 10 Prime (Bifrost Blue, 128 GB)     4.2  ₹14,890
#
#                                                imgURL
# 15  https://rukminim2.flixcart.com/image/312/312/k...  \
# 5   https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 15  Internal Storage128 GBRAM4 GBExpandable Storag...  \
# 5   Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                          os_processor
# 15  Operating SystemAndroid 10Processor TypeMediaT...  \
# 5   Operating SystemAndroid Android 11Processor Ty...
#
#                                                camera
# 15  Primary Camera AvailableYesPrimary Camera48MP ...  \
# 5   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 15  Display Size16.59 cm (6.53 inch)Resolution2340...  \
# 5   Display Size16.51 cm (6.5 inch)Resolution2400 ...
#
#                                               network
# 15  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 5   Network Type4G VOLTE, 4GSupported Networks4G V...
#
#                                               battery
# 15  Battery Capacity5020 mAhBattery TypeLithium Po...
# 5           Battery Capacity6000 mAhBattery TypeLi-Po
# df : df shape : (360, 10)
#                                name ratings    price
# 50   Mi 11X (Cosmic Black, 128 GB)     4.2  ₹23,990  \
# 223  REDMI 12C (Royal Blue, 64 GB)     4.2   ₹8,921
#
#                                                 imgURL
# 50   https://rukminim2.flixcart.com/image/312/312/x...  \
# 223  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 50   Internal Storage128 GBRAM8 GBMemory Card Slot ...  \
# 223  Internal Storage64 GBRAM4 GBMemory Card Slot T...
#
#                                           os_processor
# 50   Operating SystemAndroid Q 11Processor CoreOcta...  \
# 223  Operating SystemAndroid MIUI 13, Android 12.0P...
#
#                                                 camera
# 50   Primary Camera48MP Rear CameraDual Camera Lens...  \
# 223  Primary Camera50MP Rear CameraDual Camera Lens...
#
#                                                display
# 50   Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 223  Display Size17.04 cm (6.71 inch)Resolution1650...
#
#                                             network                   battery
# 50   Network Type5G, 4G, 3G, 2GSupported Networks5G  Battery Capacity4520 mAh
# 223  Network Type4G VOLTESupported Networks4G VoLTE  Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# ...
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:19
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=19 Page
# page df : page_shape : (24, 10)
#                                            name ratings    price
# 4                  Redmi 1S (Metal Gray, 8 GB)     4.3   ₹5,999  \
# 22  REDMI Note 11T 5G (Aquamarine Blue, 64 GB)     4.2  ₹16,795
#
#                                                imgURL
# 4   https://rukminim2.flixcart.com/image/312/312/j...  \
# 22  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 4   Internal Storage8 GBRAM1 GBExpandable Storage6...  \
# 22  Internal Storage64 GBRAM6 GBMemory Card Slot T...
#
#                                          os_processor
# 4   Operating SystemAndroid Jelly Bean 4.3Processo...  \
# 22  Operating SystemAndroid Q 11Processor CoreOcta...
#
#                                                camera
# 4   Primary Camera AvailableYesPrimary Camera8MP R...  \
# 22  Primary Camera50MP Rear CameraDual Camera Lens...
#
#                                               display
# 4   Display Size11.94 cm (4.7 inch)Resolution1280 ...  \
# 22  Display Size16.76 cm (6.6 inch)Resolution2400 ...
#
#                                               network
# 4   Network Type3GSupported NetworksGSM, WCDMAInte...  \
# 22            Network Type5GSupported NetworksGSM, 5G
#
#                      battery
# 4   Battery Capacity2000 mAh
# 22  Battery Capacity5000 mAh
# df : df shape : (456, 10)
#                                          name ratings    price
# 353  REDMI Note 11T 5G (Matte black, 128 GB)     4.2  ₹21,199  \
# 193    Redmi Note 8 (Moonlight White, 64 GB)     4.4  ₹12,999
#
#                                                 imgURL
# 353  https://rukminim2.flixcart.com/image/312/312/x...  \
# 193  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 353  Internal Storage128 GBRAM8 GBMemory Card Slot ...  \
# 193  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                           os_processor
# 353  Operating SystemAndroid Q 11Processor CoreOcta...  \
# 193  Operating SystemAndroid Pie 9Processor TypeQua...
#
#                                                 camera
# 353  Primary Camera50MP Rear CameraDual Camera Lens...  \
# 193  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                                display
# 353  Display Size16.76 cm (6.6 inch)Resolution2400 ...  \
# 193  Display Size16.0 cm (6.3 inch)Resolution2340 x...
#
#                                                network
# 353     Network Type5G, 4G, 3G, 2GSupported Networks5G  \
# 193  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                                              battery
# 353                         Battery Capacity5000 mAh
# 193  Battery Capacity4000 mAhBattery Typelithium-ion
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:20
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=20 Page
# page df : page_shape : (24, 10)
#                                           name ratings    price
# 0                    Redmi 3S (Silver, 16 GB)     4.3   ₹6,999  \
# 12  REDMI Note 11 Pro (Phantom White, 128 GB)     4.1  ₹18,336
#
#                                                imgURL
# 0   https://rukminim2.flixcart.com/image/312/312/m...  \
# 12  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 0   Internal Storage16 GBRAM2 GBExpandable Storage...  \
# 12  Internal Storage128 GBRAM8 GBMemory Card Slot ...
#
#                                          os_processor
# 0   Operating SystemAndroid Marshmallow 6.0.1Proce...  \
# 12  Operating SystemAndroid Q 11Processor CoreDual...
#
#                                                camera
# 0   Primary Camera AvailableYesPrimary Camera13MP ...  \
# 12  Primary Camera108MP Rear CameraDual Camera Len...
#
#                                               display
# 0   Display Size12.7 cm (5 inch)Resolution1280 x 7...  \
# 12  Display Size16.94 cm (6.67 inch)Resolution2400...
#
#                                               network
# 0   Network Type3G, 4GSupported NetworksWCDMA, 4G ...  \
# 12        Network Type4GSupported Networks4G LTE, GSM
#
#                                               battery
# 0   Battery Capacity4100 mAhBattery TypeLi-Ion Pol...
# 12                           Battery Capacity5000 mAh
# df : df shape : (480, 10)
#                                         name ratings    price
# 412  REDMI Note 10 Pro (Dark Night, 128 GB)     4.2  ₹17,990  \
# 401         REDMI A2 (Classic Black, 64 GB)     4.1   ₹7,499
#
#                                                 imgURL
# 412  https://rukminim2.flixcart.com/image/312/312/l...  \
# 401  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 412  Internal Storage128 GBRAM6 GBExpandable Storag...  \
# 401  Internal Storage64 GBRAM4 GBMemory Card Slot T...
#
#                                           os_processor
# 412  Operating SystemAndroid 11Processor TypeQualco...  \
# 401  Operating SystemAndroid Q 13Processor CoreOcta...
#
#                                                 camera
# 412  Primary Camera AvailableYesPrimary Camera64MP ...  \
# 401  Primary Camera8MP Rear CameraDual Camera LensP...
#
#                                                display
# 412  Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 401  Display Size16.56 cm (6.52 inch)Resolution2160...
#
#                                                network
# 412  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 401           Network Type4GSupported Networks4G VoLTE
#
#                                        battery
# 412  Battery Capacity5020 mAhTalk Time36 hours
# 401                   Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 23
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:21
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=21 Page
# page df : page_shape : (24, 10)
#                                     name ratings    price
# 14                   10A (Black, 64 GB)     4.3   ₹9,999  \
# 10  Redmi K20 Pro (Pearl White, 256 GB)     4.5  ₹31,999
#
#                                                imgURL
# 14  https://rukminim2.flixcart.com/image/312/312/x...  \
# 10  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 14  Internal Storage64 GBRAM4 GBMemory Card Slot T...  \
# 10                      Internal Storage256 GBRAM8 GB
#
#                                          os_processor
# 14  Operating SystemAndroid Q 12Processor TypeMedi...  \
# 10  Operating SystemAndroid Pie 9Processor TypeQua...
#
#                                                camera
# 14  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 10  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                               display
# 14  Display Size16.59 cm (6.53 inch)Resolution1600...  \
# 10  Display Size16.23 cm (6.39 inch)Resolution2340...
#
#                                               network
# 14  Network Type4G VOLTE, 2G, 4G, 3GSupported Netw...  \
# 10  Network Type3G, 4G VOLTE, 2GSupported Networks...
#
#                      battery
# 14  Battery Capacity5000 mAh
# 10  Battery Capacity4000 mAh
# df : df shape : (504, 10)
#                                  name ratings    price
# 32    Mi 11 Lite (Jazz Blue, 128 GB)     4.2  ₹17,499  \
# 43  Redmi 9A (Midnight Black, 32 GB)     4.3   ₹9,099
#
#                                                imgURL
# 32  https://rukminim2.flixcart.com/image/312/312/k...  \
# 43  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 32  Internal Storage128 GBRAM8 GBExpandable Storag...  \
# 43  Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                          os_processor
# 32  Operating SystemAndroid 11Processor TypeQualco...  \
# 43  Operating SystemAndroid Q 10Processor TypeMedi...
#
#                                                camera
# 32  Primary Camera AvailableYesPrimary Camera64MP ...  \
# 43  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 32  Display Size16.64 cm (6.55 inch)Resolution2400...  \
# 43  Display Size16.59 cm (6.53 inch)Resolution1600...
#
#                                               network
# 32  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 43  Network Type4G VOLTESupported Networks4G VoLTE...
#
#                                               battery
# 32            Battery Capacity4250 mAhTalk Time30 hrs
# 43  Battery Capacity5000 mAhBattery Typelithium-po...
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:22
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=22 Page
# page df : page_shape : (24, 10)
#                                name ratings    price
# 9  Redmi Note 4 (Lake Blue, 64 GB)     4.4  ₹12,749  \
# 1            Mi A2 (Black, 128 GB)     4.1  ₹20,500
#
#                                               imgURL
# 9  https://rukminim2.flixcart.com/image/312/312/j...  \
# 1  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                          storage_ram
# 9  Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 1                      Internal Storage128 GBRAM6 GB
#
#                                         os_processor
# 9  Operating SystemAndroid Marshmallow 6.0.1Proce...  \
# 1  Operating SystemAndroid Oreo 8.1Processor Type...
#
#                                               camera
# 9  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 1  Primary Camera AvailableYesPrimary Camera20MP ...
#
#                                              display
# 9  Display Size13.97 cm (5.5 inch)Resolution1920 ...  \
# 1  Display Size15.21 cm (5.99 inch)Resolution2160...
#
#                                              network
# 9  Network Type3G, 4G VOLTESupported Networks4G L...  \
# 1  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
#
#                                           battery
# 9                        Battery Capacity4100 mAh
# 1  Battery Capacity3010 mAhBattery TypeLi-polymer
# df : df shape : (528, 10)
#                                        name ratings    price
# 325  REDMI Note 10S (Cosmic Purple, 64 GB)     NaN  ₹16,999  \
# 50           Mi 11X (Cosmic Black, 128 GB)     4.2  ₹23,990
#
#                                                 imgURL
# 325  https://rukminim2.flixcart.com/image/312/312/k...  \
# 50   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 325  Internal Storage64 GBRAM6 GBExpandable Storage...  \
# 50   Internal Storage128 GBRAM8 GBMemory Card Slot ...
#
#                                           os_processor
# 325  Operating SystemAndroid 11Processor TypeMediat...  \
# 50   Operating SystemAndroid Q 11Processor CoreOcta...
#
#                                                 camera
# 325  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 50   Primary Camera48MP Rear CameraDual Camera Lens...
#
#                                                display
# 325  Display Size16.33 cm (6.43 inch)Resolution2400...  \
# 50   Display Size16.94 cm (6.67 inch)Resolution2400...
#
#                                                network
# 325  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 50      Network Type5G, 4G, 3G, 2GSupported Networks5G
#
#                       battery
# 325  Battery Capacity5000 mAh
# 50   Battery Capacity4520 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:23
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=23 Page
# page df : page_shape : (24, 10)
#                            name ratings   price
# 23  Redmi Note 3 (Gold, 32 GB)     4.3  ₹8,999  \
# 20      Redmi Y1 (Gold, 32 GB)     4.3  ₹8,999
#
#                                                imgURL
# 23  https://rukminim2.flixcart.com/image/312/312/m...  \
# 20  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                           storage_ram
# 23  Internal Storage32 GBRAM3 GBExpandable Storage...  \
# 20  Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                          os_processor
# 23  Operating SystemAndroid Lollipop 5.1Processor ...  \
# 20  Operating SystemAndroid Nougat 7.1.2Processor ...
#
#                                                camera
# 23  Primary Camera AvailableYesPrimary Camera16MP ...  \
# 20  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 23  Display Size13.97 cm (5.5 inch)Resolution1920 ...  \
# 20  Display Size13.97 cm (5.5 inch)Resolution1280 ...
#
#                                               network
# 23  Network Type3G, 4GSupported NetworksGSM, 4G LT...  \
# 20  Network Type3G, 4G, 2GSupported NetworksGSM, W...
#
#                                            battery
# 23  Battery Capacity4050 mAhBattery TypeLi-Polymer
# 20                        Battery Capacity3080 mAh
# df : df shape : (552, 10)
#                                           name ratings    price
# 78           Redmi 8A Dual (Sky White, 32 GB)     4.2   ₹8,999  \
# 6   Xiaomi 11Lite NE (Diamond Dazzle, 128 GB)     4.2  ₹20,999
#
#                                                imgURL
# 78  https://rukminim2.flixcart.com/image/312/312/k...  \
# 6   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 78  Internal Storage32 GBRAM3 GBExpandable Storage...  \
# 6   Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                          os_processor
# 78  Operating SystemAndroid Pie 9Processor TypeQua...  \
# 6   Operating SystemAndroid 11Processor TypeQualco...
#
#                                                camera
# 78  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 6   Primary Camera AvailableYesPrimary Camera64MP ...
#
#                                               display
# 78  Display Size15.8 cm (6.22 inch)Resolution1520 ...  \
# 6   Display Size16.64 cm (6.55 inch)Resolution1080...
#
#                                               network
# 78  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 6   Network Type5G, 4G VOLTESupported Networks5G, ...
#
#                                             battery
# 78  Battery Capacity5000 mAhBattery Typelithium-ion
# 6         Battery Capacity4250 mAhBattery TypeLi-Po

# %%
df
# Out:
#                                         name ratings    price
# 0     Xiaomi 11Lite NE (Vinyl Black, 128 GB)     4.2  ₹21,430  \
# 1       Redmi 9A Sport (Carbon Black, 32 GB)     4.1   ₹7,790
# 2     REDMI 10 Power (Sporty Orange, 128 GB)     4.2  ₹15,000
# 3        Redmi 9A Sport (Coral Green, 32 GB)     4.2   ₹8,990
# 4           Mi 11 Lite (Vinyl Black, 128 GB)     4.2  ₹17,499
# ..                                       ...     ...      ...
# 547        Mi 10T Pro (Lunar Silver, 128 GB)     4.2  ₹26,899
# 548                   Redmi Y1 (Gold, 32 GB)     4.3   ₹8,999
# 549  Redmi Note 7 Pro (Neptune Blue, 128 GB)     4.5  ₹17,999
# 550         Mi 10i (Pacific Sunrise, 128 GB)     4.3  ₹20,999
# 551               Redmi Note 3 (Gold, 32 GB)     4.3   ₹8,999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/k...
# ..                                                 ...
# 547  https://rukminim2.flixcart.com/image/312/312/k...
# 548  https://rukminim2.flixcart.com/image/312/312/j...
# 549  https://rukminim2.flixcart.com/image/312/312/j...
# 550  https://rukminim2.flixcart.com/image/312/312/k...
# 551  https://rukminim2.flixcart.com/image/312/312/m...
#
#                                            storage_ram
# 0    Internal Storage128 GBRAM6 GBExpandable Storag...  \
# 1    Internal Storage32 GBRAM2 GBMemory Card Slot T...
# 2    Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 3    Internal Storage32 GBRAM3 GBMemory Card Slot T...
# 4    Internal Storage128 GBRAM8 GBExpandable Storag...
# ..                                                 ...
# 547    Internal Storage128 GBRAM8 GBCall Log MemoryYes
# 548  Internal Storage32 GBRAM3 GBExpandable Storage...
# 549  Internal Storage128 GBRAM6 GBExpandable Storag...
# 550  Internal Storage128 GBRAM6 GBSupported Memory ...
# 551  Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                           os_processor
# 0    Operating SystemAndroid 11Processor TypeQualco...  \
# 1    Operating SystemAndroid Q 10Processor CoreOcta...
# 2    Operating SystemAndroid 13Processor CoreOcta C...
# 3    Operating SystemAndroid Q 10Processor CoreOcta...
# 4    Operating SystemAndroid 11Processor TypeQualco...
# ..                                                 ...
# 547  Operating SystemAndroid 10Processor TypeQualco...
# 548  Operating SystemAndroid Nougat 7.1.2Processor ...
# 549  Operating SystemAndroid Pie 9.0Processor TypeQ...
# 550  Operating SystemAndroid Q 11Processor TypeQual...
# 551  Operating SystemAndroid Lollipop 5.1Processor ...
#
#                                                 camera
# 0    Primary Camera AvailableYesPrimary Camera64MP ...  \
# 1                       Primary Camera13MP Rear Camera
# 2    Primary Camera50MP Rear CameraDual Camera Lens...
# 3                       Primary Camera13MP Rear Camera
# 4    Primary Camera AvailableYesPrimary Camera64MP ...
# ..                                                 ...
# 547  Primary Camera AvailableYesPrimary Camera108MP...
# 548  Primary Camera AvailableYesPrimary Camera13MP ...
# 549  Primary Camera AvailableYesPrimary Camera48MP ...
# 550  Primary Camera AvailableYesPrimary Camera108MP...
# 551  Primary Camera AvailableYesPrimary Camera16MP ...
#
#                                                display
# 0    Display Size16.64 cm (6.55 inch)Resolution1080...  \
# 1    Display Size16.59 cm (6.53 inch)Resolution720 ...
# 2    Display Size17.02 cm (6.7 inch)Resolution2400 ...
# 3    Display Size16.59 cm (6.53 inch)Resolution1600...
# 4    Display Size16.64 cm (6.55 inch)Resolution2400...
# ..                                                 ...
# 547  Display Size16.94 cm (6.67 inch)Resolution2400...
# 548  Display Size13.97 cm (5.5 inch)Resolution1280 ...
# 549  Display Size16.0 cm (6.3 inch)Resolution2340 x...
# 550  Display Size16.94 cm (6.67 inch)Resolution2400...
# 551  Display Size13.97 cm (5.5 inch)Resolution1920 ...
#
#                                                network
# 0    Network Type5G, 4G VOLTESupported Networks5G, ...  \
# 1    Network Type4G VOLTE, 4GSupported Networks4G V...
# 2         Network Type4G VOLTESupported Networks4G LTE
# 3    Network Type4G VOLTE, 4GSupported Networks4G V...
# 4    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# ..                                                 ...
# 547  Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...
# 548  Network Type3G, 4G, 2GSupported NetworksGSM, W...
# 549  Network Type3G, 4G VOLTE, 2GSupported Networks...
# 550  Network Type5GSupported Networks5GInternet Con...
# 551  Network Type3G, 4GSupported NetworksGSM, 4G LT...
#
#                                             battery
# 0         Battery Capacity4250 mAhBattery TypeLi-Po
# 1                          Battery Capacity5000 mAh
# 2                          Battery Capacity6000 mAh
# 3                          Battery Capacity5000 mAh
# 4           Battery Capacity4250 mAhTalk Time30 hrs
# ..                                              ...
# 547         Battery Capacity5000 mAhTalk Time26 hrs
# 548                        Battery Capacity3080 mAh
# 549                        Battery Capacity4000 mAh
# 550                        Battery Capacity4820 mAh
# 551  Battery Capacity4050 mAhBattery TypeLi-Polymer
#
# [552 rows x 10 columns]

# %%
print(os.getcwd())
os.chdir(r'd:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem')
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem\notebook\data_Ingestion\scraping
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem

# %%
df.to_csv(r'data\raw_data\mi_mobile_new_data.csv',index=False)
