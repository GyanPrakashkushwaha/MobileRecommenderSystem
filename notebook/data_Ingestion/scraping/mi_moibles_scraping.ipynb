# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import os
import numpy as np
from itertools import zip_longest

# %%
def bs4_soup(pages):
    URL = f'https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={pages}'
    request = requests.get(URL)
    soup = bs(request.text,'html.parser')
    soup = soup.find('div',class_ = '_1YokD2 _3Mn1Gg')

    return soup , URL

# %%
def mob_specs(soup):
    names = soup.find_all('div', class_='_4rR01T')
    mob_names = [i.text if i else None for i in names]

    ratings = soup.find_all('div', class_='_3LWZlK')
    mob_ratings = [i.text if i else None for i in ratings]

    price = soup.find_all('div', class_='_30jeq3 _1_WHN1')
    mob_price = [i.text if i else None for i in price]

    img = soup.find_all('div', class_='CXW8mj')
    mob_img_URL = [i.find('img')['src'] if i.find('img') else None for i in img]

    return mob_names, mob_ratings, mob_price, mob_img_URL

# %%
def features_from_mob_links(soup):
    mobile_links = ['https://www.flipkart.com' + i['href'] for i in soup.find_all('a', class_='_1fQZEK')]
    mobile_req = [requests.get(url=i) for i in mobile_links]
    mobile_soup = [bs(i.text, 'html.parser').find('div', class_='_1YokD2 _2GoDe3') for i in mobile_req]
    mobile_specs_soup = [i.find_all('div', class_='_3k-BhJ') for i in mobile_soup]

    storage_ram = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Memory' in str(specs_.text) and 'Storage' in str(specs_.text)]
    storage_ram_cross_checked = [i for i in storage_ram if 'Internal' in i.split()]

    os_processor = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Os' in str(specs_.text) and 'Processor' in str(specs_.text)]
    os_processor_cross_checked = [i for i in os_processor if 'Operating' in i.split()]

    camera = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Camera' in str(specs_.text) and 'FeaturesPrimary' in str(specs_.text)]
    camera_cross_checked = [i for i in camera if 'Primary' and 'Camera' in i.split()]

    display = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Display' in str(specs_.text) and 'FeaturesDisplay' in str(specs_.text)]
    display_cross_checked = [i for i in display if 'Display' and 'cm' in i.split()]

    network = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Connectivity' in str(specs_.text) and 'FeaturesNetwork' in str(specs_.text)]
    network_cross_checked = [i for i in network if 'Network' in i.split()]

    battery = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Battery' in str(specs_.text) and 'FeaturesBattery' in str(specs_.text)]
    battery_cross_checked = [i for i in battery if 'Battery' in i.split()]

    return mobile_specs_soup, storage_ram_cross_checked, os_processor_cross_checked, camera_cross_checked, display_cross_checked, network_cross_checked, battery_cross_checked

# %%
def fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery):
    tuple_data = zip_longest(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery,fillvalue=np.nan)
    
    data = [i for i in tuple_data]
    return data

# %%
def print_len(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery):
    print(f"Length of mob_names: {len(mob_names)}")
    print(f"Length of mob_ratings: {len(mob_ratings)}")
    print(f"Length of mob_price: {len(mob_price)}")
    print(f"Length of mob_img_URL: {len(mob_img_URL)}")
    print(f"Length of storage_ram: {len(storage_ram)}")
    print(f"Length of os_processor: {len(os_processor)}")
    print(f"Length of camera: {len(camera)}")
    print(f"Length of display: {len(display)}")
    print(f"Length of network: {len(network)}")
    print(f"Length of battery: {len(battery)}")

# %%
df = pd.DataFrame()

page_start = 1
page_ends = 24

for pages in range(page_start, page_ends):

    soup, URL = bs4_soup(pages=pages)
    
    mob_names, mob_ratings, mob_price, mob_img_URL = mob_specs(soup)
    mobile_specs_soup, storage_ram, os_processor, camera, display, network, battery = features_from_mob_links(soup=soup)
    
    data = fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)

    if mobile_specs_soup is not None and soup is not None:
        
        print_len(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)

        page_df = pd.DataFrame(data=data,columns=['name', 'ratings', 'price', 'imgURL', 'storage_ram','os_processor',
                                                   'camera', 'display', 'network', 'battery'])

        if not page_df.empty:
            df = pd.concat(objs=[df, page_df], ignore_index=True)
            print(f'scraping data from page:{pages}')
            print(f'working in {URL} Page')
            print(f'page df : page_shape : {page_df.shape} \n {page_df.sample(2)}')
            print(f'df : df shape : {df.shape} \n {df.sample(2)}')
            print()

    else:
        print(f"Skipping page {pages} due to empty mobile_specs_soup or soup.")
# Out:
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:1
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1 Page
# page df : page_shape : (24, 10)
#                                      name ratings    price
# 13          Mi 11X (Lunar White, 128 GB)     4.2  ₹22,490  \
# 12  REDMI 10 Power (Power Black, 128 GB)     4.2  ₹12,840
#
#                                                imgURL
# 13  https://rukminim2.flixcart.com/image/312/312/k...  \
# 12  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 13  Internal Storage128 GBRAM6 GBSupported Memory ...  \
# 12  Internal Storage128 GBRAM8 GBMemory Card Slot ...
#
#                                          os_processor
# 13  Operating SystemAndroid 11Processor TypeQualco...  \
# 12  Operating SystemAndroid 13Processor CoreOcta C...
#
#                                                camera
# 13  Primary Camera AvailableYesPrimary Camera48MP ...  \
# 12  Primary Camera50MP Rear CameraDual Camera Lens...
#
#                                               display
# 13  Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 12  Display Size17.02 cm (6.7 inch)Resolution2400 ...
#
#                                               network
# 13  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 12     Network Type4G VOLTESupported Networks4G VoLTE
#
#                      battery
# 13  Battery Capacity4520 mAh
# 12  Battery Capacity6000 mAh
# df : df shape : (24, 10)
#                                        name ratings    price
# 13            Mi 11X (Lunar White, 128 GB)     4.2  ₹22,490  \
# 1   Xiaomi 11Lite NE (Vinyl Black, 128 GB)     4.2  ₹21,430
#
#                                                imgURL
# 13  https://rukminim2.flixcart.com/image/312/312/k...  \
# 1   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 13  Internal Storage128 GBRAM6 GBSupported Memory ...  \
# 1   Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                          os_processor
# 13  Operating SystemAndroid 11Processor TypeQualco...  \
# 1   Operating SystemAndroid 11Processor TypeQualco...
#
#                                                camera
# 13  Primary Camera AvailableYesPrimary Camera48MP ...  \
# 1   Primary Camera AvailableYesPrimary Camera64MP ...
#
#                                               display
# 13  Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 1   Display Size16.64 cm (6.55 inch)Resolution1080...
#
#                                               network
# 13  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 1   Network Type5G, 4G VOLTESupported Networks5G, ...
#
#                                       battery
# 13                   Battery Capacity4520 mAh
# 1   Battery Capacity4250 mAhBattery TypeLi-Po
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:2
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2 Page
# page df : page_shape : (24, 10)
#                                               name ratings    price
# 16       Redmi Note 9 Pro (Glacier White, 128 GB)     4.3  ₹17,999  \
# 14  Redmi Note 9 Pro (Interstellar Black, 128 GB)     4.3  ₹14,999
#
#                                                imgURL
# 16  https://rukminim2.flixcart.com/image/312/312/k...  \
# 14  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 16  Internal Storage128 GBRAM4 GBExpandable Storag...  \
# 14  Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                          os_processor
# 16  Operating SystemAndroid Q 10Processor TypeQual...  \
# 14  Operating SystemAndroid Pie 10Processor TypeQu...
#
#                                                camera
# 16  Primary Camera AvailableYesPrimary Camera48MP ...  \
# 14  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                               display
# 16  Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 14  Display Size16.94 cm (6.67 inch)Resolution2400...
#
#                                               network
# 16  Network Type4G VOLTE, 3GSupported Networks4G L...  \
# 14  Network Type4G VOLTE, 3GSupported Networks4G L...
#
#                                               battery
# 16  Battery Capacity5020 mAhBattery Typelithium-io...
# 14  Battery Capacity5020 mAhBattery Typelithium-io...
# df : df shape : (48, 10)
#                                           name ratings    price
# 20             Redmi 9A (Nature Green, 32 GB)     4.3   ₹9,499  \
# 2   Xiaomi 11Lite NE (Diamond Dazzle, 128 GB)     4.2  ₹20,999
#
#                                                imgURL
# 20  https://rukminim2.flixcart.com/image/312/312/k...  \
# 2   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 20  Internal Storage32 GBRAM3 GBExpandable Storage...  \
# 2   Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                          os_processor
# 20  Operating SystemAndroid Q 10Processor TypeMedi...  \
# 2   Operating SystemAndroid 11Processor TypeQualco...
#
#                                                camera
# 20  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 2   Primary Camera AvailableYesPrimary Camera64MP ...
#
#                                               display
# 20  Display Size16.59 cm (6.53 inch)Resolution1600...  \
# 2   Display Size16.64 cm (6.55 inch)Resolution1080...
#
#                                               network
# 20  Network Type4G VOLTESupported Networks4G VoLTE...  \
# 2   Network Type5G, 4G VOLTESupported Networks5G, ...
#
#                                               battery
# 20  Battery Capacity5000 mAhBattery Typelithium-po...
# 2           Battery Capacity4250 mAhBattery TypeLi-Po
#
# Length of mob_names: 24
# Length of mob_ratings: 23
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:3
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3 Page
# page df : page_shape : (24, 10)
#                              name ratings    price
# 11  Redmi 8A (Sunset Red, 32 GB)     4.4   ₹7,999  \
# 19     Redmi 8 (Ruby Red, 64 GB)     4.4  ₹10,999
#
#                                                imgURL
# 11  https://rukminim2.flixcart.com/image/312/312/k...  \
# 19  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 11  Internal Storage32 GBRAM2 GBExpandable Storage...  \
# 19  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                          os_processor
# 11  Operating SystemAndroid Pie 9.0Processor TypeQ...  \
# 19  Operating SystemAndroid Pie 9Processor TypeQua...
#
#                                                camera
# 11  Primary Camera AvailableYesPrimary Camera12MP ...  \
# 19  Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                               display
# 11  Display Size15.8 cm (6.22 inch)Resolution1520 ...  \
# 19  Display Size15.8 cm (6.22 inch)Resolution1520 ...
#
#                                               network
# 11  Network Type4G VOLTE, 3G, 2GSupported Networks...  \
# 19  Network Type4G VOLTE, 3G, 2GSupported Networks...
#
#                                            battery
# 11  Battery Capacity5000 mAhBattery TypeLi-polymer
# 19  Battery Capacity5000 mAhBattery TypeLi-polymer
# df : df shape : (72, 10)
#                                        name ratings    price
# 49  Xiaomi 12 Pro 5G (Opera Mauve, 256 GB)     4.1  ₹41,999  \
# 22    Xiaomi 11Lite NE (Jazz Blue, 128 GB)     4.2  ₹22,970
#
#                                                imgURL
# 49  https://rukminim2.flixcart.com/image/312/312/x...  \
# 22  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 49    Internal Storage256 GBRAM8 GBCall Log MemoryYes  \
# 22  Internal Storage128 GBRAM8 GBExpandable Storag...
#
#                                          os_processor
# 49  Operating SystemAndroid 12Processor TypeSnapdr...  \
# 22  Operating SystemAndroid 11Processor TypeQualco...
#
#                                                camera
# 49  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 22  Primary Camera AvailableYesPrimary Camera64MP ...
#
#                                               display
# 49  Display Size17.09 cm (6.73 inch)Resolution2400...  \
# 22  Display Size16.64 cm (6.55 inch)Resolution1080...
#
#                                               network
# 49  Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...  \
# 22  Network Type5G, 4G VOLTESupported Networks5G, ...
#
#                                               battery
# 49  Battery Capacity4600 mAhBattery TypeLithium Po...
# 22          Battery Capacity4250 mAhBattery TypeLi-Po
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:4
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4 Page
# page df : page_shape : (24, 10)
#                                                   name ratings    price
# 19  Redmi Note 11 PRO Plus 5G (Stealth Black, 128 GB)     4.2  ₹23,990  \
# 12                        Redmi 4A (Dark Grey, 32 GB)     4.4   ₹6,999
#
#                                                imgURL
# 19  https://rukminim2.flixcart.com/image/312/312/x...  \
# 12  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                           storage_ram
# 19  Internal Storage128 GBRAM6 GBMemory Card Slot ...  \
# 12  Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                          os_processor
# 19  Operating SystemAndroid Q 11Processor CoreDual...  \
# 12  Operating SystemAndroid Marshmallow 6.0.1Proce...
#
#                                                camera
# 19  Primary Camera108MP Rear CameraDual Camera Len...  \
# 12  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 19  Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 12  Display Size12.7 cm (5 inch)Resolution1280 x 7...
#
#                                               network
# 19    Network Type5GSupported Networks5G, 4G LTE, GSM  \
# 12  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
#
#                      battery
# 19  Battery Capacity5000 mAh
# 12  Battery Capacity3120 mAh
# df : df shape : (96, 10)
#                                name ratings   price
# 7          Redmi 6A (Black, 16 GB)     4.3  ₹6,500  \
# 56  Redmi 9A (Nature Green, 32 GB)     4.3  ₹7,490
#
#                                                imgURL
# 7   https://rukminim2.flixcart.com/image/312/312/j...  \
# 56  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 7   Internal Storage16 GBRAM2 GBExpandable Storage...  \
# 56  Internal Storage32 GBRAM2 GBMemory Card Slot T...
#
#                                          os_processor
# 7   Operating SystemAndroid Oreo 8.1Processor Core...  \
# 56  Operating SystemAndroid Q 10Processor CoreOcta...
#
#                                                camera
# 7   Primary Camera AvailableYesPrimary Camera13MP ...  \
# 56  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 7   Display Size13.84 cm (5.45 inch)Resolution720 ...  \
# 56  Display Size16.59 cm (6.53 inch)Resolution720 ...
#
#                                               network
# 7   Network Type3G, 4G VOLTE, 2GSupported Networks...  \
# 56  Network Type4G VOLTE, 3GSupported Networks4G V...
#
#                                     battery
# 7                  Battery Capacity3000 mAh
# 56  Battery Capacity5000 mAhDual BatteryYes
#
# Length of mob_names: 24
# Length of mob_ratings: 0
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:5
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5 Page
# page df : page_shape : (24, 10)
#                                                   name  ratings    price
# 21                        Redmi 7 (Comet Blue, 32 GB)      NaN   ₹7,849  \
# 6   Xiaomi 11T Pro 5G Hyperphone (Celestial Magic,...      NaN  ₹35,999
#
#                                                imgURL
# 21  https://rukminim2.flixcart.com/image/312/312/k...  \
# 6   https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 21  Internal Storage32 GBRAM2 GBMemory Card Slot T...  \
# 6   Internal Storage256 GBRAM12 GBMemory Card Slot...
#
#                                          os_processor
# 21  Operating SystemAndroid Pie 9.0Processor CoreO...  \
# 6   Operating SystemAndroid Android 11Processor Co...
#
#                                                camera
# 21  Primary Camera12MP Rear CameraDual Camera Lens...  \
# 6   Primary Camera108MP Rear CameraDual Camera Len...
#
#                                               display
# 21  Display Size15.9 cm (6.26 inch)Resolution720 x...  \
# 6   Display Size16.94 cm (6.67 inch)Resolution1080...
#
#                                               network
# 21  Network Type3G, 4G VOLTE, 2GSupported Networks...  \
# 6                  Network Type5GSupported Networks5G
#
#                      battery
# 21  Battery Capacity4000 mAh
# 6   Battery Capacity5000 mAh
# df : df shape : (120, 10)
#                                       name ratings    price
# 17  Xiaomi 12 Pro 5G (Noir Black, 256 GB)     4.2  ₹44,999  \
# 16  Xiaomi 12 Pro 5G (Noir Black, 256 GB)     4.1  ₹41,999
#
#                                                imgURL
# 17  https://rukminim2.flixcart.com/image/312/312/x...  \
# 16  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                          storage_ram
# 17  Internal Storage256 GBRAM12 GBCall Log MemoryYes  \
# 16   Internal Storage256 GBRAM8 GBCall Log MemoryYes
#
#                                          os_processor
# 17  Operating SystemAndroid 12Processor TypeSnapdr...  \
# 16  Operating SystemAndroid 12Processor TypeSnapdr...
#
#                                                camera
# 17  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 16  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 17  Display Size17.09 cm (6.73 inch)Resolution2400...  \
# 16  Display Size17.09 cm (6.73 inch)Resolution2400...
#
#                                               network
# 17  Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...  \
# 16  Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...
#
#                                               battery
# 17  Battery Capacity4600 mAhBattery TypeLithium Po...
# 16  Battery Capacity4600 mAhBattery TypeLithium Po...
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:6
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=6 Page
# page df : page_shape : (24, 10)
#                                   name ratings    price
# 11  Redmi K20 Pro (Flame Red, 256 GB)     4.5  ₹31,999  \
# 19   Redmi K20 (Glacier Blue, 128 GB)     4.5  ₹24,999
#
#                                                imgURL
# 11  https://rukminim2.flixcart.com/image/312/312/j...  \
# 19  https://rukminim2.flixcart.com/image/312/312/j...
#
#                       storage_ram
# 11  Internal Storage256 GBRAM8 GB  \
# 19  Internal Storage128 GBRAM6 GB
#
#                                          os_processor
# 11  Operating SystemAndroid Pie 9.0Processor TypeQ...  \
# 19  Operating SystemAndroid Pie 9.0Processor TypeQ...
#
#                                                camera
# 11  Primary Camera AvailableYesPrimary Camera48MP ...  \
# 19  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                               display
# 11  Display Size16.23 cm (6.39 inch)Resolution2340...  \
# 19  Display Size16.23 cm (6.39 inch)Resolution2340...
#
#                                               network
# 11  Network Type3G, 4G VOLTE, 2GSupported Networks...  \
# 19  Network Type3G, 4G VOLTE, 2GSupported Networks...
#
#                      battery
# 11  Battery Capacity4000 mAh
# 19  Battery Capacity4000 mAh
# df : df shape : (144, 10)
#                                           name ratings    price
# 121           Redmi K20 (Carbon Black, 64 GB)     4.5  ₹22,999  \
# 3    Xiaomi 11Lite NE (Tuscany Coral, 128 GB)     4.2  ₹20,999
#
#                                                 imgURL
# 121  https://rukminim2.flixcart.com/image/312/312/j...  \
# 3    https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 121                       Internal Storage64 GBRAM6 GB  \
# 3    Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                           os_processor
# 121  Operating SystemAndroid Pie 9.0Processor TypeQ...  \
# 3    Operating SystemAndroid 11Processor TypeQualco...
#
#                                                 camera
# 121  Primary Camera AvailableYesPrimary Camera48MP ...  \
# 3    Primary Camera AvailableYesPrimary Camera64MP ...
#
#                                                display
# 121  Display Size16.23 cm (6.39 inch)Resolution2340...  \
# 3    Display Size16.64 cm (6.55 inch)Resolution1080...
#
#                                                network
# 121  Network Type3G, 4G VOLTE, 2GSupported Networks...  \
# 3    Network Type5G, 4G VOLTESupported Networks5G, ...
#
#                                        battery
# 121                   Battery Capacity4000 mAh
# 3    Battery Capacity4250 mAhBattery TypeLi-Po
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:7
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=7 Page
# page df : page_shape : (24, 10)
#                                      name ratings    price
# 20           Redmi 5A (Rose Gold, 32 GB)     4.4   ₹6,999  \
# 3   MI 11X 5G (CELESTIAL SILVER, 128 GB)     4.2  ₹25,999
#
#                                                imgURL
# 20  https://rukminim2.flixcart.com/image/312/312/j...  \
# 3   https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 20  Internal Storage32 GBRAM3 GBExpandable Storage...  \
# 3                       Internal Storage128 GBRAM6 GB
#
#                                          os_processor
# 20  Operating SystemAndroid Nougat 7.1.2Processor ...  \
# 3   Operating SystemAndroid Nougat 11Processor Cor...
#
#                                                camera
# 20  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 3                      Primary Camera48MP Rear Camera
#
#                                               display
# 20  Display Size12.7 cm (5 inch)Resolution1280 x 7...  \
# 3   Display Size16.94 cm (6.67 inch)Resolution1080...
#
#                                               network
# 20  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...  \
# 3   Network Type4G VOLTE, 5GSupported Networks4G V...
#
#                      battery
# 20  Battery Capacity3000 mAh
# 3   Battery Capacity4520 mAh
# df : df shape : (168, 10)
#                                          name ratings    price
# 65                    Redmi Go (Black, 8 GB)     4.3   ₹5,999  \
# 57  Redmi Note 9 Pro (Champagne Gold, 64 GB)     4.3  ₹15,990
#
#                                                imgURL
# 65  https://rukminim2.flixcart.com/image/312/312/j...  \
# 57  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 65  Internal Storage8 GBRAM1 GBExpandable Storage1...  \
# 57  Internal Storage64 GBRAM4 GBMemory Card Slot T...
#
#                                          os_processor
# 65  Operating SystemAndroid Oreo 8.1Processor Type...  \
# 57  Operating SystemAndroid Pie 10Processor TypeQu...
#
#                                                camera
# 65  Primary Camera AvailableYesPrimary Camera8MP R...  \
# 57  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                               display
# 65  Display Size12.7 cm (5 inch)Resolution1280 x 7...  \
# 57  Display Size16.94 cm (6.67 inch)Resolution2400...
#
#                                               network
# 65  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...  \
# 57  Network Type4G VOLTE, 4G, 3GSupported Networks...
#
#                                               battery
# 65                           Battery Capacity3000 mAh
# 57  Battery Capacity5020 mAhBattery Typelithium-io...
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:8
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=8 Page
# page df : page_shape : (24, 10)
#                             name ratings    price
# 17  Redmi Note 4 (Black, 32 GB)     4.4  ₹10,649  \
# 10   Redmi Note 5 (Blue, 32 GB)     4.4  ₹10,999
#
#                                                imgURL
# 17  https://rukminim2.flixcart.com/image/312/312/m...  \
# 10  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                           storage_ram
# 17  Internal Storage32 GBRAM3 GBExpandable Storage...  \
# 10  Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                          os_processor
# 17  Operating SystemAndroid Marshmallow 6.0.1Proce...  \
# 10  Operating SystemAndroid Nougat 7.1.2Processor ...
#
#                                                camera
# 17  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 10  Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                               display
# 17  Display Size13.97 cm (5.5 inch)Resolution1920 ...  \
# 10  Display Size15.21 cm (5.99 inch)Resolution2160...
#
#                                               network
# 17  Network Type3G, 4G VOLTESupported Networks4G L...  \
# 10  Network Type3G, 4G VOLTE, 4GSupported Networks...
#
#                      battery
# 17  Battery Capacity4100 mAh
# 10  Battery Capacity4000 mAh
# df : df shape : (192, 10)
#                                    name ratings    price
# 82  REDMI 10A (CHARCOAL BLACK, 128 GB)     4.1  ₹11,999  \
# 41          Redmi 6 (Rose Gold, 32 GB)     4.4   ₹8,999
#
#                                                imgURL
# 82  https://rukminim2.flixcart.com/image/312/312/x...  \
# 41  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                           storage_ram
# 82  Internal Storage128 GBRAM6 GBMemory Card Slot ...  \
# 41  Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                          os_processor
# 82  Operating SystemAndroid 12Processor CoreOcta C...  \
# 41  Operating SystemAndroid Oreo 8.1Processor Type...
#
#                                                camera
# 82  Primary Camera13MP Rear CameraDual Camera Lens...  \
# 41  Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                               display
# 82  Display Size16.59 cm (6.53 inch)Resolution1600...  \
# 41  Display Size13.84 cm (5.45 inch)Resolution1440...
#
#                                               network
# 82           Network Type4GSupported Networks4G VoLTE  \
# 41  Network Type3G, 4G VOLTE, 2GSupported Networks...
#
#                                               battery
# 82                           Battery Capacity5000 mAh
# 41  Battery Capacity3000 mAhBattery TypeLithium-po...
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:9
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=9 Page
# page df : page_shape : (24, 10)
#                                      name ratings    price
# 7  REDMI 11 Prime (Peppy Purple, 128 GB)     4.4  ₹10,999  \
# 2         Redmi Note 5 Pro (Blue, 64 GB)     4.5  ₹16,999
#
#                                               imgURL
# 7  https://rukminim2.flixcart.com/image/312/312/x...  \
# 2  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                          storage_ram
# 7  Internal Storage128 GBRAM6 GBExpandable Storag...  \
# 2  Internal Storage64 GBRAM6 GBExpandable Storage...
#
#                                         os_processor
# 7  Operating SystemAndroid 12Processor TypeHelio ...  \
# 2  Operating SystemAndroid Nougat 7.1.2Processor ...
#
#                                               camera
# 7  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 2  Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                              display
# 7  Display Size16.71 cm (6.58 inch)Resolution2408...  \
# 2  Display Size15.21 cm (5.99 inch)Resolution2160...
#
#                                              network
# 7  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 2  Network Type3G, 4G VOLTE, 4GSupported Networks...
#
#                                              battery
# 7  Battery Capacity5000 mAhBattery TypeLithium Po...
# 2                           Battery Capacity4000 mAh
# df : df shape : (216, 10)
#                                            name ratings    price
# 137  REDMI Note 11 Pro (Stealth Black, 128 GB)     4.1  ₹23,990  \
# 149       Redmi 8A Dual (Midnight Grey, 32 GB)     4.2   ₹8,999
#
#                                                 imgURL
# 137  https://rukminim2.flixcart.com/image/312/312/x...  \
# 149  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 137  Internal Storage128 GBRAM8 GBMemory Card Slot ...  \
# 149  Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                           os_processor
# 137  Operating SystemAndroid Q 11Processor CoreDual...  \
# 149  Operating SystemAndroid Pie 9Processor TypeQua...
#
#                                                 camera
# 137  Primary Camera108MP Rear CameraDual Camera Len...  \
# 149  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                                display
# 137  Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 149  Display Size15.8 cm (6.22 inch)Resolution1520 ...
#
#                                                network
# 137    Network Type5GSupported Networks5G, 4G LTE, GSM  \
# 149  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                                              battery
# 137                         Battery Capacity5000 mAh
# 149  Battery Capacity5000 mAhBattery Typelithium-ion
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:10
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=10 Page
# page df : page_shape : (24, 10)
#                                                name ratings    price
# 9        REDMI Note 12 Pro 5G (Onyx Black, 128 GB)     4.2  ₹23,999  \
# 11  REDMI Note 12 Pro 5G (Stardust Purple, 256 GB)     4.2  ₹26,999
#
#                                                imgURL
# 9   https://rukminim2.flixcart.com/image/312/312/x...  \
# 11  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 9   Internal Storage128 GBRAM6 GBTotal Memory128 G...  \
# 11  Internal Storage256 GBRAM8 GBTotal Memory256 G...
#
#                                          os_processor
# 9   Operating SystemAndroid 12Processor TypeMediat...  \
# 11  Operating SystemAndroid 12Processor TypeMediat...
#
#                                                camera
# 9   Primary Camera AvailableYesPrimary Camera50MP ...  \
# 11  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 9   Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 11  Display Size16.94 cm (6.67 inch)Resolution2400...
#
#                                               network
# 9   Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...  \
# 11  Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...
#
#                                               battery
# 9   Battery Capacity5000 mAhBattery TypeLithium Po...
# 11  Battery Capacity5000 mAhBattery TypeLithium Po...
# df : df shape : (240, 10)
#                                           name ratings    price
# 198                  REDMI A1+ (Black, 32 GB)     4.2   ₹6,299  \
# 63   Xiaomi 11Lite NE (Tuscany Coral, 128 GB)     4.2  ₹22,890
#
#                                                 imgURL
# 198  https://rukminim2.flixcart.com/image/312/312/x...  \
# 63   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 198  Internal Storage32 GBRAM2 GBExpandable Storage...  \
# 63   Internal Storage128 GBRAM8 GBMemory Card Slot ...
#
#                                           os_processor
# 198  Operating SystemAndroid 12 GoProcessor TypeMed...  \
# 63   Operating SystemAndroid 11Processor CoreOcta C...
#
#                                                 camera
# 198  Primary Camera AvailableYesPrimary Camera8MP R...  \
# 63   Primary Camera64MP Rear CameraDual Camera Lens...
#
#                                                display
# 198  Display Size16.56 cm (6.52 inch)Resolution1600...  \
# 63   Display Size16.64 cm (6.55 inch)Resolution1080...
#
#                                                network
# 198  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 63   Network Type5G, 4G VOLTESupported Networks5G, ...
#
#                       battery
# 198  Battery Capacity5000 mAh
# 63   Battery Capacity4250 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:11
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=11 Page
# page df : page_shape : (24, 10)
#                                      name ratings    price
# 19           REDMI 10A (Sea Blue, 64 GB)     4.2   ₹8,650  \
# 8   REDMI Note 12 (Sunrise Gold, 128 GB)     4.1  ₹15,999
#
#                                                imgURL
# 19  https://rukminim2.flixcart.com/image/312/312/x...  \
# 8   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 19  Internal Storage64 GBRAM4 GBMemory Card Slot T...  \
# 8   Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                          os_processor
# 19  Operating SystemAndroidProcessor CoreOcta Core...  \
# 8   Operating SystemAndroid 13Processor TypeSnapdr...
#
#                                                camera
# 19  Primary Camera13MP Rear CameraDual Camera Lens...  \
# 8   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 19  Display Size16.59 cm (6.53 inch)Resolution1600...  \
# 8   Display Size16.94 cm (6.67 inch)Resolution2400...
#
#                                               network
# 19     Network Type4G VOLTESupported Networks4G VoLTE  \
# 8   Network Type2G, 3G, 4G, 4G VOLTESupported Netw...
#
#                                               battery
# 19                           Battery Capacity5000 mAh
# 8   Battery Capacity5000 mAhBattery TypeLithium Po...
# df : df shape : (264, 10)
#                                 name ratings    price
# 159  Redmi 8 (Emerald Green, 64 GB)     4.4  ₹10,999  \
# 185     Redmi Note 4 (Black, 32 GB)     4.4  ₹10,649
#
#                                                 imgURL
# 159  https://rukminim2.flixcart.com/image/312/312/k...  \
# 185  https://rukminim2.flixcart.com/image/312/312/m...
#
#                                            storage_ram
# 159  Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 185  Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                           os_processor
# 159  Operating SystemAndroid Pie 9Processor TypeQua...  \
# 185  Operating SystemAndroid Marshmallow 6.0.1Proce...
#
#                                                 camera
# 159  Primary Camera AvailableYesPrimary Camera12MP ...  \
# 185  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                                display
# 159  Display Size15.8 cm (6.22 inch)Resolution1520 ...  \
# 185  Display Size13.97 cm (5.5 inch)Resolution1920 ...
#
#                                                network
# 159  Network Type4G VOLTE, 3G, 2GSupported Networks...  \
# 185  Network Type3G, 4G VOLTESupported Networks4G L...
#
#                                             battery
# 159  Battery Capacity5000 mAhBattery TypeLi-polymer
# 185                        Battery Capacity4100 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:12
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=12 Page
# page df : page_shape : (24, 10)
#                                          name ratings    price
# 14  REDMI Note 11 SE (Thunder Purple, 64 GB)     4.3  ₹13,980  \
# 9        REDMI 9 Prime (Matte Black, 128 GB)     4.4  ₹11,490
#
#                                                imgURL
# 14  https://rukminim2.flixcart.com/image/312/312/x...  \
# 9   https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 14  Internal Storage64 GBRAM6 GBExpandable Storage...  \
# 9   Internal Storage128 GBRAM4 GBExpandable Storag...
#
#                                          os_processor
# 14  Operating SystemAndroid 11Processor TypeMediat...  \
# 9   Operating SystemAndroid 10Processor TypeMediaT...
#
#                                                camera
# 14  Primary Camera AvailableYesPrimary Camera64MP ...  \
# 9   Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 14  Display Size16.33 cm (6.43 inch)Resolution2400...  \
# 9   Display Size16.59 cm (6.53 inch)Resolution2340...
#
#                                               network
# 14  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 9   Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                                     battery
# 14  Battery Capacity5000 mAhTalk Time33 Hrs
# 9   Battery Capacity5000 mAhTalk Time31 hrs
# df : df shape : (288, 10)
#                                           name ratings    price
# 23   Redmi Note 9 Pro (Glacier White, 128 GB)     4.3  ₹17,999  \
# 199     REDMI 11 Prime (Peppy Purple, 128 GB)     4.4  ₹10,999
#
#                                                 imgURL
# 23   https://rukminim2.flixcart.com/image/312/312/k...  \
# 199  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 23   Internal Storage128 GBRAM4 GBExpandable Storag...  \
# 199  Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                           os_processor
# 23   Operating SystemAndroid Q 10Processor TypeQual...  \
# 199  Operating SystemAndroid 12Processor TypeHelio ...
#
#                                                 camera
# 23   Primary Camera AvailableYesPrimary Camera48MP ...  \
# 199  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                                display
# 23   Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 199  Display Size16.71 cm (6.58 inch)Resolution2408...
#
#                                                network
# 23   Network Type4G VOLTE, 3GSupported Networks4G L...  \
# 199  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                                                battery
# 23   Battery Capacity5020 mAhBattery Typelithium-io...
# 199  Battery Capacity5000 mAhBattery TypeLithium Po...
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 23
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:13
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=13 Page
# page df : page_shape : (24, 10)
#                                         name ratings    price
# 7   REDMI Note 11T 5G (Matte black, 128 GB)     4.2  ₹19,488  \
# 21     REDMI Note 11S (Polar White, 128 GB)     4.1  ₹15,995
#
#                                                imgURL
# 7   https://rukminim2.flixcart.com/image/312/312/x...  \
# 21  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 7   Internal Storage128 GBRAM8 GBMemory Card Slot ...  \
# 21  Internal Storage128 GBRAM6 GBMemory Card Slot ...
#
#                                          os_processor
# 7   Operating SystemAndroid Q 11Processor CoreOcta...  \
# 21  Operating SystemAndroid Q 11Processor CoreOcta...
#
#                                                camera
# 7   Primary Camera50MP Rear CameraDual Camera Lens...  \
# 21  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 7   Display Size16.76 cm (6.6 inch)Resolution2400 ...  \
# 21  Display Size16.33 cm (6.43 inch)Resolution2400...
#
#                                            network                   battery
# 7   Network Type5G, 4G, 3G, 2GSupported Networks5G  Battery Capacity5000 mAh
# 21              Network Type5GSupported Networks5G  Battery Capacity5000 mAh
# df : df shape : (312, 10)
#                                       name ratings    price
# 209    REDMI Note 12 (Lunar Black, 64 GB)     4.1  ₹13,999  \
# 147  MI 11X 5G (CELESTIAL SILVER, 128 GB)     4.2  ₹25,999
#
#                                                 imgURL
# 209  https://rukminim2.flixcart.com/image/312/312/x...  \
# 147  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 209  Internal Storage64 GBRAM6 GBExpandable Storage...  \
# 147                      Internal Storage128 GBRAM6 GB
#
#                                           os_processor
# 209  Operating SystemAndroid 13Processor TypeSnapdr...  \
# 147  Operating SystemAndroid Nougat 11Processor Cor...
#
#                                                 camera
# 209  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 147                     Primary Camera48MP Rear Camera
#
#                                                display
# 209  Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 147  Display Size16.94 cm (6.67 inch)Resolution1080...
#
#                                                network
# 209  Network Type2G, 3G, 4G, 4G VOLTESupported Netw...  \
# 147  Network Type4G VOLTE, 5GSupported Networks4G V...
#
#                                                battery
# 209  Battery Capacity5000 mAhBattery TypeLithium Po...
# 147                           Battery Capacity4520 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:14
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=14 Page
# page df : page_shape : (24, 10)
#                                     name ratings    price
# 4     REDMI 10 (Caribbean Green, 64 GB)     4.3  ₹13,999  \
# 20  REDMI 9 Activ (Carbon Black, 64 GB)     4.2   ₹9,920
#
#                                                imgURL
# 4   https://rukminim2.flixcart.com/image/312/312/x...  \
# 20  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 4   Internal Storage64 GBRAM4 GBMemory Card Slot T...  \
# 20  Internal Storage64 GBRAM4 GBMemory Card Slot T...
#
#                                          os_processor
# 4   Operating SystemAndroid Q Android 11Processor ...  \
# 20  Operating SystemAndroid 11Processor CoreOcta C...
#
#                                                camera
# 4   Primary Camera50MP Rear CameraDual Camera Lens...  \
# 20  Primary Camera13MP Rear CameraDual Camera Lens...
#
#                                               display
# 4   Display Size17.04 cm (6.71 inch)Resolution1650...  \
# 20  Display Size16.59 cm (6.53 inch)Resolution1600...
#
#                                               network
# 4   Network Type4G VOLTE, 3G, 4GSupported Networks...  \
# 20  Network Type4G VOLTE, 4GSupported Networks4G V...
#
#                      battery
# 4   Battery Capacity6000 mAh
# 20  Battery Capacity5000 mAh
# df : df shape : (336, 10)
#                                         name ratings    price
# 192  Redmi Note 7 Pro (Neptune Blue, 64 GB)     4.5  ₹16,999  \
# 0       Redmi 9A Sport (Coral Green, 32 GB)     4.2   ₹8,990
#
#                                                 imgURL
# 192  https://rukminim2.flixcart.com/image/312/312/k...  \
# 0    https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 192  Internal Storage64 GBRAM6 GBExpandable Storage...  \
# 0    Internal Storage32 GBRAM3 GBMemory Card Slot T...
#
#                                           os_processor
# 192  Operating SystemAndroid Pie 9Processor TypeQua...  \
# 0    Operating SystemAndroid Q 10Processor CoreOcta...
#
#                                                 camera
# 192  Primary Camera AvailableYesPrimary Camera48MP ...  \
# 0                       Primary Camera13MP Rear Camera
#
#                                                display
# 192  Display Size16.0 cm (6.3 inch)Resolution2340 x...  \
# 0    Display Size16.59 cm (6.53 inch)Resolution1600...
#
#                                                network
# 192  Network Type3G, 4G VOLTE, 2GSupported Networks...  \
# 0    Network Type4G VOLTE, 4GSupported Networks4G V...
#
#                       battery
# 192  Battery Capacity4000 mAh
# 0    Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:15
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=15 Page
# page df : page_shape : (24, 10)
#                                         name ratings    price
# 8               REDMI A2 (Sea Green, 64 GB)       4   ₹7,479  \
# 0  REDMI Note 10T 5G (Metallic Blue, 64 GB)     4.3  ₹14,990
#
#                                               imgURL
# 8  https://rukminim2.flixcart.com/image/312/312/x...  \
# 0  https://rukminim2.flixcart.com/image/312/312/l...
#
#                                          storage_ram
# 8  Internal Storage64 GBRAM2 GBMemory Card Slot T...  \
# 0  Internal Storage64 GBRAM4 GBMemory Card Slot T...
#
#                                         os_processor
# 8  Operating SystemAndroid Android 13Processor Co...  \
# 0  Operating SystemAndroid 11Processor TypeMediat...
#
#                                               camera
# 8  Primary Camera8MP Rear CameraDual Camera LensP...  \
# 0  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                              display
# 8  Display Size16.56 cm (6.52 inch)Resolution2160...  \
# 0  Display Size16.66 cm (6.56 inch)Resolution2400...
#
#                                              network                   battery
# 8     Network Type4G VOLTESupported Networks4G VoLTE  Battery Capacity5000 mAh
# 0  Network Type5G, 4G, 3G, 2GSupported Networks5G...  Battery Capacity5000 mAh
# df : df shape : (360, 10)
#                                       name ratings   price
# 203        REDMI A1+ (Light Green, 32 GB)     4.2  ₹6,299  \
# 221  REDMI 11 Prime (Flashy Black, 64 GB)     4.3  ₹9,299
#
#                                                 imgURL
# 203  https://rukminim2.flixcart.com/image/312/312/x...  \
# 221  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 203  Internal Storage32 GBRAM2 GBExpandable Storage...  \
# 221  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                           os_processor
# 203  Operating SystemAndroid 12 GoProcessor TypeMed...  \
# 221  Operating SystemAndroid 12Processor TypeHelio ...
#
#                                                 camera
# 203  Primary Camera AvailableYesPrimary Camera8MP R...  \
# 221  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                                display
# 203  Display Size16.56 cm (6.52 inch)Resolution1600...  \
# 221  Display Size16.71 cm (6.58 inch)Resolution2408...
#
#                                                network
# 203  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 221  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                                                battery
# 203                           Battery Capacity5000 mAh
# 221  Battery Capacity5000 mAhBattery TypeLithium Po...
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# ...
# 394  Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:19
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=19 Page
# page df : page_shape : (24, 10)
#                             name ratings   price
# 15  Redmi 3S (Dark Grey, 16 GB)     4.3  ₹6,999  \
# 18     Redmi 3S (Silver, 16 GB)     4.3  ₹6,999
#
#                                                imgURL
# 15  https://rukminim2.flixcart.com/image/312/312/m...  \
# 18  https://rukminim2.flixcart.com/image/312/312/m...
#
#                                           storage_ram
# 15  Internal Storage16 GBRAM2 GBExpandable Storage...  \
# 18  Internal Storage16 GBRAM2 GBExpandable Storage...
#
#                                          os_processor
# 15  Operating SystemAndroid Marshmallow 6.0.1Proce...  \
# 18  Operating SystemAndroid Marshmallow 6.0.1Proce...
#
#                                                camera
# 15  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 18  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 15  Display Size12.7 cm (5 inch)Resolution1280 x 7...  \
# 18  Display Size12.7 cm (5 inch)Resolution1280 x 7...
#
#                                               network
# 15  Network Type3G, 4GSupported NetworksWCDMA, 4G ...  \
# 18  Network Type3G, 4GSupported NetworksWCDMA, 4G ...
#
#                                               battery
# 15  Battery Capacity4100 mAhBattery TypeLi-Ion Pol...
# 18  Battery Capacity4100 mAhBattery TypeLi-Ion Pol...
# df : df shape : (456, 10)
#                                            name ratings    price
# 29               Mi 10T (Lunar Silver, 128 GB)     4.1  ₹23,999  \
# 435  Xiaomi 11Lite NE (Diamond Dazzle, 256 GB)     4.2  ₹42,990
#
#                                                 imgURL
# 29   https://rukminim2.flixcart.com/image/312/312/k...  \
# 435  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 29                       Internal Storage128 GBRAM8 GB  \
# 435  Internal Storage256 GBRAM8 GBMemory Card Slot ...
#
#                                           os_processor
# 29   Operating SystemAndroid 10Processor TypeQualco...  \
# 435  Operating SystemAndroid Q 11Processor CoreDual...
#
#                                                 camera
# 29   Primary Camera AvailableYesPrimary Camera64MP ...  \
# 435  Primary Camera20MP Rear CameraDual Camera Lens...
#
#                                                display
# 29   Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 435  Display Size16.51 cm (6.5 inch)Resolution1920x...
#
#                                                network
# 29   Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...  \
# 435                 Network Type5GSupported Networks5G
#
#                       battery
# 29   Battery Capacity5000 mAh
# 435  Battery Capacity4250 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:20
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=20 Page
# page df : page_shape : (24, 10)
#                                                 name ratings    price
# 18  Redmi Note 11 PRO Plus 5G (Mirage Blue, 128 GB)     4.2  ₹21,599  \
# 6             Redmi 10 Prime (Astral White, 128 GB)     4.1  ₹12,331
#
#                                                imgURL
# 18  https://rukminim2.flixcart.com/image/312/312/x...  \
# 6   https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 18  Internal Storage128 GBRAM8 GBMemory Card Slot ...  \
# 6   Internal Storage128 GBRAM6 GBMemory Card Slot ...
#
#                                          os_processor
# 18  Operating SystemAndroid Q 11Processor CoreDual...  \
# 6   Operating SystemAndroid 11Processor CoreOcta C...
#
#                                                camera
# 18  Primary Camera108MP Rear CameraDual Camera Len...  \
# 6   Primary Camera8MP Rear CameraDual Camera LensP...
#
#                                               display
# 18  Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 6   Display Size16.51 cm (6.5 inch)Resolution2400 ...
#
#                                               network
# 18    Network Type5GSupported Networks4G LTE, GSM, 5G  \
# 6   Network Type4G VOLTE, 4GSupported Networks4G V...
#
#                      battery
# 18  Battery Capacity5000 mAh
# 6   Battery Capacity6000 mAh
# df : df shape : (480, 10)
#                                      name ratings    price
# 37   Xiaomi 11i 5G (Purple Mist, 128 GB)     4.2  ₹26,999  \
# 62  Xiaomi 11Lite NE (Jazz Blue, 128 GB)     4.2  ₹20,999
#
#                                                imgURL
# 37  https://rukminim2.flixcart.com/image/312/312/k...  \
# 62  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 37  Internal Storage128 GBRAM8 GBExpandable Storag...  \
# 62  Internal Storage128 GBRAM6 GBMemory Card Slot ...
#
#                                          os_processor
# 37  Operating SystemAndroid 11Processor TypeMediat...  \
# 62  Operating SystemAndroid 11Processor CoreOcta C...
#
#                                                camera
# 37  Primary Camera AvailableYesPrimary Camera108MP...  \
# 62  Primary Camera64MP Rear CameraDual Camera Lens...
#
#                                               display
# 37  Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 62  Display Size16.64 cm (6.55 inch)Resolution1080...
#
#                                               network
# 37  Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...  \
# 62  Network Type5G, 4G VOLTESupported Networks5G, ...
#
#                                     battery
# 37  Battery Capacity5160 mAhTalk Time30 hrs
# 62                 Battery Capacity4250 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:21
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=21 Page
# page df : page_shape : (24, 10)
#                           name ratings    price
# 19      Mi 4i (Yellow, 16 GB)     4.2  ₹12,999  \
# 9   Mi Max (Dark Grey, 32 GB)     4.3  ₹14,999
#
#                                                imgURL
# 19  https://rukminim2.flixcart.com/image/312/312/m...  \
# 9   https://rukminim2.flixcart.com/image/312/312/m...
#
#                                           storage_ram
# 19  Internal Storage16 GBRAM2 GBMemory Card Slot T...  \
# 9   Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                          os_processor
# 19  Operating SystemAndroid Lollipop 5.0.2Processo...  \
# 9   Operating SystemAndroid Marshmallow 6.0.1Proce...
#
#                                                camera
# 19  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 9   Primary Camera AvailableYesPrimary Camera16MP ...
#
#                                               display
# 19  Display Size12.7 cm (5 inch)Resolution1920 x 1...  \
# 9   Display Size16.36 cm (6.44 inch)Resolution1920...
#
#                                               network
# 19  Network Type3G, 4G, 2GSupported Networks4G LTE...  \
# 9   Network Type3G, 4GSupported NetworksGSM, 4G LT...
#
#                                               battery
# 19  Battery Capacity3030 mAhBattery TypeLi-Ion Pol...
# 9      Battery Capacity4850 mAhBattery TypeLi-Polymer
# df : df shape : (504, 10)
#                                       name ratings    price
# 266  REDMI Note 11S (Space Black, 128 GB)     4.1  ₹15,980  \
# 501                   Mi 4i (Grey, 32 GB)     4.2  ₹14,999
#
#                                                 imgURL
# 266  https://rukminim2.flixcart.com/image/312/312/x...  \
# 501  https://rukminim2.flixcart.com/image/312/312/m...
#
#                                            storage_ram
# 266  Internal Storage128 GBRAM6 GBMemory Card Slot ...  \
# 501  Internal Storage32 GBRAM2 GBPhone Book MemoryY...
#
#                                           os_processor
# 266  Operating SystemAndroid Q 11Processor CoreOcta...  \
# 501  Operating SystemAndroid Lollipop 5.0.2Processo...
#
#                                                 camera
# 266  Primary Camera108MP Rear CameraDual Camera Len...  \
# 501  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                                display
# 266  Display Size16.33 cm (6.43 inch)Resolution720 ...  \
# 501  Display Size12.7 cm (5 inch)Resolution1920 x 1...
#
#                                                network
# 266  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 501  Network Type3G, 4G, 2GSupported Networks4G LTE...
#
#                                                battery
# 266                           Battery Capacity5000 mAh
# 501  Battery Capacity3120 mAhBattery TypeLi-Ion Pol...
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:22
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=22 Page
# page df : page_shape : (24, 10)
#                                       name ratings    price
# 13  Xiaomi 11i 5G (Pacific Pearl, 128 GB)     4.2  ₹26,999  \
# 23      Redmi 3S Prime (Dark Grey, 32 GB)     4.3   ₹8,999
#
#                                                imgURL
# 13  https://rukminim2.flixcart.com/image/312/312/k...  \
# 23  https://rukminim2.flixcart.com/image/312/312/m...
#
#                                           storage_ram
# 13  Internal Storage128 GBRAM8 GBExpandable Storag...  \
# 23  Internal Storage32 GBRAM3 GBExpandable Storage...
#
#                                          os_processor
# 13  Operating SystemAndroid 11Processor TypeMediat...  \
# 23  Operating SystemAndroid Marshmallow 6.0.1Proce...
#
#                                                camera
# 13  Primary Camera AvailableYesPrimary Camera108MP...  \
# 23  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 13  Display Size16.94 cm (6.67 inch)Resolution2400...  \
# 23  Display Size12.7 cm (5 inch)Resolution1280 x 7...
#
#                                               network
# 13  Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...  \
# 23  Network Type3G, 4G VOLTESupported NetworksWCDM...
#
#                                               battery
# 13            Battery Capacity5160 mAhTalk Time30 hrs
# 23  Battery Capacity4100 mAhBattery TypeLi-Ion Pol...
# df : df shape : (528, 10)
#                                       name ratings    price
# 152     Redmi Note 7S (Onyx Black, 64 GB)     4.4  ₹13,999  \
# 88   Xiaomi 11Lite NE (Jazz Blue, 128 GB)     4.2  ₹22,000
#
#                                                 imgURL
# 152  https://rukminim2.flixcart.com/image/312/312/k...  \
# 88   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 152  Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 88   Internal Storage128 GBRAM8 GBMemory Card Slot ...
#
#                                           os_processor
# 152  Operating SystemAndroid Pie 9.0Processor TypeQ...  \
# 88   Operating SystemAndroid 11Processor CoreOcta C...
#
#                                                 camera
# 152  Primary Camera AvailableYesPrimary Camera48MP ...  \
# 88   Primary Camera64MP Rear CameraDual Camera Lens...
#
#                                                display
# 152  Display Size16.0 cm (6.3 inch)Resolution2340 x...  \
# 88   Display Size16.64 cm (6.55 inch)Resolution1080...
#
#                                                network
# 152  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...  \
# 88   Network Type5G, 4G VOLTESupported Networks5G, ...
#
#                                             battery
# 152  Battery Capacity4000 mAhBattery TypeLi-polymer
# 88                         Battery Capacity4250 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 23
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:23
# working in https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=23 Page
# page df : page_shape : (24, 10)
#                              name ratings    price
# 1         Redmi Y2 (Blue, 64 GB)     4.4   ₹9,990  \
# 3  Mi 10 (Twilight Grey, 128 GB)     4.1  ₹54,999
#
#                                               imgURL
# 1  https://rukminim2.flixcart.com/image/312/312/j...  \
# 3  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                          storage_ram
# 1  Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 3                      Internal Storage128 GBRAM8 GB
#
#                                         os_processor
# 1  Operating SystemAndroid Oreo 8.0Processor Type...  \
# 3  Operating SystemAndroid 10Processor TypeQualco...
#
#                                               camera
# 1  Primary Camera AvailableYesPrimary Camera12MP ...  \
# 3  Primary Camera AvailableYesPrimary Camera108MP...
#
#                                              display
# 1  Display Size15.21 cm (5.99 inch)Resolution1440...  \
# 3  Display Size16.94 cm (6.67 inch)Resolution2340...
#
#                                              network
# 1  Network Type3G, 4G, 2GSupported NetworksGSM, W...  \
# 3  Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...
#
#                                            battery
# 1                         Battery Capacity3080 mAh
# 3  Battery Capacity4780 mAhBattery TypeLithium-ion
# df : df shape : (552, 10)
#                                   name ratings    price
# 354  REDMI A2+ (Classic Black, 64 GB)     4.1   ₹8,149  \
# 109   Redmi Note 5 Pro (Black, 64 GB)     NaN  ₹16,999
#
#                                                 imgURL
# 354  https://rukminim2.flixcart.com/image/312/312/x...  \
# 109  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                            storage_ram
# 354  Internal Storage64 GBRAM4 GBMemory Card Slot T...  \
# 109  Internal Storage64 GBRAM6 GBExpandable Storage...
#
#                                           os_processor
# 354  Operating SystemAndroid Android 13Processor Co...  \
# 109  Operating SystemAndroid Nougat 7.1.2Processor ...
#
#                                                 camera
# 354  Primary Camera8MP Rear CameraDual Camera LensP...  \
# 109  Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                                display
# 354  Display Size16.56 cm (6.52 inch)Resolution1600...  \
# 109  Display Size15.21 cm (5.99 inch)Resolution2160...
#
#                                                network
# 354     Network Type4G VOLTESupported Networks4G VoLTE  \
# 109  Network Type3G, 4G VOLTE, 4GSupported Networks...
#
#                       battery
# 354  Battery Capacity5000 mAh
# 109  Battery Capacity4000 mAh

# %%
df
# Out:
#                                           name ratings    price
# 0          Redmi 9A Sport (Coral Green, 32 GB)     4.2   ₹8,990  \
# 1       Xiaomi 11Lite NE (Vinyl Black, 128 GB)     4.2  ₹21,430
# 2    Xiaomi 11Lite NE (Diamond Dazzle, 128 GB)     4.2  ₹20,999
# 3     Xiaomi 11Lite NE (Tuscany Coral, 128 GB)     4.2  ₹20,999
# 4               Mi 11 Lite (Jazz Blue, 128 GB)     4.2  ₹17,499
# ..                                         ...     ...      ...
# 547               Mi A3 (Not just Blue, 64 GB)     4.2  ₹14,999
# 548          Mi 10T Pro (Lunar Silver, 128 GB)     4.3  ₹26,899
# 549                     Redmi Y1 (Gold, 32 GB)     4.5   ₹8,999
# 550    Redmi Note 7 Pro (Neptune Blue, 128 GB)     4.3  ₹17,999
# 551           Mi 10i (Pacific Sunrise, 128 GB)     NaN  ₹20,999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/k...
# ..                                                 ...
# 547  https://rukminim2.flixcart.com/image/312/312/k...
# 548  https://rukminim2.flixcart.com/image/312/312/k...
# 549  https://rukminim2.flixcart.com/image/312/312/j...
# 550  https://rukminim2.flixcart.com/image/312/312/j...
# 551  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 0    Internal Storage32 GBRAM3 GBMemory Card Slot T...  \
# 1    Internal Storage128 GBRAM6 GBExpandable Storag...
# 2    Internal Storage128 GBRAM6 GBExpandable Storag...
# 3    Internal Storage128 GBRAM6 GBExpandable Storag...
# 4    Internal Storage128 GBRAM8 GBExpandable Storag...
# ..                                                 ...
# 547  Internal Storage64 GBRAM4 GBExpandable Storage...
# 548    Internal Storage128 GBRAM8 GBCall Log MemoryYes
# 549  Internal Storage32 GBRAM3 GBExpandable Storage...
# 550  Internal Storage128 GBRAM6 GBExpandable Storag...
# 551  Internal Storage128 GBRAM6 GBSupported Memory ...
#
#                                           os_processor
# 0    Operating SystemAndroid Q 10Processor CoreOcta...  \
# 1    Operating SystemAndroid 11Processor TypeQualco...
# 2    Operating SystemAndroid 11Processor TypeQualco...
# 3    Operating SystemAndroid 11Processor TypeQualco...
# 4    Operating SystemAndroid 11Processor TypeQualco...
# ..                                                 ...
# 547  Operating SystemAndroid Pie 9Processor TypeQua...
# 548  Operating SystemAndroid 10Processor TypeQualco...
# 549  Operating SystemAndroid Nougat 7.1.2Processor ...
# 550  Operating SystemAndroid Pie 9.0Processor TypeQ...
# 551  Operating SystemAndroid Q 11Processor TypeQual...
#
#                                                 camera
# 0                       Primary Camera13MP Rear Camera  \
# 1    Primary Camera AvailableYesPrimary Camera64MP ...
# 2    Primary Camera AvailableYesPrimary Camera64MP ...
# 3    Primary Camera AvailableYesPrimary Camera64MP ...
# 4    Primary Camera AvailableYesPrimary Camera64MP ...
# ..                                                 ...
# 547  Primary Camera AvailableYesPrimary Camera48MP ...
# 548  Primary Camera AvailableYesPrimary Camera108MP...
# 549  Primary Camera AvailableYesPrimary Camera13MP ...
# 550  Primary Camera AvailableYesPrimary Camera48MP ...
# 551  Primary Camera AvailableYesPrimary Camera108MP...
#
#                                                display
# 0    Display Size16.59 cm (6.53 inch)Resolution1600...  \
# 1    Display Size16.64 cm (6.55 inch)Resolution1080...
# 2    Display Size16.64 cm (6.55 inch)Resolution1080...
# 3    Display Size16.64 cm (6.55 inch)Resolution1080...
# 4    Display Size16.64 cm (6.55 inch)Resolution2400...
# ..                                                 ...
# 547  Display Size15.46 cm (6.088 inch)Resolution156...
# 548  Display Size16.94 cm (6.67 inch)Resolution2400...
# 549  Display Size13.97 cm (5.5 inch)Resolution1280 ...
# 550  Display Size16.0 cm (6.3 inch)Resolution2340 x...
# 551  Display Size16.94 cm (6.67 inch)Resolution2400...
#
#                                                network
# 0    Network Type4G VOLTE, 4GSupported Networks4G V...  \
# 1    Network Type5G, 4G VOLTESupported Networks5G, ...
# 2    Network Type5G, 4G VOLTESupported Networks5G, ...
# 3    Network Type5G, 4G VOLTESupported Networks5G, ...
# 4    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# ..                                                 ...
# 547  Network Type4G VOLTE, 4G, 2G, 3GSupported Netw...
# 548  Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...
# 549  Network Type3G, 4G, 2GSupported NetworksGSM, W...
# 550  Network Type3G, 4G VOLTE, 2GSupported Networks...
# 551  Network Type5GSupported Networks5GInternet Con...
#
#                                              battery
# 0                           Battery Capacity5000 mAh
# 1          Battery Capacity4250 mAhBattery TypeLi-Po
# 2          Battery Capacity4250 mAhBattery TypeLi-Po
# 3          Battery Capacity4250 mAhBattery TypeLi-Po
# 4            Battery Capacity4250 mAhTalk Time30 hrs
# ..                                               ...
# 547  Battery Capacity4030 mAhBattery TypeLithium-ion
# 548          Battery Capacity5000 mAhTalk Time26 hrs
# 549                         Battery Capacity3080 mAh
# 550                         Battery Capacity4000 mAh
# 551                         Battery Capacity4820 mAh
#
# [552 rows x 10 columns]

# %%
print(os.getcwd())
os.chdir(r'd:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem')
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem\notebook\data_Ingestion\scraping
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem

# %%
# df

# %%
df.to_csv(r'data\raw_data\mi_mobile_new_data.csv',index=False)
