# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import os
import numpy as np
from itertools import zip_longest

# %%
def bs4_soup(pages):
    URL = f'https://www.flipkart.com/search?q=motorola+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={pages}'
    request = requests.get(URL)
    soup = bs(request.text,'html.parser')
    soup = soup.find('div',class_ = '_1YokD2 _3Mn1Gg')

    return soup , URL

# %%
def mob_specs(soup):
    names = soup.find_all('div', class_='_4rR01T')
    mob_names = [i.text if i else None for i in names]

    ratings = soup.find_all('div', class_='_3LWZlK')
    mob_ratings = [i.text if i else None for i in ratings]

    price = soup.find_all('div', class_='_30jeq3 _1_WHN1')
    mob_price = [i.text if i else None for i in price]

    img = soup.find_all('div', class_='CXW8mj')
    mob_img_URL = [i.find('img')['src'] if i.find('img') else None for i in img]

    return mob_names, mob_ratings, mob_price, mob_img_URL

# %%
def features_from_mob_links(soup):
    mobile_links = ['https://www.flipkart.com' + i['href'] for i in soup.find_all('a', class_='_1fQZEK')]
    mobile_req = [requests.get(url=i) for i in mobile_links]
    mobile_soup = [bs(i.text, 'html.parser').find('div', class_='_1YokD2 _2GoDe3') for i in mobile_req]
    mobile_specs_soup = [i.find_all('div', class_='_3k-BhJ') for i in mobile_soup]

    storage_ram = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Memory' in str(specs_.text) and 'Storage' in str(specs_.text)]
    storage_ram_cross_checked = [i for i in storage_ram if 'Internal' in i.split()]

    os_processor = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Os' in str(specs_.text) and 'Processor' in str(specs_.text)]
    os_processor_cross_checked = [i for i in os_processor if 'Operating' in i.split()]

    camera = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Camera' in str(specs_.text) and 'FeaturesPrimary' in str(specs_.text)]
    camera_cross_checked = [i for i in camera if 'Primary' and 'Camera' in i.split()]

    display = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Display' in str(specs_.text) and 'FeaturesDisplay' in str(specs_.text)]
    display_cross_checked = [i for i in display if 'Display' and 'cm' in i.split()]

    network = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Connectivity' in str(specs_.text) and 'FeaturesNetwork' in str(specs_.text)]
    network_cross_checked = [i for i in network if 'Network' in i.split()]

    battery = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Battery' in str(specs_.text) and 'FeaturesBattery' in str(specs_.text)]
    battery_cross_checked = [i for i in battery if 'Battery' in i.split()]

    return mobile_specs_soup, storage_ram_cross_checked, os_processor_cross_checked, camera_cross_checked, display_cross_checked, network_cross_checked, battery_cross_checked

# %%
def fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery):
    tuple_data = zip_longest(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery,fillvalue=np.nan)
    
    data = [i for i in tuple_data]
    return data

# %%
def print_len(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery):
    print(f"Length of mob_names: {len(mob_names)}")
    print(f"Length of mob_ratings: {len(mob_ratings)}")
    print(f"Length of mob_price: {len(mob_price)}")
    print(f"Length of mob_img_URL: {len(mob_img_URL)}")
    print(f"Length of storage_ram: {len(storage_ram)}")
    print(f"Length of os_processor: {len(os_processor)}")
    print(f"Length of camera: {len(camera)}")
    print(f"Length of display: {len(display)}")
    print(f"Length of network: {len(network)}")
    print(f"Length of battery: {len(battery)}")

# %%
df = pd.DataFrame()

page_start = 1
page_ends = 6

for pages in range(page_start, page_ends):

    soup, URL = bs4_soup(pages=pages)
    
    mob_names, mob_ratings, mob_price, mob_img_URL = mob_specs(soup)
    mobile_specs_soup, storage_ram, os_processor, camera, display, network, battery = features_from_mob_links(soup=soup)
    
    data = fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)

    if mobile_specs_soup is not None and soup is not None:
        
        print_len(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)

        page_df = pd.DataFrame(data=data,columns=['name', 'ratings', 'price', 'imgURL', 'storage_ram', 'camera',
       'oS_Processor', 'display', 'network', 'battery'])

        if not page_df.empty:
            df = pd.concat(objs=[df, page_df], ignore_index=True)
            print(f'scraping data from page:{pages}')
            print(f'working in {URL} Page')
            print(f'page df : page_shape : {page_df.shape} \n {page_df.sample(2)}')
            print(f'df : df shape : {df.shape} \n {df.sample(2)}')
            print()

    else:
        print(f"Skipping page {pages} due to empty mobile_specs_soup or soup.")
# Out:
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 23
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:1
# working in https://www.flipkart.com/search?q=motorola+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1 Page
# page df : page_shape : (24, 10)
#                                     name ratings    price
# 23   MOTOROLA e13 (Creamy White, 64 GB)     3.9   ₹6,499  \
# 2   MOTOROLA G32 (Mineral Gray, 128 GB)     4.1  ₹11,999
#
#                                                imgURL
# 23  https://rukminim2.flixcart.com/image/312/312/x...  \
# 2   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 23  Internal Storage64 GBRAM2 GBExpandable Storage...  \
# 2   Internal Storage128 GBRAM8 GBSupported Memory ...
#
#                                                camera
# 23  Operating SystemAndroid 13 (Go Edition)Process...  \
# 2   Operating SystemAndroid 12Processor TypeQualco...
#
#                                          oS_Processor
# 23                                                NaN  \
# 2   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 23  Display Size16.51 cm (6.5 inch)Resolution1600 ...  \
# 2   Display Size16.51 cm (6.5 inch)Resolution2400 ...
#
#                                               network
# 23  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 2   Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 23  Battery Capacity5000 mAh
# 2   Battery Capacity5000 mAh
# df : df shape : (24, 10)
#                                         name ratings    price
# 10  MOTOROLA G62 5G (Midnight Gray, 128 GB)     4.1  ₹15,499  \
# 7       MOTOROLA g42 (Metallic Rose, 64 GB)     4.2   ₹9,999
#
#                                                imgURL
# 10  https://rukminim2.flixcart.com/image/312/312/x...  \
# 7   https://rukminim2.flixcart.com/image/312/312/l...
#
#                                           storage_ram
# 10  Internal Storage128 GBRAM6 GBSupported Memory ...  \
# 7   Internal Storage64 GBRAM4 GBSupported Memory C...
#
#                                                camera
# 10  Operating SystemAndroid 12Processor TypeQualco...  \
# 7   Operating SystemAndroid 12Processor TypeQualco...
#
#                                          oS_Processor
# 10  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 7   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 10  Display Size16.64 cm (6.55 inch)Resolution2400...  \
# 7   Display Size16.43 cm (6.47 inch)Resolution2400...
#
#                                               network
# 10  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 7   Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 10  Battery Capacity5000 mAh
# 7   Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:2
# working in https://www.flipkart.com/search?q=motorola+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2 Page
# page df : page_shape : (24, 10)
#                                    name ratings    price
# 19  MOTOROLA g22 (Cosmic Black, 64 GB)     3.8  ₹10,999  \
# 3   MOTOROLA e13 (Aurora Green, 64 GB)     3.9   ₹6,499
#
#                                                imgURL
# 19  https://rukminim2.flixcart.com/image/312/312/l...  \
# 3   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 19  Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 3   Internal Storage64 GBRAM2 GBExpandable Storage...
#
#                                                camera
# 19  Operating SystemAndroid 12Processor TypeMediat...  \
# 3   Operating SystemAndroid 13 (Go Edition)Process...
#
#                                          oS_Processor
# 19  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 3   Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 19  Display Size16.51 cm (6.5 inch)Resolution1600 ...  \
# 3   Display Size16.51 cm (6.5 inch)Resolution1600 ...
#
#                                               network
# 19  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 3   Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 19  Battery Capacity5000 mAh
# 3   Battery Capacity5000 mAh
# df : df shape : (48, 10)
#                                         name ratings    price
# 12  MOTOROLA g73 5G (Midnight Blue, 128 GB)     3.9  ₹16,999  \
# 13      MOTOROLA G32 (Satin Silver, 128 GB)     4.1  ₹11,999
#
#                                                imgURL
# 12  https://rukminim2.flixcart.com/image/312/312/x...  \
# 13  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 12  Internal Storage128 GBRAM8 GBExpandable Storag...  \
# 13  Internal Storage128 GBRAM8 GBSupported Memory ...
#
#                                                camera
# 12  Operating SystemAndroid 13Processor TypeMediat...  \
# 13  Operating SystemAndroid 12Processor TypeQualco...
#
#                                          oS_Processor
# 12  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 13  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 12  Display Size16.51 cm (6.5 inch)Resolution2400 ...  \
# 13  Display Size16.51 cm (6.5 inch)Resolution2400 ...
#
#                                               network
# 12  Network Type2G, 3G, 4G, 5GSupported Networks4G...  \
# 13  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 12  Battery Capacity5000 mAh
# 13  Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:3
# working in https://www.flipkart.com/search?q=motorola+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3 Page
# page df : page_shape : (24, 10)
#                                        name ratings    price
# 4   MOTOROLA edge 30 (Meteor Grey, 128 GB)     4.1  ₹24,999  \
# 21       Moto G8 Plus (Cosmic Blue, 64 GB)     4.3  ₹15,999
#
#                                                imgURL
# 4   https://rukminim2.flixcart.com/image/312/312/l...  \
# 21  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 4                       Internal Storage128 GBRAM6 GB  \
# 21  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                                camera
# 4   Operating SystemAndroid 12Processor TypeQualco...  \
# 21  Operating SystemAndroid Pie 9Processor TypeQua...
#
#                                          oS_Processor
# 4   Primary Camera AvailableYesPrimary Camera50MP ...  \
# 21  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                               display
# 4   Display Size16.64 cm (6.55 inch)Resolution2460...  \
# 21  Display Size16.0 cm (6.3 inch)Resolution2280 x...
#
#                                               network
# 4   Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 21  Network Type3G, 4G, 2GSupported NetworksGSM, W...
#
#                      battery
# 4   Battery Capacity4020 mAh
# 21  Battery Capacity4000 mAh
# df : df shape : (72, 10)
#                                      name ratings    price
# 0   MOTOROLA g42 (Atlantic Green, 64 GB)     4.2   ₹9,999  \
# 30  MOTOROLA g42 (Atlantic Green, 64 GB)     4.2  ₹10,899
#
#                                                imgURL
# 0   https://rukminim2.flixcart.com/image/312/312/l...  \
# 30  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 0   Internal Storage64 GBRAM4 GBSupported Memory C...  \
# 30  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                                camera
# 0   Operating SystemAndroid 12Processor TypeQualco...  \
# 30  Operating SystemAndroid Oxygen Android 12Proce...
#
#                                          oS_Processor
# 0   Primary Camera AvailableYesPrimary Camera50MP ...  \
# 30  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 0   Display Size16.43 cm (6.47 inch)Resolution2400...  \
# 30  Display Size16.43 cm (6.47 inch)Resolution2400...
#
#                                               network
# 0   Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 30  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                      battery
# 0   Battery Capacity5000 mAh
# 30  Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:4
# working in https://www.flipkart.com/search?q=motorola+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4 Page
# page df : page_shape : (24, 10)
#                                         name ratings    price
# 10   MOTOROLA E7 Power (Tahiti Blue, 32 GB)     4.1   ₹7,299  \
# 3   MOTOROLA Edge 40 (Viva Magenta, 256 GB)     4.2  ₹29,999
#
#                                                imgURL
# 10  https://rukminim2.flixcart.com/image/312/312/k...  \
# 3   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 10  Internal Storage32 GBRAM2 GBExpandable Storage...  \
# 3                       Internal Storage256 GBRAM8 GB
#
#                                                camera
# 10  Operating SystemAndroid 10Processor TypeMediaT...  \
# 3   Operating SystemAndroid 13Processor TypeDimens...
#
#                                          oS_Processor
# 10  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 3   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 10  Display Size16.54 cm (6.51 inch)Resolution1600...  \
# 3   Display Size16.64 cm (6.55 inch)Resolution2400...
#
#                                               network
# 10  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 3   Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                      battery
# 10  Battery Capacity5000 mAh
# 3   Battery Capacity4400 mAh
# df : df shape : (96, 10)
#                                            name ratings    price
# 21                                Motorola a70       4   ₹1,869  \
# 71  MOTOROLA G9 Power (Electric Violet, 64 GB)     4.1  ₹11,999
#
#                                                imgURL
# 21  https://rukminim2.flixcart.com/image/312/312/k...  \
# 71  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 21  Internal Storage4 MBRAM4 MBExpandable Storage3...  \
# 71  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                                camera
# 21            Operating Frequency2G GSM: 900/1800 MHz  \
# 71  Operating SystemAndroid 10Processor TypeQualco...
#
#                                          oS_Processor
# 21  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 71  Primary Camera AvailableYesPrimary Camera64MP ...
#
#                                               display
# 21  Display Size6.1 cm (2.4 inch)Resolution320 x 2...  \
# 71  Display Size17.22 cm (6.78 inch)Resolution1600...
#
#                                               network
# 21  Network Type2GSupported NetworksGSMInternet Co...  \
# 71  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                                               battery
# 21  Battery Capacity1750 mAhBattery TypeLi-ionDual...
# 71                           Battery Capacity6000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 23
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:5
# working in https://www.flipkart.com/search?q=motorola+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5 Page
# page df : page_shape : (24, 10)
#                                         name ratings   price
# 19      Moto E6s (Polished Graphite, 64 GB)     4.1  ₹7,499  \
# 21  MOTOROLA G10 Power (Breeze Blue, 64 GB)     4.2  ₹9,999
#
#                                                imgURL
# 19  https://rukminim2.flixcart.com/image/312/312/k...  \
# 21  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 19  Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 21  Internal Storage64 GBRAM4 GBSupported Memory C...
#
#                                                camera
# 19  Operating SystemAndroid 11Processor TypeSnapdr...  \
# 21  Operating SystemAndroid 11Processor TypeMediaT...
#
#                                          oS_Processor
# 19  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 21  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                               display
# 19  Display Size15.49 cm (6.1 inch)Resolution1560 ...  \
# 21  Display Size16.54 cm (6.51 inch)Resolution1600...
#
#                                               network
# 19  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 21  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                      battery
# 19  Battery Capacity3000 mAh
# 21  Battery Capacity6000 mAh
# df : df shape : (120, 10)
#                                      name ratings    price
# 41  MOTOROLA g31 (Meteorite Grey, 64 GB)     4.2  ₹11,999  \
# 58  MOTOROLA E7 Power (Coral Red, 32 GB)     4.1   ₹7,999
#
#                                                imgURL
# 41  https://rukminim2.flixcart.com/image/312/312/l...  \
# 58  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 41  Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 58  Internal Storage32 GBRAM2 GBExpandable Storage...
#
#                                                camera
# 41  Operating SystemAndroid 11Processor TypeMediat...  \
# 58  Operating SystemAndroid 10Processor TypeMediaT...
#
#                                          oS_Processor
# 41  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 58  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 41  Display Size16.26 cm (6.4 inch)Resolution2400 ...  \
# 58  Display Size16.54 cm (6.51 inch)Resolution1600...
#
#                                               network
# 41  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 58  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                      battery
# 41  Battery Capacity5000 mAh
# 58  Battery Capacity5000 mAh

# %%
df
# Out:
#                                                 name ratings    price
# 0               MOTOROLA g42 (Atlantic Green, 64 GB)     4.2   ₹9,999  \
# 1                 MOTOROLA e13 (Cosmic Black, 64 GB)       4   ₹7,299
# 2                MOTOROLA G32 (Mineral Gray, 128 GB)     4.1  ₹11,999
# 3                  MOTOROLA e32 (Arctic Blue, 64 GB)     3.9   ₹7,999
# 4               MOTOROLA g13 (Lavender Blue, 128 GB)     3.9   ₹9,999
# ..                                               ...     ...      ...
# 115              Moto E6s (Polished Graphite, 64 GB)     4.1   ₹7,499
# 116                 MOTOROLA G30 (Pastel Sky, 64 GB)     4.1  ₹10,999
# 117          MOTOROLA G10 Power (Breeze Blue, 64 GB)     4.2   ₹9,999
# 118  MOTOROLA Edge 20 Fusion 5G (Cyber Teal, 128 GB)       4  ₹18,999
# 119    MOTOROLA Edge 30 Pro (Stardust White, 128 GB)       4  ₹34,999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/l...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 115  https://rukminim2.flixcart.com/image/312/312/k...
# 116  https://rukminim2.flixcart.com/image/312/312/k...
# 117  https://rukminim2.flixcart.com/image/312/312/k...
# 118  https://rukminim2.flixcart.com/image/312/312/k...
# 119  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 0    Internal Storage64 GBRAM4 GBSupported Memory C...  \
# 1    Internal Storage64 GBRAM4 GBExpandable Storage...
# 2    Internal Storage128 GBRAM8 GBSupported Memory ...
# 3    Internal Storage64 GBRAM4 GBExpandable Storage...
# 4    Internal Storage128 GBRAM4 GBExpandable Storag...
# ..                                                 ...
# 115  Internal Storage64 GBRAM4 GBExpandable Storage...
# 116  Internal Storage64 GBRAM4 GBSupported Memory C...
# 117  Internal Storage64 GBRAM4 GBSupported Memory C...
# 118  Internal Storage128 GBRAM6 GBMemory Card Slot ...
# 119                      Internal Storage128 GBRAM8 GB
#
#                                                 camera
# 0    Operating SystemAndroid 12Processor TypeQualco...  \
# 1    Operating SystemAndroid 13 (Go Edition)Process...
# 2    Operating SystemAndroid 12Processor TypeQualco...
# 3    Operating SystemAndroid 12Processor TypeMediat...
# 4    Operating SystemAndroid 13Processor TypeHelio ...
# ..                                                 ...
# 115  Operating SystemAndroid 11Processor TypeSnapdr...
# 116  Operating SystemAndroid 11Processor TypeSnapdr...
# 117  Operating SystemAndroid 11Processor TypeMediaT...
# 118  Operating SystemAndroid 12Processor TypeQualco...
# 119                                                NaN
#
#                                           oS_Processor
# 0    Primary Camera AvailableYesPrimary Camera50MP ...  \
# 1    Primary Camera AvailableYesPrimary Camera13MP ...
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
# 3    Primary Camera AvailableYesPrimary Camera50MP ...
# 4    Primary Camera AvailableYesPrimary Camera50MP ...
# ..                                                 ...
# 115  Primary Camera AvailableYesPrimary Camera13MP ...
# 116  Primary Camera AvailableYesPrimary Camera64MP ...
# 117  Primary Camera AvailableYesPrimary Camera48MP ...
# 118  Primary Camera AvailableYesPrimary Camera108MP...
# 119  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                                display
# 0    Display Size16.43 cm (6.47 inch)Resolution2400...  \
# 1    Display Size16.51 cm (6.5 inch)Resolution1600 ...
# 2    Display Size16.51 cm (6.5 inch)Resolution2400 ...
# 3    Display Size16.51 cm (6.5 inch)Resolution1600 ...
# 4    Display Size16.51 cm (6.5 inch)Resolution1600 ...
# ..                                                 ...
# 115  Display Size15.49 cm (6.1 inch)Resolution1560 ...
# 116  Display Size16.54 cm (6.51 inch)Resolution1600...
# 117  Display Size16.54 cm (6.51 inch)Resolution1600...
# 118  Display Size16.94 cm (6.67 inch)Resolution2400...
# 119  Display Size16.3 cm (6.417 inch)Resolution2400...
#
#                                                network
# 0    Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 1    Network Type4G, 3G, 2GSupported Networks4G LTE...
# 2    Network Type4G, 3G, 2GSupported Networks4G LTE...
# 3    Network Type4G, 3G, 2GSupported Networks4G LTE...
# 4    Network Type2G, 3G, 4GSupported Networks4G LTE...
# ..                                                 ...
# 115  Network Type4G, 3G, 2GSupported Networks4G LTE...
# 116  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 117  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 118  Network Type5G, 4G, 3G, 2GSupported Networks5G...
# 119  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                       battery
# 0    Battery Capacity5000 mAh
# 1    Battery Capacity5000 mAh
# 2    Battery Capacity5000 mAh
# 3    Battery Capacity5000 mAh
# 4    Battery Capacity5000 mAh
# ..                        ...
# 115  Battery Capacity3000 mAh
# 116  Battery Capacity5000 mAh
# 117  Battery Capacity6000 mAh
# 118  Battery Capacity5000 mAh
# 119  Battery Capacity4800 mAh
#
# [120 rows x 10 columns]

# %%
print(os.getcwd())
os.chdir(r'd:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem')
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem

# %%
df.to_csv(r'data\raw_data\motorola_mobile_data.csv',index=False)
