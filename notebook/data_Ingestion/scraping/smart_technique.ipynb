# %% [markdown]
# # Extract features without having raw_data

# %% [markdown]
# # OnePlus Mobiles😎

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import os
import numpy as np
from itertools import zip_longest

# %%
def bs4_soup(pages):
    URL = f'https://www.flipkart.com/search?q=one+plus+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={pages}'
    request = requests.get(URL)
    soup = bs(request.text,'html.parser')
    soup = soup.find('div',class_ = '_1YokD2 _3Mn1Gg')

    return soup , URL

# %%
def mob_specs(soup):
    names = soup.find_all('div', class_='_4rR01T')
    mob_names_list = [i.text if i else None for i in names]

    ratings = soup.find_all('div', class_='_3LWZlK')
    mob_ratings = [i.text if i else None for i in ratings]

    price = soup.find_all('div', class_='_30jeq3 _1_WHN1')
    mob_price = [i.text if i else None for i in price]

    img = soup.find_all('div', class_='CXW8mj')
    mob_img_URL = [i.find('img')['src'] if i.find('img') else None for i in img]

    # Find the maximum length among all lists
    max_length = max(len(mob_names_list), len(mob_ratings), len(mob_price), len(mob_img_URL))

    # Use zip_longest to ensure all lists have the same length
    mob_names = list(zip_longest(mob_names_list, [None] * max_length,fillvalue=np.nan))
    mob_ratings = list(zip_longest(mob_ratings, [None] * max_length,fillvalue=np.nan))
    mob_price = list(zip_longest(mob_price, [None] * max_length,fillvalue=np.nan))
    mob_img_URL = list(zip_longest(mob_img_URL, [None] * max_length,fillvalue=np.nan))

    return mob_names, mob_ratings, mob_price, mob_img_URL

# mob_names, mob_ratings, mob_price, mob_img_URL = mob_specs(soup)

# print(f"Length of mob_names: {len(mob_names)}")
# print(f"Length of mob_ratings: {len(mob_ratings)}")
# print(f"Length of mob_price: {len(mob_price)}")
# print(f"Length of mob_img_URL: {len(mob_img_URL)}")

# %%
import pandas as pd
from itertools import zip_longest

def features_from_mob_links(soup):
    mobile_links = ['https://www.flipkart.com' + i['href'] for i in soup.find_all('a', class_='_1fQZEK')]
    mobile_req = [requests.get(url=i) for i in mobile_links]
    mobile_soup = [bs(i.text, 'html.parser').find('div', class_='_1YokD2 _2GoDe3') for i in mobile_req]
    mobile_specs_soup = [i.find_all('div', class_='_3k-BhJ') for i in mobile_soup]

    storage_ram = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Memory' in str(specs_.text) and 'Storage' in str(specs_.text)]
    os_processor = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Os' in str(specs_.text) and 'Processor' in str(specs_.text)]
    camera = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Camera' in str(specs_.text) and 'FeaturesPrimary' in str(specs_.text)]
    display = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Display' in str(specs_.text) and 'FeaturesDisplay' in str(specs_.text)]
    network = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Connectivity' in str(specs_.text) and 'FeaturesNetwork' in str(specs_.text)]
    battery = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Battery' in str(specs_.text) and 'FeaturesBattery' in str(specs_.text)]

    # Find the maximum length among all lists
    max_length = max(len(storage_ram), len(os_processor), len(camera), len(display), len(network), len(battery))

    # Use zip_longest to ensure all lists have the same length
    storage_ram = list(zip_longest(storage_ram, [None] * max_length,fillvalue=np.nan))
    os_processor = list(zip_longest(os_processor, [None] * max_length,fillvalue=np.nan))
    camera = list(zip_longest(camera, [None] * max_length,fillvalue=np.nan))
    display = list(zip_longest(display, [None] * max_length,fillvalue=np.nan))
    network = list(zip_longest(network, [None] * max_length,fillvalue=np.nan))
    battery = list(zip_longest(battery, [None] * max_length,fillvalue=np.nan))

    return mobile_specs_soup, storage_ram, os_processor, camera, display, network, battery

# %%
df = pd.DataFrame()

page_start = 1

for pages in range(page_start, 18):

    soup, URL = bs4_soup(pages=pages)
    mob_names, mob_ratings, mob_price, mob_img_URL = mob_specs(soup)
    mobile_specs_soup, storage_ram, os_processor, camera, display, network, battery = features_from_mob_links(soup=soup)


    if mobile_specs_soup is not None and soup is not None:
        
        print(f"Length of mob_names: {len(mob_names)}")
        print(f"Length of mob_ratings: {len(mob_ratings)}")
        print(f"Length of mob_price: {len(mob_price)}")
        print(f"Length of mob_img_URL: {len(mob_img_URL)}")
        print(f"Length of storage_ram: {len(storage_ram)}")
        print(f"Length of os_processor: {len(os_processor)}")
        print(f"Length of camera: {len(camera)}")
        print(f"Length of display: {len(display)}")
        print(f"Length of network: {len(network)}")
        print(f"Length of battery: {len(battery)}")

        names = [i for i in mob_names]
        ratings = [i for i in mob_ratings]
        price = [i for i in mob_price]
        imgURL = [i for i in mob_img_URL]
        storage_ram_ = [i for i in storage_ram]
        cam = [i for i in camera]
        os_pro = [i for i in os_processor]
        dis = [i for i in display]
        net = [i for i in network]
        bat = [i for i in battery]

        data_dict = {
            'name': names,
            'ratings': ratings,
            'price': price,
            'imgURL': imgURL,
            'storage_ram': storage_ram_,
            'camera': cam,     
            'oS_Processor': os_pro,    
            'display': dis,
            'network': net,     
            'battery': bat,    
        }

        page_df = pd.DataFrame(data=data_dict)

        if not page_df.empty:
            df = pd.concat(objs=[df, page_df], ignore_index=True)
            print(f'scraping data from page:{pages}')
            print(f'working in {URL} Page')
            print(f'page df : page_shape : {page_df.shape} \n {page_df.sample(2)}')
            print(f'df : df shape : {df.shape} \n {df.sample(2)}')
            print()

    else:
        print(f"Skipping page {pages} due to empty mobile_specs_soup or soup.")
# Out:
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:1
# working in https://www.flipkart.com/search?q=one+plus+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1 Page
# page df : page_shape : (24, 10)
#                                                  name      ratings
# 19  (OnePlus 8T 5G (Aquamarine Green, 256 GB), None)  (3.3, None)  \
# 23           (OnePlus Nord (Gray Onyx, 64 GB), None)  (4.3, None)
#
#               price                                             imgURL
# 19  (₹34,999, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 23  (₹24,490, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                           storage_ram
# 19             (Internal Storage256 GBRAM12 GB, None)  \
# 23  (Internal Storage64 GBRAM6 GBMemory Card Slot ...
#
#                                                camera
# 19  (Primary Camera48MP Rear CameraDual Camera Len...  \
# 23  (Primary Camera AvailableYesPrimary Camera48MP...
#
#                                          oS_Processor
# 19  (Operating SystemAndroid Q 11Processor CoreDua...  \
# 23  (Operating SystemAndroid Q 10Processor TypeQua...
#
#                                               display
# 19  (Display Size16.64 cm (6.55 inch)Resolution240...  \
# 23  (Display Size16.36 cm (6.44 inch)Resolution240...
#
#                                               network
# 19  (Network Type5GSupported Networks4G LTE, 5G, C...  \
# 23  (Network Type5G, 4G VOLTESupported Networks5G,...
#
#                                               battery
# 19                   (Battery Capacity4500 mAh, None)
# 23  (Battery Capacity4115 mAhBattery Typelithium-i...
# df : df shape : (24, 10)
#                                                 name      ratings
# 6  (OnePlus 11R 5G (Galactic Silver, 256 GB), None)  (4.5, None)  \
# 5      (OnePlus 11R 5G (Sonic Black, 256 GB), None)  (4.5, None)
#
#              price                                             imgURL
# 6  (₹44,565, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 5  (₹44,729, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                               storage_ram
# 6  (Internal Storage256 GBRAM16 GB, None)  \
# 5  (Internal Storage256 GBRAM16 GB, None)
#
#                                               camera
# 6  (Primary Camera50MP Rear CameraDual Camera Len...  \
# 5  (Primary Camera50MP Rear CameraDual Camera Len...
#
#                                         oS_Processor
# 6  (Operating SystemAndroid OxygenOS based on And...  \
# 5  (Operating SystemAndroid Oxygen OxygenOS based...
#
#                                              display
# 6  (Display Size17.02 cm (6.7 inch)Resolution2772...  \
# 5  (Display Size17.02 cm (6.7 inch)Resolution2772...
#
#                                       network
# 6  (Network Type5GSupported Networks5G, None)  \
# 5  (Network Type5GSupported Networks5G, None)
#
#                             battery
# 6  (Battery Capacity5000 mAh, None)
# 5  (Battery Capacity5000 mAh, None)
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:2
# working in https://www.flipkart.com/search?q=one+plus+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2 Page
# page df : page_shape : (24, 10)
#                                               name      ratings
# 18  (OnePlus Nord 2 5G (Blue Haze, 256 GB), None)  (4.3, None)  \
# 20      (OnePlus 9 5G (Arctic Sky, 256 GB), None)    (4, None)
#
#               price                                             imgURL
# 18  (₹32,990, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 20  (₹39,999, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                           storage_ram
# 18  (Internal Storage256 GBRAM12 GBMemory Card Slo...  \
# 20             (Internal Storage256 GBRAM12 GB, None)
#
#                                                camera
# 18  (Primary Camera16MP Rear CameraDual Camera Len...  \
# 20  (Primary Camera48MP Rear CameraDual Camera Len...
#
#                                          oS_Processor
# 18  (Operating SystemAndroid 11Processor CoreDual ...  \
# 20  (Operating SystemAndroid 11Processor CoreDual ...
#
#                                               display
# 18  (Display Size16.33 cm (6.43 inch)Resolution108...  \
# 20  (Display Size16.64 cm (6.55 inch)Resolution240...
#
#                                               network
# 18  (Network Type5GSupported Networks4G LTE, 5G, G...  \
# 20  (Network Type5GSupported Networks4G LTE, GSM, ...
#
#                              battery
# 18  (Battery Capacity4500 mAh, None)
# 20  (Battery Capacity4500 mAh, None)
# df : df shape : (48, 10)
#                                                  name      ratings
# 22  (OnePlus 8T 5G (Aquamarine Green, 128 GB), None)  (4.4, None)  \
# 38          (OnePlus Nord (Gray Onyx, 128 GB), None)  (4.2, None)
#
#               price                                             imgURL
# 22  (₹29,990, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 38  (₹24,990, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                           storage_ram
# 22              (Internal Storage128 GBRAM8 GB, None)  \
# 38  (Internal Storage128 GBRAM8 GBMemory Card Slot...
#
#                                                camera
# 22  (Primary Camera48MP Rear CameraDual Camera Len...  \
# 38             (Primary Camera50MP Rear Camera, None)
#
#                                          oS_Processor
# 22  (Operating SystemAndroid Q 11Processor CoreDua...  \
# 38  (Operating SystemAndroid Q 10Processor TypeQua...
#
#                                               display
# 22  (Display Size16.64 cm (6.55 inch)Resolution240...  \
# 38  (Display Size16.36 cm (6.44 inch)Resolution240...
#
#                                               network
# 22  (Network Type5GSupported Networks4G LTE, 5G, C...  \
# 38  (Network Type5G, 4G VOLTESupported Networks5G,...
#
#                                               battery
# 22                   (Battery Capacity4500 mAh, None)
# 38  (Battery Capacity4115 mAhBattery Typelithium-i...
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:3
# working in https://www.flipkart.com/search?q=one+plus+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3 Page
# page df : page_shape : (24, 10)
#                                                  name      ratings
# 21  (OnePlus Nord 2T 5G (Gray Shadow, 128 GB), None)  (4.4, None)  \
# 11    (OnePlus Nord CE 5G (Blue Void, 128 GB), None)  (3.4, None)
#
#               price                                             imgURL
# 21  (₹28,900, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 11  (₹24,499, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                           storage_ram
# 21  (Internal Storage128 GBRAM8 GBMemory Card Slot...  \
# 11              (Internal Storage128 GBRAM8 GB, None)
#
#                                     camera
# 21  (Primary Camera50MP Rear Camera, None)  \
# 11  (Primary Camera64MP Rear Camera, None)
#
#                                          oS_Processor
# 21  (Operating SystemAndroid 13Processor CoreOcta ...  \
# 11  (Operating SystemAndroid 11Processor CoreDual ...
#
#                                               display
# 21  (Display Size17.02 cm (6.7 inch)Resolution2400...  \
# 11  (Display Size16.33 cm (6.43 inch)Resolution108...
#
#                                               network
# 21         (Network Type5GSupported Networks5G, None)  \
# 11  (Network Type5GSupported Networks4G LTE, 5G, G...
#
#                              battery
# 21  (Battery Capacity4500 mAh, None)
# 11  (Battery Capacity4500 mAh, None)
# df : df shape : (72, 10)
#                                                   name      ratings
# 31   (OnePlus 8T 5G (Aquamarine Green, 128 GB), None)  (4.4, None)  \
# 56  (OnePlus 10 Pro 5G (Emerald Forest, 128 GB), N...  (4.2, None)
#
#               price                                             imgURL
# 31  (₹29,990, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 56  (₹54,999, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                           storage_ram
# 31              (Internal Storage128 GBRAM8 GB, None)  \
# 56  (Internal Storage128 GBRAM8 GBMemory Card Slot...
#
#                                     camera
# 31  (Primary Camera48MP Rear Camera, None)  \
# 56  (Primary Camera48MP Rear Camera, None)
#
#                                          oS_Processor
# 31  (Operating SystemAndroid Q 11Processor CoreDua...  \
# 56  (Operating SystemAndroid 12Processor CoreDual ...
#
#                                               display
# 31  (Display Size16.64 cm (6.55 inch)Resolution240...  \
# 56  (Display Size17.02 cm (6.7 inch)Resolution3216...
#
#                                               network
# 31  (Network Type5GSupported Networks4G LTE, 5G, C...  \
# 56  (Network Type5GSupported Networks5G, 4G VoLTE,...
#
#                              battery
# 31  (Battery Capacity4500 mAh, None)
# 56  (Battery Capacity5000 mAh, None)
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:4
# working in https://www.flipkart.com/search?q=one+plus+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4 Page
# page df : page_shape : (24, 10)
#                                                   name      ratings
# 23  (OnePlus Nord CE 2 5G (Gray Mirror, 128 GB), N...  (nan, None)  \
# 2     (OnePlus 9 Pro 5G (Morning Mist, 256 GB), None)  (3.8, None)
#
#               price                                             imgURL
# 23  (₹17,999, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 2   (₹49,999, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                           storage_ram
# 23  (Internal Storage128 GBRAM6 GBMemory Card Slot...  \
# 2              (Internal Storage256 GBRAM12 GB, None)
#
#                                                camera
# 23                                        (nan, None)  \
# 2   (Primary Camera48MP Rear CameraDual Camera Len...
#
#                                          oS_Processor
# 23  (Operating SystemAndroid Q 13Processor CoreOct...  \
# 2   (Operating SystemAndroid Q 11Processor CoreDua...
#
#                                               display
# 23  (Display Size16.33 cm (6.43 inch)Resolution240...  \
# 2   (Display Size17.02 cm (6.7 inch)Resolution3216...
#
#                                               network
# 23         (Network Type5GSupported Networks5G, None)  \
# 2   (Network Type5GSupported Networks5G, 4G LTE, G...
#
#                              battery
# 23  (Battery Capacity4500 mAh, None)
# 2   (Battery Capacity4500 mAh, None)
# df : df shape : (96, 10)
#                                                  name      ratings
# 31  (OnePlus 8T 5G (Aquamarine Green, 128 GB), None)  (4.4, None)  \
# 6   (OnePlus 11R 5G (Galactic Silver, 256 GB), None)  (4.5, None)
#
#               price                                             imgURL
# 31  (₹29,990, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 6   (₹44,565, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                storage_ram
# 31   (Internal Storage128 GBRAM8 GB, None)  \
# 6   (Internal Storage256 GBRAM16 GB, None)
#
#                                                camera
# 31             (Primary Camera48MP Rear Camera, None)  \
# 6   (Primary Camera50MP Rear CameraDual Camera Len...
#
#                                          oS_Processor
# 31  (Operating SystemAndroid Q 11Processor CoreDua...  \
# 6   (Operating SystemAndroid OxygenOS based on And...
#
#                                               display
# 31  (Display Size16.64 cm (6.55 inch)Resolution240...  \
# 6   (Display Size17.02 cm (6.7 inch)Resolution2772...
#
#                                               network
# 31  (Network Type5GSupported Networks4G LTE, 5G, C...  \
# 6          (Network Type5GSupported Networks5G, None)
#
#                              battery
# 31  (Battery Capacity4500 mAh, None)
# 6   (Battery Capacity5000 mAh, None)
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:5
# working in https://www.flipkart.com/search?q=one+plus+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5 Page
# page df : page_shape : (24, 10)
#                                                   name      ratings
# 5       (OnePlus 10R 5G (Forest Green, 256 GB), None)  (4.2, None)  \
# 21  (OnePlus Nord CE 2 5G (Gray Mirror, 128 GB), N...  (4.2, None)
#
#               price                                             imgURL
# 5   (₹34,198, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 21  (₹24,989, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                           storage_ram
# 5   (Internal Storage256 GBRAM12 GBMemory Card Slo...  \
# 21  (Internal Storage128 GBRAM8 GBMemory Card Slot...
#
#                                                camera
# 5              (Primary Camera50MP Rear Camera, None)  \
# 21  (Primary Camera64MP Rear CameraDual Camera Len...
#
#                                          oS_Processor
# 5   (Operating SystemAndroid 12Processor CoreOcta ...  \
# 21  (Operating SystemAndroid Q 13Processor CoreOct...
#
#                                               display
# 5   (Display Size17.02 cm (6.7 inch)Resolution2400...  \
# 21  (Display Size16.33 cm (6.43 inch)Resolution240...
#
#                                        network
# 5   (Network Type5GSupported Networks5G, None)  \
# 21  (Network Type5GSupported Networks5G, None)
#
#                              battery
# 5   (Battery Capacity5000 mAh, None)
# 21  (Battery Capacity4500 mAh, None)
# df : df shape : (120, 10)
#                                                  name      ratings
# 19  (OnePlus 8T 5G (Aquamarine Green, 256 GB), None)  (3.3, None)  \
# 75     (OnePlus 9 Pro 5G (Pine Green, 256 GB), None)  (3.8, None)
#
#               price                                             imgURL
# 19  (₹34,999, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 75  (₹47,999, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                storage_ram
# 19  (Internal Storage256 GBRAM12 GB, None)  \
# 75  (Internal Storage256 GBRAM12 GB, None)
#
#                                                camera
# 19  (Primary Camera48MP Rear CameraDual Camera Len...  \
# 75  (Primary Camera48MP Rear CameraDual Camera Len...
#
#                                          oS_Processor
# 19  (Operating SystemAndroid Q 11Processor CoreDua...  \
# 75  (Operating SystemAndroid 11Processor CoreDual ...
#
#                                               display
# 19  (Display Size16.64 cm (6.55 inch)Resolution240...  \
# 75  (Display Size17.02 cm (6.7 inch)Resolution3216...
#
#                                               network
# 19  (Network Type5GSupported Networks4G LTE, 5G, C...  \
# 75  (Network Type5GSupported Networks4G LTE, GSM, ...
#
#                              battery
# 19  (Battery Capacity4500 mAh, None)
# 75  (Battery Capacity4500 mAh, None)
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:6
# working in https://www.flipkart.com/search?q=one+plus+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=6 Page
# page df : page_shape : (24, 10)
#                                                 name      ratings
# 23      (OnePlus 7T (Frosted Silver, 256 GB), None)  (nan, None)  \
# 20  (OnePlus Nord 2 5G (Gray Sierra, 256 GB), None)  (4.1, None)
#
#               price                                             imgURL
# 23  (₹35,989, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 20  (₹29,992, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                           storage_ram
# 23              (Internal Storage256 GBRAM8 GB, None)  \
# 20  (Internal Storage256 GBRAM12 GBMemory Card Slo...
#
#                                                camera
# 23  (Primary Camera AvailableYesPrimary Camera48 M...  \
# 20  (Primary Camera50MP Rear CameraDual Camera Len...
#
#                                          oS_Processor
# 23  (Operating SystemAndroid Pie 10Processor TypeQ...  \
# 20  (Operating SystemAndroid 11Processor CoreDual ...
#
#                                               display
# 23  (Display Size16.64 cm (6.55 inch)Resolution240...  \
# 20  (Display Size16.33 cm (6.43 inch)Resolution108...
#
#                                               network
# 23  (Network Type4G, 3G, 2GSupported Networks4G LT...  \
# 20  (Network Type5GSupported Networks4G LTE, GSM, ...
#
#                                               battery
# 23  (Battery Capacity3800 mAhBattery Typelithium-i...
# 20                   (Battery Capacity4500 mAh, None)
# df : df shape : (144, 10)
#                                                   name      ratings
# 1   (OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB...  (4.4, None)  \
# 86        (OnePlus 10R 5G (Prime Blue, 128 GB), None)  (4.3, None)
#
#               price                                             imgURL
# 1   (₹17,882, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 86  (₹30,999, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                           storage_ram
# 1   (Internal Storage128 GBRAM6 GBMemory Card Slot...  \
# 86              (Internal Storage128 GBRAM8 GB, None)
#
#                                                camera
# 1              (Primary Camera64MP Rear Camera, None)  \
# 86  (Primary Camera AvailableYesPrimary Camera48MP...
#
#                                          oS_Processor
# 1   (Operating SystemAndroid 13Processor CoreOcta ...  \
# 86          (Operating SystemAndroid Oxygen 12, None)
#
#                                               display
# 1   (Display Size16.74 cm (6.59 inch)Resolution241...  \
# 86  (Display Size17.02 cm (6.7 inch)Resolution2400...
#
#                                               network
# 1          (Network Type5GSupported Networks5G, None)  \
# 86  (Network Type4G VOLTE, 4GSupported Networks4G ...
#
#                              battery
# 1   (Battery Capacity5000 mAh, None)
# 86  (Battery Capacity5000 mAh, None)
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:7
# working in https://www.flipkart.com/search?q=one+plus+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=7 Page
# page df : page_shape : (24, 10)
#                                                  name      ratings
# 22  (OnePlus Nord CE 3 Lite 5G (Lime, 256 GB), None)  (nan, None)  \
# 1        (OnePlus 9 5G (Astral Black, 256 GB), None)    (4, None)
#
#               price                                             imgURL
# 22  (₹21,999, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 1   (₹39,680, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                           storage_ram
# 22  (Internal Storage256 GBRAM8 GBMemory Card Slot...  \
# 1              (Internal Storage256 GBRAM12 GB, None)
#
#                                                camera
# 22  (Primary Camera108MP Rear CameraDual Camera Le...  \
# 1              (Primary Camera48MP Rear Camera, None)
#
#                                          oS_Processor
# 22  (Operating SystemAndroid Oxygen 12Processor Co...  \
# 1   (Operating SystemAndroid 11Processor CoreDual ...
#
#                                               display
# 22  (Display Size17.07 cm (6.72 inch)Resolution108...  \
# 1   (Display Size16.81 cm (6.62 inch)Resolution240...
#
#                                               network
# 22         (Network Type5GSupported Networks5G, None)  \
# 1   (Network Type5GSupported Networks4G LTE, 5G, C...
#
#                              battery
# 22  (Battery Capacity5000 mAh, None)
# 1   (Battery Capacity4500 mAh, None)
# df : df shape : (168, 10)
#                                              name      ratings
# 5   (OnePlus 11R 5G (Sonic Black, 256 GB), None)  (4.5, None)  \
# 17    (OnePlus 10R (Forest Green, 256 GB), None)  (4.1, None)
#
#               price                                             imgURL
# 5   (₹44,729, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 17  (₹37,978, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                           storage_ram
# 5              (Internal Storage256 GBRAM16 GB, None)  \
# 17  (Internal Storage256 GBRAM12 GBMemory Card Slo...
#
#                                                camera
# 5   (Primary Camera50MP Rear CameraDual Camera Len...  \
# 17             (Primary Camera50MP Rear Camera, None)
#
#                                          oS_Processor
# 5   (Operating SystemAndroid Oxygen OxygenOS based...  \
# 17  (Operating SystemAndroid 12Processor CoreOcta ...
#
#                                               display
# 5   (Display Size17.02 cm (6.7 inch)Resolution2772...  \
# 17  (Display Size17.02 cm (6.7 inch)Resolution2400...
#
#                                        network
# 5   (Network Type5GSupported Networks5G, None)  \
# 17  (Network Type5GSupported Networks5G, None)
#
#                              battery
# 5   (Battery Capacity5000 mAh, None)
# 17  (Battery Capacity5000 mAh, None)
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:8
# working in https://www.flipkart.com/search?q=one+plus+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=8 Page
# page df : page_shape : (24, 10)
#                                                   name      ratings
# 14  (OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 12...  (3.9, None)  \
# 17          (OnePlus 9R 5G (Lake Blue, 256 GB), None)  (4.3, None)
#
#               price                                             imgURL
# 14  (₹19,999, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 17  (₹43,500, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                           storage_ram
# 14  (Internal Storage128 GBRAM8 GBMemory Card Slot...  \
# 17             (Internal Storage256 GBRAM12 GB, None)
#
#                                                camera
# 14  (Primary Camera108MP Rear CameraDual Camera Le...  \
# 17  (Primary Camera48MP Rear CameraDual Camera Len...
#
#                                          oS_Processor
# 14  (Operating SystemAndroid 13Processor CoreOcta ...  \
# 17  (Operating SystemAndroid Q 11Processor CoreDua...
#
#                                               display
# 14  (Display Size17.07 cm (6.72 inch)Resolution240...  \
# 17  (Display Size16.64 cm (6.55 inch)Resolution240...
#
#                                               network
# 14         (Network Type5GSupported Networks5G, None)  \
# 17  (Network Type5GSupported Networks4G LTE, GSM, ...
#
#                              battery
# 14  (Battery Capacity5000 mAh, None)
# 17  (Battery Capacity4500 mAh, None)
# df : df shape : (192, 10)
#                                                   name      ratings
# 87   (OnePlus 8 Pro (Ultramarine Blue, 256 GB), None)  (4.3, None)  \
# 145       (OnePlus 9 5G (Astral Black, 256 GB), None)    (4, None)
#
#                price                                             imgURL
# 87   (₹43,990, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 145  (₹39,680, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                            storage_ram
# 87   (Internal Storage256 GBRAM12 GBMemory Card Slo...  \
# 145             (Internal Storage256 GBRAM12 GB, None)
#
#                                                 camera
# 87   (Primary Camera50MP Rear CameraDual Camera Len...  \
# 145             (Primary Camera48MP Rear Camera, None)
#
#                                           oS_Processor
# 87   (Operating SystemAndroid Oreo 10Processor Type...  \
# 145  (Operating SystemAndroid 11Processor CoreDual ...
#
#                                                display
# 87   (Display Size17.22 cm (6.78 inch)Resolution316...  \
# 145  (Display Size16.81 cm (6.62 inch)Resolution240...
#
#                                                network
# 87   (Network Type5G, 4G VOLTESupported Networks5G,...  \
# 145  (Network Type5GSupported Networks4G LTE, 5G, C...
#
#                                                battery
# 87   (Battery Capacity4510 mAhBattery Typelithium-i...
# 145                   (Battery Capacity4500 mAh, None)
#
# Length of mob_names: 19
# Length of mob_ratings: 19
# Length of mob_price: 19
# Length of mob_img_URL: 19
# Length of storage_ram: 19
# Length of os_processor: 19
# Length of camera: 19
# Length of display: 19
# Length of network: 19
# Length of battery: 19
# scraping data from page:9
# working in https://www.flipkart.com/search?q=one+plus+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=9 Page
# page df : page_shape : (19, 10)
#                                             name      ratings            price
# 5    (OnePlus 10R (Sierra Black, 128 GB), None)  (4.3, None)  (₹29,999, None)  \
# 11  (OnePlus 10T 5G (Jade Green, 128 GB), None)  (4.3, None)  (₹49,800, None)
#
#                                                imgURL
# 5   (https://rukminim2.flixcart.com/image/312/312/...  \
# 11  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                           storage_ram
# 5   (Internal Storage128 GBRAM8 GBMemory Card Slot...  \
# 11  (Internal Storage128 GBRAM8 GBMemory Card Slot...
#
#                                     camera
# 5   (Primary Camera50MP Rear Camera, None)  \
# 11  (Primary Camera50MP Rear Camera, None)
#
#                                          oS_Processor
# 5   (Operating SystemAndroid 12Processor CoreOcta ...  \
# 11  (Operating SystemAndroid 12Processor CoreOcta ...
#
#                                               display
# 5   (Display Size17.02 cm (6.7 inch)Resolution2400...  \
# 11  (Display Size17.02 cm (6.7 inch)Resolution2412...
#
#                                        network
# 5   (Network Type5GSupported Networks5G, None)  \
# 11  (Network Type5GSupported Networks5G, None)
#
#                              battery
# 5   (Battery Capacity5000 mAh, None)
# 11  (Battery Capacity4800 mAh, None)
# df : df shape : (211, 10)
#                                                  name      ratings
# 19  (OnePlus 8T 5G (Aquamarine Green, 256 GB), None)  (3.3, None)  \
# 46   (OnePlus 9 Pro 5G (Morning Mist, 128 GB), None)  (4.2, None)
#
#               price                                             imgURL
# 19  (₹34,999, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 46  (₹49,499, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                storage_ram
# 19  (Internal Storage256 GBRAM12 GB, None)  \
# 46   (Internal Storage128 GBRAM8 GB, None)
#
#                                                camera
# 19  (Primary Camera48MP Rear CameraDual Camera Len...  \
# 46  (Primary Camera48MP Rear CameraDual Camera Len...
#
#                                          oS_Processor
# 19  (Operating SystemAndroid Q 11Processor CoreDua...  \
# 46  (Operating SystemAndroid Q 11Processor CoreDua...
#
#                                               display
# 19  (Display Size16.64 cm (6.55 inch)Resolution240...  \
# 46  (Display Size17.02 cm (6.7 inch)Resolution3216...
#
#                                               network
# 19  (Network Type5GSupported Networks4G LTE, 5G, C...  \
# 46  (Network Type5GSupported Networks4G LTE, GSM, ...
#
#                              battery
# 19  (Battery Capacity4500 mAh, None)
# 46  (Battery Capacity4500 mAh, None)
#
# Length of mob_names: 0
# Length of mob_ratings: 0
# Length of mob_price: 0
# Length of mob_img_URL: 0
# Length of storage_ram: 0
# Length of os_processor: 0
# Length of camera: 0
# Length of display: 0
# Length of network: 0
# Length of battery: 0
# Length of mob_names: 0
# Length of mob_ratings: 0
# Length of mob_price: 0
# Length of mob_img_URL: 0
# Length of storage_ram: 0
# Length of os_processor: 0
# Length of camera: 0
# Length of display: 0
# Length of network: 0
# Length of battery: 0
# Length of mob_names: 0
# Length of mob_ratings: 0
# Length of mob_price: 0
# Length of mob_img_URL: 0
# Length of storage_ram: 0
# Length of os_processor: 0
# Length of camera: 0
# Length of display: 0
# Length of network: 0
# Length of battery: 0
# Length of mob_names: 0
# Length of mob_ratings: 0
# Length of mob_price: 0
# Length of mob_img_URL: 0
# Length of storage_ram: 0
# Length of os_processor: 0
# Length of camera: 0
# Length of display: 0
# Length of network: 0
# Length of battery: 0
# Length of mob_names: 0
# Length of mob_ratings: 0
# Length of mob_price: 0
# Length of mob_img_URL: 0
# Length of storage_ram: 0
# Length of os_processor: 0
# Length of camera: 0
# Length of display: 0
# Length of network: 0
# Length of battery: 0
# Length of mob_names: 0
# Length of mob_ratings: 0
# Length of mob_price: 0
# Length of mob_img_URL: 0
# Length of storage_ram: 0
# Length of os_processor: 0
# Length of camera: 0
# Length of display: 0
# Length of network: 0
# Length of battery: 0
# Length of mob_names: 0
# Length of mob_ratings: 0
# Length of mob_price: 0
# Length of mob_img_URL: 0
# Length of storage_ram: 0
# Length of os_processor: 0
# Length of camera: 0
# Length of display: 0
# Length of network: 0
# Length of battery: 0
# Length of mob_names: 0
# Length of mob_ratings: 0
# Length of mob_price: 0
# Length of mob_img_URL: 0
# Length of storage_ram: 0
# Length of os_processor: 0
# Length of camera: 0
# Length of display: 0
# Length of network: 0
# Length of battery: 0

# %%
df
# Out:
#                                                   name      ratings
# 0    (OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)...  (4.4, None)  \
# 1    (OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB...  (4.4, None)
# 2         (OnePlus 11R 5G (Sonic Black, 128 GB), None)  (4.5, None)
# 3     (OnePlus Nord 2T 5G (Gray Shadow, 128 GB), None)  (4.4, None)
# 4     (OnePlus 11R 5G (Galactic Silver, 128 GB), None)  (4.5, None)
# ..                                                 ...          ...
# 206      (OnePlus 11 5G (Eternal Green, 128 GB), None)  (4.4, None)
# 207      (OnePlus 10R 5G (Sierra Black, 256 GB), None)  (4.2, None)
# 208        (OnePlus 3T (Midnight Black, 128 GB), None)  (4.2, None)
# 209  (OnePlus 10 Pro 5G (Emerald Forest, 128 GB), N...  (nan, None)
# 210      (OnePlus Nord 2 5G (Blue Haze, 128 GB), None)  (nan, None)
#
#                price                                             imgURL
# 0    (₹17,955, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 1    (₹17,882, None)  (https://rukminim2.flixcart.com/image/312/312/...
# 2    (₹39,594, None)  (https://rukminim2.flixcart.com/image/312/312/...
# 3    (₹28,729, None)  (https://rukminim2.flixcart.com/image/312/312/...
# 4    (₹39,843, None)  (https://rukminim2.flixcart.com/image/312/312/...
# ..               ...                                                ...
# 206  (₹51,810, None)  (https://rukminim2.flixcart.com/image/312/312/...
# 207  (₹36,990, None)  (https://rukminim2.flixcart.com/image/312/312/...
# 208   (₹9,999, None)  (https://rukminim2.flixcart.com/image/312/312/...
# 209  (₹49,999, None)  (https://rukminim2.flixcart.com/image/312/312/...
# 210  (₹26,999, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                            storage_ram
# 0    (Internal Storage128 GBRAM6 GBMemory Card Slot...  \
# 1    (Internal Storage128 GBRAM6 GBMemory Card Slot...
# 2                (Internal Storage128 GBRAM8 GB, None)
# 3    (Internal Storage128 GBRAM8 GBMemory Card Slot...
# 4                (Internal Storage128 GBRAM8 GB, None)
# ..                                                 ...
# 206  (Internal Storage128 GBRAM8 GBMemory Card Slot...
# 207             (Internal Storage256 GBRAM12 GB, None)
# 208  (Internal Storage128 GBRAM6 GBMemory Card Slot...
# 209  (Internal Storage128 GBRAM8 GBMemory Card Slot...
# 210  (Internal Storage128 GBRAM6 GBMemory Card Slot...
#
#                                                 camera
# 0               (Primary Camera64MP Rear Camera, None)  \
# 1               (Primary Camera64MP Rear Camera, None)
# 2    (Primary Camera50MP Rear CameraDual Camera Len...
# 3               (Primary Camera50MP Rear Camera, None)
# 4    (Primary Camera50MP Rear CameraDual Camera Len...
# ..                                                 ...
# 206  (Primary Camera50MP Rear CameraDual Camera Len...
# 207             (Primary Camera50MP Rear Camera, None)
# 208  (Primary Camera16MP Rear CameraSecondary Camer...
# 209             (Primary Camera48MP Rear Camera, None)
# 210  (Primary Camera AvailableYesPrimary Camera50MP...
#
#                                           oS_Processor
# 0    (Operating SystemAndroid 10Processor CoreOcta ...  \
# 1    (Operating SystemAndroid 13Processor CoreOcta ...
# 2    (Operating SystemAndroid Oxygen OxygenOS based...
# 3    (Operating SystemAndroid 13Processor CoreOcta ...
# 4    (Operating SystemAndroid OxygenOS based on And...
# ..                                                 ...
# 206  (Operating SystemAndroid OxygenOS based on And...
# 207  (Operating SystemAndroid 12Primary Clock Speed...
# 208  (Operating SystemAndroid Marshmallow 6Processo...
# 209  (Operating SystemAndroid 12Processor CoreDual ...
# 210  (Operating SystemAndroid Oxygen 11Processor Co...
#
#                                                display
# 0    (Display Size16.74 cm (6.59 inch)Resolution241...  \
# 1    (Display Size16.74 cm (6.59 inch)Resolution241...
# 2    (Display Size17.02 cm (6.7 inch)Resolution2772...
# 3    (Display Size17.02 cm (6.7 inch)Resolution2400...
# 4    (Display Size17.02 cm (6.7 inch)Resolution2772...
# ..                                                 ...
# 206  (Display Size17.02 cm (6.7 inch)Resolution3216...
# 207  (Display Size17.02 cm (6.7 inch)Resolution1080...
# 208  (Display Size13.97 cm (5.5 inch)Resolution1920...
# 209  (Display Size17.02 cm (6.7 inch)Resolution3216...
# 210  (Display Size16.33 cm (6.43 inch)Resolution108...
#
#                                                network
# 0           (Network Type5GSupported Networks5G, None)  \
# 1           (Network Type5GSupported Networks5G, None)
# 2           (Network Type5GSupported Networks5G, None)
# 3           (Network Type5GSupported Networks5G, None)
# 4           (Network Type5GSupported Networks5G, None)
# ..                                                 ...
# 206         (Network Type5GSupported Networks5G, None)
# 207  (Network Type5GSupported Networks5G, 4G VoLTE,...
# 208     (Network Type4GSupported Networks4G LTE, None)
# 209  (Network Type5GSupported Networks5G, 4G VoLTE,...
# 210  (Network Type5GSupported Networks5G, 4G VoLTE,...
#
#                                                battery
# 0                     (Battery Capacity5000 mAh, None)
# 1                     (Battery Capacity5000 mAh, None)
# 2                     (Battery Capacity5000 mAh, None)
# 3                     (Battery Capacity4500 mAh, None)
# 4                     (Battery Capacity5000 mAh, None)
# ..                                                 ...
# 206                   (Battery Capacity5000 mAh, None)
# 207                   (Battery Capacity5000 mAh, None)
# 208                   (Battery Capacity3400 mAh, None)
# 209                   (Battery Capacity5000 mAh, None)
# 210  (Battery Capacity4500 mAhBattery TypeLithium I...
#
# [211 rows x 10 columns]

# %%
print(os.getcwd())
print(os.chdir(r'd:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem'))
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem
# None
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem

# %%
df.to_csv(path_or_buf=r'data\raw_data\onePlus_mobile_data.csv')

# %% [markdown]
# ## Realme Mobiles

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import os
import numpy as np
from itertools import zip_longest

# %%
def bs4_soup(pages):
    URL = f'https://www.flipkart.com/search?q=realme+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={pages}'
    request = requests.get(URL)
    soup = bs(request.text,'html.parser')
    soup = soup.find('div',class_ = '_1YokD2 _3Mn1Gg')

    return soup , URL

# %%
def mob_specs(soup):
    names = soup.find_all('div', class_='_4rR01T')
    mob_names_list = [i.text if i else None for i in names]

    ratings = soup.find_all('div', class_='_3LWZlK')
    mob_ratings = [i.text if i else None for i in ratings]

    price = soup.find_all('div', class_='_30jeq3 _1_WHN1')
    mob_price = [i.text if i else None for i in price]

    img = soup.find_all('div', class_='CXW8mj')
    mob_img_URL = [i.find('img')['src'] if i.find('img') else None for i in img]

    # Find the maximum length among all lists
    max_length = max(len(mob_names_list), len(mob_ratings), len(mob_price), len(mob_img_URL))

    # Use zip_longest to ensure all lists have the same length
    mob_names = list(zip_longest(mob_names_list, [None] * max_length,fillvalue=np.nan))
    mob_ratings = list(zip_longest(mob_ratings, [None] * max_length,fillvalue=np.nan))
    mob_price = list(zip_longest(mob_price, [None] * max_length,fillvalue=np.nan))
    mob_img_URL = list(zip_longest(mob_img_URL, [None] * max_length,fillvalue=np.nan))

    return mob_names, mob_ratings, mob_price, mob_img_URL

# %%
import pandas as pd
from itertools import zip_longest

def features_from_mob_links(soup):
    mobile_links = ['https://www.flipkart.com' + i['href'] for i in soup.find_all('a', class_='_1fQZEK')]
    mobile_req = [requests.get(url=i) for i in mobile_links]
    mobile_soup = [bs(i.text, 'html.parser').find('div', class_='_1YokD2 _2GoDe3') for i in mobile_req]
    mobile_specs_soup = [i.find_all('div', class_='_3k-BhJ') for i in mobile_soup]

    storage_ram = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Memory' in str(specs_.text) and 'Storage' in str(specs_.text)]
    os_processor = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Os' in str(specs_.text) and 'Processor' in str(specs_.text)]
    camera = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Camera' in str(specs_.text) and 'FeaturesPrimary' in str(specs_.text)]
    display = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Display' in str(specs_.text) and 'FeaturesDisplay' in str(specs_.text)]
    network = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Connectivity' in str(specs_.text) and 'FeaturesNetwork' in str(specs_.text)]
    battery = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Battery' in str(specs_.text) and 'FeaturesBattery' in str(specs_.text)]

    # Find the maximum length among all lists
    max_length = max(len(storage_ram), len(os_processor), len(camera), len(display), len(network), len(battery))

    # Use zip_longest to ensure all lists have the same length
    storage_ram = list(zip_longest(storage_ram, [None] * max_length,fillvalue=np.nan))
    os_processor = list(zip_longest(os_processor, [None] * max_length,fillvalue=np.nan))
    camera = list(zip_longest(camera, [None] * max_length,fillvalue=np.nan))
    display = list(zip_longest(display, [None] * max_length,fillvalue=np.nan))
    network = list(zip_longest(network, [None] * max_length,fillvalue=np.nan))
    battery = list(zip_longest(battery, [None] * max_length,fillvalue=np.nan))

    return mobile_specs_soup, storage_ram, os_processor, camera, display, network, battery

# %%
df = pd.DataFrame()

page_start = 1

for pages in range(page_start, 20):

    soup, URL = bs4_soup(pages=pages)
    mob_names, mob_ratings, mob_price, mob_img_URL = mob_specs(soup)
    mobile_specs_soup, storage_ram, os_processor, camera, display, network, battery = features_from_mob_links(soup=soup)


    if mobile_specs_soup is not None and soup is not None:
        
        print(f"Length of mob_names: {len(mob_names)}")
        print(f"Length of mob_ratings: {len(mob_ratings)}")
        print(f"Length of mob_price: {len(mob_price)}")
        print(f"Length of mob_img_URL: {len(mob_img_URL)}")
        print(f"Length of storage_ram: {len(storage_ram)}")
        print(f"Length of os_processor: {len(os_processor)}")
        print(f"Length of camera: {len(camera)}")
        print(f"Length of display: {len(display)}")
        print(f"Length of network: {len(network)}")
        print(f"Length of battery: {len(battery)}")

        names = [i for i in mob_names]
        ratings = [i for i in mob_ratings]
        price = [i for i in mob_price]
        imgURL = [i for i in mob_img_URL]
        storage_ram_ = [i for i in storage_ram]
        cam = [i for i in camera]
        os_pro = [i for i in os_processor]
        dis = [i for i in display]
        net = [i for i in network]
        bat = [i for i in battery]

        data_dict = {
            'name': names,
            'ratings': ratings,
            'price': price,
            'imgURL': imgURL,
            'storage_ram': storage_ram_,
            'camera': cam,     
            'oS_Processor': os_pro,    
            'display': dis,
            'network': net,     
            'battery': bat,    
        }

        page_df = pd.DataFrame(data=data_dict)

        if not page_df.empty:
            df = pd.concat(objs=[df, page_df], ignore_index=True)
            print(f'scraping data from page:{pages}')
            print(f'working in {URL} Page')
            print(f'page df : page_shape : {page_df.shape} \n {page_df.sample(2)}')
            print(f'df : df shape : {df.shape} \n {df.sample(2)}')
            print()

    else:
        print(f"Skipping page {pages} due to empty mobile_specs_soup or soup.")
# Out:
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:1
# working in https://www.flipkart.com/search?q=realme+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1 Page
# page df : page_shape : (24, 10)
#                                                name      ratings
# 8          (realme C30 (Denim Black, 32 GB), None)  (4.1, None)  \
# 21  (realme 10 Pro 5G (Nebula Blue, 128 GB), None)  (4.3, None)
#
#               price                                             imgURL
# 8    (₹6,499, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 21  (₹18,999, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                           storage_ram
# 8   (Internal Storage32 GBRAM3 GBExpandable Storag...  \
# 21  (Internal Storage128 GBRAM6 GBExpandable Stora...
#
#                                                camera
# 8   (Primary Camera AvailableYesPrimary Camera8MP ...  \
# 21  (Primary Camera AvailableYesPrimary Camera108M...
#
#                                          oS_Processor
# 8   (Operating SystemAndroid 11Processor TypeUniso...  \
# 21  (Operating SystemAndroid 13Processor TypeQualc...
#
#                                               display
# 8   (Display Size16.51 cm (6.5 inch)Resolution1600...  \
# 21  (Display Size17.07 cm (6.72 inch)Resolution240...
#
#                                               network
# 8   (Network Type4G VOLTE, 4G, 3G, 2GSupported Net...  \
# 21  (Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported...
#
#                              battery
# 8   (Battery Capacity5000 mAh, None)
# 21  (Battery Capacity5000 mAh, None)
# df : df shape : (24, 10)
#                                               name      ratings
# 19  (realme 10 Pro 5G (Hyperspace, 128 GB), None)  (4.3, None)  \
# 7          (realme C55 (Rainforest, 64 GB), None)  (4.4, None)
#
#               price                                             imgURL
# 19  (₹19,999, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 7   (₹10,999, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                           storage_ram
# 19  (Internal Storage128 GBRAM8 GBExpandable Stora...  \
# 7   (Internal Storage64 GBRAM4 GBExpandable Storag...
#
#                                                camera
# 19  (Primary Camera AvailableYesPrimary Camera108M...  \
# 7   (Primary Camera AvailableYesPrimary Camera64MP...
#
#                                          oS_Processor
# 19  (Operating SystemAndroid 13Processor TypeQualc...  \
# 7   (Operating SystemAndroid 13Processor TypeHelio...
#
#                                               display
# 19  (Display Size17.07 cm (6.72 inch)Resolution240...  \
# 7   (Display Size17.07 cm (6.72 inch)Resolution240...
#
#                                               network
# 19  (Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported...  \
# 7   (Network Type2G, 3G, 4GSupported Networks4G LT...
#
#                              battery
# 19  (Battery Capacity5000 mAh, None)
# 7   (Battery Capacity5000 mAh, None)
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:2
# working in https://www.flipkart.com/search?q=realme+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2 Page
# page df : page_shape : (24, 10)
#                                                 name      ratings
# 19  (realme 10 Pro+ 5G (Dark Matter, 128 GB), None)  (4.4, None)  \
# 5        (realme 9i 5G (Soulful Blue, 64 GB), None)  (4.5, None)
#
#               price                                             imgURL
# 19  (₹25,999, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 5   (₹14,999, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                           storage_ram
# 19              (Internal Storage128 GBRAM8 GB, None)  \
# 5   (Internal Storage64 GBRAM4 GBExpandable Storag...
#
#                                                camera
# 19  (Primary Camera AvailableYesPrimary Camera108M...  \
# 5   (Primary Camera AvailableYesPrimary Camera50MP...
#
#                                          oS_Processor
# 19  (Operating SystemAndroid 13Processor TypeMedia...  \
# 5   (Operating SystemAndroid 12Processor TypeMedia...
#
#                                               display
# 19  (Display Size17.02 cm (6.7 inch)Resolution2412...  \
# 5   (Display Size16.76 cm (6.6 inch)Resolution2408...
#
#                                               network
# 19  (Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported...  \
# 5   (Network Type5G, 4G, 3G, 2GSupported Networks5...
#
#                              battery
# 19  (Battery Capacity5000 mAh, None)
# 5   (Battery Capacity5000 mAh, None)
# df : df shape : (48, 10)
#                                                 name      ratings
# 47  (realme 10 Pro+ 5G (Dark Matter, 128 GB), None)  (4.4, None)  \
# 45         (realme C30s (Stripe Blue, 32 GB), None)  (4.4, None)
#
#               price                                             imgURL
# 47  (₹24,999, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 45   (₹6,999, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                           storage_ram
# 47              (Internal Storage128 GBRAM6 GB, None)  \
# 45  (Internal Storage32 GBRAM2 GBExpandable Storag...
#
#                                                camera
# 47  (Primary Camera AvailableYesPrimary Camera108M...  \
# 45  (Primary Camera AvailableYesPrimary Camera8MP ...
#
#                                          oS_Processor
# 47  (Operating SystemAndroid 13Processor TypeMedia...  \
# 45  (Operating SystemAndroid 12Processor TypeUniso...
#
#                                               display
# 47  (Display Size17.02 cm (6.7 inch)Resolution2412...  \
# 45  (Display Size16.51 cm (6.5 inch)Resolution1600...
#
#                                               network
# 47  (Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported...  \
# 45  (Network Type4G VOLTE, 4G, 3G, 2GSupported Net...
#
#                              battery
# 47  (Battery Capacity5000 mAh, None)
# 45  (Battery Capacity5000 mAh, None)
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:3
# working in https://www.flipkart.com/search?q=realme+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3 Page
# page df : page_shape : (24, 10)
#                                                name      ratings
# 4   (realme Narzo 50i (Carbon Black, 32 GB), None)  (4.5, None)  \
# 14           (realme C33 (Night Sea, 32 GB), None)  (4.4, None)
#
#              price                                             imgURL
# 4   (₹7,059, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 14  (₹8,999, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                           storage_ram
# 4   (Internal Storage32 GBRAM2 GBExpandable Storag...  \
# 14  (Internal Storage32 GBRAM3 GBExpandable Storag...
#
#                                                camera
# 4   (Primary Camera AvailableYesPrimary Camera8MP ...  \
# 14  (Primary Camera AvailableYesPrimary Camera50MP...
#
#                                          oS_Processor
# 4   (Operating SystemAndroid 11Processor TypeSC986...  \
# 14  (Operating SystemAndroid 12Processor TypeUniso...
#
#                                               display
# 4   (Display Size16.51 cm (6.5 inch)Resolution1600...  \
# 14  (Display Size16.51 cm (6.5 inch)Resolution1600...
#
#                                               network
# 4   (Network Type4G VOLTE, 4G, 3G, 2GSupported Net...  \
# 14  (Network Type4G VOLTE, 4G, 3G, 2GSupported Net...
#
#                              battery
# 4   (Battery Capacity5000 mAh, None)
# 14  (Battery Capacity5000 mAh, None)
# df : df shape : (72, 10)
#                                              name      ratings
# 29    (realme 9i 5G (Soulful Blue, 64 GB), None)  (4.5, None)  \
# 49  (realme Narzo 50i (Mint Green, 32 GB), None)  (4.5, None)
#
#               price                                             imgURL
# 29  (₹14,999, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 49   (₹7,324, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                           storage_ram
# 29  (Internal Storage64 GBRAM4 GBExpandable Storag...  \
# 49  (Internal Storage32 GBRAM2 GBExpandable Storag...
#
#                                                camera
# 29  (Primary Camera AvailableYesPrimary Camera50MP...  \
# 49  (Primary Camera AvailableYesPrimary Camera8MP ...
#
#                                          oS_Processor
# 29  (Operating SystemAndroid 12Processor TypeMedia...  \
# 49  (Operating SystemAndroid 11Processor TypeSC986...
#
#                                               display
# 29  (Display Size16.76 cm (6.6 inch)Resolution2408...  \
# 49  (Display Size16.51 cm (6.5 inch)Resolution1600...
#
#                                               network
# 29  (Network Type5G, 4G, 3G, 2GSupported Networks5...  \
# 49  (Network Type4G VOLTE, 4G, 3G, 2GSupported Net...
#
#                              battery
# 29  (Battery Capacity5000 mAh, None)
# 49  (Battery Capacity5000 mAh, None)
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 25
# Length of os_processor: 25
# Length of camera: 25
# Length of display: 25
# Length of network: 25
# Length of battery: 25
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 49
#      34 bat = [i for i in battery]
#      36 data_dict = {
#      37     'name': names,
#      38     'ratings': ratings,
#    (...)
#      46     'battery': bat,
#      47 }
# ---> 49 page_df = pd.DataFrame(data=data_dict)
#      51 if not page_df.empty:
#      52     df = pd.concat(objs=[df, page_df], ignore_index=True)
#
# File c:\Users\Gyanprakash\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:708, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     702     mgr = self._init_mgr(
#     703         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     704     )
#     706 elif isinstance(data, dict):
#     707     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 708     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     709 elif isinstance(data, ma.MaskedArray):
#     710     from numpy.ma import mrecords
#
# File c:\Users\Gyanprakash\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\construction.py:481, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     477     else:
#     478         # dtype check to exclude e.g. range objects, scalars
#     479         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 481 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\Gyanprakash\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\construction.py:115, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     112 if verify_integrity:
#     113     # figure out the index, if necessary
#     114     if index is None:
# --> 115         index = _extract_index(arrays)
#     116     else:
#     117         index = ensure_index(index)
#
# File c:\Users\Gyanprakash\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\construction.py:655, in _extract_index(data)
#     653 lengths = list(set(raw_lengths))
#     654 if len(lengths) > 1:
# --> 655     raise ValueError("All arrays must be of the same length")
#     657 if have_dicts:
#     658     raise ValueError(
#     659         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     660     )
#
# ValueError: All arrays must be of the same length

# %%
df
# Out:
#                                                name      ratings
# 0      (realme C33 2023 (Sandy Gold, 128 GB), None)  (4.4, None)  \
# 1       (realme C33 2023 (Aqua Blue, 128 GB), None)  (4.4, None)
# 2       (realme C33 2023 (Night Sea, 128 GB), None)  (4.4, None)
# 3           (realme C30 (Denim Black, 32 GB), None)  (4.2, None)
# 4          (realme C30 (Bamboo Green, 32 GB), None)  (4.1, None)
# ..                                              ...          ...
# 67     (realme Narzo N55 (Prime Blue, 64 GB), None)  (4.2, None)
# 68            (realme C33 (Aqua Blue, 64 GB), None)  (4.4, None)
# 69            (realme C33 (Night Sea, 64 GB), None)  (4.4, None)
# 70  (realme Narzo 50A (Oxygen Green, 128 GB), None)  (4.4, None)
# 71    (realme Narzo 50A (Oxygen Blue, 64 GB), None)  (4.4, None)
#
#               price                                             imgURL
# 0   (₹10,499, None)  (https://rukminim2.flixcart.com/image/312/312/...  \
# 1   (₹10,499, None)  (https://rukminim2.flixcart.com/image/312/312/...
# 2   (₹10,499, None)  (https://rukminim2.flixcart.com/image/312/312/...
# 3    (₹5,999, None)  (https://rukminim2.flixcart.com/image/312/312/...
# 4    (₹6,499, None)  (https://rukminim2.flixcart.com/image/312/312/...
# ..              ...                                                ...
# 67  (₹12,899, None)  (https://rukminim2.flixcart.com/image/312/312/...
# 68   (₹9,999, None)  (https://rukminim2.flixcart.com/image/312/312/...
# 69   (₹9,999, None)  (https://rukminim2.flixcart.com/image/312/312/...
# 70  (₹11,538, None)  (https://rukminim2.flixcart.com/image/312/312/...
# 71  (₹11,999, None)  (https://rukminim2.flixcart.com/image/312/312/...
#
#                                           storage_ram
# 0   (Internal Storage128 GBRAM4 GBExpandable Stora...  \
# 1   (Internal Storage128 GBRAM4 GBExpandable Stora...
# 2   (Internal Storage128 GBRAM4 GBExpandable Stora...
# 3   (Internal Storage32 GBRAM2 GBExpandable Storag...
# 4   (Internal Storage32 GBRAM3 GBExpandable Storag...
# ..                                                ...
# 67               (Internal Storage64 GBRAM4 GB, None)
# 68  (Internal Storage64 GBRAM4 GBExpandable Storag...
# 69  (Internal Storage64 GBRAM4 GBExpandable Storag...
# 70  (Internal Storage128 GBRAM4 GBExpandable Stora...
# 71  (Internal Storage64 GBRAM4 GBExpandable Storag...
#
#                                                camera
# 0   (Primary Camera AvailableYesPrimary Camera50MP...  \
# 1   (Primary Camera AvailableYesPrimary Camera50MP...
# 2   (Primary Camera AvailableYesPrimary Camera50MP...
# 3   (Primary Camera AvailableYesPrimary Camera8MP ...
# 4   (Primary Camera AvailableYesPrimary Camera8MP ...
# ..                                                ...
# 67  (Primary Camera64MP Rear CameraDual Camera Len...
# 68  (Primary Camera AvailableYesPrimary Camera50MP...
# 69  (Primary Camera AvailableYesPrimary Camera50MP...
# 70  (Primary Camera AvailableYesPrimary Camera50MP...
# 71  (Primary Camera AvailableYesPrimary Camera50MP...
#
#                                          oS_Processor
# 0   (Operating SystemAndroid 12Processor TypeUniso...  \
# 1   (Operating SystemAndroid 12Processor TypeUniso...
# 2   (Operating SystemAndroid 12Processor TypeUniso...
# 3   (Operating SystemAndroid 11Processor TypeUniso...
# 4   (Operating SystemAndroid 11Processor TypeUniso...
# ..                                                ...
# 67  (Operating SystemAndroid 13Processor CoreOcta ...
# 68  (Operating SystemAndroid 12Processor TypeUniso...
# 69  (Operating SystemAndroid 12Processor TypeUniso...
# 70  (Operating SystemAndroid 11Processor TypeMedia...
# 71  (Operating SystemAndroid 11Processor TypeMedia...
#
#                                               display
# 0   (Display Size16.51 cm (6.5 inch)Resolution1600...  \
# 1   (Display Size16.51 cm (6.5 inch)Resolution1600...
# 2   (Display Size16.51 cm (6.5 inch)Resolution1600...
# 3   (Display Size16.51 cm (6.5 inch)Resolution1600...
# 4   (Display Size16.51 cm (6.5 inch)Resolution1600...
# ..                                                ...
# 67  (Display Size17.07 cm (6.72 inch)Resolution108...
# 68  (Display Size16.51 cm (6.5 inch)Resolution1600...
# 69  (Display Size16.51 cm (6.5 inch)Resolution1600...
# 70  (Display Size16.51 cm (6.5 inch)Resolution1600...
# 71  (Display Size16.51 cm (6.5 inch)Resolution1600...
#
#                                               network
# 0   (Network Type4G VOLTE, 4G, 3G, 2GSupported Net...  \
# 1   (Network Type4G VOLTE, 4G, 3G, 2GSupported Net...
# 2   (Network Type4G VOLTE, 4G, 3G, 2GSupported Net...
# 3   (Network Type4G VOLTE, 4G, 3G, 2GSupported Net...
# 4   (Network Type4G VOLTE, 4G, 3G, 2GSupported Net...
# ..                                                ...
# 67  (Network Type4G VOLTESupported Networks4G VoLT...
# 68  (Network Type4G VOLTE, 4G, 3G, 2GSupported Net...
# 69  (Network Type4G VOLTE, 4G, 3G, 2GSupported Net...
# 70  (Network Type4G VOLTE, 4G, 3G, 2GSupported Net...
# 71  (Network Type4G VOLTE, 4G, 3G, 2GSupported Net...
#
#                              battery
# 0   (Battery Capacity5000 mAh, None)
# 1   (Battery Capacity5000 mAh, None)
# 2   (Battery Capacity5000 mAh, None)
# 3   (Battery Capacity5000 mAh, None)
# 4   (Battery Capacity5000 mAh, None)
# ..                               ...
# 67  (Battery Capacity5000 mAh, None)
# 68  (Battery Capacity5000 mAh, None)
# 69  (Battery Capacity5000 mAh, None)
# 70  (Battery Capacity6000 mAh, None)
# 71  (Battery Capacity6000 mAh, None)
#
# [72 rows x 10 columns]

# %%
print(os.getcwd())
os.chdir(r'd:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem')
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem\notebook\data_Ingestion\scraping
# None
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem
