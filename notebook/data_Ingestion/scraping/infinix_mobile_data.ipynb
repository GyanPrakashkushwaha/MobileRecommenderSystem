# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import os
import numpy as np
from itertools import zip_longest

# %%
def bs4_soup(pages):
    URL = f'https://www.flipkart.com/search?q=infinix+mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={pages}'
    request = requests.get(URL)
    soup = bs(request.text,'html.parser')
    soup = soup.find('div',class_ = '_1YokD2 _3Mn1Gg')

    return soup , URL

# %%
def mob_specs(soup):
    names = soup.find_all('div', class_='_4rR01T')
    mob_names = [i.text if i else None for i in names]

    ratings = soup.find_all('div', class_='_3LWZlK')
    mob_ratings = [i.text if i else None for i in ratings]

    price = soup.find_all('div', class_='_30jeq3 _1_WHN1')
    mob_price = [i.text if i else None for i in price]

    img = soup.find_all('div', class_='CXW8mj')
    mob_img_URL = [i.find('img')['src'] if i.find('img') else None for i in img]

    return mob_names, mob_ratings, mob_price, mob_img_URL

# %%
def features_from_mob_links(soup):
    mobile_links = ['https://www.flipkart.com' + i['href'] for i in soup.find_all('a', class_='_1fQZEK')]
    mobile_req = [requests.get(url=i) for i in mobile_links]
    mobile_soup = [bs(i.text, 'html.parser').find('div', class_='_1YokD2 _2GoDe3') for i in mobile_req]
    mobile_specs_soup = [i.find_all('div', class_='_3k-BhJ') for i in mobile_soup]

    storage_ram = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Memory' in str(specs_.text) and 'Storage' in str(specs_.text)]
    storage_ram_cross_checked = [i for i in storage_ram if 'Internal' in i.split()]

    os_processor = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Os' in str(specs_.text) and 'Processor' in str(specs_.text)]
    os_processor_cross_checked = [i for i in os_processor if 'Operating' in i.split()]

    camera = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Camera' in str(specs_.text) and 'FeaturesPrimary' in str(specs_.text)]
    camera_cross_checked = [i for i in camera if 'Primary' and 'Camera' in i.split()]

    display = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Display' in str(specs_.text) and 'FeaturesDisplay' in str(specs_.text)]
    display_cross_checked = [i for i in display if 'Display' and 'cm' in i.split()]

    network = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Connectivity' in str(specs_.text) and 'FeaturesNetwork' in str(specs_.text)]
    network_cross_checked = [i for i in network if 'Network' in i.split()]

    battery = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Battery' in str(specs_.text) and 'FeaturesBattery' in str(specs_.text)]
    battery_cross_checked = [i for i in battery if 'Battery' in i.split()]

    return mobile_specs_soup, storage_ram_cross_checked, os_processor_cross_checked, camera_cross_checked, display_cross_checked, network_cross_checked, battery_cross_checked

# %%
def fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery):
    tuple_data = zip_longest(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery,fillvalue=np.nan)
    
    data = [i for i in tuple_data]
    return data

# %%
def print_len(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery):
    print(f"Length of mob_names: {len(mob_names)}")
    print(f"Length of mob_ratings: {len(mob_ratings)}")
    print(f"Length of mob_price: {len(mob_price)}")
    print(f"Length of mob_img_URL: {len(mob_img_URL)}")
    print(f"Length of storage_ram: {len(storage_ram)}")
    print(f"Length of os_processor: {len(os_processor)}")
    print(f"Length of camera: {len(camera)}")
    print(f"Length of display: {len(display)}")
    print(f"Length of network: {len(network)}")
    print(f"Length of battery: {len(battery)}")

# %%
df = pd.DataFrame()

page_start = 1
page_ends = 9

for pages in range(page_start, page_ends):

    soup, URL = bs4_soup(pages=pages)
    
    mob_names, mob_ratings, mob_price, mob_img_URL = mob_specs(soup)
    mobile_specs_soup, storage_ram, os_processor, camera, display, network, battery = features_from_mob_links(soup=soup)
    
    data = fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)

    if mobile_specs_soup is not None and soup is not None:
        
        print_len(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)

        page_df = pd.DataFrame(data=data,columns=['name', 'ratings', 'price', 'imgURL', 'storage_ram', 'camera',
       'oS_Processor', 'display', 'network', 'battery'])

        if not page_df.empty:
            df = pd.concat(objs=[df, page_df], ignore_index=True)
            print(f'scraping data from page:{pages}')
            print(f'working in {URL} Page')
            print(f'page df : page_shape : {page_df.shape} \n {page_df.sample(2)}')
            print(f'df : df shape : {df.shape} \n {df.sample(2)}')
            print()

    else:
        print(f"Skipping page {pages} due to empty mobile_specs_soup or soup.")
# Out:
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:1
# working in https://www.flipkart.com/search?q=infinix+mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1 Page
# page df : page_shape : (24, 10)
#                                        name ratings   price
# 11    Infinix SMART 7 (Night Black, 64 GB)     4.3  ₹7,299  \
# 4   Infinix HOT 30i (Diamond White, 64 GB)     4.3  ₹7,999
#
#                                                imgURL
# 11  https://rukminim2.flixcart.com/image/312/312/x...  \
# 4   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 11  Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 4   Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                                camera
# 11  Operating SystemAndroid 12Processor TypeUnisoc...  \
# 4   Operating SystemAndroid 12Processor TypeG37Pro...
#
#                                          oS_Processor
# 11  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 4   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 11  Display Size16.76 cm (6.6 inch)Resolution1612 ...  \
# 4   Display Size16.76 cm (6.6 inch)Resolution1612 ...
#
#                                               network
# 11  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 4   Network Type2G, 3G, 4GSupported Networks4G LTE...
#
#                                               battery
# 11  Battery Capacity6000 mAhBattery TypeLithium-io...
# 4   Battery Capacity5000 mAhBattery TypeLithium-io...
# df : df shape : (24, 10)
#                                             name ratings   price
# 14  Infinix HOT 20 Play (Fantasy Purple, 64 GB)     4.4  ₹7,999  \
# 19        Infinix Smart 7 HD (Silk Blue, 64 GB)     4.3  ₹6,199
#
#                                                imgURL
# 14  https://rukminim2.flixcart.com/image/312/312/x...  \
# 19  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 14  Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 19  Internal Storage64 GBRAM2 GBExpandable Storage...
#
#                                                camera
# 14  Operating SystemAndroid 12Processor TypeMediaT...  \
# 19  Operating SystemAndroid 12Processor TypeSpread...
#
#                                          oS_Processor
# 14  Primary Camera AvailableYesPrimary Camera13Mp ...  \
# 19  Primary Camera AvailableYesPrimary Camera8MP +...
#
#                                               display
# 14  Display Size17.32 cm (6.82 inch)Resolution720 ...  \
# 19  Display Size16.76 cm (6.6 inch)Resolution1612 ...
#
#                                               network
# 14  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 19  Network Type2G, 3G, 4GSupported Networks4G LTE...
#
#                                               battery
# 14                           Battery Capacity6000 mAh
# 19  Battery Capacity5000 mAhBattery TypeLithium Io...
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:2
# working in https://www.flipkart.com/search?q=infinix+mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2 Page
# page df : page_shape : (24, 10)
#                                         name ratings    price
# 14   Infinix Hot 20 5G (Space Blue, 128 GB)     4.1  ₹13,499  \
# 18  Infinix Zero 20 (Green Fantasy, 128 GB)     4.2  ₹15,999
#
#                                                imgURL
# 14  https://rukminim2.flixcart.com/image/312/312/x...  \
# 18  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 14  Internal Storage128 GBRAM6 GBExpandable Storag...  \
# 18  Internal Storage128 GBRAM8 GBExpandable Storag...
#
#                                                camera
# 14  Operating SystemAndroid 12Processor TypeDimens...  \
# 18  Operating SystemAndroid 12Processor TypeMediat...
#
#                                          oS_Processor
# 14  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 18  Primary Camera AvailableYesPrimary Camera108MP...
#
#                                               display
# 14  Display Size16.76 cm (6.6 inch)Resolution1080 ...  \
# 18  Display Size17.02 cm (6.7 inch)Resolution2400 ...
#
#                                               network
# 14  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 18  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 14  Battery Capacity5000 mAh
# 18  Battery Capacity4500 mAh
# df : df shape : (48, 10)
#                                              name ratings    price
# 47          Infinix Note 11s (Haze Green, 64 GB)     4.3  ₹13,999  \
# 16  Infinix Note 12 Pro 5G (Force Black, 128 GB)     4.1  ₹15,999
#
#                                                imgURL
# 47  https://rukminim2.flixcart.com/image/312/312/k...  \
# 16  https://rukminim2.flixcart.com/image/312/312/l...
#
#                                           storage_ram
# 47  Internal Storage64 GBRAM6 GBExpandable Storage...  \
# 16  Internal Storage128 GBRAM8 GBExpandable Storag...
#
#                                                camera
# 47  Operating SystemAndroid 11Processor TypeMediaT...  \
# 16  Operating SystemAndroid 12Processor TypeMediat...
#
#                                          oS_Processor
# 47  Primary Camera AvailableYesPrimary Camera50 MP...  \
# 16  Primary Camera AvailableYesPrimary Camera108MP...
#
#                                               display
# 47  Display Size17.65 cm (6.95 inch)Resolution2460...  \
# 16  Display Size17.02 cm (6.7 inch)Resolution2400 ...
#
#                                               network
# 47  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 16  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                      battery
# 47  Battery Capacity5000 mAh
# 16  Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:3
# working in https://www.flipkart.com/search?q=infinix+mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3 Page
# page df : page_shape : (24, 10)
#                                                   name ratings    price
# 0           Infinix HOT 12 Play (Racing Black, 64 GB)     4.3   ₹8,999  \
# 14  Infinix Zero 5G 2023 TURBO (Pearly White, 256 GB)       4  ₹16,999
#
#                                                imgURL
# 0   https://rukminim2.flixcart.com/image/312/312/l...  \
# 14  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 0   Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 14  Internal Storage256 GBRAM8 GBExpandable Storag...
#
#                                                camera
# 0   Operating SystemAndroid 11Processor TypeUnisoc...  \
# 14  Operating SystemAndroid 12Processor TypeMediat...
#
#                                          oS_Processor
# 0   Primary Camera AvailableYesPrimary Camera13MP ...  \
# 14  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 0   Display Size17.32 cm (6.82 inch)Resolution1640...  \
# 14  Display Size17.22 cm (6.78 inch)Resolution2460...
#
#                                               network
# 0   Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 14  Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...
#
#                      battery
# 0   Battery Capacity6000 mAh
# 14  Battery Capacity5000 mAh
# df : df shape : (72, 10)
#                                        name ratings   price
# 56  Infinix Hot 12 Pro (Halo White, 64 GB)     4.2  ₹9,999  \
# 58   Infinix Hot 11 (Emerald Green, 64 GB)     4.3  ₹9,999
#
#                                                imgURL
# 56  https://rukminim2.flixcart.com/image/312/312/x...  \
# 58  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 56  Internal Storage64 GBRAM6 GBExpandable Storage...  \
# 58  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                                camera
# 56  Operating SystemAndroid 12Processor TypeUnisoc...  \
# 58  Operating SystemAndroid 11Processor TypeMediaT...
#
#                                          oS_Processor
# 56  Primary Camera AvailableYesPrimary Camera50 MP...  \
# 58  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 56  Display Size16.76 cm (6.6 inch)Resolution1612 ...  \
# 58  Display Size16.76 cm (6.6 inch)Resolution2408 ...
#
#                                               network
# 56  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 58  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 56  Battery Capacity5000 mAh
# 58  Battery Capacity5200 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 22
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:4
# working in https://www.flipkart.com/search?q=infinix+mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4 Page
# page df : page_shape : (24, 10)
#                                            name ratings    price
# 22  Infinix Hot 10 Play (Morandi Green, 32 GB)     NaN   ₹8,990  \
# 2      Infinix Note 11 (Glacier Green, 128 GB)     4.2  ₹16,999
#
#                                                imgURL
# 22  https://rukminim2.flixcart.com/image/312/312/k...  \
# 2   https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 22  Internal Storage32 GBRAM3 GBExpandable Storage...  \
# 2   Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                                camera
# 22  Operating SystemAndroid 10Processor TypeMediaT...  \
# 2   Operating SystemAndroid 11Processor TypeMediat...
#
#                                          oS_Processor
# 22  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 2   Primary Camera AvailableYesPrimary Camera50 MP...
#
#                                               display
# 22  Display Size17.32 cm (6.82 inch)Resolution1640...  \
# 2   Display Size17.02 cm (6.7 inch)Resolution2400 ...
#
#                                               network
# 22  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 2   Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 22  Battery Capacity6000 mAh
# 2   Battery Capacity5000 mAh
# df : df shape : (96, 10)
#                                           name ratings   price
# 36          Infinix Hot 12 (7° Purple, 64 GB)     4.2  ₹8,999  \
# 55  Infinix Smart HD 2021 (Topaz Blue, 32 GB)     4.3  ₹6,499
#
#                                                imgURL
# 36  https://rukminim2.flixcart.com/image/312/312/x...  \
# 55  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 36  Internal Storage64 GBRAM4 GBSupported Memory C...  \
# 55  Internal Storage32 GBRAM2 GBExpandable Storage...
#
#                                                camera
# 36  Operating SystemAndroid 11Processor TypeMedite...  \
# 55  Operating SystemAndroid 10Processor TypeMediaT...
#
#                                          oS_Processor
# 36  Primary Camera AvailableYesPrimary Camera50 MP...  \
# 55  Primary Camera AvailableYesPrimary Camera8MP R...
#
#                                               display
# 36  Display Size17.32 cm (6.82 inch)Resolution1640...  \
# 55  Display Size15.49 cm (6.1 inch)Resolution1560 ...
#
#                                               network
# 36  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 55  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                      battery
# 36  Battery Capacity6000 mAh
# 55  Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:5
# working in https://www.flipkart.com/search?q=infinix+mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5 Page
# page df : page_shape : (24, 10)
#                                         name ratings    price
# 23  Infinix Smart 5 (Obsidian Black, 32 GB)     4.3   ₹7,499  \
# 22       Infinix Note 10 (7° Purple, 64 GB)     4.2  ₹10,999
#
#                                                imgURL
# 23  https://rukminim2.flixcart.com/image/312/312/k...  \
# 22  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 23  Internal Storage32 GBRAM2 GBExpandable Storage...  \
# 22  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                                camera
# 23  Operating SystemAndroid 10Processor TypeMediaT...  \
# 22  Operating SystemAndroid 11Processor TypeMediaT...
#
#                                          oS_Processor
# 23  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 22  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                               display
# 23  Display Size17.32 cm (6.82 inch)Resolution1640...  \
# 22  Display Size17.65 cm (6.95 inch)Resolution2460...
#
#                                               network
# 23  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 22  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 23  Battery Capacity6000 mAh
# 22  Battery Capacity5000 mAh
# df : df shape : (120, 10)
#                                           name ratings    price
# 67  Infinix Hot 12 Pro (Racing Black, 128 GB)       4  ₹12,999  \
# 74    Infinix Note 11 (Glacier Green, 128 GB)     4.2  ₹16,999
#
#                                                imgURL
# 67  https://rukminim2.flixcart.com/image/312/312/x...  \
# 74  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 67  Internal Storage128 GBRAM8 GBExpandable Storag...  \
# 74  Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                                camera
# 67  Operating SystemAndroid 12Processor TypeUnisoc...  \
# 74  Operating SystemAndroid 11Processor TypeMediat...
#
#                                          oS_Processor
# 67  Primary Camera AvailableYesPrimary Camera50 MP...  \
# 74  Primary Camera AvailableYesPrimary Camera50 MP...
#
#                                               display
# 67  Display Size16.76 cm (6.6 inch)Resolution1612 ...  \
# 74  Display Size17.02 cm (6.7 inch)Resolution2400 ...
#
#                                               network
# 67  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 74  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 67  Battery Capacity5000 mAh
# 74  Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:6
# working in https://www.flipkart.com/search?q=infinix+mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=6 Page
# page df : page_shape : (24, 10)
#                                                name ratings    price
# 16          Infinix Note 10 (Emerald Green, 64 GB)     4.2  ₹10,999  \
# 3   Infinix Note 30 5G (Interstellar Blue, 128 GB)     4.2  ₹14,999
#
#                                                imgURL
# 16  https://rukminim2.flixcart.com/image/312/312/k...  \
# 3   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 16  Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 3   Internal Storage128 GBRAM4 GBExpandable Storag...
#
#                                                camera
# 16  Operating SystemAndroid 11Processor TypeMediaT...  \
# 3   Operating SystemAndroid 13Processor TypeDimens...
#
#                                          oS_Processor
# 16  Primary Camera AvailableYesPrimary Camera48MP ...  \
# 3   Primary Camera AvailableYesPrimary Camera108 M...
#
#                                               display
# 16  Display Size17.65 cm (6.95 inch)Resolution2460...  \
# 3   Display Size17.22 cm (6.78 inch)Resolution2460...
#
#                                               network
# 16  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 3   Network Type2G, 3G, 4G, 5GSupported Networks4G...
#
#                      battery
# 16  Battery Capacity5000 mAh
# 3   Battery Capacity5000 mAh
# df : df shape : (144, 10)
#                                          name ratings    price
# 119  Infinix Smart 5 (Obsidian Black, 32 GB)     4.3   ₹7,499  \
# 100      Infinix Hot 11S (Green Wave, 64 GB)     4.3  ₹10,999
#
#                                                 imgURL
# 119  https://rukminim2.flixcart.com/image/312/312/k...  \
# 100  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 119  Internal Storage32 GBRAM2 GBExpandable Storage...  \
# 100  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                                 camera
# 119  Operating SystemAndroid 10Processor TypeMediaT...  \
# 100  Operating SystemAndroid 11Processor TypeMediaT...
#
#                                           oS_Processor
# 119  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 100  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                                display
# 119  Display Size17.32 cm (6.82 inch)Resolution1640...  \
# 100  Display Size17.22 cm (6.78 inch)Resolution2480...
#
#                                                network
# 119  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 100  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                       battery
# 119  Battery Capacity6000 mAh
# 100  Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:7
# working in https://www.flipkart.com/search?q=infinix+mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=7 Page
# page df : page_shape : (24, 10)
#                                              name ratings    price
# 19  Infinix Smart 6 Plus (Crystal Violet, 64 GB)     4.2   ₹8,299  \
# 3             Infinix Hot 10S (7° Purple, 64 GB)     4.3  ₹10,999
#
#                                                imgURL
# 19  https://rukminim2.flixcart.com/image/312/312/x...  \
# 3   https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 19  Internal Storage64 GBRAM3 GBExpandable Storage...  \
# 3   Internal Storage64 GBRAM6 GBExpandable Storage...
#
#                                                camera
# 19  Operating SystemAndroid 12 (Go Edition)Process...  \
# 3   Operating SystemAndroid 11Processor TypeMediaT...
#
#                                          oS_Processor
# 19  Primary Camera AvailableYesPrimary Camera8 MP ...  \
# 3   Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                               display
# 19  Display Size17.32 cm (6.82 inch)Resolution1600...  \
# 3   Display Size17.32 cm (6.82 inch)Resolution1640...
#
#                                               network
# 19  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 3   Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 19  Battery Capacity5000 mAh
# 3   Battery Capacity6000 mAh
# df : df shape : (168, 10)
#                                       name ratings    price
# 85  Infinix Hot 11S (Silver Wave, 128 GB)     4.3  ₹11,999  \
# 6   Infinix HOT 30i (Glacier Blue, 64 GB)     4.3   ₹7,999
#
#                                                imgURL
# 85  https://rukminim2.flixcart.com/image/312/312/k...  \
# 6   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 85  Internal Storage128 GBRAM4 GBExpandable Storag...  \
# 6   Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                                camera
# 85  Operating SystemAndroid 11Processor TypeMediat...  \
# 6   Operating SystemAndroid 12Processor TypeG37Pro...
#
#                                          oS_Processor
# 85  Primary Camera AvailableYesPrimary Camera50 MP...  \
# 6   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 85  Display Size17.22 cm (6.78 inch)Resolution2480...  \
# 6   Display Size16.76 cm (6.6 inch)Resolution1612 ...
#
#                                               network
# 85  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 6   Network Type2G, 3G, 4GSupported Networks4G LTE...
#
#                                               battery
# 85                           Battery Capacity5000 mAh
# 6   Battery Capacity5000 mAhBattery TypeLithium-io...
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:8
# working in https://www.flipkart.com/search?q=infinix+mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=8 Page
# page df : page_shape : (24, 10)
#                                       name ratings    price
# 9       Infinix Hot 8 (Shark Grey, 64 GB)     4.5   ₹8,999  \
# 6  Infinix Zero 5G (Cosmic Black, 128 GB)     4.2  ₹19,999
#
#                                               imgURL
# 9  https://rukminim2.flixcart.com/image/312/312/k...  \
# 6  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                          storage_ram
# 9  Internal Storage64 GBRAM4 GBMemory Card Slot T...  \
# 6  Internal Storage128 GBRAM8 GBExpandable Storag...
#
#                                               camera
# 9  Operating SystemAndroid Pie 9Processor TypeHel...  \
# 6  Operating SystemAndroid 11Processor TypeMediat...
#
#                                         oS_Processor
# 9  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 6  Primary Camera AvailableYesPrimary Camera48 MP...
#
#                                              display
# 9  Display Size16.56 cm (6.52 inch)Resolution720 ...  \
# 6  Display Size17.22 cm (6.78 inch)Resolution2460...
#
#                                              network                   battery
# 9  Network Type3G, 4G, 2GSupported NetworksGSM, W...  Battery Capacity5000 mAh
# 6  Network Type5G, 4G, 3G, 2GSupported Networks5G...  Battery Capacity5000 mAh
# df : df shape : (192, 10)
#                                           name ratings   price
# 3     Infinix HOT 30i (Diamond White, 128 GB)     4.3  ₹8,999  \
# 68  Infinix Hot 12 Pro (Electric Blue, 64 GB)     4.2  ₹9,999
#
#                                                imgURL
# 3   https://rukminim2.flixcart.com/image/312/312/x...  \
# 68  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 3   Internal Storage128 GBRAM8 GBExpandable Storag...  \
# 68  Internal Storage64 GBRAM6 GBExpandable Storage...
#
#                                                camera
# 3   Operating SystemAndroid 12Processor TypeG37Pro...  \
# 68  Operating SystemAndroid 12Processor TypeUnisoc...
#
#                                          oS_Processor
# 3   Primary Camera AvailableYesPrimary Camera50MP ...  \
# 68  Primary Camera AvailableYesPrimary Camera50 MP...
#
#                                               display
# 3   Display Size16.76 cm (6.6 inch)Resolution1612 ...  \
# 68  Display Size16.76 cm (6.6 inch)Resolution1612 ...
#
#                                               network
# 3   Network Type2G, 3G, 4GSupported Networks4G LTE...  \
# 68  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                                               battery
# 3   Battery Capacity5000 mAhBattery TypeLithium-io...
# 68                           Battery Capacity5000 mAh

# %%
df
# Out:
#                                              name ratings    price
# 0             Infinix SMART 7 (Azure Blue, 64 GB)     4.3   ₹7,299  \
# 1              Infinix HOT 30i (Marigold, 128 GB)     4.3   ₹8,999
# 2               Infinix HOT 30i (Marigold, 64 GB)     4.3   ₹7,999
# 3         Infinix HOT 30i (Diamond White, 128 GB)     4.3   ₹8,999
# 4          Infinix HOT 30i (Diamond White, 64 GB)     4.3   ₹7,999
# ..                                            ...     ...      ...
# 187          Infinix Hot S3X (Milan Black, 32 GB)     4.2  ₹10,999
# 188   Infinix Note 10 Pro (Nordic Secret, 256 GB)     4.2  ₹16,999
# 189   Infinix Note 5 Stylus (Bordeaux Red, 64 GB)     3.9  ₹16,999
# 190  Infinix Note 5 Stylus (Charcoal Blue, 64 GB)     3.9  ₹16,999
# 191       Infinix S5 Lite (Midnight Black, 64 GB)     4.3   ₹9,999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 187  https://rukminim2.flixcart.com/image/312/312/j...
# 188  https://rukminim2.flixcart.com/image/312/312/k...
# 189  https://rukminim2.flixcart.com/image/312/312/j...
# 190  https://rukminim2.flixcart.com/image/312/312/j...
# 191  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 0    Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 1    Internal Storage128 GBRAM8 GBExpandable Storag...
# 2    Internal Storage64 GBRAM4 GBExpandable Storage...
# 3    Internal Storage128 GBRAM8 GBExpandable Storag...
# 4    Internal Storage64 GBRAM4 GBExpandable Storage...
# ..                                                 ...
# 187  Internal Storage32 GBRAM3 GBExpandable Storage...
# 188  Internal Storage256 GBRAM8 GBExpandable Storag...
# 189  Internal Storage64 GBRAM4 GBExpandable Storage...
# 190  Internal Storage64 GBRAM4 GBExpandable Storage...
# 191  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                                 camera
# 0    Operating SystemAndroid 12Processor TypeUnisoc...  \
# 1    Operating SystemAndroid 12Processor TypeG37Pro...
# 2    Operating SystemAndroid 12Processor TypeG37Pro...
# 3    Operating SystemAndroid 12Processor TypeG37Pro...
# 4    Operating SystemAndroid 12Processor TypeG37Pro...
# ..                                                 ...
# 187  Operating SystemAndroid Oreo 8.1Processor Type...
# 188  Operating SystemAndroid 11Processor TypeMediaT...
# 189  Operating SystemAndroid Oreo 8.1Processor Type...
# 190  Operating SystemAndroid Oreo 8.1Processor Type...
# 191  Operating SystemAndroid Pie 9Processor TypeHel...
#
#                                           oS_Processor
# 0    Primary Camera AvailableYesPrimary Camera13MP ...  \
# 1    Primary Camera AvailableYesPrimary Camera50MP ...
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
# 3    Primary Camera AvailableYesPrimary Camera50MP ...
# 4    Primary Camera AvailableYesPrimary Camera50MP ...
# ..                                                 ...
# 187  Primary Camera AvailableYesPrimary Camera13MP ...
# 188  Primary Camera AvailableYesPrimary Camera64MP ...
# 189  Primary Camera AvailableYesPrimary Camera16MP ...
# 190  Primary Camera AvailableYesPrimary Camera16MP ...
# 191  Primary Camera AvailableYesPrimary Camera16MP ...
#
#                                                display
# 0    Display Size16.76 cm (6.6 inch)Resolution1612 ...  \
# 1    Display Size16.76 cm (6.6 inch)Resolution1612 ...
# 2    Display Size16.76 cm (6.6 inch)Resolution1612 ...
# 3    Display Size16.76 cm (6.6 inch)Resolution1612 ...
# 4    Display Size16.76 cm (6.6 inch)Resolution1612 ...
# ..                                                 ...
# 187  Display Size15.75 cm (6.2 inch)Resolution1500 ...
# 188  Display Size17.65 cm (6.95 inch)Resolution2460...
# 189  Display Size15.06 cm (5.93 inch)Resolution1080...
# 190  Display Size15.06 cm (5.93 inch)Resolution1080...
# 191  Display Size16.76 cm (6.6 inch)Resolution720 x...
#
#                                                network
# 0    Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 1    Network Type2G, 3G, 4GSupported Networks4G LTE...
# 2    Network Type2G, 3G, 4GSupported Networks4G LTE...
# 3    Network Type2G, 3G, 4GSupported Networks4G LTE...
# 4    Network Type2G, 3G, 4GSupported Networks4G LTE...
# ..                                                 ...
# 187  Network Type3G, 4G, 2GSupported NetworksGSM, W...
# 188  Network Type4G, 3G, 2GSupported Networks4G LTE...
# 189  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
# 190  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...
# 191  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                                                battery
# 0    Battery Capacity6000 mAhBattery TypeLithium-io...
# 1    Battery Capacity5000 mAhBattery TypeLithium-io...
# 2    Battery Capacity5000 mAhBattery TypeLithium-io...
# 3    Battery Capacity5000 mAhBattery TypeLithium-io...
# 4    Battery Capacity5000 mAhBattery TypeLithium-io...
# ..                                                 ...
# 187                           Battery Capacity4000 mAh
# 188                           Battery Capacity5000 mAh
# 189  Battery Capacity4000 mAhBattery TypeLi-ion Pol...
# 190  Battery Capacity4000 mAhBattery TypeLi-ion Pol...
# 191                           Battery Capacity4000 mAh
#
# [192 rows x 10 columns]

# %%
print(os.getcwd())
os.chdir(r'd:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem')
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem\notebook\data_Ingestion\scraping
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem

# %%
df['imgURL'][0]
# Out:
# 'https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/u/c/u/-original-imagnanh2yvpc4zx.jpeg?q=70'

# %%
df.to_csv(r'data\raw_data\infinix_mobile_data.csv',index=False)
