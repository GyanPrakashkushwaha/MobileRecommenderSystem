# %%
import requests
from bs4 import BeautifulSoup as bs
import logging

# %%
pages = 1
URL = f'https://www.flipkart.com/search?q=mi+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={pages}'
request = requests.get(URL)
soup = bs(request.text,'html.parser')
soup = soup.find('div',class_ = '_1YokD2 _3Mn1Gg')

# %%
'https://www.flipkart.com' + soup.find('a',class_ = '_1fQZEK')['href']
# Out:
# 'https://www.flipkart.com/redmi-10-power-sporty-orange-128-gb/p/itm97f5d2ec83588?pid=MOBGHDXFV9PCSYXV&lid=LSTMOBGHDXFV9PCSYXVDQIVX6&marketplace=FLIPKART&q=mi+mobiles&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=589c4c24-3c41-48a0-8df8-a25440acf750.MOBGHDXFV9PCSYXV.SEARCH&ppt=None&ppn=None&ssid=bebi3cj5ow0000001689821370239&qH=fe263b216b5e362a'

# %%
mobile_links = soup.find_all('a',class_ = '_1fQZEK')
mobile_links
# Out:
# [<a class="_1fQZEK" href="/redmi-10-power-sporty-orange-128-gb/p/itm97f5d2ec83588?pid=MOBGHDXFV9PCSYXV&amp;lid=LSTMOBGHDXFV9PCSYXVDQIVX6&amp;marketplace=FLIPKART&amp;q=mi+mobiles&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;otracker1=search&amp;fm=organic&amp;iid=589c4c24-3c41-48a0-8df8-a25440acf750.MOBGHDXFV9PCSYXV.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=bebi3cj5ow0000001689821370239&amp;qH=fe263b216b5e362a" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="REDMI 10 Power (Sporty Orange, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/p/g/k/-original-imageyuud3bey9hh.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Comp
# ...

# %%
for i in mobile_links:
    links = 'https://www.flipkart.com' + i['href']
    print(links)
# Out:
# https://www.flipkart.com/redmi-10-power-sporty-orange-128-gb/p/itm97f5d2ec83588?pid=MOBGHDXFV9PCSYXV&lid=LSTMOBGHDXFV9PCSYXVDQIVX6&marketplace=FLIPKART&q=mi+mobiles&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=589c4c24-3c41-48a0-8df8-a25440acf750.MOBGHDXFV9PCSYXV.SEARCH&ppt=None&ppn=None&ssid=bebi3cj5ow0000001689821370239&qH=fe263b216b5e362a
# https://www.flipkart.com/redmi-9a-sport-carbon-black-32-gb/p/itm53bc6ebfe147b?pid=MOBGHDXFDH2AYAPY&lid=LSTMOBGHDXFDH2AYAPYX5ARMR&marketplace=FLIPKART&q=mi+mobiles&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=589c4c24-3c41-48a0-8df8-a25440acf750.MOBGHDXFDH2AYAPY.SEARCH&ppt=None&ppn=None&ssid=bebi3cj5ow0000001689821370239&qH=fe263b216b5e362a
# ...

# %%
mobile_links = soup.find_all('a',class_ = '_1fQZEK')
lnk = 'https://www.flipkart.com' + mobile_links[0]['href']
lnk
# Out:
# 'https://www.flipkart.com/redmi-10-power-sporty-orange-128-gb/p/itm97f5d2ec83588?pid=MOBGHDXFV9PCSYXV&lid=LSTMOBGHDXFV9PCSYXVDQIVX6&marketplace=FLIPKART&q=mi+mobiles&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=589c4c24-3c41-48a0-8df8-a25440acf750.MOBGHDXFV9PCSYXV.SEARCH&ppt=None&ppn=None&ssid=bebi3cj5ow0000001689821370239&qH=fe263b216b5e362a'

# %%
lnk_req = requests.get(url=lnk)

# %%
lnk_req
# Out:
# <Response [200]>

# %%
soup_lnk = bs(lnk_req.text,'html.parser')
soup_lnk = soup_lnk.find('div',class_ = '_1YokD2 _2GoDe3')

# %%
specs = soup_lnk.find_all('div',class_ = '_3k-BhJ')
specs
# Out:
# [<div class="_3k-BhJ"><div class="flxcaE">General</div><table class="_14cfVK"><tbody><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">In The Box</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">Handset| Adapter | USB Type-C Cable | SIM Eject Tool | Protective Case | Quick Start Guide | Warranty Card</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Model Number</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">220333QBI</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Model Name</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">REDMI 10 Power</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Color</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">Sporty Orange</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Browse Type</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">Smartphones</li></ul></td></tr><tr class="_1s_Smc row
# ...

# %%
storage_ram = specs[3].find('table',class_ = '_14cfVK').text
storage_ram
# Out:
# 'Internal Storage256 GBRAM8 GBCall Log MemoryYes'

# %%
os_processor = specs[2].find('table',class_ = '_14cfVK').text
os_processor
# Out:
# 'Operating SystemAndroid 13Processor CoreOcta CorePrimary Clock Speed2.4 GHz'

# %%
camera = specs[4].find('table',class_ = '_14cfVK').text
camera
# Out:
# 'Primary Camera50MP Rear CameraDual Camera LensPrimary Camera'

# %%
display = specs[1].find('table',class_ = '_14cfVK').text
display
# Out:
# 'Display Size17.02 cm (6.7 inch)Resolution2400 x 1080 pixel'

# %%
network = specs[5].find('li',class_ = '_21lJbe')
network.text
# Out:
# '4G VOLTE'

# %%
hre = 'https://www.flipkart.com/xiaomi-12-pro-5g-noir-black-256-gb/p/itm0d1601b39b8bb?pid=MOBGDZ72AVDBGA66&lid=LSTMOBGDZ72AVDBGA66GUUHUZ&marketplace=FLIPKART&q=mi+mobiles&store=tyy%2F4io&srno=s_1_1&otracker=AS_Query_HistoryAutoSuggest_1_1_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_1_na_na_na&fm=search-autosuggest&iid=12d6eba4-4fd6-441f-a96a-94a76929af82.MOBGDZ72AVDBGA66.SEARCH&ppt=sp&ppn=sp&ssid=f6w82nr2u80000001689824793399&qH=fe263b216b5e362a'

# %%
lnk_req = requests.get(url=hre)
soup_lnk = bs(lnk_req.text,'html.parser')
soup_lnk = soup_lnk.find('div',class_ = '_1YokD2 _2GoDe3')
specs = soup_lnk.find_all('div',class_ = '_3k-BhJ')
specs
# Out:
# [<div class="_3k-BhJ"><div class="flxcaE">General</div><table class="_14cfVK"><tbody><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">In The Box</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">Handset, 120W Charging Adaptor, USB Type-C Cable, Sim Eject Tool, Protective Case, USB Type C to 3.5mm Converter, Quick Start Guide, Warranty Card</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Model Number</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">2201122G|MZB0BUPIN</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Model Name</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">12 Pro 5G</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Color</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">Noir Black</li></ul></td></tr><tr class="_1s_Smc row"><td class="_1hKmbr col col-3-12">Browse Type</td><td class="URwL2w col col-9-12"><ul><li class="_21lJbe">Smartphones<
# ...

# %%
for i in specs:
    key_word = str(i.text).split(' ')
    # print(key_word)
    if 'Connectivity'and 'FeaturesNetwork'  in key_word:
        print(i.text)
# Out:
# Connectivity FeaturesNetwork Type5G, 4G VOLTE, 4G, 3G, 2GSupported Networks5G, 4G VoLTE, 4G LTE, WCDMA, GSMInternet Connectivity5G, 4G, 3G, Wi-Fi, EDGE, GPRS3GYesGPRSYesMicro USB PortYesMicro USB VersionUSB Type CBluetooth SupportYesBluetooth Versionv5.2Wi-FiYesWi-Fi VersionSupports 2.4 GHz and 5 GHz Dual BandWi-Fi HotspotYesMini HDMI PortNoNFCYesUSB TetheringYesInfraredYesUSB ConnectivityYesEDGEYesAudio JackNAMap SupportGoogle MapsGPS SupportYes

# %%
if specs[0].text :
    print(specs[0].text)
# Out:
# GeneralIn The BoxHandset, 120W Charging Adaptor, USB Type-C Cable, Sim Eject Tool, Protective Case, USB Type C to 3.5mm Converter, Quick Start Guide, Warranty CardModel Number2201122G|MZB0BUPINModel Name12 Pro 5GColorNoir BlackBrowse TypeSmartphonesSIM TypeDual SimHybrid Sim SlotNoTouchscreenYesOTG CompatibleYesQuick ChargingYesSAR ValueSAR Limit: 1.6 W/kg, Head: 0.775 W/kg, Body: 0.451 W/kg
