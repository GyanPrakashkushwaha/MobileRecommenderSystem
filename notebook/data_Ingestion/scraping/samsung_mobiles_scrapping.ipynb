# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import os
import numpy as np
from itertools import zip_longest

# %%
def bs4_soup(pages):
    URL = f'https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={pages}'
    request = requests.get(URL)
    soup = bs(request.text,'html.parser')
    soup = soup.find('div',class_ = '_1YokD2 _3Mn1Gg')

    return soup , URL

# %%
def mob_specs(soup):
    names = soup.find_all('div', class_='_4rR01T')
    mob_names = [i.text if i else None for i in names]

    ratings = soup.find_all('div', class_='_3LWZlK')
    mob_ratings = [i.text if i else None for i in ratings]

    price = soup.find_all('div', class_='_30jeq3 _1_WHN1')
    mob_price = [i.text if i else None for i in price]

    img = soup.find_all('div', class_='CXW8mj')
    mob_img_URL = [i.find('img')['src'] if i.find('img') else None for i in img]

    return mob_names, mob_ratings, mob_price, mob_img_URL

# %%
def features_from_mob_links(soup):
    mobile_links = ['https://www.flipkart.com' + i['href'] for i in soup.find_all('a', class_='_1fQZEK')]
    mobile_req = [requests.get(url=i) for i in mobile_links]
    mobile_soup = [bs(i.text, 'html.parser').find('div', class_='_1YokD2 _2GoDe3') for i in mobile_req]
    mobile_specs_soup = [i.find_all('div', class_='_3k-BhJ') for i in mobile_soup]

    storage_ram = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Memory' in str(specs_.text) and 'Storage' in str(specs_.text)]
    storage_ram_cross_checked = [i for i in storage_ram if 'Internal' in i.split()]

    os_processor = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Os' in str(specs_.text) and 'Processor' in str(specs_.text)]
    os_processor_cross_checked = [i for i in os_processor if 'Operating' in i.split()]

    camera = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Camera' in str(specs_.text) and 'FeaturesPrimary' in str(specs_.text)]
    camera_cross_checked = [i for i in camera if 'Primary' and 'Camera' in i.split()]

    display = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Display' in str(specs_.text) and 'FeaturesDisplay' in str(specs_.text)]
    display_cross_checked = [i for i in display if 'Display' and 'cm' in i.split()]

    network = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Connectivity' in str(specs_.text) and 'FeaturesNetwork' in str(specs_.text)]
    network_cross_checked = [i for i in network if 'Network' in i.split()]

    battery = [specs_.find('table', class_='_14cfVK').text if specs_ else None for mob_specs in mobile_specs_soup for specs_ in mob_specs if 'Battery' in str(specs_.text) and 'FeaturesBattery' in str(specs_.text)]
    battery_cross_checked = [i for i in battery if 'Battery' in i.split()]

    return mobile_specs_soup, storage_ram_cross_checked, os_processor_cross_checked, camera_cross_checked, display_cross_checked, network_cross_checked, battery_cross_checked

# %%
def fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery):
    tuple_data = zip_longest(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery,fillvalue=np.nan)
    
    data = [i for i in tuple_data]
    return data

# %%
def print_len(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery):
    print(f"Length of mob_names: {len(mob_names)}")
    print(f"Length of mob_ratings: {len(mob_ratings)}")
    print(f"Length of mob_price: {len(mob_price)}")
    print(f"Length of mob_img_URL: {len(mob_img_URL)}")
    print(f"Length of storage_ram: {len(storage_ram)}")
    print(f"Length of os_processor: {len(os_processor)}")
    print(f"Length of camera: {len(camera)}")
    print(f"Length of display: {len(display)}")
    print(f"Length of network: {len(network)}")
    print(f"Length of battery: {len(battery)}")

# %%
df = pd.DataFrame()

page_start = 1
page_ends = 25

for pages in range(page_start, page_ends):

    soup, URL = bs4_soup(pages=pages)
    
    mob_names, mob_ratings, mob_price, mob_img_URL = mob_specs(soup)
    mobile_specs_soup, storage_ram, os_processor, camera, display, network, battery = features_from_mob_links(soup=soup)
    
    data = fill_nan_values_func(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)

    if mobile_specs_soup is not None and soup is not None:
        
        print_len(mob_names, mob_ratings, mob_price, mob_img_URL, storage_ram, os_processor, camera, display, network, battery)

        page_df = pd.DataFrame(data=data,columns=['name', 'ratings', 'price', 'imgURL', 'storage_ram','os_processor',
                                                   'camera', 'display', 'network', 'battery'])

        if not page_df.empty:
            df = pd.concat(objs=[df, page_df], ignore_index=True)
            print(f'scraping data from page:{pages}')
            print(f'working in {URL} Page')
            print(f'page df : page_shape : {page_df.shape} \n {page_df.sample(2)}')
            print(f'df : df shape : {df.shape} \n {df.sample(2)}')
            print()

    else:
        print(f"Skipping page {pages} due to empty mobile_specs_soup or soup.")
# Out:
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 23
# Length of os_processor: 22
# Length of camera: 23
# Length of display: 24
# Length of network: 23
# Length of battery: 24
# scraping data from page:1
# working in https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1 Page
# page df : page_shape : (24, 10)
#                                          name ratings    price
# 4  SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)     4.3  ₹15,499  \
# 7     SAMSUNG Galaxy F04 (Opal Green, 64 GB)     4.2   ₹6,999
#
#                                               imgURL
# 4  https://rukminim2.flixcart.com/image/312/312/x...  \
# 7  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                          storage_ram
# 4  Internal Storage128 GBRAM6 GBTotal Memory128 G...  \
# 7  Internal Storage64 GBRAM4 GBTotal Memory64 GBE...
#
#                                         os_processor
# 4  Operating SystemAndroid 12Processor TypeQualco...  \
# 7  Operating SystemAndroid 12Processor TypeMediat...
#
#                                               camera
# 4  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 7  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                              display
# 4  Display Size16.76 cm (6.6 inch)Resolution2408 ...  \
# 7  Display Size16.51 cm (6.5 inch)Resolution1600 ...
#
#                                              network
# 4  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 7  Network Type4G, 3G, 2GSupported NetworksGSM, C...
#
#                                   battery
# 4                Battery Capacity5000 mAh
# 7  Battery Capacity5000 mAhDual BatteryNo
# df : df shape : (24, 10)
#                                             name ratings    price
# 3   SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)     4.3  ₹10,499  \
# 13      SAMSUNG Galaxy M04 (Light Green, 64 GB)     4.1   ₹8,185
#
#                                                imgURL
# 3   https://rukminim2.flixcart.com/image/312/312/x...  \
# 13  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 3   Internal Storage128 GBRAM4 GBExpandable Storag...  \
# 13     Internal Storage64 GBRAM4 GBCall Log MemoryYes
#
#                                          os_processor
# 3   Operating SystemAndroid 12Processor TypeExynos...  \
# 13  Operating SystemAndroid 12Processor TypeMediaT...
#
#                                                camera
# 3   Primary Camera AvailableYesPrimary Camera50MP ...  \
# 13  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 3   Display Size16.76 cm (6.6 inch)Resolution2408 ...  \
# 13  Display Size16.51 cm (6.5 inch)Resolution720 x...
#
#                                               network
# 3   Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 13  Network Type4GSupported Networks4G LTE3GYesGPR...
#
#                                             battery
# 3            Battery Capacity6000 mAhDual BatteryNo
# 13  Battery Capacity5000 mAhBattery TypeLithium ion
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 22
# Length of camera: 22
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:2
# working in https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2 Page
# page df : page_shape : (24, 10)
#                                                   name ratings    price
# 19  SAMSUNG Galaxy S22 Plus 5G (Phantom Black, 128...     4.5  ₹59,999  \
# 17   SAMSUNG Galaxy A34 5G (Awesome Graphite, 256 GB)     4.2  ₹32,999
#
#                                                imgURL
# 19  https://rukminim2.flixcart.com/image/312/312/x...  \
# 17  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 19                      Internal Storage128 GBRAM8 GB  \
# 17  Internal Storage256 GBRAM8 GBTotal Memory256 G...
#
#                                          os_processor
# 19  Operating SystemAndroid Q 12Processor CoreOcta...  \
# 17  Operating SystemAndroid 12Processor TypeQualco...
#
#                                                camera
# 19  Primary Camera50MP Rear CameraDual Camera Lens...  \
# 17  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 19  Display Size16.76 cm (6.6 inch)Resolution2340 ...  \
# 17  Display Size16.76 cm (6.6 inch)Resolution1080 ...
#
#                                               network
# 19  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 17  Network Type2G, 3G, 4G VOLTE, 5GSupported Netw...
#
#                                    battery
# 19  Battery Capacity4500 mAhDual BatteryNo
# 17  Battery Capacity5000 mAhDual BatteryNo
# df : df shape : (48, 10)
#                                              name ratings    price
# 5   SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)     4.3  ₹15,499  \
# 12    SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)     4.3   ₹9,499
#
#                                                imgURL
# 5   https://rukminim2.flixcart.com/image/312/312/x...  \
# 12  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 5   Internal Storage128 GBRAM6 GBTotal Memory128 G...  \
# 12  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                          os_processor
# 5   Operating SystemAndroid 12Processor TypeQualco...  \
# 12  Operating SystemAndroid 12Processor TypeExynos...
#
#                                                camera
# 5   Primary Camera AvailableYesPrimary Camera50MP ...  \
# 12  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 5   Display Size16.76 cm (6.6 inch)Resolution2408 ...  \
# 12  Display Size16.76 cm (6.6 inch)Resolution2408 ...
#
#                                               network
# 5   Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 12  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                                    battery
# 5                 Battery Capacity5000 mAh
# 12  Battery Capacity6000 mAhDual BatteryNo
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:3
# working in https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3 Page
# page df : page_shape : (24, 10)
#                                                name ratings    price
# 0   SAMSUNG Galaxy A54 5G (Awesome Violet, 128 GB)     4.3  ₹38,999  \
# 23      SAMSUNG Galaxy S20 FE (Cloud Mint, 128 GB)       4  ₹27,500
#
#                                                imgURL
# 0   https://rukminim2.flixcart.com/image/312/312/x...  \
# 23  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 0   Internal Storage128 GBRAM8 GBExpandable Storag...  \
# 23  Internal Storage128 GBRAM8 GBMemory Card Slot ...
#
#                                          os_processor
# 0   Operating SystemAndroid 13Processor TypeExynos...  \
# 23  Operating SystemAndroid 10Processor CoreOcta C...
#
#                                                camera
# 0   Primary Camera AvailableYesPrimary Camera50MP ...  \
# 23  Primary Camera12MP Rear CameraDual Camera Lens...
#
#                                               display
# 0   Display Size16.26 cm (6.4 inch)Resolution2340 ...  \
# 23  Display Size16.51 cm (6.5 inch)Resolution2400 ...
#
#                                               network
# 0   Network Type2G, 3G, 4G, 5GSupported Networks4G...  \
# 23  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                                    battery
# 0   Battery Capacity5000 mAhDual BatteryNo
# 23                Battery Capacity4500 mAh
# df : df shape : (72, 10)
#                                            name ratings   price
# 12  SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)     4.3  ₹9,499  \
# 6      SAMSUNG Galaxy F04 (Jade Purple, 64 GB)     4.2  ₹6,999
#
#                                                imgURL
# 12  https://rukminim2.flixcart.com/image/312/312/x...  \
# 6   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 12  Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 6   Internal Storage64 GBRAM4 GBTotal Memory64 GBE...
#
#                                          os_processor
# 12  Operating SystemAndroid 12Processor TypeExynos...  \
# 6   Operating SystemAndroid 12Processor TypeMediat...
#
#                                                camera
# 12  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 6   Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 12  Display Size16.76 cm (6.6 inch)Resolution2408 ...  \
# 6   Display Size16.51 cm (6.5 inch)Resolution1600 ...
#
#                                               network
# 12  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 6   Network Type4G, 3G, 2GSupported NetworksGSM, C...
#
#                                    battery
# 12  Battery Capacity6000 mAhDual BatteryNo
# 6   Battery Capacity5000 mAhDual BatteryNo
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 23
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:4
# working in https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4 Page
# page df : page_shape : (24, 10)
#                                             name ratings    price
# 14  SAMSUNG Galaxy A14 5G (Light Green, 128 GB)     4.1  ₹19,999  \
# 1       SAMSUNG Galaxy A04e (Light Blue, 64 GB)     4.2   ₹9,999
#
#                                                imgURL
# 14  https://rukminim2.flixcart.com/image/312/312/x...  \
# 1   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 14  Internal Storage128 GBRAM8 GBTotal Memory128 G...  \
# 1   Internal Storage64 GBRAM3 GBTotal Memory64 GBE...
#
#                                          os_processor
# 14  Operating SystemAndroid 12Processor TypeQualco...  \
# 1   Operating SystemAndroid 13Processor TypeSEC S5...
#
#                                                camera
# 14  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 1   Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 14  Display Size16.76 cm (6.6 inch)Resolution2408 ...  \
# 1   Display Size16.51 cm (6.5 inch)Resolution1600 ...
#
#                                               network
# 14  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 1   Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                                    battery
# 14  Battery Capacity5000 mAhDual BatteryNo
# 1   Battery Capacity5000 mAhDual BatteryNo
# df : df shape : (96, 10)
#                                                name ratings    price
# 48  SAMSUNG Galaxy A54 5G (Awesome Violet, 128 GB)     4.3  ₹38,999  \
# 74           SAMSUNG Galaxy A14 5G (Black, 128 GB)     4.1  ₹19,999
#
#                                                imgURL
# 48  https://rukminim2.flixcart.com/image/312/312/x...  \
# 74  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 48  Internal Storage128 GBRAM8 GBExpandable Storag...  \
# 74  Internal Storage128 GBRAM8 GBTotal Memory128 G...
#
#                                          os_processor
# 48  Operating SystemAndroid 13Processor TypeExynos...  \
# 74  Operating SystemAndroid 13Processor TypeSEC S5...
#
#                                                camera
# 48  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 74  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 48  Display Size16.26 cm (6.4 inch)Resolution2340 ...  \
# 74  Display Size16.76 cm (6.6 inch)Resolution2408 ...
#
#                                               network
# 48  Network Type2G, 3G, 4G, 5GSupported Networks4G...  \
# 74  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                                    battery
# 48  Battery Capacity5000 mAhDual BatteryNo
# 74  Battery Capacity5000 mAhDual BatteryNo
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:5
# working in https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5 Page
# page df : page_shape : (24, 10)
#                                         name ratings   price
# 3   SAMSUNG Galaxy A03 Core (Bronze, 32 GB)     4.1  ₹7,199  \
# 20    SAMSUNG Galaxy A03 Core (Mint, 32 GB)     4.1  ₹7,199
#
#                                                imgURL
# 3   https://rukminim2.flixcart.com/image/312/312/x...  \
# 20  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 3   Internal Storage32 GBRAM2 GBExpandable Storage...  \
# 20  Internal Storage32 GBRAM2 GBMemory Card Slot T...
#
#                                          os_processor
# 3   Operating SystemAndroid Q 11Processor CoreOcta...  \
# 20  Operating SystemAndroid Q 11Processor CoreOcta...
#
#                                                camera
# 3   Primary Camera AvailableYesPrimary Camera8MP R...  \
# 20                      Primary Camera8MP Rear Camera
#
#                                               display
# 3   Display Size16.51 cm (6.5 inch)Resolution1600x...  \
# 20  Display Size16.51 cm (6.5 inch)Resolution1600 ...
#
#                                               network
# 3   Network Type4G VOLTESupported Networks4G LTE, ...  \
# 20             Network Type4GSupported Networks4G LTE
#
#                      battery
# 3   Battery Capacity5000 mAh
# 20  Battery Capacity5000 mAh
# df : df shape : (120, 10)
#                                        name ratings    price
# 57   SAMSUNG Galaxy A14 5G (Black, 128 GB)       4  ₹17,999  \
# 7   SAMSUNG Galaxy F04 (Opal Green, 64 GB)     4.2   ₹6,999
#
#                                                imgURL
# 57  https://rukminim2.flixcart.com/image/312/312/x...  \
# 7   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 57  Internal Storage128 GBRAM6 GBTotal Memory128 G...  \
# 7   Internal Storage64 GBRAM4 GBTotal Memory64 GBE...
#
#                                          os_processor
# 57  Operating SystemAndroid 13Processor TypeSEC S5...  \
# 7   Operating SystemAndroid 12Processor TypeMediat...
#
#                                                camera
# 57  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 7   Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 57  Display Size16.76 cm (6.6 inch)Resolution2408 ...  \
# 7   Display Size16.51 cm (6.5 inch)Resolution1600 ...
#
#                                               network
# 57  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 7   Network Type4G, 3G, 2GSupported NetworksGSM, C...
#
#                                    battery
# 57  Battery Capacity5000 mAhDual BatteryNo
# 7   Battery Capacity5000 mAhDual BatteryNo
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:6
# working in https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=6 Page
# page df : page_shape : (24, 10)
#                                               name ratings    price
# 23            SAMSUNG Galaxy A04e (Copper, 64 GB)     4.2   ₹9,999  \
# 4   SAMSUNG Galaxy S23 5G (Phantom Black, 128 GB)     4.5  ₹74,999
#
#                                                imgURL
# 23  https://rukminim2.flixcart.com/image/312/312/x...  \
# 4   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 23  Internal Storage64 GBRAM3 GBTotal Memory64 GBE...  \
# 4     Internal Storage128 GBRAM8 GBTotal Memory128 GB
#
#                                          os_processor
# 23  Operating SystemAndroid 12Processor TypeMediat...  \
# 4   Operating SystemAndroid 13Processor TypeQualco...
#
#                                                camera
# 23  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 4   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 23  Display Size16.51 cm (6.5 inch)Resolution1600 ...  \
# 4   Display Size15.49 cm (6.1 inch)Resolution2340 ...
#
#                                               network
# 23  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 4   Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                                    battery
# 23  Battery Capacity5000 mAhDual BatteryNo
# 4   Battery Capacity3900 mAhDual BatteryNo
# df : df shape : (144, 10)
#                                               name ratings    price
# 123  SAMSUNG Galaxy A34 5G (Awesome Lime, 128 GB)     4.2  ₹30,999  \
# 110             SAMSUNG Galaxy M12 (Black, 64 GB)     4.2  ₹12,498
#
#                                                 imgURL
# 123  https://rukminim2.flixcart.com/image/312/312/x...  \
# 110  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 123  Internal Storage128 GBRAM8 GBTotal Memory128 G...  \
# 110  Internal Storage64 GBRAM4 GBMemory Card Slot T...
#
#                                           os_processor
# 123  Operating SystemAndroid 13Processor TypeDimens...  \
# 110  Operating SystemAndroid Oreo V11Processor Core...
#
#                                                 camera
# 123  Primary Camera AvailableYesPrimary Camera48MP ...  \
# 110  Primary Camera48MP Rear CameraDual Camera Lens...
#
#                                                display
# 123  Display Size16.76 cm (6.6 inch)Resolution1080 ...  \
# 110  Display Size16.51 cm (6.5 inch)Resolution720*1...
#
#                                                network
# 123  Network Type2G, 3G, 4G VOLTE, 5GSupported Netw...  \
# 110     Network Type4G VOLTESupported Networks4G VoLTE
#
#                                     battery
# 123  Battery Capacity5000 mAhDual BatteryNo
# 110                Battery Capacity6000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 23
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:7
# working in https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=7 Page
# page df : page_shape : (24, 10)
#                                            name ratings    price
# 8         SAMSUNG Galaxy F12 (Sky Blue, 64 GB)     4.1  ₹10,890  \
# 14  SAMSUNG Galaxy F42 5G (Matte Aqua, 128 GB)     4.1  ₹22,999
#
#                                                imgURL
# 8   https://rukminim2.flixcart.com/image/312/312/k...  \
# 14  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 8   Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 14  Internal Storage128 GBRAM8 GBExpandable Storag...
#
#                                          os_processor
# 8   Operating SystemAndroid 11Processor TypeExynos...  \
# 14  Operating SystemAndroid 11Processor TypeMediaT...
#
#                                                camera
# 8   Primary Camera AvailableYesPrimary Camera48MP ...  \
# 14  Primary Camera AvailableYesPrimary Camera64MP ...
#
#                                               display
# 8   Display Size16.55 cm (6.515 inch)Resolution160...  \
# 14  Display Size16.76 cm (6.6 inch)Resolution2408 ...
#
#                                               network
# 8   Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 14  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                      battery
# 8   Battery Capacity6000 mAh
# 14  Battery Capacity5000 mAh
# df : df shape : (168, 10)
#                                           name ratings    price
# 13    SAMSUNG Galaxy M04 (Light Green, 64 GB)     4.1   ₹8,185  \
# 39  SAMSUNG GALAXY M13 (Midnight Blue, 64 GB)     4.2  ₹11,599
#
#                                                imgURL
# 13  https://rukminim2.flixcart.com/image/312/312/x...  \
# 39  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 13     Internal Storage64 GBRAM4 GBCall Log MemoryYes  \
# 39  Internal Storage64 GBRAM4 GBMemory Card Slot T...
#
#                                          os_processor
# 13  Operating SystemAndroid 12Processor TypeMediaT...  \
# 39  Operating SystemAndroid 13Processor TypeDimens...
#
#                                                camera
# 13  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 39  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                               display
# 13  Display Size16.51 cm (6.5 inch)Resolution720 x...  \
# 39  Display Size16.76 cm (6.6 inch)Resolution720x2408
#
#                                               network
# 13  Network Type4GSupported Networks4G LTE3GYesGPR...  \
# 39     Network Type4G VOLTESupported Networks4G VoLTE
#
#                                             battery
# 13  Battery Capacity5000 mAhBattery TypeLithium ion
# 39                         Battery Capacity6000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 23
# Length of os_processor: 23
# Length of camera: 23
# Length of display: 23
# Length of network: 23
# Length of battery: 23
# scraping data from page:8
# working in https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=8 Page
# page df : page_shape : (24, 10)
#                                               name ratings      price
# 18      SAMSUNG Galaxy A52 (Awesome Blue, 128 GB)     4.3    ₹25,989  \
# 17  SAMSUNG Galaxy Z Fold4 5G (Graygreen, 512 GB)     2.9  ₹1,64,999
#
#                                                imgURL
# 18  https://rukminim2.flixcart.com/image/312/312/k...  \
# 17  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 18  Internal Storage128 GBRAM6 GBExpandable Storag...  \
# 17                     Internal Storage512 GBRAM12 GB
#
#                                          os_processor
# 18  Operating SystemAndroid 11Processor TypeQualco...  \
# 17  Operating SystemAndroid 12Processor TypeQualco...
#
#                                                camera
# 18  Primary Camera AvailableYesPrimary Camera64MP ...  \
# 17  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 18  Display Size16.51 cm (6.5 inch)Resolution2400 ...  \
# 17  Display Size19.3 cm (7.6 inch)Resolution2176 x...
#
#                                               network
# 18  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 17  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                                     battery
# 18                 Battery Capacity4500 mAh
# 17  Battery Capacity4400 mAhDual BatteryYes
# df : df shape : (192, 10)
#                                     name ratings    price
# 166     SAMSUNG Galaxy A03 (Red, 32 GB)     3.7   ₹9,498  \
# 80   SAMSUNG Galaxy A23 (Peach, 128 GB)     4.2  ₹17,499
#
#                                                 imgURL
# 166  https://rukminim2.flixcart.com/image/312/312/l...  \
# 80   https://rukminim2.flixcart.com/image/312/312/l...
#
#                                            storage_ram
# 166  Internal Storage32 GBRAM3 GBSupported Memory C...  \
# 80   Internal Storage128 GBRAM6 GBTotal Memory128 G...
#
#                                           os_processor
# 166  Operating SystemAndroid 11Processor TypeUnisoc...  \
# 80   Operating SystemAndroid 12Processor TypeMediat...
#
#                                                 camera
# 166  Primary Camera AvailableYesPrimary Camera48MP ...  \
# 80   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                                display
# 166  Display Size16.51 cm (6.5 inch)Resolution1600 ...  \
# 80   Display Size16.76 cm (6.6 inch)Resolution1920x...
#
#                                                network
# 166  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 80   Network Type4GSupported Networks4G LTEInternet...
#
#                                                battery
# 166                           Battery Capacity5000 mAh
# 80   Battery Capacity5000 mAhTalk Time56 HoursDual ...
#
# Length of mob_names: 24
# Length of mob_ratings: 24
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 23
# Length of battery: 24
# scraping data from page:9
# working in https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=9 Page
# page df : page_shape : (24, 10)
#                                    name ratings    price
# 20  SAMSUNG Galaxy A23 (Black, 128 GB)     4.3  ₹18,790  \
# 13  SAMSUNG Galaxy A22 (Black, 128 GB)     4.2  ₹20,499
#
#                                                imgURL
# 20  https://rukminim2.flixcart.com/image/312/312/l...  \
# 13  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 20  Internal Storage128 GBRAM8 GBTotal Memory128 G...  \
# 13  Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                          os_processor
# 20  Operating SystemAndroid 12Processor TypeOcta-c...  \
# 13  Operating SystemAndroid 11Processor TypeMediaT...
#
#                                                camera
# 20  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 13  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                               display
# 20  Display Size16.76 cm (6.6 inch)Resolution1920x...  \
# 13  Display Size16.26 cm (6.4 inch)Resolution1600 ...
#
#                                               network
# 20  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 13  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
#
#                                               battery
# 20  Battery Capacity5000 mAhTalk Time56 HoursDual ...
# 13                           Battery Capacity5000 mAh
# df : df shape : (216, 10)
#                                                    name ratings    price
# 60          SAMSUNG GALAXY M13 5G (Aqua Green, 128 GB)     4.1  ₹14,049  \
# 145  SAMSUNG Galaxy M34 5G without charger (Prism S...     4.3  ₹21,399
#
#                                                 imgURL
# 60   https://rukminim2.flixcart.com/image/312/312/x...  \
# 145  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 60   Internal Storage128 GBRAM6 GBMemory Card Slot ...  \
# 145  Internal Storage128 GBRAM6 GBMemory Card Slot ...
#
#                                           os_processor
# 60   Operating SystemAndroid Q 12Processor CoreOcta...  \
# 145  Operating SystemAndroid Android 13Processor Co...
#
#                                                 camera
# 60   Primary Camera50MP Rear CameraDual Camera Lens...  \
# 145  Primary Camera50MP Rear CameraDual Camera Lens...
#
#                                                display
# 60   Display Size16.51 cm (6.5 inch)Resolution720x1...  \
# 145  Display Size16.51 cm (6.5 inch)Resolution2340X...
#
#                                 network                   battery
# 60   Network Type5GSupported Networks5G  Battery Capacity5000 mAh
# 145  Network Type5GSupported Networks5G  Battery Capacity6000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 23
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:10
# working in https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=10 Page
# page df : page_shape : (24, 10)
#                                          name ratings    price
# 14  SAMSUNG Galaxy A14 (Light Green, 128 GB)     3.9  ₹15,499  \
# 19       SAMSUNG Galaxy On Max (Gold, 32 GB)     4.3  ₹19,900
#
#                                                imgURL
# 14  https://rukminim2.flixcart.com/image/312/312/x...  \
# 19  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                           storage_ram
# 14  Internal Storage128 GBRAM4 GBTotal Memory128 G...  \
# 19  Internal Storage32 GBRAM4 GBExpandable Storage...
#
#                                          os_processor
# 14  Operating SystemAndroid 13Processor TypeExynos...  \
# 19  Operating SystemAndroid Nougat 7Processor Type...
#
#                                                camera
# 14  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 19  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 14  Display Size16.76 cm (6.6 inch)Resolution2408 ...  \
# 19  Display Size14.48 cm (5.7 inch)Resolution1920 ...
#
#                                               network
# 14  Network Type2G, 3G, 4GSupported Networks4G LTE...  \
# 19  Network Type3G, 4G VOLTE, 2GSupported Networks...
#
#                                             battery
# 14  Battery Capacity5000 mAhBattery TypeLithium Ion
# 19                         Battery Capacity3300 mAh
# df : df shape : (240, 10)
#                                                 name ratings    price
# 234             SAMSUNG Galaxy On Nxt (Gold, 64 GB)     4.3  ₹17,900  \
# 98   SAMSUNG Galaxy A54 5G (Awesome Violet, 256 GB)     4.3  ₹40,999
#
#                                                 imgURL
# 234  https://rukminim2.flixcart.com/image/312/312/j...  \
# 98   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 234  Internal Storage64 GBRAM3 GBExpandable Storage...  \
# 98   Internal Storage256 GBRAM8 GBExpandable Storag...
#
#                                           os_processor
# 234  Operating SystemAndroid Marshmallow 6Processor...  \
# 98   Operating SystemAndroid 13Processor TypeExynos...
#
#                                                 camera
# 234  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 98   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                                display
# 234  Display Size13.97 cm (5.5 inch)Resolution1920 ...  \
# 98   Display Size16.26 cm (6.4 inch)Resolution2340 ...
#
#                                                network
# 234  Network Type3G, 4G, 2GSupported Networks4G LTE...  \
# 98   Network Type2G, 3G, 4G, 5GSupported Networks4G...
#
#                                     battery
# 234                Battery Capacity3300 mAh
# 98   Battery Capacity5000 mAhDual BatteryNo
#
# Length of mob_names: 24
# Length of mob_ratings: 21
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 23
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:11
# working in https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=11 Page
# page df : page_shape : (24, 10)
#                                               name ratings    price
# 10           SAMSUNG Galaxy On Max (Black, 32 GB)     4.1  ₹19,900  \
# 4   SAMSUNG Galaxy Z Flip4 5G (Pink Gold, 128 GB)     4.2  ₹89,999
#
#                                                imgURL
# 10  https://rukminim2.flixcart.com/image/312/312/j...  \
# 4   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 10  Internal Storage32 GBRAM4 GBExpandable Storage...  \
# 4                       Internal Storage128 GBRAM8 GB
#
#                                          os_processor
# 10  Operating SystemAndroid Nougat 7Processor Type...  \
# 4   Operating SystemAndroid 12Processor TypeQualco...
#
#                                                camera
# 10  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 4   Primary Camera AvailableYesPrimary Camera12MP ...
#
#                                               display
# 10  Display Size14.48 cm (5.7 inch)Resolution1920 ...  \
# 4   Display Size17.02 cm (6.7 inch)Resolution2640 ...
#
#                                               network
# 10  Network Type3G, 4G VOLTE, 2GSupported Networks...  \
# 4   Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                                     battery
# 10                 Battery Capacity3300 mAh
# 4   Battery Capacity3700 mAhDual BatteryYes
# df : df shape : (264, 10)
#                                                    name ratings      price
# 257  SAMSUNG Galaxy S23 Ultra 5G Smarphone (Green, ...     3.7  ₹1,16,989  \
# 134         SAMSUNG Galaxy A33 (Awesome Black, 128 GB)     4.1    ₹27,990
#
#                                                 imgURL
# 257  https://rukminim2.flixcart.com/image/312/312/x...  \
# 134  https://rukminim2.flixcart.com/image/312/312/l...
#
#                                            storage_ram
# 257   Internal Storage256 GBRAM12 GBTotal Memory256 GB  \
# 134  Internal Storage128 GBRAM8 GBTotal Memory128 G...
#
#                                           os_processor
# 257  Operating SystemAndroid 13Processor TypeQualco...  \
# 134  Operating SystemAndroid 12Processor TypeExynos...
#
#                                                 camera
# 257  Primary Camera AvailableYesPrimary Camera200MP...  \
# 134  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                                display
# 257  Display Size17.27 cm (6.8 inch)Resolution3088 ...  \
# 134  Display Size16.26 cm (6.4 inch)Resolution2400 ...
#
#                                                network
# 257  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 134  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                                     battery
# 257  Battery Capacity5000 mAhDual BatteryNo
# 134  Battery Capacity5000 mAhDual BatteryNo
#
# Length of mob_names: 24
# Length of mob_ratings: 23
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 21
# Length of camera: 23
# Length of display: 24
# Length of network: 22
# Length of battery: 24
# scraping data from page:12
# working in https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=12 Page
# page df : page_shape : (24, 10)
#                                                name ratings    price
# 5  SAMSUNG Galaxy A52s 5G (Awesome Violet, 128 GB)     2.9  ₹37,999  \
# 0                SAMSUNG Galaxy A13 (Blue, 128 GB)     4.1  ₹15,499
#
#                                               imgURL
# 5  https://rukminim2.flixcart.com/image/312/312/k...  \
# 0  https://rukminim2.flixcart.com/image/312/312/l...
#
#                                          storage_ram
# 5  Internal Storage128 GBRAM6 GBExpandable Storag...  \
# 0  Internal Storage128 GBRAM4 GBTotal Memory128 G...
#
#                                         os_processor
# 5  Operating SystemAndroid 11Processor TypeQualco...  \
# 0  Operating SystemAndroid 12Processor TypeExynos...
#
#                                               camera
# 5  Primary Camera AvailableYesPrimary Camera64MP ...  \
# 0  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                              display
# 5  Display Size16.51 cm (6.5 inch)Resolution2400 ...  \
# 0  Display Size16.76 cm (6.6 inch)Resolution1927 ...
#
#                                              network                   battery
# 5  Network Type5G, 4G, 3G, 2GSupported Networks5G...  Battery Capacity4500 mAh
# 0  Network Type4G, 3G, 2GSupported Networks4G LTE...  Battery Capacity5000 mAh
# df : df shape : (288, 10)
#                                            name ratings    price
# 8   SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)     4.2  ₹13,990  \
# 73     SAMSUNG Galaxy A04e (Light Blue, 64 GB)     4.2   ₹9,999
#
#                                                imgURL
# 8   https://rukminim2.flixcart.com/image/312/312/x...  \
# 73  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 8   Internal Storage128 GBRAM6 GBExpandable Storag...  \
# 73  Internal Storage64 GBRAM3 GBTotal Memory64 GBE...
#
#                                          os_processor
# 8   Operating SystemAndroid 13Processor TypeExynos...  \
# 73  Operating SystemAndroid 13Processor TypeSEC S5...
#
#                                                camera
# 8   Primary Camera AvailableYesPrimary Camera50MP ...  \
# 73  Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 8   Display Size16.76 cm (6.6 inch)Resolution2408 ...  \
# 73  Display Size16.51 cm (6.5 inch)Resolution1600 ...
#
#                                               network
# 8   Network Type2G, 3G, 4G, 5GSupported Networks4G...  \
# 73  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                                               battery
# 8   Battery Capacity6000 mAhBattery TypeLithium Io...
# 73             Battery Capacity5000 mAhDual BatteryNo
#
# Length of mob_names: 24
# Length of mob_ratings: 23
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 23
# Length of camera: 24
# Length of display: 24
# Length of network: 23
# Length of battery: 24
# scraping data from page:13
# working in https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=13 Page
# page df : page_shape : (24, 10)
#                                               name ratings    price
# 6   SAMSUNG Galaxy M52 5G (Blazing Black, 128 GB)     4.4  ₹24,999  \
# 22            SAMSUNG Galaxy A14 (Silver, 128 GB)     4.2  ₹16,399
#
#                                                imgURL
# 6   https://rukminim2.flixcart.com/image/312/312/x...  \
# 22  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 6   Internal Storage128 GBRAM6 GBMemory Card Slot ...  \
# 22  Internal Storage128 GBRAM4 GBTotal Memory128 G...
#
#                                          os_processor
# 6   Operating SystemAndroid 11Processor CoreOcta C...  \
# 22  Operating SystemAndroid 12Processor CoreOcta C...
#
#                                                camera
# 6   Primary Camera64MP Rear CameraDual Camera Lens...  \
# 22  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 6   Display Size17.02 cm (6.7 inch)Resolution1080 ...  \
# 22  Display Size16.76 cm (6.6 inch)Resolution2408 ...
#
#                                               network
# 6   Network Type5G, 4G VOLTESupported Networks5G, ...  \
# 22                 Network Type5GSupported Networks5G
#
#                                             battery
# 6                          Battery Capacity5000 mAh
# 22  Battery Capacity5000 mAhBattery TypeLithium Ion
# df : df shape : (312, 10)
#                                             name ratings    price
# 33                         SAMSUNG Guru Music 2     4.3   ₹2,890  \
# 158  SAMSUNG Galaxy F42 5G (Matte Aqua, 128 GB)     4.1  ₹22,999
#
#                                                 imgURL
# 33   https://rukminim2.flixcart.com/image/312/312/k...  \
# 158  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 33   Internal StorageNAPhone Book MemoryYesCall Log...  \
# 158  Internal Storage128 GBRAM8 GBExpandable Storag...
#
#                                           os_processor
# 33   Operating System0Primary Clock Speed208 MHzOpe...  \
# 158  Operating SystemAndroid 11Processor TypeMediaT...
#
#                                                 camera
# 33   Primary Camera50MP Rear CameraDual Camera Lens...  \
# 158  Primary Camera AvailableYesPrimary Camera64MP ...
#
#                                                display
# 33   Display Size5.08 cm (2 inch)Resolution128 x 16...  \
# 158  Display Size16.76 cm (6.6 inch)Resolution2408 ...
#
#                                                network
# 33   Network Type2GSupported NetworksGSMUSB Connect...  \
# 158  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                                       battery
# 33   Battery Capacity800 mAhBattery TypeLi-on
# 158                  Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 21
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 23
# Length of os_processor: 21
# Length of camera: 22
# Length of display: 24
# Length of network: 22
# Length of battery: 24
# scraping data from page:14
# working in https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=14 Page
# page df : page_shape : (24, 10)
#                                               name ratings    price
# 4               OPPO Reno10 5G (Ice Blue, 256 GB)     4.2  ₹32,999  \
# 18  SAMSUNG Galaxy S22 5G (Phantom Black, 128 GB)     4.3  ₹52,999
#
#                                                imgURL
# 4   https://rukminim2.flixcart.com/image/312/312/x...  \
# 18  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 4   Internal Storage256 GBRAM8 GBSupported Memory ...  \
# 18                      Internal Storage256 GBRAM8 GB
#
#                                          os_processor
# 4   Operating SystemAndroid 13Processor TypeDimens...  \
# 18  Operating SystemAndroid 12Processor TypeOcta C...
#
#                                                camera
# 4   Primary Camera AvailableYesPrimary Camera64MP ...  \
# 18  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                               display
# 4   Display Size17.02 cm (6.7 inch)Resolution2412 ...  \
# 18  Display Size15.49 cm (6.1 inch)Resolution2340 ...
#
#                                               network
# 4   Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 18  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                                    battery
# 4                 Battery Capacity5000 mAh
# 18  Battery Capacity3700 mAhDual BatteryNo
# df : df shape : (336, 10)
#                                             name ratings    price
# 161          SAMSUNG Galaxy A03s (Black, 32 GB)     4.4  ₹11,499  \
# 17   SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)     4.3   ₹9,499
#
#                                                 imgURL
# 161  https://rukminim2.flixcart.com/image/312/312/k...  \
# 17   https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 161  Internal Storage32 GBRAM3 GBExpandable Storage...  \
# 17   Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                           os_processor
# 161  Operating SystemAndroid 11Processor TypeMediat...  \
# 17   Operating SystemAndroid 12Processor CoreOcta C...
#
#                                                 camera
# 161  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 17   Primary Camera50MP Rear CameraDual Camera Lens...
#
#                                                display
# 161  Display Size16.51 cm (6.5 inch)Resolution1600 ...  \
# 17   Display Size16.76 cm (6.6 inch)Resolution2408 ...
#
#                                                network
# 161  Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 17   Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                                     battery
# 161                Battery Capacity5000 mAh
# 17   Battery Capacity6000 mAhDual BatteryNo
#
# Length of mob_names: 24
# Length of mob_ratings: 23
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 23
# Length of os_processor: 22
# Length of camera: 24
# Length of display: 23
# Length of network: 23
# Length of battery: 23
# scraping data from page:15
# working in https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=15 Page
# page df : page_shape : (24, 10)
#                                          name ratings    price
# 7                      SAMSUNG GT 1200 R/I/M     4.4   ₹1,499  \
# 4  SAMSUNG Galaxy M21 (Midnight Blue, 64 GB)     4.2  ₹14,248
#
#                                               imgURL
# 7  https://rukminim2.flixcart.com/image/312/312/t...  \
# 4  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                          storage_ram
# 7  Internal Storage64 GBRAM4 GBTotal Memory64 GBE...  \
# 4  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                         os_processor
# 7  Operating SystemAndroid Oreo 8Processor Type1....  \
# 4  Operating SystemAndroid Pie 10Processor TypeEx...
#
#                                               camera
# 7  Primary Camera AvailableNoSecondary Camera Ava...  \
# 4  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                              display
# 7  Display Size14.22 cm (5.6 inch)Resolution720 x...  \
# 4  Display Size16.26 cm (6.4 inch)Resolution2340 ...
#
#                                              network
# 7  Network Type3G, 4G VOLTE, 4G, 2GSupported Netw...  \
# 4  Network Type4G VOLTESupported Networks4G VoLTE...
#
#                                            battery
# 7                         Battery Capacity3000 mAh
# 4  Battery Capacity6000 mAhBattery Typelithium-ion
# df : df shape : (360, 10)
#                                           name ratings    price
# 230  SAMSUNG Galaxy A14 (Light Green, 128 GB)     3.9  ₹15,499  \
# 55         SAMSUNG Galaxy A13 (Peach, 128 GB)     4.2  ₹16,499
#
#                                                 imgURL
# 230  https://rukminim2.flixcart.com/image/312/312/x...  \
# 55   https://rukminim2.flixcart.com/image/312/312/l...
#
#                                            storage_ram
# 230  Internal Storage128 GBRAM4 GBTotal Memory128 G...  \
# 55   Internal Storage128 GBRAM6 GBTotal Memory128 G...
#
#                                           os_processor
# 230  Operating SystemAndroid 13Processor TypeExynos...  \
# 55   Operating SystemAndroid 12Processor TypeExynos...
#
#                                                 camera
# 230  Primary Camera AvailableYesPrimary Camera50MP ...  \
# 55   Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                                display
# ...
# Length of storage_ram: 23
# Length of os_processor: 23
# Length of camera: 23
# Length of display: 23
# Length of network: 23
# Length of battery: 23
# scraping data from page:20
# working in https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=20 Page
# page df : page_shape : (24, 10)
#                                           name ratings    price
# 21                      SAMSUNG GT 1200 R/I/M     4.3   ₹1,499  \
# 16  SAMSUNG Galaxy M21 (Midnight Blue, 64 GB)     4.1  ₹14,248
#
#                                                imgURL
# 21  https://rukminim2.flixcart.com/image/312/312/t...  \
# 16  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 21  Internal Storage32 GBRAM3 GBExpandable Storage...  \
# 16  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                          os_processor
# 21  Operating SystemAndroid Pie 9Processor TypeMed...  \
# 16  Operating SystemAndroid Pie 10Processor TypeEx...
#
#                                                camera
# 21  Primary Camera AvailableYesPrimary Camera13MP ...  \
# 16  Primary Camera48MP Rear CameraDual Camera Lens...
#
#                                               display
# 21  Display Size15.75 cm (6.2 inch)Resolution720 x...  \
# 16  Display Size16.26 cm (6.4 inch)Resolution2340 ...
#
#                                               network
# 21  Network Type4G, 3G, 2GSupported NetworksGSM, W...  \
# 16  Network Type4G VOLTESupported Networks4G VoLTE...
#
#                                             battery
# 21                         Battery Capacity4000 mAh
# 16  Battery Capacity6000 mAhBattery Typelithium-ion
# df : df shape : (480, 10)
#                                                name ratings    price
# 50        SAMSUNG Galaxy S21 FE 5G (White, 128 GB)     4.3  ₹31,999  \
# 122  SAMSUNG Galaxy S23 5G (Phantom Black, 256 GB)     4.5  ₹79,999
#
#                                                 imgURL
# 50   https://rukminim2.flixcart.com/image/312/312/l...  \
# 122  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                          storage_ram
# 50   Internal Storage128 GBRAM8 GBCall Log MemoryYes  \
# 122  Internal Storage256 GBRAM8 GBTotal Memory256 GB
#
#                                           os_processor
# 50   Operating SystemAndroid 12Processor CoreOcta C...  \
# 122  Operating SystemAndroid 13Processor TypeQualco...
#
#                                                 camera
# 50   Primary Camera AvailableYesPrimary Camera12MP ...  \
# 122  Primary Camera AvailableYesPrimary Camera50MP ...
#
#                                                display
# 50   Display Size16.26 cm (6.4 inch)Resolution2340 ...  \
# 122  Display Size15.49 cm (6.1 inch)Resolution2340 ...
#
#                                                network
# 50   Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 122  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                                     battery
# 50   Battery Capacity4500 mAhDual BatteryNo
# 122  Battery Capacity3900 mAhDual BatteryNo
#
# Length of mob_names: 24
# Length of mob_ratings: 23
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 22
# Length of camera: 24
# Length of display: 24
# Length of network: 23
# Length of battery: 24
# scraping data from page:21
# working in https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=21 Page
# page df : page_shape : (24, 10)
#                                                name ratings    price
# 9    SAMSUNG Galaxy A70s (Prism Crush Red, 128 GB)     4.3  ₹31,000  \
# 6  SAMSUNG Galaxy M42 5G (Prism Dot Black, 128 GB)     4.3  ₹21,450
#
#                                               imgURL
# 9  https://rukminim2.flixcart.com/image/312/312/k...  \
# 6  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                          storage_ram
# 9  Internal Storage128 GBRAM6 GBExpandable Storag...  \
# 6  Internal Storage128 GBRAM6 GBTotal Memory128 G...
#
#                                         os_processor
# 9  Operating SystemAndroid Pie 10Processor TypeEx...  \
# 6  Operating SystemAndroid Pie 9.0Processor TypeE...
#
#                                               camera
# 9  Primary Camera AvailableYesPrimary Camera64MP ...  \
# 6  Primary Camera48MP Rear CameraDual Camera Lens...
#
#                                              display
# 9  Display Size17.02 cm (6.7 inch)Resolution1080 ...  \
# 6  Display Size16.76 cm (6.6 inch)Resolution720 x...
#
#                                              network                   battery
# 9  Network Type3G, 4G, 2GSupported NetworksGSM, W...  Battery Capacity4500 mAh
# 6  Network Type5GSupported Networks5GWi-FiYesNFCY...  Battery Capacity5000 mAh
# df : df shape : (504, 10)
#                                                  name ratings    price
# 240                OPPO Reno10 5G (Ice Blue, 256 GB)     4.3  ₹32,999  \
# 486  SAMSUNG Galaxy M42 5G (Prism Dot Black, 128 GB)     4.3  ₹21,450
#
#                                                 imgURL
# 240  https://rukminim2.flixcart.com/image/312/312/x...  \
# 486  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 240  Internal Storage256 GBRAM8 GBSupported Memory ...  \
# 486  Internal Storage128 GBRAM6 GBTotal Memory128 G...
#
#                                           os_processor
# 240  Operating SystemAndroid 13Processor TypeDimens...  \
# 486  Operating SystemAndroid Pie 9.0Processor TypeE...
#
#                                                 camera
# 240  Primary Camera AvailableYesPrimary Camera64MP ...  \
# 486  Primary Camera48MP Rear CameraDual Camera Lens...
#
#                                                display
# 240  Display Size17.02 cm (6.7 inch)Resolution2412 ...  \
# 486  Display Size16.76 cm (6.6 inch)Resolution720 x...
#
#                                                network
# 240  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 486  Network Type5GSupported Networks5GWi-FiYesNFCY...
#
#                       battery
# 240  Battery Capacity5000 mAh
# 486  Battery Capacity5000 mAh
#
# Length of mob_names: 24
# Length of mob_ratings: 23
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:22
# working in https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=22 Page
# page df : page_shape : (24, 10)
#                                  name ratings    price
# 2  OPPO Reno10 5G (Ice Blue, 256 GB)     4.3  ₹32,999  \
# 6  SAMSUNG Galaxy A12 (Blue, 128 GB)     4.1  ₹17,999
#
#                                               imgURL
# 2  https://rukminim2.flixcart.com/image/312/312/x...  \
# 6  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                          storage_ram
# 2  Internal Storage256 GBRAM8 GBSupported Memory ...  \
# 6  Internal Storage128 GBRAM6 GBExpandable Storag...
#
#                                         os_processor
# 2  Operating SystemAndroid 13Processor TypeDimens...  \
# 6  Operating SystemAndroid 10Processor TypeMediaT...
#
#                                               camera
# 2  Primary Camera AvailableYesPrimary Camera64MP ...  \
# 6  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                              display
# 2  Display Size17.02 cm (6.7 inch)Resolution2412 ...  \
# 6  Display Size16.51 cm (6.5 inch)Resolution1600 ...
#
#                                              network                   battery
# 2  Network Type5G, 4G, 3G, 2GSupported Networks5G...  Battery Capacity5000 mAh
# 6  Network Type4G, 3G, 2GSupported Networks4G LTE...  Battery Capacity5000 mAh
# df : df shape : (528, 10)
#                                                    name ratings      price
# 202  SAMSUNG Galaxy S23 Ultra 5G Smartphone (Cream,...     4.7  ₹1,11,000  \
# 162        SAMSUNG Galaxy S23 Ultra 5G (Green, 256 GB)       4  ₹1,24,999
#
#                                                 imgURL
# 202  https://rukminim2.flixcart.com/image/312/312/x...  \
# 162  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                           storage_ram
# 202  Internal Storage256 GBRAM12 GBTotal Memory256 GB  \
# 162  Internal Storage256 GBRAM12 GBTotal Memory256 GB
#
#                                           os_processor
# 202  Operating SystemAndroid 13Processor TypeQualco...  \
# 162  Operating SystemAndroid 13Processor TypeQualco...
#
#                                                 camera
# 202  Primary Camera AvailableYesPrimary Camera200MP...  \
# 162  Primary Camera AvailableYesPrimary Camera200MP...
#
#                                                display
# 202  Display Size17.27 cm (6.8 inch)Resolution3088 ...  \
# 162  Display Size17.27 cm (6.8 inch)Resolution3088 ...
#
#                                                network
# 202  Network Type5G, 4G, 3G, 2GSupported Networks5G...  \
# 162  Network Type5G, 4G, 3G, 2GSupported Networks5G...
#
#                                     battery
# 202  Battery Capacity5000 mAhDual BatteryNo
# 162  Battery Capacity5000 mAhDual BatteryNo
#
# Length of mob_names: 24
# Length of mob_ratings: 22
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:23
# working in https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=23 Page
# page df : page_shape : (24, 10)
#                                               name ratings    price
# 18  SAMSUNG Galaxy A70s (Prism Crush Red, 128 GB)     4.3  ₹32,000  \
# 6                SAMSUNG Galaxy M02 (Gray, 32 GB)     4.3   ₹8,499
#
#                                                imgURL
# 18  https://rukminim2.flixcart.com/image/312/312/k...  \
# 6   https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 18  Internal Storage128 GBRAM8 GBExpandable Storag...  \
# 6   Internal Storage32 GBRAM3 GBMemory Card Slot T...
#
#                                          os_processor
# 18  Operating SystemAndroid Pie 9Processor TypeQua...  \
# 6   Operating SystemAndroid Pie 10Processor TypeMe...
#
#                                                camera
# 18  Primary Camera AvailableYesPrimary Camera64MP ...  \
# 6   Primary Camera AvailableYesPrimary Camera13MP ...
#
#                                               display
# 18  Display Size17.02 cm (6.7 inch)Resolution1080 ...  \
# 6   Display Size16.64 cm (6.55 inch)Resolution720 ...
#
#                                               network
# 18  Network Type3G, 4G, 2GSupported NetworksGSM, W...  \
# 6   Network Type4G VOLTESupported Networks4G VoLTE...
#
#                                             battery
# 18                         Battery Capacity4500 mAh
# 6   Battery Capacity5000 mAhBattery Typelithium-ion
# df : df shape : (552, 10)
#                                            name ratings    price
# 33                        SAMSUNG Guru Music 2     4.3   ₹2,890  \
# 340  SAMSUNG Galaxy M21 (Midnight Blue, 64 GB)     4.2  ₹14,248
#
#                                                 imgURL
# 33   https://rukminim2.flixcart.com/image/312/312/k...  \
# 340  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 33   Internal StorageNAPhone Book MemoryYesCall Log...  \
# 340  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                           os_processor
# 33   Operating System0Primary Clock Speed208 MHzOpe...  \
# 340  Operating SystemAndroid Pie 10Processor TypeEx...
#
#                                                 camera
# 33   Primary Camera50MP Rear CameraDual Camera Lens...  \
# 340  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                                display
# 33   Display Size5.08 cm (2 inch)Resolution128 x 16...  \
# 340  Display Size16.26 cm (6.4 inch)Resolution2340 ...
#
#                                                network
# 33   Network Type2GSupported NetworksGSMUSB Connect...  \
# 340  Network Type4G VOLTESupported Networks4G VoLTE...
#
#                                              battery
# 33          Battery Capacity800 mAhBattery TypeLi-on
# 340  Battery Capacity6000 mAhBattery Typelithium-ion
#
# Length of mob_names: 24
# Length of mob_ratings: 22
# Length of mob_price: 24
# Length of mob_img_URL: 24
# Length of storage_ram: 24
# Length of os_processor: 24
# Length of camera: 24
# Length of display: 24
# Length of network: 24
# Length of battery: 24
# scraping data from page:24
# working in https://www.flipkart.com/search?q=samsung+mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=24 Page
# page df : page_shape : (24, 10)
#                                            name ratings    price
# 11   SAMSUNG Galaxy M31s (Mirage Blue, 128 GB)     4.1  ₹18,999  \
# 17  SAMSUNG Galaxy M40 (Seawater Blue, 128 GB)     4.5  ₹21,490
#
#                                                imgURL
# 11  https://rukminim2.flixcart.com/image/312/312/k...  \
# 17  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                           storage_ram
# 11  Internal Storage128 GBRAM6 GBMemory Card Slot ...  \
# 17  Internal Storage128 GBRAM6 GBMemory Card Slot ...
#
#                                          os_processor
# 11  Operating SystemAndroid Q V10Processor CoreOct...  \
# 17  Operating SystemAndroid Pie 9.0Processor CoreO...
#
#                                                camera
# 11  Primary Camera64MP Rear CameraDual Camera Lens...  \
# 17  Primary Camera32MP Rear CameraDual Camera Lens...
#
#                                               display
# 11  Display Size16.51 cm (6.5 inch)Resolution1080 ...  \
# 17  Display Size16.0 cm (6.3 inch)Resolution2340 x...
#
#                                               network
# 11  Network Type4G VOLTE, 3GSupported Networks4G V...  \
# 17  Network Type4G, 3G, 2GSupported Networks4G LTE...
#
#                      battery
# 11  Battery Capacity6000 mAh
# 17  Battery Capacity3500 mAh
# df : df shape : (576, 10)
#                                                 name ratings    price
# 469  SAMSUNG Galaxy A71 (Haze Crush Silver, 128 GB)     4.3  ₹29,499  \
# 404                 SAMSUNG Galaxy On7 (Gold, 8 GB)     4.2   ₹5,999
#
#                                                 imgURL
# 469  https://rukminim2.flixcart.com/image/312/312/k...  \
# 404  https://rukminim2.flixcart.com/image/312/312/m...
#
#                                            storage_ram
# 469  Internal Storage128 GBRAM8 GBExpandable Storag...  \
# 404  Internal Storage8 GBRAM1.5 GBExpandable Storag...
#
#                                           os_processor
# 469  Operating SystemAndroid 10Processor TypeQualco...  \
# 404  Operating SystemAndroid 10Processor TypeMediat...
#
#                                                 camera
# 469  Primary Camera AvailableYesPrimary Camera48MP ...  \
# 404  Primary Camera AvailableYesPrimary Camera48MP ...
#
#                                                display
# 469  Display Size17.02 cm (6.7 inch)Resolution2340 ...  \
# 404  Display Size13.97 cm (5.5 inch)Resolution1280 ...
#
#                                                network
# 469  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...  \
# 404  Network Type3G, 4GSupported Networks4G LTEInte...
#
#                                         battery
# 469                    Battery Capacity4500 mAh
# 404  Battery Capacity3000 mAhBattery TypeLi-Ion

# %%
df
# Out:
#                                                 name ratings    price
# 0         SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)     4.3   ₹9,499  \
# 1        SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)     4.3  ₹10,499
# 2        SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)     4.3  ₹10,499
# 3        SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)     4.3  ₹10,499
# 4          SAMSUNG Galaxy F23 5G (Aqua Blue, 128 GB)     4.3  ₹15,499
# ..                                               ...     ...      ...
# 571  SAMSUNG Galaxy A30s (Prism Crush Violet, 64 GB)     4.3  ₹16,199
# 572            SAMSUNG Galaxy J4 Plus (Black, 32 GB)     4.4   ₹9,000
# 573   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)     4.2  ₹34,999
# 574                SAMSUNG Galaxy M01s (Gray, 32 GB)     NaN  ₹10,999
# 575           SAMSUNG Galaxy S22 (Pink Gold, 128 GB)     NaN  ₹85,999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 571  https://rukminim2.flixcart.com/image/312/312/k...
# 572  https://rukminim2.flixcart.com/image/312/312/j...
# 573  https://rukminim2.flixcart.com/image/312/312/k...
# 574  https://rukminim2.flixcart.com/image/312/312/k...
# 575  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 0    Internal Storage64 GBRAM4 GBExpandable Storage...  \
# 1    Internal Storage128 GBRAM4 GBExpandable Storag...
# 2    Internal Storage128 GBRAM4 GBExpandable Storag...
# 3    Internal Storage128 GBRAM4 GBExpandable Storag...
# 4    Internal Storage128 GBRAM6 GBTotal Memory128 G...
# ..                                                 ...
# 571  Internal Storage64 GBRAM4 GBSupported Memory C...
# 572  Internal Storage32 GBRAM2 GBExpandable Storage...
# 573  Internal Storage128 GBRAM8 GBExpandable Storag...
# 574  Internal Storage32 GBRAM3 GBExpandable Storage...
# 575  Internal Storage128 GBRAM8 GBMemory Card Slot ...
#
#                                           os_processor
# 0    Operating SystemAndroid 12Processor TypeExynos...  \
# 1    Operating SystemAndroid 12Processor TypeExynos...
# 2    Operating SystemAndroid 12Processor TypeExynos...
# 3    Operating SystemAndroid 12Processor TypeExynos...
# 4    Operating SystemAndroid 12Processor TypeQualco...
# ..                                                 ...
# 571  Operating SystemAndroid Pie 9.0Processor TypeE...
# 572  Operating SystemAndroid Oreo 8.1Processor Type...
# 573  Operating SystemAndroid 10Processor TypeQualco...
# 574  Operating SystemAndroid Pie 9Processor TypeMed...
# 575  Operating SystemAndroid Android 12.0Processor ...
#
#                                                 camera
# 0    Primary Camera AvailableYesPrimary Camera50MP ...  \
# 1    Primary Camera AvailableYesPrimary Camera50MP ...
# 2    Primary Camera AvailableYesPrimary Camera50MP ...
# 3    Primary Camera AvailableYesPrimary Camera50MP ...
# 4    Primary Camera AvailableYesPrimary Camera50MP ...
# ..                                                 ...
# 571  Primary Camera AvailableYesPrimary Camera25MP ...
# 572  Primary Camera AvailableYesPrimary Camera13MP ...
# 573  Primary Camera AvailableYesPrimary Camera64MP ...
# 574  Primary Camera AvailableYesPrimary Camera13MP ...
# 575  Primary Camera50MP Rear CameraDual Camera Lens...
#
#                                                display
# 0    Display Size16.76 cm (6.6 inch)Resolution2408 ...  \
# 1    Display Size16.76 cm (6.6 inch)Resolution2408 ...
# 2    Display Size16.76 cm (6.6 inch)Resolution2408 ...
# 3    Display Size16.76 cm (6.6 inch)Resolution2408 ...
# 4    Display Size16.76 cm (6.6 inch)Resolution2408 ...
# ..                                                 ...
# 571  Display Size16.26 cm (6.4 inch)Resolution1920 ...
# 572  Display Size15.24 cm (6 inch)Resolution720 x 1...
# 573  Display Size17.02 cm (6.7 inch)Resolution2340 ...
# 574  Display Size15.75 cm (6.2 inch)Resolution720 x...
# 575  Display Size15.49 cm (6.1 inch)Resolution2340x...
#
#                                                network
# 0    Network Type4G, 3G, 2GSupported Networks4G LTE...  \
# 1    Network Type4G, 3G, 2GSupported Networks4G LTE...
# 2    Network Type4G, 3G, 2GSupported Networks4G LTE...
# 3    Network Type4G, 3G, 2GSupported Networks4G LTE...
# 4    Network Type5G, 4G, 3G, 2GSupported Networks5G...
# ..                                                 ...
# 571  Network Type3G, 4G, 2GSupported NetworksGSM, W...
# 572  Network Type3G, 4G, 2GSupported NetworksGSM, W...
# 573  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 574  Network Type4G VOLTE, 3GSupported Networks4G V...
# 575                 Network Type5GSupported Networks5G
#
#                                              battery
# 0             Battery Capacity6000 mAhDual BatteryNo
# 1             Battery Capacity6000 mAhDual BatteryNo
# 2             Battery Capacity6000 mAhDual BatteryNo
# 3             Battery Capacity6000 mAhDual BatteryNo
# 4                           Battery Capacity5000 mAh
# ..                                               ...
# 571                         Battery Capacity4000 mAh
# 572           Battery Capacity3300 mAhDual BatteryNo
# 573                         Battery Capacity4500 mAh
# 574  Battery Capacity4000 mAhBattery Typelithium-ion
# 575                         Battery Capacity3700 mAh
#
# [576 rows x 10 columns]

# %%
print(os.getcwd())
os.chdir(r'd:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem')
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem\notebook\data_Ingestion\scraping
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem

# %%
df.to_csv(r'data\raw_data\samsung_mobile_new_data.csv',index=False)
