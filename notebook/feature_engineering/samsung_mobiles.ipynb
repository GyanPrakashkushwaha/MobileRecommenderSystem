# %%
import pandas as pd
import os
import numpy as np
from ensure import ensure_annotations
import re
import warnings
warnings.filterwarnings('ignore')

# %%
print(os.getcwd())
print(os.chdir(r'd:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem'))
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem\notebook\feature_engineering
# None
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem

# %%
df = pd.read_csv('data\data_to_merge\samsung_data.csv',index_col=None)

# %%
df
# Out:
#                                      model_names  ratings    price
# 0         SAMSUNG Galaxy F04 (Opal Green, 64 GB)      4.2   ₹8,499  \
# 1     SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)      4.3  ₹10,999
# 2     SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)      4.3  ₹10,999
# 3     SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)      4.3  ₹10,999
# 4    SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)      4.3  ₹11,999
# ..                                           ...      ...      ...
# 490                       SAMSUNG SM-B310EZDDINS      4.3   ₹2,149
# 491           SAMSUNG Galaxy M11 (Violet, 64 GB)      4.6  ₹12,999
# 492              SAMSUNG Galaxy M01 (Red, 32 GB)      4.1   ₹8,999
# 493            SAMSUNG Galaxy A12 (Blue, 128 GB)      4.2  ₹14,999
# 494   SAMSUNG Galaxy A52 (Awesome White, 128 GB)      4.2  ₹30,499
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 490  https://rukminim2.flixcart.com/image/312/312/k...
# 491  https://rukminim2.flixcart.com/image/312/312/k...
# 492  https://rukminim2.flixcart.com/image/312/312/k...
# 493  https://rukminim2.flixcart.com/image/312/312/k...
# 494  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 0    Internal Storage64 GBRAM4 GBTotal Memory64 GBE...  \
# 1    Internal Storage64 GBRAM4 GBExpandable Storage...
# 2    Internal Storage64 GBRAM4 GBExpandable Storage...
# 3    Internal Storage64 GBRAM4 GBExpandable Storage...
# 4    Internal Storage128 GBRAM4 GBExpandable Storag...
# ..                                                 ...
# 490  Internal Storage64 GBRAM4 GBExpandable Storage...
# 491  Internal Storage32 GBRAM3 GBExpandable Storage...
# 492  Internal Storage128 GBRAM4 GBExpandable Storag...
# 493  Internal Storage128 GBRAM6 GBExpandable Storag...
# 494  Internal Storage64 GBRAM6 GBExpandable Storage...
#
#                                           os_processor
# 0    Operating SystemAndroid 12Processor TypeMediat...  \
# 1    Operating SystemAndroid 12Processor TypeExynos...
# 2    Operating SystemAndroid 12Processor TypeExynos...
# 3    Operating SystemAndroid 12Processor TypeExynos...
# 4    Operating SystemAndroid 12Processor TypeExynos...
# ..                                                 ...
# 490  Operating SystemAndroid 13Processor TypeQualco...
# 491  Operating SystemAndroid Pie 10Processor TypeEx...
# 492  Operating SystemAndroid Nougat 7Processor Type...
# 493  Operating SystemAndroid 11Processor TypeMediaT...
# 494  Operating SystemAndroid 10Processor TypeQualco...
#
#                                                network
# 0    Network Type4G, 3G, 2GSupported NetworksGSM, C...  \
# 1    Network Type4G, 3G, 2GSupported Networks4G LTE...
# 2    Network Type4G, 3G, 2GSupported Networks4G LTE...
# 3    Network Type4G, 3G, 2GSupported Networks4G LTE...
# 4    Network Type4G, 3G, 2GSupported Networks4G LTE...
# ..                                                 ...
# 490  Network Type5G, 4G, 3G, 2GSupported Networks5G...
# 491  Network Type4G, 3G, 2GSupported Networks4G LTE...
# 492  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...
# 493  Network Type3G, 4G, 2GSupported NetworksGSM, W...
# 494  Network Type3G, 4G, 2GSupported NetworksGSM, W...
#
#                                     battery
# 0    Battery Capacity5000 mAhDual BatteryNo
# 1    Battery Capacity6000 mAhDual BatteryNo
# 2    Battery Capacity6000 mAhDual BatteryNo
# 3    Battery Capacity6000 mAhDual BatteryNo
# 4    Battery Capacity6000 mAhDual BatteryNo
# ..                                      ...
# 490                Battery Capacity5000 mAh
# 491                Battery Capacity4000 mAh
# 492                Battery Capacity5000 mAh
# 493                Battery Capacity4500 mAh
# 494                Battery Capacity4000 mAh
#
# [495 rows x 8 columns]

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df.drop_duplicates(inplace=True,ignore_index=True)

# %% [markdown]
# ## Battery

# %%
def extract_battery(row):
    return row.split()[1]

# %%
df['battery'] = df['battery'].apply(func=extract_battery)

# %%
count = 0
for i in range(0,len(df['battery'])):
    # print(i)
    df['battery'][i]= df['battery'].iloc[i].replace('Capacity','')
    # print(df['battery'][i])
    count+=1
print(f'looped till {count} index')
# Out:
# looped till 492 index

# %%
df['battery'] = df['battery'].astype('Int16')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 492 entries, 0 to 491
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model_names   492 non-null    object
#  1   ratings       492 non-null    float64
#  2   price         492 non-null    object
#  3   imgURL        492 non-null    object
#  4   storage_ram   492 non-null    object
#  5   os_processor  492 non-null    object
#  6   network       492 non-null    object
#  7   battery       492 non-null    Int16
# dtypes: Int16(1), float64(1), object(6)
# memory usage: 28.5+ KB

# %%
df
# Out:
#                                      model_names  ratings    price
# 0         SAMSUNG Galaxy F04 (Opal Green, 64 GB)      4.2   ₹8,499  \
# 1     SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)      4.3  ₹10,999
# 2     SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)      4.3  ₹10,999
# 3     SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)      4.3  ₹10,999
# 4    SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)      4.3  ₹11,999
# ..                                           ...      ...      ...
# 487                       SAMSUNG SM-B310EZDDINS      4.3   ₹2,149
# 488           SAMSUNG Galaxy M11 (Violet, 64 GB)      4.6  ₹12,999
# 489              SAMSUNG Galaxy M01 (Red, 32 GB)      4.1   ₹8,999
# 490            SAMSUNG Galaxy A12 (Blue, 128 GB)      4.2  ₹14,999
# 491   SAMSUNG Galaxy A52 (Awesome White, 128 GB)      4.2  ₹30,499
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 487  https://rukminim2.flixcart.com/image/312/312/k...
# 488  https://rukminim2.flixcart.com/image/312/312/k...
# 489  https://rukminim2.flixcart.com/image/312/312/k...
# 490  https://rukminim2.flixcart.com/image/312/312/k...
# 491  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 0    Internal Storage64 GBRAM4 GBTotal Memory64 GBE...  \
# 1    Internal Storage64 GBRAM4 GBExpandable Storage...
# 2    Internal Storage64 GBRAM4 GBExpandable Storage...
# 3    Internal Storage64 GBRAM4 GBExpandable Storage...
# 4    Internal Storage128 GBRAM4 GBExpandable Storag...
# ..                                                 ...
# 487  Internal Storage64 GBRAM4 GBExpandable Storage...
# 488  Internal Storage32 GBRAM3 GBExpandable Storage...
# 489  Internal Storage128 GBRAM4 GBExpandable Storag...
# 490  Internal Storage128 GBRAM6 GBExpandable Storag...
# 491  Internal Storage64 GBRAM6 GBExpandable Storage...
#
#                                           os_processor
# 0    Operating SystemAndroid 12Processor TypeMediat...  \
# 1    Operating SystemAndroid 12Processor TypeExynos...
# 2    Operating SystemAndroid 12Processor TypeExynos...
# 3    Operating SystemAndroid 12Processor TypeExynos...
# 4    Operating SystemAndroid 12Processor TypeExynos...
# ..                                                 ...
# 487  Operating SystemAndroid 13Processor TypeQualco...
# 488  Operating SystemAndroid Pie 10Processor TypeEx...
# 489  Operating SystemAndroid Nougat 7Processor Type...
# 490  Operating SystemAndroid 11Processor TypeMediaT...
# 491  Operating SystemAndroid 10Processor TypeQualco...
#
#                                                network  battery
# 0    Network Type4G, 3G, 2GSupported NetworksGSM, C...     5000
# 1    Network Type4G, 3G, 2GSupported Networks4G LTE...     6000
# 2    Network Type4G, 3G, 2GSupported Networks4G LTE...     6000
# 3    Network Type4G, 3G, 2GSupported Networks4G LTE...     6000
# 4    Network Type4G, 3G, 2GSupported Networks4G LTE...     6000
# ..                                                 ...      ...
# 487  Network Type5G, 4G, 3G, 2GSupported Networks5G...     5000
# 488  Network Type4G, 3G, 2GSupported Networks4G LTE...     4000
# 489  Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...     5000
# 490  Network Type3G, 4G, 2GSupported NetworksGSM, W...     4500
# 491  Network Type3G, 4G, 2GSupported NetworksGSM, W...     4000
#
# [492 rows x 8 columns]

# %% [markdown]
# ## Storage and Ram

# %%
def extract_storage(row):
    storage = row.split()[1]
    return storage

def extract_ram(row):
    ram = row.split()[2]
    return ram

df['storage'] = df['storage_ram'].apply(func=extract_storage)
df['ram'] = df['storage_ram'].apply(func=extract_ram)

# %%
import warnings
warnings.filterwarnings('ignore')
count = 0
for i in range(0,len(df['storage'])):
    df['storage'][i]= df['storage'].iloc[i].replace('Storage','')
    count+=1
print(f'looped till {count} index')
# Out:
# looped till 492 index

# %%
df['storage'] = df['storage'].astype('Int16')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df['storage'] = df['storage'].astype('Int16')
#
# File c:\Users\Gyanprakash\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File c:\Users\Gyanprakash\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# --> 451 return self.apply(
#     452     "astype",
#     453     dtype=dtype,
#     454     copy=copy,
#     455     errors=errors,
#     456     using_cow=using_copy_on_write(),
#     457 )
#
# File c:\Users\Gyanprakash\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353     result_blocks = extend_blocks(applied, result_blocks)
#     355 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\Gyanprakash\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:511, in Block.astype(self, dtype, copy, errors, using_cow)
#     491 """
#     492 Coerce to the new dtype.
#     493
#    (...)
#     507 Block
#     508 """
#     509 values = self.values
# --> 511 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     513 new_values = maybe_coerce_values(new_values)
#     515 refs = None
#
# File c:\Users\Gyanprakash\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:242, in astype_array_safe(values, dtype, copy, errors)
#     239     dtype = dtype.numpy_dtype
#     241 try:
# --> 242     new_values = astype_array(values, dtype, copy=copy)
#     243 except (ValueError, TypeError):
#     244     # e.g. _astype_nansafe can fail on object-dtype of strings
#     245     #  trying to convert to float
#     246     if errors == "ignore":
#
# File c:\Users\Gyanprakash\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:187, in astype_array(values, dtype, copy)
#     184     values = values.astype(dtype, copy=copy)
#     186 else:
# --> 187     values = _astype_nansafe(values, dtype, copy=copy)
#     189 # in pandas we don't store numpy str dtypes, so convert to object
#     190 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\Gyanprakash\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:84, in _astype_nansafe(arr, dtype, copy, skipna)
#      82 # dispatch on extension dtype if needed
#      83 if isinstance(dtype, ExtensionDtype):
# ---> 84     return dtype.construct_array_type()._from_sequence(arr, dtype=dtype, copy=copy)
#      86 elif not isinstance(dtype, np.dtype):  # pragma: no cover
#      87     raise ValueError("dtype must be np.dtype or ExtensionDtype")
#
# File c:\Users\Gyanprakash\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arrays\masked.py:140, in BaseMaskedArray._from_sequence(cls, scalars, dtype, copy)
#     136 @classmethod
#     137 def _from_sequence(
#     138     cls: type[BaseMaskedArrayT], scalars, *, dtype=None, copy: bool = False
#     139 ) -> BaseMaskedArrayT:
# --> 140     values, mask = cls._coerce_to_array(scalars, dtype=dtype, copy=copy)
#     141     return cls(values, mask)
#
# File c:\Users\Gyanprakash\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arrays\numeric.py:277, in NumericArray._coerce_to_array(cls, value, dtype, copy)
#     275 default_dtype = dtype_cls._default_np_dtype
#     276 mask = None
# --> 277 values, mask, _, _ = _coerce_to_data_and_mask(
#     278     value, mask, dtype, copy, dtype_cls, default_dtype
#     279 )
#     280 return values, mask
#
# File c:\Users\Gyanprakash\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arrays\numeric.py:231, in _coerce_to_data_and_mask(values, mask, dtype, copy, dtype_cls, default_dtype)
#     227     values[mask] = cls._internal_fill_value
#     228 if inferred_type in ("string", "unicode"):
#     229     # casts from str are always safe since they raise
#     230     # a ValueError if the str cannot be parsed into a float
# --> 231     values = values.astype(dtype, copy=copy)
#     232 else:
#     233     values = dtype_cls._safe_cast(values, dtype, copy=False)
#
# ValueError: invalid literal for int() with base 10: 'NACall'

# %%
import warnings
warnings.filterwarnings('ignore')
count = 0
for i in range(0,len(df['ram'])):
    # df['ram'][i]= df['ram'].iloc[i].replace('MBRAM','')
    df['ram'][i]= df['ram'].iloc[i].replace('GBRAM','')
    count+=1
print(f'looped till {count} index')
# Out:
# looped till 501 index

# %%
df[df['ram'] == 'MBRAM64']
# Out:
#        model_names  ratings price
# 276      Peace Mi4      3.8  ₹849  \
# 319  Peace Mi3 Pro      3.7  ₹799
# 360      Peace Mi2      4.5  ₹849
#
#                                                 imgURL
# 276  https://rukminim2.flixcart.com/image/312/312/x...  \
# 319  https://rukminim2.flixcart.com/image/312/312/x...
# 360  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 276  Internal Storage128 MBRAM64 MBMemory Card Slot...  \
# 319  Internal Storage128 MBRAM64 MBMemory Card Slot...
# 360  Internal Storage128 MBRAM64 MBMemory Card Slot...
#
#                                         os_processor
# 276  Operating System1.77Primary Clock Speed1.77 MHz  \
# 319  Operating System1.77Primary Clock Speed1.77 MHz
# 360  Operating System1.77Primary Clock Speed1.77 MHz
#
#                                  network  battery  storage      ram
# 276  Network Type2GSupported NetworksGSM     2500      128  MBRAM64
# 319  Network Type2GSupported NetworksGSM     2500      128  MBRAM64
# 360  Network Type2GSupported NetworksGSM     2500      128  MBRAM64

# %%
df.drop(index=[276,319,360],inplace=True)

# %%
df['ram'] = df['ram'].astype('Int16')

# %%
df.reset_index(inplace=True)

# %% [markdown]
# ## Processors

# %%
def extract_processor(text):
    pattern = r'.*Processor'
    match = re.findall(pattern, text)
    if match:
        return match[0]
    else:
        return text

# %%
df['processors'] = df['os_processor'].apply(func=extract_processor)

# %% [markdown]
# ## Android Version

# %%
def android_version(text_):
    pattern=r'^\d+[Processor]|\d+[GProcessor]|\d+[.Processor]'
    found = re.findall(pattern,text_)
    if found:
        return found[0]
    else:
        return np.nan

# %%
df['android_version'] = df['processors'].apply(android_version)

# %%
for Index,i in enumerate(df['android_version']):
    # print(i)
    i = str(i).replace('P','')
    i = str(i).replace('.','')
    df['android_version'][Index] = i

# %%
# df['android_version'] = df['android_version'].astype('Int16')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            498 non-null    int64
#  1   model_names      498 non-null    object
#  2   ratings          498 non-null    float64
#  3   price            498 non-null    object
#  4   imgURL           498 non-null    object
#  5   storage_ram      498 non-null    object
#  6   os_processor     498 non-null    object
#  7   network          498 non-null    object
#  8   battery          498 non-null    Int16
#  9   storage          498 non-null    Int16
#  10  ram              498 non-null    Int16
#  11  processors       498 non-null    object
#  12  android_version  498 non-null    object
# dtypes: Int16(3), float64(1), int64(1), object(8)
# memory usage: 43.4+ KB

# %%
# df

# %% [markdown]
# ## Processors

# %%
def processor(text):
    pattern=r'(?<=Type).*'
    search = re.search(pattern,text)
    if search != None:
        return ' '.join(re.findall(pattern,text))
    else:
        return 'not montioned'

# %%
df['processors'] = df['processors'].apply(processor)

# %%
df
# Out:
#      index                             model_names  ratings    price
# 0        0  REDMI 10 Power (Sporty Orange, 128 GB)      4.2  ₹13,500  \
# 1        1    REDMI 10 Power (Power Black, 128 GB)      4.2  ₹12,840
# 2        2   Redmi 9A Sport (Metallic Blue, 32 GB)      4.1   ₹7,520
# 3        3     Redmi 9A Sport (Coral Green, 32 GB)      4.2   ₹8,450
# 4        4  Xiaomi 11Lite NE (Vinyl Black, 128 GB)      4.2  ₹21,644
# ..     ...                                     ...      ...      ...
# 493    496      Xiaomi 11i 5G (Camo Green, 128 GB)      4.5  ₹26,999
# 494    497              Redmi Note 3 (Gold, 32 GB)      4.1   ₹8,999
# 495    498   Redmi Note 8 (Moonlight White, 32 GB)      4.3  ₹11,990
# 496    499    MI 11X 5G (CELESTIAL SILVER, 128 GB)      4.3  ₹24,999
# 497    500           Redmi Note 5 Pro (Red, 64 GB)      4.1  ₹12,500
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 493  https://rukminim2.flixcart.com/image/312/312/k...
# 494  https://rukminim2.flixcart.com/image/312/312/m...
# 495  https://rukminim2.flixcart.com/image/312/312/k...
# 496  https://rukminim2.flixcart.com/image/312/312/k...
# 497  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                            storage_ram
# 0    Internal Storage128 GBRAM8 GBMemory Card Slot ...  \
# 1    Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 2    Internal Storage32 GBRAM2 GBMemory Card Slot T...
# 3    Internal Storage32 GBRAM3 GBMemory Card Slot T...
# 4    Internal Storage128 GBRAM6 GBExpandable Storag...
# ..                                                 ...
# 493  Internal Storage32 GBRAM3 GBExpandable Storage...
# 494  Internal Storage32 GBRAM3 GBMemory Card Slot T...
# 495                      Internal Storage128 GBRAM6 GB
# 496  Internal Storage64 GBRAM4 GBExpandable Storage...
# 497  Internal Storage64 GBRAM4 GBExpandable Storage...
#
#                                           os_processor
# 0    Operating SystemAndroid 13Processor CoreOcta C...  \
# 1    Operating SystemAndroid 13Processor CoreOcta C...
# 2    Operating SystemAndroid Q 10Processor CoreOcta...
# 3    Operating SystemAndroid Q 10Processor CoreOcta...
# 4    Operating SystemAndroid 11Processor TypeQualco...
# ..                                                 ...
# 493  Operating SystemAndroid Lollipop 5.1Processor ...
# 494  Operating SystemAndroid Pie 9Processor CoreOct...
# 495  Operating SystemAndroid Nougat 11Processor Cor...
# 496  Operating SystemAndroid Nougat 7.1.2Processor ...
# 497  Operating SystemAndroid Nougat 7.1.2Processor ...
#
#                                                network  battery  storage  ram
# 0         Network Type4G VOLTESupported Networks4G LTE     6000      128    8  \
# 1       Network Type4G VOLTESupported Networks4G VoLTE     6000      128    8
# 2     Network Type4G VOLTE, 4GSupported Networks4G LTE     5000       32    2
# 3    Network Type4G VOLTE, 4GSupported Networks4G V...     5000       32    3
# 4    Network Type5G, 4G VOLTESupported Networks5G, ...     4250      128    6
# ..                                                 ...      ...      ...  ...
# 493  Network Type3G, 4GSupported NetworksGSM, 4G LT...     4050       32    3
# 494  Network Type4G VOLTESupported Networks4G LTEBl...     4000       32    3
# 495  Network Type4G VOLTE, 5GSupported Networks4G V...     4520      128    6
# 496  Network Type3G, 4G VOLTE, 4GSupported Networks...     4000       64    4
# 497  Network Type3G, 4G, 2GSupported NetworksGSM, W...     3080       64    4
#
#                                            processors android_version
# 0                                       not montioned              13
# 1                                       not montioned              13
# 2                                       not montioned              10
# 3                                       not montioned              10
# 4                   Qualcomm Snapdragon 778GProcessor              11
# ..                                                ...             ...
# 493  Qualcomm Snapdragon 650 64-bit 0 1.8GHzProcessor               5
# 494                                     not montioned               9
# 495                                     not montioned              11
# 496                  Qualcomm Snapdragon 636Processor               7
# 497                  Qualcomm Snapdragon 435Processor               7
#
# [498 rows x 13 columns]

# %% [markdown]
# ## Remove columns
# 1) storage_ram
# 2) os_processor

# %%
df = df.drop(columns=['os_processor','storage_ram'])

# %%
df.rename({'processors':'processor'},axis=1,inplace=True)

# %%
# df.tail()

# %% [markdown]
# ## Price

# %%
for Index,i in enumerate(df['price']):
    i = str(i).replace('₹','')
    i = str(i).replace(',','')
    df['price'][Index] = i

# %%
df['price'] = df['price'].astype('Int16')

# %%
df
# Out:
#      index                             model_names  ratings  price
# 0        0  REDMI 10 Power (Sporty Orange, 128 GB)      4.2  13500  \
# 1        1    REDMI 10 Power (Power Black, 128 GB)      4.2  12840
# 2        2   Redmi 9A Sport (Metallic Blue, 32 GB)      4.1   7520
# 3        3     Redmi 9A Sport (Coral Green, 32 GB)      4.2   8450
# 4        4  Xiaomi 11Lite NE (Vinyl Black, 128 GB)      4.2  21644
# ..     ...                                     ...      ...    ...
# 493    496      Xiaomi 11i 5G (Camo Green, 128 GB)      4.5  26999
# 494    497              Redmi Note 3 (Gold, 32 GB)      4.1   8999
# 495    498   Redmi Note 8 (Moonlight White, 32 GB)      4.3  11990
# 496    499    MI 11X 5G (CELESTIAL SILVER, 128 GB)      4.3  24999
# 497    500           Redmi Note 5 Pro (Red, 64 GB)      4.1  12500
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/x...
# ..                                                 ...
# 493  https://rukminim2.flixcart.com/image/312/312/k...
# 494  https://rukminim2.flixcart.com/image/312/312/m...
# 495  https://rukminim2.flixcart.com/image/312/312/k...
# 496  https://rukminim2.flixcart.com/image/312/312/k...
# 497  https://rukminim2.flixcart.com/image/312/312/j...
#
#                                                network  battery  storage  ram
# 0         Network Type4G VOLTESupported Networks4G LTE     6000      128    8  \
# 1       Network Type4G VOLTESupported Networks4G VoLTE     6000      128    8
# 2     Network Type4G VOLTE, 4GSupported Networks4G LTE     5000       32    2
# 3    Network Type4G VOLTE, 4GSupported Networks4G V...     5000       32    3
# 4    Network Type5G, 4G VOLTESupported Networks5G, ...     4250      128    6
# ..                                                 ...      ...      ...  ...
# 493  Network Type3G, 4GSupported NetworksGSM, 4G LT...     4050       32    3
# 494  Network Type4G VOLTESupported Networks4G LTEBl...     4000       32    3
# 495  Network Type4G VOLTE, 5GSupported Networks4G V...     4520      128    6
# 496  Network Type3G, 4G VOLTE, 4GSupported Networks...     4000       64    4
# 497  Network Type3G, 4G, 2GSupported NetworksGSM, W...     3080       64    4
#
#                                             processor android_version
# 0                                       not montioned              13
# 1                                       not montioned              13
# 2                                       not montioned              10
# 3                                       not montioned              10
# 4                   Qualcomm Snapdragon 778GProcessor              11
# ..                                                ...             ...
# 493  Qualcomm Snapdragon 650 64-bit 0 1.8GHzProcessor               5
# 494                                     not montioned               9
# 495                                     not montioned              11
# 496                  Qualcomm Snapdragon 636Processor               7
# 497                  Qualcomm Snapdragon 435Processor               7
#
# [498 rows x 11 columns]

# %% [markdown]
# ## Processor

# %%
df['processor']
# Out:
# 0                                         not montioned
# 1                                         not montioned
# 2                                         not montioned
# 3                                         not montioned
# 4                     Qualcomm Snapdragon 778GProcessor
#                              ...
# 493    Qualcomm Snapdragon 650 64-bit 0 1.8GHzProcessor
# 494                                       not montioned
# 495                                       not montioned
# 496                    Qualcomm Snapdragon 636Processor
# 497                    Qualcomm Snapdragon 435Processor
# Name: processor, Length: 498, dtype: object

# %%
@ensure_annotations
def random_values(feature_name:str,total=6):
    for i in range(0,total):
        index = np.random.randint(df.shape[0])
        print(index,':',df[feature_name].iloc[index])

# %%
random_values('processor',10)
# Out:
# 92 : Mediatek Dimensity 920Processor
# 15 : 2.0 GHz Mediatek P22 OctacoreProcessor
# 489 : Qualcomm Snapdragon 410 MSM8916Processor
# 116 : Qualcomm Snapdragon 730Processor
# 229 : not montioned
# 382 : Qualcomm® Snapdragon™ 720GProcessor
# 22 : Qualcomm Snapdragon 636Processor
# 77 : Qualcomm Snapdragon 636Processor
# 340 : not montioned
# 289 : not montioned

# %%
def processor_extract(text):
    splitted_sentence = text.split()
    if 'Mediatek' and 'Helio' in splitted_sentence:
        pattern = r'\d+[Processor]'
        string = ' '.join(splitted_sentence)
        match = re.findall(pattern,string)
        return 'Heilo'+''.join(match)

    elif 'Mediatek' and 'Dimensity' in splitted_sentence:
        pattern = r'\d+[Processor]'
        string = ' '.join(splitted_sentence)
        match = re.findall(pattern,string)
        return 'Dimensity'+ ''.join(match)

    elif 'Snapdragon' and 'Gen' and '4' in splitted_sentence:
        return 'Gen4'   

    elif 'Snapdragon' and 'Gen' and '8' in splitted_sentence:         
        return 'Gen8'
    
    elif 'Snapdragon' in splitted_sentence:
        pattern = r'\d+[Processor]|\d+[GProcessor]'
        if 'Gen' and '4' and '8' not in splitted_sentence:
            string = ' '.join(splitted_sentence)
            match = re.findall(pattern,string)
            return 'Snapdragon'+''.join(match)

    else:
        return 'not mentioned'

# %%
df['processor']=df['processor'].apply(processor_extract)

# %%
random_values('processor')
# Out:
# 26 : not mentioned
# 193 : Dimensity1080P
# 355 : not mentioned
# 462 : Snapdragon
# 251 : Heilo35P
# 472 : Snapdragon855P

# %% [markdown]
# ## Network
# I don't need in my project I will just drop.

# %%
df = df.drop(labels=['network'],axis=1)

# %%
df
# Out:
#      index                             model_names  ratings  price
# 0        0  REDMI 10 Power (Sporty Orange, 128 GB)      4.2  13500  \
# 1        1    REDMI 10 Power (Power Black, 128 GB)      4.2  12840
# 2        2   Redmi 9A Sport (Metallic Blue, 32 GB)      4.1   7520
# 3        3     Redmi 9A Sport (Coral Green, 32 GB)      4.2   8450
# 4        4  Xiaomi 11Lite NE (Vinyl Black, 128 GB)      4.2  21644
# ..     ...                                     ...      ...    ...
# 493    496      Xiaomi 11i 5G (Camo Green, 128 GB)      4.5  26999
# 494    497              Redmi Note 3 (Gold, 32 GB)      4.1   8999
# 495    498   Redmi Note 8 (Moonlight White, 32 GB)      4.3  11990
# 496    499    MI 11X 5G (CELESTIAL SILVER, 128 GB)      4.3  24999
# 497    500           Redmi Note 5 Pro (Red, 64 GB)      4.1  12500
#
#                                                 imgURL  battery  storage  ram
# 0    https://rukminim2.flixcart.com/image/312/312/x...     6000      128    8  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...     6000      128    8
# 2    https://rukminim2.flixcart.com/image/312/312/x...     5000       32    2
# 3    https://rukminim2.flixcart.com/image/312/312/x...     5000       32    3
# 4    https://rukminim2.flixcart.com/image/312/312/x...     4250      128    6
# ..                                                 ...      ...      ...  ...
# 493  https://rukminim2.flixcart.com/image/312/312/k...     4050       32    3
# 494  https://rukminim2.flixcart.com/image/312/312/m...     4000       32    3
# 495  https://rukminim2.flixcart.com/image/312/312/k...     4520      128    6
# 496  https://rukminim2.flixcart.com/image/312/312/k...     4000       64    4
# 497  https://rukminim2.flixcart.com/image/312/312/j...     3080       64    4
#
#           processor android_version
# 0     not mentioned              13
# 1     not mentioned              13
# 2     not mentioned              10
# 3     not mentioned              10
# 4    Snapdragon778G              11
# ..              ...             ...
# 493    Snapdragon8G               5
# 494   not mentioned               9
# 495   not mentioned              11
# 496  Snapdragon636P               7
# 497  Snapdragon435P               7
#
# [498 rows x 10 columns]

# %%
df.to_csv(path_or_buf='data\cleaned_dataset/mi_cleaned_data.csv')
