# %%
import pandas as pd
import os
import numpy as np
from ensure import ensure_annotations
import re
import warnings
warnings.filterwarnings('ignore')

# %%
print(os.getcwd())
print(os.chdir(r'd:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem'))
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem
# None
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem

# %%
df = pd.read_csv(r'data\raw_data\mi_mobile_new_data.csv',index_col=None)

# %%
df.drop_duplicates(inplace=True,ignore_index=True)

# %% [markdown]
# ## Battery

# %%
def extract_battery(row):
    return row.split()[1]

# %%
df['battery'] = df['battery'].apply(func=extract_battery)

# %%
count = 0
for i in range(0,len(df['battery'])):
    # print(i)
    df['battery'][i]= df['battery'].iloc[i].replace('Capacity','')
    # print(df['battery'][i])
    count+=1
print(f'looped till {count} index')
# Out:
# looped till 517 index

# %%
df['battery'] = df['battery'].astype('Int16')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          517 non-null    object
#  1   ratings       490 non-null    float64
#  2   price         517 non-null    object
#  3   imgURL        517 non-null    object
#  4   storage_ram   517 non-null    object
#  5   os_processor  517 non-null    object
#  6   camera        516 non-null    object
#  7   display       517 non-null    object
#  8   network       517 non-null    object
#  9   battery       517 non-null    Int16
# dtypes: Int16(1), float64(1), object(8)
# memory usage: 38.0+ KB

# %% [markdown]
# ## Storage and Ram

# %%
def extract_storage(row):
    storage = row.split()[1]
    return storage

def extract_ram(row):
    ram = row.split()[2]
    return ram

df['storage'] = df['storage_ram'].apply(func=extract_storage)
df['ram'] = df['storage_ram'].apply(func=extract_ram)

# %%
import warnings
warnings.filterwarnings('ignore')
count = 0
for i in range(0,len(df['storage'])):
    df['storage'][i]= df['storage'].iloc[i].replace('Storage','')
    count+=1
print(f'looped till {count} index')
# Out:
# looped till 517 index

# %%
df['storage'] = df['storage'].astype('Int16')

# %%
import warnings
warnings.filterwarnings('ignore')
count = 0
for i in range(0,len(df['ram'])):
    # df['ram'][i]= df['ram'].iloc[i].replace('MBRAM','')
    df['ram'][i]= df['ram'].iloc[i].replace('GBRAM','')
    count+=1
print(f'looped till {count} index')
# Out:
# looped till 517 index

# %%
df[df['ram'] == 'MBRAM64']
# Out:
#           name  ratings price
# 294  Peace Mi4      3.8  ₹849  \
# 397  Peace Mi2      4.4  ₹849
#
#                                                 imgURL
# 294  https://rukminim2.flixcart.com/image/312/312/x...  \
# 397  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                            storage_ram
# 294  Internal Storage128 MBRAM64 MBMemory Card Slot...  \
# 397  Internal Storage128 MBRAM64 MBMemory Card Slot...
#
#                                         os_processor
# 294  Operating System1.77Primary Clock Speed1.77 MHz  \
# 397  Operating System1.77Primary Clock Speed1.77 MHz
#
#                                                 camera
# 294  Primary Camera13MP Rear CameraDual Camera Lens...  \
# 397                    Primary Camera0.3MP Rear Camera
#
#                                                display
# 294  Display Size4.57 cm (1.8 inch)Resolution128x16...  \
# 397  Display Size50.8 cm (20 inch)Resolution320x240...
#
#                                  network  battery  storage      ram
# 294  Network Type2GSupported NetworksGSM     2500      128  MBRAM64
# 397  Network Type2GSupported NetworksGSM     2500      128  MBRAM64

# %%
df.drop(index=df[df['ram'] == 'MBRAM64'].index,inplace=True)

# %%
df['ram'] = df['ram'].astype('Int16')

# %%
df.reset_index(inplace=True)

# %% [markdown]
# ## Processors

# %%
def extract_processor(text):
    pattern = r'.*Processor'
    match = re.findall(pattern, text)
    if match:
        return match[0]
    else:
        return text

# %%
df['processors'] = df['os_processor'].apply(func=extract_processor)

# %% [markdown]
# ## Android Version

# %%
def android_version(text_):
    pattern=r'^\d+[Processor]|\d+[GProcessor]|\d+[.Processor]'
    found = re.findall(pattern,text_)
    if found:
        return found[0]
    else:
        return np.nan

# %%
df['android_version'] = df['processors'].apply(android_version)

# %%
for Index,i in enumerate(df['android_version']):
    # print(i)
    i = str(i).replace('P','')
    i = str(i).replace('.','')
    df['android_version'][Index] = i

# %%
# df['android_version'] = df['android_version'].astype('Int16')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515 entries, 0 to 514
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            515 non-null    int64
#  1   name             515 non-null    object
#  2   ratings          488 non-null    float64
#  3   price            515 non-null    object
#  4   imgURL           515 non-null    object
#  5   storage_ram      515 non-null    object
#  6   os_processor     515 non-null    object
#  7   camera           514 non-null    object
#  8   display          515 non-null    object
#  9   network          515 non-null    object
#  10  battery          515 non-null    Int16
#  11  storage          515 non-null    Int16
#  12  ram              515 non-null    Int16
#  13  processors       515 non-null    object
#  14  android_version  515 non-null    object
# dtypes: Int16(3), float64(1), int64(1), object(10)
# memory usage: 52.9+ KB

# %%
# df

# %% [markdown]
# ## Processors

# %%
def processor(text):
    pattern=r'(?<=Type).*'
    search = re.search(pattern,text)
    if search != None:
        return ' '.join(re.findall(pattern,text))
    else:
        return 'not montioned'

# %%
df['processors'] = df['processors'].apply(processor)

# %%
df
# Out:
#      index                                       name  ratings    price
# 0        0        Redmi 9A Sport (Coral Green, 32 GB)      4.2   ₹8,990  \
# 1        1     Xiaomi 11Lite NE (Vinyl Black, 128 GB)      4.2  ₹21,430
# 2        2  Xiaomi 11Lite NE (Diamond Dazzle, 128 GB)      4.2  ₹20,999
# 3        3   Xiaomi 11Lite NE (Tuscany Coral, 128 GB)      4.2  ₹20,999
# 4        4             Mi 11 Lite (Jazz Blue, 128 GB)      4.2  ₹17,499
# ..     ...                                        ...      ...      ...
# 510    512               Mi A3 (Not just Blue, 64 GB)      4.2  ₹14,999
# 511    513          Mi 10T Pro (Lunar Silver, 128 GB)      4.3  ₹26,899
# 512    514                     Redmi Y1 (Gold, 32 GB)      4.5   ₹8,999
# 513    515    Redmi Note 7 Pro (Neptune Blue, 128 GB)      4.3  ₹17,999
# 514    516           Mi 10i (Pacific Sunrise, 128 GB)      NaN  ₹20,999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/k...
# ..                                                 ...
# 510  https://rukminim2.flixcart.com/image/312/312/k...
# 511  https://rukminim2.flixcart.com/image/312/312/k...
# 512  https://rukminim2.flixcart.com/image/312/312/j...
# 513  https://rukminim2.flixcart.com/image/312/312/j...
# 514  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                            storage_ram
# 0    Internal Storage32 GBRAM3 GBMemory Card Slot T...  \
# 1    Internal Storage128 GBRAM6 GBExpandable Storag...
# 2    Internal Storage128 GBRAM6 GBExpandable Storag...
# 3    Internal Storage128 GBRAM6 GBExpandable Storag...
# 4    Internal Storage128 GBRAM8 GBExpandable Storag...
# ..                                                 ...
# 510  Internal Storage64 GBRAM4 GBExpandable Storage...
# 511    Internal Storage128 GBRAM8 GBCall Log MemoryYes
# 512  Internal Storage32 GBRAM3 GBExpandable Storage...
# 513  Internal Storage128 GBRAM6 GBExpandable Storag...
# 514  Internal Storage128 GBRAM6 GBSupported Memory ...
#
#                                           os_processor
# 0    Operating SystemAndroid Q 10Processor CoreOcta...  \
# 1    Operating SystemAndroid 11Processor TypeQualco...
# 2    Operating SystemAndroid 11Processor TypeQualco...
# 3    Operating SystemAndroid 11Processor TypeQualco...
# 4    Operating SystemAndroid 11Processor TypeQualco...
# ..                                                 ...
# 510  Operating SystemAndroid Pie 9Processor TypeQua...
# 511  Operating SystemAndroid 10Processor TypeQualco...
# 512  Operating SystemAndroid Nougat 7.1.2Processor ...
# 513  Operating SystemAndroid Pie 9.0Processor TypeQ...
# 514  Operating SystemAndroid Q 11Processor TypeQual...
#
#                                                 camera
# 0                       Primary Camera13MP Rear Camera  \
# 1    Primary Camera AvailableYesPrimary Camera64MP ...
# 2    Primary Camera AvailableYesPrimary Camera64MP ...
# 3    Primary Camera AvailableYesPrimary Camera64MP ...
# 4    Primary Camera AvailableYesPrimary Camera64MP ...
# ..                                                 ...
# 510  Primary Camera AvailableYesPrimary Camera48MP ...
# 511  Primary Camera AvailableYesPrimary Camera108MP...
# 512  Primary Camera AvailableYesPrimary Camera13MP ...
# 513  Primary Camera AvailableYesPrimary Camera48MP ...
# 514  Primary Camera AvailableYesPrimary Camera108MP...
#
#                                                display
# 0    Display Size16.59 cm (6.53 inch)Resolution1600...  \
# 1    Display Size16.64 cm (6.55 inch)Resolution1080...
# 2    Display Size16.64 cm (6.55 inch)Resolution1080...
# 3    Display Size16.64 cm (6.55 inch)Resolution1080...
# 4    Display Size16.64 cm (6.55 inch)Resolution2400...
# ..                                                 ...
# 510  Display Size15.46 cm (6.088 inch)Resolution156...
# 511  Display Size16.94 cm (6.67 inch)Resolution2400...
# 512  Display Size13.97 cm (5.5 inch)Resolution1280 ...
# 513  Display Size16.0 cm (6.3 inch)Resolution2340 x...
# 514  Display Size16.94 cm (6.67 inch)Resolution2400...
#
#                                                network  battery  storage  ram
# 0    Network Type4G VOLTE, 4GSupported Networks4G V...     5000       32    3  \
# 1    Network Type5G, 4G VOLTESupported Networks5G, ...     4250      128    6
# 2    Network Type5G, 4G VOLTESupported Networks5G, ...     4250      128    6
# 3    Network Type5G, 4G VOLTESupported Networks5G, ...     4250      128    6
# 4    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...     4250      128    8
# ..                                                 ...      ...      ...  ...
# 510  Network Type4G VOLTE, 4G, 2G, 3GSupported Netw...     4030       64    4
# 511  Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...     5000      128    8
# 512  Network Type3G, 4G, 2GSupported NetworksGSM, W...     3080       32    3
# 513  Network Type3G, 4G VOLTE, 2GSupported Networks...     4000      128    6
# 514  Network Type5GSupported Networks5GInternet Con...     4820      128    6
#
#                               processors android_version
# 0                          not montioned              10
# 1      Qualcomm Snapdragon 778GProcessor              11
# 2      Qualcomm Snapdragon 778GProcessor              11
# 3      Qualcomm Snapdragon 778GProcessor              11
# 4      Qualcomm Snapdragon 732GProcessor              11
# ..                                   ...             ...
# 510     Qualcomm Snapdragon 665Processor               9
# 511     Qualcomm Snapdragon 865Processor              10
# 512     Qualcomm Snapdragon 435Processor               7
# 513     Qualcomm Snapdragon 675Processor               9
# 514  Qualcomm® Snapdragon™ 750GProcessor              11
#
# [515 rows x 15 columns]

# %% [markdown]
# ## Remove columns
# 1) storage_ram
# 2) os_processor

# %%
df = df.drop(columns=['os_processor','storage_ram'])

# %%
df.rename({'processors':'processor'},axis=1,inplace=True)

# %%
# df.tail()

# %% [markdown]
# ## Price

# %%
for Index,i in enumerate(df['price']):
    i = str(i).replace('₹','')
    i = str(i).replace(',','')
    df['price'][Index] = i

# %%
df['price'] = df['price'].astype('Int16')

# %%
df
# Out:
#      index                                       name  ratings  price
# 0        0        Redmi 9A Sport (Coral Green, 32 GB)      4.2   8990  \
# 1        1     Xiaomi 11Lite NE (Vinyl Black, 128 GB)      4.2  21430
# 2        2  Xiaomi 11Lite NE (Diamond Dazzle, 128 GB)      4.2  20999
# 3        3   Xiaomi 11Lite NE (Tuscany Coral, 128 GB)      4.2  20999
# 4        4             Mi 11 Lite (Jazz Blue, 128 GB)      4.2  17499
# ..     ...                                        ...      ...    ...
# 510    512               Mi A3 (Not just Blue, 64 GB)      4.2  14999
# 511    513          Mi 10T Pro (Lunar Silver, 128 GB)      4.3  26899
# 512    514                     Redmi Y1 (Gold, 32 GB)      4.5   8999
# 513    515    Redmi Note 7 Pro (Neptune Blue, 128 GB)      4.3  17999
# 514    516           Mi 10i (Pacific Sunrise, 128 GB)      NaN  20999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/k...
# ..                                                 ...
# 510  https://rukminim2.flixcart.com/image/312/312/k...
# 511  https://rukminim2.flixcart.com/image/312/312/k...
# 512  https://rukminim2.flixcart.com/image/312/312/j...
# 513  https://rukminim2.flixcart.com/image/312/312/j...
# 514  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                                 camera
# 0                       Primary Camera13MP Rear Camera  \
# 1    Primary Camera AvailableYesPrimary Camera64MP ...
# 2    Primary Camera AvailableYesPrimary Camera64MP ...
# 3    Primary Camera AvailableYesPrimary Camera64MP ...
# 4    Primary Camera AvailableYesPrimary Camera64MP ...
# ..                                                 ...
# 510  Primary Camera AvailableYesPrimary Camera48MP ...
# 511  Primary Camera AvailableYesPrimary Camera108MP...
# 512  Primary Camera AvailableYesPrimary Camera13MP ...
# 513  Primary Camera AvailableYesPrimary Camera48MP ...
# 514  Primary Camera AvailableYesPrimary Camera108MP...
#
#                                                display
# 0    Display Size16.59 cm (6.53 inch)Resolution1600...  \
# 1    Display Size16.64 cm (6.55 inch)Resolution1080...
# 2    Display Size16.64 cm (6.55 inch)Resolution1080...
# 3    Display Size16.64 cm (6.55 inch)Resolution1080...
# 4    Display Size16.64 cm (6.55 inch)Resolution2400...
# ..                                                 ...
# 510  Display Size15.46 cm (6.088 inch)Resolution156...
# 511  Display Size16.94 cm (6.67 inch)Resolution2400...
# 512  Display Size13.97 cm (5.5 inch)Resolution1280 ...
# 513  Display Size16.0 cm (6.3 inch)Resolution2340 x...
# 514  Display Size16.94 cm (6.67 inch)Resolution2400...
#
#                                                network  battery  storage  ram
# 0    Network Type4G VOLTE, 4GSupported Networks4G V...     5000       32    3  \
# 1    Network Type5G, 4G VOLTESupported Networks5G, ...     4250      128    6
# 2    Network Type5G, 4G VOLTESupported Networks5G, ...     4250      128    6
# 3    Network Type5G, 4G VOLTESupported Networks5G, ...     4250      128    6
# 4    Network Type4G VOLTE, 4G, 3G, 2GSupported Netw...     4250      128    8
# ..                                                 ...      ...      ...  ...
# 510  Network Type4G VOLTE, 4G, 2G, 3GSupported Netw...     4030       64    4
# 511  Network Type5G, 4G VOLTE, 4G, 3G, 2GSupported ...     5000      128    8
# 512  Network Type3G, 4G, 2GSupported NetworksGSM, W...     3080       32    3
# 513  Network Type3G, 4G VOLTE, 2GSupported Networks...     4000      128    6
# 514  Network Type5GSupported Networks5GInternet Con...     4820      128    6
#
#                                processor android_version
# 0                          not montioned              10
# 1      Qualcomm Snapdragon 778GProcessor              11
# 2      Qualcomm Snapdragon 778GProcessor              11
# 3      Qualcomm Snapdragon 778GProcessor              11
# 4      Qualcomm Snapdragon 732GProcessor              11
# ..                                   ...             ...
# 510     Qualcomm Snapdragon 665Processor               9
# 511     Qualcomm Snapdragon 865Processor              10
# 512     Qualcomm Snapdragon 435Processor               7
# 513     Qualcomm Snapdragon 675Processor               9
# 514  Qualcomm® Snapdragon™ 750GProcessor              11
#
# [515 rows x 13 columns]

# %% [markdown]
# ## Processor

# %%
df['processor']
# Out:
# 0                            not montioned
# 1        Qualcomm Snapdragon 778GProcessor
# 2        Qualcomm Snapdragon 778GProcessor
# 3        Qualcomm Snapdragon 778GProcessor
# 4        Qualcomm Snapdragon 732GProcessor
#                       ...
# 510       Qualcomm Snapdragon 665Processor
# 511       Qualcomm Snapdragon 865Processor
# 512       Qualcomm Snapdragon 435Processor
# 513       Qualcomm Snapdragon 675Processor
# 514    Qualcomm® Snapdragon™ 750GProcessor
# Name: processor, Length: 515, dtype: object

# %%
@ensure_annotations
def random_values(feature_name:str,total=6):
    for i in range(0,total):
        index = np.random.randint(df.shape[0])
        print(index,':',df[feature_name].iloc[index])

# %%
random_values('processor',10)
# Out:
# 280 : not montioned
# 385 : Qualcomm Snapdragon 678Processor
# 35 : Qualcomm Snapdragon 439Processor
# 306 : not montioned
# 59 : Qualcomm Snapdragon 625Processor
# 244 : not montioned
# 214 : Mediatek Dimensity 1080Processor
# 7 : not montioned
# 83 : Qualcomm Snapdragon 439Processor
# 60 : not montioned

# %%
def processor_extract(text):
    splitted_sentence = text.split()
    if 'Mediatek' and 'Helio' in splitted_sentence:
        pattern = r'\d+[Processor]|\d+'
        string = ' '.join(splitted_sentence)
        match = re.search(pattern,string)
        if match == None:
            return 'Heilo'+str(splitted_sentence[2])
        else:
            find = re.findall(pattern,string)
            return 'Heilo'+''.join(find)


    elif 'Mediatek' and 'Dimensity' in splitted_sentence:
        pattern = r'(\d+)+[Processor]'
        string = ' '.join(splitted_sentence)
        match = re.search(pattern,string)
        if match == None:
            if 'Dimensity' == str(splitted_sentence[1]):
                return 'Dimensity'+str(splitted_sentence[2])
            else:
                return 'Dimensity'+str(splitted_sentence[1])
        else:
            find = re.findall(pattern,string)
            return 'Dimensity'+ ''.join(find)
        

    elif 'Snapdragon' and 'Gen' and '4' in splitted_sentence:
        return 'Gen4'   

    elif 'Snapdragon' and 'Gen' and '8' in splitted_sentence:         
        return 'Gen8'

    elif 'Snapdragon' in splitted_sentence:
        pattern = r'\d+[Processor]'
        if 'Gen' and '4' and '8' not in splitted_sentence:
            string = ' '.join(splitted_sentence)
            match = re.search(pattern,string)
            if match == None:
                if 'Snapdragon' == str(splitted_sentence[1]):
                    return 'Snapdragon'+str(splitted_sentence[2])
                else:
                    return 'Snapdragon'+str(splitted_sentence[1])
            else:
                find = re.findall(pattern,string)
                return 'Snapdragon'+''.join(find)
            
    elif 'Snapdragon™' in splitted_sentence and 'Snapdragon™' in splitted_sentence:
        pattern = r'\d+[Processor]|\d+[GProcessor]'
        string = ' '.join(splitted_sentence)
        match = re.findall(pattern,string)
        return 'Snapdragon'+''.join(match)
    

    elif 'MediaTek' == splitted_sentence[0]:
        pattern = r'[P]\d.'
        string = ' '.join(splitted_sentence)
        match = re.findall(pattern,string)
        return 'MediaTek' + ' '.join(match)

    else:
        return 'not mentioned'

# %%
df['processor']=df['processor'].apply(processor_extract)

# %%
random_values('processor')
# Out:
# 231 : not mentioned
# 213 : not mentioned
# 85 : not mentioned
# 41 : Snapdragon625P
# 204 : Snapdragon685P
# 147 : Snapdragon625

# %% [markdown]
# ## Network
# I don't need in my project I will just drop.

# %%
df = df.drop(labels=['network'],axis=1)

# %% [markdown]
# ## Camera

# %%
def camera_extract(row):
    if isinstance(row, str):  # Check if row is a string
        row_splitted = row.split()
        pattern = r'\d+MP'
        words = ' '.join(row_splitted)
        find_cam = re.findall(pattern, words)
        return ' '.join(find_cam)
    else:
        return np.nan

# %%
df['camera'] = df['camera'].apply(camera_extract)
df = df.drop('index',axis=1)

# %%
df
# Out:
#                                           name  ratings  price
# 0          Redmi 9A Sport (Coral Green, 32 GB)      4.2   8990  \
# 1       Xiaomi 11Lite NE (Vinyl Black, 128 GB)      4.2  21430
# 2    Xiaomi 11Lite NE (Diamond Dazzle, 128 GB)      4.2  20999
# 3     Xiaomi 11Lite NE (Tuscany Coral, 128 GB)      4.2  20999
# 4               Mi 11 Lite (Jazz Blue, 128 GB)      4.2  17499
# ..                                         ...      ...    ...
# 510               Mi A3 (Not just Blue, 64 GB)      4.2  14999
# 511          Mi 10T Pro (Lunar Silver, 128 GB)      4.3  26899
# 512                     Redmi Y1 (Gold, 32 GB)      4.5   8999
# 513    Redmi Note 7 Pro (Neptune Blue, 128 GB)      4.3  17999
# 514           Mi 10i (Pacific Sunrise, 128 GB)      NaN  20999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/k...
# ..                                                 ...
# 510  https://rukminim2.flixcart.com/image/312/312/k...
# 511  https://rukminim2.flixcart.com/image/312/312/k...
# 512  https://rukminim2.flixcart.com/image/312/312/j...
# 513  https://rukminim2.flixcart.com/image/312/312/j...
# 514  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                                 camera
# 0                                                 13MP  \
# 1                                    64MP 8MP 5MP 20MP
# 2                                    64MP 8MP 5MP 20MP
# 3                                    64MP 8MP 5MP 20MP
# 4                  64MP 8MP 5MP 64MP 8MP 5MP 16MP 16MP
# ..                                                 ...
# 510                48MP 8MP 2MP 48MP 8MP 2MP 32MP 32MP
# 511  108MP 13MP 5MP 108MP 13MP 5MP 108MP 13MP 5MP 20MP
# 512                                          13MP 16MP
# 513                             48MP 5MP 48MP 5MP 13MP
# 514                       108MP 8MP 2MP 2MP 108MP 16MP
#
#                                                display  battery  storage  ram
# 0    Display Size16.59 cm (6.53 inch)Resolution1600...     5000       32    3  \
# 1    Display Size16.64 cm (6.55 inch)Resolution1080...     4250      128    6
# 2    Display Size16.64 cm (6.55 inch)Resolution1080...     4250      128    6
# 3    Display Size16.64 cm (6.55 inch)Resolution1080...     4250      128    6
# 4    Display Size16.64 cm (6.55 inch)Resolution2400...     4250      128    8
# ..                                                 ...      ...      ...  ...
# 510  Display Size15.46 cm (6.088 inch)Resolution156...     4030       64    4
# 511  Display Size16.94 cm (6.67 inch)Resolution2400...     5000      128    8
# 512  Display Size13.97 cm (5.5 inch)Resolution1280 ...     3080       32    3
# 513  Display Size16.0 cm (6.3 inch)Resolution2340 x...     4000      128    6
# 514  Display Size16.94 cm (6.67 inch)Resolution2400...     4820      128    6
#
#                    processor android_version
# 0              not mentioned              10
# 1    Snapdragon778GProcessor              11
# 2    Snapdragon778GProcessor              11
# 3    Snapdragon778GProcessor              11
# 4    Snapdragon732GProcessor              11
# ..                       ...             ...
# 510           Snapdragon665P               9
# 511           Snapdragon865P              10
# 512           Snapdragon435P               7
# 513           Snapdragon675P               9
# 514           Snapdragon750G              11
#
# [515 rows x 11 columns]

# %% [markdown]
# ## display

# %%
def display_extract(row):
    split_row = row.split()
    if 'LCD' in split_row:
        if 'IPS' in split_row and 'LCD' in split_row:
            return 'IPS LCD'
        return 'LCD'
    
    if 'OLED' in split_row:
        return 'OLED'
    
    if 'TFT' in split_row:
        return 'TFT'
    
    if 'LED' in split_row:
        return 'LED'

    # if 'Adreno' in split_row:
    #     return 'Adreno'
    if 'AMOLED' in split_row:
        if 'HD+' in split_row and 'AMOLED' in split_row:
            return 'HD+ AMOLED'
        return 'AMOLED'
    
    return 'other_types'
# Out:
# Display Size17.09 cm (6.73 inch)Resolution2400 x 1080 PixelsResolution TypeFull HD+GPUQualcomm AdrenoDisplay TypeFull HD+ 2K+ AMOLED DisplayDisplay Colors2KOther Display Features2K+ AMOLED Display, 120Hz Adaptive Sync Pro Display, 1500nits Peak Brightness, Touch Sampling Rate: Upto 480Hz, In-Display Fingerprint, Over 1 Billion Colors, Color Gamut: DCI-P3, Contrast Ratio: 8,000,000: 1, HDR10+ Dolby Vision, 16000 Level Brightness Adjustment, Corning Gorilla Glass Victus, Reading Mode, Sunlight Mode, 360 Degree Ambient Light Sensor, DisplayMate A+SGS, Eye Care Display Certification
# HD+ AMOLED

# %%
random_values('display')
# Out:
# 333 : Display Size16.76 cm (6.6 inch)Resolution2400 x 1080 pixel
# 257 : Display Size16.33 cm (6.43 inch)Resolution720 x 1600 pixel
# 242 : Display Size16.71 cm (6.58 inch)Resolution2408 x 1080 PixelsResolution TypeFull HD+GPUARM Mali-G57 MC2Display TypeFull HD+ LCD DisplayOther Display Features90Hz Refresh Rate, 400nits Peak Brightness
# 299 : Display Size16.33 cm (6.43 inch)Resolution2400 x 1080 Pixels
# 38 : Display Size16.94 cm (6.67 inch)Resolution2400 x 1080 pixelResolution TypeFull HD+GPUAdreno A618Display TypeDotDisplayHD Game SupportYes
# 289 : Display Size16.33 cm (6.43 inch)Resolution2400 x 1080 PixelsResolution TypeFull HD+ Super AMOLED DisplayGPUARM Mali G76Display TypeFHD+ Super AMOLEDHD Game SupportYesDisplay Colors16MOther Display FeaturesContrast Ratio: 4,500,000:1, Color Gamut: DCI-P3, Brightness: HBM 700 nits,1100 nits Peak Brightness, 8-Bit Color, Reading Mode 3.0, Sunlight Mode 2.0, Low Blue Light Certified by SGS

# %%
df['display'] = df['display'].apply(display_extract)

# %%
df
# Out:
#                                           name  ratings  price
# 0          Redmi 9A Sport (Coral Green, 32 GB)      4.2   8990  \
# 1       Xiaomi 11Lite NE (Vinyl Black, 128 GB)      4.2  21430
# 2    Xiaomi 11Lite NE (Diamond Dazzle, 128 GB)      4.2  20999
# 3     Xiaomi 11Lite NE (Tuscany Coral, 128 GB)      4.2  20999
# 4               Mi 11 Lite (Jazz Blue, 128 GB)      4.2  17499
# ..                                         ...      ...    ...
# 510               Mi A3 (Not just Blue, 64 GB)      4.2  14999
# 511          Mi 10T Pro (Lunar Silver, 128 GB)      4.3  26899
# 512                     Redmi Y1 (Gold, 32 GB)      4.5   8999
# 513    Redmi Note 7 Pro (Neptune Blue, 128 GB)      4.3  17999
# 514           Mi 10i (Pacific Sunrise, 128 GB)      NaN  20999
#
#                                                 imgURL
# 0    https://rukminim2.flixcart.com/image/312/312/x...  \
# 1    https://rukminim2.flixcart.com/image/312/312/x...
# 2    https://rukminim2.flixcart.com/image/312/312/x...
# 3    https://rukminim2.flixcart.com/image/312/312/x...
# 4    https://rukminim2.flixcart.com/image/312/312/k...
# ..                                                 ...
# 510  https://rukminim2.flixcart.com/image/312/312/k...
# 511  https://rukminim2.flixcart.com/image/312/312/k...
# 512  https://rukminim2.flixcart.com/image/312/312/j...
# 513  https://rukminim2.flixcart.com/image/312/312/j...
# 514  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                                 camera      display  battery
# 0                                                 13MP  other_types     5000  \
# 1                                    64MP 8MP 5MP 20MP  other_types     4250
# 2                                    64MP 8MP 5MP 20MP  other_types     4250
# 3                                    64MP 8MP 5MP 20MP  other_types     4250
# 4                  64MP 8MP 5MP 64MP 8MP 5MP 16MP 16MP   HD+ AMOLED     4250
# ..                                                 ...          ...      ...
# 510                48MP 8MP 2MP 48MP 8MP 2MP 32MP 32MP  other_types     4030
# 511  108MP 13MP 5MP 108MP 13MP 5MP 108MP 13MP 5MP 20MP  other_types     5000
# 512                                          13MP 16MP  other_types     3080
# 513                             48MP 5MP 48MP 5MP 13MP  other_types     4000
# 514                       108MP 8MP 2MP 2MP 108MP 16MP  other_types     4820
#
#      storage  ram                processor android_version
# 0         32    3            not mentioned              10
# 1        128    6  Snapdragon778GProcessor              11
# 2        128    6  Snapdragon778GProcessor              11
# 3        128    6  Snapdragon778GProcessor              11
# 4        128    8  Snapdragon732GProcessor              11
# ..       ...  ...                      ...             ...
# 510       64    4           Snapdragon665P               9
# 511      128    8           Snapdragon865P              10
# 512       32    3           Snapdragon435P               7
# 513      128    6           Snapdragon675P               9
# 514      128    6           Snapdragon750G              11
#
# [515 rows x 11 columns]

# %%
df.to_csv(path_or_buf='data\cleaned_dataset/mi_cleaned_data.csv')
