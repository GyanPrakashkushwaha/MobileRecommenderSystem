# %%
import pandas as pd
import os
import numpy as np

# %%
print(os.getcwd())
os.chdir(r'd:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem')
print(os.getcwd())
# Out:
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem
# d:\vscode_machineLearning\BEST_PROJECTS\mobileRecommenderSystem

# %%
df = pd.read_csv('data\cleaned_dataset\mi_cleaned_data.csv')

# %%
def random_values(feature_name:str,total=6):
    for i in range(0,total):
        index = np.random.randint(df.shape[0])
        print(index,':',df[feature_name].iloc[index])

# %%
random_values('camera')
# Out:
# 32 : 48MP 8MP 5MP 20MP 20MP
# 476 : 108MP 108MP 8MP 2MP 16MP
# 466 : 13MP 16MP
# 305 : 64MP 8MP 2MP 2MP 64MP 8MP 2MP 2MP 64MP 13MP 13MP
# 395 : 50MP
# 252 : 108MP

# %%
df['camera'][3].split()
# Out:
# ['64MP', '8MP', '5MP', '20MP']

# %%
def camera(txt):
    lst = []
    splitted = txt.split()
    for i in splitted:
        make_int = i.replace('MP','')
        lst.append(int(make_int))
    return max(lst)

# %%
camera(df['camera'][3])
# Out:
# 64

# %%
df[df['camera'].isnull()==True].index
# Out:
# Index([301], dtype='int64')

# %%
df['camera'][df[df['camera'].isnull()==True].index] = '13MP 2MP'
# Out:
# C:\Users\Gyanprakash\AppData\Local\Temp\ipykernel_13028\3182977041.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['camera'][df[df['camera'].isnull()==True].index] = '13MP 2MP'

# %%
df['camera'] =df['camera'].apply(camera)

# %%
random_values('camera')
# Out:
# 42 : 20
# 440 : 108
# 412 : 64
# 84 : 50
# 72 : 12
# 159 : 12

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df.isnull().sum()
# Out:
# name                0
# ratings            27
# price               0
# imgURL              0
# camera              0
# display             0
# battery             0
# storage             0
# ram                 0
# processor           0
# android_version     7
# dtype: int64

# %%
df['android_version'].mode()
# Out:
# 0    11.0
# Name: android_version, dtype: float64

# %%
df[df['android_version'].isnull() == True].fillna(11)
# Out:
#                                         name  ratings  price
# 250              REDMI 10A (Sea Blue, 64 GB)      4.2   8650  \
# 255        REDMI 10A (Charcoal Black, 64 GB)      4.2   9199
# 266   REDMI 9 Activ (Metallic Purple, 64 GB)      4.2   9980
# 296              REDMI 10A (Sea Blue, 32 GB)      4.1   8195
# 313            REDMI 10A (Slate Grey, 32 GB)      4.1   9999
# 324       REDMI 9 Activ (Coral Green, 64 GB)      4.2  10999
# 339  REDMI Note 11 (Starburst White, 128 GB)      4.2  19999
#
#                                                 imgURL  camera      display
# 250  https://rukminim2.flixcart.com/image/312/312/x...      13  other_types  \
# 255  https://rukminim2.flixcart.com/image/312/312/x...      13  other_types
# 266  https://rukminim2.flixcart.com/image/312/312/x...      13  other_types
# 296  https://rukminim2.flixcart.com/image/312/312/x...       5  other_types
# 313  https://rukminim2.flixcart.com/image/312/312/x...      13  other_types
# ...

# %%
df['android_version'] = df['android_version'].replace(np.nan,11)

# %%
random_values('ratings')
# Out:
# 117 : 4.0
# 111 : nan
# 52 : 4.5
# 511 : 4.3
# 361 : 4.4
# 260 : 4.2

# %%
df['ratings'].mode()
# Out:
# 0    4.2
# Name: ratings, dtype: float64

# %%
df[df['ratings'].isnull() == True]
# Out:
#                                                   name  ratings  price
# 69                        Redmi 7A (Matte Gold, 32 GB)      NaN   6999  \
# 93                               Redmi 6 (Blue, 32 GB)      NaN   8999
# 94                        Redmi 7A (Matte Gold, 16 GB)      NaN   6499
# 95   Xiaomi 11T Pro 5G Hyperphone (Celestial Magic,...      NaN  31999
# 96                 Redmi Note 7 (Sapphire Blue, 32 GB)      NaN  12999
# 97                       Mi 10T (Cosmic Black, 128 GB)      NaN -27537
# 98                              Redmi 6 (Black, 64 GB)      NaN  10499
# 99   Xiaomi 11T Pro 5G Hyperphone (Celestial Magic,...      NaN -29537
# 100                         Redmi Note 5 (Gold, 32 GB)      NaN  10999
# 101                   Redmi 8A (Midnight Black, 32 GB)      NaN   7999
# 102                    Redmi Note 4 (Dark Grey, 64 GB)      NaN  12749
# 103                      Mi 11X (Cosmic Black, 128 GB)      NaN  22490
# ...

# %%
df['ratings'] = df['ratings'].replace(np.nan,4.2)

# %%
df.isnull().sum()
# Out:
# name               0
# ratings            0
# price              0
# imgURL             0
# camera             0
# display            0
# battery            0
# storage            0
# ram                0
# processor          0
# android_version    0
# dtype: int64

# %% [markdown]
# ## Price

# %%
random_values('price')
# Out:
# 429 : 6999
# 280 : 13199
# 152 : 14999
# 200 : 6299
# 379 : 9575
# 193 : 10999

# %%
def replace(txt):
    return txt.replace('-','')

# %%
# df['price'] = df['price'].astype(object)

# %%
# df['price'] = df['price'].astype('Int16')

# %%
df['price'] = df['price'].replace('-','')

# %%
random_values('price')
# Out:
# 158 : 15999
# 214 : 24999
# 513 : 17999
# 474 : 12999
# 87 : 24999
# 431 : 6999

# %%
# df['price'] = df['price'].astype(object)
df.reset_index(inplace=True)
for Index,i in enumerate(df['price']):
    if i <= 0:
        i = str(i).replace('-','')
        df['price'][Index] = i
# Out:
# C:\Users\Gyanprakash\AppData\Local\Temp\ipykernel_13028\1706069549.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price'][Index] = i

# %%
random_values('price',10)
# Out:
# 89 : 25537
# 222 : 16999
# 282 : 13945
# 443 : 21599
# 40 : 10280
# 243 : 32537
# 42 : 17999
# 106 : 16999
# 162 : 5999
# 138 : 24999

# %%
df[df['price'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [index, name, ratings, price, imgURL, camera, display, battery, storage, ram, processor, android_version]
# Index: []

# %%
df['price'] = np.floor(pd.to_numeric(df['price'], errors='coerce')).astype('Int16')

# %%
df.reset_index(inplace=True)

# %%
def processor(txt):
    if txt == 'not mentioned':
        return 'otherProcessor'
    return txt

# %%
df['processor'] = df['processor'].apply(processor)

# %%
df
# Out:
#      level_0  index                                       name  ratings
# 0          0      0        Redmi 9A Sport (Coral Green, 32 GB)      4.2  \
# 1          1      1     Xiaomi 11Lite NE (Vinyl Black, 128 GB)      4.2
# 2          2      2  Xiaomi 11Lite NE (Diamond Dazzle, 128 GB)      4.2
# 3          3      3   Xiaomi 11Lite NE (Tuscany Coral, 128 GB)      4.2
# 4          4      4             Mi 11 Lite (Jazz Blue, 128 GB)      4.2
# ..       ...    ...                                        ...      ...
# 510      510    510               Mi A3 (Not just Blue, 64 GB)      4.2
# 511      511    511          Mi 10T Pro (Lunar Silver, 128 GB)      4.3
# 512      512    512                     Redmi Y1 (Gold, 32 GB)      4.5
# 513      513    513    Redmi Note 7 Pro (Neptune Blue, 128 GB)      4.3
# 514      514    514           Mi 10i (Pacific Sunrise, 128 GB)      4.2
#
#      price                                             imgURL  camera
# ...

# %%
df=df.drop(labels=['level_0','index'],axis=1)

# %%
df
# Out:
#                                           name  ratings  price
# 0          Redmi 9A Sport (Coral Green, 32 GB)      4.2   8990  \
# 1       Xiaomi 11Lite NE (Vinyl Black, 128 GB)      4.2  21430
# 2    Xiaomi 11Lite NE (Diamond Dazzle, 128 GB)      4.2  20999
# 3     Xiaomi 11Lite NE (Tuscany Coral, 128 GB)      4.2  20999
# 4               Mi 11 Lite (Jazz Blue, 128 GB)      4.2  17499
# ..                                         ...      ...    ...
# 510               Mi A3 (Not just Blue, 64 GB)      4.2  14999
# 511          Mi 10T Pro (Lunar Silver, 128 GB)      4.3  26899
# 512                     Redmi Y1 (Gold, 32 GB)      4.5   8999
# 513    Redmi Note 7 Pro (Neptune Blue, 128 GB)      4.3  17999
# 514           Mi 10i (Pacific Sunrise, 128 GB)      4.2  20999
#
#                                                 imgURL  camera      display
# 0    https://rukminim2.flixcart.com/image/312/312/x...      13  other_types  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515 entries, 0 to 514
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             515 non-null    object
#  1   ratings          515 non-null    float64
#  2   price            515 non-null    Int16
#  3   imgURL           515 non-null    object
#  4   camera           515 non-null    int64
#  5   display          515 non-null    object
#  6   battery          515 non-null    int64
#  7   storage          515 non-null    int64
#  8   ram              515 non-null    int64
#  9   processor        515 non-null    object
#  10  android_version  515 non-null    float64
# dtypes: Int16(1), float64(2), int64(4), object(4)
# memory usage: 41.9+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515 entries, 0 to 514
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             515 non-null    object
#  1   ratings          515 non-null    float16
#  2   price            515 non-null    Int16
#  3   imgURL           515 non-null    object
#  4   camera           515 non-null    int16
#  5   display          515 non-null    object
#  6   battery          515 non-null    int16
#  7   storage          515 non-null    int16
#  8   ram              515 non-null    int16
#  9   processor        515 non-null    object
#  10  android_version  515 non-null    float16
# dtypes: Int16(1), float16(2), int16(4), object(4)
# memory usage: 23.8+ KB

# %%
for i in df.columns:
    if df[i].dtype == 'int64':
        df[i] = df[i].astype('int16')
    elif df[i].dtype == 'float64':
        df[i] = df[i].astype('float16')

    else:
        pass

# %%
df.to_csv(r'kaggle\data\xiaomiMobilesData.csv',index=False)

# %%
pd.read_csv(r'kaggle\data\xiaomiMobilesData.csv')
# Out:
#                                           name  ratings  price
# 0          Redmi 9A Sport (Coral Green, 32 GB)      4.2   8990  \
# 1       Xiaomi 11Lite NE (Vinyl Black, 128 GB)      4.2  21430
# 2    Xiaomi 11Lite NE (Diamond Dazzle, 128 GB)      4.2  20999
# 3     Xiaomi 11Lite NE (Tuscany Coral, 128 GB)      4.2  20999
# 4               Mi 11 Lite (Jazz Blue, 128 GB)      4.2  17499
# ..                                         ...      ...    ...
# 510               Mi A3 (Not just Blue, 64 GB)      4.2  14999
# 511          Mi 10T Pro (Lunar Silver, 128 GB)      4.3  26899
# 512                     Redmi Y1 (Gold, 32 GB)      4.5   8999
# 513    Redmi Note 7 Pro (Neptune Blue, 128 GB)      4.3  17999
# 514           Mi 10i (Pacific Sunrise, 128 GB)      4.2  20999
#
#                                                 imgURL  camera      display
# 0    https://rukminim2.flixcart.com/image/312/312/x...      13  other_types  \
# ...

# %%
df.columns
# Out:
# Index(['name', 'ratings', 'price', 'imgURL', 'camera', 'display', 'battery',
#        'storage', 'ram', 'processor', 'android_version'],
#       dtype='object')
